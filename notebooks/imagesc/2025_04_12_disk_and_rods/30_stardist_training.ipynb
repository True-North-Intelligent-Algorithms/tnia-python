# %% [markdown]
# ## Stardist training example
#
# This notebook shows how to train a Stardist model to predict disks but not rods (remember the rod images have empty labels)
#
# Before running this notebook a set of patches must exist in the following format.
#
# 1.  Ground Truth are put in a directory called ```/ground truth0```
# 2.  Inputs are put in a directory called ```inputn``` where n is an integer 0...m and represents the channel.  Note:  RGB images may only have one 'channel' directory.
# 3.  In each of the both directories there exist a set of files of the same names.  For example if in the ```inputn``` directory we have ```apples0```, ```apples1```, ```apples2``` label images of the same name must exist in the ```ground truth``` directory.

# %%
import os
from tnia.plotting.plt_helper import imshow_multi2d
import tensorflow as tf
from pathlib import Path
import json

# %% [markdown]
# ## Check what devices we have access to....
#
# Not as important to have a beefy GPU for 2D as it is for 3D, but let's check

# %%
visible_devices = tf.config.list_physical_devices()
print(visible_devices)
# Out:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'), PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# ## Load inputs and ground truth
#
# We load directories called 'input0' and 'ground truth0' which should exist under ```train_path```.  The reason we append '0' to the end of the name is simply because some of the code that generates image and label sets is meant to work on multiple channels (so the 0 is the channel number)

# %%
parent_path = r'D:\images\tnia-python-images\imagesc\2025_04_12_disk_like'
n_rays = 32

train_path = os.path.join(parent_path , 'patches')

with open(os.path.join(train_path , 'info.json'), 'r') as json_file:
    data = json.load(json_file)
    # Access the sub_sample parameter
    sub_sample = data['sub_sample']
    print('sub_sample',sub_sample)
    axes = data['axes']
    print('axes',axes)

image_patch_path = os.path.join(train_path , 'ground truth0')
label_patch_path = os.path.join(train_path , 'input0' )

model_path = os.path.join(parent_path , 'models')

if not os.path.exists(model_path):
    os.makedirs(model_path)

if not os.path.exists(image_patch_path):
    print('image_patch_path does not exist')

if not os.path.exists(label_patch_path):
    print('label_patch_path does not exist')
# Out:
# sub_sample 1
# axes YX

# %% [markdown]
# ## Use a helper to collect the training data
#
# The helper will also optionally normalize the inputs.  However in this case we set ```normalize_input``` to ```False```.
#
# Normalization is a tricky issue sometimes it makes sense to normalize before creating patches, such that the data is normalized based on statistics of a larger region, closer to the normalization range that will be used for prediction.

# %%
from tnia.deeplearning.dl_helper import collect_training_data
add_trivial_channel = False

X, Y = collect_training_data(train_path, sub_sample=1, downsample=False, normalize_input=False, add_trivial_channel = add_trivial_channel)

print('type X ', type(X))
print('type Y ', type(Y))
# Out:
# 100%|██████████| 200/200 [00:02<00:00, 84.46it/s]
# type X  <class 'list'>
# type Y  <class 'list'>

# %% [markdown]
# ## Inspect images
#
# Output training data shapes and plot images to make sure image and label set look OK.  We take a look at the 0th (should be a disk image), and the 100th images (should be a rod image), the labels for the rod image should be empty.

# %%
n=77
print(X[n].shape, Y[n].shape)
print(X[n].min(), X[n].max())
print(Y[n].min(), Y[n].max())
fig=imshow_multi2d([X[n], Y[n]], ['input', 'label'], 1,2)

n=177
print(X[n].shape, Y[n].shape)
print(X[n].min(), X[n].max())
print(Y[n].min(), Y[n].max())
fig=imshow_multi2d([X[n], Y[n]], ['input', 'label'], 1,2)
# Out:
# (256, 256) (256, 256)
# 0.0 0.72591174
# 0 16
# (256, 256) (256, 256)
# 0.021670146 1.0
# 0 0

# %%
from tnia.deeplearning.dl_helper import divide_training_data
import numpy as np

#X_train, Y_train, X_val, Y_val = divide_training_data(X, Y, val_size=2)

X_train = np.array(X)
Y_train = np.array(Y)

X_val = np.array(X[:2])
Y_val = np.array(Y[:2])


print('type X_train ', type(X_train))
# Out:
# type X_train  <class 'numpy.ndarray'>

# %% [markdown]
# ## Create stardist model
#
# In this cell we create the model.  Make sure to rename the model and give it a descriptive name that conveys the training data and setting used.

# %%
from stardist.models import StarDist2D, Config2D

if axes == 'YXC':
    n_channel_in =3
else:
    n_channel_in = 1

model_name = "stardist_disks"
new_model = True

if new_model:

    config = Config2D (n_rays=n_rays, axes=axes,n_channel_in=n_channel_in, train_patch_size = (256,256), unet_n_depth=3)
    model = StarDist2D(config=config, name=model_name, basedir=model_path)
else:
    model = StarDist2D(config=None, name=model_name, basedir=model_path)
# Out:
# Using default values: prob_thresh=0.5, nms_thresh=0.4.

# %% [markdown]
# ## Train the model

# %%
model.train(X_train, Y_train, validation_data=(X_val,Y_val),epochs=75, steps_per_epoch=100)
# Out:
# Epoch 1/75
# 100/100 [==============================] - 31s 196ms/step - loss: 3.0222 - prob_loss: 0.2450 - dist_loss: 13.8858 - prob_kld: 0.1915 - dist_relevant_mae: 13.8846 - dist_relevant_mse: 377.4656 - dist_dist_iou_metric: 0.1386 - val_loss: 2.5601 - val_prob_loss: 0.3040 - val_dist_loss: 11.2803 - val_prob_kld: 0.1984 - val_dist_relevant_mae: 11.2787 - val_dist_relevant_mse: 286.6292 - val_dist_dist_iou_metric: 0.2839 - lr: 3.0000e-04
# Epoch 2/75
# 100/100 [==============================] - 17s 173ms/step - loss: 1.9819 - prob_loss: 0.1758 - dist_loss: 9.0305 - prob_kld: 0.1255 - dist_relevant_mae: 9.0288 - dist_relevant_mse: 190.1107 - dist_dist_iou_metric: 0.3034 - val_loss: 2.2932 - val_prob_loss: 0.2852 - val_dist_loss: 10.0399 - val_prob_kld: 0.1797 - val_dist_relevant_mae: 10.0385 - val_dist_relevant_mse: 246.0228 - val_dist_dist_iou_metric: 0.3232 - lr: 3.0000e-04
# Epoch 3/75
# 100/100 [==============================] - 17s 175ms/step - loss: 1.8391 - prob_loss: 0.1807 - dist_loss: 8.2919 - prob_kld: 0.1297 - dist_relevant_mae: 8.2903 - dist_relevant_mse: 170.8079 - dist_dist_iou_metric: 0.3409 - val_loss: 2.1284 - val_prob_loss: 0.2187 - val_dist_loss: 9.5484 - val_prob_kld: 0.1132 - val_dist_relevant_mae: 9.5471 - val_dist_relevant_mse: 238.8400 - val_dist_dist_iou_metric: 0.3108 - lr: 3.0000e-04
# Epoch 4/75
# 100/100 [==============================] - 17s 173ms/step - loss: 1.4312 - prob_loss: 0.1453 - dist_loss: 6.4295 - prob_kld: 0.0949 - dist_relevant_mae: 6.4277 - dist_relevant_mse: 117.3189 - dist_dist_iou_metric: 0.4669 - val_loss: 1.5766 - val_prob_loss: 0.1940 - val_dist_loss: 6.9131 - val_prob_kld: 0.0884 - val_dist_relevant_mae: 6.9118 - val_dist_relevant_mse: 163.9370 - val_dist_dist_iou_metric: 0.4653 - lr: 3.0000e-04
# Epoch 5/75
# 100/100 [==============================] - 18s 183ms/step - loss: 1.2038 - prob_loss: 0.1201 - dist_loss: 5.4188 - prob_kld: 0.0698 - dist_relevant_mae: 5.4170 - dist_relevant_mse: 96.4166 - dist_dist_iou_metric: 0.5242 - val_loss: 1.5961 - val_prob_loss: 0.3504 - val_dist_loss: 6.2285 - val_prob_kld: 0.2448 - val_dist_relevant_mae: 6.2266 - val_dist_relevant_mse: 125.3421 - val_dist_dist_iou_metric: 0.5455 - lr: 3.0000e-04
# Epoch 6/75
# 100/100 [==============================] - 17s 175ms/step - loss: 1.0664 - prob_loss: 0.1239 - dist_loss: 4.7124 - prob_kld: 0.0736 - dist_relevant_mae: 4.7106 - dist_relevant_mse: 82.5084 - dist_dist_iou_metric: 0.5424 - val_loss: 1.2508 - val_prob_loss: 0.1602 - val_dist_loss: 5.4530 - val_prob_kld: 0.0546 - val_dist_relevant_mae: 5.4515 - val_dist_relevant_mse: 127.7226 - val_dist_dist_iou_metric: 0.5686 - lr: 3.0000e-04
# Epoch 7/75
# 100/100 [==============================] - 17s 172ms/step - loss: 1.1162 - prob_loss: 0.1162 - dist_loss: 4.9998 - prob_kld: 0.0658 - dist_relevant_mae: 4.9980 - dist_relevant_mse: 89.1482 - dist_dist_iou_metric: 0.5453 - val_loss: 1.2043 - val_prob_loss: 0.1948 - val_dist_loss: 5.0476 - val_prob_kld: 0.0892 - val_dist_relevant_mae: 5.0462 - val_dist_relevant_mse: 120.9098 - val_dist_dist_iou_metric: 0.5816 - lr: 3.0000e-04
# Epoch 8/75
# 100/100 [==============================] - 18s 175ms/step - loss: 0.9666 - prob_loss: 0.0988 - dist_loss: 4.3392 - prob_kld: 0.0485 - dist_relevant_mae: 4.3373 - dist_relevant_mse: 74.2065 - dist_dist_iou_metric: 0.5806 - val_loss: 1.1576 - val_prob_loss: 0.1628 - val_dist_loss: 4.9739 - val_prob_kld: 0.0572 - val_dist_relevant_mae: 4.9724 - val_dist_relevant_mse: 118.1318 - val_dist_dist_iou_metric: 0.5888 - lr: 3.0000e-04
# Epoch 9/75
# 100/100 [==============================] - 18s 176ms/step - loss: 0.8706 - prob_loss: 0.0864 - dist_loss: 3.9209 - prob_kld: 0.0361 - dist_relevant_mae: 3.9191 - dist_relevant_mse: 67.4404 - dist_dist_iou_metric: 0.5967 - val_loss: 1.0805 - val_prob_loss: 0.1580 - val_dist_loss: 4.6124 - val_prob_kld: 0.0525 - val_dist_relevant_mae: 4.6108 - val_dist_relevant_mse: 106.5220 - val_dist_dist_iou_metric: 0.6211 - lr: 3.0000e-04
# Epoch 10/75
# 100/100 [==============================] - 17s 172ms/step - loss: 0.8627 - prob_loss: 0.0820 - dist_loss: 3.9034 - prob_kld: 0.0317 - dist_relevant_mae: 3.9015 - dist_relevant_mse: 64.7294 - dist_dist_iou_metric: 0.6230 - val_loss: 1.0065 - val_prob_loss: 0.1500 - val_dist_loss: 4.2827 - val_prob_kld: 0.0444 - val_dist_relevant_mae: 4.2811 - val_dist_relevant_mse: 90.3379 - val_dist_dist_iou_metric: 0.6324 - lr: 3.0000e-04
# Epoch 11/75
# 100/100 [==============================] - 18s 181ms/step - loss: 0.8613 - prob_loss: 0.0817 - dist_loss: 3.8984 - prob_kld: 0.0313 - dist_relevant_mae: 3.8965 - dist_relevant_mse: 61.8689 - dist_dist_iou_metric: 0.5988 - val_loss: 0.9536 - val_prob_loss: 0.1482 - val_dist_loss: 4.0273 - val_prob_kld: 0.0426 - val_dist_relevant_mae: 4.0258 - val_dist_relevant_mse: 81.7689 - val_dist_dist_iou_metric: 0.6397 - lr: 3.0000e-04
# Epoch 12/75
# 100/100 [==============================] - 17s 170ms/step - loss: 0.8056 - prob_loss: 0.0801 - dist_loss: 3.6275 - prob_kld: 0.0298 - dist_relevant_mae: 3.6257 - dist_relevant_mse: 52.8658 - dist_dist_iou_metric: 0.6332 - val_loss: 0.9701 - val_prob_loss: 0.1617 - val_dist_loss: 4.0422 - val_prob_kld: 0.0561 - val_dist_relevant_mae: 4.0406 - val_dist_relevant_mse: 61.8812 - val_dist_dist_iou_metric: 0.6546 - lr: 3.0000e-04
# Epoch 13/75
# 100/100 [==============================] - 18s 177ms/step - loss: 0.7646 - prob_loss: 0.0726 - dist_loss: 3.4599 - prob_kld: 0.0223 - dist_relevant_mae: 3.4580 - dist_relevant_mse: 46.7594 - dist_dist_iou_metric: 0.6655 - val_loss: 0.7917 - val_prob_loss: 0.1351 - val_dist_loss: 3.2832 - val_prob_kld: 0.0295 - val_dist_relevant_mae: 3.2818 - val_dist_relevant_mse: 53.3206 - val_dist_dist_iou_metric: 0.6970 - lr: 3.0000e-04
# Epoch 14/75
# 100/100 [==============================] - 19s 191ms/step - loss: 0.6554 - prob_loss: 0.0678 - dist_loss: 2.9382 - prob_kld: 0.0174 - dist_relevant_mae: 2.9364 - dist_relevant_mse: 37.6633 - dist_dist_iou_metric: 0.6641 - val_loss: 0.7704 - val_prob_loss: 0.1325 - val_dist_loss: 3.1896 - val_prob_kld: 0.0269 - val_dist_relevant_mae: 3.1881 - val_dist_relevant_mse: 49.3907 - val_dist_dist_iou_metric: 0.7102 - lr: 3.0000e-04
# Epoch 15/75
# 100/100 [==============================] - 17s 174ms/step - loss: 0.6265 - prob_loss: 0.0651 - dist_loss: 2.8066 - prob_kld: 0.0148 - dist_relevant_mae: 2.8048 - dist_relevant_mse: 34.1792 - dist_dist_iou_metric: 0.6839 - val_loss: 0.7283 - val_prob_loss: 0.1255 - val_dist_loss: 3.0141 - val_prob_kld: 0.0199 - val_dist_relevant_mae: 3.0126 - val_dist_relevant_mse: 43.0312 - val_dist_dist_iou_metric: 0.7222 - lr: 3.0000e-04
# Epoch 16/75
# 100/100 [==============================] - 17s 175ms/step - loss: 0.6071 - prob_loss: 0.0670 - dist_loss: 2.7004 - prob_kld: 0.0167 - dist_relevant_mae: 2.6986 - dist_relevant_mse: 31.1234 - dist_dist_iou_metric: 0.6454 - val_loss: 0.7818 - val_prob_loss: 0.1256 - val_dist_loss: 3.2808 - val_prob_kld: 0.0200 - val_dist_relevant_mae: 3.2792 - val_dist_relevant_mse: 45.7636 - val_dist_dist_iou_metric: 0.7129 - lr: 3.0000e-04
# Epoch 17/75
# 100/100 [==============================] - 17s 174ms/step - loss: 0.5867 - prob_loss: 0.0629 - dist_loss: 2.6192 - prob_kld: 0.0126 - dist_relevant_mae: 2.6174 - dist_relevant_mse: 30.2627 - dist_dist_iou_metric: 0.6607 - val_loss: 0.7227 - val_prob_loss: 0.1234 - val_dist_loss: 2.9966 - val_prob_kld: 0.0178 - val_dist_relevant_mae: 2.9952 - val_dist_relevant_mse: 42.2188 - val_dist_dist_iou_metric: 0.7282 - lr: 3.0000e-04
# Epoch 18/75
# 100/100 [==============================] - 18s 178ms/step - loss: 0.5824 - prob_loss: 0.0610 - dist_loss: 2.6072 - prob_kld: 0.0106 - dist_relevant_mae: 2.6055 - dist_relevant_mse: 29.0667 - dist_dist_iou_metric: 0.7101 - val_loss: 0.6795 - val_prob_loss: 0.1176 - val_dist_loss: 2.8093 - val_prob_kld: 0.0120 - val_dist_relevant_mae: 2.8080 - val_dist_relevant_mse: 41.0891 - val_dist_dist_iou_metric: 0.7363 - lr: 3.0000e-04
# Epoch 19/75
# 100/100 [==============================] - 17s 172ms/step - loss: 0.5858 - prob_loss: 0.0607 - dist_loss: 2.6255 - prob_kld: 0.0104 - dist_relevant_mae: 2.6239 - dist_relevant_mse: 29.1017 - dist_dist_iou_metric: 0.6885 - val_loss: 0.6848 - val_prob_loss: 0.1190 - val_dist_loss: 2.8289 - val_prob_kld: 0.0134 - val_dist_relevant_mae: 2.8277 - val_dist_relevant_mse: 40.6284 - val_dist_dist_iou_metric: 0.7326 - lr: 3.0000e-04
# Epoch 20/75
# 100/100 [==============================] - 19s 186ms/step - loss: 0.5849 - prob_loss: 0.0596 - dist_loss: 2.6265 - prob_kld: 0.0093 - dist_relevant_mae: 2.6249 - dist_relevant_mse: 28.3320 - dist_dist_iou_metric: 0.7198 - val_loss: 0.6834 - val_prob_loss: 0.1244 - val_dist_loss: 2.7950 - val_prob_kld: 0.0188 - val_dist_relevant_mae: 2.7938 - val_dist_relevant_mse: 41.1076 - val_dist_dist_iou_metric: 0.7342 - lr: 3.0000e-04
# Epoch 21/75
# 100/100 [==============================] - 18s 185ms/step - loss: 0.5612 - prob_loss: 0.0592 - dist_loss: 2.5103 - prob_kld: 0.0089 - dist_relevant_mae: 2.5087 - dist_relevant_mse: 27.5228 - dist_dist_iou_metric: 0.7140 - val_loss: 0.6628 - val_prob_loss: 0.1193 - val_dist_loss: 2.7176 - val_prob_kld: 0.0137 - val_dist_relevant_mae: 2.7163 - val_dist_relevant_mse: 39.2595 - val_dist_dist_iou_metric: 0.7415 - lr: 3.0000e-04
# Epoch 22/75
# 100/100 [==============================] - 18s 178ms/step - loss: 0.5524 - prob_loss: 0.0580 - dist_loss: 2.4718 - prob_kld: 0.0077 - dist_relevant_mae: 2.4702 - dist_relevant_mse: 25.7152 - dist_dist_iou_metric: 0.7203 - val_loss: 0.7384 - val_prob_loss: 0.1180 - val_dist_loss: 3.1020 - val_prob_kld: 0.0125 - val_dist_relevant_mae: 3.1007 - val_dist_relevant_mse: 42.4160 - val_dist_dist_iou_metric: 0.7149 - lr: 3.0000e-04
# Epoch 23/75
# 100/100 [==============================] - 18s 176ms/step - loss: 0.5543 - prob_loss: 0.0579 - dist_loss: 2.4818 - prob_kld: 0.0076 - dist_relevant_mae: 2.4803 - dist_relevant_mse: 25.9285 - dist_dist_iou_metric: 0.7192 - val_loss: 0.6392 - val_prob_loss: 0.1171 - val_dist_loss: 2.6104 - val_prob_kld: 0.0115 - val_dist_relevant_mae: 2.6092 - val_dist_relevant_mse: 36.8177 - val_dist_dist_iou_metric: 0.7553 - lr: 3.0000e-04
# Epoch 24/75
# 100/100 [==============================] - 18s 181ms/step - loss: 0.5256 - prob_loss: 0.0575 - dist_loss: 2.3401 - prob_kld: 0.0072 - dist_relevant_mae: 2.3387 - dist_relevant_mse: 24.3554 - dist_dist_iou_metric: 0.7295 - val_loss: 0.6339 - val_prob_loss: 0.1172 - val_dist_loss: 2.5837 - val_prob_kld: 0.0116 - val_dist_relevant_mae: 2.5825 - val_dist_relevant_mse: 35.5079 - val_dist_dist_iou_metric: 0.7591 - lr: 3.0000e-04
# Epoch 25/75
# 100/100 [==============================] - 18s 181ms/step - loss: 0.5099 - prob_loss: 0.0572 - dist_loss: 2.2632 - prob_kld: 0.0069 - dist_relevant_mae: 2.2618 - dist_relevant_mse: 23.4026 - dist_dist_iou_metric: 0.6974 - val_loss: 0.6292 - val_prob_loss: 0.1180 - val_dist_loss: 2.5562 - val_prob_kld: 0.0124 - val_dist_relevant_mae: 2.5551 - val_dist_relevant_mse: 35.1289 - val_dist_dist_iou_metric: 0.7617 - lr: 3.0000e-04
# Epoch 26/75
# 100/100 [==============================] - 19s 190ms/step - loss: 0.5228 - prob_loss: 0.0574 - dist_loss: 2.3269 - prob_kld: 0.0071 - dist_relevant_mae: 2.3256 - dist_relevant_mse: 23.7809 - dist_dist_iou_metric: 0.7692 - val_loss: 0.5932 - val_prob_loss: 0.1159 - val_dist_loss: 2.3866 - val_prob_kld: 0.0103 - val_dist_relevant_mae: 2.3855 - val_dist_relevant_mse: 32.3423 - val_dist_dist_iou_metric: 0.7719 - lr: 3.0000e-04
# Epoch 27/75
# 100/100 [==============================] - 18s 178ms/step - loss: 0.4982 - prob_loss: 0.0574 - dist_loss: 2.2040 - prob_kld: 0.0071 - dist_relevant_mae: 2.2027 - dist_relevant_mse: 21.6510 - dist_dist_iou_metric: 0.7408 - val_loss: 0.6217 - val_prob_loss: 0.1158 - val_dist_loss: 2.5296 - val_prob_kld: 0.0102 - val_dist_relevant_mae: 2.5286 - val_dist_relevant_mse: 33.5508 - val_dist_dist_iou_metric: 0.7540 - lr: 3.0000e-04
# Epoch 28/75
# 100/100 [==============================] - 18s 180ms/step - loss: 0.5011 - prob_loss: 0.0571 - dist_loss: 2.2201 - prob_kld: 0.0068 - dist_relevant_mae: 2.2188 - dist_relevant_mse: 21.8796 - dist_dist_iou_metric: 0.7308 - val_loss: 0.6288 - val_prob_loss: 0.1178 - val_dist_loss: 2.5551 - val_prob_kld: 0.0122 - val_dist_relevant_mae: 2.5541 - val_dist_relevant_mse: 32.1410 - val_dist_dist_iou_metric: 0.7535 - lr: 3.0000e-04
# Epoch 29/75
# 100/100 [==============================] - 18s 182ms/step - loss: 0.4866 - prob_loss: 0.0568 - dist_loss: 2.1490 - prob_kld: 0.0065 - dist_relevant_mae: 2.1478 - dist_relevant_mse: 20.7827 - dist_dist_iou_metric: 0.7535 - val_loss: 0.5526 - val_prob_loss: 0.1153 - val_dist_loss: 2.1866 - val_prob_kld: 0.0097 - val_dist_relevant_mae: 2.1856 - val_dist_relevant_mse: 25.0807 - val_dist_dist_iou_metric: 0.7915 - lr: 3.0000e-04
# Epoch 30/75
# 100/100 [==============================] - 18s 176ms/step - loss: 0.4921 - prob_loss: 0.0565 - dist_loss: 2.1780 - prob_kld: 0.0062 - dist_relevant_mae: 2.1768 - dist_relevant_mse: 20.2311 - dist_dist_iou_metric: 0.7527 - val_loss: 0.6267 - val_prob_loss: 0.1167 - val_dist_loss: 2.5503 - val_prob_kld: 0.0111 - val_dist_relevant_mae: 2.5492 - val_dist_relevant_mse: 24.1013 - val_dist_dist_iou_metric: 0.7777 - lr: 3.0000e-04
# Epoch 31/75
# 100/100 [==============================] - 18s 177ms/step - loss: 0.4802 - prob_loss: 0.0577 - dist_loss: 2.1122 - prob_kld: 0.0074 - dist_relevant_mae: 2.1109 - dist_relevant_mse: 18.1064 - dist_dist_iou_metric: 0.7232 - val_loss: 0.5757 - val_prob_loss: 0.1159 - val_dist_loss: 2.2986 - val_prob_kld: 0.0104 - val_dist_relevant_mae: 2.2976 - val_dist_relevant_mse: 21.7309 - val_dist_dist_iou_metric: 0.7830 - lr: 3.0000e-04
# Epoch 32/75
# 100/100 [==============================] - 18s 179ms/step - loss: 0.4497 - prob_loss: 0.0563 - dist_loss: 1.9668 - prob_kld: 0.0060 - dist_relevant_mae: 1.9655 - dist_relevant_mse: 16.1592 - dist_dist_iou_metric: 0.7638 - val_loss: 0.5811 - val_prob_loss: 0.1175 - val_dist_loss: 2.3181 - val_prob_kld: 0.0119 - val_dist_relevant_mae: 2.3170 - val_dist_relevant_mse: 17.5303 - val_dist_dist_iou_metric: 0.8012 - lr: 3.0000e-04
# Epoch 33/75
# 100/100 [==============================] - 18s 177ms/step - loss: 0.4375 - prob_loss: 0.0563 - dist_loss: 1.9062 - prob_kld: 0.0059 - dist_relevant_mae: 1.9050 - dist_relevant_mse: 15.0313 - dist_dist_iou_metric: 0.7591 - val_loss: 0.5264 - val_prob_loss: 0.1150 - val_dist_loss: 2.0574 - val_prob_kld: 0.0094 - val_dist_relevant_mae: 2.0564 - val_dist_relevant_mse: 15.7018 - val_dist_dist_iou_metric: 0.8114 - lr: 3.0000e-04
# Epoch 34/75
# 100/100 [==============================] - 18s 183ms/step - loss: 0.4190 - prob_loss: 0.0560 - dist_loss: 1.8153 - prob_kld: 0.0057 - dist_relevant_mae: 1.8140 - dist_relevant_mse: 13.9816 - dist_dist_iou_metric: 0.7485 - val_loss: 0.5027 - val_prob_loss: 0.1153 - val_dist_loss: 1.9374 - val_prob_kld: 0.0097 - val_dist_relevant_mae: 1.9364 - val_dist_relevant_mse: 12.7704 - val_dist_dist_iou_metric: 0.8187 - lr: 3.0000e-04
# Epoch 35/75
# 100/100 [==============================] - 18s 175ms/step - loss: 0.4203 - prob_loss: 0.0573 - dist_loss: 1.8149 - prob_kld: 0.0070 - dist_relevant_mae: 1.8137 - dist_relevant_mse: 13.5019 - dist_dist_iou_metric: 0.7581 - val_loss: 0.4609 - val_prob_loss: 0.1143 - val_dist_loss: 1.7329 - val_prob_kld: 0.0088 - val_dist_relevant_mae: 1.7319 - val_dist_relevant_mse: 10.1750 - val_dist_dist_iou_metric: 0.8393 - lr: 3.0000e-04
# Epoch 36/75
# 100/100 [==============================] - 18s 183ms/step - loss: 0.4156 - prob_loss: 0.0555 - dist_loss: 1.8009 - prob_kld: 0.0051 - dist_relevant_mae: 1.7997 - dist_relevant_mse: 12.7842 - dist_dist_iou_metric: 0.7507 - val_loss: 0.4598 - val_prob_loss: 0.1136 - val_dist_loss: 1.7310 - val_prob_kld: 0.0080 - val_dist_relevant_mae: 1.7301 - val_dist_relevant_mse: 10.1555 - val_dist_dist_iou_metric: 0.8373 - lr: 3.0000e-04
# Epoch 37/75
# 100/100 [==============================] - 19s 187ms/step - loss: 0.3922 - prob_loss: 0.0553 - dist_loss: 1.6846 - prob_kld: 0.0050 - dist_relevant_mae: 1.6834 - dist_relevant_mse: 11.4257 - dist_dist_iou_metric: 0.7695 - val_loss: 0.4382 - val_prob_loss: 0.1152 - val_dist_loss: 1.6148 - val_prob_kld: 0.0096 - val_dist_relevant_mae: 1.6138 - val_dist_relevant_mse: 8.8032 - val_dist_dist_iou_metric: 0.8525 - lr: 3.0000e-04
# Epoch 38/75
# 100/100 [==============================] - 18s 178ms/step - loss: 0.4067 - prob_loss: 0.0561 - dist_loss: 1.7527 - prob_kld: 0.0058 - dist_relevant_mae: 1.7515 - dist_relevant_mse: 11.8887 - dist_dist_iou_metric: 0.7942 - val_loss: 0.5346 - val_prob_loss: 0.1336 - val_dist_loss: 2.0052 - val_prob_kld: 0.0280 - val_dist_relevant_mae: 2.0042 - val_dist_relevant_mse: 11.0453 - val_dist_dist_iou_metric: 0.8254 - lr: 3.0000e-04
# Epoch 39/75
# 100/100 [==============================] - 19s 186ms/step - loss: 0.4191 - prob_loss: 0.0560 - dist_loss: 1.8152 - prob_kld: 0.0057 - dist_relevant_mae: 1.8141 - dist_relevant_mse: 11.7548 - dist_dist_iou_metric: 0.7995 - val_loss: 0.5321 - val_prob_loss: 0.1135 - val_dist_loss: 2.0931 - val_prob_kld: 0.0079 - val_dist_relevant_mae: 2.0921 - val_dist_relevant_mse: 11.0420 - val_dist_dist_iou_metric: 0.8308 - lr: 3.0000e-04
# Epoch 40/75
# 100/100 [==============================] - 17s 174ms/step - loss: 0.3901 - prob_loss: 0.0550 - dist_loss: 1.6757 - prob_kld: 0.0047 - dist_relevant_mae: 1.6746 - dist_relevant_mse: 11.0637 - dist_dist_iou_metric: 0.7623 - val_loss: 0.4678 - val_prob_loss: 0.1138 - val_dist_loss: 1.7700 - val_prob_kld: 0.0082 - val_dist_relevant_mae: 1.7691 - val_dist_relevant_mse: 9.0605 - val_dist_dist_iou_metric: 0.8380 - lr: 3.0000e-04
# Epoch 41/75
# 100/100 [==============================] - 18s 176ms/step - loss: 0.3986 - prob_loss: 0.0549 - dist_loss: 1.7188 - prob_kld: 0.0046 - dist_relevant_mae: 1.7178 - dist_relevant_mse: 10.9824 - dist_dist_iou_metric: 0.7608 - val_loss: 0.4701 - val_prob_loss: 0.1133 - val_dist_loss: 1.7842 - val_prob_kld: 0.0077 - val_dist_relevant_mae: 1.7833 - val_dist_relevant_mse: 8.9544 - val_dist_dist_iou_metric: 0.8419 - lr: 3.0000e-04
# Epoch 42/75
# 100/100 [==============================] - 18s 183ms/step - loss: 0.3920 - prob_loss: 0.0546 - dist_loss: 1.6869 - prob_kld: 0.0043 - dist_relevant_mae: 1.6859 - dist_relevant_mse: 10.3804 - dist_dist_iou_metric: 0.8022 - val_loss: 0.4455 - val_prob_loss: 0.1129 - val_dist_loss: 1.6626 - val_prob_kld: 0.0074 - val_dist_relevant_mae: 1.6618 - val_dist_relevant_mse: 7.8015 - val_dist_dist_iou_metric: 0.8526 - lr: 3.0000e-04
# Epoch 43/75
# 100/100 [==============================] - 18s 183ms/step - loss: 0.3654 - prob_loss: 0.0549 - dist_loss: 1.5525 - prob_kld: 0.0046 - dist_relevant_mae: 1.5516 - dist_relevant_mse: 9.3376 - dist_dist_iou_metric: 0.7929 - val_loss: 0.4255 - val_prob_loss: 0.1128 - val_dist_loss: 1.5640 - val_prob_kld: 0.0072 - val_dist_relevant_mae: 1.5631 - val_dist_relevant_mse: 7.2079 - val_dist_dist_iou_metric: 0.8599 - lr: 3.0000e-04
# Epoch 44/75
# 100/100 [==============================] - 18s 178ms/step - loss: 0.3774 - prob_loss: 0.0545 - dist_loss: 1.6150 - prob_kld: 0.0041 - dist_relevant_mae: 1.6141 - dist_relevant_mse: 10.0401 - dist_dist_iou_metric: 0.8073 - val_loss: 0.4216 - val_prob_loss: 0.1126 - val_dist_loss: 1.5451 - val_prob_kld: 0.0071 - val_dist_relevant_mae: 1.5443 - val_dist_relevant_mse: 6.8723 - val_dist_dist_iou_metric: 0.8574 - lr: 3.0000e-04
# Epoch 45/75
# 100/100 [==============================] - 18s 184ms/step - loss: 0.3759 - prob_loss: 0.0545 - dist_loss: 1.6073 - prob_kld: 0.0042 - dist_relevant_mae: 1.6065 - dist_relevant_mse: 9.5908 - dist_dist_iou_metric: 0.7986 - val_loss: 0.4282 - val_prob_loss: 0.1142 - val_dist_loss: 1.5699 - val_prob_kld: 0.0087 - val_dist_relevant_mae: 1.5691 - val_dist_relevant_mse: 7.0068 - val_dist_dist_iou_metric: 0.8608 - lr: 3.0000e-04
# Epoch 46/75
# 100/100 [==============================] - 18s 179ms/step - loss: 0.3659 - prob_loss: 0.0542 - dist_loss: 1.5583 - prob_kld: 0.0039 - dist_relevant_mae: 1.5575 - dist_relevant_mse: 9.2153 - dist_dist_iou_metric: 0.7942 - val_loss: 0.4376 - val_prob_loss: 0.1133 - val_dist_loss: 1.6216 - val_prob_kld: 0.0077 - val_dist_relevant_mae: 1.6209 - val_dist_relevant_mse: 7.1168 - val_dist_dist_iou_metric: 0.8543 - lr: 3.0000e-04
# Epoch 47/75
# 100/100 [==============================] - 18s 177ms/step - loss: 0.3761 - prob_loss: 0.0543 - dist_loss: 1.6087 - prob_kld: 0.0040 - dist_relevant_mae: 1.6079 - dist_relevant_mse: 9.4674 - dist_dist_iou_metric: 0.7906 - val_loss: 0.4395 - val_prob_loss: 0.1125 - val_dist_loss: 1.6351 - val_prob_kld: 0.0069 - val_dist_relevant_mae: 1.6343 - val_dist_relevant_mse: 7.5037 - val_dist_dist_iou_metric: 0.8580 - lr: 3.0000e-04
# Epoch 48/75
# 100/100 [==============================] - 18s 181ms/step - loss: 0.3706 - prob_loss: 0.0541 - dist_loss: 1.5827 - prob_kld: 0.0038 - dist_relevant_mae: 1.5819 - dist_relevant_mse: 9.0210 - dist_dist_iou_metric: 0.7822 - val_loss: 0.4296 - val_prob_loss: 0.1122 - val_dist_loss: 1.5871 - val_prob_kld: 0.0066 - val_dist_relevant_mae: 1.5863 - val_dist_relevant_mse: 7.3955 - val_dist_dist_iou_metric: 0.8586 - lr: 3.0000e-04
# Epoch 49/75
# 100/100 [==============================] - 18s 178ms/step - loss: 0.3846 - prob_loss: 0.0549 - dist_loss: 1.6487 - prob_kld: 0.0045 - dist_relevant_mae: 1.6480 - dist_relevant_mse: 9.4514 - dist_dist_iou_metric: 0.7984 - val_loss: 0.4459 - val_prob_loss: 0.1129 - val_dist_loss: 1.6647 - val_prob_kld: 0.0074 - val_dist_relevant_mae: 1.6639 - val_dist_relevant_mse: 7.2563 - val_dist_dist_iou_metric: 0.8600 - lr: 3.0000e-04
# Epoch 50/75
# 100/100 [==============================] - 19s 189ms/step - loss: 0.3676 - prob_loss: 0.0541 - dist_loss: 1.5674 - prob_kld: 0.0038 - dist_relevant_mae: 1.5666 - dist_relevant_mse: 8.8439 - dist_dist_iou_metric: 0.8045 - val_loss: 0.4348 - val_prob_loss: 0.1125 - val_dist_loss: 1.6116 - val_prob_kld: 0.0069 - val_dist_relevant_mae: 1.6108 - val_dist_relevant_mse: 7.6965 - val_dist_dist_iou_metric: 0.8542 - lr: 3.0000e-04
# Epoch 51/75
# 100/100 [==============================] - 18s 181ms/step - loss: 0.3639 - prob_loss: 0.0544 - dist_loss: 1.5474 - prob_kld: 0.0041 - dist_relevant_mae: 1.5467 - dist_relevant_mse: 8.8455 - dist_dist_iou_metric: 0.7571 - val_loss: 0.4031 - val_prob_loss: 0.1123 - val_dist_loss: 1.4540 - val_prob_kld: 0.0068 - val_dist_relevant_mae: 1.4532 - val_dist_relevant_mse: 6.2142 - val_dist_dist_iou_metric: 0.8688 - lr: 3.0000e-04
# Epoch 52/75
# 100/100 [==============================] - 18s 177ms/step - loss: 0.4983 - prob_loss: 0.0636 - dist_loss: 2.1734 - prob_kld: 0.0133 - dist_relevant_mae: 2.1726 - dist_relevant_mse: 15.1669 - dist_dist_iou_metric: 0.7531 - val_loss: 0.4814 - val_prob_loss: 0.1165 - val_dist_loss: 1.8245 - val_prob_kld: 0.0109 - val_dist_relevant_mae: 1.8234 - val_dist_relevant_mse: 9.4408 - val_dist_dist_iou_metric: 0.8392 - lr: 3.0000e-04
# Epoch 53/75
# 100/100 [==============================] - 18s 184ms/step - loss: 0.3626 - prob_loss: 0.0550 - dist_loss: 1.5377 - prob_kld: 0.0047 - dist_relevant_mae: 1.5367 - dist_relevant_mse: 8.6256 - dist_dist_iou_metric: 0.8059 - val_loss: 0.4021 - val_prob_loss: 0.1116 - val_dist_loss: 1.4525 - val_prob_kld: 0.0061 - val_dist_relevant_mae: 1.4517 - val_dist_relevant_mse: 6.2725 - val_dist_dist_iou_metric: 0.8673 - lr: 3.0000e-04
# Epoch 54/75
# 100/100 [==============================] - 18s 180ms/step - loss: 0.3505 - prob_loss: 0.0544 - dist_loss: 1.4807 - prob_kld: 0.0041 - dist_relevant_mae: 1.4799 - dist_relevant_mse: 8.1607 - dist_dist_iou_metric: 0.7723 - val_loss: 0.4218 - val_prob_loss: 0.1111 - val_dist_loss: 1.5534 - val_prob_kld: 0.0056 - val_dist_relevant_mae: 1.5526 - val_dist_relevant_mse: 6.6919 - val_dist_dist_iou_metric: 0.8664 - lr: 3.0000e-04
# Epoch 55/75
# 100/100 [==============================] - 18s 177ms/step - loss: 0.3439 - prob_loss: 0.0537 - dist_loss: 1.4512 - prob_kld: 0.0034 - dist_relevant_mae: 1.4505 - dist_relevant_mse: 7.9332 - dist_dist_iou_metric: 0.8139 - val_loss: 0.3962 - val_prob_loss: 0.1117 - val_dist_loss: 1.4224 - val_prob_kld: 0.0061 - val_dist_relevant_mae: 1.4216 - val_dist_relevant_mse: 5.9439 - val_dist_dist_iou_metric: 0.8735 - lr: 3.0000e-04
# Epoch 56/75
# 100/100 [==============================] - 18s 182ms/step - loss: 0.3291 - prob_loss: 0.0537 - dist_loss: 1.3770 - prob_kld: 0.0034 - dist_relevant_mae: 1.3763 - dist_relevant_mse: 7.6104 - dist_dist_iou_metric: 0.7802 - val_loss: 0.3868 - val_prob_loss: 0.1112 - val_dist_loss: 1.3781 - val_prob_kld: 0.0056 - val_dist_relevant_mae: 1.3773 - val_dist_relevant_mse: 5.8930 - val_dist_dist_iou_metric: 0.8761 - lr: 3.0000e-04
# Epoch 57/75
# 100/100 [==============================] - 18s 182ms/step - loss: 0.3383 - prob_loss: 0.0535 - dist_loss: 1.4238 - prob_kld: 0.0032 - dist_relevant_mae: 1.4231 - dist_relevant_mse: 7.5838 - dist_dist_iou_metric: 0.8262 - val_loss: 0.3937 - val_prob_loss: 0.1119 - val_dist_loss: 1.4091 - val_prob_kld: 0.0063 - val_dist_relevant_mae: 1.4083 - val_dist_relevant_mse: 5.7676 - val_dist_dist_iou_metric: 0.8702 - lr: 3.0000e-04
# Epoch 58/75
# 100/100 [==============================] - 17s 175ms/step - loss: 0.3383 - prob_loss: 0.0536 - dist_loss: 1.4234 - prob_kld: 0.0033 - dist_relevant_mae: 1.4228 - dist_relevant_mse: 7.7006 - dist_dist_iou_metric: 0.7966 - val_loss: 0.4215 - val_prob_loss: 0.1112 - val_dist_loss: 1.5516 - val_prob_kld: 0.0056 - val_dist_relevant_mae: 1.5509 - val_dist_relevant_mse: 6.5991 - val_dist_dist_iou_metric: 0.8585 - lr: 3.0000e-04
# Epoch 59/75
# 100/100 [==============================] - 18s 184ms/step - loss: 0.3340 - prob_loss: 0.0535 - dist_loss: 1.4024 - prob_kld: 0.0032 - dist_relevant_mae: 1.4017 - dist_relevant_mse: 7.2825 - dist_dist_iou_metric: 0.8082 - val_loss: 0.4773 - val_prob_loss: 0.1105 - val_dist_loss: 1.8340 - val_prob_kld: 0.0050 - val_dist_relevant_mae: 1.8332 - val_dist_relevant_mse: 8.1459 - val_dist_dist_iou_metric: 0.8343 - lr: 3.0000e-04
# Epoch 60/75
# 100/100 [==============================] - 18s 181ms/step - loss: 0.3299 - prob_loss: 0.0536 - dist_loss: 1.3816 - prob_kld: 0.0033 - dist_relevant_mae: 1.3810 - dist_relevant_mse: 7.1923 - dist_dist_iou_metric: 0.8102 - val_loss: 0.3723 - val_prob_loss: 0.1111 - val_dist_loss: 1.3059 - val_prob_kld: 0.0055 - val_dist_relevant_mae: 1.3051 - val_dist_relevant_mse: 5.3549 - val_dist_dist_iou_metric: 0.8832 - lr: 3.0000e-04
# Epoch 61/75
# 100/100 [==============================] - 18s 177ms/step - loss: 0.3296 - prob_loss: 0.0535 - dist_loss: 1.3806 - prob_kld: 0.0032 - dist_relevant_mae: 1.3800 - dist_relevant_mse: 7.4771 - dist_dist_iou_metric: 0.8298 - val_loss: 0.3732 - val_prob_loss: 0.1110 - val_dist_loss: 1.3108 - val_prob_kld: 0.0054 - val_dist_relevant_mae: 1.3101 - val_dist_relevant_mse: 5.4749 - val_dist_dist_iou_metric: 0.8795 - lr: 3.0000e-04
# Epoch 62/75
# 100/100 [==============================] - 19s 192ms/step - loss: 0.3153 - prob_loss: 0.0534 - dist_loss: 1.3094 - prob_kld: 0.0031 - dist_relevant_mae: 1.3088 - dist_relevant_mse: 6.8123 - dist_dist_iou_metric: 0.8260 - val_loss: 0.3643 - val_prob_loss: 0.1109 - val_dist_loss: 1.2668 - val_prob_kld: 0.0053 - val_dist_relevant_mae: 1.2660 - val_dist_relevant_mse: 5.0386 - val_dist_dist_iou_metric: 0.8848 - lr: 3.0000e-04
# Epoch 63/75
# 100/100 [==============================] - 18s 175ms/step - loss: 0.3052 - prob_loss: 0.0535 - dist_loss: 1.2584 - prob_kld: 0.0032 - dist_relevant_mae: 1.2578 - dist_relevant_mse: 6.3845 - dist_dist_iou_metric: 0.8013 - val_loss: 0.3857 - val_prob_loss: 0.1115 - val_dist_loss: 1.3709 - val_prob_kld: 0.0060 - val_dist_relevant_mae: 1.3701 - val_dist_relevant_mse: 5.3394 - val_dist_dist_iou_metric: 0.8788 - lr: 3.0000e-04
# Epoch 64/75
# 100/100 [==============================] - 18s 179ms/step - loss: 0.3108 - prob_loss: 0.0538 - dist_loss: 1.2850 - prob_kld: 0.0035 - dist_relevant_mae: 1.2844 - dist_relevant_mse: 6.5328 - dist_dist_iou_metric: 0.8085 - val_loss: 0.4028 - val_prob_loss: 0.1116 - val_dist_loss: 1.4560 - val_prob_kld: 0.0060 - val_dist_relevant_mae: 1.4552 - val_dist_relevant_mse: 5.7002 - val_dist_dist_iou_metric: 0.8746 - lr: 3.0000e-04
# Epoch 65/75
# 100/100 [==============================] - 19s 195ms/step - loss: 0.3241 - prob_loss: 0.0539 - dist_loss: 1.3513 - prob_kld: 0.0036 - dist_relevant_mae: 1.3507 - dist_relevant_mse: 6.5573 - dist_dist_iou_metric: 0.8137 - val_loss: 0.3596 - val_prob_loss: 0.1107 - val_dist_loss: 1.2448 - val_prob_kld: 0.0051 - val_dist_relevant_mae: 1.2441 - val_dist_relevant_mse: 5.0736 - val_dist_dist_iou_metric: 0.8860 - lr: 3.0000e-04
# Epoch 66/75
# 100/100 [==============================] - 18s 180ms/step - loss: 0.3012 - prob_loss: 0.0532 - dist_loss: 1.2402 - prob_kld: 0.0029 - dist_relevant_mae: 1.2396 - dist_relevant_mse: 6.1363 - dist_dist_iou_metric: 0.8419 - val_loss: 0.3720 - val_prob_loss: 0.1112 - val_dist_loss: 1.3042 - val_prob_kld: 0.0056 - val_dist_relevant_mae: 1.3035 - val_dist_relevant_mse: 5.1862 - val_dist_dist_iou_metric: 0.8808 - lr: 3.0000e-04
# Epoch 67/75
# 100/100 [==============================] - 18s 178ms/step - loss: 0.3045 - prob_loss: 0.0532 - dist_loss: 1.2563 - prob_kld: 0.0029 - dist_relevant_mae: 1.2558 - dist_relevant_mse: 6.3986 - dist_dist_iou_metric: 0.8308 - val_loss: 0.3637 - val_prob_loss: 0.1112 - val_dist_loss: 1.2629 - val_prob_kld: 0.0056 - val_dist_relevant_mae: 1.2621 - val_dist_relevant_mse: 5.1730 - val_dist_dist_iou_metric: 0.8869 - lr: 3.0000e-04
# Epoch 68/75
# 100/100 [==============================] - 18s 181ms/step - loss: 0.3084 - prob_loss: 0.0533 - dist_loss: 1.2755 - prob_kld: 0.0030 - dist_relevant_mae: 1.2749 - dist_relevant_mse: 6.2671 - dist_dist_iou_metric: 0.8211 - val_loss: 0.3611 - val_prob_loss: 0.1109 - val_dist_loss: 1.2507 - val_prob_kld: 0.0054 - val_dist_relevant_mae: 1.2500 - val_dist_relevant_mse: 4.7978 - val_dist_dist_iou_metric: 0.8864 - lr: 3.0000e-04
# Epoch 69/75
# 100/100 [==============================] - 19s 187ms/step - loss: 0.3187 - prob_loss: 0.0546 - dist_loss: 1.3207 - prob_kld: 0.0043 - dist_relevant_mae: 1.3202 - dist_relevant_mse: 6.7675 - dist_dist_iou_metric: 0.7874 - val_loss: 0.3787 - val_prob_loss: 0.1126 - val_dist_loss: 1.3304 - val_prob_kld: 0.0070 - val_dist_relevant_mae: 1.3296 - val_dist_relevant_mse: 5.2382 - val_dist_dist_iou_metric: 0.8815 - lr: 3.0000e-04
# Epoch 70/75
# 100/100 [==============================] - 19s 189ms/step - loss: 0.3107 - prob_loss: 0.0535 - dist_loss: 1.2860 - prob_kld: 0.0032 - dist_relevant_mae: 1.2855 - dist_relevant_mse: 6.2760 - dist_dist_iou_metric: 0.8287 - val_loss: 0.3688 - val_prob_loss: 0.1116 - val_dist_loss: 1.2861 - val_prob_kld: 0.0060 - val_dist_relevant_mae: 1.2853 - val_dist_relevant_mse: 5.1747 - val_dist_dist_iou_metric: 0.8842 - lr: 3.0000e-04
# Epoch 71/75
# 100/100 [==============================] - 18s 183ms/step - loss: 0.3081 - prob_loss: 0.0532 - dist_loss: 1.2747 - prob_kld: 0.0029 - dist_relevant_mae: 1.2742 - dist_relevant_mse: 5.9825 - dist_dist_iou_metric: 0.8499 - val_loss: 0.3515 - val_prob_loss: 0.1115 - val_dist_loss: 1.2005 - val_prob_kld: 0.0059 - val_dist_relevant_mae: 1.1998 - val_dist_relevant_mse: 4.6057 - val_dist_dist_iou_metric: 0.8900 - lr: 3.0000e-04
# Epoch 72/75
# 100/100 [==============================] - 18s 181ms/step - loss: 0.3070 - prob_loss: 0.0532 - dist_loss: 1.2688 - prob_kld: 0.0029 - dist_relevant_mae: 1.2683 - dist_relevant_mse: 6.0233 - dist_dist_iou_metric: 0.8320 - val_loss: 0.3532 - val_prob_loss: 0.1105 - val_dist_loss: 1.2135 - val_prob_kld: 0.0050 - val_dist_relevant_mae: 1.2128 - val_dist_relevant_mse: 4.6614 - val_dist_dist_iou_metric: 0.8923 - lr: 3.0000e-04
# Epoch 73/75
# 100/100 [==============================] - 18s 177ms/step - loss: 0.3352 - prob_loss: 0.0535 - dist_loss: 1.4085 - prob_kld: 0.0031 - dist_relevant_mae: 1.4080 - dist_relevant_mse: 6.8452 - dist_dist_iou_metric: 0.8399 - val_loss: 0.4008 - val_prob_loss: 0.1106 - val_dist_loss: 1.4514 - val_prob_kld: 0.0050 - val_dist_relevant_mae: 1.4507 - val_dist_relevant_mse: 5.7632 - val_dist_dist_iou_metric: 0.8719 - lr: 3.0000e-04
# Epoch 74/75
# 100/100 [==============================] - 18s 184ms/step - loss: 0.3115 - prob_loss: 0.0535 - dist_loss: 1.2903 - prob_kld: 0.0032 - dist_relevant_mae: 1.2897 - dist_relevant_mse: 5.9946 - dist_dist_iou_metric: 0.8299 - val_loss: 0.3579 - val_prob_loss: 0.1105 - val_dist_loss: 1.2369 - val_prob_kld: 0.0049 - val_dist_relevant_mae: 1.2362 - val_dist_relevant_mse: 4.6957 - val_dist_dist_iou_metric: 0.8883 - lr: 3.0000e-04
# Epoch 75/75
# 100/100 [==============================] - 18s 182ms/step - loss: 0.2824 - prob_loss: 0.0533 - dist_loss: 1.1459 - prob_kld: 0.0030 - dist_relevant_mae: 1.1454 - dist_relevant_mse: 5.3185 - dist_dist_iou_metric: 0.8219 - val_loss: 0.3596 - val_prob_loss: 0.1103 - val_dist_loss: 1.2466 - val_prob_kld: 0.0048 - val_dist_relevant_mae: 1.2459 - val_dist_relevant_mse: 4.6235 - val_dist_dist_iou_metric: 0.8861 - lr: 3.0000e-04
#
# Loading network weights from 'weights_best.h5'.

# %%
model.optimize_thresholds(X_train, Y_train)
# Out:
# NMS threshold = 0.3:  80%|████████  | 16/20 [00:26<00:06,  1.65s/it, 0.497 -> 0.883]
# NMS threshold = 0.4:  80%|████████  | 16/20 [00:23<00:05,  1.46s/it, 0.497 -> 0.883]
# NMS threshold = 0.5:  80%|████████  | 16/20 [00:22<00:05,  1.41s/it, 0.497 -> 0.882]
# Using optimized values: prob_thresh=0.49523, nms_thresh=0.3.
# Saving to 'thresholds.json'.
# {'prob': 0.4952300786972046, 'nms': 0.3}

# %% [markdown]
# ## Test network on some of the training images (self prediction)
#
# Self prediction is not a good way to evaluate the 'real' performance of the NN.  However it is good sanity test.  If the self prediction looks wrong something really went bad.
#
# The predictions for the rod images should be empty.

# %%
for n in range(10):
    labels, details = model.predict_instances(X_train[n], prob_thresh=0.5, nms_thresh=0.3)
    fig = imshow_multi2d([X_train[n],Y_train[n],labels],['input','ground truth','predicted instances'],1,3)

for n in range(110,120):
    labels, details = model.predict_instances(X_train[n], prob_thresh=0.5, nms_thresh=0.3)
    fig = imshow_multi2d([X_train[n],Y_train[n],labels],['input','ground truth','predicted instances'],1,3)
