# %%
import os
from tnia.plotting.plt_helper import imshow_multi2d
import tensorflow as tf
from pathlib import Path
import json

# %% [markdown]
# ## Check what devices we have access to....
#
# Not as important to have a beefy GPU for 2D as it is for 3D, but let's check

# %%
visible_devices = tf.config.list_physical_devices()
print(visible_devices)
# Out:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'), PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# ## Load inputs and ground truth
#
# We load directories called 'input0' and 'ground truth0' which should exist under ```train_path```.  The reason we append '0' to the end of the name is simply because some of the code that generates image and label sets is meant to work on multiple channels (so the 0 is the channel number)

# %%
tnia_images_path = Path(r'D:\images')

parent_path = Path(tnia_images_path / r'tnia-python-images/imagesc/2024_02_06_em_pores')
n_rays = 32

patch_path = parent_path / 'patches'

with open(patch_path / 'info.json', 'r') as json_file:
    data = json.load(json_file)
    # Access the sub_sample parameter
    sub_sample = data['sub_sample']
    print('sub_sample',sub_sample)
    axes = data['axes']
    print('axes',axes)

image_patch_path = patch_path / 'ground truth0'
label_patch_path = patch_path / 'input0'

model_path = parent_path / 'model'

if not os.path.exists(model_path):
    os.makedirs(model_path)

if not os.path.exists(image_patch_path):
    print('image_patch_path does not exist')

if not os.path.exists(label_patch_path):
    print('label_patch_path does not exist')
# Out:
# sub_sample 1
# axes YX

# %% [markdown]
# ## Use a helper to collect the training data
#
# The helper will also normalize the inputs.

# %%
from tnia.deeplearning.dl_helper import collect_training_data
add_trivial_channel = False
if axes == 'YX':
    add_trivial_channel = True

X, Y = collect_training_data(patch_path, sub_sample=1, downsample=False, add_trivial_channel = add_trivial_channel)

print('type X ', type(X))
print('type Y ', type(Y))
# Out:
# type X  <class 'list'>
# type Y  <class 'list'>

# %% [markdown]
# ## Inspect images
#
# Output training data shapes and plot images to make sure image and label set look OK

# %%
print(X[0].shape, Y[0].shape)
print(X[0].min(), X[0].max())
fig=imshow_multi2d([X[0], Y[0]], ['input', 'label'], 1,2)
# Out:
# (448, 448, 1) (448, 448)
# 0.0 1.082701

# %% [markdown]
# ## Divide in to training and validation sets
#
# Use a helper to divide into training and validation.  Note the conversion to numpy arrays (needed for stardist training) is also baked into the divide_training_data function

# %%
from tnia.deeplearning.dl_helper import divide_training_data

X_train, Y_train, X_val, Y_val = divide_training_data(X, Y, val_size=2)

print('type X_train ', type(X_train))
# Out:
# type X_train  <class 'numpy.ndarray'>

# %% [markdown]
# ## Create stardist model

# %%
axes
# Out:
# 'YX'

# %%
from stardist.models import StarDist2D, Config2D
from tnia.deeplearning.dl_helper import augmenter

if axes == 'YXC':
    n_channel_in =3
else:
    n_channel_in = 1


config = Config2D (n_rays=n_rays, axes=axes,n_channel_in=n_channel_in, train_patch_size = (256,256), unet_n_depth=4)

model = StarDist2D(config=config, name="stardistmodel1", basedir=model_path)
# Out:
# Using default values: prob_thresh=0.5, nms_thresh=0.4.

# %% [markdown]
# ## Train the model

# %%
X_train.shape, Y_train.shape
# Out:
# ((98, 448, 448, 1), (98, 448, 448))

# %%
print(config)
# Out:
# Config2D(n_dim=2, axes='YXC', n_channel_in=1, n_channel_out=33, train_checkpoint='weights_best.h5', train_checkpoint_last='weights_last.h5', train_checkpoint_epoch='weights_now.h5', n_rays=32, grid=(1, 1), backbone='unet', n_classes=None, unet_n_depth=4, unet_kernel_size=(3, 3), unet_n_filter_base=32, unet_n_conv_per_depth=2, unet_pool=(2, 2), unet_activation='relu', unet_last_activation='relu', unet_batch_norm=False, unet_dropout=0.0, unet_prefix='', net_conv_after_unet=128, net_input_shape=(None, None, 1), net_mask_shape=(None, None, 1), train_shape_completion=False, train_completion_crop=32, train_patch_size=(256, 256), train_background_reg=0.0001, train_foreground_only=0.9, train_sample_cache=True, train_dist_loss='mae', train_loss_weights=(1, 0.2), train_class_weights=(1, 1), train_epochs=400, train_steps_per_epoch=100, train_learning_rate=0.0003, train_batch_size=4, train_n_val_patches=None, train_tensorboard=True, train_reduce_lr={'factor': 0.5, 'patience': 40, 'min_delta': 0}, use_gpu=False)

# %%
model.train(X_train, Y_train, validation_data=(X_val,Y_val),epochs=30, steps_per_epoch=100, augmenter=augmenter)
# Out:
# Epoch 1/30
# 2/2 [==============================] - 0s 10ms/step- loss: 0.3982 - prob_loss: 0.0090 - dist_loss: 1.9459 - prob_kld: 0.0049 - dist_relevant_mae: 1.9456 - dist_relevant_mse: 9.3623 - dist_dist_iou_metric: 0.57
# 100/100 [==============================] - 11s 109ms/step - loss: 0.3982 - prob_loss: 0.0090 - dist_loss: 1.9459 - prob_kld: 0.0049 - dist_relevant_mae: 1.9456 - dist_relevant_mse: 9.3623 - dist_dist_iou_metric: 0.5732 - val_loss: 0.3801 - val_prob_loss: 0.0097 - val_dist_loss: 1.8521 - val_prob_kld: 0.0041 - val_dist_relevant_mae: 1.8518 - val_dist_relevant_mse: 6.7694 - val_dist_dist_iou_metric: 0.5829 - lr: 3.0000e-04
# Epoch 2/30
# 2/2 [==============================] - 0s 7ms/step - loss: 0.4058 - prob_loss: 0.0093 - dist_loss: 1.9825 - prob_kld: 0.0051 - dist_relevant_mae: 1.9821 - dist_relevant_mse: 10.0026 - dist_dist_iou_metric: 0.57
# 100/100 [==============================] - 11s 107ms/step - loss: 0.4058 - prob_loss: 0.0093 - dist_loss: 1.9825 - prob_kld: 0.0051 - dist_relevant_mae: 1.9821 - dist_relevant_mse: 10.0026 - dist_dist_iou_metric: 0.5700 - val_loss: 0.3782 - val_prob_loss: 0.0103 - val_dist_loss: 1.8395 - val_prob_kld: 0.0047 - val_dist_relevant_mae: 1.8391 - val_dist_relevant_mse: 7.0651 - val_dist_dist_iou_metric: 0.6017 - lr: 3.0000e-04
# Epoch 3/30
# 2/2 [==============================] - 0s 7ms/step - loss: 0.3750 - prob_loss: 0.0084 - dist_loss: 1.8331 - prob_kld: 0.0042 - dist_relevant_mae: 1.8327 - dist_relevant_mse: 7.9282 - dist_dist_iou_metric: 0.58
# 100/100 [==============================] - 11s 108ms/step - loss: 0.3750 - prob_loss: 0.0084 - dist_loss: 1.8331 - prob_kld: 0.0042 - dist_relevant_mae: 1.8327 - dist_relevant_mse: 7.9282 - dist_dist_iou_metric: 0.5855 - val_loss: 0.3449 - val_prob_loss: 0.0092 - val_dist_loss: 1.6786 - val_prob_kld: 0.0036 - val_dist_relevant_mae: 1.6782 - val_dist_relevant_mse: 5.6217 - val_dist_dist_iou_metric: 0.6301 - lr: 3.0000e-04
# Epoch 4/30
# 2/2 [==============================] - 0s 6ms/step - loss: 0.3934 - prob_loss: 0.0085 - dist_loss: 1.9244 - prob_kld: 0.0041 - dist_relevant_mae: 1.9241 - dist_relevant_mse: 8.7149 - dist_dist_iou_metric: 0.58
# 100/100 [==============================] - 11s 111ms/step - loss: 0.3934 - prob_loss: 0.0085 - dist_loss: 1.9244 - prob_kld: 0.0041 - dist_relevant_mae: 1.9241 - dist_relevant_mse: 8.7149 - dist_dist_iou_metric: 0.5881 - val_loss: 0.3589 - val_prob_loss: 0.0091 - val_dist_loss: 1.7493 - val_prob_kld: 0.0035 - val_dist_relevant_mae: 1.7490 - val_dist_relevant_mse: 6.3798 - val_dist_dist_iou_metric: 0.6151 - lr: 3.0000e-04
# Epoch 5/30
# 2/2 [==============================] - 0s 12ms/step- loss: 0.3822 - prob_loss: 0.0085 - dist_loss: 1.8685 - prob_kld: 0.0041 - dist_relevant_mae: 1.8681 - dist_relevant_mse: 8.6258 - dist_dist_iou_metric: 0.59
# 100/100 [==============================] - 11s 108ms/step - loss: 0.3822 - prob_loss: 0.0085 - dist_loss: 1.8685 - prob_kld: 0.0041 - dist_relevant_mae: 1.8681 - dist_relevant_mse: 8.6258 - dist_dist_iou_metric: 0.5910 - val_loss: 0.3526 - val_prob_loss: 0.0095 - val_dist_loss: 1.7155 - val_prob_kld: 0.0039 - val_dist_relevant_mae: 1.7152 - val_dist_relevant_mse: 6.3361 - val_dist_dist_iou_metric: 0.6150 - lr: 3.0000e-04
# Epoch 6/30
# 2/2 [==============================] - 0s 11ms/step- loss: 0.3934 - prob_loss: 0.0089 - dist_loss: 1.9224 - prob_kld: 0.0047 - dist_relevant_mae: 1.9221 - dist_relevant_mse: 9.1056 - dist_dist_iou_metric: 0.58
# 100/100 [==============================] - 11s 110ms/step - loss: 0.3934 - prob_loss: 0.0089 - dist_loss: 1.9224 - prob_kld: 0.0047 - dist_relevant_mae: 1.9221 - dist_relevant_mse: 9.1056 - dist_dist_iou_metric: 0.5812 - val_loss: 0.3789 - val_prob_loss: 0.0094 - val_dist_loss: 1.8475 - val_prob_kld: 0.0038 - val_dist_relevant_mae: 1.8472 - val_dist_relevant_mse: 7.3435 - val_dist_dist_iou_metric: 0.5965 - lr: 3.0000e-04
# Epoch 7/30
# 2/2 [==============================] - 0s 11ms/step- loss: 0.4001 - prob_loss: 0.0088 - dist_loss: 1.9565 - prob_kld: 0.0045 - dist_relevant_mae: 1.9561 - dist_relevant_mse: 9.0417 - dist_dist_iou_metric: 0.58
# 100/100 [==============================] - 11s 108ms/step - loss: 0.4001 - prob_loss: 0.0088 - dist_loss: 1.9565 - prob_kld: 0.0045 - dist_relevant_mae: 1.9561 - dist_relevant_mse: 9.0417 - dist_dist_iou_metric: 0.5841 - val_loss: 0.3887 - val_prob_loss: 0.0087 - val_dist_loss: 1.8996 - val_prob_kld: 0.0031 - val_dist_relevant_mae: 1.8993 - val_dist_relevant_mse: 7.1710 - val_dist_dist_iou_metric: 0.5719 - lr: 3.0000e-04
# Epoch 8/30
# 2/2 [==============================] - 0s 11ms/step- loss: 0.3605 - prob_loss: 0.0081 - dist_loss: 1.7619 - prob_kld: 0.0039 - dist_relevant_mae: 1.7616 - dist_relevant_mse: 7.5460 - dist_dist_iou_metric: 0.60
# 100/100 [==============================] - 11s 110ms/step - loss: 0.3605 - prob_loss: 0.0081 - dist_loss: 1.7619 - prob_kld: 0.0039 - dist_relevant_mae: 1.7616 - dist_relevant_mse: 7.5460 - dist_dist_iou_metric: 0.6039 - val_loss: 0.3529 - val_prob_loss: 0.0095 - val_dist_loss: 1.7171 - val_prob_kld: 0.0039 - val_dist_relevant_mae: 1.7168 - val_dist_relevant_mse: 6.2290 - val_dist_dist_iou_metric: 0.6215 - lr: 3.0000e-04
# Epoch 9/30
# 2/2 [==============================] - 0s 8ms/step - loss: 0.3786 - prob_loss: 0.0092 - dist_loss: 1.8472 - prob_kld: 0.0049 - dist_relevant_mae: 1.8468 - dist_relevant_mse: 8.5920 - dist_dist_iou_metric: 0.59
# 100/100 [==============================] - 11s 109ms/step - loss: 0.3786 - prob_loss: 0.0092 - dist_loss: 1.8472 - prob_kld: 0.0049 - dist_relevant_mae: 1.8468 - dist_relevant_mse: 8.5920 - dist_dist_iou_metric: 0.5941 - val_loss: 0.3367 - val_prob_loss: 0.0086 - val_dist_loss: 1.6407 - val_prob_kld: 0.0030 - val_dist_relevant_mae: 1.6404 - val_dist_relevant_mse: 5.9691 - val_dist_dist_iou_metric: 0.6313 - lr: 3.0000e-04
# Epoch 10/30
# 2/2 [==============================] - 0s 8ms/step - loss: 0.3905 - prob_loss: 0.0093 - dist_loss: 1.9061 - prob_kld: 0.0050 - dist_relevant_mae: 1.9058 - dist_relevant_mse: 9.0341 - dist_dist_iou_metric: 0.58
# 100/100 [==============================] - 11s 110ms/step - loss: 0.3905 - prob_loss: 0.0093 - dist_loss: 1.9061 - prob_kld: 0.0050 - dist_relevant_mae: 1.9058 - dist_relevant_mse: 9.0341 - dist_dist_iou_metric: 0.5824 - val_loss: 0.3570 - val_prob_loss: 0.0093 - val_dist_loss: 1.7387 - val_prob_kld: 0.0037 - val_dist_relevant_mae: 1.7384 - val_dist_relevant_mse: 6.0120 - val_dist_dist_iou_metric: 0.6293 - lr: 3.0000e-04
# Epoch 11/30
# 2/2 [==============================] - 0s 11ms/step- loss: 0.3772 - prob_loss: 0.0086 - dist_loss: 1.8429 - prob_kld: 0.0044 - dist_relevant_mae: 1.8426 - dist_relevant_mse: 8.4807 - dist_dist_iou_metric: 0.59
# 100/100 [==============================] - 11s 109ms/step - loss: 0.3772 - prob_loss: 0.0086 - dist_loss: 1.8429 - prob_kld: 0.0044 - dist_relevant_mae: 1.8426 - dist_relevant_mse: 8.4807 - dist_dist_iou_metric: 0.5963 - val_loss: 0.3377 - val_prob_loss: 0.0086 - val_dist_loss: 1.6457 - val_prob_kld: 0.0030 - val_dist_relevant_mae: 1.6454 - val_dist_relevant_mse: 5.7435 - val_dist_dist_iou_metric: 0.6268 - lr: 3.0000e-04
# Epoch 12/30
# 2/2 [==============================] - 0s 11ms/step- loss: 0.3576 - prob_loss: 0.0081 - dist_loss: 1.7473 - prob_kld: 0.0039 - dist_relevant_mae: 1.7470 - dist_relevant_mse: 7.3063 - dist_dist_iou_metric: 0.61
# 100/100 [==============================] - 11s 108ms/step - loss: 0.3576 - prob_loss: 0.0081 - dist_loss: 1.7473 - prob_kld: 0.0039 - dist_relevant_mae: 1.7470 - dist_relevant_mse: 7.3063 - dist_dist_iou_metric: 0.6100 - val_loss: 0.3401 - val_prob_loss: 0.0084 - val_dist_loss: 1.6589 - val_prob_kld: 0.0028 - val_dist_relevant_mae: 1.6586 - val_dist_relevant_mse: 5.4313 - val_dist_dist_iou_metric: 0.6329 - lr: 3.0000e-04
# Epoch 13/30
# 2/2 [==============================] - 0s 10ms/step- loss: 0.3535 - prob_loss: 0.0077 - dist_loss: 1.7289 - prob_kld: 0.0035 - dist_relevant_mae: 1.7285 - dist_relevant_mse: 7.1615 - dist_dist_iou_metric: 0.61
# 100/100 [==============================] - 11s 108ms/step - loss: 0.3535 - prob_loss: 0.0077 - dist_loss: 1.7289 - prob_kld: 0.0035 - dist_relevant_mae: 1.7285 - dist_relevant_mse: 7.1615 - dist_dist_iou_metric: 0.6117 - val_loss: 0.3186 - val_prob_loss: 0.0086 - val_dist_loss: 1.5502 - val_prob_kld: 0.0030 - val_dist_relevant_mae: 1.5498 - val_dist_relevant_mse: 4.7221 - val_dist_dist_iou_metric: 0.6562 - lr: 3.0000e-04
# Epoch 14/30
# 2/2 [==============================] - 0s 10ms/step- loss: 0.3717 - prob_loss: 0.0086 - dist_loss: 1.8156 - prob_kld: 0.0042 - dist_relevant_mae: 1.8153 - dist_relevant_mse: 7.8717 - dist_dist_iou_metric: 0.60
# 100/100 [==============================] - 11s 109ms/step - loss: 0.3717 - prob_loss: 0.0086 - dist_loss: 1.8156 - prob_kld: 0.0042 - dist_relevant_mae: 1.8153 - dist_relevant_mse: 7.8717 - dist_dist_iou_metric: 0.6059 - val_loss: 0.3480 - val_prob_loss: 0.0091 - val_dist_loss: 1.6943 - val_prob_kld: 0.0035 - val_dist_relevant_mae: 1.6939 - val_dist_relevant_mse: 6.0623 - val_dist_dist_iou_metric: 0.6133 - lr: 3.0000e-04
# Epoch 15/30
# 2/2 [==============================] - 0s 11ms/step- loss: 0.3475 - prob_loss: 0.0084 - dist_loss: 1.6952 - prob_kld: 0.0042 - dist_relevant_mae: 1.6949 - dist_relevant_mse: 6.8717 - dist_dist_iou_metric: 0.61
# 100/100 [==============================] - 11s 111ms/step - loss: 0.3475 - prob_loss: 0.0084 - dist_loss: 1.6952 - prob_kld: 0.0042 - dist_relevant_mae: 1.6949 - dist_relevant_mse: 6.8717 - dist_dist_iou_metric: 0.6106 - val_loss: 0.3599 - val_prob_loss: 0.0091 - val_dist_loss: 1.7542 - val_prob_kld: 0.0035 - val_dist_relevant_mae: 1.7538 - val_dist_relevant_mse: 6.3637 - val_dist_dist_iou_metric: 0.6147 - lr: 3.0000e-04
# Epoch 16/30
# 2/2 [==============================] - 0s 7ms/step - loss: 0.3594 - prob_loss: 0.0085 - dist_loss: 1.7544 - prob_kld: 0.0042 - dist_relevant_mae: 1.7541 - dist_relevant_mse: 7.4851 - dist_dist_iou_metric: 0.61
# 100/100 [==============================] - 11s 108ms/step - loss: 0.3594 - prob_loss: 0.0085 - dist_loss: 1.7544 - prob_kld: 0.0042 - dist_relevant_mae: 1.7541 - dist_relevant_mse: 7.4851 - dist_dist_iou_metric: 0.6148 - val_loss: 0.3159 - val_prob_loss: 0.0084 - val_dist_loss: 1.5373 - val_prob_kld: 0.0028 - val_dist_relevant_mae: 1.5370 - val_dist_relevant_mse: 4.9823 - val_dist_dist_iou_metric: 0.6464 - lr: 3.0000e-04
# Epoch 17/30
# 2/2 [==============================] - 0s 11ms/step- loss: 0.3405 - prob_loss: 0.0079 - dist_loss: 1.6630 - prob_kld: 0.0037 - dist_relevant_mae: 1.6627 - dist_relevant_mse: 6.5289 - dist_dist_iou_metric: 0.62
# 100/100 [==============================] - 11s 109ms/step - loss: 0.3405 - prob_loss: 0.0079 - dist_loss: 1.6630 - prob_kld: 0.0037 - dist_relevant_mae: 1.6627 - dist_relevant_mse: 6.5289 - dist_dist_iou_metric: 0.6218 - val_loss: 0.3286 - val_prob_loss: 0.0085 - val_dist_loss: 1.6002 - val_prob_kld: 0.0030 - val_dist_relevant_mae: 1.5998 - val_dist_relevant_mse: 5.5796 - val_dist_dist_iou_metric: 0.6336 - lr: 3.0000e-04
# Epoch 18/30
# 2/2 [==============================] - 0s 11ms/step- loss: 0.3300 - prob_loss: 0.0079 - dist_loss: 1.6107 - prob_kld: 0.0036 - dist_relevant_mae: 1.6104 - dist_relevant_mse: 6.1015 - dist_dist_iou_metric: 0.62
# 100/100 [==============================] - 11s 109ms/step - loss: 0.3300 - prob_loss: 0.0079 - dist_loss: 1.6107 - prob_kld: 0.0036 - dist_relevant_mae: 1.6104 - dist_relevant_mse: 6.1015 - dist_dist_iou_metric: 0.6247 - val_loss: 0.2952 - val_prob_loss: 0.0084 - val_dist_loss: 1.4341 - val_prob_kld: 0.0028 - val_dist_relevant_mae: 1.4338 - val_dist_relevant_mse: 4.2159 - val_dist_dist_iou_metric: 0.6679 - lr: 3.0000e-04
# Epoch 19/30
# 2/2 [==============================] - 0s 10ms/step- loss: 0.3437 - prob_loss: 0.0079 - dist_loss: 1.6792 - prob_kld: 0.0036 - dist_relevant_mae: 1.6788 - dist_relevant_mse: 6.6066 - dist_dist_iou_metric: 0.62
# 100/100 [==============================] - 11s 109ms/step - loss: 0.3437 - prob_loss: 0.0079 - dist_loss: 1.6792 - prob_kld: 0.0036 - dist_relevant_mae: 1.6788 - dist_relevant_mse: 6.6066 - dist_dist_iou_metric: 0.6205 - val_loss: 0.3016 - val_prob_loss: 0.0083 - val_dist_loss: 1.4661 - val_prob_kld: 0.0027 - val_dist_relevant_mae: 1.4658 - val_dist_relevant_mse: 4.2936 - val_dist_dist_iou_metric: 0.6543 - lr: 3.0000e-04
# Epoch 20/30
# 2/2 [==============================] - 0s 7ms/step - loss: 0.3258 - prob_loss: 0.0074 - dist_loss: 1.5916 - prob_kld: 0.0033 - dist_relevant_mae: 1.5913 - dist_relevant_mse: 6.0704 - dist_dist_iou_metric: 0.63
# 100/100 [==============================] - 11s 108ms/step - loss: 0.3258 - prob_loss: 0.0074 - dist_loss: 1.5916 - prob_kld: 0.0033 - dist_relevant_mae: 1.5913 - dist_relevant_mse: 6.0704 - dist_dist_iou_metric: 0.6315 - val_loss: 0.2973 - val_prob_loss: 0.0082 - val_dist_loss: 1.4452 - val_prob_kld: 0.0026 - val_dist_relevant_mae: 1.4449 - val_dist_relevant_mse: 4.3600 - val_dist_dist_iou_metric: 0.6626 - lr: 3.0000e-04
# Epoch 21/30
# 2/2 [==============================] - 0s 11ms/step- loss: 0.3365 - prob_loss: 0.0082 - dist_loss: 1.6415 - prob_kld: 0.0037 - dist_relevant_mae: 1.6412 - dist_relevant_mse: 6.4960 - dist_dist_iou_metric: 0.62
# 100/100 [==============================] - 11s 112ms/step - loss: 0.3365 - prob_loss: 0.0082 - dist_loss: 1.6415 - prob_kld: 0.0037 - dist_relevant_mae: 1.6412 - dist_relevant_mse: 6.4960 - dist_dist_iou_metric: 0.6281 - val_loss: 0.3106 - val_prob_loss: 0.0082 - val_dist_loss: 1.5119 - val_prob_kld: 0.0026 - val_dist_relevant_mae: 1.5116 - val_dist_relevant_mse: 4.7270 - val_dist_dist_iou_metric: 0.6511 - lr: 3.0000e-04
# Epoch 22/30
# 2/2 [==============================] - 0s 12ms/step- loss: 0.3529 - prob_loss: 0.0081 - dist_loss: 1.7240 - prob_kld: 0.0037 - dist_relevant_mae: 1.7236 - dist_relevant_mse: 7.0567 - dist_dist_iou_metric: 0.62
# 100/100 [==============================] - 11s 106ms/step - loss: 0.3529 - prob_loss: 0.0081 - dist_loss: 1.7240 - prob_kld: 0.0037 - dist_relevant_mae: 1.7236 - dist_relevant_mse: 7.0567 - dist_dist_iou_metric: 0.6227 - val_loss: 0.2998 - val_prob_loss: 0.0084 - val_dist_loss: 1.4569 - val_prob_kld: 0.0028 - val_dist_relevant_mae: 1.4566 - val_dist_relevant_mse: 4.1782 - val_dist_dist_iou_metric: 0.6806 - lr: 3.0000e-04
# Epoch 23/30
# 2/2 [==============================] - 0s 6ms/step - loss: 0.3367 - prob_loss: 0.0077 - dist_loss: 1.6448 - prob_kld: 0.0034 - dist_relevant_mae: 1.6445 - dist_relevant_mse: 6.4026 - dist_dist_iou_metric: 0.63
# 100/100 [==============================] - 11s 112ms/step - loss: 0.3367 - prob_loss: 0.0077 - dist_loss: 1.6448 - prob_kld: 0.0034 - dist_relevant_mae: 1.6445 - dist_relevant_mse: 6.4026 - dist_dist_iou_metric: 0.6307 - val_loss: 0.3100 - val_prob_loss: 0.0085 - val_dist_loss: 1.5072 - val_prob_kld: 0.0029 - val_dist_relevant_mae: 1.5069 - val_dist_relevant_mse: 4.4157 - val_dist_dist_iou_metric: 0.6514 - lr: 3.0000e-04
# Epoch 24/30
# 2/2 [==============================] - 0s 8ms/step - loss: 0.3198 - prob_loss: 0.0077 - dist_loss: 1.5606 - prob_kld: 0.0034 - dist_relevant_mae: 1.5603 - dist_relevant_mse: 5.7422 - dist_dist_iou_metric: 0.63
# 100/100 [==============================] - 11s 108ms/step - loss: 0.3198 - prob_loss: 0.0077 - dist_loss: 1.5606 - prob_kld: 0.0034 - dist_relevant_mae: 1.5603 - dist_relevant_mse: 5.7422 - dist_dist_iou_metric: 0.6367 - val_loss: 0.3207 - val_prob_loss: 0.0082 - val_dist_loss: 1.5621 - val_prob_kld: 0.0026 - val_dist_relevant_mae: 1.5618 - val_dist_relevant_mse: 5.3006 - val_dist_dist_iou_metric: 0.6355 - lr: 3.0000e-04
# Epoch 25/30
# 2/2 [==============================] - 0s 10ms/step- loss: 0.3189 - prob_loss: 0.0074 - dist_loss: 1.5576 - prob_kld: 0.0033 - dist_relevant_mae: 1.5573 - dist_relevant_mse: 5.5044 - dist_dist_iou_metric: 0.63
# 100/100 [==============================] - 11s 108ms/step - loss: 0.3189 - prob_loss: 0.0074 - dist_loss: 1.5576 - prob_kld: 0.0033 - dist_relevant_mae: 1.5573 - dist_relevant_mse: 5.5044 - dist_dist_iou_metric: 0.6347 - val_loss: 0.3041 - val_prob_loss: 0.0085 - val_dist_loss: 1.4780 - val_prob_kld: 0.0029 - val_dist_relevant_mae: 1.4777 - val_dist_relevant_mse: 4.2450 - val_dist_dist_iou_metric: 0.6565 - lr: 3.0000e-04
# Epoch 26/30
# 2/2 [==============================] - 0s 12ms/step- loss: 0.3263 - prob_loss: 0.0075 - dist_loss: 1.5940 - prob_kld: 0.0032 - dist_relevant_mae: 1.5937 - dist_relevant_mse: 5.9093 - dist_dist_iou_metric: 0.63
# 100/100 [==============================] - 11s 112ms/step - loss: 0.3263 - prob_loss: 0.0075 - dist_loss: 1.5940 - prob_kld: 0.0032 - dist_relevant_mae: 1.5937 - dist_relevant_mse: 5.9093 - dist_dist_iou_metric: 0.6399 - val_loss: 0.3002 - val_prob_loss: 0.0083 - val_dist_loss: 1.4596 - val_prob_kld: 0.0027 - val_dist_relevant_mae: 1.4593 - val_dist_relevant_mse: 4.2838 - val_dist_dist_iou_metric: 0.6692 - lr: 3.0000e-04
# Epoch 27/30
# 2/2 [==============================] - 0s 12ms/step- loss: 0.3250 - prob_loss: 0.0078 - dist_loss: 1.5859 - prob_kld: 0.0034 - dist_relevant_mae: 1.5856 - dist_relevant_mse: 5.9857 - dist_dist_iou_metric: 0.64
# 100/100 [==============================] - 11s 114ms/step - loss: 0.3250 - prob_loss: 0.0078 - dist_loss: 1.5859 - prob_kld: 0.0034 - dist_relevant_mae: 1.5856 - dist_relevant_mse: 5.9857 - dist_dist_iou_metric: 0.6462 - val_loss: 0.2902 - val_prob_loss: 0.0083 - val_dist_loss: 1.4098 - val_prob_kld: 0.0027 - val_dist_relevant_mae: 1.4094 - val_dist_relevant_mse: 4.0710 - val_dist_dist_iou_metric: 0.6736 - lr: 3.0000e-04
# Epoch 28/30
# 2/2 [==============================] - 0s 10ms/step- loss: 0.3292 - prob_loss: 0.0077 - dist_loss: 1.6072 - prob_kld: 0.0034 - dist_relevant_mae: 1.6068 - dist_relevant_mse: 6.0238 - dist_dist_iou_metric: 0.63
# 100/100 [==============================] - 12s 118ms/step - loss: 0.3292 - prob_loss: 0.0077 - dist_loss: 1.6072 - prob_kld: 0.0034 - dist_relevant_mae: 1.6068 - dist_relevant_mse: 6.0238 - dist_dist_iou_metric: 0.6342 - val_loss: 0.3138 - val_prob_loss: 0.0085 - val_dist_loss: 1.5266 - val_prob_kld: 0.0029 - val_dist_relevant_mae: 1.5263 - val_dist_relevant_mse: 4.8491 - val_dist_dist_iou_metric: 0.6357 - lr: 3.0000e-04
# Epoch 29/30
# 2/2 [==============================] - 0s 10ms/step- loss: 0.3135 - prob_loss: 0.0078 - dist_loss: 1.5287 - prob_kld: 0.0035 - dist_relevant_mae: 1.5284 - dist_relevant_mse: 5.5369 - dist_dist_iou_metric: 0.64
# 100/100 [==============================] - 11s 110ms/step - loss: 0.3135 - prob_loss: 0.0078 - dist_loss: 1.5287 - prob_kld: 0.0035 - dist_relevant_mae: 1.5284 - dist_relevant_mse: 5.5369 - dist_dist_iou_metric: 0.6451 - val_loss: 0.3032 - val_prob_loss: 0.0083 - val_dist_loss: 1.4745 - val_prob_kld: 0.0027 - val_dist_relevant_mae: 1.4742 - val_dist_relevant_mse: 4.7019 - val_dist_dist_iou_metric: 0.6609 - lr: 3.0000e-04
# Epoch 30/30
# 2/2 [==============================] - 0s 11ms/step- loss: 0.3022 - prob_loss: 0.0073 - dist_loss: 1.4747 - prob_kld: 0.0030 - dist_relevant_mae: 1.4744 - dist_relevant_mse: 5.0668 - dist_dist_iou_metric: 0.65
# 100/100 [==============================] - 11s 108ms/step - loss: 0.3022 - prob_loss: 0.0073 - dist_loss: 1.4747 - prob_kld: 0.0030 - dist_relevant_mae: 1.4744 - dist_relevant_mse: 5.0668 - dist_dist_iou_metric: 0.6503 - val_loss: 0.2841 - val_prob_loss: 0.0082 - val_dist_loss: 1.3792 - val_prob_kld: 0.0026 - val_dist_relevant_mae: 1.3789 - val_dist_relevant_mse: 3.8397 - val_dist_dist_iou_metric: 0.6804 - lr: 3.0000e-04
#
# Loading network weights from 'weights_best.h5'.

# %%
model.optimize_thresholds(X_val, Y_val)
# Out:
# NMS threshold = 0.3:  15%|█▌        | 3/20 [00:00<00:00, 48.52it/s, 0.574 -> 0.000]
# NMS threshold = 0.4:  15%|█▌        | 3/20 [00:00<00:00, 73.37it/s, 0.574 -> 0.000]
# NMS threshold = 0.5:  15%|█▌        | 3/20 [00:00<00:00, 77.13it/s, 0.574 -> 0.000]
# Using optimized values: prob_thresh=0.287112, nms_thresh=0.3.
# Saving to 'thresholds.json'.
# {'prob': 0.28711235523223877, 'nms': 0.3}

# %% [markdown]
# ## Test network on one of the training images (self prediction)
#
# Self prediction is not a good way to evaluate the 'real' performance of the NN.  However it is good sanity test.  If the self prediction looks wrong something really went bad.

# %%
from tnia.plotting.plt_helper import random_label_cmap
n=2
labels, details = model.predict_instances(X_train[n], prob_thresh=0.1, nms_thresh=0.1)
fig = imshow_multi2d([X_train[n],Y_train[n],labels],['input','ground truth','predicted instances'],1,3, colormaps=['gray','gray',random_label_cmap()])

# %%
from skimage.io import imread
from tnia.deeplearning.dl_helper import ray4_to_ellipsoid2d_labels
from csbdeep.utils import normalize
import numpy as np

testim = imread(parent_path  / 'labels' / 'inputs' / 'test_2.tif') 
if (sub_sample != 1):
    testim = testim[::sub_sample,::sub_sample]  
testim = normalize(testim,3,97, axis=(0,1))
labels, details = model.predict_instances(testim, prob_thresh=0.05, nms_thresh=0.1)

if n_rays == 4:
    labels2 = np.zeros_like(labels)#ray4_to_ellipsoid2d_labels(details['coord'], testim.shape)
    fig = imshow_multi2d([testim,labels,labels2],['input','predicted octohedrons', 'rendered as ellipses'],1,3, width=14, height=8,colormaps=['gray', random_label_cmap(), random_label_cmap()])
else:
    fig = imshow_multi2d([testim,labels],['input','predicted octohedrons'],1,2, width=14, height=8,colormaps=['gray', random_label_cmap()])

# %%
import napari

viewer = napari.Viewer()
viewer.add_image(testim, name='testim')
viewer.add_labels(labels, name='labels')
# Out:
# <Labels layer 'labels' at 0x2198c81ebe0>
