# %% [markdown]
# ## Train a semantic segmentation unet using Pytorch

# %% [markdown]
# ## Pytorch setup
#
# setting up environment (Windows 10 with Cuda 11.8)
#
# ```
# conda create --name pytorch_tests python=3.10
# conda activate pytorch_tests
# conda install pip
# pip install pykernel
# pip3 install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118
# pip install pytorch-lightning
# pip install monai
# pip install scipy
# pip install tifffile
# pip install matplotlib
# ```

# %% [markdown]
# ## Imports

# %%
from tifffile import imread
from tqdm import tqdm
from tnia.deeplearning.dl_helper import quantile_normalization
import matplotlib.pyplot as plt
import numpy as np
import torch

from torchvision import transforms
from torchvision.transforms import v2
import torchvision.transforms.functional as TF

# %% [markdown]
# ## Check if GPU is present

# %%
cuda_present = torch.cuda.is_available()
ndevices = torch.cuda.device_count()
use_cuda = cuda_present and ndevices > 0
device = torch.device("cuda" if use_cuda else "cpu")  # "cuda:0" ... default device, "cuda:1" would be GPU index 1, "cuda:2" etc
print("number of devices:", ndevices, "\tchosen device:", device, "\tuse_cuda=", use_cuda)
# Out:
# number of devices: 1 	chosen device: cuda 	use_cuda= True

# %% [markdown]
# ## Set up image and label directories

# %%
from pathlib import Path
import json

tnia_images_path = Path(r'D:/images')
parent_path=Path(tnia_images_path / r'tnia-python-images/imagesc/2024_03_19_aggregate_in_concrete')
train_path= parent_path / 'patches' 

with open(train_path / 'info.json', 'r') as json_file:
    data = json.load(json_file)
    # Access the sub_sample parameter
    sub_sample = data.get('sub_sample',1)
    print('sub_sample',sub_sample)
    axes = data['axes']
    print('axes',axes)

image_patch_path = train_path / 'ground truth0'
label_patch_path = train_path / 'input0'
# Out:
# sub_sample 1
# axes YXC

# %% [markdown]
# ## Create a PyTorch Dataset
#
# Dataset is simply used to retrieve the training patches.  In this case we just set it up to read in image files, then convert the numpy arrays to tensors and a torch stack.
#
# In this example augmentation was done in a previous notebook, and the augmented images explicitly saved.  It is also possible to do augmentation as the data is retrieved.  So in the future the ```MyDataSet``` could be extended to apply augmentation as data is retrieved.

# %%
class MyDataSet():

    def __init__(self, image_files, label_files, target_shape=(256, 256, 3)):
            """
            Parameters
            ----------
            image_files: list of pathlib.Path objects pointing to the *.tif images
            label_files: list of pathlib.Path objects pointing to the *.tif segmentation masks
            target_shape: tuple of length 2 specifying the sample resolutions of files that
                        will be kept. All other files will NOT be used.
            """
            assert len(image_files) == len(label_files)
            assert all(x.name==y.name for x,y in zip(image_files, label_files))

            self.images = []
            self.labels = []

            tensor_transform = transforms.Compose([
                v2.ToTensor(),
            ])

            # use tqdm to have eye pleasing error bars
            for idx in tqdm(range(len(image_files))):
                # we use the same data reading approach as in the previous notebook
                image = imread(image_files[idx])
                label = imread(label_files[idx])

                if image.shape != target_shape:
                    continue
                
                # do the normalizations
                #image = quantile_normalization(
                #   image,
                #    quantile_low=0.01,
                #    quantile_high=0.998,
                #    clip=True)[0].astype(np.float32)

                # NOTE: we convert the label to dtype float32 and not uint8 because
                # the tensor transformation does a normalization if the input is of
                # dtype uint8, destroying the 0/1 labelling which we want to avoid.
                #label = fill_label_holes(label)
                label_binary = np.zeros_like(label).astype(np.float32)
                label_binary[label != 0] = 1.
                

                # convert to torch tensor: adds an artificial color channel in the front
                # and scales inputs to have same size as samples tend to differ in image
                # resolutions
                image = tensor_transform(image)
                label = tensor_transform(label_binary)

                self.images.append(image)
                self.labels.append(label)

            self.images = torch.stack(self.images)
            self.labels = torch.stack(self.labels)
    
    def __getitem__(self, idx):
        return self.images[idx], self.labels[idx]

    def __len__(self):
        return len(self.images)

# %% [markdown]
# ## Initialize the DataSet
#
# Initialize the DataSet with the pre-generated patch names

# %%
src_dir = train_path

assert src_dir.exists(), f"root directory with images and masks {src_dir} does not exist"

X = sorted(src_dir.rglob('**/input0/*.tif'))
Y = sorted(src_dir.rglob('**/ground truth0/*.tif'))

train_data = MyDataSet(
    image_files=X,
    label_files=Y,
    target_shape=(256, 256, 3)
)

# NOTE: the length of the dataset might not be the same as n_samples
#       because files not having the target shape will be discarded
print(len(train_data))
# Out:
# 100%|██████████| 301/301 [00:00<00:00, 521.26it/s]
# 301

# %% [markdown]
# ## Create a DataLoader
#
# This is done so we can load batches of images.

# %%
from torch.utils.data import DataLoader

train_loader = DataLoader(train_data, batch_size=32, shuffle=True)

# %% [markdown]
# ## Create a UNET

# %%
from monai.networks.nets import BasicUNet

model = BasicUNet(
    spatial_dims=2,
    in_channels=3,
    out_channels=1,
    #features=[16, 16, 32, 64, 128, 16],
    act="relu",
    norm="batch",
    dropout=0.25,
)

# Important: transfer the model to the chosen device
model = model.to(device)

optimizer = torch.optim.Adam(model.parameters(), lr=1.e-3)
init_params = list(model.parameters())[0].clone().detach()
# Out:
# BasicUNet features: (32, 32, 64, 128, 256, 32).

# %% [markdown]
# ## Train the UNET

# %%
max_nepochs = 200
log_interval = 1
model.train(True)

# BCEWithLogitsLoss combines sigmoid + BCELoss for better
# numerical stability. It expects raw unnormalized scores as input which are shaped like 
# B x C x W x D
loss_function = torch.nn.BCEWithLogitsLoss(reduction="mean")

for epoch in range(1, max_nepochs + 1):
    for batch_idx, (X, y) in enumerate(train_loader):
        # the inputs and labels have to be on the same device as the model
        X, y = X.to(device), y.to(device)
        
        optimizer.zero_grad()

        prediction_logits = model(X)
        
        batch_loss = loss_function(prediction_logits, y)

        batch_loss.backward()

        optimizer.step()

        if batch_idx % log_interval == 0:
            print(
                "Train Epoch:",
                epoch,
                "Batch:",
                batch_idx,
                "Total samples processed:",
                (batch_idx + 1) * train_loader.batch_size,
                "Loss:",
                batch_loss.item(),
            )
# Out:
# Train Epoch: 1 Batch: 0 Total samples processed: 32 Loss: 0.7241578102111816
# Train Epoch: 1 Batch: 1 Total samples processed: 64 Loss: 0.6913292407989502
# Train Epoch: 1 Batch: 2 Total samples processed: 96 Loss: 0.6597611308097839
# Train Epoch: 1 Batch: 3 Total samples processed: 128 Loss: 0.642471194267273
# Train Epoch: 1 Batch: 4 Total samples processed: 160 Loss: 0.6368253827095032
# Train Epoch: 1 Batch: 5 Total samples processed: 192 Loss: 0.627289891242981
# Train Epoch: 1 Batch: 6 Total samples processed: 224 Loss: 0.597440242767334
# Train Epoch: 1 Batch: 7 Total samples processed: 256 Loss: 0.5808532238006592
# Train Epoch: 1 Batch: 8 Total samples processed: 288 Loss: 0.590753436088562
# Train Epoch: 1 Batch: 9 Total samples processed: 320 Loss: 0.6179795265197754
# Train Epoch: 2 Batch: 0 Total samples processed: 32 Loss: 0.564697802066803
# Train Epoch: 2 Batch: 1 Total samples processed: 64 Loss: 0.5317906141281128
# Train Epoch: 2 Batch: 2 Total samples processed: 96 Loss: 0.5356417894363403
# Train Epoch: 2 Batch: 3 Total samples processed: 128 Loss: 0.48769551515579224
# Train Epoch: 2 Batch: 4 Total samples processed: 160 Loss: 0.501442015171051
# Train Epoch: 2 Batch: 5 Total samples processed: 192 Loss: 0.4962882101535797
# Train Epoch: 2 Batch: 6 Total samples processed: 224 Loss: 0.48685207962989807
# Train Epoch: 2 Batch: 7 Total samples processed: 256 Loss: 0.46670112013816833
# Train Epoch: 2 Batch: 8 Total samples processed: 288 Loss: 0.4838275909423828
# Train Epoch: 2 Batch: 9 Total samples processed: 320 Loss: 0.6099500060081482
# Train Epoch: 3 Batch: 0 Total samples processed: 32 Loss: 0.5068167448043823
# Train Epoch: 3 Batch: 1 Total samples processed: 64 Loss: 0.4717021584510803
# Train Epoch: 3 Batch: 2 Total samples processed: 96 Loss: 0.45226776599884033
# Train Epoch: 3 Batch: 3 Total samples processed: 128 Loss: 0.47036731243133545
# Train Epoch: 3 Batch: 4 Total samples processed: 160 Loss: 0.4379926025867462
# Train Epoch: 3 Batch: 5 Total samples processed: 192 Loss: 0.4463316798210144
# Train Epoch: 3 Batch: 6 Total samples processed: 224 Loss: 0.4336468279361725
# Train Epoch: 3 Batch: 7 Total samples processed: 256 Loss: 0.4378002882003784
# Train Epoch: 3 Batch: 8 Total samples processed: 288 Loss: 0.43072542548179626
# Train Epoch: 3 Batch: 9 Total samples processed: 320 Loss: 0.4937504529953003
# Train Epoch: 4 Batch: 0 Total samples processed: 32 Loss: 0.43696773052215576
# Train Epoch: 4 Batch: 1 Total samples processed: 64 Loss: 0.4197458326816559
# Train Epoch: 4 Batch: 2 Total samples processed: 96 Loss: 0.4064590334892273
# Train Epoch: 4 Batch: 3 Total samples processed: 128 Loss: 0.4154646396636963
# Train Epoch: 4 Batch: 4 Total samples processed: 160 Loss: 0.40962639451026917
# Train Epoch: 4 Batch: 5 Total samples processed: 192 Loss: 0.4117312431335449
# Train Epoch: 4 Batch: 6 Total samples processed: 224 Loss: 0.3895341753959656
# Train Epoch: 4 Batch: 7 Total samples processed: 256 Loss: 0.4027729630470276
# Train Epoch: 4 Batch: 8 Total samples processed: 288 Loss: 0.38319331407546997
# Train Epoch: 4 Batch: 9 Total samples processed: 320 Loss: 0.37025800347328186
# Train Epoch: 5 Batch: 0 Total samples processed: 32 Loss: 0.3757552206516266
# Train Epoch: 5 Batch: 1 Total samples processed: 64 Loss: 0.37470436096191406
# Train Epoch: 5 Batch: 2 Total samples processed: 96 Loss: 0.3605647683143616
# Train Epoch: 5 Batch: 3 Total samples processed: 128 Loss: 0.3594048023223877
# Train Epoch: 5 Batch: 4 Total samples processed: 160 Loss: 0.3816080093383789
# Train Epoch: 5 Batch: 5 Total samples processed: 192 Loss: 0.3932708501815796
# Train Epoch: 5 Batch: 6 Total samples processed: 224 Loss: 0.3649097681045532
# Train Epoch: 5 Batch: 7 Total samples processed: 256 Loss: 0.37006300687789917
# Train Epoch: 5 Batch: 8 Total samples processed: 288 Loss: 0.35511279106140137
# Train Epoch: 5 Batch: 9 Total samples processed: 320 Loss: 0.35689422488212585
# Train Epoch: 6 Batch: 0 Total samples processed: 32 Loss: 0.3400946259498596
# Train Epoch: 6 Batch: 1 Total samples processed: 64 Loss: 0.3624897003173828
# Train Epoch: 6 Batch: 2 Total samples processed: 96 Loss: 0.35671985149383545
# Train Epoch: 6 Batch: 3 Total samples processed: 128 Loss: 0.3374369442462921
# Train Epoch: 6 Batch: 4 Total samples processed: 160 Loss: 0.3458835482597351
# Train Epoch: 6 Batch: 5 Total samples processed: 192 Loss: 0.32835251092910767
# Train Epoch: 6 Batch: 6 Total samples processed: 224 Loss: 0.36060118675231934
# Train Epoch: 6 Batch: 7 Total samples processed: 256 Loss: 0.33726632595062256
# Train Epoch: 6 Batch: 8 Total samples processed: 288 Loss: 0.3212742209434509
# Train Epoch: 6 Batch: 9 Total samples processed: 320 Loss: 0.34883400797843933
# Train Epoch: 7 Batch: 0 Total samples processed: 32 Loss: 0.3329771161079407
# Train Epoch: 7 Batch: 1 Total samples processed: 64 Loss: 0.3245529234409332
# Train Epoch: 7 Batch: 2 Total samples processed: 96 Loss: 0.31815600395202637
# Train Epoch: 7 Batch: 3 Total samples processed: 128 Loss: 0.31232184171676636
# Train Epoch: 7 Batch: 4 Total samples processed: 160 Loss: 0.3038277328014374
# Train Epoch: 7 Batch: 5 Total samples processed: 192 Loss: 0.32379150390625
# Train Epoch: 7 Batch: 6 Total samples processed: 224 Loss: 0.3233518898487091
# Train Epoch: 7 Batch: 7 Total samples processed: 256 Loss: 0.3043976426124573
# Train Epoch: 7 Batch: 8 Total samples processed: 288 Loss: 0.32018470764160156
# Train Epoch: 7 Batch: 9 Total samples processed: 320 Loss: 0.28679925203323364
# Train Epoch: 8 Batch: 0 Total samples processed: 32 Loss: 0.29819637537002563
# Train Epoch: 8 Batch: 1 Total samples processed: 64 Loss: 0.29762059450149536
# Train Epoch: 8 Batch: 2 Total samples processed: 96 Loss: 0.30115190148353577
# Train Epoch: 8 Batch: 3 Total samples processed: 128 Loss: 0.2931366562843323
# Train Epoch: 8 Batch: 4 Total samples processed: 160 Loss: 0.28694337606430054
# Train Epoch: 8 Batch: 5 Total samples processed: 192 Loss: 0.2907446324825287
# Train Epoch: 8 Batch: 6 Total samples processed: 224 Loss: 0.2819371819496155
# Train Epoch: 8 Batch: 7 Total samples processed: 256 Loss: 0.2896796464920044
# Train Epoch: 8 Batch: 8 Total samples processed: 288 Loss: 0.27438488602638245
# Train Epoch: 8 Batch: 9 Total samples processed: 320 Loss: 0.3082200586795807
# Train Epoch: 9 Batch: 0 Total samples processed: 32 Loss: 0.26348525285720825
# Train Epoch: 9 Batch: 1 Total samples processed: 64 Loss: 0.27249547839164734
# Train Epoch: 9 Batch: 2 Total samples processed: 96 Loss: 0.2695595622062683
# Train Epoch: 9 Batch: 3 Total samples processed: 128 Loss: 0.261857271194458
# Train Epoch: 9 Batch: 4 Total samples processed: 160 Loss: 0.2631239891052246
# Train Epoch: 9 Batch: 5 Total samples processed: 192 Loss: 0.2630109190940857
# Train Epoch: 9 Batch: 6 Total samples processed: 224 Loss: 0.27436599135398865
# Train Epoch: 9 Batch: 7 Total samples processed: 256 Loss: 0.2669724225997925
# Train Epoch: 9 Batch: 8 Total samples processed: 288 Loss: 0.250404417514801
# Train Epoch: 9 Batch: 9 Total samples processed: 320 Loss: 0.26274192333221436
# Train Epoch: 10 Batch: 0 Total samples processed: 32 Loss: 0.2456747591495514
# Train Epoch: 10 Batch: 1 Total samples processed: 64 Loss: 0.24369271099567413
# Train Epoch: 10 Batch: 2 Total samples processed: 96 Loss: 0.254905104637146
# Train Epoch: 10 Batch: 3 Total samples processed: 128 Loss: 0.26331353187561035
# Train Epoch: 10 Batch: 4 Total samples processed: 160 Loss: 0.24905748665332794
# Train Epoch: 10 Batch: 5 Total samples processed: 192 Loss: 0.23953701555728912
# Train Epoch: 10 Batch: 6 Total samples processed: 224 Loss: 0.23584681749343872
# Train Epoch: 10 Batch: 7 Total samples processed: 256 Loss: 0.2597367465496063
# Train Epoch: 10 Batch: 8 Total samples processed: 288 Loss: 0.2500355839729309
# Train Epoch: 10 Batch: 9 Total samples processed: 320 Loss: 0.24130763113498688
# Train Epoch: 11 Batch: 0 Total samples processed: 32 Loss: 0.22943726181983948
# Train Epoch: 11 Batch: 1 Total samples processed: 64 Loss: 0.24743613600730896
# Train Epoch: 11 Batch: 2 Total samples processed: 96 Loss: 0.23965641856193542
# Train Epoch: 11 Batch: 3 Total samples processed: 128 Loss: 0.2455042600631714
# Train Epoch: 11 Batch: 4 Total samples processed: 160 Loss: 0.23929469287395477
# Train Epoch: 11 Batch: 5 Total samples processed: 192 Loss: 0.235142320394516
# Train Epoch: 11 Batch: 6 Total samples processed: 224 Loss: 0.2287725806236267
# Train Epoch: 11 Batch: 7 Total samples processed: 256 Loss: 0.22788964211940765
# Train Epoch: 11 Batch: 8 Total samples processed: 288 Loss: 0.24375483393669128
# Train Epoch: 11 Batch: 9 Total samples processed: 320 Loss: 0.21356521546840668
# Train Epoch: 12 Batch: 0 Total samples processed: 32 Loss: 0.23691827058792114
# Train Epoch: 12 Batch: 1 Total samples processed: 64 Loss: 0.2314450740814209
# Train Epoch: 12 Batch: 2 Total samples processed: 96 Loss: 0.23451215028762817
# Train Epoch: 12 Batch: 3 Total samples processed: 128 Loss: 0.22044378519058228
# Train Epoch: 12 Batch: 4 Total samples processed: 160 Loss: 0.21833716332912445
# Train Epoch: 12 Batch: 5 Total samples processed: 192 Loss: 0.2197219729423523
# Train Epoch: 12 Batch: 6 Total samples processed: 224 Loss: 0.21908752620220184
# Train Epoch: 12 Batch: 7 Total samples processed: 256 Loss: 0.22726711630821228
# Train Epoch: 12 Batch: 8 Total samples processed: 288 Loss: 0.2105923593044281
# Train Epoch: 12 Batch: 9 Total samples processed: 320 Loss: 0.21291689574718475
# Train Epoch: 13 Batch: 0 Total samples processed: 32 Loss: 0.21259728074073792
# Train Epoch: 13 Batch: 1 Total samples processed: 64 Loss: 0.2337835729122162
# Train Epoch: 13 Batch: 2 Total samples processed: 96 Loss: 0.21551737189292908
# Train Epoch: 13 Batch: 3 Total samples processed: 128 Loss: 0.2130313515663147
# Train Epoch: 13 Batch: 4 Total samples processed: 160 Loss: 0.2207265943288803
# Train Epoch: 13 Batch: 5 Total samples processed: 192 Loss: 0.20817506313323975
# Train Epoch: 13 Batch: 6 Total samples processed: 224 Loss: 0.20469143986701965
# Train Epoch: 13 Batch: 7 Total samples processed: 256 Loss: 0.2067650407552719
# Train Epoch: 13 Batch: 8 Total samples processed: 288 Loss: 0.20383134484291077
# Train Epoch: 13 Batch: 9 Total samples processed: 320 Loss: 0.19587181508541107
# Train Epoch: 14 Batch: 0 Total samples processed: 32 Loss: 0.22250518202781677
# Train Epoch: 14 Batch: 1 Total samples processed: 64 Loss: 0.1936584860086441
# Train Epoch: 14 Batch: 2 Total samples processed: 96 Loss: 0.21231034398078918
# Train Epoch: 14 Batch: 3 Total samples processed: 128 Loss: 0.18986406922340393
# Train Epoch: 14 Batch: 4 Total samples processed: 160 Loss: 0.20198842883110046
# Train Epoch: 14 Batch: 5 Total samples processed: 192 Loss: 0.19519777595996857
# Train Epoch: 14 Batch: 6 Total samples processed: 224 Loss: 0.20133918523788452
# Train Epoch: 14 Batch: 7 Total samples processed: 256 Loss: 0.20186105370521545
# Train Epoch: 14 Batch: 8 Total samples processed: 288 Loss: 0.2063615322113037
# Train Epoch: 14 Batch: 9 Total samples processed: 320 Loss: 0.18695497512817383
# Train Epoch: 15 Batch: 0 Total samples processed: 32 Loss: 0.20276790857315063
# Train Epoch: 15 Batch: 1 Total samples processed: 64 Loss: 0.18963642418384552
# Train Epoch: 15 Batch: 2 Total samples processed: 96 Loss: 0.20813335478305817
# Train Epoch: 15 Batch: 3 Total samples processed: 128 Loss: 0.2006305605173111
# Train Epoch: 15 Batch: 4 Total samples processed: 160 Loss: 0.19876962900161743
# Train Epoch: 15 Batch: 5 Total samples processed: 192 Loss: 0.19242388010025024
# Train Epoch: 15 Batch: 6 Total samples processed: 224 Loss: 0.20918889343738556
# Train Epoch: 15 Batch: 7 Total samples processed: 256 Loss: 0.187935009598732
# Train Epoch: 15 Batch: 8 Total samples processed: 288 Loss: 0.19778046011924744
# Train Epoch: 15 Batch: 9 Total samples processed: 320 Loss: 0.1773432046175003
# Train Epoch: 16 Batch: 0 Total samples processed: 32 Loss: 0.19265082478523254
# Train Epoch: 16 Batch: 1 Total samples processed: 64 Loss: 0.20131798088550568
# Train Epoch: 16 Batch: 2 Total samples processed: 96 Loss: 0.19448301196098328
# Train Epoch: 16 Batch: 3 Total samples processed: 128 Loss: 0.18717974424362183
# Train Epoch: 16 Batch: 4 Total samples processed: 160 Loss: 0.18822622299194336
# Train Epoch: 16 Batch: 5 Total samples processed: 192 Loss: 0.18404999375343323
# Train Epoch: 16 Batch: 6 Total samples processed: 224 Loss: 0.18328016996383667
# Train Epoch: 16 Batch: 7 Total samples processed: 256 Loss: 0.19035595655441284
# Train Epoch: 16 Batch: 8 Total samples processed: 288 Loss: 0.1817321479320526
# Train Epoch: 16 Batch: 9 Total samples processed: 320 Loss: 0.18080011010169983
# Train Epoch: 17 Batch: 0 Total samples processed: 32 Loss: 0.18253621459007263
# Train Epoch: 17 Batch: 1 Total samples processed: 64 Loss: 0.1798582375049591
# Train Epoch: 17 Batch: 2 Total samples processed: 96 Loss: 0.18412190675735474
# Train Epoch: 17 Batch: 3 Total samples processed: 128 Loss: 0.18698662519454956
# Train Epoch: 17 Batch: 4 Total samples processed: 160 Loss: 0.19274955987930298
# Train Epoch: 17 Batch: 5 Total samples processed: 192 Loss: 0.18344932794570923
# Train Epoch: 17 Batch: 6 Total samples processed: 224 Loss: 0.1801224946975708
# Train Epoch: 17 Batch: 7 Total samples processed: 256 Loss: 0.17662790417671204
# Train Epoch: 17 Batch: 8 Total samples processed: 288 Loss: 0.17382603883743286
# Train Epoch: 17 Batch: 9 Total samples processed: 320 Loss: 0.17528043687343597
# Train Epoch: 18 Batch: 0 Total samples processed: 32 Loss: 0.17578203976154327
# Train Epoch: 18 Batch: 1 Total samples processed: 64 Loss: 0.16641667485237122
# Train Epoch: 18 Batch: 2 Total samples processed: 96 Loss: 0.17770081758499146
# Train Epoch: 18 Batch: 3 Total samples processed: 128 Loss: 0.1807609647512436
# Train Epoch: 18 Batch: 4 Total samples processed: 160 Loss: 0.18377336859703064
# Train Epoch: 18 Batch: 5 Total samples processed: 192 Loss: 0.1748965084552765
# Train Epoch: 18 Batch: 6 Total samples processed: 224 Loss: 0.16945239901542664
# Train Epoch: 18 Batch: 7 Total samples processed: 256 Loss: 0.17927727103233337
# Train Epoch: 18 Batch: 8 Total samples processed: 288 Loss: 0.17146457731723785
# Train Epoch: 18 Batch: 9 Total samples processed: 320 Loss: 0.16344086825847626
# Train Epoch: 19 Batch: 0 Total samples processed: 32 Loss: 0.1731034368276596
# Train Epoch: 19 Batch: 1 Total samples processed: 64 Loss: 0.166693776845932
# Train Epoch: 19 Batch: 2 Total samples processed: 96 Loss: 0.16073675453662872
# Train Epoch: 19 Batch: 3 Total samples processed: 128 Loss: 0.16543522477149963
# Train Epoch: 19 Batch: 4 Total samples processed: 160 Loss: 0.16955694556236267
# Train Epoch: 19 Batch: 5 Total samples processed: 192 Loss: 0.17001305520534515
# Train Epoch: 19 Batch: 6 Total samples processed: 224 Loss: 0.16465438902378082
# Train Epoch: 19 Batch: 7 Total samples processed: 256 Loss: 0.1753861904144287
# Train Epoch: 19 Batch: 8 Total samples processed: 288 Loss: 0.17175999283790588
# Train Epoch: 19 Batch: 9 Total samples processed: 320 Loss: 0.1676991581916809
# Train Epoch: 20 Batch: 0 Total samples processed: 32 Loss: 0.1772596389055252
# Train Epoch: 20 Batch: 1 Total samples processed: 64 Loss: 0.16814789175987244
# Train Epoch: 20 Batch: 2 Total samples processed: 96 Loss: 0.16322119534015656
# Train Epoch: 20 Batch: 3 Total samples processed: 128 Loss: 0.17175506055355072
# Train Epoch: 20 Batch: 4 Total samples processed: 160 Loss: 0.15376503765583038
# Train Epoch: 20 Batch: 5 Total samples processed: 192 Loss: 0.15612350404262543
# Train Epoch: 20 Batch: 6 Total samples processed: 224 Loss: 0.16152477264404297
# Train Epoch: 20 Batch: 7 Total samples processed: 256 Loss: 0.17372232675552368
# Train Epoch: 20 Batch: 8 Total samples processed: 288 Loss: 0.15883374214172363
# Train Epoch: 20 Batch: 9 Total samples processed: 320 Loss: 0.15175390243530273
# Train Epoch: 21 Batch: 0 Total samples processed: 32 Loss: 0.1635391116142273
# Train Epoch: 21 Batch: 1 Total samples processed: 64 Loss: 0.1562333106994629
# Train Epoch: 21 Batch: 2 Total samples processed: 96 Loss: 0.152543842792511
# Train Epoch: 21 Batch: 3 Total samples processed: 128 Loss: 0.1579791009426117
# Train Epoch: 21 Batch: 4 Total samples processed: 160 Loss: 0.16116614639759064
# Train Epoch: 21 Batch: 5 Total samples processed: 192 Loss: 0.15517932176589966
# Train Epoch: 21 Batch: 6 Total samples processed: 224 Loss: 0.17255176603794098
# Train Epoch: 21 Batch: 7 Total samples processed: 256 Loss: 0.1571321189403534
# Train Epoch: 21 Batch: 8 Total samples processed: 288 Loss: 0.14544245600700378
# Train Epoch: 21 Batch: 9 Total samples processed: 320 Loss: 0.1828290820121765
# Train Epoch: 22 Batch: 0 Total samples processed: 32 Loss: 0.1537216603755951
# Train Epoch: 22 Batch: 1 Total samples processed: 64 Loss: 0.1577758938074112
# Train Epoch: 22 Batch: 2 Total samples processed: 96 Loss: 0.14945203065872192
# Train Epoch: 22 Batch: 3 Total samples processed: 128 Loss: 0.1664198786020279
# Train Epoch: 22 Batch: 4 Total samples processed: 160 Loss: 0.15184706449508667
# Train Epoch: 22 Batch: 5 Total samples processed: 192 Loss: 0.1646789312362671
# Train Epoch: 22 Batch: 6 Total samples processed: 224 Loss: 0.14972668886184692
# Train Epoch: 22 Batch: 7 Total samples processed: 256 Loss: 0.15612545609474182
# Train Epoch: 22 Batch: 8 Total samples processed: 288 Loss: 0.1701304316520691
# Train Epoch: 22 Batch: 9 Total samples processed: 320 Loss: 0.1708979308605194
# Train Epoch: 23 Batch: 0 Total samples processed: 32 Loss: 0.1547609567642212
# Train Epoch: 23 Batch: 1 Total samples processed: 64 Loss: 0.15043582022190094
# Train Epoch: 23 Batch: 2 Total samples processed: 96 Loss: 0.14691531658172607
# Train Epoch: 23 Batch: 3 Total samples processed: 128 Loss: 0.15227210521697998
# Train Epoch: 23 Batch: 4 Total samples processed: 160 Loss: 0.15085823833942413
# Train Epoch: 23 Batch: 5 Total samples processed: 192 Loss: 0.15991485118865967
# Train Epoch: 23 Batch: 6 Total samples processed: 224 Loss: 0.16839253902435303
# Train Epoch: 23 Batch: 7 Total samples processed: 256 Loss: 0.14950191974639893
# Train Epoch: 23 Batch: 8 Total samples processed: 288 Loss: 0.149879589676857
# Train Epoch: 23 Batch: 9 Total samples processed: 320 Loss: 0.1577555239200592
# Train Epoch: 24 Batch: 0 Total samples processed: 32 Loss: 0.15071037411689758
# Train Epoch: 24 Batch: 1 Total samples processed: 64 Loss: 0.1501307338476181
# Train Epoch: 24 Batch: 2 Total samples processed: 96 Loss: 0.15653306245803833
# Train Epoch: 24 Batch: 3 Total samples processed: 128 Loss: 0.1592182219028473
# Train Epoch: 24 Batch: 4 Total samples processed: 160 Loss: 0.1518489569425583
# Train Epoch: 24 Batch: 5 Total samples processed: 192 Loss: 0.14644962549209595
# Train Epoch: 24 Batch: 6 Total samples processed: 224 Loss: 0.14799611270427704
# Train Epoch: 24 Batch: 7 Total samples processed: 256 Loss: 0.1574581265449524
# Train Epoch: 24 Batch: 8 Total samples processed: 288 Loss: 0.15512026846408844
# Train Epoch: 24 Batch: 9 Total samples processed: 320 Loss: 0.15454623103141785
# Train Epoch: 25 Batch: 0 Total samples processed: 32 Loss: 0.1533050537109375
# Train Epoch: 25 Batch: 1 Total samples processed: 64 Loss: 0.14895281195640564
# Train Epoch: 25 Batch: 2 Total samples processed: 96 Loss: 0.15073147416114807
# Train Epoch: 25 Batch: 3 Total samples processed: 128 Loss: 0.14976194500923157
# Train Epoch: 25 Batch: 4 Total samples processed: 160 Loss: 0.14980897307395935
# Train Epoch: 25 Batch: 5 Total samples processed: 192 Loss: 0.14631173014640808
# Train Epoch: 25 Batch: 6 Total samples processed: 224 Loss: 0.1534520387649536
# Train Epoch: 25 Batch: 7 Total samples processed: 256 Loss: 0.14565244317054749
# Train Epoch: 25 Batch: 8 Total samples processed: 288 Loss: 0.14606845378875732
# Train Epoch: 25 Batch: 9 Total samples processed: 320 Loss: 0.14352522790431976
# Train Epoch: 26 Batch: 0 Total samples processed: 32 Loss: 0.14652186632156372
# Train Epoch: 26 Batch: 1 Total samples processed: 64 Loss: 0.14618179202079773
# Train Epoch: 26 Batch: 2 Total samples processed: 96 Loss: 0.14242014288902283
# Train Epoch: 26 Batch: 3 Total samples processed: 128 Loss: 0.13942524790763855
# Train Epoch: 26 Batch: 4 Total samples processed: 160 Loss: 0.1412815898656845
# Train Epoch: 26 Batch: 5 Total samples processed: 192 Loss: 0.14658716320991516
# Train Epoch: 26 Batch: 6 Total samples processed: 224 Loss: 0.1424039900302887
# Train Epoch: 26 Batch: 7 Total samples processed: 256 Loss: 0.1421523094177246
# Train Epoch: 26 Batch: 8 Total samples processed: 288 Loss: 0.1477953940629959
# Train Epoch: 26 Batch: 9 Total samples processed: 320 Loss: 0.1428174078464508
# Train Epoch: 27 Batch: 0 Total samples processed: 32 Loss: 0.13983985781669617
# Train Epoch: 27 Batch: 1 Total samples processed: 64 Loss: 0.13721564412117004
# Train Epoch: 27 Batch: 2 Total samples processed: 96 Loss: 0.1386326551437378
# Train Epoch: 27 Batch: 3 Total samples processed: 128 Loss: 0.1394452452659607
# Train Epoch: 27 Batch: 4 Total samples processed: 160 Loss: 0.14585429430007935
# Train Epoch: 27 Batch: 5 Total samples processed: 192 Loss: 0.138167142868042
# Train Epoch: 27 Batch: 6 Total samples processed: 224 Loss: 0.14104974269866943
# Train Epoch: 27 Batch: 7 Total samples processed: 256 Loss: 0.14118239283561707
# Train Epoch: 27 Batch: 8 Total samples processed: 288 Loss: 0.1371607482433319
# Train Epoch: 27 Batch: 9 Total samples processed: 320 Loss: 0.1326676309108734
# Train Epoch: 28 Batch: 0 Total samples processed: 32 Loss: 0.13772886991500854
# Train Epoch: 28 Batch: 1 Total samples processed: 64 Loss: 0.13621839880943298
# Train Epoch: 28 Batch: 2 Total samples processed: 96 Loss: 0.1420741081237793
# Train Epoch: 28 Batch: 3 Total samples processed: 128 Loss: 0.13456521928310394
# Train Epoch: 28 Batch: 4 Total samples processed: 160 Loss: 0.14437422156333923
# Train Epoch: 28 Batch: 5 Total samples processed: 192 Loss: 0.1337103545665741
# Train Epoch: 28 Batch: 6 Total samples processed: 224 Loss: 0.14059260487556458
# Train Epoch: 28 Batch: 7 Total samples processed: 256 Loss: 0.14087118208408356
# Train Epoch: 28 Batch: 8 Total samples processed: 288 Loss: 0.14910593628883362
# Train Epoch: 28 Batch: 9 Total samples processed: 320 Loss: 0.13877980411052704
# Train Epoch: 29 Batch: 0 Total samples processed: 32 Loss: 0.14443130791187286
# Train Epoch: 29 Batch: 1 Total samples processed: 64 Loss: 0.1381424069404602
# Train Epoch: 29 Batch: 2 Total samples processed: 96 Loss: 0.13942688703536987
# Train Epoch: 29 Batch: 3 Total samples processed: 128 Loss: 0.13325226306915283
# Train Epoch: 29 Batch: 4 Total samples processed: 160 Loss: 0.13948339223861694
# Train Epoch: 29 Batch: 5 Total samples processed: 192 Loss: 0.13284167647361755
# Train Epoch: 29 Batch: 6 Total samples processed: 224 Loss: 0.13425888121128082
# Train Epoch: 29 Batch: 7 Total samples processed: 256 Loss: 0.14115333557128906
# Train Epoch: 29 Batch: 8 Total samples processed: 288 Loss: 0.1367175281047821
# Train Epoch: 29 Batch: 9 Total samples processed: 320 Loss: 0.13642697036266327
# Train Epoch: 30 Batch: 0 Total samples processed: 32 Loss: 0.13219034671783447
# Train Epoch: 30 Batch: 1 Total samples processed: 64 Loss: 0.13643717765808105
# Train Epoch: 30 Batch: 2 Total samples processed: 96 Loss: 0.126896932721138
# Train Epoch: 30 Batch: 3 Total samples processed: 128 Loss: 0.13620583713054657
# Train Epoch: 30 Batch: 4 Total samples processed: 160 Loss: 0.14969879388809204
# Train Epoch: 30 Batch: 5 Total samples processed: 192 Loss: 0.1320309340953827
# Train Epoch: 30 Batch: 6 Total samples processed: 224 Loss: 0.13668952882289886
# Train Epoch: 30 Batch: 7 Total samples processed: 256 Loss: 0.13345280289649963
# Train Epoch: 30 Batch: 8 Total samples processed: 288 Loss: 0.13457751274108887
# Train Epoch: 30 Batch: 9 Total samples processed: 320 Loss: 0.12916329503059387
# Train Epoch: 31 Batch: 0 Total samples processed: 32 Loss: 0.13648906350135803
# Train Epoch: 31 Batch: 1 Total samples processed: 64 Loss: 0.13239747285842896
# Train Epoch: 31 Batch: 2 Total samples processed: 96 Loss: 0.13713501393795013
# Train Epoch: 31 Batch: 3 Total samples processed: 128 Loss: 0.12535607814788818
# Train Epoch: 31 Batch: 4 Total samples processed: 160 Loss: 0.13185033202171326
# Train Epoch: 31 Batch: 5 Total samples processed: 192 Loss: 0.1302042007446289
# Train Epoch: 31 Batch: 6 Total samples processed: 224 Loss: 0.12593074142932892
# Train Epoch: 31 Batch: 7 Total samples processed: 256 Loss: 0.13064044713974
# Train Epoch: 31 Batch: 8 Total samples processed: 288 Loss: 0.13682706654071808
# Train Epoch: 31 Batch: 9 Total samples processed: 320 Loss: 0.13741172850131989
# Train Epoch: 32 Batch: 0 Total samples processed: 32 Loss: 0.12804967164993286
# Train Epoch: 32 Batch: 1 Total samples processed: 64 Loss: 0.12763899564743042
# Train Epoch: 32 Batch: 2 Total samples processed: 96 Loss: 0.13308538496494293
# Train Epoch: 32 Batch: 3 Total samples processed: 128 Loss: 0.13087618350982666
# Train Epoch: 32 Batch: 4 Total samples processed: 160 Loss: 0.13542398810386658
# Train Epoch: 32 Batch: 5 Total samples processed: 192 Loss: 0.12974998354911804
# Train Epoch: 32 Batch: 6 Total samples processed: 224 Loss: 0.13120190799236298
# Train Epoch: 32 Batch: 7 Total samples processed: 256 Loss: 0.12891483306884766
# Train Epoch: 32 Batch: 8 Total samples processed: 288 Loss: 0.13494527339935303
# Train Epoch: 32 Batch: 9 Total samples processed: 320 Loss: 0.12866537272930145
# Train Epoch: 33 Batch: 0 Total samples processed: 32 Loss: 0.1312551200389862
# Train Epoch: 33 Batch: 1 Total samples processed: 64 Loss: 0.1297016739845276
# Train Epoch: 33 Batch: 2 Total samples processed: 96 Loss: 0.1375107765197754
# Train Epoch: 33 Batch: 3 Total samples processed: 128 Loss: 0.14078693091869354
# Train Epoch: 33 Batch: 4 Total samples processed: 160 Loss: 0.13469980657100677
# Train Epoch: 33 Batch: 5 Total samples processed: 192 Loss: 0.12685373425483704
# Train Epoch: 33 Batch: 6 Total samples processed: 224 Loss: 0.12821973860263824
# Train Epoch: 33 Batch: 7 Total samples processed: 256 Loss: 0.1378391832113266
# Train Epoch: 33 Batch: 8 Total samples processed: 288 Loss: 0.12271748483181
# Train Epoch: 33 Batch: 9 Total samples processed: 320 Loss: 0.13202983140945435
# Train Epoch: 34 Batch: 0 Total samples processed: 32 Loss: 0.13594283163547516
# Train Epoch: 34 Batch: 1 Total samples processed: 64 Loss: 0.13648341596126556
# Train Epoch: 34 Batch: 2 Total samples processed: 96 Loss: 0.13274788856506348
# Train Epoch: 34 Batch: 3 Total samples processed: 128 Loss: 0.13288037478923798
# Train Epoch: 34 Batch: 4 Total samples processed: 160 Loss: 0.12923064827919006
# Train Epoch: 34 Batch: 5 Total samples processed: 192 Loss: 0.14029046893119812
# Train Epoch: 34 Batch: 6 Total samples processed: 224 Loss: 0.13466541469097137
# Train Epoch: 34 Batch: 7 Total samples processed: 256 Loss: 0.12457004189491272
# Train Epoch: 34 Batch: 8 Total samples processed: 288 Loss: 0.12671512365341187
# Train Epoch: 34 Batch: 9 Total samples processed: 320 Loss: 0.13936614990234375
# Train Epoch: 35 Batch: 0 Total samples processed: 32 Loss: 0.12731923162937164
# Train Epoch: 35 Batch: 1 Total samples processed: 64 Loss: 0.1296137124300003
# Train Epoch: 35 Batch: 2 Total samples processed: 96 Loss: 0.13619014620780945
# Train Epoch: 35 Batch: 3 Total samples processed: 128 Loss: 0.1266169250011444
# Train Epoch: 35 Batch: 4 Total samples processed: 160 Loss: 0.12479615956544876
# Train Epoch: 35 Batch: 5 Total samples processed: 192 Loss: 0.12846843898296356
# Train Epoch: 35 Batch: 6 Total samples processed: 224 Loss: 0.12103627622127533
# Train Epoch: 35 Batch: 7 Total samples processed: 256 Loss: 0.12990432977676392
# Train Epoch: 35 Batch: 8 Total samples processed: 288 Loss: 0.12217946350574493
# Train Epoch: 35 Batch: 9 Total samples processed: 320 Loss: 0.1302909255027771
# Train Epoch: 36 Batch: 0 Total samples processed: 32 Loss: 0.123372882604599
# Train Epoch: 36 Batch: 1 Total samples processed: 64 Loss: 0.12540680170059204
# Train Epoch: 36 Batch: 2 Total samples processed: 96 Loss: 0.1266610324382782
# Train Epoch: 36 Batch: 3 Total samples processed: 128 Loss: 0.11891639232635498
# Train Epoch: 36 Batch: 4 Total samples processed: 160 Loss: 0.12073974311351776
# Train Epoch: 36 Batch: 5 Total samples processed: 192 Loss: 0.12473281472921371
# Train Epoch: 36 Batch: 6 Total samples processed: 224 Loss: 0.11715297400951385
# Train Epoch: 36 Batch: 7 Total samples processed: 256 Loss: 0.13010992109775543
# Train Epoch: 36 Batch: 8 Total samples processed: 288 Loss: 0.12528744339942932
# Train Epoch: 36 Batch: 9 Total samples processed: 320 Loss: 0.13736803829669952
# Train Epoch: 37 Batch: 0 Total samples processed: 32 Loss: 0.12248218059539795
# Train Epoch: 37 Batch: 1 Total samples processed: 64 Loss: 0.1211332231760025
# Train Epoch: 37 Batch: 2 Total samples processed: 96 Loss: 0.1265726089477539
# Train Epoch: 37 Batch: 3 Total samples processed: 128 Loss: 0.12135984003543854
# Train Epoch: 37 Batch: 4 Total samples processed: 160 Loss: 0.1200275644659996
# Train Epoch: 37 Batch: 5 Total samples processed: 192 Loss: 0.11673285067081451
# Train Epoch: 37 Batch: 6 Total samples processed: 224 Loss: 0.11892549693584442
# Train Epoch: 37 Batch: 7 Total samples processed: 256 Loss: 0.11710093170404434
# Train Epoch: 37 Batch: 8 Total samples processed: 288 Loss: 0.1295357048511505
# Train Epoch: 37 Batch: 9 Total samples processed: 320 Loss: 0.11186807602643967
# Train Epoch: 38 Batch: 0 Total samples processed: 32 Loss: 0.11840755492448807
# Train Epoch: 38 Batch: 1 Total samples processed: 64 Loss: 0.12545284628868103
# Train Epoch: 38 Batch: 2 Total samples processed: 96 Loss: 0.1185699999332428
# Train Epoch: 38 Batch: 3 Total samples processed: 128 Loss: 0.121038518846035
# Train Epoch: 38 Batch: 4 Total samples processed: 160 Loss: 0.11862725764513016
# Train Epoch: 38 Batch: 5 Total samples processed: 192 Loss: 0.11895906925201416
# Train Epoch: 38 Batch: 6 Total samples processed: 224 Loss: 0.11986013501882553
# Train Epoch: 38 Batch: 7 Total samples processed: 256 Loss: 0.11202265322208405
# Train Epoch: 38 Batch: 8 Total samples processed: 288 Loss: 0.11997459083795547
# Train Epoch: 38 Batch: 9 Total samples processed: 320 Loss: 0.12265215069055557
# Train Epoch: 39 Batch: 0 Total samples processed: 32 Loss: 0.1134575754404068
# Train Epoch: 39 Batch: 1 Total samples processed: 64 Loss: 0.1210707351565361
# Train Epoch: 39 Batch: 2 Total samples processed: 96 Loss: 0.11751767247915268
# Train Epoch: 39 Batch: 3 Total samples processed: 128 Loss: 0.11439713835716248
# Train Epoch: 39 Batch: 4 Total samples processed: 160 Loss: 0.11760521680116653
# Train Epoch: 39 Batch: 5 Total samples processed: 192 Loss: 0.11468673497438431
# Train Epoch: 39 Batch: 6 Total samples processed: 224 Loss: 0.11228320747613907
# Train Epoch: 39 Batch: 7 Total samples processed: 256 Loss: 0.12227652221918106
# Train Epoch: 39 Batch: 8 Total samples processed: 288 Loss: 0.1186460629105568
# Train Epoch: 39 Batch: 9 Total samples processed: 320 Loss: 0.12165318429470062
# Train Epoch: 40 Batch: 0 Total samples processed: 32 Loss: 0.11472702026367188
# Train Epoch: 40 Batch: 1 Total samples processed: 64 Loss: 0.11625036597251892
# Train Epoch: 40 Batch: 2 Total samples processed: 96 Loss: 0.11414879560470581
# Train Epoch: 40 Batch: 3 Total samples processed: 128 Loss: 0.12265029549598694
# Train Epoch: 40 Batch: 4 Total samples processed: 160 Loss: 0.11253590881824493
# Train Epoch: 40 Batch: 5 Total samples processed: 192 Loss: 0.11874652653932571
# Train Epoch: 40 Batch: 6 Total samples processed: 224 Loss: 0.11764027923345566
# Train Epoch: 40 Batch: 7 Total samples processed: 256 Loss: 0.11348794400691986
# Train Epoch: 40 Batch: 8 Total samples processed: 288 Loss: 0.11743871122598648
# Train Epoch: 40 Batch: 9 Total samples processed: 320 Loss: 0.11399513483047485
# Train Epoch: 41 Batch: 0 Total samples processed: 32 Loss: 0.11415114253759384
# Train Epoch: 41 Batch: 1 Total samples processed: 64 Loss: 0.12195385992527008
# Train Epoch: 41 Batch: 2 Total samples processed: 96 Loss: 0.1149127408862114
# Train Epoch: 41 Batch: 3 Total samples processed: 128 Loss: 0.11577071994543076
# Train Epoch: 41 Batch: 4 Total samples processed: 160 Loss: 0.1185217797756195
# Train Epoch: 41 Batch: 5 Total samples processed: 192 Loss: 0.11285285651683807
# Train Epoch: 41 Batch: 6 Total samples processed: 224 Loss: 0.11786733567714691
# Train Epoch: 41 Batch: 7 Total samples processed: 256 Loss: 0.11497196555137634
# Train Epoch: 41 Batch: 8 Total samples processed: 288 Loss: 0.11161044239997864
# Train Epoch: 41 Batch: 9 Total samples processed: 320 Loss: 0.12038977444171906
# Train Epoch: 42 Batch: 0 Total samples processed: 32 Loss: 0.11104711890220642
# Train Epoch: 42 Batch: 1 Total samples processed: 64 Loss: 0.11453872919082642
# Train Epoch: 42 Batch: 2 Total samples processed: 96 Loss: 0.11006668210029602
# Train Epoch: 42 Batch: 3 Total samples processed: 128 Loss: 0.11904851347208023
# Train Epoch: 42 Batch: 4 Total samples processed: 160 Loss: 0.11500151455402374
# Train Epoch: 42 Batch: 5 Total samples processed: 192 Loss: 0.12301602959632874
# Train Epoch: 42 Batch: 6 Total samples processed: 224 Loss: 0.11161231994628906
# Train Epoch: 42 Batch: 7 Total samples processed: 256 Loss: 0.11939984560012817
# Train Epoch: 42 Batch: 8 Total samples processed: 288 Loss: 0.11350232362747192
# Train Epoch: 42 Batch: 9 Total samples processed: 320 Loss: 0.1095508486032486
# Train Epoch: 43 Batch: 0 Total samples processed: 32 Loss: 0.1137743592262268
# Train Epoch: 43 Batch: 1 Total samples processed: 64 Loss: 0.11836959421634674
# Train Epoch: 43 Batch: 2 Total samples processed: 96 Loss: 0.11528638005256653
# Train Epoch: 43 Batch: 3 Total samples processed: 128 Loss: 0.11821341514587402
# Train Epoch: 43 Batch: 4 Total samples processed: 160 Loss: 0.12039192020893097
# Train Epoch: 43 Batch: 5 Total samples processed: 192 Loss: 0.10813748836517334
# Train Epoch: 43 Batch: 6 Total samples processed: 224 Loss: 0.11891111731529236
# Train Epoch: 43 Batch: 7 Total samples processed: 256 Loss: 0.12053921818733215
# Train Epoch: 43 Batch: 8 Total samples processed: 288 Loss: 0.10831103473901749
# Train Epoch: 43 Batch: 9 Total samples processed: 320 Loss: 0.10894656926393509
# Train Epoch: 44 Batch: 0 Total samples processed: 32 Loss: 0.11126355826854706
# Train Epoch: 44 Batch: 1 Total samples processed: 64 Loss: 0.11270181834697723
# Train Epoch: 44 Batch: 2 Total samples processed: 96 Loss: 0.10940845310688019
# Train Epoch: 44 Batch: 3 Total samples processed: 128 Loss: 0.10852744430303574
# Train Epoch: 44 Batch: 4 Total samples processed: 160 Loss: 0.11461701989173889
# Train Epoch: 44 Batch: 5 Total samples processed: 192 Loss: 0.11248677223920822
# Train Epoch: 44 Batch: 6 Total samples processed: 224 Loss: 0.11257098615169525
# Train Epoch: 44 Batch: 7 Total samples processed: 256 Loss: 0.11127831041812897
# Train Epoch: 44 Batch: 8 Total samples processed: 288 Loss: 0.11321718245744705
# Train Epoch: 44 Batch: 9 Total samples processed: 320 Loss: 0.1245364099740982
# Train Epoch: 45 Batch: 0 Total samples processed: 32 Loss: 0.11315993964672089
# Train Epoch: 45 Batch: 1 Total samples processed: 64 Loss: 0.11209863424301147
# Train Epoch: 45 Batch: 2 Total samples processed: 96 Loss: 0.11604803800582886
# Train Epoch: 45 Batch: 3 Total samples processed: 128 Loss: 0.10800215601921082
# Train Epoch: 45 Batch: 4 Total samples processed: 160 Loss: 0.1063825786113739
# Train Epoch: 45 Batch: 5 Total samples processed: 192 Loss: 0.11560800671577454
# Train Epoch: 45 Batch: 6 Total samples processed: 224 Loss: 0.1142132580280304
# Train Epoch: 45 Batch: 7 Total samples processed: 256 Loss: 0.10998775064945221
# Train Epoch: 45 Batch: 8 Total samples processed: 288 Loss: 0.11155898869037628
# Train Epoch: 45 Batch: 9 Total samples processed: 320 Loss: 0.11989619582891464
# Train Epoch: 46 Batch: 0 Total samples processed: 32 Loss: 0.10500714182853699
# Train Epoch: 46 Batch: 1 Total samples processed: 64 Loss: 0.11089397966861725
# Train Epoch: 46 Batch: 2 Total samples processed: 96 Loss: 0.11020497232675552
# Train Epoch: 46 Batch: 3 Total samples processed: 128 Loss: 0.1353990137577057
# Train Epoch: 46 Batch: 4 Total samples processed: 160 Loss: 0.13725072145462036
# Train Epoch: 46 Batch: 5 Total samples processed: 192 Loss: 0.1491740494966507
# Train Epoch: 46 Batch: 6 Total samples processed: 224 Loss: 0.1319173276424408
# Train Epoch: 46 Batch: 7 Total samples processed: 256 Loss: 0.13394813239574432
# Train Epoch: 46 Batch: 8 Total samples processed: 288 Loss: 0.1553640365600586
# Train Epoch: 46 Batch: 9 Total samples processed: 320 Loss: 0.14827537536621094
# Train Epoch: 47 Batch: 0 Total samples processed: 32 Loss: 0.13999328017234802
# Train Epoch: 47 Batch: 1 Total samples processed: 64 Loss: 0.12583474814891815
# Train Epoch: 47 Batch: 2 Total samples processed: 96 Loss: 0.14411409199237823
# Train Epoch: 47 Batch: 3 Total samples processed: 128 Loss: 0.15177826583385468
# Train Epoch: 47 Batch: 4 Total samples processed: 160 Loss: 0.13470667600631714
# Train Epoch: 47 Batch: 5 Total samples processed: 192 Loss: 0.1385950744152069
# Train Epoch: 47 Batch: 6 Total samples processed: 224 Loss: 0.12997210025787354
# Train Epoch: 47 Batch: 7 Total samples processed: 256 Loss: 0.14157931506633759
# Train Epoch: 47 Batch: 8 Total samples processed: 288 Loss: 0.13257727026939392
# Train Epoch: 47 Batch: 9 Total samples processed: 320 Loss: 0.1372130662202835
# Train Epoch: 48 Batch: 0 Total samples processed: 32 Loss: 0.12220107018947601
# Train Epoch: 48 Batch: 1 Total samples processed: 64 Loss: 0.11962317675352097
# Train Epoch: 48 Batch: 2 Total samples processed: 96 Loss: 0.1265104115009308
# Train Epoch: 48 Batch: 3 Total samples processed: 128 Loss: 0.12123608589172363
# Train Epoch: 48 Batch: 4 Total samples processed: 160 Loss: 0.11592793464660645
# Train Epoch: 48 Batch: 5 Total samples processed: 192 Loss: 0.1358850747346878
# Train Epoch: 48 Batch: 6 Total samples processed: 224 Loss: 0.1187501773238182
# Train Epoch: 48 Batch: 7 Total samples processed: 256 Loss: 0.1262459009885788
# Train Epoch: 48 Batch: 8 Total samples processed: 288 Loss: 0.12003570795059204
# Train Epoch: 48 Batch: 9 Total samples processed: 320 Loss: 0.11137327551841736
# Train Epoch: 49 Batch: 0 Total samples processed: 32 Loss: 0.11148874461650848
# Train Epoch: 49 Batch: 1 Total samples processed: 64 Loss: 0.1241380050778389
# Train Epoch: 49 Batch: 2 Total samples processed: 96 Loss: 0.11853715777397156
# Train Epoch: 49 Batch: 3 Total samples processed: 128 Loss: 0.11242903023958206
# Train Epoch: 49 Batch: 4 Total samples processed: 160 Loss: 0.11213500052690506
# Train Epoch: 49 Batch: 5 Total samples processed: 192 Loss: 0.11832798272371292
# Train Epoch: 49 Batch: 6 Total samples processed: 224 Loss: 0.11002124845981598
# Train Epoch: 49 Batch: 7 Total samples processed: 256 Loss: 0.11011806130409241
# Train Epoch: 49 Batch: 8 Total samples processed: 288 Loss: 0.11831442266702652
# Train Epoch: 49 Batch: 9 Total samples processed: 320 Loss: 0.11281438171863556
# Train Epoch: 50 Batch: 0 Total samples processed: 32 Loss: 0.10821688920259476
# Train Epoch: 50 Batch: 1 Total samples processed: 64 Loss: 0.11480578035116196
# Train Epoch: 50 Batch: 2 Total samples processed: 96 Loss: 0.10574125498533249
# Train Epoch: 50 Batch: 3 Total samples processed: 128 Loss: 0.1102028489112854
# Train Epoch: 50 Batch: 4 Total samples processed: 160 Loss: 0.11645430326461792
# Train Epoch: 50 Batch: 5 Total samples processed: 192 Loss: 0.10862429440021515
# Train Epoch: 50 Batch: 6 Total samples processed: 224 Loss: 0.10995262861251831
# Train Epoch: 50 Batch: 7 Total samples processed: 256 Loss: 0.10614215582609177
# Train Epoch: 50 Batch: 8 Total samples processed: 288 Loss: 0.10433776676654816
# Train Epoch: 50 Batch: 9 Total samples processed: 320 Loss: 0.12214868515729904
# Train Epoch: 51 Batch: 0 Total samples processed: 32 Loss: 0.11037273705005646
# Train Epoch: 51 Batch: 1 Total samples processed: 64 Loss: 0.10738764703273773
# Train Epoch: 51 Batch: 2 Total samples processed: 96 Loss: 0.10569016635417938
# Train Epoch: 51 Batch: 3 Total samples processed: 128 Loss: 0.1124204695224762
# Train Epoch: 51 Batch: 4 Total samples processed: 160 Loss: 0.1040312647819519
# Train Epoch: 51 Batch: 5 Total samples processed: 192 Loss: 0.11152344197034836
# Train Epoch: 51 Batch: 6 Total samples processed: 224 Loss: 0.1123899295926094
# Train Epoch: 51 Batch: 7 Total samples processed: 256 Loss: 0.10602529346942902
# Train Epoch: 51 Batch: 8 Total samples processed: 288 Loss: 0.10700982809066772
# Train Epoch: 51 Batch: 9 Total samples processed: 320 Loss: 0.10152138769626617
# Train Epoch: 52 Batch: 0 Total samples processed: 32 Loss: 0.10205763578414917
# Train Epoch: 52 Batch: 1 Total samples processed: 64 Loss: 0.10763533413410187
# Train Epoch: 52 Batch: 2 Total samples processed: 96 Loss: 0.11195119470357895
# Train Epoch: 52 Batch: 3 Total samples processed: 128 Loss: 0.10725109279155731
# Train Epoch: 52 Batch: 4 Total samples processed: 160 Loss: 0.11106576025485992
# Train Epoch: 52 Batch: 5 Total samples processed: 192 Loss: 0.1116030290722847
# Train Epoch: 52 Batch: 6 Total samples processed: 224 Loss: 0.10285235941410065
# Train Epoch: 52 Batch: 7 Total samples processed: 256 Loss: 0.1034708321094513
# Train Epoch: 52 Batch: 8 Total samples processed: 288 Loss: 0.1041451171040535
# Train Epoch: 52 Batch: 9 Total samples processed: 320 Loss: 0.10972187668085098
# Train Epoch: 53 Batch: 0 Total samples processed: 32 Loss: 0.10472606867551804
# Train Epoch: 53 Batch: 1 Total samples processed: 64 Loss: 0.10307734459638596
# Train Epoch: 53 Batch: 2 Total samples processed: 96 Loss: 0.10360726714134216
# Train Epoch: 53 Batch: 3 Total samples processed: 128 Loss: 0.09976759552955627
# Train Epoch: 53 Batch: 4 Total samples processed: 160 Loss: 0.10395996272563934
# Train Epoch: 53 Batch: 5 Total samples processed: 192 Loss: 0.10824647545814514
# Train Epoch: 53 Batch: 6 Total samples processed: 224 Loss: 0.10511370748281479
# Train Epoch: 53 Batch: 7 Total samples processed: 256 Loss: 0.10840100795030594
# Train Epoch: 53 Batch: 8 Total samples processed: 288 Loss: 0.10405860841274261
# Train Epoch: 53 Batch: 9 Total samples processed: 320 Loss: 0.10939908772706985
# Train Epoch: 54 Batch: 0 Total samples processed: 32 Loss: 0.10507741570472717
# Train Epoch: 54 Batch: 1 Total samples processed: 64 Loss: 0.10417266190052032
# Train Epoch: 54 Batch: 2 Total samples processed: 96 Loss: 0.10563294589519501
# Train Epoch: 54 Batch: 3 Total samples processed: 128 Loss: 0.10708893835544586
# Train Epoch: 54 Batch: 4 Total samples processed: 160 Loss: 0.09931765496730804
# Train Epoch: 54 Batch: 5 Total samples processed: 192 Loss: 0.10598921775817871
# Train Epoch: 54 Batch: 6 Total samples processed: 224 Loss: 0.10248582065105438
# Train Epoch: 54 Batch: 7 Total samples processed: 256 Loss: 0.10518211871385574
# Train Epoch: 54 Batch: 8 Total samples processed: 288 Loss: 0.10070144385099411
# Train Epoch: 54 Batch: 9 Total samples processed: 320 Loss: 0.10533677786588669
# Train Epoch: 55 Batch: 0 Total samples processed: 32 Loss: 0.10507354885339737
# Train Epoch: 55 Batch: 1 Total samples processed: 64 Loss: 0.10171784460544586
# Train Epoch: 55 Batch: 2 Total samples processed: 96 Loss: 0.10310868173837662
# Train Epoch: 55 Batch: 3 Total samples processed: 128 Loss: 0.10471481829881668
# Train Epoch: 55 Batch: 4 Total samples processed: 160 Loss: 0.10226486623287201
# Train Epoch: 55 Batch: 5 Total samples processed: 192 Loss: 0.10575124621391296
# Train Epoch: 55 Batch: 6 Total samples processed: 224 Loss: 0.10233157873153687
# Train Epoch: 55 Batch: 7 Total samples processed: 256 Loss: 0.0945129245519638
# Train Epoch: 55 Batch: 8 Total samples processed: 288 Loss: 0.10484737157821655
# Train Epoch: 55 Batch: 9 Total samples processed: 320 Loss: 0.10121230036020279
# Train Epoch: 56 Batch: 0 Total samples processed: 32 Loss: 0.09741286933422089
# Train Epoch: 56 Batch: 1 Total samples processed: 64 Loss: 0.10246466100215912
# Train Epoch: 56 Batch: 2 Total samples processed: 96 Loss: 0.1005936861038208
# Train Epoch: 56 Batch: 3 Total samples processed: 128 Loss: 0.10336031019687653
# Train Epoch: 56 Batch: 4 Total samples processed: 160 Loss: 0.10469675809144974
# Train Epoch: 56 Batch: 5 Total samples processed: 192 Loss: 0.10148516297340393
# Train Epoch: 56 Batch: 6 Total samples processed: 224 Loss: 0.10558708012104034
# Train Epoch: 56 Batch: 7 Total samples processed: 256 Loss: 0.10479295998811722
# Train Epoch: 56 Batch: 8 Total samples processed: 288 Loss: 0.10063013434410095
# Train Epoch: 56 Batch: 9 Total samples processed: 320 Loss: 0.09763814508914948
# Train Epoch: 57 Batch: 0 Total samples processed: 32 Loss: 0.10716401040554047
# Train Epoch: 57 Batch: 1 Total samples processed: 64 Loss: 0.09677673876285553
# Train Epoch: 57 Batch: 2 Total samples processed: 96 Loss: 0.09934813529253006
# Train Epoch: 57 Batch: 3 Total samples processed: 128 Loss: 0.10473474860191345
# Train Epoch: 57 Batch: 4 Total samples processed: 160 Loss: 0.10110177099704742
# Train Epoch: 57 Batch: 5 Total samples processed: 192 Loss: 0.09892598539590836
# Train Epoch: 57 Batch: 6 Total samples processed: 224 Loss: 0.10177121311426163
# Train Epoch: 57 Batch: 7 Total samples processed: 256 Loss: 0.10625811666250229
# Train Epoch: 57 Batch: 8 Total samples processed: 288 Loss: 0.09743659198284149
# Train Epoch: 57 Batch: 9 Total samples processed: 320 Loss: 0.0947345718741417
# Train Epoch: 58 Batch: 0 Total samples processed: 32 Loss: 0.10882191359996796
# Train Epoch: 58 Batch: 1 Total samples processed: 64 Loss: 0.1054101437330246
# Train Epoch: 58 Batch: 2 Total samples processed: 96 Loss: 0.09259361028671265
# Train Epoch: 58 Batch: 3 Total samples processed: 128 Loss: 0.10080230236053467
# Train Epoch: 58 Batch: 4 Total samples processed: 160 Loss: 0.10037784278392792
# Train Epoch: 58 Batch: 5 Total samples processed: 192 Loss: 0.09686946868896484
# Train Epoch: 58 Batch: 6 Total samples processed: 224 Loss: 0.101796954870224
# Train Epoch: 58 Batch: 7 Total samples processed: 256 Loss: 0.09818507730960846
# Train Epoch: 58 Batch: 8 Total samples processed: 288 Loss: 0.09679609537124634
# Train Epoch: 58 Batch: 9 Total samples processed: 320 Loss: 0.0949411615729332
# Train Epoch: 59 Batch: 0 Total samples processed: 32 Loss: 0.09920582175254822
# Train Epoch: 59 Batch: 1 Total samples processed: 64 Loss: 0.10015551745891571
# Train Epoch: 59 Batch: 2 Total samples processed: 96 Loss: 0.10179948806762695
# Train Epoch: 59 Batch: 3 Total samples processed: 128 Loss: 0.09324480593204498
# Train Epoch: 59 Batch: 4 Total samples processed: 160 Loss: 0.09976169466972351
# Train Epoch: 59 Batch: 5 Total samples processed: 192 Loss: 0.10113152861595154
# Train Epoch: 59 Batch: 6 Total samples processed: 224 Loss: 0.09848660230636597
# Train Epoch: 59 Batch: 7 Total samples processed: 256 Loss: 0.10470223426818848
# Train Epoch: 59 Batch: 8 Total samples processed: 288 Loss: 0.09453124552965164
# Train Epoch: 59 Batch: 9 Total samples processed: 320 Loss: 0.09711212664842606
# Train Epoch: 60 Batch: 0 Total samples processed: 32 Loss: 0.1023823618888855
# Train Epoch: 60 Batch: 1 Total samples processed: 64 Loss: 0.09745891392230988
# Train Epoch: 60 Batch: 2 Total samples processed: 96 Loss: 0.09695608168840408
# Train Epoch: 60 Batch: 3 Total samples processed: 128 Loss: 0.10081563889980316
# Train Epoch: 60 Batch: 4 Total samples processed: 160 Loss: 0.10108622163534164
# Train Epoch: 60 Batch: 5 Total samples processed: 192 Loss: 0.10331371426582336
# Train Epoch: 60 Batch: 6 Total samples processed: 224 Loss: 0.10117675364017487
# Train Epoch: 60 Batch: 7 Total samples processed: 256 Loss: 0.09552201628684998
# Train Epoch: 60 Batch: 8 Total samples processed: 288 Loss: 0.09930106997489929
# Train Epoch: 60 Batch: 9 Total samples processed: 320 Loss: 0.09937070310115814
# Train Epoch: 61 Batch: 0 Total samples processed: 32 Loss: 0.09444060921669006
# Train Epoch: 61 Batch: 1 Total samples processed: 64 Loss: 0.10360303521156311
# Train Epoch: 61 Batch: 2 Total samples processed: 96 Loss: 0.09873618185520172
# Train Epoch: 61 Batch: 3 Total samples processed: 128 Loss: 0.09489145129919052
# Train Epoch: 61 Batch: 4 Total samples processed: 160 Loss: 0.0974762961268425
# ...
# Train Epoch: 181 Batch: 2 Total samples processed: 96 Loss: 0.07027946412563324
# Train Epoch: 181 Batch: 3 Total samples processed: 128 Loss: 0.06704120337963104
# Train Epoch: 181 Batch: 4 Total samples processed: 160 Loss: 0.06699930876493454
# Train Epoch: 181 Batch: 5 Total samples processed: 192 Loss: 0.06903478503227234
# Train Epoch: 181 Batch: 6 Total samples processed: 224 Loss: 0.07097561657428741
# Train Epoch: 181 Batch: 7 Total samples processed: 256 Loss: 0.06498343497514725
# Train Epoch: 181 Batch: 8 Total samples processed: 288 Loss: 0.06693124771118164
# Train Epoch: 181 Batch: 9 Total samples processed: 320 Loss: 0.0677979364991188
# Train Epoch: 182 Batch: 0 Total samples processed: 32 Loss: 0.06802518665790558
# Train Epoch: 182 Batch: 1 Total samples processed: 64 Loss: 0.0712246224284172
# Train Epoch: 182 Batch: 2 Total samples processed: 96 Loss: 0.06782974302768707
# Train Epoch: 182 Batch: 3 Total samples processed: 128 Loss: 0.06469270586967468
# Train Epoch: 182 Batch: 4 Total samples processed: 160 Loss: 0.06778016686439514
# Train Epoch: 182 Batch: 5 Total samples processed: 192 Loss: 0.06978750228881836
# Train Epoch: 182 Batch: 6 Total samples processed: 224 Loss: 0.06754308193922043
# Train Epoch: 182 Batch: 7 Total samples processed: 256 Loss: 0.06745868176221848
# Train Epoch: 182 Batch: 8 Total samples processed: 288 Loss: 0.07353062927722931
# Train Epoch: 182 Batch: 9 Total samples processed: 320 Loss: 0.07115519046783447
# Train Epoch: 183 Batch: 0 Total samples processed: 32 Loss: 0.06869299709796906
# Train Epoch: 183 Batch: 1 Total samples processed: 64 Loss: 0.07020454108715057
# Train Epoch: 183 Batch: 2 Total samples processed: 96 Loss: 0.06654991209506989
# Train Epoch: 183 Batch: 3 Total samples processed: 128 Loss: 0.06853213906288147
# Train Epoch: 183 Batch: 4 Total samples processed: 160 Loss: 0.06808006763458252
# Train Epoch: 183 Batch: 5 Total samples processed: 192 Loss: 0.06912872195243835
# Train Epoch: 183 Batch: 6 Total samples processed: 224 Loss: 0.06592392921447754
# Train Epoch: 183 Batch: 7 Total samples processed: 256 Loss: 0.06876744329929352
# Train Epoch: 183 Batch: 8 Total samples processed: 288 Loss: 0.07106993347406387
# Train Epoch: 183 Batch: 9 Total samples processed: 320 Loss: 0.0745416060090065
# Train Epoch: 184 Batch: 0 Total samples processed: 32 Loss: 0.0675334483385086
# Train Epoch: 184 Batch: 1 Total samples processed: 64 Loss: 0.07060961425304413
# Train Epoch: 184 Batch: 2 Total samples processed: 96 Loss: 0.07030348479747772
# Train Epoch: 184 Batch: 3 Total samples processed: 128 Loss: 0.06899215281009674
# Train Epoch: 184 Batch: 4 Total samples processed: 160 Loss: 0.06752991676330566
# Train Epoch: 184 Batch: 5 Total samples processed: 192 Loss: 0.06677307188510895
# Train Epoch: 184 Batch: 6 Total samples processed: 224 Loss: 0.06904946267604828
# Train Epoch: 184 Batch: 7 Total samples processed: 256 Loss: 0.06701670587062836
# Train Epoch: 184 Batch: 8 Total samples processed: 288 Loss: 0.0672207772731781
# Train Epoch: 184 Batch: 9 Total samples processed: 320 Loss: 0.0645737498998642
# Train Epoch: 185 Batch: 0 Total samples processed: 32 Loss: 0.07289420068264008
# Train Epoch: 185 Batch: 1 Total samples processed: 64 Loss: 0.06729663908481598
# Train Epoch: 185 Batch: 2 Total samples processed: 96 Loss: 0.070706307888031
# Train Epoch: 185 Batch: 3 Total samples processed: 128 Loss: 0.06739015132188797
# Train Epoch: 185 Batch: 4 Total samples processed: 160 Loss: 0.06444992125034332
# Train Epoch: 185 Batch: 5 Total samples processed: 192 Loss: 0.07059264183044434
# Train Epoch: 185 Batch: 6 Total samples processed: 224 Loss: 0.06347966194152832
# Train Epoch: 185 Batch: 7 Total samples processed: 256 Loss: 0.0647616982460022
# Train Epoch: 185 Batch: 8 Total samples processed: 288 Loss: 0.07382090389728546
# Train Epoch: 185 Batch: 9 Total samples processed: 320 Loss: 0.06463828682899475
# Train Epoch: 186 Batch: 0 Total samples processed: 32 Loss: 0.07099708914756775
# Train Epoch: 186 Batch: 1 Total samples processed: 64 Loss: 0.06692647188901901
# Train Epoch: 186 Batch: 2 Total samples processed: 96 Loss: 0.06948122382164001
# Train Epoch: 186 Batch: 3 Total samples processed: 128 Loss: 0.06901870667934418
# Train Epoch: 186 Batch: 4 Total samples processed: 160 Loss: 0.07177971303462982
# Train Epoch: 186 Batch: 5 Total samples processed: 192 Loss: 0.06503206491470337
# Train Epoch: 186 Batch: 6 Total samples processed: 224 Loss: 0.06838075071573257
# Train Epoch: 186 Batch: 7 Total samples processed: 256 Loss: 0.06807172298431396
# Train Epoch: 186 Batch: 8 Total samples processed: 288 Loss: 0.0659426897764206
# Train Epoch: 186 Batch: 9 Total samples processed: 320 Loss: 0.06685911864042282
# Train Epoch: 187 Batch: 0 Total samples processed: 32 Loss: 0.07058419287204742
# Train Epoch: 187 Batch: 1 Total samples processed: 64 Loss: 0.06732958555221558
# Train Epoch: 187 Batch: 2 Total samples processed: 96 Loss: 0.06804364919662476
# Train Epoch: 187 Batch: 3 Total samples processed: 128 Loss: 0.06652089953422546
# Train Epoch: 187 Batch: 4 Total samples processed: 160 Loss: 0.070638507604599
# Train Epoch: 187 Batch: 5 Total samples processed: 192 Loss: 0.06955386698246002
# Train Epoch: 187 Batch: 6 Total samples processed: 224 Loss: 0.06871481239795685
# Train Epoch: 187 Batch: 7 Total samples processed: 256 Loss: 0.0669187605381012
# Train Epoch: 187 Batch: 8 Total samples processed: 288 Loss: 0.06726111471652985
# Train Epoch: 187 Batch: 9 Total samples processed: 320 Loss: 0.06203151121735573
# Train Epoch: 188 Batch: 0 Total samples processed: 32 Loss: 0.06593727320432663
# Train Epoch: 188 Batch: 1 Total samples processed: 64 Loss: 0.07196766138076782
# Train Epoch: 188 Batch: 2 Total samples processed: 96 Loss: 0.06723851710557938
# Train Epoch: 188 Batch: 3 Total samples processed: 128 Loss: 0.06229899078607559
# Train Epoch: 188 Batch: 4 Total samples processed: 160 Loss: 0.07233252376317978
# Train Epoch: 188 Batch: 5 Total samples processed: 192 Loss: 0.06863090395927429
# Train Epoch: 188 Batch: 6 Total samples processed: 224 Loss: 0.07075440138578415
# Train Epoch: 188 Batch: 7 Total samples processed: 256 Loss: 0.0675160363316536
# Train Epoch: 188 Batch: 8 Total samples processed: 288 Loss: 0.06647352874279022
# Train Epoch: 188 Batch: 9 Total samples processed: 320 Loss: 0.05966493859887123
# Train Epoch: 189 Batch: 0 Total samples processed: 32 Loss: 0.0699993148446083
# Train Epoch: 189 Batch: 1 Total samples processed: 64 Loss: 0.06799021363258362
# Train Epoch: 189 Batch: 2 Total samples processed: 96 Loss: 0.06819359213113785
# Train Epoch: 189 Batch: 3 Total samples processed: 128 Loss: 0.0676194429397583
# Train Epoch: 189 Batch: 4 Total samples processed: 160 Loss: 0.06250862777233124
# Train Epoch: 189 Batch: 5 Total samples processed: 192 Loss: 0.0677686333656311
# Train Epoch: 189 Batch: 6 Total samples processed: 224 Loss: 0.06895514577627182
# Train Epoch: 189 Batch: 7 Total samples processed: 256 Loss: 0.06755760312080383
# Train Epoch: 189 Batch: 8 Total samples processed: 288 Loss: 0.07083742320537567
# Train Epoch: 189 Batch: 9 Total samples processed: 320 Loss: 0.07110613584518433
# Train Epoch: 190 Batch: 0 Total samples processed: 32 Loss: 0.0674331858754158
# Train Epoch: 190 Batch: 1 Total samples processed: 64 Loss: 0.06463459879159927
# Train Epoch: 190 Batch: 2 Total samples processed: 96 Loss: 0.07141190767288208
# Train Epoch: 190 Batch: 3 Total samples processed: 128 Loss: 0.06768079102039337
# Train Epoch: 190 Batch: 4 Total samples processed: 160 Loss: 0.06893036514520645
# Train Epoch: 190 Batch: 5 Total samples processed: 192 Loss: 0.06553611159324646
# Train Epoch: 190 Batch: 6 Total samples processed: 224 Loss: 0.06923235207796097
# Train Epoch: 190 Batch: 7 Total samples processed: 256 Loss: 0.067204549908638
# Train Epoch: 190 Batch: 8 Total samples processed: 288 Loss: 0.066263347864151
# Train Epoch: 190 Batch: 9 Total samples processed: 320 Loss: 0.06812582165002823
# Train Epoch: 191 Batch: 0 Total samples processed: 32 Loss: 0.06694292277097702
# Train Epoch: 191 Batch: 1 Total samples processed: 64 Loss: 0.0645017921924591
# Train Epoch: 191 Batch: 2 Total samples processed: 96 Loss: 0.06823399662971497
# Train Epoch: 191 Batch: 3 Total samples processed: 128 Loss: 0.06835789233446121
# Train Epoch: 191 Batch: 4 Total samples processed: 160 Loss: 0.06678535044193268
# Train Epoch: 191 Batch: 5 Total samples processed: 192 Loss: 0.0677509680390358
# Train Epoch: 191 Batch: 6 Total samples processed: 224 Loss: 0.0682598352432251
# Train Epoch: 191 Batch: 7 Total samples processed: 256 Loss: 0.06613881886005402
# Train Epoch: 191 Batch: 8 Total samples processed: 288 Loss: 0.06284505128860474
# Train Epoch: 191 Batch: 9 Total samples processed: 320 Loss: 0.06677477806806564
# Train Epoch: 192 Batch: 0 Total samples processed: 32 Loss: 0.0686538890004158
# Train Epoch: 192 Batch: 1 Total samples processed: 64 Loss: 0.0688113197684288
# Train Epoch: 192 Batch: 2 Total samples processed: 96 Loss: 0.065270334482193
# Train Epoch: 192 Batch: 3 Total samples processed: 128 Loss: 0.06606078147888184
# Train Epoch: 192 Batch: 4 Total samples processed: 160 Loss: 0.06376634538173676
# Train Epoch: 192 Batch: 5 Total samples processed: 192 Loss: 0.06960995495319366
# Train Epoch: 192 Batch: 6 Total samples processed: 224 Loss: 0.06702348589897156
# Train Epoch: 192 Batch: 7 Total samples processed: 256 Loss: 0.06904319673776627
# Train Epoch: 192 Batch: 8 Total samples processed: 288 Loss: 0.0640677809715271
# Train Epoch: 192 Batch: 9 Total samples processed: 320 Loss: 0.07003559172153473
# Train Epoch: 193 Batch: 0 Total samples processed: 32 Loss: 0.06595948338508606
# Train Epoch: 193 Batch: 1 Total samples processed: 64 Loss: 0.06625762581825256
# Train Epoch: 193 Batch: 2 Total samples processed: 96 Loss: 0.07179923355579376
# Train Epoch: 193 Batch: 3 Total samples processed: 128 Loss: 0.06841446459293365
# Train Epoch: 193 Batch: 4 Total samples processed: 160 Loss: 0.06792206317186356
# Train Epoch: 193 Batch: 5 Total samples processed: 192 Loss: 0.06810735166072845
# Train Epoch: 193 Batch: 6 Total samples processed: 224 Loss: 0.06559839844703674
# Train Epoch: 193 Batch: 7 Total samples processed: 256 Loss: 0.0651412382721901
# Train Epoch: 193 Batch: 8 Total samples processed: 288 Loss: 0.06700266897678375
# Train Epoch: 193 Batch: 9 Total samples processed: 320 Loss: 0.0632731169462204
# Train Epoch: 194 Batch: 0 Total samples processed: 32 Loss: 0.06937050819396973
# Train Epoch: 194 Batch: 1 Total samples processed: 64 Loss: 0.06546156108379364
# Train Epoch: 194 Batch: 2 Total samples processed: 96 Loss: 0.06304965913295746
# Train Epoch: 194 Batch: 3 Total samples processed: 128 Loss: 0.06414446979761124
# Train Epoch: 194 Batch: 4 Total samples processed: 160 Loss: 0.06815609335899353
# Train Epoch: 194 Batch: 5 Total samples processed: 192 Loss: 0.06775055080652237
# Train Epoch: 194 Batch: 6 Total samples processed: 224 Loss: 0.06775745749473572
# Train Epoch: 194 Batch: 7 Total samples processed: 256 Loss: 0.06720364093780518
# Train Epoch: 194 Batch: 8 Total samples processed: 288 Loss: 0.06585462391376495
# Train Epoch: 194 Batch: 9 Total samples processed: 320 Loss: 0.07172118127346039
# Train Epoch: 195 Batch: 0 Total samples processed: 32 Loss: 0.06597878038883209
# Train Epoch: 195 Batch: 1 Total samples processed: 64 Loss: 0.07018386572599411
# Train Epoch: 195 Batch: 2 Total samples processed: 96 Loss: 0.06693050265312195
# Train Epoch: 195 Batch: 3 Total samples processed: 128 Loss: 0.07062359899282455
# Train Epoch: 195 Batch: 4 Total samples processed: 160 Loss: 0.06630904227495193
# Train Epoch: 195 Batch: 5 Total samples processed: 192 Loss: 0.07018551230430603
# Train Epoch: 195 Batch: 6 Total samples processed: 224 Loss: 0.06402243673801422
# Train Epoch: 195 Batch: 7 Total samples processed: 256 Loss: 0.06648187339305878
# Train Epoch: 195 Batch: 8 Total samples processed: 288 Loss: 0.061965811997652054
# Train Epoch: 195 Batch: 9 Total samples processed: 320 Loss: 0.06462136656045914
# Train Epoch: 196 Batch: 0 Total samples processed: 32 Loss: 0.06887510418891907
# Train Epoch: 196 Batch: 1 Total samples processed: 64 Loss: 0.06308764219284058
# Train Epoch: 196 Batch: 2 Total samples processed: 96 Loss: 0.07153131067752838
# Train Epoch: 196 Batch: 3 Total samples processed: 128 Loss: 0.06393299996852875
# Train Epoch: 196 Batch: 4 Total samples processed: 160 Loss: 0.07562317699193954
# Train Epoch: 196 Batch: 5 Total samples processed: 192 Loss: 0.06734513491392136
# Train Epoch: 196 Batch: 6 Total samples processed: 224 Loss: 0.06664949655532837
# Train Epoch: 196 Batch: 7 Total samples processed: 256 Loss: 0.06533442437648773
# Train Epoch: 196 Batch: 8 Total samples processed: 288 Loss: 0.06598853319883347
# Train Epoch: 196 Batch: 9 Total samples processed: 320 Loss: 0.06411318480968475
# Train Epoch: 197 Batch: 0 Total samples processed: 32 Loss: 0.06868326663970947
# Train Epoch: 197 Batch: 1 Total samples processed: 64 Loss: 0.06784325838088989
# Train Epoch: 197 Batch: 2 Total samples processed: 96 Loss: 0.06277893483638763
# Train Epoch: 197 Batch: 3 Total samples processed: 128 Loss: 0.06678267568349838
# Train Epoch: 197 Batch: 4 Total samples processed: 160 Loss: 0.0676635205745697
# Train Epoch: 197 Batch: 5 Total samples processed: 192 Loss: 0.0651034414768219
# Train Epoch: 197 Batch: 6 Total samples processed: 224 Loss: 0.06520357728004456
# Train Epoch: 197 Batch: 7 Total samples processed: 256 Loss: 0.06629350036382675
# Train Epoch: 197 Batch: 8 Total samples processed: 288 Loss: 0.06461741030216217
# Train Epoch: 197 Batch: 9 Total samples processed: 320 Loss: 0.0645739883184433
# Train Epoch: 198 Batch: 0 Total samples processed: 32 Loss: 0.06269548833370209
# Train Epoch: 198 Batch: 1 Total samples processed: 64 Loss: 0.06413046270608902
# Train Epoch: 198 Batch: 2 Total samples processed: 96 Loss: 0.07026713341474533
# Train Epoch: 198 Batch: 3 Total samples processed: 128 Loss: 0.07008956372737885
# Train Epoch: 198 Batch: 4 Total samples processed: 160 Loss: 0.06554190069437027
# Train Epoch: 198 Batch: 5 Total samples processed: 192 Loss: 0.0678802877664566
# Train Epoch: 198 Batch: 6 Total samples processed: 224 Loss: 0.06741796433925629
# Train Epoch: 198 Batch: 7 Total samples processed: 256 Loss: 0.06539630889892578
# Train Epoch: 198 Batch: 8 Total samples processed: 288 Loss: 0.06483888626098633
# Train Epoch: 198 Batch: 9 Total samples processed: 320 Loss: 0.061351992189884186
# Train Epoch: 199 Batch: 0 Total samples processed: 32 Loss: 0.06314939260482788
# Train Epoch: 199 Batch: 1 Total samples processed: 64 Loss: 0.07056716829538345
# Train Epoch: 199 Batch: 2 Total samples processed: 96 Loss: 0.06304872035980225
# Train Epoch: 199 Batch: 3 Total samples processed: 128 Loss: 0.06175641715526581
# Train Epoch: 199 Batch: 4 Total samples processed: 160 Loss: 0.06653714179992676
# Train Epoch: 199 Batch: 5 Total samples processed: 192 Loss: 0.06514088809490204
# Train Epoch: 199 Batch: 6 Total samples processed: 224 Loss: 0.07025465369224548
# Train Epoch: 199 Batch: 7 Total samples processed: 256 Loss: 0.0662519633769989
# Train Epoch: 199 Batch: 8 Total samples processed: 288 Loss: 0.06780747324228287
# Train Epoch: 199 Batch: 9 Total samples processed: 320 Loss: 0.06841479241847992
# Train Epoch: 200 Batch: 0 Total samples processed: 32 Loss: 0.0686187595129013
# Train Epoch: 200 Batch: 1 Total samples processed: 64 Loss: 0.06735300272703171
# Train Epoch: 200 Batch: 2 Total samples processed: 96 Loss: 0.06404544413089752
# Train Epoch: 200 Batch: 3 Total samples processed: 128 Loss: 0.06692905724048615
# Train Epoch: 200 Batch: 4 Total samples processed: 160 Loss: 0.07071720063686371
# Train Epoch: 200 Batch: 5 Total samples processed: 192 Loss: 0.06372369825839996
# Train Epoch: 200 Batch: 6 Total samples processed: 224 Loss: 0.06287593394517899
# Train Epoch: 200 Batch: 7 Total samples processed: 256 Loss: 0.06676489859819412
# Train Epoch: 200 Batch: 8 Total samples processed: 288 Loss: 0.06889824569225311
# Train Epoch: 200 Batch: 9 Total samples processed: 320 Loss: 0.07471588253974915

# %% [markdown]
# ## Look at self-prediction
#
# Self-prediction does not tell us how the UNET will perform on new data, but it is a useful check to make sure the UNET is learning the training data.

# %%
len(X)
X.shape
# Out:
# torch.Size([13, 3, 256, 256])

# %%
import matplotlib.pyplot as plt

# convert to 0/1 range on each pixel
prediction = torch.nn.functional.sigmoid(prediction_logits)
prediction_binary = prediction #(prediction > 0.5).to(torch.uint8)

sidx = 1
plt.subplot(131)
plt.imshow(X[sidx, 0].cpu().numpy(), cmap="gray")
plt.title("Input")

plt.subplot(132)
plt.imshow(y[sidx, 0].cpu().numpy(), cmap="gray")
plt.title("Ground truth")

plt.subplot(133)
plt.imshow(prediction_binary.cpu().detach()[sidx, 0].numpy(), cmap="gray")
plt.title("Predictions")
# Out:
# Text(0.5, 1.0, 'Predictions')

# %% [markdown]
# ## Save the UNET

# %%
torch.save(model.state_dict(), train_path / 'model1')

# %% [markdown]
# ## Test on unseen data

# %%
test_name = 'g29635.tif'
testim = imread(parent_path  / test_name) 
testim.shape
plt.imshow(testim, cmap="gray")
print('original min max', testim.min(), testim.max())
# Out:
# original min max 17 243

# %%
testim_ = testim.copy().astype(np.float32)
for i in range(testim.shape[2]):
    testim_[:,:,i] = quantile_normalization(
        testim[:,:,i],
        quantile_low=0.01,
        quantile_high=0.998,
        clip=True).astype(np.float32)

tensor_transform = transforms.Compose([
    v2.ToTensor(),
])
x = tensor_transform(testim_)
x = x.unsqueeze(0).to(device)
#x = torch.from_numpy(testim_).to(device)

x.shape
y = model(x)
# Out:
# c:\Users\bnort\miniconda3\envs\pytorch_and_SAM\lib\site-packages\torchvision\transforms\v2\_deprecated.py:43: UserWarning: The transform `ToTensor()` is deprecated and will be removed in a future release. Instead, please use `v2.Compose([v2.ToImage(), v2.ToDtype(torch.float32, scale=True)])`.
#   warnings.warn(

# %% [markdown]
# ## Look at results in Napari

# %%
testim.min(), testim.max()
testim.shape
# Out:
# (521, 495, 3)

# %%
testim.dtype
# Out:
# dtype('float32')

# %%
import napari
viewer = napari.Viewer()
viewer.add_image(testim, name='testim')
viewer.add_image(y.cpu().detach()[0, 0].numpy(), name='prediction')
binary = y.cpu().detach()[0, 0].numpy() > 0.5
viewer.add_labels(binary, name='prediction binary')
# Out:
# <Labels layer 'prediction binary' at 0x2b7c5a56350>

# %%
from skimage.io import imsave
imsave(parent_path / 'CNN_segmentation.tif', y.cpu().detach()[0, 0].numpy())

# %%
from cProfile import label
from os import sep
from tnia.segmentation.separate import separate_touching

labels = y.cpu().detach()[0, 0].numpy() > 0.5
# invert labels
labels = 1 - labels

separated, label_separated, _ = separate_touching(labels, 15, 1)

from skimage.measure import label
label_separated = label(separated)

viewer = napari.Viewer()
viewer.add_image(testim, name='image')
viewer.add_labels(label_separated, name='separated')
# Out:
# <Labels layer 'separated' at 0x27faab17a30>

# %%
labels.shape
# Out:
# (1024, 1536)
