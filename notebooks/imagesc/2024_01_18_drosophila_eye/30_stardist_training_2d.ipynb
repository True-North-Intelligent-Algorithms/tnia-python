# %% [markdown]
# ## Stardist training
#
# The eye structure is very circular.  Good candidate for Stardist.

# %%
import os
from tnia.plotting.plt_helper import imshow_multi2d
import tensorflow as tf
from pathlib import Path
import json

# %% [markdown]
# ## Check what devices we have access to....
#
# Not as important to have a beefy GPU for 2D as it is for 3D, but let's check

# %%
visible_devices = tf.config.list_physical_devices()
print(visible_devices)
# Out:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'), PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# ## Load inputs and ground truth
#
# We load directories called 'input0' and 'ground truth0' which should exist under ```train_path```.  The reason we append '0' to the end of the name is simply because some of the code that generates image and label sets is meant to work on multiple channels (so the 0 is the channel number)

# %%
#tnia_images_path = Path(r'/home/bnorthan/images')
tnia_images_path = Path(r'D:/images')

parent_path=Path(tnia_images_path / r'tnia-python-images/imagesc/2024_01_18_drosophila_eye')

test_name='eyes3.jpg'
n_rays = 32

train_path = parent_path / 'patches'

with open(train_path / 'info.json', 'r') as json_file:
    data = json.load(json_file)
    # Access the sub_sample parameter
    sub_sample = data['sub_sample']
    print('sub_sample',sub_sample)
    axes = data['axes']
    print('axes',axes)

image_patch_path = train_path / 'ground truth0'
label_patch_path = train_path / 'input0'

model_path = parent_path / 'model'

if not os.path.exists(model_path):
    os.makedirs(model_path)

if not os.path.exists(image_patch_path):
    print('image_patch_path does not exist')

if not os.path.exists(label_patch_path):
    print('label_patch_path does not exist')
# Out:
# sub_sample 1
# axes YXC

# %% [markdown]
# ## Use a helper to collect the training data
#
# The helper will also normalize the inputs.

# %%
from tnia.deeplearning.dl_helper import collect_training_data
add_trivial_channel = False

X, Y = collect_training_data(train_path, sub_sample=1, downsample=False, normalize_input=False, add_trivial_channel = add_trivial_channel)

print('type X ', type(X))
print('type Y ', type(Y))
# Out:
# type X  <class 'list'>
# type Y  <class 'list'>

# %% [markdown]
# ## Inspect images
#
# Output training data shapes and plot images to make sure image and label set look OK

# %%
n=506
print(X[n].shape, Y[n].shape)
print(X[n].min(), X[n].max())
fig=imshow_multi2d([X[n], Y[n]], ['input', 'label'], 1,2)
# Out:
# (256, 256, 3) (256, 256)
# 0.0 0.8596985

# %% [markdown]
# ## Divide in to training and validation sets
#
# Use a helper to divide into training and validation.  Note the conversion to numpy arrays (needed for stardist training) is also baked into the divide_training_data function

# %%
from tnia.deeplearning.dl_helper import divide_training_data

X_train, Y_train, X_val, Y_val = divide_training_data(X, Y, val_size=2)

print('type X_train ', type(X_train))
# Out:
# type X_train  <class 'numpy.ndarray'>

# %% [markdown]
# ## Create stardist model

# %%
from stardist.models import StarDist2D, Config2D
from tnia.deeplearning.dl_helper import augmenter

if axes == 'YXC':
    n_channel_in =3
else:
    n_channel_in = 1

config = Config2D (n_rays=n_rays, axes=axes,n_channel_in=n_channel_in, train_patch_size = (256,256), unet_n_depth=4)

model = StarDist2D(config=config, name="model1", basedir=model_path)
# Out:
# Using default values: prob_thresh=0.5, nms_thresh=0.4.

# %% [markdown]
# ## Train the model

# %%
X_val.shape, Y_val.shape
# Out:
# ((2, 256, 256, 3), (2, 256, 256))

# %%
X_train.shape, Y_train.shape
# Out:
# ((880, 256, 256, 3), (880, 256, 256))

# %%
print(config)
# Out:
# Config2D(n_dim=2, axes='YXC', n_channel_in=3, n_channel_out=33, train_checkpoint='weights_best.h5', train_checkpoint_last='weights_last.h5', train_checkpoint_epoch='weights_now.h5', n_rays=32, grid=(1, 1), backbone='unet', n_classes=None, unet_n_depth=4, unet_kernel_size=(3, 3), unet_n_filter_base=32, unet_n_conv_per_depth=2, unet_pool=(2, 2), unet_activation='relu', unet_last_activation='relu', unet_batch_norm=False, unet_dropout=0.0, unet_prefix='', net_conv_after_unet=128, net_input_shape=(None, None, 3), net_mask_shape=(None, None, 1), train_shape_completion=False, train_completion_crop=32, train_patch_size=(256, 256), train_background_reg=0.0001, train_foreground_only=0.9, train_sample_cache=True, train_dist_loss='mae', train_loss_weights=(1, 0.2), train_class_weights=(1, 1), train_epochs=400, train_steps_per_epoch=100, train_learning_rate=0.0003, train_batch_size=4, train_n_val_patches=None, train_tensorboard=True, train_reduce_lr={'factor': 0.5, 'patience': 40, 'min_delta': 0}, use_gpu=False)

# %%
#model.train(X_train, Y_train, validation_data=(X_val,Y_val),epochs=100, steps_per_epoch=200, augmenter=augmenter) 
model.train(X_train, Y_train, validation_data=(X_val,Y_val),epochs=50, steps_per_epoch=311)
# Out:
# Epoch 1/50
# WARNING:tensorflow:AutoGraph could not transform <function _gcd_import at 0x00000247C7F813A0> and will run it as-is.
# Cause: Unable to locate the source code of <function _gcd_import at 0x00000247C7F813A0>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function _gcd_import at 0x00000247C7F813A0> and will run it as-is.
# Cause: Unable to locate the source code of <function _gcd_import at 0x00000247C7F813A0>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
#   6/311 [..............................] - ETA: 1:16 - loss: 3.4757 - prob_loss: 0.6613 - dist_loss: 14.0721 - prob_kld: 0.5097 - dist_relevant_mae: 14.0721 - dist_relevant_mse: 250.5156 - dist_dist_iou_metric: 2.0928e-06WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1113s vs `on_train_batch_end` time: 0.1154s). Check your callbacks.
# 2/2 [==============================] - 1s 8ms/step - loss: 1.8683 - prob_loss: 0.3940 - dist_loss: 7.3713 - prob_kld: 0.2221 - dist_relevant_mae: 7.3703 - dist_relevant_mse: 90.3789 - dist_dist_iou_metric: 0.36
# 311/311 [==============================] - 107s 320ms/step - loss: 1.8683 - prob_loss: 0.3940 - dist_loss: 7.3713 - prob_kld: 0.2221 - dist_relevant_mae: 7.3703 - dist_relevant_mse: 90.3789 - dist_dist_iou_metric: 0.3681 - val_loss: 1.4010 - val_prob_loss: 0.3441 - val_dist_loss: 5.2849 - val_prob_kld: 0.1889 - val_dist_relevant_mae: 5.2836 - val_dist_relevant_mse: 43.0736 - val_dist_dist_iou_metric: 0.5103 - lr: 3.0000e-04
# Epoch 2/50
# 2/2 [==============================] - 0s 7ms/step - loss: 1.4462 - prob_loss: 0.3672 - dist_loss: 5.3953 - prob_kld: 0.1932 - dist_relevant_mae: 5.3941 - dist_relevant_mse: 47.3563 - dist_dist_iou_metric: 0.49
# 311/311 [==============================] - 97s 312ms/step - loss: 1.4462 - prob_loss: 0.3672 - dist_loss: 5.3953 - prob_kld: 0.1932 - dist_relevant_mae: 5.3941 - dist_relevant_mse: 47.3563 - dist_dist_iou_metric: 0.4954 - val_loss: 1.2796 - val_prob_loss: 0.3940 - val_dist_loss: 4.4281 - val_prob_kld: 0.2388 - val_dist_relevant_mae: 4.4270 - val_dist_relevant_mse: 32.7578 - val_dist_dist_iou_metric: 0.5220 - lr: 3.0000e-04
# Epoch 3/50
# 2/2 [==============================] - 0s 10ms/step- loss: 1.1012 - prob_loss: 0.3009 - dist_loss: 4.0012 - prob_kld: 0.1275 - dist_relevant_mae: 4.0000 - dist_relevant_mse: 28.2998 - dist_dist_iou_metric: 0.60
# 311/311 [==============================] - 97s 311ms/step - loss: 1.1012 - prob_loss: 0.3009 - dist_loss: 4.0012 - prob_kld: 0.1275 - dist_relevant_mae: 4.0000 - dist_relevant_mse: 28.2998 - dist_dist_iou_metric: 0.6052 - val_loss: 0.8541 - val_prob_loss: 0.2523 - val_dist_loss: 3.0090 - val_prob_kld: 0.0971 - val_dist_relevant_mae: 3.0078 - val_dist_relevant_mse: 15.9739 - val_dist_dist_iou_metric: 0.6842 - lr: 3.0000e-04
# Epoch 4/50
# 2/2 [==============================] - 0s 11ms/step- loss: 0.9012 - prob_loss: 0.2615 - dist_loss: 3.1985 - prob_kld: 0.0874 - dist_relevant_mae: 3.1974 - dist_relevant_mse: 18.7031 - dist_dist_iou_metric: 0.67
# 311/311 [==============================] - 97s 313ms/step - loss: 0.9012 - prob_loss: 0.2615 - dist_loss: 3.1985 - prob_kld: 0.0874 - dist_relevant_mae: 3.1974 - dist_relevant_mse: 18.7031 - dist_dist_iou_metric: 0.6733 - val_loss: 0.7929 - val_prob_loss: 0.2548 - val_dist_loss: 2.6903 - val_prob_kld: 0.0996 - val_dist_relevant_mae: 2.6892 - val_dist_relevant_mse: 12.8219 - val_dist_dist_iou_metric: 0.6842 - lr: 3.0000e-04
# Epoch 5/50
# 2/2 [==============================] - 0s 11ms/step- loss: 0.8289 - prob_loss: 0.2466 - dist_loss: 2.9115 - prob_kld: 0.0743 - dist_relevant_mae: 2.9104 - dist_relevant_mse: 15.6851 - dist_dist_iou_metric: 0.69
# 311/311 [==============================] - 96s 309ms/step - loss: 0.8289 - prob_loss: 0.2466 - dist_loss: 2.9115 - prob_kld: 0.0743 - dist_relevant_mae: 2.9104 - dist_relevant_mse: 15.6851 - dist_dist_iou_metric: 0.6982 - val_loss: 0.7732 - val_prob_loss: 0.2382 - val_dist_loss: 2.6747 - val_prob_kld: 0.0830 - val_dist_relevant_mae: 2.6736 - val_dist_relevant_mse: 12.4476 - val_dist_dist_iou_metric: 0.6984 - lr: 3.0000e-04
# Epoch 6/50
# 2/2 [==============================] - 0s 9ms/step - loss: 0.7852 - prob_loss: 0.2402 - dist_loss: 2.7249 - prob_kld: 0.0667 - dist_relevant_mae: 2.7238 - dist_relevant_mse: 13.7711 - dist_dist_iou_metric: 0.71
# 311/311 [==============================] - 97s 312ms/step - loss: 0.7852 - prob_loss: 0.2402 - dist_loss: 2.7249 - prob_kld: 0.0667 - dist_relevant_mae: 2.7238 - dist_relevant_mse: 13.7711 - dist_dist_iou_metric: 0.7146 - val_loss: 0.7314 - val_prob_loss: 0.2466 - val_dist_loss: 2.4241 - val_prob_kld: 0.0914 - val_dist_relevant_mae: 2.4231 - val_dist_relevant_mse: 10.7533 - val_dist_dist_iou_metric: 0.7181 - lr: 3.0000e-04
# Epoch 7/50
# 2/2 [==============================] - 0s 7ms/step - loss: 0.7477 - prob_loss: 0.2329 - dist_loss: 2.5735 - prob_kld: 0.0613 - dist_relevant_mae: 2.5724 - dist_relevant_mse: 12.2991 - dist_dist_iou_metric: 0.72
# 311/311 [==============================] - 96s 309ms/step - loss: 0.7477 - prob_loss: 0.2329 - dist_loss: 2.5735 - prob_kld: 0.0613 - dist_relevant_mae: 2.5724 - dist_relevant_mse: 12.2991 - dist_dist_iou_metric: 0.7296 - val_loss: 0.7429 - val_prob_loss: 0.2241 - val_dist_loss: 2.5939 - val_prob_kld: 0.0689 - val_dist_relevant_mae: 2.5929 - val_dist_relevant_mse: 11.4655 - val_dist_dist_iou_metric: 0.6839 - lr: 3.0000e-04
# Epoch 8/50
# 2/2 [==============================] - 0s 10ms/step- loss: 0.6980 - prob_loss: 0.2266 - dist_loss: 2.3570 - prob_kld: 0.0526 - dist_relevant_mae: 2.3559 - dist_relevant_mse: 10.2884 - dist_dist_iou_metric: 0.75
# 311/311 [==============================] - 97s 313ms/step - loss: 0.6980 - prob_loss: 0.2266 - dist_loss: 2.3570 - prob_kld: 0.0526 - dist_relevant_mae: 2.3559 - dist_relevant_mse: 10.2884 - dist_dist_iou_metric: 0.7506 - val_loss: 0.6556 - val_prob_loss: 0.2152 - val_dist_loss: 2.2022 - val_prob_kld: 0.0600 - val_dist_relevant_mae: 2.2012 - val_dist_relevant_mse: 8.7770 - val_dist_dist_iou_metric: 0.7493 - lr: 3.0000e-04
# Epoch 9/50
# 2/2 [==============================] - 0s 7ms/step - loss: 0.6499 - prob_loss: 0.2185 - dist_loss: 2.1572 - prob_kld: 0.0462 - dist_relevant_mae: 2.1561 - dist_relevant_mse: 8.5957 - dist_dist_iou_metric: 0.76
# 311/311 [==============================] - 97s 311ms/step - loss: 0.6499 - prob_loss: 0.2185 - dist_loss: 2.1572 - prob_kld: 0.0462 - dist_relevant_mae: 2.1561 - dist_relevant_mse: 8.5957 - dist_dist_iou_metric: 0.7692 - val_loss: 0.6207 - val_prob_loss: 0.2033 - val_dist_loss: 2.0873 - val_prob_kld: 0.0481 - val_dist_relevant_mae: 2.0863 - val_dist_relevant_mse: 8.0955 - val_dist_dist_iou_metric: 0.7619 - lr: 3.0000e-04
# Epoch 10/50
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6138 - prob_loss: 0.2130 - dist_loss: 2.0041 - prob_kld: 0.0401 - dist_relevant_mae: 2.0030 - dist_relevant_mse: 7.3859 - dist_dist_iou_metric: 0.78
# 311/311 [==============================] - 97s 313ms/step - loss: 0.6138 - prob_loss: 0.2130 - dist_loss: 2.0041 - prob_kld: 0.0401 - dist_relevant_mae: 2.0030 - dist_relevant_mse: 7.3859 - dist_dist_iou_metric: 0.7836 - val_loss: 0.5963 - val_prob_loss: 0.2046 - val_dist_loss: 1.9584 - val_prob_kld: 0.0495 - val_dist_relevant_mae: 1.9575 - val_dist_relevant_mse: 7.4040 - val_dist_dist_iou_metric: 0.7728 - lr: 3.0000e-04
# Epoch 11/50
# 2/2 [==============================] - 0s 9ms/step - loss: 0.5688 - prob_loss: 0.2077 - dist_loss: 1.8059 - prob_kld: 0.0336 - dist_relevant_mae: 1.8049 - dist_relevant_mse: 6.0157 - dist_dist_iou_metric: 0.80
# 311/311 [==============================] - 98s 315ms/step - loss: 0.5688 - prob_loss: 0.2077 - dist_loss: 1.8059 - prob_kld: 0.0336 - dist_relevant_mae: 1.8049 - dist_relevant_mse: 6.0157 - dist_dist_iou_metric: 0.8029 - val_loss: 0.5635 - val_prob_loss: 0.1965 - val_dist_loss: 1.8351 - val_prob_kld: 0.0413 - val_dist_relevant_mae: 1.8341 - val_dist_relevant_mse: 6.6075 - val_dist_dist_iou_metric: 0.7850 - lr: 3.0000e-04
# Epoch 12/50
# 2/2 [==============================] - 0s 15ms/step- loss: 0.5346 - prob_loss: 0.2001 - dist_loss: 1.6728 - prob_kld: 0.0278 - dist_relevant_mae: 1.6718 - dist_relevant_mse: 5.1253 - dist_dist_iou_metric: 0.81
# 311/311 [==============================] - 97s 311ms/step - loss: 0.5346 - prob_loss: 0.2001 - dist_loss: 1.6728 - prob_kld: 0.0278 - dist_relevant_mae: 1.6718 - dist_relevant_mse: 5.1253 - dist_dist_iou_metric: 0.8149 - val_loss: 0.5471 - val_prob_loss: 0.1919 - val_dist_loss: 1.7760 - val_prob_kld: 0.0367 - val_dist_relevant_mae: 1.7751 - val_dist_relevant_mse: 6.0937 - val_dist_dist_iou_metric: 0.7886 - lr: 3.0000e-04
# Epoch 13/50
# 2/2 [==============================] - 0s 11ms/step- loss: 0.5019 - prob_loss: 0.1971 - dist_loss: 1.5241 - prob_kld: 0.0233 - dist_relevant_mae: 1.5231 - dist_relevant_mse: 4.2579 - dist_dist_iou_metric: 0.82
# 311/311 [==============================] - 96s 310ms/step - loss: 0.5019 - prob_loss: 0.1971 - dist_loss: 1.5241 - prob_kld: 0.0233 - dist_relevant_mae: 1.5231 - dist_relevant_mse: 4.2579 - dist_dist_iou_metric: 0.8298 - val_loss: 0.5690 - val_prob_loss: 0.1941 - val_dist_loss: 1.8748 - val_prob_kld: 0.0389 - val_dist_relevant_mae: 1.8739 - val_dist_relevant_mse: 6.6042 - val_dist_dist_iou_metric: 0.7710 - lr: 3.0000e-04
# Epoch 14/50
# 2/2 [==============================] - 0s 10ms/step- loss: 0.4792 - prob_loss: 0.1930 - dist_loss: 1.4310 - prob_kld: 0.0211 - dist_relevant_mae: 1.4301 - dist_relevant_mse: 3.7962 - dist_dist_iou_metric: 0.83
# 311/311 [==============================] - 96s 309ms/step - loss: 0.4792 - prob_loss: 0.1930 - dist_loss: 1.4310 - prob_kld: 0.0211 - dist_relevant_mae: 1.4301 - dist_relevant_mse: 3.7962 - dist_dist_iou_metric: 0.8389 - val_loss: 0.5343 - val_prob_loss: 0.1906 - val_dist_loss: 1.7189 - val_prob_kld: 0.0354 - val_dist_relevant_mae: 1.7180 - val_dist_relevant_mse: 5.7508 - val_dist_dist_iou_metric: 0.7886 - lr: 3.0000e-04
# Epoch 15/50
# 2/2 [==============================] - 0s 10ms/step- loss: 0.4605 - prob_loss: 0.1907 - dist_loss: 1.3489 - prob_kld: 0.0185 - dist_relevant_mae: 1.3480 - dist_relevant_mse: 3.3549 - dist_dist_iou_metric: 0.84
# 311/311 [==============================] - 96s 310ms/step - loss: 0.4605 - prob_loss: 0.1907 - dist_loss: 1.3489 - prob_kld: 0.0185 - dist_relevant_mae: 1.3480 - dist_relevant_mse: 3.3549 - dist_dist_iou_metric: 0.8467 - val_loss: 0.5244 - val_prob_loss: 0.1892 - val_dist_loss: 1.6760 - val_prob_kld: 0.0340 - val_dist_relevant_mae: 1.6752 - val_dist_relevant_mse: 5.6233 - val_dist_dist_iou_metric: 0.7972 - lr: 3.0000e-04
# Epoch 16/50
# 2/2 [==============================] - 0s 11ms/step- loss: 0.4411 - prob_loss: 0.1904 - dist_loss: 1.2536 - prob_kld: 0.0157 - dist_relevant_mae: 1.2527 - dist_relevant_mse: 2.9158 - dist_dist_iou_metric: 0.85
# 311/311 [==============================] - 98s 316ms/step - loss: 0.4411 - prob_loss: 0.1904 - dist_loss: 1.2536 - prob_kld: 0.0157 - dist_relevant_mae: 1.2527 - dist_relevant_mse: 2.9158 - dist_dist_iou_metric: 0.8568 - val_loss: 0.5221 - val_prob_loss: 0.1902 - val_dist_loss: 1.6591 - val_prob_kld: 0.0351 - val_dist_relevant_mae: 1.6583 - val_dist_relevant_mse: 5.4935 - val_dist_dist_iou_metric: 0.8054 - lr: 3.0000e-04
# Epoch 17/50
# 2/2 [==============================] - 0s 9ms/step - loss: 0.4161 - prob_loss: 0.1858 - dist_loss: 1.1510 - prob_kld: 0.0137 - dist_relevant_mae: 1.1502 - dist_relevant_mse: 2.4793 - dist_dist_iou_metric: 0.86
# 311/311 [==============================] - 97s 313ms/step - loss: 0.4161 - prob_loss: 0.1858 - dist_loss: 1.1510 - prob_kld: 0.0137 - dist_relevant_mae: 1.1502 - dist_relevant_mse: 2.4793 - dist_dist_iou_metric: 0.8671 - val_loss: 0.4835 - val_prob_loss: 0.1897 - val_dist_loss: 1.4690 - val_prob_kld: 0.0345 - val_dist_relevant_mae: 1.4682 - val_dist_relevant_mse: 4.1539 - val_dist_dist_iou_metric: 0.8214 - lr: 3.0000e-04
# Epoch 18/50
# 2/2 [==============================] - 0s 11ms/step- loss: 0.4128 - prob_loss: 0.1870 - dist_loss: 1.1290 - prob_kld: 0.0129 - dist_relevant_mae: 1.1281 - dist_relevant_mse: 2.3708 - dist_dist_iou_metric: 0.86
# 311/311 [==============================] - 98s 314ms/step - loss: 0.4128 - prob_loss: 0.1870 - dist_loss: 1.1290 - prob_kld: 0.0129 - dist_relevant_mae: 1.1281 - dist_relevant_mse: 2.3708 - dist_dist_iou_metric: 0.8694 - val_loss: 0.4995 - val_prob_loss: 0.1865 - val_dist_loss: 1.5647 - val_prob_kld: 0.0314 - val_dist_relevant_mae: 1.5639 - val_dist_relevant_mse: 4.7579 - val_dist_dist_iou_metric: 0.8176 - lr: 3.0000e-04
# Epoch 19/50
# 2/2 [==============================] - 0s 12ms/step- loss: 0.4011 - prob_loss: 0.1851 - dist_loss: 1.0797 - prob_kld: 0.0118 - dist_relevant_mae: 1.0788 - dist_relevant_mse: 2.1731 - dist_dist_iou_metric: 0.87
# 311/311 [==============================] - 97s 312ms/step - loss: 0.4011 - prob_loss: 0.1851 - dist_loss: 1.0797 - prob_kld: 0.0118 - dist_relevant_mae: 1.0788 - dist_relevant_mse: 2.1731 - dist_dist_iou_metric: 0.8744 - val_loss: 0.4835 - val_prob_loss: 0.1820 - val_dist_loss: 1.5075 - val_prob_kld: 0.0268 - val_dist_relevant_mae: 1.5068 - val_dist_relevant_mse: 4.1283 - val_dist_dist_iou_metric: 0.8178 - lr: 3.0000e-04
# Epoch 20/50
# 2/2 [==============================] - 0s 11ms/step- loss: 0.3826 - prob_loss: 0.1828 - dist_loss: 0.9992 - prob_kld: 0.0105 - dist_relevant_mae: 0.9984 - dist_relevant_mse: 1.8785 - dist_dist_iou_metric: 0.88
# 311/311 [==============================] - 97s 310ms/step - loss: 0.3826 - prob_loss: 0.1828 - dist_loss: 0.9992 - prob_kld: 0.0105 - dist_relevant_mae: 0.9984 - dist_relevant_mse: 1.8785 - dist_dist_iou_metric: 0.8828 - val_loss: 0.4990 - val_prob_loss: 0.1856 - val_dist_loss: 1.5669 - val_prob_kld: 0.0304 - val_dist_relevant_mae: 1.5661 - val_dist_relevant_mse: 4.8867 - val_dist_dist_iou_metric: 0.8125 - lr: 3.0000e-04
# Epoch 21/50
# 2/2 [==============================] - 0s 10ms/step- loss: 0.3714 - prob_loss: 0.1811 - dist_loss: 0.9512 - prob_kld: 0.0093 - dist_relevant_mae: 0.9504 - dist_relevant_mse: 1.7037 - dist_dist_iou_metric: 0.88
# 311/311 [==============================] - 96s 308ms/step - loss: 0.3714 - prob_loss: 0.1811 - dist_loss: 0.9512 - prob_kld: 0.0093 - dist_relevant_mae: 0.9504 - dist_relevant_mse: 1.7037 - dist_dist_iou_metric: 0.8881 - val_loss: 0.5168 - val_prob_loss: 0.1910 - val_dist_loss: 1.6291 - val_prob_kld: 0.0358 - val_dist_relevant_mae: 1.6283 - val_dist_relevant_mse: 5.2966 - val_dist_dist_iou_metric: 0.8005 - lr: 3.0000e-04
# Epoch 22/50
# 2/2 [==============================] - 0s 10ms/step- loss: 0.3698 - prob_loss: 0.1825 - dist_loss: 0.9364 - prob_kld: 0.0090 - dist_relevant_mae: 0.9356 - dist_relevant_mse: 1.6428 - dist_dist_iou_metric: 0.88
# 311/311 [==============================] - 97s 313ms/step - loss: 0.3698 - prob_loss: 0.1825 - dist_loss: 0.9364 - prob_kld: 0.0090 - dist_relevant_mae: 0.9356 - dist_relevant_mse: 1.6428 - dist_dist_iou_metric: 0.8896 - val_loss: 0.5204 - val_prob_loss: 0.1877 - val_dist_loss: 1.6637 - val_prob_kld: 0.0325 - val_dist_relevant_mae: 1.6631 - val_dist_relevant_mse: 5.3098 - val_dist_dist_iou_metric: 0.7970 - lr: 3.0000e-04
# Epoch 23/50
# 2/2 [==============================] - 0s 9ms/step - loss: 0.3603 - prob_loss: 0.1804 - dist_loss: 0.8992 - prob_kld: 0.0083 - dist_relevant_mae: 0.8984 - dist_relevant_mse: 1.5219 - dist_dist_iou_metric: 0.89
# 311/311 [==============================] - 96s 308ms/step - loss: 0.3603 - prob_loss: 0.1804 - dist_loss: 0.8992 - prob_kld: 0.0083 - dist_relevant_mae: 0.8984 - dist_relevant_mse: 1.5219 - dist_dist_iou_metric: 0.8936 - val_loss: 0.4861 - val_prob_loss: 0.1846 - val_dist_loss: 1.5073 - val_prob_kld: 0.0294 - val_dist_relevant_mae: 1.5066 - val_dist_relevant_mse: 4.3822 - val_dist_dist_iou_metric: 0.8178 - lr: 3.0000e-04
# Epoch 24/50
# 2/2 [==============================] - 0s 11ms/step- loss: 0.3507 - prob_loss: 0.1815 - dist_loss: 0.8459 - prob_kld: 0.0075 - dist_relevant_mae: 0.8451 - dist_relevant_mse: 1.3596 - dist_dist_iou_metric: 0.89
# 311/311 [==============================] - 97s 312ms/step - loss: 0.3507 - prob_loss: 0.1815 - dist_loss: 0.8459 - prob_kld: 0.0075 - dist_relevant_mae: 0.8451 - dist_relevant_mse: 1.3596 - dist_dist_iou_metric: 0.8995 - val_loss: 0.5238 - val_prob_loss: 0.1938 - val_dist_loss: 1.6499 - val_prob_kld: 0.0386 - val_dist_relevant_mae: 1.6492 - val_dist_relevant_mse: 5.6343 - val_dist_dist_iou_metric: 0.8017 - lr: 3.0000e-04
# Epoch 25/50
# 2/2 [==============================] - 0s 9ms/step - loss: 0.3542 - prob_loss: 0.1818 - dist_loss: 0.8620 - prob_kld: 0.0077 - dist_relevant_mae: 0.8612 - dist_relevant_mse: 1.3952 - dist_dist_iou_metric: 0.89
# 311/311 [==============================] - 98s 315ms/step - loss: 0.3542 - prob_loss: 0.1818 - dist_loss: 0.8620 - prob_kld: 0.0077 - dist_relevant_mae: 0.8612 - dist_relevant_mse: 1.3952 - dist_dist_iou_metric: 0.8980 - val_loss: 0.4924 - val_prob_loss: 0.1949 - val_dist_loss: 1.4873 - val_prob_kld: 0.0397 - val_dist_relevant_mae: 1.4867 - val_dist_relevant_mse: 4.5765 - val_dist_dist_iou_metric: 0.8184 - lr: 3.0000e-04
# Epoch 26/50
# 2/2 [==============================] - 0s 7ms/step - loss: 0.3395 - prob_loss: 0.1784 - dist_loss: 0.8051 - prob_kld: 0.0068 - dist_relevant_mae: 0.8044 - dist_relevant_mse: 1.2301 - dist_dist_iou_metric: 0.90
# 311/311 [==============================] - 95s 306ms/step - loss: 0.3395 - prob_loss: 0.1784 - dist_loss: 0.8051 - prob_kld: 0.0068 - dist_relevant_mae: 0.8044 - dist_relevant_mse: 1.2301 - dist_dist_iou_metric: 0.9038 - val_loss: 0.5220 - val_prob_loss: 0.1956 - val_dist_loss: 1.6318 - val_prob_kld: 0.0404 - val_dist_relevant_mae: 1.6312 - val_dist_relevant_mse: 5.3923 - val_dist_dist_iou_metric: 0.8025 - lr: 3.0000e-04
# Epoch 27/50
# 2/2 [==============================] - 0s 11ms/step- loss: 0.3411 - prob_loss: 0.1789 - dist_loss: 0.8109 - prob_kld: 0.0066 - dist_relevant_mae: 0.8101 - dist_relevant_mse: 1.2461 - dist_dist_iou_metric: 0.90
# 311/311 [==============================] - 97s 312ms/step - loss: 0.3411 - prob_loss: 0.1789 - dist_loss: 0.8109 - prob_kld: 0.0066 - dist_relevant_mae: 0.8101 - dist_relevant_mse: 1.2461 - dist_dist_iou_metric: 0.9037 - val_loss: 0.4739 - val_prob_loss: 0.1845 - val_dist_loss: 1.4471 - val_prob_kld: 0.0293 - val_dist_relevant_mae: 1.4464 - val_dist_relevant_mse: 4.1015 - val_dist_dist_iou_metric: 0.8247 - lr: 3.0000e-04
# Epoch 28/50
# 2/2 [==============================] - 0s 11ms/step- loss: 0.3392 - prob_loss: 0.1813 - dist_loss: 0.7897 - prob_kld: 0.0063 - dist_relevant_mae: 0.7889 - dist_relevant_mse: 1.1792 - dist_dist_iou_metric: 0.90
# 311/311 [==============================] - 98s 314ms/step - loss: 0.3392 - prob_loss: 0.1813 - dist_loss: 0.7897 - prob_kld: 0.0063 - dist_relevant_mae: 0.7889 - dist_relevant_mse: 1.1792 - dist_dist_iou_metric: 0.9058 - val_loss: 0.4862 - val_prob_loss: 0.1948 - val_dist_loss: 1.4573 - val_prob_kld: 0.0395 - val_dist_relevant_mae: 1.4566 - val_dist_relevant_mse: 4.7117 - val_dist_dist_iou_metric: 0.8249 - lr: 3.0000e-04
# Epoch 29/50
# 2/2 [==============================] - 0s 9ms/step - loss: 0.3273 - prob_loss: 0.1780 - dist_loss: 0.7465 - prob_kld: 0.0058 - dist_relevant_mae: 0.7457 - dist_relevant_mse: 1.0629 - dist_dist_iou_metric: 0.91
# 311/311 [==============================] - 96s 309ms/step - loss: 0.3273 - prob_loss: 0.1780 - dist_loss: 0.7465 - prob_kld: 0.0058 - dist_relevant_mae: 0.7457 - dist_relevant_mse: 1.0629 - dist_dist_iou_metric: 0.9107 - val_loss: 0.4779 - val_prob_loss: 0.1921 - val_dist_loss: 1.4291 - val_prob_kld: 0.0369 - val_dist_relevant_mae: 1.4284 - val_dist_relevant_mse: 4.2911 - val_dist_dist_iou_metric: 0.8282 - lr: 3.0000e-04
# Epoch 30/50
# 2/2 [==============================] - 0s 14ms/step- loss: 0.3282 - prob_loss: 0.1786 - dist_loss: 0.7479 - prob_kld: 0.0056 - dist_relevant_mae: 0.7472 - dist_relevant_mse: 1.0564 - dist_dist_iou_metric: 0.91
# 311/311 [==============================] - 98s 314ms/step - loss: 0.3282 - prob_loss: 0.1786 - dist_loss: 0.7479 - prob_kld: 0.0056 - dist_relevant_mae: 0.7472 - dist_relevant_mse: 1.0564 - dist_dist_iou_metric: 0.9105 - val_loss: 0.4712 - val_prob_loss: 0.1813 - val_dist_loss: 1.4494 - val_prob_kld: 0.0261 - val_dist_relevant_mae: 1.4487 - val_dist_relevant_mse: 4.0502 - val_dist_dist_iou_metric: 0.8285 - lr: 3.0000e-04
# Epoch 31/50
# 2/2 [==============================] - 0s 9ms/step - loss: 0.3274 - prob_loss: 0.1797 - dist_loss: 0.7387 - prob_kld: 0.0056 - dist_relevant_mae: 0.7380 - dist_relevant_mse: 1.0421 - dist_dist_iou_metric: 0.91
# 311/311 [==============================] - 97s 311ms/step - loss: 0.3274 - prob_loss: 0.1797 - dist_loss: 0.7387 - prob_kld: 0.0056 - dist_relevant_mae: 0.7380 - dist_relevant_mse: 1.0421 - dist_dist_iou_metric: 0.9117 - val_loss: 0.4682 - val_prob_loss: 0.1900 - val_dist_loss: 1.3908 - val_prob_kld: 0.0348 - val_dist_relevant_mae: 1.3901 - val_dist_relevant_mse: 4.1804 - val_dist_dist_iou_metric: 0.8295 - lr: 3.0000e-04
# Epoch 32/50
# 2/2 [==============================] - 0s 10ms/step- loss: 0.3295 - prob_loss: 0.1790 - dist_loss: 0.7522 - prob_kld: 0.0057 - dist_relevant_mae: 0.7515 - dist_relevant_mse: 1.0781 - dist_dist_iou_metric: 0.91
# 311/311 [==============================] - 97s 312ms/step - loss: 0.3295 - prob_loss: 0.1790 - dist_loss: 0.7522 - prob_kld: 0.0057 - dist_relevant_mae: 0.7515 - dist_relevant_mse: 1.0781 - dist_dist_iou_metric: 0.9101 - val_loss: 0.5147 - val_prob_loss: 0.1952 - val_dist_loss: 1.5977 - val_prob_kld: 0.0400 - val_dist_relevant_mae: 1.5971 - val_dist_relevant_mse: 5.0209 - val_dist_dist_iou_metric: 0.8091 - lr: 3.0000e-04
# Epoch 33/50
# 2/2 [==============================] - 0s 11ms/step- loss: 0.3204 - prob_loss: 0.1756 - dist_loss: 0.7239 - prob_kld: 0.0052 - dist_relevant_mae: 0.7232 - dist_relevant_mse: 0.9906 - dist_dist_iou_metric: 0.91
# 311/311 [==============================] - 97s 311ms/step - loss: 0.3204 - prob_loss: 0.1756 - dist_loss: 0.7239 - prob_kld: 0.0052 - dist_relevant_mae: 0.7232 - dist_relevant_mse: 0.9906 - dist_dist_iou_metric: 0.9132 - val_loss: 0.4685 - val_prob_loss: 0.1870 - val_dist_loss: 1.4073 - val_prob_kld: 0.0318 - val_dist_relevant_mae: 1.4066 - val_dist_relevant_mse: 4.1702 - val_dist_dist_iou_metric: 0.8300 - lr: 3.0000e-04
# Epoch 34/50
# 2/2 [==============================] - 0s 7ms/step - loss: 0.3190 - prob_loss: 0.1797 - dist_loss: 0.6965 - prob_kld: 0.0050 - dist_relevant_mae: 0.6959 - dist_relevant_mse: 0.9204 - dist_dist_iou_metric: 0.91
# 311/311 [==============================] - 98s 315ms/step - loss: 0.3190 - prob_loss: 0.1797 - dist_loss: 0.6965 - prob_kld: 0.0050 - dist_relevant_mae: 0.6959 - dist_relevant_mse: 0.9204 - dist_dist_iou_metric: 0.9164 - val_loss: 0.4770 - val_prob_loss: 0.1877 - val_dist_loss: 1.4463 - val_prob_kld: 0.0325 - val_dist_relevant_mae: 1.4457 - val_dist_relevant_mse: 4.3428 - val_dist_dist_iou_metric: 0.8277 - lr: 3.0000e-04
# Epoch 35/50
# 2/2 [==============================] - 0s 12ms/step- loss: 0.3219 - prob_loss: 0.1765 - dist_loss: 0.7271 - prob_kld: 0.0052 - dist_relevant_mae: 0.7265 - dist_relevant_mse: 0.9959 - dist_dist_iou_metric: 0.91
# 311/311 [==============================] - 96s 308ms/step - loss: 0.3219 - prob_loss: 0.1765 - dist_loss: 0.7271 - prob_kld: 0.0052 - dist_relevant_mae: 0.7265 - dist_relevant_mse: 0.9959 - dist_dist_iou_metric: 0.9131 - val_loss: 0.5174 - val_prob_loss: 0.1977 - val_dist_loss: 1.5985 - val_prob_kld: 0.0425 - val_dist_relevant_mae: 1.5979 - val_dist_relevant_mse: 5.1122 - val_dist_dist_iou_metric: 0.8085 - lr: 3.0000e-04
# Epoch 36/50
# 2/2 [==============================] - 0s 7ms/step - loss: 0.3199 - prob_loss: 0.1788 - dist_loss: 0.7056 - prob_kld: 0.0051 - dist_relevant_mae: 0.7050 - dist_relevant_mse: 0.9340 - dist_dist_iou_metric: 0.91
# 311/311 [==============================] - 98s 314ms/step - loss: 0.3199 - prob_loss: 0.1788 - dist_loss: 0.7056 - prob_kld: 0.0051 - dist_relevant_mae: 0.7050 - dist_relevant_mse: 0.9340 - dist_dist_iou_metric: 0.9154 - val_loss: 0.4517 - val_prob_loss: 0.1844 - val_dist_loss: 1.3362 - val_prob_kld: 0.0292 - val_dist_relevant_mae: 1.3357 - val_dist_relevant_mse: 3.6434 - val_dist_dist_iou_metric: 0.8390 - lr: 3.0000e-04
# Epoch 37/50
# 2/2 [==============================] - 0s 11ms/step- loss: 0.3127 - prob_loss: 0.1762 - dist_loss: 0.6824 - prob_kld: 0.0045 - dist_relevant_mae: 0.6818 - dist_relevant_mse: 0.8827 - dist_dist_iou_metric: 0.91
# 311/311 [==============================] - 96s 310ms/step - loss: 0.3127 - prob_loss: 0.1762 - dist_loss: 0.6824 - prob_kld: 0.0045 - dist_relevant_mae: 0.6818 - dist_relevant_mse: 0.8827 - dist_dist_iou_metric: 0.9179 - val_loss: 0.4788 - val_prob_loss: 0.1870 - val_dist_loss: 1.4591 - val_prob_kld: 0.0318 - val_dist_relevant_mae: 1.4585 - val_dist_relevant_mse: 4.2339 - val_dist_dist_iou_metric: 0.8249 - lr: 3.0000e-04
# Epoch 38/50
# 2/2 [==============================] - 0s 9ms/step - loss: 0.3178 - prob_loss: 0.1800 - dist_loss: 0.6887 - prob_kld: 0.0047 - dist_relevant_mae: 0.6882 - dist_relevant_mse: 0.8941 - dist_dist_iou_metric: 0.91
# 311/311 [==============================] - 97s 313ms/step - loss: 0.3178 - prob_loss: 0.1800 - dist_loss: 0.6887 - prob_kld: 0.0047 - dist_relevant_mae: 0.6882 - dist_relevant_mse: 0.8941 - dist_dist_iou_metric: 0.9171 - val_loss: 0.5083 - val_prob_loss: 0.1904 - val_dist_loss: 1.5892 - val_prob_kld: 0.0352 - val_dist_relevant_mae: 1.5887 - val_dist_relevant_mse: 5.1245 - val_dist_dist_iou_metric: 0.8082 - lr: 3.0000e-04
# Epoch 39/50
# 2/2 [==============================] - 0s 9ms/step - loss: 0.3104 - prob_loss: 0.1758 - dist_loss: 0.6730 - prob_kld: 0.0045 - dist_relevant_mae: 0.6725 - dist_relevant_mse: 0.8564 - dist_dist_iou_metric: 0.91
# 311/311 [==============================] - 96s 308ms/step - loss: 0.3104 - prob_loss: 0.1758 - dist_loss: 0.6730 - prob_kld: 0.0045 - dist_relevant_mae: 0.6725 - dist_relevant_mse: 0.8564 - dist_dist_iou_metric: 0.9193 - val_loss: 0.4804 - val_prob_loss: 0.1856 - val_dist_loss: 1.4739 - val_prob_kld: 0.0304 - val_dist_relevant_mae: 1.4734 - val_dist_relevant_mse: 4.5050 - val_dist_dist_iou_metric: 0.8214 - lr: 3.0000e-04
# Epoch 40/50
# 2/2 [==============================] - 0s 11ms/step- loss: 0.3087 - prob_loss: 0.1786 - dist_loss: 0.6504 - prob_kld: 0.0042 - dist_relevant_mae: 0.6499 - dist_relevant_mse: 0.8063 - dist_dist_iou_metric: 0.92
# 311/311 [==============================] - 98s 316ms/step - loss: 0.3087 - prob_loss: 0.1786 - dist_loss: 0.6504 - prob_kld: 0.0042 - dist_relevant_mae: 0.6499 - dist_relevant_mse: 0.8063 - dist_dist_iou_metric: 0.9218 - val_loss: 0.4578 - val_prob_loss: 0.1876 - val_dist_loss: 1.3511 - val_prob_kld: 0.0323 - val_dist_relevant_mae: 1.3506 - val_dist_relevant_mse: 3.7705 - val_dist_dist_iou_metric: 0.8363 - lr: 3.0000e-04
# Epoch 41/50
# 2/2 [==============================] - 0s 7ms/step - loss: 0.3037 - prob_loss: 0.1767 - dist_loss: 0.6349 - prob_kld: 0.0041 - dist_relevant_mae: 0.6344 - dist_relevant_mse: 0.7760 - dist_dist_iou_metric: 0.92
# 311/311 [==============================] - 97s 312ms/step - loss: 0.3037 - prob_loss: 0.1767 - dist_loss: 0.6349 - prob_kld: 0.0041 - dist_relevant_mae: 0.6344 - dist_relevant_mse: 0.7760 - dist_dist_iou_metric: 0.9237 - val_loss: 0.4695 - val_prob_loss: 0.1891 - val_dist_loss: 1.4021 - val_prob_kld: 0.0338 - val_dist_relevant_mae: 1.4016 - val_dist_relevant_mse: 4.1856 - val_dist_dist_iou_metric: 0.8319 - lr: 3.0000e-04
# Epoch 42/50
# 2/2 [==============================] - 0s 11ms/step- loss: 0.3067 - prob_loss: 0.1755 - dist_loss: 0.6560 - prob_kld: 0.0041 - dist_relevant_mae: 0.6555 - dist_relevant_mse: 0.8170 - dist_dist_iou_metric: 0.92
# 311/311 [==============================] - 97s 311ms/step - loss: 0.3067 - prob_loss: 0.1755 - dist_loss: 0.6560 - prob_kld: 0.0041 - dist_relevant_mae: 0.6555 - dist_relevant_mse: 0.8170 - dist_dist_iou_metric: 0.9211 - val_loss: 0.4664 - val_prob_loss: 0.1883 - val_dist_loss: 1.3908 - val_prob_kld: 0.0330 - val_dist_relevant_mae: 1.3903 - val_dist_relevant_mse: 4.0252 - val_dist_dist_iou_metric: 0.8333 - lr: 3.0000e-04
# Epoch 43/50
# 2/2 [==============================] - 0s 8ms/step - loss: 0.3118 - prob_loss: 0.1776 - dist_loss: 0.6708 - prob_kld: 0.0040 - dist_relevant_mae: 0.6703 - dist_relevant_mse: 0.8418 - dist_dist_iou_metric: 0.91
# 311/311 [==============================] - 97s 312ms/step - loss: 0.3118 - prob_loss: 0.1776 - dist_loss: 0.6708 - prob_kld: 0.0040 - dist_relevant_mae: 0.6703 - dist_relevant_mse: 0.8418 - dist_dist_iou_metric: 0.9195 - val_loss: 0.4730 - val_prob_loss: 0.1885 - val_dist_loss: 1.4223 - val_prob_kld: 0.0332 - val_dist_relevant_mae: 1.4218 - val_dist_relevant_mse: 4.2329 - val_dist_dist_iou_metric: 0.8302 - lr: 3.0000e-04
# Epoch 44/50
# 2/2 [==============================] - 0s 12ms/step- loss: 0.3053 - prob_loss: 0.1773 - dist_loss: 0.6396 - prob_kld: 0.0040 - dist_relevant_mae: 0.6391 - dist_relevant_mse: 0.7792 - dist_dist_iou_metric: 0.92
# 311/311 [==============================] - 97s 312ms/step - loss: 0.3053 - prob_loss: 0.1773 - dist_loss: 0.6396 - prob_kld: 0.0040 - dist_relevant_mae: 0.6391 - dist_relevant_mse: 0.7792 - dist_dist_iou_metric: 0.9230 - val_loss: 0.4696 - val_prob_loss: 0.1925 - val_dist_loss: 1.3856 - val_prob_kld: 0.0372 - val_dist_relevant_mae: 1.3852 - val_dist_relevant_mse: 4.2611 - val_dist_dist_iou_metric: 0.8338 - lr: 3.0000e-04
# Epoch 45/50
# 2/2 [==============================] - 0s 11ms/step- loss: 0.3017 - prob_loss: 0.1775 - dist_loss: 0.6207 - prob_kld: 0.0038 - dist_relevant_mae: 0.6202 - dist_relevant_mse: 0.7400 - dist_dist_iou_metric: 0.92
# 311/311 [==============================] - 97s 312ms/step - loss: 0.3017 - prob_loss: 0.1775 - dist_loss: 0.6207 - prob_kld: 0.0038 - dist_relevant_mae: 0.6202 - dist_relevant_mse: 0.7400 - dist_dist_iou_metric: 0.9254 - val_loss: 0.4700 - val_prob_loss: 0.1892 - val_dist_loss: 1.4041 - val_prob_kld: 0.0339 - val_dist_relevant_mae: 1.4037 - val_dist_relevant_mse: 4.1151 - val_dist_dist_iou_metric: 0.8293 - lr: 3.0000e-04
# Epoch 46/50
# 2/2 [==============================] - 0s 11ms/step- loss: 0.2987 - prob_loss: 0.1765 - dist_loss: 0.6105 - prob_kld: 0.0037 - dist_relevant_mae: 0.6100 - dist_relevant_mse: 0.7114 - dist_dist_iou_metric: 0.92
# 311/311 [==============================] - 97s 311ms/step - loss: 0.2987 - prob_loss: 0.1765 - dist_loss: 0.6105 - prob_kld: 0.0037 - dist_relevant_mae: 0.6100 - dist_relevant_mse: 0.7114 - dist_dist_iou_metric: 0.9265 - val_loss: 0.4743 - val_prob_loss: 0.1952 - val_dist_loss: 1.3956 - val_prob_kld: 0.0398 - val_dist_relevant_mae: 1.3952 - val_dist_relevant_mse: 4.0568 - val_dist_dist_iou_metric: 0.8330 - lr: 3.0000e-04
# Epoch 47/50
# 2/2 [==============================] - 0s 11ms/step- loss: 0.3032 - prob_loss: 0.1780 - dist_loss: 0.6261 - prob_kld: 0.0038 - dist_relevant_mae: 0.6256 - dist_relevant_mse: 0.7469 - dist_dist_iou_metric: 0.92
# 311/311 [==============================] - 98s 314ms/step - loss: 0.3032 - prob_loss: 0.1780 - dist_loss: 0.6261 - prob_kld: 0.0038 - dist_relevant_mae: 0.6256 - dist_relevant_mse: 0.7469 - dist_dist_iou_metric: 0.9249 - val_loss: 0.5392 - val_prob_loss: 0.2281 - val_dist_loss: 1.5553 - val_prob_kld: 0.0650 - val_dist_relevant_mae: 1.5549 - val_dist_relevant_mse: 6.2079 - val_dist_dist_iou_metric: 0.8201 - lr: 3.0000e-04
# Epoch 48/50
# 2/2 [==============================] - 0s 10ms/step- loss: 0.2985 - prob_loss: 0.1750 - dist_loss: 0.6175 - prob_kld: 0.0038 - dist_relevant_mae: 0.6170 - dist_relevant_mse: 0.7280 - dist_dist_iou_metric: 0.92
# 311/311 [==============================] - 96s 308ms/step - loss: 0.2985 - prob_loss: 0.1750 - dist_loss: 0.6175 - prob_kld: 0.0038 - dist_relevant_mae: 0.6170 - dist_relevant_mse: 0.7280 - dist_dist_iou_metric: 0.9258 - val_loss: 0.4682 - val_prob_loss: 0.1920 - val_dist_loss: 1.3809 - val_prob_kld: 0.0365 - val_dist_relevant_mae: 1.3805 - val_dist_relevant_mse: 4.2374 - val_dist_dist_iou_metric: 0.8342 - lr: 3.0000e-04
# Epoch 49/50
# 2/2 [==============================] - 0s 7ms/step - loss: 0.2980 - prob_loss: 0.1790 - dist_loss: 0.5949 - prob_kld: 0.0035 - dist_relevant_mae: 0.5944 - dist_relevant_mse: 0.6775 - dist_dist_iou_metric: 0.92
# 311/311 [==============================] - 98s 315ms/step - loss: 0.2980 - prob_loss: 0.1790 - dist_loss: 0.5949 - prob_kld: 0.0035 - dist_relevant_mae: 0.5944 - dist_relevant_mse: 0.6775 - dist_dist_iou_metric: 0.9282 - val_loss: 0.4867 - val_prob_loss: 0.1894 - val_dist_loss: 1.4863 - val_prob_kld: 0.0341 - val_dist_relevant_mae: 1.4859 - val_dist_relevant_mse: 4.2454 - val_dist_dist_iou_metric: 0.8209 - lr: 3.0000e-04
# Epoch 50/50
# 2/2 [==============================] - 0s 11ms/step- loss: 0.3031 - prob_loss: 0.1741 - dist_loss: 0.6448 - prob_kld: 0.0037 - dist_relevant_mae: 0.6443 - dist_relevant_mse: 0.7793 - dist_dist_iou_metric: 0.92
# 311/311 [==============================] - 96s 308ms/step - loss: 0.3031 - prob_loss: 0.1741 - dist_loss: 0.6448 - prob_kld: 0.0037 - dist_relevant_mae: 0.6443 - dist_relevant_mse: 0.7793 - dist_dist_iou_metric: 0.9224 - val_loss: 0.4701 - val_prob_loss: 0.1933 - val_dist_loss: 1.3840 - val_prob_kld: 0.0380 - val_dist_relevant_mae: 1.3836 - val_dist_relevant_mse: 3.9293 - val_dist_dist_iou_metric: 0.8345 - lr: 3.0000e-04
#
# Loading network weights from 'weights_best.h5'.

# %%
model.optimize_thresholds(X_val, Y_val)
# Out:
# NMS threshold = 0.3:  80%|████████  | 16/20 [00:02<00:00,  7.29it/s, 0.492 -> 0.641]
# NMS threshold = 0.4:  80%|████████  | 16/20 [00:00<00:00, 21.05it/s, 0.492 -> 0.641]
# NMS threshold = 0.5:  80%|████████  | 16/20 [00:00<00:00, 20.89it/s, 0.492 -> 0.641]
# Using optimized values: prob_thresh=0.490578, nms_thresh=0.3.
# Saving to 'thresholds.json'.
# {'prob': 0.49057814054541066, 'nms': 0.3}

# %% [markdown]
# ## Test network on one of the training images (self prediction)
#
# Self prediction is not a good way to evaluate the 'real' performance of the NN.  However it is good sanity test.  If the self prediction looks wrong something really went bad.

# %%
n=60
labels, details = model.predict_instances(X_train[n], prob_thresh=0.5, nms_thresh=0.1)
fig = imshow_multi2d([X_train[n],Y_train[n],labels],['input','ground truth','predicted instances'],1,3)

# %%
from skimage.io import imread
from tnia.plotting.plt_helper import random_label_cmap
from tnia.deeplearning.dl_helper import ray4_to_ellipsoid2d_labels
from csbdeep.utils import normalize
import numpy as np
test_name='eye1.jpeg'
testim = imread(parent_path  / test_name) 
if (sub_sample != 1):
    testim = testim[::sub_sample,::sub_sample]  
testim = normalize(testim,1,99.8, axis=(0,1))
labels, details = model.predict_instances(testim, prob_thresh=0.01, nms_thresh=0.1)

if n_rays == 4:
    labels2 = np.zeros_like(labels)#ray4_to_ellipsoid2d_labels(details['coord'], testim.shape)
    fig = imshow_multi2d([testim,labels,labels2],['input','predicted octohedrons', 'rendered as ellipses'],1,3, width=14, height=8,colormaps=['gray', random_label_cmap(), random_label_cmap()])
else:
    fig = imshow_multi2d([testim,labels],['input','predicted octohedrons'],1,2, width=14, height=8,colormaps=['gray', random_label_cmap()])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
import napari

viewer = napari.Viewer()
viewer.add_image(testim, name='testim')
viewer.add_labels(labels, name='labels2')
# Out:
# <Labels layer 'labels2' at 0x24eca9867f0>
