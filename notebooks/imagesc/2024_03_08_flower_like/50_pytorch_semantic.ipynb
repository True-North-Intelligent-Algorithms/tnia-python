# %% [markdown]
# ## Train a semantic segmentation unet using Pytorch

# %% [markdown]
# ## Pytorch setup
#
# setting up environment (Windows 10 with Cuda 11.8)
#
# ```
# conda create --name pytorch_tests python=3.10
# conda activate pytorch_tests
# conda install pip
# pip install pykernel
# pip3 install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118
# pip install pytorch-lightning
# pip install monai
# pip install scipy
# pip install tifffile
# pip install matplotlib
# ```

# %% [markdown]
# ## Imports

# %%
from skimage.io import imread
from tqdm import tqdm
from tnia.deeplearning.dl_helper import quantile_normalization
import matplotlib.pyplot as plt
import numpy as np
import torch

from torchvision import transforms
from torchvision.transforms import v2
import torchvision.transforms.functional as TF

# %% [markdown]
# ## Check if GPU is present

# %%
cuda_present = torch.cuda.is_available()
ndevices = torch.cuda.device_count()
use_cuda = cuda_present and ndevices > 0
device = torch.device("cuda" if use_cuda else "cpu")  # "cuda:0" ... default device, "cuda:1" would be GPU index 1, "cuda:2" etc
print("number of devices:", ndevices, "\tchosen device:", device, "\tuse_cuda=", use_cuda)
# Out:
# number of devices: 1 	chosen device: cuda 	use_cuda= True

# %% [markdown]
# ## Set up image and label directories

# %%
from pathlib import Path
import json

tnia_images_path = Path(r'D:/images')
parent_path=Path(tnia_images_path / r'D:\images\tnia-python-images\imagesc\2024_03_08_flower_like')
train_path= parent_path / 'patches' 

with open(train_path / 'info.json', 'r') as json_file:
    data = json.load(json_file)
    # Access the sub_sample parameter
    sub_sample = data.get('sub_sample',1)
    print('sub_sample',sub_sample)
    axes = data['axes']
    print('axes',axes)

image_patch_path = train_path / 'ground truth0'
label_patch_path = train_path / 'input0'
# Out:
# sub_sample 1
# axes YX

# %% [markdown]
# ## Create a PyTorch Dataset
#
# Dataset is simply used to retrieve the training patches.  In this case we just set it up to read in image files, then convert the numpy arrays to tensors and a torch stack.
#
# In this example augmentation was done in a previous notebook, and the augmented images explicitly saved.  It is also possible to do augmentation as the data is retrieved.  So in the future the ```MyDataSet``` could be extended to apply augmentation as data is retrieved.

# %%
class MyDataSet():

    def __init__(self, image_files, label_files, target_shape=(256, 256)):
            """
            Parameters
            ----------
            image_files: list of pathlib.Path objects pointing to the *.tif images
            label_files: list of pathlib.Path objects pointing to the *.tif segmentation masks
            target_shape: tuple of length 2 specifying the sample resolutions of files that
                        will be kept. All other files will NOT be used.
            """
            assert len(image_files) == len(label_files)
            assert all(x.name==y.name for x,y in zip(image_files, label_files))

            self.images = []
            self.labels = []

            tensor_transform = transforms.Compose([
                v2.ToTensor(),
            ])

            # use tqdm to have eye pleasing error bars
            for idx in tqdm(range(len(image_files))):
                # we use the same data reading approach as in the previous notebook
                image = imread(image_files[idx])
                label = imread(label_files[idx])

                if image.shape != target_shape:
                    continue
                
                # do the normalizations
                #image = quantile_normalization(
                #   image,
                #    quantile_low=0.01,
                #    quantile_high=0.998,
                #    clip=True)[0].astype(np.float32)

                # NOTE: we convert the label to dtype float32 and not uint8 because
                # the tensor transformation does a normalization if the input is of
                # dtype uint8, destroying the 0/1 labelling which we want to avoid.
                #label = fill_label_holes(label)
                label_binary = np.zeros_like(label).astype(np.float32)
                label_binary[label != 0] = 1.
                

                # convert to torch tensor: adds an artificial color channel in the front
                # and scales inputs to have same size as samples tend to differ in image
                # resolutions
                image = tensor_transform(image)
                label = tensor_transform(label_binary)

                self.images.append(image)
                self.labels.append(label)

            self.images = torch.stack(self.images)
            self.labels = torch.stack(self.labels)
    
    def __getitem__(self, idx):
        return self.images[idx], self.labels[idx]

    def __len__(self):
        return len(self.images)

# %% [markdown]
# ## Initialize the DataSet
#
# Initialize the DataSet with the pre-generated patch names

# %%
src_dir = train_path

assert src_dir.exists(), f"root directory with images and masks {src_dir} does not exist"

X = sorted(src_dir.rglob('**/input0/*.tif'))
Y = sorted(src_dir.rglob('**/ground truth0/*.tif'))

train_data = MyDataSet(
    image_files=X,
    label_files=Y,
    target_shape=(512, 512)
)

# NOTE: the length of the dataset might not be the same as n_samples
#       because files not having the target shape will be discarded
print(len(train_data))
# Out:
# c:\Users\bnort\miniconda3\envs\pytorch_tests2\lib\site-packages\torchvision\transforms\v2\_deprecated.py:43: UserWarning: The transform `ToTensor()` is deprecated and will be removed in a future release. Instead, please use `v2.Compose([v2.ToImage(), v2.ToDtype(torch.float32, scale=True)])`.
#   warnings.warn(
# 100%|██████████| 100/100 [00:00<00:00, 374.11it/s]
# 100

# %% [markdown]
# ## Create a DataLoader
#
# This is done so we can load batches of images.

# %%
from torch.utils.data import DataLoader

train_loader = DataLoader(train_data, batch_size=32, shuffle=True)

# %% [markdown]
# ## Create a UNET

# %%
from monai.networks.nets import BasicUNet

model = BasicUNet(
    spatial_dims=2,
    in_channels=1,
    out_channels=1,
    #features=[16, 16, 32, 64, 128, 16],
    act="relu",
    norm="batch",
    dropout=0.25,
)

# Important: transfer the model to the chosen device
model = model.to(device)

optimizer = torch.optim.Adam(model.parameters(), lr=1.e-3)
init_params = list(model.parameters())[0].clone().detach()
# Out:
# BasicUNet features: (32, 32, 64, 128, 256, 32).

# %% [markdown]
# ## Train the UNET

# %%
max_nepochs = 200
log_interval = 1
model.train(True)

# BCEWithLogitsLoss combines sigmoid + BCELoss for better
# numerical stability. It expects raw unnormalized scores as input which are shaped like 
# B x C x W x D
loss_function = torch.nn.BCEWithLogitsLoss(reduction="mean")

for epoch in range(1, max_nepochs + 1):
    for batch_idx, (X, y) in enumerate(train_loader):
        # the inputs and labels have to be on the same device as the model
        X, y = X.to(device), y.to(device)
        
        optimizer.zero_grad()

        prediction_logits = model(X)
        
        batch_loss = loss_function(prediction_logits, y)

        batch_loss.backward()

        optimizer.step()

        if batch_idx % log_interval == 0:
            print(
                "Train Epoch:",
                epoch,
                "Batch:",
                batch_idx,
                "Total samples processed:",
                (batch_idx + 1) * train_loader.batch_size,
                "Loss:",
                batch_loss.item(),
            )
# Out:
# Train Epoch: 1 Batch: 0 Total samples processed: 32 Loss: 0.7155537605285645
# Train Epoch: 1 Batch: 1 Total samples processed: 64 Loss: 0.6845452785491943
# Train Epoch: 1 Batch: 2 Total samples processed: 96 Loss: 0.6621086597442627
# Train Epoch: 1 Batch: 3 Total samples processed: 128 Loss: 0.6313705444335938
# Train Epoch: 2 Batch: 0 Total samples processed: 32 Loss: 0.6220630407333374
# Train Epoch: 2 Batch: 1 Total samples processed: 64 Loss: 0.6082337498664856
# Train Epoch: 2 Batch: 2 Total samples processed: 96 Loss: 0.5809699892997742
# Train Epoch: 2 Batch: 3 Total samples processed: 128 Loss: 0.5706837773323059
# Train Epoch: 3 Batch: 0 Total samples processed: 32 Loss: 0.5572272539138794
# Train Epoch: 3 Batch: 1 Total samples processed: 64 Loss: 0.5479890704154968
# Train Epoch: 3 Batch: 2 Total samples processed: 96 Loss: 0.5260027647018433
# Train Epoch: 3 Batch: 3 Total samples processed: 128 Loss: 0.513390302658081
# Train Epoch: 4 Batch: 0 Total samples processed: 32 Loss: 0.5044753551483154
# Train Epoch: 4 Batch: 1 Total samples processed: 64 Loss: 0.495219886302948
# Train Epoch: 4 Batch: 2 Total samples processed: 96 Loss: 0.48834511637687683
# Train Epoch: 4 Batch: 3 Total samples processed: 128 Loss: 0.4708296060562134
# Train Epoch: 5 Batch: 0 Total samples processed: 32 Loss: 0.46333998441696167
# Train Epoch: 5 Batch: 1 Total samples processed: 64 Loss: 0.45939910411834717
# Train Epoch: 5 Batch: 2 Total samples processed: 96 Loss: 0.44759494066238403
# Train Epoch: 5 Batch: 3 Total samples processed: 128 Loss: 0.4464902877807617
# Train Epoch: 6 Batch: 0 Total samples processed: 32 Loss: 0.4306790232658386
# Train Epoch: 6 Batch: 1 Total samples processed: 64 Loss: 0.42603179812431335
# Train Epoch: 6 Batch: 2 Total samples processed: 96 Loss: 0.41575196385383606
# Train Epoch: 6 Batch: 3 Total samples processed: 128 Loss: 0.4114654064178467
# Train Epoch: 7 Batch: 0 Total samples processed: 32 Loss: 0.4018794298171997
# Train Epoch: 7 Batch: 1 Total samples processed: 64 Loss: 0.39503273367881775
# Train Epoch: 7 Batch: 2 Total samples processed: 96 Loss: 0.3884931802749634
# Train Epoch: 7 Batch: 3 Total samples processed: 128 Loss: 0.39872393012046814
# Train Epoch: 8 Batch: 0 Total samples processed: 32 Loss: 0.3739922046661377
# Train Epoch: 8 Batch: 1 Total samples processed: 64 Loss: 0.3700869381427765
# Train Epoch: 8 Batch: 2 Total samples processed: 96 Loss: 0.3701102137565613
# Train Epoch: 8 Batch: 3 Total samples processed: 128 Loss: 0.37033116817474365
# Train Epoch: 9 Batch: 0 Total samples processed: 32 Loss: 0.35877692699432373
# Train Epoch: 9 Batch: 1 Total samples processed: 64 Loss: 0.35526394844055176
# Train Epoch: 9 Batch: 2 Total samples processed: 96 Loss: 0.34642958641052246
# Train Epoch: 9 Batch: 3 Total samples processed: 128 Loss: 0.36721867322921753
# Train Epoch: 10 Batch: 0 Total samples processed: 32 Loss: 0.34268391132354736
# Train Epoch: 10 Batch: 1 Total samples processed: 64 Loss: 0.33661550283432007
# Train Epoch: 10 Batch: 2 Total samples processed: 96 Loss: 0.3416486978530884
# Train Epoch: 10 Batch: 3 Total samples processed: 128 Loss: 0.3317723274230957
# Train Epoch: 11 Batch: 0 Total samples processed: 32 Loss: 0.3270168900489807
# Train Epoch: 11 Batch: 1 Total samples processed: 64 Loss: 0.32944852113723755
# Train Epoch: 11 Batch: 2 Total samples processed: 96 Loss: 0.325761616230011
# Train Epoch: 11 Batch: 3 Total samples processed: 128 Loss: 0.32917600870132446
# Train Epoch: 12 Batch: 0 Total samples processed: 32 Loss: 0.3247867524623871
# Train Epoch: 12 Batch: 1 Total samples processed: 64 Loss: 0.3151600658893585
# Train Epoch: 12 Batch: 2 Total samples processed: 96 Loss: 0.3164459764957428
# Train Epoch: 12 Batch: 3 Total samples processed: 128 Loss: 0.3407811224460602
# Train Epoch: 13 Batch: 0 Total samples processed: 32 Loss: 0.3069726824760437
# Train Epoch: 13 Batch: 1 Total samples processed: 64 Loss: 0.30821794271469116
# Train Epoch: 13 Batch: 2 Total samples processed: 96 Loss: 0.3083125352859497
# Train Epoch: 13 Batch: 3 Total samples processed: 128 Loss: 0.3188159465789795
# Train Epoch: 14 Batch: 0 Total samples processed: 32 Loss: 0.30171704292297363
# Train Epoch: 14 Batch: 1 Total samples processed: 64 Loss: 0.3005061149597168
# Train Epoch: 14 Batch: 2 Total samples processed: 96 Loss: 0.2956933081150055
# Train Epoch: 14 Batch: 3 Total samples processed: 128 Loss: 0.30773812532424927
# Train Epoch: 15 Batch: 0 Total samples processed: 32 Loss: 0.2934534251689911
# Train Epoch: 15 Batch: 1 Total samples processed: 64 Loss: 0.2924070954322815
# Train Epoch: 15 Batch: 2 Total samples processed: 96 Loss: 0.28922832012176514
# Train Epoch: 15 Batch: 3 Total samples processed: 128 Loss: 0.2986507713794708
# Train Epoch: 16 Batch: 0 Total samples processed: 32 Loss: 0.28710228204727173
# Train Epoch: 16 Batch: 1 Total samples processed: 64 Loss: 0.281459778547287
# Train Epoch: 16 Batch: 2 Total samples processed: 96 Loss: 0.28155702352523804
# Train Epoch: 16 Batch: 3 Total samples processed: 128 Loss: 0.2798924148082733
# Train Epoch: 17 Batch: 0 Total samples processed: 32 Loss: 0.27836379408836365
# Train Epoch: 17 Batch: 1 Total samples processed: 64 Loss: 0.2766718864440918
# Train Epoch: 17 Batch: 2 Total samples processed: 96 Loss: 0.27465811371803284
# Train Epoch: 17 Batch: 3 Total samples processed: 128 Loss: 0.28943970799446106
# Train Epoch: 18 Batch: 0 Total samples processed: 32 Loss: 0.27224987745285034
# Train Epoch: 18 Batch: 1 Total samples processed: 64 Loss: 0.2709594666957855
# Train Epoch: 18 Batch: 2 Total samples processed: 96 Loss: 0.2678118944168091
# Train Epoch: 18 Batch: 3 Total samples processed: 128 Loss: 0.27383193373680115
# Train Epoch: 19 Batch: 0 Total samples processed: 32 Loss: 0.27192237973213196
# Train Epoch: 19 Batch: 1 Total samples processed: 64 Loss: 0.26661309599876404
# Train Epoch: 19 Batch: 2 Total samples processed: 96 Loss: 0.2695041000843048
# Train Epoch: 19 Batch: 3 Total samples processed: 128 Loss: 0.28321415185928345
# Train Epoch: 20 Batch: 0 Total samples processed: 32 Loss: 0.26973292231559753
# Train Epoch: 20 Batch: 1 Total samples processed: 64 Loss: 0.2587767243385315
# Train Epoch: 20 Batch: 2 Total samples processed: 96 Loss: 0.26330071687698364
# Train Epoch: 20 Batch: 3 Total samples processed: 128 Loss: 0.25449955463409424
# Train Epoch: 21 Batch: 0 Total samples processed: 32 Loss: 0.26025962829589844
# Train Epoch: 21 Batch: 1 Total samples processed: 64 Loss: 0.25864213705062866
# Train Epoch: 21 Batch: 2 Total samples processed: 96 Loss: 0.2506473660469055
# Train Epoch: 21 Batch: 3 Total samples processed: 128 Loss: 0.25312164425849915
# Train Epoch: 22 Batch: 0 Total samples processed: 32 Loss: 0.2501499056816101
# Train Epoch: 22 Batch: 1 Total samples processed: 64 Loss: 0.25360584259033203
# Train Epoch: 22 Batch: 2 Total samples processed: 96 Loss: 0.24881014227867126
# Train Epoch: 22 Batch: 3 Total samples processed: 128 Loss: 0.2786633372306824
# Train Epoch: 23 Batch: 0 Total samples processed: 32 Loss: 0.24624896049499512
# Train Epoch: 23 Batch: 1 Total samples processed: 64 Loss: 0.24398918449878693
# Train Epoch: 23 Batch: 2 Total samples processed: 96 Loss: 0.24803456664085388
# Train Epoch: 23 Batch: 3 Total samples processed: 128 Loss: 0.25965142250061035
# Train Epoch: 24 Batch: 0 Total samples processed: 32 Loss: 0.2473095804452896
# Train Epoch: 24 Batch: 1 Total samples processed: 64 Loss: 0.2362733781337738
# Train Epoch: 24 Batch: 2 Total samples processed: 96 Loss: 0.2392158806324005
# Train Epoch: 24 Batch: 3 Total samples processed: 128 Loss: 0.23083999752998352
# Train Epoch: 25 Batch: 0 Total samples processed: 32 Loss: 0.23558972775936127
# Train Epoch: 25 Batch: 1 Total samples processed: 64 Loss: 0.23619693517684937
# Train Epoch: 25 Batch: 2 Total samples processed: 96 Loss: 0.23225617408752441
# Train Epoch: 25 Batch: 3 Total samples processed: 128 Loss: 0.2538497745990753
# Train Epoch: 26 Batch: 0 Total samples processed: 32 Loss: 0.23015521466732025
# Train Epoch: 26 Batch: 1 Total samples processed: 64 Loss: 0.232811838388443
# Train Epoch: 26 Batch: 2 Total samples processed: 96 Loss: 0.22638505697250366
# Train Epoch: 26 Batch: 3 Total samples processed: 128 Loss: 0.2493288815021515
# Train Epoch: 27 Batch: 0 Total samples processed: 32 Loss: 0.22825080156326294
# Train Epoch: 27 Batch: 1 Total samples processed: 64 Loss: 0.22843562066555023
# Train Epoch: 27 Batch: 2 Total samples processed: 96 Loss: 0.22250083088874817
# Train Epoch: 27 Batch: 3 Total samples processed: 128 Loss: 0.2304534614086151
# Train Epoch: 28 Batch: 0 Total samples processed: 32 Loss: 0.22372755408287048
# Train Epoch: 28 Batch: 1 Total samples processed: 64 Loss: 0.21540983021259308
# Train Epoch: 28 Batch: 2 Total samples processed: 96 Loss: 0.22191298007965088
# Train Epoch: 28 Batch: 3 Total samples processed: 128 Loss: 0.240794837474823
# Train Epoch: 29 Batch: 0 Total samples processed: 32 Loss: 0.2144814133644104
# Train Epoch: 29 Batch: 1 Total samples processed: 64 Loss: 0.21674397587776184
# Train Epoch: 29 Batch: 2 Total samples processed: 96 Loss: 0.22646217048168182
# Train Epoch: 29 Batch: 3 Total samples processed: 128 Loss: 0.21821224689483643
# Train Epoch: 30 Batch: 0 Total samples processed: 32 Loss: 0.21783417463302612
# Train Epoch: 30 Batch: 1 Total samples processed: 64 Loss: 0.2123810201883316
# Train Epoch: 30 Batch: 2 Total samples processed: 96 Loss: 0.21034257113933563
# Train Epoch: 30 Batch: 3 Total samples processed: 128 Loss: 0.21046718955039978
# Train Epoch: 31 Batch: 0 Total samples processed: 32 Loss: 0.20933419466018677
# Train Epoch: 31 Batch: 1 Total samples processed: 64 Loss: 0.2110937386751175
# Train Epoch: 31 Batch: 2 Total samples processed: 96 Loss: 0.20615935325622559
# Train Epoch: 31 Batch: 3 Total samples processed: 128 Loss: 0.2116597294807434
# Train Epoch: 32 Batch: 0 Total samples processed: 32 Loss: 0.20463977754116058
# Train Epoch: 32 Batch: 1 Total samples processed: 64 Loss: 0.20643681287765503
# Train Epoch: 32 Batch: 2 Total samples processed: 96 Loss: 0.20659410953521729
# Train Epoch: 32 Batch: 3 Total samples processed: 128 Loss: 0.2131045013666153
# Train Epoch: 33 Batch: 0 Total samples processed: 32 Loss: 0.20193159580230713
# Train Epoch: 33 Batch: 1 Total samples processed: 64 Loss: 0.20638644695281982
# Train Epoch: 33 Batch: 2 Total samples processed: 96 Loss: 0.20519007742404938
# Train Epoch: 33 Batch: 3 Total samples processed: 128 Loss: 0.19454020261764526
# Train Epoch: 34 Batch: 0 Total samples processed: 32 Loss: 0.20142138004302979
# Train Epoch: 34 Batch: 1 Total samples processed: 64 Loss: 0.20235350728034973
# Train Epoch: 34 Batch: 2 Total samples processed: 96 Loss: 0.1985490620136261
# Train Epoch: 34 Batch: 3 Total samples processed: 128 Loss: 0.1961265355348587
# Train Epoch: 35 Batch: 0 Total samples processed: 32 Loss: 0.1953389197587967
# Train Epoch: 35 Batch: 1 Total samples processed: 64 Loss: 0.19858509302139282
# Train Epoch: 35 Batch: 2 Total samples processed: 96 Loss: 0.1963978111743927
# Train Epoch: 35 Batch: 3 Total samples processed: 128 Loss: 0.19098417460918427
# Train Epoch: 36 Batch: 0 Total samples processed: 32 Loss: 0.1889112889766693
# Train Epoch: 36 Batch: 1 Total samples processed: 64 Loss: 0.19599562883377075
# Train Epoch: 36 Batch: 2 Total samples processed: 96 Loss: 0.19122102856636047
# Train Epoch: 36 Batch: 3 Total samples processed: 128 Loss: 0.19791191816329956
# Train Epoch: 37 Batch: 0 Total samples processed: 32 Loss: 0.19146788120269775
# Train Epoch: 37 Batch: 1 Total samples processed: 64 Loss: 0.18422380089759827
# Train Epoch: 37 Batch: 2 Total samples processed: 96 Loss: 0.18990546464920044
# Train Epoch: 37 Batch: 3 Total samples processed: 128 Loss: 0.18765294551849365
# Train Epoch: 38 Batch: 0 Total samples processed: 32 Loss: 0.18623292446136475
# Train Epoch: 38 Batch: 1 Total samples processed: 64 Loss: 0.18479390442371368
# Train Epoch: 38 Batch: 2 Total samples processed: 96 Loss: 0.1845385879278183
# Train Epoch: 38 Batch: 3 Total samples processed: 128 Loss: 0.1946350336074829
# Train Epoch: 39 Batch: 0 Total samples processed: 32 Loss: 0.18114303052425385
# Train Epoch: 39 Batch: 1 Total samples processed: 64 Loss: 0.1814124584197998
# Train Epoch: 39 Batch: 2 Total samples processed: 96 Loss: 0.18612030148506165
# Train Epoch: 39 Batch: 3 Total samples processed: 128 Loss: 0.18292531371116638
# Train Epoch: 40 Batch: 0 Total samples processed: 32 Loss: 0.1793586015701294
# Train Epoch: 40 Batch: 1 Total samples processed: 64 Loss: 0.1832394152879715
# Train Epoch: 40 Batch: 2 Total samples processed: 96 Loss: 0.18009237945079803
# Train Epoch: 40 Batch: 3 Total samples processed: 128 Loss: 0.17051056027412415
# Train Epoch: 41 Batch: 0 Total samples processed: 32 Loss: 0.17475906014442444
# Train Epoch: 41 Batch: 1 Total samples processed: 64 Loss: 0.1761908084154129
# Train Epoch: 41 Batch: 2 Total samples processed: 96 Loss: 0.1782151460647583
# Train Epoch: 41 Batch: 3 Total samples processed: 128 Loss: 0.18993209302425385
# Train Epoch: 42 Batch: 0 Total samples processed: 32 Loss: 0.1759641468524933
# Train Epoch: 42 Batch: 1 Total samples processed: 64 Loss: 0.17623037099838257
# Train Epoch: 42 Batch: 2 Total samples processed: 96 Loss: 0.17546296119689941
# Train Epoch: 42 Batch: 3 Total samples processed: 128 Loss: 0.17149291932582855
# Train Epoch: 43 Batch: 0 Total samples processed: 32 Loss: 0.17307332158088684
# Train Epoch: 43 Batch: 1 Total samples processed: 64 Loss: 0.1710352599620819
# Train Epoch: 43 Batch: 2 Total samples processed: 96 Loss: 0.17405304312705994
# Train Epoch: 43 Batch: 3 Total samples processed: 128 Loss: 0.17017197608947754
# Train Epoch: 44 Batch: 0 Total samples processed: 32 Loss: 0.17143699526786804
# Train Epoch: 44 Batch: 1 Total samples processed: 64 Loss: 0.17484012246131897
# Train Epoch: 44 Batch: 2 Total samples processed: 96 Loss: 0.1755085587501526
# Train Epoch: 44 Batch: 3 Total samples processed: 128 Loss: 0.16043439507484436
# Train Epoch: 45 Batch: 0 Total samples processed: 32 Loss: 0.17128080129623413
# Train Epoch: 45 Batch: 1 Total samples processed: 64 Loss: 0.1686895489692688
# Train Epoch: 45 Batch: 2 Total samples processed: 96 Loss: 0.1696184128522873
# Train Epoch: 45 Batch: 3 Total samples processed: 128 Loss: 0.17276553809642792
# Train Epoch: 46 Batch: 0 Total samples processed: 32 Loss: 0.16709408164024353
# Train Epoch: 46 Batch: 1 Total samples processed: 64 Loss: 0.1664111465215683
# Train Epoch: 46 Batch: 2 Total samples processed: 96 Loss: 0.1658647507429123
# Train Epoch: 46 Batch: 3 Total samples processed: 128 Loss: 0.17480948567390442
# Train Epoch: 47 Batch: 0 Total samples processed: 32 Loss: 0.16407746076583862
# Train Epoch: 47 Batch: 1 Total samples processed: 64 Loss: 0.16923874616622925
# Train Epoch: 47 Batch: 2 Total samples processed: 96 Loss: 0.1627011001110077
# Train Epoch: 47 Batch: 3 Total samples processed: 128 Loss: 0.1539892703294754
# Train Epoch: 48 Batch: 0 Total samples processed: 32 Loss: 0.1645570993423462
# Train Epoch: 48 Batch: 1 Total samples processed: 64 Loss: 0.1632610261440277
# Train Epoch: 48 Batch: 2 Total samples processed: 96 Loss: 0.16109612584114075
# Train Epoch: 48 Batch: 3 Total samples processed: 128 Loss: 0.17804588377475739
# Train Epoch: 49 Batch: 0 Total samples processed: 32 Loss: 0.16743150353431702
# Train Epoch: 49 Batch: 1 Total samples processed: 64 Loss: 0.16297805309295654
# Train Epoch: 49 Batch: 2 Total samples processed: 96 Loss: 0.1568244993686676
# Train Epoch: 49 Batch: 3 Total samples processed: 128 Loss: 0.14969147741794586
# Train Epoch: 50 Batch: 0 Total samples processed: 32 Loss: 0.16395412385463715
# Train Epoch: 50 Batch: 1 Total samples processed: 64 Loss: 0.1601715087890625
# Train Epoch: 50 Batch: 2 Total samples processed: 96 Loss: 0.15843358635902405
# Train Epoch: 50 Batch: 3 Total samples processed: 128 Loss: 0.17184588313102722
# Train Epoch: 51 Batch: 0 Total samples processed: 32 Loss: 0.16120296716690063
# Train Epoch: 51 Batch: 1 Total samples processed: 64 Loss: 0.15854887664318085
# Train Epoch: 51 Batch: 2 Total samples processed: 96 Loss: 0.15726402401924133
# Train Epoch: 51 Batch: 3 Total samples processed: 128 Loss: 0.1669747531414032
# Train Epoch: 52 Batch: 0 Total samples processed: 32 Loss: 0.1614578366279602
# Train Epoch: 52 Batch: 1 Total samples processed: 64 Loss: 0.15492311120033264
# Train Epoch: 52 Batch: 2 Total samples processed: 96 Loss: 0.1545461118221283
# Train Epoch: 52 Batch: 3 Total samples processed: 128 Loss: 0.16711311042308807
# Train Epoch: 53 Batch: 0 Total samples processed: 32 Loss: 0.15272372961044312
# Train Epoch: 53 Batch: 1 Total samples processed: 64 Loss: 0.15453892946243286
# Train Epoch: 53 Batch: 2 Total samples processed: 96 Loss: 0.15367883443832397
# Train Epoch: 53 Batch: 3 Total samples processed: 128 Loss: 0.16720566153526306
# Train Epoch: 54 Batch: 0 Total samples processed: 32 Loss: 0.1525459587574005
# Train Epoch: 54 Batch: 1 Total samples processed: 64 Loss: 0.1510351300239563
# Train Epoch: 54 Batch: 2 Total samples processed: 96 Loss: 0.15092632174491882
# Train Epoch: 54 Batch: 3 Total samples processed: 128 Loss: 0.15575885772705078
# Train Epoch: 55 Batch: 0 Total samples processed: 32 Loss: 0.1503477841615677
# Train Epoch: 55 Batch: 1 Total samples processed: 64 Loss: 0.1566712111234665
# Train Epoch: 55 Batch: 2 Total samples processed: 96 Loss: 0.1459963172674179
# Train Epoch: 55 Batch: 3 Total samples processed: 128 Loss: 0.15921729803085327
# Train Epoch: 56 Batch: 0 Total samples processed: 32 Loss: 0.14455413818359375
# Train Epoch: 56 Batch: 1 Total samples processed: 64 Loss: 0.1523987352848053
# Train Epoch: 56 Batch: 2 Total samples processed: 96 Loss: 0.150140181183815
# Train Epoch: 56 Batch: 3 Total samples processed: 128 Loss: 0.1453479379415512
# Train Epoch: 57 Batch: 0 Total samples processed: 32 Loss: 0.1482349932193756
# Train Epoch: 57 Batch: 1 Total samples processed: 64 Loss: 0.16342836618423462
# Train Epoch: 57 Batch: 2 Total samples processed: 96 Loss: 0.1540515273809433
# Train Epoch: 57 Batch: 3 Total samples processed: 128 Loss: 0.15499840676784515
# Train Epoch: 58 Batch: 0 Total samples processed: 32 Loss: 0.1583128273487091
# Train Epoch: 58 Batch: 1 Total samples processed: 64 Loss: 0.15292103588581085
# Train Epoch: 58 Batch: 2 Total samples processed: 96 Loss: 0.15497615933418274
# Train Epoch: 58 Batch: 3 Total samples processed: 128 Loss: 0.1474752426147461
# Train Epoch: 59 Batch: 0 Total samples processed: 32 Loss: 0.14949387311935425
# Train Epoch: 59 Batch: 1 Total samples processed: 64 Loss: 0.15346571803092957
# Train Epoch: 59 Batch: 2 Total samples processed: 96 Loss: 0.1525554358959198
# Train Epoch: 59 Batch: 3 Total samples processed: 128 Loss: 0.15235626697540283
# Train Epoch: 60 Batch: 0 Total samples processed: 32 Loss: 0.14988750219345093
# Train Epoch: 60 Batch: 1 Total samples processed: 64 Loss: 0.152502179145813
# Train Epoch: 60 Batch: 2 Total samples processed: 96 Loss: 0.14604616165161133
# Train Epoch: 60 Batch: 3 Total samples processed: 128 Loss: 0.17351582646369934
# Train Epoch: 61 Batch: 0 Total samples processed: 32 Loss: 0.151328906416893
# Train Epoch: 61 Batch: 1 Total samples processed: 64 Loss: 0.15326017141342163
# Train Epoch: 61 Batch: 2 Total samples processed: 96 Loss: 0.14498761296272278
# Train Epoch: 61 Batch: 3 Total samples processed: 128 Loss: 0.14313945174217224
# Train Epoch: 62 Batch: 0 Total samples processed: 32 Loss: 0.15174201130867004
# Train Epoch: 62 Batch: 1 Total samples processed: 64 Loss: 0.14465802907943726
# Train Epoch: 62 Batch: 2 Total samples processed: 96 Loss: 0.14401045441627502
# Train Epoch: 62 Batch: 3 Total samples processed: 128 Loss: 0.14381125569343567
# Train Epoch: 63 Batch: 0 Total samples processed: 32 Loss: 0.1455119401216507
# Train Epoch: 63 Batch: 1 Total samples processed: 64 Loss: 0.14090892672538757
# Train Epoch: 63 Batch: 2 Total samples processed: 96 Loss: 0.14246103167533875
# Train Epoch: 63 Batch: 3 Total samples processed: 128 Loss: 0.1499442309141159
# Train Epoch: 64 Batch: 0 Total samples processed: 32 Loss: 0.1423182189464569
# Train Epoch: 64 Batch: 1 Total samples processed: 64 Loss: 0.1379610002040863
# Train Epoch: 64 Batch: 2 Total samples processed: 96 Loss: 0.14556348323822021
# Train Epoch: 64 Batch: 3 Total samples processed: 128 Loss: 0.16440212726593018
# Train Epoch: 65 Batch: 0 Total samples processed: 32 Loss: 0.14325137436389923
# Train Epoch: 65 Batch: 1 Total samples processed: 64 Loss: 0.14423158764839172
# Train Epoch: 65 Batch: 2 Total samples processed: 96 Loss: 0.135112002491951
# Train Epoch: 65 Batch: 3 Total samples processed: 128 Loss: 0.15317636728286743
# Train Epoch: 66 Batch: 0 Total samples processed: 32 Loss: 0.13712799549102783
# Train Epoch: 66 Batch: 1 Total samples processed: 64 Loss: 0.13764256238937378
# Train Epoch: 66 Batch: 2 Total samples processed: 96 Loss: 0.1383766382932663
# Train Epoch: 66 Batch: 3 Total samples processed: 128 Loss: 0.14787833392620087
# Train Epoch: 67 Batch: 0 Total samples processed: 32 Loss: 0.14284712076187134
# Train Epoch: 67 Batch: 1 Total samples processed: 64 Loss: 0.14353929460048676
# Train Epoch: 67 Batch: 2 Total samples processed: 96 Loss: 0.13692432641983032
# Train Epoch: 67 Batch: 3 Total samples processed: 128 Loss: 0.14252692461013794
# Train Epoch: 68 Batch: 0 Total samples processed: 32 Loss: 0.14003540575504303
# Train Epoch: 68 Batch: 1 Total samples processed: 64 Loss: 0.13895058631896973
# Train Epoch: 68 Batch: 2 Total samples processed: 96 Loss: 0.13495054841041565
# Train Epoch: 68 Batch: 3 Total samples processed: 128 Loss: 0.15963563323020935
# Train Epoch: 69 Batch: 0 Total samples processed: 32 Loss: 0.14085420966148376
# Train Epoch: 69 Batch: 1 Total samples processed: 64 Loss: 0.14161105453968048
# Train Epoch: 69 Batch: 2 Total samples processed: 96 Loss: 0.14345583319664001
# Train Epoch: 69 Batch: 3 Total samples processed: 128 Loss: 0.14876198768615723
# Train Epoch: 70 Batch: 0 Total samples processed: 32 Loss: 0.14238913357257843
# Train Epoch: 70 Batch: 1 Total samples processed: 64 Loss: 0.14182710647583008
# Train Epoch: 70 Batch: 2 Total samples processed: 96 Loss: 0.1394377052783966
# Train Epoch: 70 Batch: 3 Total samples processed: 128 Loss: 0.13377518951892853
# Train Epoch: 71 Batch: 0 Total samples processed: 32 Loss: 0.135575532913208
# Train Epoch: 71 Batch: 1 Total samples processed: 64 Loss: 0.13940100371837616
# Train Epoch: 71 Batch: 2 Total samples processed: 96 Loss: 0.14136634767055511
# Train Epoch: 71 Batch: 3 Total samples processed: 128 Loss: 0.12745776772499084
# Train Epoch: 72 Batch: 0 Total samples processed: 32 Loss: 0.1353532373905182
# Train Epoch: 72 Batch: 1 Total samples processed: 64 Loss: 0.14105194807052612
# Train Epoch: 72 Batch: 2 Total samples processed: 96 Loss: 0.1310730129480362
# Train Epoch: 72 Batch: 3 Total samples processed: 128 Loss: 0.15388967096805573
# Train Epoch: 73 Batch: 0 Total samples processed: 32 Loss: 0.13384632766246796
# Train Epoch: 73 Batch: 1 Total samples processed: 64 Loss: 0.1304905116558075
# Train Epoch: 73 Batch: 2 Total samples processed: 96 Loss: 0.13516269624233246
# Train Epoch: 73 Batch: 3 Total samples processed: 128 Loss: 0.1278802901506424
# Train Epoch: 74 Batch: 0 Total samples processed: 32 Loss: 0.132224440574646
# Train Epoch: 74 Batch: 1 Total samples processed: 64 Loss: 0.13582727313041687
# Train Epoch: 74 Batch: 2 Total samples processed: 96 Loss: 0.12421499937772751
# Train Epoch: 74 Batch: 3 Total samples processed: 128 Loss: 0.12265383452177048
# Train Epoch: 75 Batch: 0 Total samples processed: 32 Loss: 0.12786954641342163
# Train Epoch: 75 Batch: 1 Total samples processed: 64 Loss: 0.13144437968730927
# Train Epoch: 75 Batch: 2 Total samples processed: 96 Loss: 0.12712641060352325
# Train Epoch: 75 Batch: 3 Total samples processed: 128 Loss: 0.11967629194259644
# Train Epoch: 76 Batch: 0 Total samples processed: 32 Loss: 0.1265815943479538
# Train Epoch: 76 Batch: 1 Total samples processed: 64 Loss: 0.12872491776943207
# Train Epoch: 76 Batch: 2 Total samples processed: 96 Loss: 0.13178595900535583
# Train Epoch: 76 Batch: 3 Total samples processed: 128 Loss: 0.11640810966491699
# Train Epoch: 77 Batch: 0 Total samples processed: 32 Loss: 0.13399651646614075
# Train Epoch: 77 Batch: 1 Total samples processed: 64 Loss: 0.12565156817436218
# Train Epoch: 77 Batch: 2 Total samples processed: 96 Loss: 0.1242230236530304
# Train Epoch: 77 Batch: 3 Total samples processed: 128 Loss: 0.12240833789110184
# Train Epoch: 78 Batch: 0 Total samples processed: 32 Loss: 0.12237577140331268
# Train Epoch: 78 Batch: 1 Total samples processed: 64 Loss: 0.12491920590400696
# Train Epoch: 78 Batch: 2 Total samples processed: 96 Loss: 0.13149909675121307
# Train Epoch: 78 Batch: 3 Total samples processed: 128 Loss: 0.14247234165668488
# Train Epoch: 79 Batch: 0 Total samples processed: 32 Loss: 0.12446001172065735
# Train Epoch: 79 Batch: 1 Total samples processed: 64 Loss: 0.1239168792963028
# Train Epoch: 79 Batch: 2 Total samples processed: 96 Loss: 0.12497138231992722
# Train Epoch: 79 Batch: 3 Total samples processed: 128 Loss: 0.1398170292377472
# Train Epoch: 80 Batch: 0 Total samples processed: 32 Loss: 0.12496592849493027
# Train Epoch: 80 Batch: 1 Total samples processed: 64 Loss: 0.12555038928985596
# Train Epoch: 80 Batch: 2 Total samples processed: 96 Loss: 0.12241925299167633
# Train Epoch: 80 Batch: 3 Total samples processed: 128 Loss: 0.11489704251289368
# Train Epoch: 81 Batch: 0 Total samples processed: 32 Loss: 0.12140040099620819
# Train Epoch: 81 Batch: 1 Total samples processed: 64 Loss: 0.11873947083950043
# Train Epoch: 81 Batch: 2 Total samples processed: 96 Loss: 0.12502801418304443
# Train Epoch: 81 Batch: 3 Total samples processed: 128 Loss: 0.12740501761436462
# Train Epoch: 82 Batch: 0 Total samples processed: 32 Loss: 0.11782016605138779
# Train Epoch: 82 Batch: 1 Total samples processed: 64 Loss: 0.11642470210790634
# Train Epoch: 82 Batch: 2 Total samples processed: 96 Loss: 0.12627100944519043
# Train Epoch: 82 Batch: 3 Total samples processed: 128 Loss: 0.11742181330919266
# Train Epoch: 83 Batch: 0 Total samples processed: 32 Loss: 0.12482434511184692
# Train Epoch: 83 Batch: 1 Total samples processed: 64 Loss: 0.12075814604759216
# Train Epoch: 83 Batch: 2 Total samples processed: 96 Loss: 0.11680980026721954
# Train Epoch: 83 Batch: 3 Total samples processed: 128 Loss: 0.10574930906295776
# Train Epoch: 84 Batch: 0 Total samples processed: 32 Loss: 0.12350046634674072
# Train Epoch: 84 Batch: 1 Total samples processed: 64 Loss: 0.11437423527240753
# Train Epoch: 84 Batch: 2 Total samples processed: 96 Loss: 0.11535851657390594
# Train Epoch: 84 Batch: 3 Total samples processed: 128 Loss: 0.1353163719177246
# Train Epoch: 85 Batch: 0 Total samples processed: 32 Loss: 0.11687542498111725
# Train Epoch: 85 Batch: 1 Total samples processed: 64 Loss: 0.12422831356525421
# Train Epoch: 85 Batch: 2 Total samples processed: 96 Loss: 0.1187083050608635
# Train Epoch: 85 Batch: 3 Total samples processed: 128 Loss: 0.11193612217903137
# Train Epoch: 86 Batch: 0 Total samples processed: 32 Loss: 0.11265608668327332
# Train Epoch: 86 Batch: 1 Total samples processed: 64 Loss: 0.12125733494758606
# Train Epoch: 86 Batch: 2 Total samples processed: 96 Loss: 0.11580103635787964
# Train Epoch: 86 Batch: 3 Total samples processed: 128 Loss: 0.1100759506225586
# Train Epoch: 87 Batch: 0 Total samples processed: 32 Loss: 0.11356721818447113
# Train Epoch: 87 Batch: 1 Total samples processed: 64 Loss: 0.11630778014659882
# Train Epoch: 87 Batch: 2 Total samples processed: 96 Loss: 0.11529834568500519
# Train Epoch: 87 Batch: 3 Total samples processed: 128 Loss: 0.10588356852531433
# Train Epoch: 88 Batch: 0 Total samples processed: 32 Loss: 0.10748187452554703
# Train Epoch: 88 Batch: 1 Total samples processed: 64 Loss: 0.1130584180355072
# Train Epoch: 88 Batch: 2 Total samples processed: 96 Loss: 0.11869598180055618
# Train Epoch: 88 Batch: 3 Total samples processed: 128 Loss: 0.1036224514245987
# Train Epoch: 89 Batch: 0 Total samples processed: 32 Loss: 0.11495548486709595
# Train Epoch: 89 Batch: 1 Total samples processed: 64 Loss: 0.11103262007236481
# Train Epoch: 89 Batch: 2 Total samples processed: 96 Loss: 0.10923512279987335
# Train Epoch: 89 Batch: 3 Total samples processed: 128 Loss: 0.11112602800130844
# Train Epoch: 90 Batch: 0 Total samples processed: 32 Loss: 0.11538635194301605
# Train Epoch: 90 Batch: 1 Total samples processed: 64 Loss: 0.11365041136741638
# Train Epoch: 90 Batch: 2 Total samples processed: 96 Loss: 0.1041843369603157
# Train Epoch: 90 Batch: 3 Total samples processed: 128 Loss: 0.13653452694416046
# Train Epoch: 91 Batch: 0 Total samples processed: 32 Loss: 0.10064387321472168
# Train Epoch: 91 Batch: 1 Total samples processed: 64 Loss: 0.10918565094470978
# Train Epoch: 91 Batch: 2 Total samples processed: 96 Loss: 0.11083982139825821
# Train Epoch: 91 Batch: 3 Total samples processed: 128 Loss: 0.1201825737953186
# Train Epoch: 92 Batch: 0 Total samples processed: 32 Loss: 0.10791175067424774
# Train Epoch: 92 Batch: 1 Total samples processed: 64 Loss: 0.10897842049598694
# Train Epoch: 92 Batch: 2 Total samples processed: 96 Loss: 0.10479213297367096
# Train Epoch: 92 Batch: 3 Total samples processed: 128 Loss: 0.11079420894384384
# Train Epoch: 93 Batch: 0 Total samples processed: 32 Loss: 0.10687180608510971
# Train Epoch: 93 Batch: 1 Total samples processed: 64 Loss: 0.09909486025571823
# Train Epoch: 93 Batch: 2 Total samples processed: 96 Loss: 0.11029231548309326
# Train Epoch: 93 Batch: 3 Total samples processed: 128 Loss: 0.09935197979211807
# Train Epoch: 94 Batch: 0 Total samples processed: 32 Loss: 0.1010279506444931
# Train Epoch: 94 Batch: 1 Total samples processed: 64 Loss: 0.10174481570720673
# Train Epoch: 94 Batch: 2 Total samples processed: 96 Loss: 0.10879983007907867
# Train Epoch: 94 Batch: 3 Total samples processed: 128 Loss: 0.11717052757740021
# Train Epoch: 95 Batch: 0 Total samples processed: 32 Loss: 0.10473836958408356
# Train Epoch: 95 Batch: 1 Total samples processed: 64 Loss: 0.09654513001441956
# Train Epoch: 95 Batch: 2 Total samples processed: 96 Loss: 0.11686646193265915
# Train Epoch: 95 Batch: 3 Total samples processed: 128 Loss: 0.11509031057357788
# Train Epoch: 96 Batch: 0 Total samples processed: 32 Loss: 0.11176840960979462
# Train Epoch: 96 Batch: 1 Total samples processed: 64 Loss: 0.10895148664712906
# Train Epoch: 96 Batch: 2 Total samples processed: 96 Loss: 0.1073560118675232
# Train Epoch: 96 Batch: 3 Total samples processed: 128 Loss: 0.09572096168994904
# Train Epoch: 97 Batch: 0 Total samples processed: 32 Loss: 0.11123039573431015
# Train Epoch: 97 Batch: 1 Total samples processed: 64 Loss: 0.10339541733264923
# Train Epoch: 97 Batch: 2 Total samples processed: 96 Loss: 0.10087158530950546
# Train Epoch: 97 Batch: 3 Total samples processed: 128 Loss: 0.09722250699996948
# Train Epoch: 98 Batch: 0 Total samples processed: 32 Loss: 0.1008925512433052
# Train Epoch: 98 Batch: 1 Total samples processed: 64 Loss: 0.10576249659061432
# Train Epoch: 98 Batch: 2 Total samples processed: 96 Loss: 0.10475387424230576
# Train Epoch: 98 Batch: 3 Total samples processed: 128 Loss: 0.10328581929206848
# Train Epoch: 99 Batch: 0 Total samples processed: 32 Loss: 0.10284048318862915
# Train Epoch: 99 Batch: 1 Total samples processed: 64 Loss: 0.09952010214328766
# Train Epoch: 99 Batch: 2 Total samples processed: 96 Loss: 0.10065767168998718
# Train Epoch: 99 Batch: 3 Total samples processed: 128 Loss: 0.11812447011470795
# Train Epoch: 100 Batch: 0 Total samples processed: 32 Loss: 0.10218626260757446
# Train Epoch: 100 Batch: 1 Total samples processed: 64 Loss: 0.09962140768766403
# Train Epoch: 100 Batch: 2 Total samples processed: 96 Loss: 0.10716541856527328
# Train Epoch: 100 Batch: 3 Total samples processed: 128 Loss: 0.1019701212644577
# Train Epoch: 101 Batch: 0 Total samples processed: 32 Loss: 0.09342912584543228
# Train Epoch: 101 Batch: 1 Total samples processed: 64 Loss: 0.10186151415109634
# Train Epoch: 101 Batch: 2 Total samples processed: 96 Loss: 0.10650327801704407
# Train Epoch: 101 Batch: 3 Total samples processed: 128 Loss: 0.11318640410900116
# Train Epoch: 102 Batch: 0 Total samples processed: 32 Loss: 0.09944432228803635
# Train Epoch: 102 Batch: 1 Total samples processed: 64 Loss: 0.10114353150129318
# Train Epoch: 102 Batch: 2 Total samples processed: 96 Loss: 0.10578419268131256
# Train Epoch: 102 Batch: 3 Total samples processed: 128 Loss: 0.09904786199331284
# Train Epoch: 103 Batch: 0 Total samples processed: 32 Loss: 0.09759458899497986
# Train Epoch: 103 Batch: 1 Total samples processed: 64 Loss: 0.10209038108587265
# Train Epoch: 103 Batch: 2 Total samples processed: 96 Loss: 0.10393250733613968
# Train Epoch: 103 Batch: 3 Total samples processed: 128 Loss: 0.08861032128334045
# Train Epoch: 104 Batch: 0 Total samples processed: 32 Loss: 0.10219758749008179
# Train Epoch: 104 Batch: 1 Total samples processed: 64 Loss: 0.10119703412055969
# Train Epoch: 104 Batch: 2 Total samples processed: 96 Loss: 0.09509295225143433
# Train Epoch: 104 Batch: 3 Total samples processed: 128 Loss: 0.11144500970840454
# Train Epoch: 105 Batch: 0 Total samples processed: 32 Loss: 0.09976431727409363
# Train Epoch: 105 Batch: 1 Total samples processed: 64 Loss: 0.1011417955160141
# Train Epoch: 105 Batch: 2 Total samples processed: 96 Loss: 0.10188834369182587
# Train Epoch: 105 Batch: 3 Total samples processed: 128 Loss: 0.09039623290300369
# Train Epoch: 106 Batch: 0 Total samples processed: 32 Loss: 0.09787962585687637
# Train Epoch: 106 Batch: 1 Total samples processed: 64 Loss: 0.09476993978023529
# Train Epoch: 106 Batch: 2 Total samples processed: 96 Loss: 0.10378614813089371
# Train Epoch: 106 Batch: 3 Total samples processed: 128 Loss: 0.10262240469455719
# Train Epoch: 107 Batch: 0 Total samples processed: 32 Loss: 0.10308443009853363
# Train Epoch: 107 Batch: 1 Total samples processed: 64 Loss: 0.09513148665428162
# Train Epoch: 107 Batch: 2 Total samples processed: 96 Loss: 0.09938108921051025
# Train Epoch: 107 Batch: 3 Total samples processed: 128 Loss: 0.09891736507415771
# Train Epoch: 108 Batch: 0 Total samples processed: 32 Loss: 0.09863585233688354
# Train Epoch: 108 Batch: 1 Total samples processed: 64 Loss: 0.09330826997756958
# Train Epoch: 108 Batch: 2 Total samples processed: 96 Loss: 0.10079368948936462
# Train Epoch: 108 Batch: 3 Total samples processed: 128 Loss: 0.08078800141811371
# Train Epoch: 109 Batch: 0 Total samples processed: 32 Loss: 0.09475703537464142
# Train Epoch: 109 Batch: 1 Total samples processed: 64 Loss: 0.10016358643770218
# Train Epoch: 109 Batch: 2 Total samples processed: 96 Loss: 0.09316381812095642
# Train Epoch: 109 Batch: 3 Total samples processed: 128 Loss: 0.08136714994907379
# Train Epoch: 110 Batch: 0 Total samples processed: 32 Loss: 0.09409080445766449
# Train Epoch: 110 Batch: 1 Total samples processed: 64 Loss: 0.09476806968450546
# Train Epoch: 110 Batch: 2 Total samples processed: 96 Loss: 0.09575290977954865
# Train Epoch: 110 Batch: 3 Total samples processed: 128 Loss: 0.08304314315319061
# Train Epoch: 111 Batch: 0 Total samples processed: 32 Loss: 0.09878477454185486
# Train Epoch: 111 Batch: 1 Total samples processed: 64 Loss: 0.08953474462032318
# Train Epoch: 111 Batch: 2 Total samples processed: 96 Loss: 0.0898711234331131
# Train Epoch: 111 Batch: 3 Total samples processed: 128 Loss: 0.10706060379743576
# Train Epoch: 112 Batch: 0 Total samples processed: 32 Loss: 0.08840050548315048
# Train Epoch: 112 Batch: 1 Total samples processed: 64 Loss: 0.09618182480335236
# Train Epoch: 112 Batch: 2 Total samples processed: 96 Loss: 0.10706472396850586
# Train Epoch: 112 Batch: 3 Total samples processed: 128 Loss: 0.11743299663066864
# Train Epoch: 113 Batch: 0 Total samples processed: 32 Loss: 0.0963859111070633
# Train Epoch: 113 Batch: 1 Total samples processed: 64 Loss: 0.10717570781707764
# Train Epoch: 113 Batch: 2 Total samples processed: 96 Loss: 0.0968397706747055
# Train Epoch: 113 Batch: 3 Total samples processed: 128 Loss: 0.08563476800918579
# Train Epoch: 114 Batch: 0 Total samples processed: 32 Loss: 0.09125445783138275
# Train Epoch: 114 Batch: 1 Total samples processed: 64 Loss: 0.0957673043012619
# Train Epoch: 114 Batch: 2 Total samples processed: 96 Loss: 0.09559949487447739
# Train Epoch: 114 Batch: 3 Total samples processed: 128 Loss: 0.09812300652265549
# Train Epoch: 115 Batch: 0 Total samples processed: 32 Loss: 0.09117993712425232
# Train Epoch: 115 Batch: 1 Total samples processed: 64 Loss: 0.10084167122840881
# Train Epoch: 115 Batch: 2 Total samples processed: 96 Loss: 0.08637110888957977
# Train Epoch: 115 Batch: 3 Total samples processed: 128 Loss: 0.09938465803861618
# Train Epoch: 116 Batch: 0 Total samples processed: 32 Loss: 0.09438939392566681
# Train Epoch: 116 Batch: 1 Total samples processed: 64 Loss: 0.09113992005586624
# Train Epoch: 116 Batch: 2 Total samples processed: 96 Loss: 0.09218667447566986
# Train Epoch: 116 Batch: 3 Total samples processed: 128 Loss: 0.09031784534454346
# Train Epoch: 117 Batch: 0 Total samples processed: 32 Loss: 0.09009183943271637
# Train Epoch: 117 Batch: 1 Total samples processed: 64 Loss: 0.09218171238899231
# Train Epoch: 117 Batch: 2 Total samples processed: 96 Loss: 0.09239057451486588
# Train Epoch: 117 Batch: 3 Total samples processed: 128 Loss: 0.11837097257375717
# Train Epoch: 118 Batch: 0 Total samples processed: 32 Loss: 0.09824224561452866
# Train Epoch: 118 Batch: 1 Total samples processed: 64 Loss: 0.09244456887245178
# Train Epoch: 118 Batch: 2 Total samples processed: 96 Loss: 0.09124433249235153
# Train Epoch: 118 Batch: 3 Total samples processed: 128 Loss: 0.10135487467050552
# Train Epoch: 119 Batch: 0 Total samples processed: 32 Loss: 0.08887390792369843
# Train Epoch: 119 Batch: 1 Total samples processed: 64 Loss: 0.09294193983078003
# Train Epoch: 119 Batch: 2 Total samples processed: 96 Loss: 0.09549188613891602
# Train Epoch: 119 Batch: 3 Total samples processed: 128 Loss: 0.08644917607307434
# Train Epoch: 120 Batch: 0 Total samples processed: 32 Loss: 0.09361757338047028
# Train Epoch: 120 Batch: 1 Total samples processed: 64 Loss: 0.08875621110200882
# Train Epoch: 120 Batch: 2 Total samples processed: 96 Loss: 0.0944163054227829
# Train Epoch: 120 Batch: 3 Total samples processed: 128 Loss: 0.07187134027481079
# Train Epoch: 121 Batch: 0 Total samples processed: 32 Loss: 0.08977337181568146
# Train Epoch: 121 Batch: 1 Total samples processed: 64 Loss: 0.08555397391319275
# Train Epoch: 121 Batch: 2 Total samples processed: 96 Loss: 0.0870128646492958
# Train Epoch: 121 Batch: 3 Total samples processed: 128 Loss: 0.0970565676689148
# Train Epoch: 122 Batch: 0 Total samples processed: 32 Loss: 0.08333202451467514
# Train Epoch: 122 Batch: 1 Total samples processed: 64 Loss: 0.08825688064098358
# Train Epoch: 122 Batch: 2 Total samples processed: 96 Loss: 0.08867213129997253
# Train Epoch: 122 Batch: 3 Total samples processed: 128 Loss: 0.07960195094347
# Train Epoch: 123 Batch: 0 Total samples processed: 32 Loss: 0.08572680503129959
# Train Epoch: 123 Batch: 1 Total samples processed: 64 Loss: 0.07951740175485611
# Train Epoch: 123 Batch: 2 Total samples processed: 96 Loss: 0.08693934231996536
# Train Epoch: 123 Batch: 3 Total samples processed: 128 Loss: 0.07710260152816772
# Train Epoch: 124 Batch: 0 Total samples processed: 32 Loss: 0.0872408002614975
# Train Epoch: 124 Batch: 1 Total samples processed: 64 Loss: 0.08002651482820511
# Train Epoch: 124 Batch: 2 Total samples processed: 96 Loss: 0.08284305036067963
# Train Epoch: 124 Batch: 3 Total samples processed: 128 Loss: 0.08939995616674423
# Train Epoch: 125 Batch: 0 Total samples processed: 32 Loss: 0.08544658124446869
# Train Epoch: 125 Batch: 1 Total samples processed: 64 Loss: 0.07931779325008392
# Train Epoch: 125 Batch: 2 Total samples processed: 96 Loss: 0.08197751641273499
# Train Epoch: 125 Batch: 3 Total samples processed: 128 Loss: 0.07982397079467773
# Train Epoch: 126 Batch: 0 Total samples processed: 32 Loss: 0.08496358245611191
# Train Epoch: 126 Batch: 1 Total samples processed: 64 Loss: 0.08041323721408844
# Train Epoch: 126 Batch: 2 Total samples processed: 96 Loss: 0.07994148880243301
# Train Epoch: 126 Batch: 3 Total samples processed: 128 Loss: 0.07216896861791611
# Train Epoch: 127 Batch: 0 Total samples processed: 32 Loss: 0.08075723052024841
# Train Epoch: 127 Batch: 1 Total samples processed: 64 Loss: 0.07783070206642151
# Train Epoch: 127 Batch: 2 Total samples processed: 96 Loss: 0.07876673340797424
# Train Epoch: 127 Batch: 3 Total samples processed: 128 Loss: 0.07959384471178055
# Train Epoch: 128 Batch: 0 Total samples processed: 32 Loss: 0.08185248076915741
# Train Epoch: 128 Batch: 1 Total samples processed: 64 Loss: 0.07478716969490051
# Train Epoch: 128 Batch: 2 Total samples processed: 96 Loss: 0.07956934720277786
# Train Epoch: 128 Batch: 3 Total samples processed: 128 Loss: 0.07721994072198868
# Train Epoch: 129 Batch: 0 Total samples processed: 32 Loss: 0.07807020097970963
# Train Epoch: 129 Batch: 1 Total samples processed: 64 Loss: 0.07537668943405151
# Train Epoch: 129 Batch: 2 Total samples processed: 96 Loss: 0.0833527147769928
# Train Epoch: 129 Batch: 3 Total samples processed: 128 Loss: 0.08064194023609161
# Train Epoch: 130 Batch: 0 Total samples processed: 32 Loss: 0.07894319295883179
# Train Epoch: 130 Batch: 1 Total samples processed: 64 Loss: 0.08125315606594086
# Train Epoch: 130 Batch: 2 Total samples processed: 96 Loss: 0.07883037626743317
# Train Epoch: 130 Batch: 3 Total samples processed: 128 Loss: 0.07141769677400589
# Train Epoch: 131 Batch: 0 Total samples processed: 32 Loss: 0.07950497418642044
# Train Epoch: 131 Batch: 1 Total samples processed: 64 Loss: 0.07500675320625305
# Train Epoch: 131 Batch: 2 Total samples processed: 96 Loss: 0.07513897866010666
# Train Epoch: 131 Batch: 3 Total samples processed: 128 Loss: 0.09581863880157471
# Train Epoch: 132 Batch: 0 Total samples processed: 32 Loss: 0.08058448880910873
# Train Epoch: 132 Batch: 1 Total samples processed: 64 Loss: 0.07832738757133484
# Train Epoch: 132 Batch: 2 Total samples processed: 96 Loss: 0.07779006659984589
# Train Epoch: 132 Batch: 3 Total samples processed: 128 Loss: 0.11140318959951401
# Train Epoch: 133 Batch: 0 Total samples processed: 32 Loss: 0.07741104811429977
# Train Epoch: 133 Batch: 1 Total samples processed: 64 Loss: 0.07818472385406494
# Train Epoch: 133 Batch: 2 Total samples processed: 96 Loss: 0.08193140476942062
# Train Epoch: 133 Batch: 3 Total samples processed: 128 Loss: 0.09826681017875671
# Train Epoch: 134 Batch: 0 Total samples processed: 32 Loss: 0.08392582088708878
# Train Epoch: 134 Batch: 1 Total samples processed: 64 Loss: 0.07511283457279205
# Train Epoch: 134 Batch: 2 Total samples processed: 96 Loss: 0.08709156513214111
# Train Epoch: 134 Batch: 3 Total samples processed: 128 Loss: 0.08989784121513367
# Train Epoch: 135 Batch: 0 Total samples processed: 32 Loss: 0.07993486523628235
# Train Epoch: 135 Batch: 1 Total samples processed: 64 Loss: 0.08196079730987549
# Train Epoch: 135 Batch: 2 Total samples processed: 96 Loss: 0.08650172501802444
# Train Epoch: 135 Batch: 3 Total samples processed: 128 Loss: 0.07144827395677567
# Train Epoch: 136 Batch: 0 Total samples processed: 32 Loss: 0.07450638711452484
# Train Epoch: 136 Batch: 1 Total samples processed: 64 Loss: 0.08399142324924469
# Train Epoch: 136 Batch: 2 Total samples processed: 96 Loss: 0.0853363499045372
# Train Epoch: 136 Batch: 3 Total samples processed: 128 Loss: 0.07059545814990997
# Train Epoch: 137 Batch: 0 Total samples processed: 32 Loss: 0.0728980004787445
# Train Epoch: 137 Batch: 1 Total samples processed: 64 Loss: 0.08327877521514893
# Train Epoch: 137 Batch: 2 Total samples processed: 96 Loss: 0.07659420371055603
# Train Epoch: 137 Batch: 3 Total samples processed: 128 Loss: 0.073170505464077
# Train Epoch: 138 Batch: 0 Total samples processed: 32 Loss: 0.07496695965528488
# Train Epoch: 138 Batch: 1 Total samples processed: 64 Loss: 0.07651190459728241
# Train Epoch: 138 Batch: 2 Total samples processed: 96 Loss: 0.08367784321308136
# Train Epoch: 138 Batch: 3 Total samples processed: 128 Loss: 0.06810545921325684
# Train Epoch: 139 Batch: 0 Total samples processed: 32 Loss: 0.08247872442007065
# Train Epoch: 139 Batch: 1 Total samples processed: 64 Loss: 0.07264631986618042
# Train Epoch: 139 Batch: 2 Total samples processed: 96 Loss: 0.07695558667182922
# Train Epoch: 139 Batch: 3 Total samples processed: 128 Loss: 0.07394179701805115
# Train Epoch: 140 Batch: 0 Total samples processed: 32 Loss: 0.08152906596660614
# Train Epoch: 140 Batch: 1 Total samples processed: 64 Loss: 0.0752197802066803
# Train Epoch: 140 Batch: 2 Total samples processed: 96 Loss: 0.06867717206478119
# Train Epoch: 140 Batch: 3 Total samples processed: 128 Loss: 0.06184648349881172
# Train Epoch: 141 Batch: 0 Total samples processed: 32 Loss: 0.07554753124713898
# Train Epoch: 141 Batch: 1 Total samples processed: 64 Loss: 0.0724480003118515
# Train Epoch: 141 Batch: 2 Total samples processed: 96 Loss: 0.0709703266620636
# Train Epoch: 141 Batch: 3 Total samples processed: 128 Loss: 0.07419760525226593
# Train Epoch: 142 Batch: 0 Total samples processed: 32 Loss: 0.0747278705239296
# Train Epoch: 142 Batch: 1 Total samples processed: 64 Loss: 0.07175047695636749
# Train Epoch: 142 Batch: 2 Total samples processed: 96 Loss: 0.07535573840141296
# Train Epoch: 142 Batch: 3 Total samples processed: 128 Loss: 0.07830624282360077
# Train Epoch: 143 Batch: 0 Total samples processed: 32 Loss: 0.07391933351755142
# Train Epoch: 143 Batch: 1 Total samples processed: 64 Loss: 0.07678763568401337
# Train Epoch: 143 Batch: 2 Total samples processed: 96 Loss: 0.06843838095664978
# Train Epoch: 143 Batch: 3 Total samples processed: 128 Loss: 0.07866835594177246
# Train Epoch: 144 Batch: 0 Total samples processed: 32 Loss: 0.07727576792240143
# Train Epoch: 144 Batch: 1 Total samples processed: 64 Loss: 0.07964414358139038
# Train Epoch: 144 Batch: 2 Total samples processed: 96 Loss: 0.07189473509788513
# Train Epoch: 144 Batch: 3 Total samples processed: 128 Loss: 0.07304218411445618
# Train Epoch: 145 Batch: 0 Total samples processed: 32 Loss: 0.06972883641719818
# Train Epoch: 145 Batch: 1 Total samples processed: 64 Loss: 0.07437676191329956
# Train Epoch: 145 Batch: 2 Total samples processed: 96 Loss: 0.07507479190826416
# Train Epoch: 145 Batch: 3 Total samples processed: 128 Loss: 0.07881638407707214
# Train Epoch: 146 Batch: 0 Total samples processed: 32 Loss: 0.07141584903001785
# Train Epoch: 146 Batch: 1 Total samples processed: 64 Loss: 0.07525204867124557
# Train Epoch: 146 Batch: 2 Total samples processed: 96 Loss: 0.07409379631280899
# Train Epoch: 146 Batch: 3 Total samples processed: 128 Loss: 0.07329230010509491
# Train Epoch: 147 Batch: 0 Total samples processed: 32 Loss: 0.0672091543674469
# Train Epoch: 147 Batch: 1 Total samples processed: 64 Loss: 0.07547613233327866
# Train Epoch: 147 Batch: 2 Total samples processed: 96 Loss: 0.07317601144313812
# Train Epoch: 147 Batch: 3 Total samples processed: 128 Loss: 0.06225096434354782
# Train Epoch: 148 Batch: 0 Total samples processed: 32 Loss: 0.07302050292491913
# Train Epoch: 148 Batch: 1 Total samples processed: 64 Loss: 0.07455767691135406
# Train Epoch: 148 Batch: 2 Total samples processed: 96 Loss: 0.06307494640350342
# Train Epoch: 148 Batch: 3 Total samples processed: 128 Loss: 0.06265104562044144
# Train Epoch: 149 Batch: 0 Total samples processed: 32 Loss: 0.0733797699213028
# Train Epoch: 149 Batch: 1 Total samples processed: 64 Loss: 0.0698220506310463
# Train Epoch: 149 Batch: 2 Total samples processed: 96 Loss: 0.06597405672073364
# Train Epoch: 149 Batch: 3 Total samples processed: 128 Loss: 0.05888708680868149
# Train Epoch: 150 Batch: 0 Total samples processed: 32 Loss: 0.06952084600925446
# Train Epoch: 150 Batch: 1 Total samples processed: 64 Loss: 0.06863971054553986
# Train Epoch: 150 Batch: 2 Total samples processed: 96 Loss: 0.060697074979543686
# Train Epoch: 150 Batch: 3 Total samples processed: 128 Loss: 0.07669773697853088
# Train Epoch: 151 Batch: 0 Total samples processed: 32 Loss: 0.06348558515310287
# Train Epoch: 151 Batch: 1 Total samples processed: 64 Loss: 0.06406493484973907
# Train Epoch: 151 Batch: 2 Total samples processed: 96 Loss: 0.07156109809875488
# Train Epoch: 151 Batch: 3 Total samples processed: 128 Loss: 0.07136845588684082
# Train Epoch: 152 Batch: 0 Total samples processed: 32 Loss: 0.0693737119436264
# Train Epoch: 152 Batch: 1 Total samples processed: 64 Loss: 0.06304389983415604
# Train Epoch: 152 Batch: 2 Total samples processed: 96 Loss: 0.07015827298164368
# Train Epoch: 152 Batch: 3 Total samples processed: 128 Loss: 0.059931591153144836
# Train Epoch: 153 Batch: 0 Total samples processed: 32 Loss: 0.06380023062229156
# Train Epoch: 153 Batch: 1 Total samples processed: 64 Loss: 0.06785192340612411
# Train Epoch: 153 Batch: 2 Total samples processed: 96 Loss: 0.07513546943664551
# Train Epoch: 153 Batch: 3 Total samples processed: 128 Loss: 0.0646149143576622
# Train Epoch: 154 Batch: 0 Total samples processed: 32 Loss: 0.06675253808498383
# Train Epoch: 154 Batch: 1 Total samples processed: 64 Loss: 0.07290403544902802
# Train Epoch: 154 Batch: 2 Total samples processed: 96 Loss: 0.07606598734855652
# Train Epoch: 154 Batch: 3 Total samples processed: 128 Loss: 0.06665650010108948
# Train Epoch: 155 Batch: 0 Total samples processed: 32 Loss: 0.06904460489749908
# Train Epoch: 155 Batch: 1 Total samples processed: 64 Loss: 0.06812325119972229
# Train Epoch: 155 Batch: 2 Total samples processed: 96 Loss: 0.06870321929454803
# Train Epoch: 155 Batch: 3 Total samples processed: 128 Loss: 0.07903499156236649
# Train Epoch: 156 Batch: 0 Total samples processed: 32 Loss: 0.06560367345809937
# Train Epoch: 156 Batch: 1 Total samples processed: 64 Loss: 0.07560873031616211
# Train Epoch: 156 Batch: 2 Total samples processed: 96 Loss: 0.06705524027347565
# Train Epoch: 156 Batch: 3 Total samples processed: 128 Loss: 0.06814150512218475
# Train Epoch: 157 Batch: 0 Total samples processed: 32 Loss: 0.06961899995803833
# Train Epoch: 157 Batch: 1 Total samples processed: 64 Loss: 0.06590791046619415
# Train Epoch: 157 Batch: 2 Total samples processed: 96 Loss: 0.06900654733181
# Train Epoch: 157 Batch: 3 Total samples processed: 128 Loss: 0.06822514533996582
# Train Epoch: 158 Batch: 0 Total samples processed: 32 Loss: 0.06677732616662979
# Train Epoch: 158 Batch: 1 Total samples processed: 64 Loss: 0.0691288411617279
# Train Epoch: 158 Batch: 2 Total samples processed: 96 Loss: 0.06531786173582077
# Train Epoch: 158 Batch: 3 Total samples processed: 128 Loss: 0.06287362426519394
# Train Epoch: 159 Batch: 0 Total samples processed: 32 Loss: 0.06341646611690521
# Train Epoch: 159 Batch: 1 Total samples processed: 64 Loss: 0.06744352728128433
# Train Epoch: 159 Batch: 2 Total samples processed: 96 Loss: 0.06954462826251984
# Train Epoch: 159 Batch: 3 Total samples processed: 128 Loss: 0.07981234043836594
# Train Epoch: 160 Batch: 0 Total samples processed: 32 Loss: 0.06711519509553909
# Train Epoch: 160 Batch: 1 Total samples processed: 64 Loss: 0.07151523232460022
# Train Epoch: 160 Batch: 2 Total samples processed: 96 Loss: 0.06659937649965286
# Train Epoch: 160 Batch: 3 Total samples processed: 128 Loss: 0.05976015329360962
# Train Epoch: 161 Batch: 0 Total samples processed: 32 Loss: 0.06149271875619888
# Train Epoch: 161 Batch: 1 Total samples processed: 64 Loss: 0.06889460980892181
# Train Epoch: 161 Batch: 2 Total samples processed: 96 Loss: 0.06545397639274597
# Train Epoch: 161 Batch: 3 Total samples processed: 128 Loss: 0.066187784075737
# Train Epoch: 162 Batch: 0 Total samples processed: 32 Loss: 0.0644555538892746
# Train Epoch: 162 Batch: 1 Total samples processed: 64 Loss: 0.06572131812572479
# Train Epoch: 162 Batch: 2 Total samples processed: 96 Loss: 0.06367218494415283
# Train Epoch: 162 Batch: 3 Total samples processed: 128 Loss: 0.0623076856136322
# Train Epoch: 163 Batch: 0 Total samples processed: 32 Loss: 0.07000234723091125
# Train Epoch: 163 Batch: 1 Total samples processed: 64 Loss: 0.061753638088703156
# Train Epoch: 163 Batch: 2 Total samples processed: 96 Loss: 0.06801168620586395
# Train Epoch: 163 Batch: 3 Total samples processed: 128 Loss: 0.06713643670082092
# Train Epoch: 164 Batch: 0 Total samples processed: 32 Loss: 0.06259411573410034
# Train Epoch: 164 Batch: 1 Total samples processed: 64 Loss: 0.06441430002450943
# Train Epoch: 164 Batch: 2 Total samples processed: 96 Loss: 0.06309494376182556
# Train Epoch: 164 Batch: 3 Total samples processed: 128 Loss: 0.06664352864027023
# Train Epoch: 165 Batch: 0 Total samples processed: 32 Loss: 0.06147575005888939
# Train Epoch: 165 Batch: 1 Total samples processed: 64 Loss: 0.06274180859327316
# Train Epoch: 165 Batch: 2 Total samples processed: 96 Loss: 0.06222538650035858
# Train Epoch: 165 Batch: 3 Total samples processed: 128 Loss: 0.06163499876856804
# Train Epoch: 166 Batch: 0 Total samples processed: 32 Loss: 0.06275905668735504
# Train Epoch: 166 Batch: 1 Total samples processed: 64 Loss: 0.062350619584321976
# Train Epoch: 166 Batch: 2 Total samples processed: 96 Loss: 0.06387006491422653
# Train Epoch: 166 Batch: 3 Total samples processed: 128 Loss: 0.06781630963087082
# Train Epoch: 167 Batch: 0 Total samples processed: 32 Loss: 0.05921880900859833
# Train Epoch: 167 Batch: 1 Total samples processed: 64 Loss: 0.06771793961524963
# Train Epoch: 167 Batch: 2 Total samples processed: 96 Loss: 0.06424793601036072
# Train Epoch: 167 Batch: 3 Total samples processed: 128 Loss: 0.06538735330104828
# Train Epoch: 168 Batch: 0 Total samples processed: 32 Loss: 0.062225960195064545
# Train Epoch: 168 Batch: 1 Total samples processed: 64 Loss: 0.06337539851665497
# Train Epoch: 168 Batch: 2 Total samples processed: 96 Loss: 0.06527946889400482
# Train Epoch: 168 Batch: 3 Total samples processed: 128 Loss: 0.07301557064056396
# Train Epoch: 169 Batch: 0 Total samples processed: 32 Loss: 0.06533975899219513
# Train Epoch: 169 Batch: 1 Total samples processed: 64 Loss: 0.07591722905635834
# Train Epoch: 169 Batch: 2 Total samples processed: 96 Loss: 0.07527372241020203
# Train Epoch: 169 Batch: 3 Total samples processed: 128 Loss: 0.06496354937553406
# Train Epoch: 170 Batch: 0 Total samples processed: 32 Loss: 0.058917976915836334
# Train Epoch: 170 Batch: 1 Total samples processed: 64 Loss: 0.06734510511159897
# Train Epoch: 170 Batch: 2 Total samples processed: 96 Loss: 0.07323251664638519
# Train Epoch: 170 Batch: 3 Total samples processed: 128 Loss: 0.07926671952009201
# Train Epoch: 171 Batch: 0 Total samples processed: 32 Loss: 0.06723559647798538
# Train Epoch: 171 Batch: 1 Total samples processed: 64 Loss: 0.061524491757154465
# Train Epoch: 171 Batch: 2 Total samples processed: 96 Loss: 0.06581105291843414
# Train Epoch: 171 Batch: 3 Total samples processed: 128 Loss: 0.0784364566206932
# Train Epoch: 172 Batch: 0 Total samples processed: 32 Loss: 0.06393741071224213
# Train Epoch: 172 Batch: 1 Total samples processed: 64 Loss: 0.06807312369346619
# Train Epoch: 172 Batch: 2 Total samples processed: 96 Loss: 0.07061317563056946
# Train Epoch: 172 Batch: 3 Total samples processed: 128 Loss: 0.06794773787260056
# Train Epoch: 173 Batch: 0 Total samples processed: 32 Loss: 0.0728055015206337
# Train Epoch: 173 Batch: 1 Total samples processed: 64 Loss: 0.06363192200660706
# Train Epoch: 173 Batch: 2 Total samples processed: 96 Loss: 0.06222166121006012
# Train Epoch: 173 Batch: 3 Total samples processed: 128 Loss: 0.07409869134426117
# Train Epoch: 174 Batch: 0 Total samples processed: 32 Loss: 0.06873314082622528
# Train Epoch: 174 Batch: 1 Total samples processed: 64 Loss: 0.06714420020580292
# Train Epoch: 174 Batch: 2 Total samples processed: 96 Loss: 0.06992495805025101
# Train Epoch: 174 Batch: 3 Total samples processed: 128 Loss: 0.10170086473226547
# Train Epoch: 175 Batch: 0 Total samples processed: 32 Loss: 0.0641026645898819
# Train Epoch: 175 Batch: 1 Total samples processed: 64 Loss: 0.07207217812538147
# Train Epoch: 175 Batch: 2 Total samples processed: 96 Loss: 0.06525114923715591
# Train Epoch: 175 Batch: 3 Total samples processed: 128 Loss: 0.071442149579525
# Train Epoch: 176 Batch: 0 Total samples processed: 32 Loss: 0.06850294768810272
# Train Epoch: 176 Batch: 1 Total samples processed: 64 Loss: 0.06911350786685944
# Train Epoch: 176 Batch: 2 Total samples processed: 96 Loss: 0.06175728887319565
# Train Epoch: 176 Batch: 3 Total samples processed: 128 Loss: 0.08006669580936432
# Train Epoch: 177 Batch: 0 Total samples processed: 32 Loss: 0.06580191850662231
# Train Epoch: 177 Batch: 1 Total samples processed: 64 Loss: 0.0665915459394455
# Train Epoch: 177 Batch: 2 Total samples processed: 96 Loss: 0.05938730388879776
# Train Epoch: 177 Batch: 3 Total samples processed: 128 Loss: 0.08447156846523285
# Train Epoch: 178 Batch: 0 Total samples processed: 32 Loss: 0.06324349343776703
# Train Epoch: 178 Batch: 1 Total samples processed: 64 Loss: 0.061632752418518066
# Train Epoch: 178 Batch: 2 Total samples processed: 96 Loss: 0.06122841686010361
# Train Epoch: 178 Batch: 3 Total samples processed: 128 Loss: 0.059622734785079956
# Train Epoch: 179 Batch: 0 Total samples processed: 32 Loss: 0.06257414072751999
# Train Epoch: 179 Batch: 1 Total samples processed: 64 Loss: 0.05871494114398956
# Train Epoch: 179 Batch: 2 Total samples processed: 96 Loss: 0.061517246067523956
# Train Epoch: 179 Batch: 3 Total samples processed: 128 Loss: 0.06154399737715721
# Train Epoch: 180 Batch: 0 Total samples processed: 32 Loss: 0.058049656450748444
# Train Epoch: 180 Batch: 1 Total samples processed: 64 Loss: 0.065866619348526
# Train Epoch: 180 Batch: 2 Total samples processed: 96 Loss: 0.05739583820104599
# Train Epoch: 180 Batch: 3 Total samples processed: 128 Loss: 0.05905992537736893
# Train Epoch: 181 Batch: 0 Total samples processed: 32 Loss: 0.05762389674782753
# Train Epoch: 181 Batch: 1 Total samples processed: 64 Loss: 0.05916859582066536
# Train Epoch: 181 Batch: 2 Total samples processed: 96 Loss: 0.0599747970700264
# Train Epoch: 181 Batch: 3 Total samples processed: 128 Loss: 0.05765672028064728
# Train Epoch: 182 Batch: 0 Total samples processed: 32 Loss: 0.05572950094938278
# Train Epoch: 182 Batch: 1 Total samples processed: 64 Loss: 0.06061022728681564
# Train Epoch: 182 Batch: 2 Total samples processed: 96 Loss: 0.06034070625901222
# Train Epoch: 182 Batch: 3 Total samples processed: 128 Loss: 0.05216112732887268
# Train Epoch: 183 Batch: 0 Total samples processed: 32 Loss: 0.05720720440149307
# Train Epoch: 183 Batch: 1 Total samples processed: 64 Loss: 0.053286127746105194
# Train Epoch: 183 Batch: 2 Total samples processed: 96 Loss: 0.05921412259340286
# Train Epoch: 183 Batch: 3 Total samples processed: 128 Loss: 0.05684686824679375
# Train Epoch: 184 Batch: 0 Total samples processed: 32 Loss: 0.05472388118505478
# Train Epoch: 184 Batch: 1 Total samples processed: 64 Loss: 0.05346527323126793
# Train Epoch: 184 Batch: 2 Total samples processed: 96 Loss: 0.057853490114212036
# Train Epoch: 184 Batch: 3 Total samples processed: 128 Loss: 0.048855528235435486
# Train Epoch: 185 Batch: 0 Total samples processed: 32 Loss: 0.055788494646549225
# Train Epoch: 185 Batch: 1 Total samples processed: 64 Loss: 0.05716530978679657
# Train Epoch: 185 Batch: 2 Total samples processed: 96 Loss: 0.054381631314754486
# Train Epoch: 185 Batch: 3 Total samples processed: 128 Loss: 0.048329222947359085
# Train Epoch: 186 Batch: 0 Total samples processed: 32 Loss: 0.053893957287073135
# Train Epoch: 186 Batch: 1 Total samples processed: 64 Loss: 0.05385344475507736
# Train Epoch: 186 Batch: 2 Total samples processed: 96 Loss: 0.052373096346855164
# Train Epoch: 186 Batch: 3 Total samples processed: 128 Loss: 0.05491664260625839
# Train Epoch: 187 Batch: 0 Total samples processed: 32 Loss: 0.05540314316749573
# Train Epoch: 187 Batch: 1 Total samples processed: 64 Loss: 0.05234948545694351
# Train Epoch: 187 Batch: 2 Total samples processed: 96 Loss: 0.053454816341400146
# Train Epoch: 187 Batch: 3 Total samples processed: 128 Loss: 0.04863535612821579
# Train Epoch: 188 Batch: 0 Total samples processed: 32 Loss: 0.054320551455020905
# Train Epoch: 188 Batch: 1 Total samples processed: 64 Loss: 0.053192831575870514
# Train Epoch: 188 Batch: 2 Total samples processed: 96 Loss: 0.05427224189043045
# Train Epoch: 188 Batch: 3 Total samples processed: 128 Loss: 0.05473297834396362
# Train Epoch: 189 Batch: 0 Total samples processed: 32 Loss: 0.05060505121946335
# Train Epoch: 189 Batch: 1 Total samples processed: 64 Loss: 0.056240882724523544
# Train Epoch: 189 Batch: 2 Total samples processed: 96 Loss: 0.050980426371097565
# Train Epoch: 189 Batch: 3 Total samples processed: 128 Loss: 0.06745214760303497
# Train Epoch: 190 Batch: 0 Total samples processed: 32 Loss: 0.05532846599817276
# Train Epoch: 190 Batch: 1 Total samples processed: 64 Loss: 0.05488111451268196
# Train Epoch: 190 Batch: 2 Total samples processed: 96 Loss: 0.056741952896118164
# Train Epoch: 190 Batch: 3 Total samples processed: 128 Loss: 0.052302613854408264
# Train Epoch: 191 Batch: 0 Total samples processed: 32 Loss: 0.054381899535655975
# Train Epoch: 191 Batch: 1 Total samples processed: 64 Loss: 0.06169343739748001
# Train Epoch: 191 Batch: 2 Total samples processed: 96 Loss: 0.05310250073671341
# Train Epoch: 191 Batch: 3 Total samples processed: 128 Loss: 0.046904079616069794
# Train Epoch: 192 Batch: 0 Total samples processed: 32 Loss: 0.057390592992305756
# Train Epoch: 192 Batch: 1 Total samples processed: 64 Loss: 0.05249897390604019
# Train Epoch: 192 Batch: 2 Total samples processed: 96 Loss: 0.05127044767141342
# Train Epoch: 192 Batch: 3 Total samples processed: 128 Loss: 0.051595643162727356
# Train Epoch: 193 Batch: 0 Total samples processed: 32 Loss: 0.057008370757102966
# Train Epoch: 193 Batch: 1 Total samples processed: 64 Loss: 0.05618239939212799
# Train Epoch: 193 Batch: 2 Total samples processed: 96 Loss: 0.05479390546679497
# Train Epoch: 193 Batch: 3 Total samples processed: 128 Loss: 0.050132885575294495
# Train Epoch: 194 Batch: 0 Total samples processed: 32 Loss: 0.05426488071680069
# Train Epoch: 194 Batch: 1 Total samples processed: 64 Loss: 0.05379817634820938
# Train Epoch: 194 Batch: 2 Total samples processed: 96 Loss: 0.053485207259655
# Train Epoch: 194 Batch: 3 Total samples processed: 128 Loss: 0.04751633480191231
# Train Epoch: 195 Batch: 0 Total samples processed: 32 Loss: 0.053637657314538956
# Train Epoch: 195 Batch: 1 Total samples processed: 64 Loss: 0.0526006855070591
# Train Epoch: 195 Batch: 2 Total samples processed: 96 Loss: 0.052419133484363556
# Train Epoch: 195 Batch: 3 Total samples processed: 128 Loss: 0.04223313182592392
# Train Epoch: 196 Batch: 0 Total samples processed: 32 Loss: 0.04984166473150253
# Train Epoch: 196 Batch: 1 Total samples processed: 64 Loss: 0.05604955554008484
# Train Epoch: 196 Batch: 2 Total samples processed: 96 Loss: 0.052402108907699585
# Train Epoch: 196 Batch: 3 Total samples processed: 128 Loss: 0.045387476682662964
# Train Epoch: 197 Batch: 0 Total samples processed: 32 Loss: 0.05040663480758667
# Train Epoch: 197 Batch: 1 Total samples processed: 64 Loss: 0.05164533108472824
# Train Epoch: 197 Batch: 2 Total samples processed: 96 Loss: 0.05238213390111923
# Train Epoch: 197 Batch: 3 Total samples processed: 128 Loss: 0.04968846216797829
# Train Epoch: 198 Batch: 0 Total samples processed: 32 Loss: 0.054614584892988205
# Train Epoch: 198 Batch: 1 Total samples processed: 64 Loss: 0.051849909126758575
# Train Epoch: 198 Batch: 2 Total samples processed: 96 Loss: 0.049605593085289
# Train Epoch: 198 Batch: 3 Total samples processed: 128 Loss: 0.04574566334486008
# Train Epoch: 199 Batch: 0 Total samples processed: 32 Loss: 0.0503658801317215
# Train Epoch: 199 Batch: 1 Total samples processed: 64 Loss: 0.05215419456362724
# Train Epoch: 199 Batch: 2 Total samples processed: 96 Loss: 0.05157653987407684
# Train Epoch: 199 Batch: 3 Total samples processed: 128 Loss: 0.047212935984134674
# Train Epoch: 200 Batch: 0 Total samples processed: 32 Loss: 0.047274380922317505
# Train Epoch: 200 Batch: 1 Total samples processed: 64 Loss: 0.04996222257614136
# Train Epoch: 200 Batch: 2 Total samples processed: 96 Loss: 0.05342497676610947
# Train Epoch: 200 Batch: 3 Total samples processed: 128 Loss: 0.05191187560558319

# %% [markdown]
# ## Look at self-prediction
#
# Self-prediction does not tell us how the UNET will perform on new data, but it is a useful check to make sure the UNET is learning the training data.

# %%
len(X)
# Out:
# 4

# %%
import matplotlib.pyplot as plt

# convert to 0/1 range on each pixel
prediction = torch.nn.functional.sigmoid(prediction_logits)
prediction_binary = prediction #(prediction > 0.5).to(torch.uint8)

sidx = 1
plt.subplot(131)
plt.imshow(X[sidx, 0].cpu().numpy(), cmap="gray")
plt.title("Input")

plt.subplot(132)
plt.imshow(y[sidx, 0].cpu().numpy(), cmap="gray")
plt.title("Ground truth")

plt.subplot(133)
plt.imshow(prediction_binary.cpu().detach()[sidx, 0].numpy(), cmap="gray")
plt.title("Predictions")
# Out:
# Text(0.5, 1.0, 'Predictions')

# %% [markdown]
# ## Save the UNET

# %%
torch.save(model.state_dict(), train_path / 'model1')

# %% [markdown]
# ## Test on unseen data

# %%
test_name = 'HP_1week_screenshot.jpg'
testim = imread(parent_path  / test_name)
testim = testim.mean(axis=2)
testim.shape
plt.imshow(testim, cmap="gray")
print('original min max', testim.min(), testim.max())
# Out:
# original min max 0.0 160.0

# %%
testim_ = quantile_normalization(
    testim,
    quantile_low=0.01,
    quantile_high=0.998,
    clip=True).astype(np.float32)

x = torch.from_numpy(testim_).unsqueeze(0).unsqueeze(0).to(device)
y = model(x)

plt.imshow(y.cpu().detach()[0, 0].numpy(), cmap="gray")

# %% [markdown]
# ## Look at results in Napari

# %%
import napari
viewer = napari.Viewer()
viewer.add_image(testim, name='testim')
viewer.add_image(y.cpu().detach()[0, 0].numpy(), name='prediction')
binary = y.cpu().detach()[0, 0].numpy() > 0.5
viewer.add_labels(binary, name='prediction binary')
# Out:
# <Labels layer 'prediction binary' at 0x2576e40c6d0>

# %%
from skimage.io import imsave
imsave(parent_path / 'CNN_segmentation.tif', y.cpu().detach()[0, 0].numpy())

# %%
from cProfile import label
from os import sep
from tnia.segmentation.separate import separate_touching

labels = y.cpu().detach()[0, 0].numpy() > 0.5
# invert labels
labels = 1 - labels

separated, label_separated, _ = separate_touching(labels, 15, 1)

from skimage.measure import label
label_separated = label(separated)

viewer = napari.Viewer()
viewer.add_image(testim, name='image')
viewer.add_labels(label_separated, name='separated')
# Out:
# <Labels layer 'separated' at 0x27faab17a30>

# %%
labels.shape
# Out:
# (1024, 1536)
