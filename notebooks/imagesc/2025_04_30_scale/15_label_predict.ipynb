# %% [markdown]
# ## Use Napari-Easy-Augment-Batch-DL to load and label images
#
# This notebook starts up Napari-Easy-Augment-Batch-DL and points it to our project directory.  At the beginning of a project this directory is simply the location of our collection of images.

# %% [markdown]
# ## Import and check versions

# %%
import napari
import numpy as np
from napari_easy_augment_batch_dl.easy_augment_batch_dl import NapariEasyAugmentBatchDL, EasyAugmentMode
import os
# for trouble shooting print the napari and numpy version. This can give us clues if there are dependency issues
print('napari version', napari.__version__)
print('numpy version', np.__version__)
# Out:
# napari version 0.5.6
# numpy version 1.26.4

# %% [markdown]
# ## Start Napari and Easy Augment Batch DL
#
# Start Napari, show Easy-Augment-Batch-DL and show the parent directory.

# %%
viewer = napari.Viewer()

batch_dl = NapariEasyAugmentBatchDL(viewer, mode=EasyAugmentMode.DL_PIXEL_ONLY)

viewer.window.add_dock_widget(
    batch_dl
)

parent_path = r'D:\images\tnia-python-images\imagesc\2025_04_30_scale'
batch_dl.load_image_directory(parent_path)
# Out:
# WARNING: QWindowsWindow::setGeometry: Unable to set geometry 1086x1108+207+31 (frame: 1102x1147+199+0) on QWidgetWindow/"_QtMainWindowClassWindow" on "\\.\DISPLAY1". Resulting geometry: 1086x1061+207+31 (frame: 1102x1100+199+0) margins: 8, 31, 8, 8 minimum size: 385x497 MINMAXINFO maxSize=0,0 maxpos=0,0 mintrack=401,536 maxtrack=0,0)
# 2025-04-30 17:08:55,051 [WARNING] QWindowsWindow::setGeometry: Unable to set geometry 1086x1108+207+31 (frame: 1102x1147+199+0) on QWidgetWindow/"_QtMainWindowClassWindow" on "\\.\DISPLAY1". Resulting geometry: 1086x1061+207+31 (frame: 1102x1100+199+0) margins: 8, 31, 8, 8 minimum size: 385x497 MINMAXINFO maxSize=0,0 maxpos=0,0 mintrack=401,536 maxtrack=0,0)
# VIT checkpoint loaded successfully
# Found framework CellPoseInstanceFramework
# creating new log file
# 2025-04-30 17:08:58,790 [INFO] WRITING LOG OUTPUT TO C:\Users\bnort\.cellpose\run.log
# 2025-04-30 17:08:58,791 [INFO]
# cellpose version: 	3.1.0
# platform:       	win32
# python version: 	3.11.11
# torch version:  	2.6.0
# Found framework PytorchSemanticFramework
# Found framework MobileSAMFramework
# Found framework YoloSAMFramework
# Found framework RandomForestFramework
# Zarr store already up-to-date.
# Zarr store already up-to-date.
# Adding object boxes layer
# Adding predicted object boxes layer
# Adding label boxes
# Data changed
# Data changed
# Adding object boxes
# Adding predicted object boxes
# Setting object box classes
# Setting predicted object box classes
#   0%|          | 0/500 [00:00<?, ?it/s]c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\dl_helper.py:429: FutureWarning: The plugin infrastructure in `skimage.io` and the parameter `plugin` are deprecated since version 0.25 and will be removed in 0.27 (or later). To avoid this warning, please do not use the parameter `plugin`. Instead, use `imageio` or other I/O packages directly. See also `imread`.
#   input_img = io.imread(os.path.join(input_path, input_files[i]), plugin='tifffile')
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\dl_helper.py:430: FutureWarning: The plugin infrastructure in `skimage.io` and the parameter `plugin` are deprecated since version 0.25 and will be removed in 0.27 (or later). To avoid this warning, please do not use the parameter `plugin`. Instead, use `imageio` or other I/O packages directly. See also `imread`.
#   ground_truth_img = io.imread(os.path.join(truth_path, truth_files[i]), plugin='tifffile')
#   0%|          | 1/500 [00:00<01:01,  8.13it/s]c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\dl_helper.py:429: FutureWarning: The plugin infrastructure in `skimage.io` and the parameter `plugin` are deprecated since version 0.25 and will be removed in 0.27 (or later). To avoid this warning, please do not use the parameter `plugin`. Instead, use `imageio` or other I/O packages directly. See also `imread`.
#   input_img = io.imread(os.path.join(input_path, input_files[i]), plugin='tifffile')
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\dl_helper.py:430: FutureWarning: The plugin infrastructure in `skimage.io` and the parameter `plugin` are deprecated since version 0.25 and will be removed in 0.27 (or later). To avoid this warning, please do not use the parameter `plugin`. Instead, use `imageio` or other I/O packages directly. See also `imread`.
#   ground_truth_img = io.imread(os.path.join(truth_path, truth_files[i]), plugin='tifffile')
#   0%|          | 2/500 [00:00<01:11,  6.93it/s]c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\dl_helper.py:429: FutureWarning: The plugin infrastructure in `skimage.io` and the parameter `plugin` are deprecated since version 0.25 and will be removed in 0.27 (or later). To avoid this warning, please do not use the parameter `plugin`. Instead, use `imageio` or other I/O packages directly. See also `imread`.
#   input_img = io.imread(os.path.join(input_path, input_files[i]), plugin='tifffile')
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\dl_helper.py:430: FutureWarning: The plugin infrastructure in `skimage.io` and the parameter `plugin` are deprecated since version 0.25 and will be removed in 0.27 (or later). To avoid this warning, please do not use the parameter `plugin`. Instead, use `imageio` or other I/O packages directly. See also `imread`.
#   ground_truth_img = io.imread(os.path.join(truth_path, truth_files[i]), plugin='tifffile')
#   1%|          | 3/500 [00:00<01:10,  7.07it/s]c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\dl_helper.py:429: FutureWarning: The plugin infrastructure in `skimage.io` and the parameter `plugin` are deprecated since version 0.25 and will be removed in 0.27 (or later). To avoid this warning, please do not use the parameter `plugin`. Instead, use `imageio` or other I/O packages directly. See also `imread`.
#   input_img = io.imread(os.path.join(input_path, input_files[i]), plugin='tifffile')
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\dl_helper.py:430: FutureWarning: The plugin infrastructure in `skimage.io` and the parameter `plugin` are deprecated since version 0.25 and will be removed in 0.27 (or later). To avoid this warning, please do not use the parameter `plugin`. Instead, use `imageio` or other I/O packages directly. See also `imread`.
#   ground_truth_img = io.imread(os.path.join(truth_path, truth_files[i]), plugin='tifffile')
#   1%|          | 4/500 [00:00<01:05,  7.59it/s]c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\dl_helper.py:429: FutureWarning: The plugin infrastructure in `skimage.io` and the parameter `plugin` are deprecated since version 0.25 and will be removed in 0.27 (or later). To avoid this warning, please do not use the parameter `plugin`. Instead, use `imageio` or other I/O packages directly. See also `imread`.
#   input_img = io.imread(os.path.join(input_path, input_files[i]), plugin='tifffile')
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\dl_helper.py:430: FutureWarning: The plugin infrastructure in `skimage.io` and the parameter `plugin` are deprecated since version 0.25 and will be removed in 0.27 (or later). To avoid this warning, please do not use the parameter `plugin`. Instead, use `imageio` or other I/O packages directly. See also `imread`.
#   ground_truth_img = io.imread(os.path.join(truth_path, truth_files[i]), plugin='tifffile')
#   1%|          | 5/500 [00:00<01:05,  7.59it/s]c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\dl_helper.py:429: FutureWarning: The plugin infrastructure in `skimage.io` and the parameter `plugin` are deprecated since version 0.25 and will be removed in 0.27 (or later). To avoid this warning, please do not use the parameter `plugin`. Instead, use `imageio` or other I/O packages directly. See also `imread`.
#   input_img = io.imread(os.path.join(input_path, input_files[i]), plugin='tifffile')
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\dl_helper.py:430: FutureWarning: The plugin infrastructure in `skimage.io` and the parameter `plugin` are deprecated since version 0.25 and will be removed in 0.27 (or later). To avoid this warning, please do not use the parameter `plugin`. Instead, use `imageio` or other I/O packages directly. See also `imread`.
#   ground_truth_img = io.imread(os.path.join(truth_path, truth_files[i]), plugin='tifffile')
#   1%|          | 6/500 [00:00<00:59,  8.24it/s]c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\dl_helper.py:429: FutureWarning: The plugin infrastructure in `skimage.io` and the parameter `plugin` are deprecated since version 0.25 and will be removed in 0.27 (or later). To avoid this warning, please do not use the parameter `plugin`. Instead, use `imageio` or other I/O packages directly. See also `imread`.
#   input_img = io.imread(os.path.join(input_path, input_files[i]), plugin='tifffile')
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\dl_helper.py:430: FutureWarning: The plugin infrastructure in `skimage.io` and the parameter `plugin` are deprecated since version 0.25 and will be removed in 0.27 (or later). To avoid this warning, please do not use the parameter `plugin`. Instead, use `imageio` or other I/O packages directly. See also `imread`.
#   ground_truth_img = io.imread(os.path.join(truth_path, truth_files[i]), plugin='tifffile')
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\dl_helper.py:429: FutureWarning: The plugin infrastructure in `skimage.io` and the parameter `plugin` are deprecated since version 0.25 and will be removed in 0.27 (or later). To avoid this warning, please do not use the parameter `plugin`. Instead, use `imageio` or other I/O packages directly. See also `imread`.
#   input_img = io.imread(os.path.join(input_path, input_files[i]), plugin='tifffile')
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\dl_helper.py:430: FutureWarning: The plugin infrastructure in `skimage.io` and the parameter `plugin` are deprecated since version 0.25 and will be removed in 0.27 (or later). To avoid this warning, please do not use the parameter `plugin`. Instead, use `imageio` or other I/O packages directly. See also `imread`.
#   ground_truth_img = io.imread(os.path.join(truth_path, truth_files[i]), plugin='tifffile')
#   2%|▏         | 8/500 [00:01<00:59,  8.29it/s]c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\dl_helper.py:429: FutureWarning: The plugin infrastructure in `skimage.io` and the parameter `plugin` are deprecated since version 0.25 and will be removed in 0.27 (or later). To avoid this warning, please do not use the parameter `plugin`. Instead, use `imageio` or other I/O packages directly. See also `imread`.
#   input_img = io.imread(os.path.join(input_path, input_files[i]), plugin='tifffile')
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\dl_helper.py:430: FutureWarning: The plugin infrastructure in `skimage.io` and the parameter `plugin` are deprecated since version 0.25 and will be removed in 0.27 (or later). To avoid this warning, please do not use the parameter `plugin`. Instead, use `imageio` or other I/O packages directly. See also `imread`.
#   ground_truth_img = io.imread(os.path.join(truth_path, truth_files[i]), plugin='tifffile')
#   2%|▏         | 9/500 [00:01<01:00,  8.05it/s]c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\dl_helper.py:429: FutureWarning: The plugin infrastructure in `skimage.io` and the parameter `plugin` are deprecated since version 0.25 and will be removed in 0.27 (or later). To avoid this warning, please do not use the parameter `plugin`. Instead, use `imageio` or other I/O packages directly. See also `imread`.
#   input_img = io.imread(os.path.join(input_path, input_files[i]), plugin='tifffile')
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\dl_helper.py:430: FutureWarning: The plugin infrastructure in `skimage.io` and the parameter `plugin` are deprecated since version 0.25 and will be removed in 0.27 (or later). To avoid this warning, please do not use the parameter `plugin`. Instead, use `imageio` or other I/O packages directly. See also `imread`.
#   ground_truth_img = io.imread(os.path.join(truth_path, truth_files[i]), plugin='tifffile')
#   2%|▏         | 10/500 [00:01<00:58,  8.39it/s]c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\dl_helper.py:429: FutureWarning: The plugin infrastructure in `skimage.io` and the parameter `plugin` are deprecated since version 0.25 and will be removed in 0.27 (or later). To avoid this warning, please do not use the parameter `plugin`. Instead, use `imageio` or other I/O packages directly. See also `imread`.
#   input_img = io.imread(os.path.join(input_path, input_files[i]), plugin='tifffile')
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\dl_helper.py:430: FutureWarning: The plugin infrastructure in `skimage.io` and the parameter `plugin` are deprecated since version 0.25 and will be removed in 0.27 (or later). To avoid this warning, please do not use the parameter `plugin`. Instead, use `imageio` or other I/O packages directly. See also `imread`.
#   ground_truth_img = io.imread(os.path.join(truth_path, truth_files[i]), plugin='tifffile')
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\dl_helper.py:429: FutureWarning: The plugin infrastructure in `skimage.io` and the parameter `plugin` are deprecated since version 0.25 and will be removed in 0.27 (or later). To avoid this warning, please do not use the parameter `plugin`. Instead, use `imageio` or other I/O packages directly. See also `imread`.
#   input_img = io.imread(os.path.join(input_path, input_files[i]), plugin='tifffile')
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\dl_helper.py:430: FutureWarning: The plugin infrastructure in `skimage.io` and the parameter `plugin` are deprecated since version 0.25 and will be removed in 0.27 (or later). To avoid this warning, please do not use the parameter `plugin`. Instead, use `imageio` or other I/O packages directly. See also `imread`.
#   ground_truth_img = io.imread(os.path.join(truth_path, truth_files[i]), plugin='tifffile')
#   2%|▏         | 12/500 [00:01<00:47, 10.28it/s]c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\dl_helper.py:429: FutureWarning: The plugin infrastructure in `skimage.io` and the parameter `plugin` are deprecated since version 0.25 and will be removed in 0.27 (or later). To avoid this warning, please do not use the parameter `plugin`. Instead, use `imageio` or other I/O packages directly. See also `imread`.
#   input_img = io.imread(os.path.join(input_path, input_files[i]), plugin='tifffile')
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\dl_helper.py:430: FutureWarning: The plugin infrastructure in `skimage.io` and the parameter `plugin` are deprecated since version 0.25 and will be removed in 0.27 (or later). To avoid this warning, please do not use the parameter `plugin`. Instead, use `imageio` or other I/O packages directly. See also `imread`.
#   ground_truth_img = io.imread(os.path.join(truth_path, truth_files[i]), plugin='tifffile')
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\dl_helper.py:429: FutureWarning: The plugin infrastructure in `skimage.io` and the parameter `plugin` are deprecated since version 0.25 and will be removed in 0.27 (or later). To avoid this warning, please do not use the parameter `plugin`. Instead, use `imageio` or other I/O packages directly. See also `imread`.
#   input_img = io.imread(os.path.join(input_path, input_files[i]), plugin='tifffile')
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\dl_helper.py:430: FutureWarning: The plugin infrastructure in `skimage.io` and the parameter `plugin` are deprecated since version 0.25 and will be removed in 0.27 (or later). To avoid this warning, please do not use the parameter `plugin`. Instead, use `imageio` or other I/O packages directly. See also `imread`.
#   ground_truth_img = io.imread(os.path.join(truth_path, truth_files[i]), plugin='tifffile')
#   3%|▎         | 14/500 [00:01<00:46, 10.45it/s]c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\dl_helper.py:429: FutureWarning: The plugin infrastructure in `skimage.io` and the parameter `plugin` are deprecated since version 0.25 and will be removed in 0.27 (or later). To avoid this warning, please do not use the parameter `plugin`. Instead, use `imageio` or other I/O packages directly. See also `imread`.
#   input_img = io.imread(os.path.join(input_path, input_files[i]), plugin='tifffile')
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\dl_helper.py:430: FutureWarning: The plugin infrastructure in `skimage.io` and the parameter `plugin` are deprecated since version 0.25 and will be removed in 0.27 (or later). To avoid this warning, please do not use the parameter `plugin`. Instead, use `imageio` or other I/O packages directly. See also `imread`.
#   ground_truth_img = io.imread(os.path.join(truth_path, truth_files[i]), plugin='tifffile')
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\dl_helper.py:429: FutureWarning: The plugin infrastructure in `skimage.io` and the parameter `plugin` are deprecated since version 0.25 and will be removed in 0.27 (or later). To avoid this warning, please do not use the parameter `plugin`. Instead, use `imageio` or other I/O packages directly. See also `imread`.
#   input_img = io.imread(os.path.join(input_path, input_files[i]), plugin='tifffile')
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\dl_helper.py:430: FutureWarning: The plugin infrastructure in `skimage.io` and the parameter `plugin` are deprecated since version 0.25 and will be removed in 0.27 (or later). To avoid this warning, please do not use the parameter `plugin`. Instead, use `imageio` or other I/O packages directly. See also `imread`.
#   ground_truth_img = io.imread(os.path.join(truth_path, truth_files[i]), plugin='tifffile')
#   3%|▎         | 16/500 [00:01<00:47, 10.29it/s]c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\dl_helper.py:429: FutureWarning: The plugin infrastructure in `skimage.io` and the parameter `plugin` are deprecated since version 0.25 and will be removed in 0.27 (or later). To avoid this warning, please do not use the parameter `plugin`. Instead, use `imageio` or other I/O packages directly. See also `imread`.
#   input_img = io.imread(os.path.join(input_path, input_files[i]), plugin='tifffile')
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\dl_helper.py:430: FutureWarning: The plugin infrastructure in `skimage.io` and the parameter `plugin` are deprecated since version 0.25 and will be removed in 0.27 (or later). To avoid this warning, please do not use the parameter `plugin`. Instead, use `imageio` or other I/O packages directly. See also `imread`.
#   ground_truth_img = io.imread(os.path.join(truth_path, truth_files[i]), plugin='tifffile')
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\dl_helper.py:429: FutureWarning: The plugin infrastructure in `skimage.io` and the parameter `plugin` are deprecated since version 0.25 and will be removed in 0.27 (or later). To avoid this warning, please do not use the parameter `plugin`. Instead, use `imageio` or other I/O packages directly. See also `imread`.
#   input_img = io.imread(os.path.join(input_path, input_files[i]), plugin='tifffile')
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\dl_helper.py:430: FutureWarning: The plugin infrastructure in `skimage.io` and the parameter `plugin` are deprecated since version 0.25 and will be removed in 0.27 (or later). To avoid this warning, please do not use the parameter `plugin`. Instead, use `imageio` or other I/O packages directly. See also `imread`.
#   ground_truth_img = io.imread(os.path.join(truth_path, truth_files[i]), plugin='tifffile')
#   4%|▎         | 18/500 [00:01<00:47, 10.15it/s]c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\dl_helper.py:429: FutureWarning: The plugin infrastructure in `skimage.io` and the parameter `plugin` are deprecated since version 0.25 and will be removed in 0.27 (or later). To avoid this warning, please do not use the parameter `plugin`. Instead, use `imageio` or other I/O packages directly. See also `imread`.
#   input_img = io.imread(os.path.join(input_path, input_files[i]), plugin='tifffile')
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\dl_helper.py:430: FutureWarning: The plugin infrastructure in `skimage.io` and the parameter `plugin` are deprecated since version 0.25 and will be removed in 0.27 (or later). To avoid this warning, please do not use the parameter `plugin`. Instead, use `imageio` or other I/O packages directly. See also `imread`.
#   ground_truth_img = io.imread(os.path.join(truth_path, truth_files[i]), plugin='tifffile')
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\dl_helper.py:429: FutureWarning: The plugin infrastructure in `skimage.io` and the parameter `plugin` are deprecated since version 0.25 and will be removed in 0.27 (or later). To avoid this warning, please do not use the parameter `plugin`. Instead, use `imageio` or other I/O packages directly. See also `imread`.
#   input_img = io.imread(os.path.join(input_path, input_files[i]), plugin='tifffile')
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\dl_helper.py:430: FutureWarning: The plugin infrastructure in `skimage.io` and the parameter `plugin` are deprecated since version 0.25 and will be removed in 0.27 (or later). To avoid this warning, please do not use the parameter `plugin`. Instead, use `imageio` or other I/O packages directly. See also `imread`.
#   ground_truth_img = io.imread(os.path.join(truth_path, truth_files[i]), plugin='tifffile')
#   4%|▍         | 20/500 [00:02<00:41, 11.43it/s]c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\dl_helper.py:429: FutureWarning: The plugin infrastructure in `skimage.io` and the parameter `plugin` are deprecated since version 0.25 and will be removed in 0.27 (or later). To avoid this warning, please do not use the parameter `plugin`. Instead, use `imageio` or other I/O packages directly. See also `imread`.
#   input_img = io.imread(os.path.join(input_path, input_files[i]), plugin='tifffile')
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\dl_helper.py:430: FutureWarning: The plugin infrastructure in `skimage.io` and the parameter `plugin` are deprecated since version 0.25 and will be removed in 0.27 (or later). To avoid this warning, please do not use the parameter `plugin`. Instead, use `imageio` or other I/O packages directly. See also `imread`.
#   ground_truth_img = io.imread(os.path.join(truth_path, truth_files[i]), plugin='tifffile')
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\dl_helper.py:429: FutureWarning: The plugin infrastructure in `skimage.io` and the parameter `plugin` are deprecated since version 0.25 and will be removed in 0.27 (or later). To avoid this warning, please do not use the parameter `plugin`. Instead, use `imageio` or other I/O packages directly. See also `imread`.
#   input_img = io.imread(os.path.join(input_path, input_files[i]), plugin='tifffile')
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\dl_helper.py:430: FutureWarning: The plugin infrastructure in `skimage.io` and the parameter `plugin` are deprecated since version 0.25 and will be removed in 0.27 (or later). To avoid this warning, please do not use the parameter `plugin`. Instead, use `imageio` or other I/O packages directly. See also `imread`.
#   ground_truth_img = io.imread(os.path.join(truth_path, truth_files[i]), plugin='tifffile')
#   4%|▍         | 22/500 [00:02<00:37, 12.67it/s]c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\dl_helper.py:429: FutureWarning: The plugin infrastructure in `skimage.io` and the parameter `plugin` are deprecated since version 0.25 and will be removed in 0.27 (or later). To avoid this warning, please do not use the parameter `plugin`. Instead, use `imageio` or other I/O packages directly. See also `imread`.
#   input_img = io.imread(os.path.join(input_path, input_files[i]), plugin='tifffile')
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\dl_helper.py:430: FutureWarning: The plugin infrastructure in `skimage.io` and the parameter `plugin` are deprecated since version 0.25 and will be removed in 0.27 (or later). To avoid this warning, please do not use the parameter `plugin`. Instead, use `imageio` or other I/O packages directly. See also `imread`.
#   ground_truth_img = io.imread(os.path.join(truth_path, truth_files[i]), plugin='tifffile')
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\dl_helper.py:429: FutureWarning: The plugin infrastructure in `skimage.io` and the parameter `plugin` are deprecated since version 0.25 and will be removed in 0.27 (or later). To avoid this warning, please do not use the parameter `plugin`. Instead, use `imageio` or other I/O packages directly. See also `imread`.
#   input_img = io.imread(os.path.join(input_path, input_files[i]), plugin='tifffile')
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\dl_helper.py:430: FutureWarning: The plugin infrastructure in `skimage.io` and the parameter `plugin` are deprecated since version 0.25 and will be removed in 0.27 (or later). To avoid this warning, please do not use the parameter `plugin`. Instead, use `imageio` or other I/O packages directly. See also `imread`.
#   ground_truth_img = io.imread(os.path.join(truth_path, truth_files[i]), plugin='tifffile')
#   5%|▍         | 24/500 [00:02<00:41, 11.47it/s]c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\dl_helper.py:429: FutureWarning: The plugin infrastructure in `skimage.io` and the parameter `plugin` are deprecated since version 0.25 and will be removed in 0.27 (or later). To avoid this warning, please do not use the parameter `plugin`. Instead, use `imageio` or other I/O packages directly. See also `imread`.
#   input_img = io.imread(os.path.join(input_path, input_files[i]), plugin='tifffile')
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\dl_helper.py:430: FutureWarning: The plugin infrastructure in `skimage.io` and the parameter `plugin` are deprecated since version 0.25 and will be removed in 0.27 (or later). To avoid this warning, please do not use the parameter `plugin`. Instead, use `imageio` or other I/O packages directly. See also `imread`.
#   ground_truth_img = io.imread(os.path.join(truth_path, truth_files[i]), plugin='tifffile')
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\dl_helper.py:429: FutureWarning: The plugin infrastructure in `skimage.io` and the parameter `plugin` are deprecated since version 0.25 and will be removed in 0.27 (or later). To avoid this warning, please do not use the parameter `plugin`. Instead, use `imageio` or other I/O packages directly. See also `imread`.
#   input_img = io.imread(os.path.join(input_path, input_files[i]), plugin='tifffile')
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\dl_helper.py:430: FutureWarning: The plugin infrastructure in `skimage.io` and the parameter `plugin` are deprecated since version 0.25 and will be removed in 0.27 (or later). To avoid this warning, please do not use the parameter `plugin`. Instead, use `imageio` or other I/O packages directly. See also `imread`.
#   ground_truth_img = io.imread(os.path.join(truth_path, truth_files[i]), plugin='tifffile')
#   5%|▌         | 26/500 [00:02<00:48,  9.87it/s]c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\dl_helper.py:429: FutureWarning: The plugin infrastructure in `skimage.io` and the parameter `plugin` are deprecated since version 0.25 and will be removed in 0.27 (or later). To avoid this warning, please do not use the parameter `plugin`. Instead, use `imageio` or other I/O packages directly. See also `imread`.
#   input_img = io.imread(os.path.join(input_path, input_files[i]), plugin='tifffile')
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\dl_helper.py:430: FutureWarning: The plugin infrastructure in `skimage.io` and the parameter `plugin` are deprecated since version 0.25 and will be removed in 0.27 (or later). To avoid this warning, please do not use the parameter `plugin`. Instead, use `imageio` or other I/O packages directly. See also `imread`.
#   ground_truth_img = io.imread(os.path.join(truth_path, truth_files[i]), plugin='tifffile')
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\dl_helper.py:429: FutureWarning: The plugin infrastructure in `skimage.io` and the parameter `plugin` are deprecated since version 0.25 and will be removed in 0.27 (or later). To avoid this warning, please do not use the parameter `plugin`. Instead, use `imageio` or other I/O packages directly. See also `imread`.
#   input_img = io.imread(os.path.join(input_path, input_files[i]), plugin='tifffile')
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\dl_helper.py:430: FutureWarning: The plugin infrastructure in `skimage.io` and the parameter `plugin` are deprecated since version 0.25 and will be removed in 0.27 (or later). To avoid this warning, please do not use the parameter `plugin`. Instead, use `imageio` or other I/O packages directly. See also `imread`.
#   ground_truth_img = io.imread(os.path.join(truth_path, truth_files[i]), plugin='tifffile')
#   6%|▌         | 28/500 [00:02<00:48,  9.78it/s]c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\dl_helper.py:429: FutureWarning: The plugin infrastructure in `skimage.io` and the parameter `plugin` are deprecated since version 0.25 and will be removed in 0.27 (or later). To avoid this warning, please do not use the parameter `plugin`. Instead, use `imageio` or other I/O packages directly. See also `imread`.
#   input_img = io.imread(os.path.join(input_path, input_files[i]), plugin='tifffile')
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\dl_helper.py:430: FutureWarning: The plugin infrastructure in `skimage.io` and the parameter `plugin` are deprecated since version 0.25 and will be removed in 0.27 (or later). To avoid this warning, please do not use the parameter `plugin`. Instead, use `imageio` or other I/O packages directly. See also `imread`.
#   ground_truth_img = io.imread(os.path.join(truth_path, truth_files[i]), plugin='tifffile')
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\dl_helper.py:429: FutureWarning: The plugin infrastructure in `skimage.io` and the parameter `plugin` are deprecated since version 0.25 and will be removed in 0.27 (or later). To avoid this warning, please do not use the parameter `plugin`. Instead, use `imageio` or other I/O packages directly. See also `imread`.
#   input_img = io.imread(os.path.join(input_path, input_files[i]), plugin='tifffile')
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\dl_helper.py:430: FutureWarning: The plugin infrastructure in `skimage.io` and the parameter `plugin` are deprecated since version 0.25 and will be removed in 0.27 (or later). To avoid this warning, please do not use the parameter `plugin`. Instead, use `imageio` or other I/O packages directly. See also `imread`.
#   ground_truth_img = io.imread(os.path.join(truth_path, truth_files[i]), plugin='tifffile')
#   6%|▌         | 30/500 [00:03<00:49,  9.51it/s]c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\dl_helper.py:429: FutureWarning: The plugin infrastructure in `skimage.io` and the parameter `plugin` are deprecated since version 0.25 and will be removed in 0.27 (or later). To avoid this warning, please do not use the parameter `plugin`. Instead, use `imageio` or other I/O packages directly. See also `imread`.
#   input_img = io.imread(os.path.join(input_path, input_files[i]), plugin='tifffile')
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\dl_helper.py:430: FutureWarning: The plugin infrastructure in `skimage.io` and the parameter `plugin` are deprecated since version 0.25 and will be removed in 0.27 (or later). To avoid this warning, please do not use the parameter `plugin`. Instead, use `imageio` or other I/O packages directly. See also `imread`.
#   ground_truth_img = io.imread(os.path.join(truth_path, truth_files[i]), plugin='tifffile')
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\dl_helper.py:429: FutureWarning: The plugin infrastructure in `skimage.io` and the parameter `plugin` are deprecated since version 0.25 and will be removed in 0.27 (or later). To avoid this warning, please do not use the parameter `plugin`. Instead, use `imageio` or other I/O packages directly. See also `imread`.
#   input_img = io.imread(os.path.join(input_path, input_files[i]), plugin='tifffile')
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\dl_helper.py:430: FutureWarning: The plugin infrastructure in `skimage.io` and the parameter `plugin` are deprecated since version 0.25 and will be removed in 0.27 (or later). To avoid this warning, please do not use the parameter `plugin`. Instead, use `imageio` or other I/O packages directly. See also `imread`.
#   ground_truth_img = io.imread(os.path.join(truth_path, truth_files[i]), plugin='tifffile')
#   6%|▋         | 32/500 [00:03<00:45, 10.31it/s]c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\dl_helper.py:429: FutureWarning: The plugin infrastructure in `skimage.io` and the parameter `plugin` are deprecated since version 0.25 and will be removed in 0.27 (or later). To avoid this warning, please do not use the parameter `plugin`. Instead, use `imageio` or other I/O packages directly. See also `imread`.
#   input_img = io.imread(os.path.join(input_path, input_files[i]), plugin='tifffile')
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\dl_helper.py:430: FutureWarning: The plugin infrastructure in `skimage.io` and the parameter `plugin` are deprecated since version 0.25 and will be removed in 0.27 (or later). To avoid this warning, please do not use the parameter `plugin`. Instead, use `imageio` or other I/O packages directly. See also `imread`.
#   ground_truth_img = io.imread(os.path.join(truth_path, truth_files[i]), plugin='tifffile')
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\dl_helper.py:429: FutureWarning: The plugin infrastructure in `skimage.io` and the parameter `plugin` are deprecated since version 0.25 and will be removed in 0.27 (or later). To avoid this warning, please do not use the parameter `plugin`. Instead, use `imageio` or other I/O packages directly. See also `imread`.
#   input_img = io.imread(os.path.join(input_path, input_files[i]), plugin='tifffile')
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\dl_helper.py:430: FutureWarning: The plugin infrastructure in `skimage.io` and the parameter `plugin` are deprecated since version 0.25 and will be removed in 0.27 (or later). To avoid this warning, please do not use the parameter `plugin`. Instead, use `imageio` or other I/O packages directly. See also `imread`.
#   ground_truth_img = io.imread(os.path.join(truth_path, truth_files[i]), plugin='tifffile')
#   7%|▋         | 34/500 [00:03<00:45, 10.34it/s]c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\dl_helper.py:429: FutureWarning: The plugin infrastructure in `skimage.io` and the parameter `plugin` are deprecated since version 0.25 and will be removed in 0.27 (or later). To avoid this warning, please do not use the parameter `plugin`. Instead, use `imageio` or other I/O packages directly. See also `imread`.
#   input_img = io.imread(os.path.join(input_path, input_files[i]), plugin='tifffile')
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\dl_helper.py:430: FutureWarning: The plugin infrastructure in `skimage.io` and the parameter `plugin` are deprecated since version 0.25 and will be removed in 0.27 (or later). To avoid this warning, please do not use the parameter `plugin`. Instead, use `imageio` or other I/O packages directly. See also `imread`.
#   ground_truth_img = io.imread(os.path.join(truth_path, truth_files[i]), plugin='tifffile')
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\dl_helper.py:429: FutureWarning: The plugin infrastructure in `skimage.io` and the parameter `plugin` are deprecated since version 0.25 and will be removed in 0.27 (or later). To avoid this warning, please do not use the parameter `plugin`. Instead, use `imageio` or other I/O packages directly. See also `imread`.
#   input_img = io.imread(os.path.join(input_path, input_files[i]), plugin='tifffile')
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\dl_helper.py:430: FutureWarning: The plugin infrastructure in `skimage.io` and the parameter `plugin` are deprecated since version 0.25 and will be removed in 0.27 (or later). To avoid this warning, please do not use the parameter `plugin`. Instead, use `imageio` or other I/O packages directly. See also `imread`.
#   ground_truth_img = io.imread(os.path.join(truth_path, truth_files[i]), plugin='tifffile')
#   7%|▋         | 36/500 [00:03<00:38, 12.00it/s]c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\dl_helper.py:429: FutureWarning: The plugin infrastructure in `skimage.io` and the parameter `plugin` are deprecated since version 0.25 and will be removed in 0.27 (or later). To avoid this warning, please do not use the parameter `plugin`. Instead, use `imageio` or other I/O packages directly. See also `imread`.
#   input_img = io.imread(os.path.join(input_path, input_files[i]), plugin='tifffile')
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\dl_helper.py:430: FutureWarning: The plugin infrastructure in `skimage.io` and the parameter `plugin` are deprecated since version 0.25 and will be removed in 0.27 (or later). To avoid this warning, please do not use the parameter `plugin`. Instead, use `imageio` or other I/O packages directly. See also `imread`.
#   ground_truth_img = io.imread(os.path.join(truth_path, truth_files[i]), plugin='tifffile')
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\dl_helper.py:429: FutureWarning: The plugin infrastructure in `skimage.io` and the parameter `plugin` are deprecated since version 0.25 and will be removed in 0.27 (or later). To avoid this warning, please do not use the parameter `plugin`. Instead, use `imageio` or other I/O packages directly. See also `imread`.
#   input_img = io.imread(os.path.join(input_path, input_files[i]), plugin='tifffile')
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\dl_helper.py:430: FutureWarning: The plugin infrastructure in `skimage.io` and the parameter `plugin` are deprecated since version 0.25 and will be removed in 0.27 (or later). To avoid this warning, please do not use the parameter `plugin`. Instead, use `imageio` or other I/O packages directly. See also `imread`.
#   ground_truth_img = io.imread(os.path.join(truth_path, truth_files[i]), plugin='tifffile')
#   8%|▊         | 38/500 [00:03<00:40, 11.41it/s]c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\dl_helper.py:429: FutureWarning: The plugin infrastructure in `skimage.io` and the parameter `plugin` are deprecated since version 0.25 and will be removed in 0.27 (or later). To avoid this warning, please do not use the parameter `plugin`. Instead, use `imageio` or other I/O packages directly. See also `imread`.
#   input_img = io.imread(os.path.join(input_path, input_files[i]), plugin='tifffile')
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\dl_helper.py:430: FutureWarning: The plugin infrastructure in `skimage.io` and the parameter `plugin` are deprecated since version 0.25 and will be removed in 0.27 (or later). To avoid this warning, please do not use the parameter `plugin`. Instead, use `imageio` or other I/O packages directly. See also `imread`.
#   ground_truth_img = io.imread(os.path.join(truth_path, truth_files[i]), plugin='tifffile')
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\dl_helper.py:429: FutureWarning: The plugin infrastructure in `skimage.io` and the parameter `plugin` are deprecated since version 0.25 and will be removed in 0.27 (or later). To avoid this warning, please do not use the parameter `plugin`. Instead, use `imageio` or other I/O packages directly. See also `imread`.
#   input_img = io.imread(os.path.join(input_path, input_files[i]), plugin='tifffile')
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\dl_helper.py:430: FutureWarning: The plugin infrastructure in `skimage.io` and the parameter `plugin` are deprecated since version 0.25 and will be removed in 0.27 (or later). To avoid this warning, please do not use the parameter `plugin`. Instead, use `imageio` or other I/O packages directly. See also `imread`.
#   ground_truth_img = io.imread(os.path.join(truth_path, truth_files[i]), plugin='tifffile')
#   8%|▊         | 40/500 [00:03<00:37, 12.19it/s]c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\dl_helper.py:429: FutureWarning: The plugin infrastructure in `skimage.io` and the parameter `plugin` are deprecated since version 0.25 and will be removed in 0.27 (or later). To avoid this warning, please do not use the parameter `plugin`. Instead, use `imageio` or other I/O packages directly. See also `imread`.
#   input_img = io.imread(os.path.join(input_path, input_files[i]), plugin='tifffile')
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\dl_helper.py:430: FutureWarning: The plugin infrastructure in `skimage.io` and the parameter `plugin` are deprecated since version 0.25 and will be removed in 0.27 (or later). To avoid this warning, please do not use the parameter `plugin`. Instead, use `imageio` or other I/O packages directly. See also `imread`.
#   ground_truth_img = io.imread(os.path.join(truth_path, truth_files[i]), plugin='tifffile')
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\dl_helper.py:429: FutureWarning: The plugin infrastructure in `skimage.io` and the parameter `plugin` are deprecated since version 0.25 and will be removed in 0.27 (or later). To avoid this warning, please do not use the parameter `plugin`. Instead, use `imageio` or other I/O packages directly. See also `imread`.
#   input_img = io.imread(os.path.join(input_path, input_files[i]), plugin='tifffile')
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\dl_helper.py:430: FutureWarning: The plugin infrastructure in `skimage.io` and the parameter `plugin` are deprecated since version 0.25 and will be removed in 0.27 (or later). To avoid this warning, please do not use the parameter `plugin`. Instead, use `imageio` or other I/O packages directly. See also `imread`.
#   ground_truth_img = io.imread(os.path.join(truth_path, truth_files[i]), plugin='tifffile')
#   8%|▊         | 42/500 [00:04<00:37, 12.06it/s]c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\dl_helper.py:429: FutureWarning: The plugin infrastructure in `skimage.io` and the parameter `plugin` are deprecated since version 0.25 and will be removed in 0.27 (or later). To avoid this warning, please do not use the parameter `plugin`. Instead, use `imageio` or other I/O packages directly. See also `imread`.
#   input_img = io.imread(os.path.join(input_path, input_files[i]), plugin='tifffile')
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\dl_helper.py:430: FutureWarning: The plugin infrastructure in `skimage.io` and the parameter `plugin` are deprecated since version 0.25 and will be removed in 0.27 (or later). To avoid this warning, please do not use the parameter `plugin`. Instead, use `imageio` or other I/O packages directly. See also `imread`.
#   ground_truth_img = io.imread(os.path.join(truth_path, truth_files[i]), plugin='tifffile')
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\dl_helper.py:429: FutureWarning: The plugin infrastructure in `skimage.io` and the parameter `plugin` are deprecated since version 0.25 and will be removed in 0.27 (or later). To avoid this warning, please do not use the parameter `plugin`. Instead, use `imageio` or other I/O packages directly. See also `imread`.
#   input_img = io.imread(os.path.join(input_path, input_files[i]), plugin='tifffile')
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\dl_helper.py:430: FutureWarning: The plugin infrastructure in `skimage.io` and the parameter `plugin` are deprecated since version 0.25 and will be removed in 0.27 (or later). To avoid this warning, please do not use the parameter `plugin`. Instead, use `imageio` or other I/O packages directly. See also `imread`.
#   ground_truth_img = io.imread(os.path.join(truth_path, truth_files[i]), plugin='tifffile')
#   9%|▉         | 44/500 [00:04<00:38, 11.84it/s]c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\dl_helper.py:429: FutureWarning: The plugin infrastructure in `skimage.io` and the parameter `plugin` are deprecated since version 0.25 and will be removed in 0.27 (or later). To avoid this warning, please do not use the parameter `plugin`. Instead, use `imageio` or other I/O packages directly. See also `imread`.
#   input_img = io.imread(os.path.join(input_path, input_files[i]), plugin='tifffile')
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\dl_helper.py:430: FutureWarning: The plugin infrastructure in `skimage.io` and the parameter `plugin` are deprecated since version 0.25 and will be removed in 0.27 (or later). To avoid this warning, please do not use the parameter `plugin`. Instead, use `imageio` or other I/O packages directly. See also `imread`.
#   ground_truth_img = io.imread(os.path.join(truth_path, truth_files[i]), plugin='tifffile')
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\dl_helper.py:429: FutureWarning: The plugin infrastructure in `skimage.io` and the parameter `plugin` are deprecated since version 0.25 and will be removed in 0.27 (or later). To avoid this warning, please do not use the parameter `plugin`. Instead, use `imageio` or other I/O packages directly. See also `imread`.
#   input_img = io.imread(os.path.join(input_path, input_files[i]), plugin='tifffile')
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\dl_helper.py:430: FutureWarning: The plugin infrastructure in `skimage.io` and the parameter `plugin` are deprecated since version 0.25 and will be removed in 0.27 (or later). To avoid this warning, please do not use the parameter `plugin`. Instead, use `imageio` or other I/O packages directly. See also `imread`.
#   ground_truth_img = io.imread(os.path.join(truth_path, truth_files[i]), plugin='tifffile')
#   9%|▉         | 46/500 [00:04<00:35, 12.94it/s]c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\dl_helper.py:429: FutureWarning: The plugin infrastructure in `skimage.io` and the parameter `plugin` are deprecated since version 0.25 and will be removed in 0.27 (or later). To avoid this warning, please do not use the parameter `plugin`. Instead, use `imageio` or other I/O packages directly. See also `imread`.
#   input_img = io.imread(os.path.join(input_path, input_files[i]), plugin='tifffile')
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\dl_helper.py:430: FutureWarning: The plugin infrastructure in `skimage.io` and the parameter `plugin` are deprecated since version 0.25 and will be removed in 0.27 (or later). To avoid this warning, please do not use the parameter `plugin`. Instead, use `imageio` or other I/O packages directly. See also `imread`.
#   ground_truth_img = io.imread(os.path.join(truth_path, truth_files[i]), plugin='tifffile')
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\dl_helper.py:429: FutureWarning: The plugin infrastructure in `skimage.io` and the parameter `plugin` are deprecated since version 0.25 and will be removed in 0.27 (or later). To avoid this warning, please do not use the parameter `plugin`. Instead, use `imageio` or other I/O packages directly. See also `imread`.
#   input_img = io.imread(os.path.join(input_path, input_files[i]), plugin='tifffile')
# c:\users\bnort\work\imagej2022\tnia\tnia-python\tnia\deeplearning\dl_helper.py:430: FutureWarning: The plugin infrastructure in `skimage.io` and the parameter `plugin` are deprecated since version 0.25 and will be removed in 0.27 (or later). To avoid this warning, please do not use the parameter `plugin`. Instead, use `imageio` or other I/O packages directly. See also `imread`.
#   ground_truth_img = io.imread(os.path.join(truth_path, truth_files[i]), plugin='tifffile')
# ...
#   return func(*args, **kwargs)
# c:\Users\bnort\miniconda3\envs\microsam_cellpose\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: D:\images\tnia-python-images\imagesc\2025_04_30_scale\predictions\class_0\image (3).tif is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\bnort\miniconda3\envs\microsam_cellpose\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: D:\images\tnia-python-images\imagesc\2025_04_30_scale\annotations\class_0\VRBD_07.tif is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\bnort\miniconda3\envs\microsam_cellpose\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: D:\images\tnia-python-images\imagesc\2025_04_30_scale\predictions\class_0\VRBD_07.tif is a low contrast image
#   return func(*args, **kwargs)
# Deleted file: D:\images\tnia-python-images\imagesc\2025_04_30_scale\labels\input0\image (3)_00000.json
# Deleted file: D:\images\tnia-python-images\imagesc\2025_04_30_scale\labels\input0\image (3)_00000.tif
# Deleted file: D:\images\tnia-python-images\imagesc\2025_04_30_scale\labels\input0\image (3)_00001.json
# Deleted file: D:\images\tnia-python-images\imagesc\2025_04_30_scale\labels\input0\image (3)_00001.tif
# Deleted file: D:\images\tnia-python-images\imagesc\2025_04_30_scale\labels\input0\VRBD_07_00000.json
# Deleted file: D:\images\tnia-python-images\imagesc\2025_04_30_scale\labels\input0\VRBD_07_00000.tif
# Deleted file: D:\images\tnia-python-images\imagesc\2025_04_30_scale\labels\ground truth0\image (3)_00000.tif
# Deleted file: D:\images\tnia-python-images\imagesc\2025_04_30_scale\labels\ground truth0\image (3)_00001.tif
# Deleted file: D:\images\tnia-python-images\imagesc\2025_04_30_scale\labels\ground truth0\VRBD_07_00000.tif
# image file is  D:\images\tnia-python-images\imagesc\2025_04_30_scale\image (3).jpg
# labelsum is  2963175
# (386, 622, 3) (386, 622)
# image (3)_00000
# D:\images\tnia-python-images\imagesc\2025_04_30_scale\labels\input0/image (3)_00000.tif
# D:\images\tnia-python-images\imagesc\2025_04_30_scale\labels\ground truth0/image (3)_00000.tif
# D:\images\tnia-python-images\imagesc\2025_04_30_scale\labels\input0/image (3)_00000.tif
# D:\images\tnia-python-images\imagesc\2025_04_30_scale\labels\ground truth0
# image file is  D:\images\tnia-python-images\imagesc\2025_04_30_scale\image (3).jpg
# labelsum is  2959444
# (372, 283, 3) (372, 283)
# image (3)_00001
# D:\images\tnia-python-images\imagesc\2025_04_30_scale\labels\input0/image (3)_00001.tif
# D:\images\tnia-python-images\imagesc\2025_04_30_scale\labels\ground truth0/image (3)_00001.tif
# D:\images\tnia-python-images\imagesc\2025_04_30_scale\labels\input0/image (3)_00001.tif
# D:\images\tnia-python-images\imagesc\2025_04_30_scale\labels\ground truth0
# image file is  D:\images\tnia-python-images\imagesc\2025_04_30_scale\VRBD_07.png
# labelsum is  568525
# (387, 461, 3) (387, 461)
# VRBD_07_00000
# D:\images\tnia-python-images\imagesc\2025_04_30_scale\labels\input0/VRBD_07_00000.tif
# D:\images\tnia-python-images\imagesc\2025_04_30_scale\labels\ground truth0/VRBD_07_00000.tif
# D:\images\tnia-python-images\imagesc\2025_04_30_scale\labels\input0/VRBD_07_00000.tif
# D:\images\tnia-python-images\imagesc\2025_04_30_scale\labels\ground truth0
# image file is  D:\images\tnia-python-images\imagesc\2025_04_30_scale\A2_10.png
# labelsum is  0
# (316, 0, 3) (316, 0)
# A2_10_00000
# D:\images\tnia-python-images\imagesc\2025_04_30_scale\labels\input0/A2_10_00000.tif
# D:\images\tnia-python-images\imagesc\2025_04_30_scale\labels\ground truth0/A2_10_00000.tif
# error saving bounding box
# c:\Users\bnort\miniconda3\envs\microsam_cellpose\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: D:\images\tnia-python-images\imagesc\2025_04_30_scale\labels\ground truth0\image (3)_00000.tif is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\bnort\miniconda3\envs\microsam_cellpose\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: D:\images\tnia-python-images\imagesc\2025_04_30_scale\labels\ground truth0\image (3)_00001.tif is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\bnort\miniconda3\envs\microsam_cellpose\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: D:\images\tnia-python-images\imagesc\2025_04_30_scale\labels\ground truth0\VRBD_07_00000.tif is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\bnort\miniconda3\envs\microsam_cellpose\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: D:\images\tnia-python-images\imagesc\2025_04_30_scale\annotations\class_0\A2_10.tif is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\bnort\miniconda3\envs\microsam_cellpose\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: D:\images\tnia-python-images\imagesc\2025_04_30_scale\predictions\class_0\A2_10.tif is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\bnort\miniconda3\envs\microsam_cellpose\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: D:\images\tnia-python-images\imagesc\2025_04_30_scale\annotations\class_0\image (3).tif is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\bnort\miniconda3\envs\microsam_cellpose\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: D:\images\tnia-python-images\imagesc\2025_04_30_scale\predictions\class_0\image (3).tif is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\bnort\miniconda3\envs\microsam_cellpose\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: D:\images\tnia-python-images\imagesc\2025_04_30_scale\annotations\class_0\VRBD_07.tif is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\bnort\miniconda3\envs\microsam_cellpose\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: D:\images\tnia-python-images\imagesc\2025_04_30_scale\predictions\class_0\VRBD_07.tif is a low contrast image
#   return func(*args, **kwargs)
# Deleted file: D:\images\tnia-python-images\imagesc\2025_04_30_scale\labels\ground truth0\image (3)_00000.tif
# Deleted file: D:\images\tnia-python-images\imagesc\2025_04_30_scale\labels\ground truth0\image (3)_00001.tif
# Deleted file: D:\images\tnia-python-images\imagesc\2025_04_30_scale\labels\ground truth0\VRBD_07_00000.tif
# image file is  D:\images\tnia-python-images\imagesc\2025_04_30_scale\image (3).jpg
# labelsum is  2963175
# (386, 622, 3) (386, 622)
# image (3)_00000
# D:\images\tnia-python-images\imagesc\2025_04_30_scale\labels\input0/image (3)_00000.tif
# D:\images\tnia-python-images\imagesc\2025_04_30_scale\labels\ground truth0/image (3)_00000.tif
# D:\images\tnia-python-images\imagesc\2025_04_30_scale\labels\input0/image (3)_00000.tif
# D:\images\tnia-python-images\imagesc\2025_04_30_scale\labels\ground truth0
# image file is  D:\images\tnia-python-images\imagesc\2025_04_30_scale\image (3).jpg
# labelsum is  2959444
# (372, 283, 3) (372, 283)
# image (3)_00001
# D:\images\tnia-python-images\imagesc\2025_04_30_scale\labels\input0/image (3)_00001.tif
# D:\images\tnia-python-images\imagesc\2025_04_30_scale\labels\ground truth0/image (3)_00001.tif
# D:\images\tnia-python-images\imagesc\2025_04_30_scale\labels\input0/image (3)_00001.tif
# D:\images\tnia-python-images\imagesc\2025_04_30_scale\labels\ground truth0
# image file is  D:\images\tnia-python-images\imagesc\2025_04_30_scale\VRBD_07.png
# labelsum is  568525
# (387, 461, 3) (387, 461)
# VRBD_07_00000
# D:\images\tnia-python-images\imagesc\2025_04_30_scale\labels\input0/VRBD_07_00000.tif
# D:\images\tnia-python-images\imagesc\2025_04_30_scale\labels\ground truth0/VRBD_07_00000.tif
# D:\images\tnia-python-images\imagesc\2025_04_30_scale\labels\input0/VRBD_07_00000.tif
# D:\images\tnia-python-images\imagesc\2025_04_30_scale\labels\ground truth0
# image file is  D:\images\tnia-python-images\imagesc\2025_04_30_scale\A2_10.png
# labelsum is  0
# (316, 0, 3) (316, 0)
# A2_10_00000
# D:\images\tnia-python-images\imagesc\2025_04_30_scale\labels\input0/A2_10_00000.tif
# D:\images\tnia-python-images\imagesc\2025_04_30_scale\labels\ground truth0/A2_10_00000.tif
# error saving bounding box
# c:\Users\bnort\miniconda3\envs\microsam_cellpose\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: D:\images\tnia-python-images\imagesc\2025_04_30_scale\labels\ground truth0\image (3)_00000.tif is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\bnort\miniconda3\envs\microsam_cellpose\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: D:\images\tnia-python-images\imagesc\2025_04_30_scale\labels\ground truth0\image (3)_00001.tif is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\bnort\miniconda3\envs\microsam_cellpose\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: D:\images\tnia-python-images\imagesc\2025_04_30_scale\labels\ground truth0\VRBD_07_00000.tif is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\bnort\miniconda3\envs\microsam_cellpose\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: D:\images\tnia-python-images\imagesc\2025_04_30_scale\annotations\class_0\A2_10.tif is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\bnort\miniconda3\envs\microsam_cellpose\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: D:\images\tnia-python-images\imagesc\2025_04_30_scale\predictions\class_0\A2_10.tif is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\bnort\miniconda3\envs\microsam_cellpose\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: D:\images\tnia-python-images\imagesc\2025_04_30_scale\annotations\class_0\image (3).tif is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\bnort\miniconda3\envs\microsam_cellpose\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: D:\images\tnia-python-images\imagesc\2025_04_30_scale\predictions\class_0\image (3).tif is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\bnort\miniconda3\envs\microsam_cellpose\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: D:\images\tnia-python-images\imagesc\2025_04_30_scale\annotations\class_0\VRBD_07.tif is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\bnort\miniconda3\envs\microsam_cellpose\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: D:\images\tnia-python-images\imagesc\2025_04_30_scale\predictions\class_0\VRBD_07.tif is a low contrast image
#   return func(*args, **kwargs)
# Data changed
# Data changed
# Deleted file: D:\images\tnia-python-images\imagesc\2025_04_30_scale\labels\input0\image (3)_00000.json
# Deleted file: D:\images\tnia-python-images\imagesc\2025_04_30_scale\labels\input0\image (3)_00000.tif
# Deleted file: D:\images\tnia-python-images\imagesc\2025_04_30_scale\labels\input0\image (3)_00001.json
# Deleted file: D:\images\tnia-python-images\imagesc\2025_04_30_scale\labels\input0\image (3)_00001.tif
# Deleted file: D:\images\tnia-python-images\imagesc\2025_04_30_scale\labels\input0\VRBD_07_00000.json
# Deleted file: D:\images\tnia-python-images\imagesc\2025_04_30_scale\labels\input0\VRBD_07_00000.tif
# Deleted file: D:\images\tnia-python-images\imagesc\2025_04_30_scale\labels\ground truth0\image (3)_00000.tif
# Deleted file: D:\images\tnia-python-images\imagesc\2025_04_30_scale\labels\ground truth0\image (3)_00001.tif
# Deleted file: D:\images\tnia-python-images\imagesc\2025_04_30_scale\labels\ground truth0\VRBD_07_00000.tif
# image file is  D:\images\tnia-python-images\imagesc\2025_04_30_scale\image (3).jpg
# labelsum is  2963175
# (386, 622, 3) (386, 622)
# image (3)_00000
# D:\images\tnia-python-images\imagesc\2025_04_30_scale\labels\input0/image (3)_00000.tif
# D:\images\tnia-python-images\imagesc\2025_04_30_scale\labels\ground truth0/image (3)_00000.tif
# D:\images\tnia-python-images\imagesc\2025_04_30_scale\labels\input0/image (3)_00000.tif
# D:\images\tnia-python-images\imagesc\2025_04_30_scale\labels\ground truth0
# image file is  D:\images\tnia-python-images\imagesc\2025_04_30_scale\image (3).jpg
# labelsum is  2959444
# (372, 283, 3) (372, 283)
# image (3)_00001
# D:\images\tnia-python-images\imagesc\2025_04_30_scale\labels\input0/image (3)_00001.tif
# D:\images\tnia-python-images\imagesc\2025_04_30_scale\labels\ground truth0/image (3)_00001.tif
# D:\images\tnia-python-images\imagesc\2025_04_30_scale\labels\input0/image (3)_00001.tif
# D:\images\tnia-python-images\imagesc\2025_04_30_scale\labels\ground truth0
# image file is  D:\images\tnia-python-images\imagesc\2025_04_30_scale\VRBD_07.png
# labelsum is  568525
# (387, 461, 3) (387, 461)
# VRBD_07_00000
# D:\images\tnia-python-images\imagesc\2025_04_30_scale\labels\input0/VRBD_07_00000.tif
# D:\images\tnia-python-images\imagesc\2025_04_30_scale\labels\ground truth0/VRBD_07_00000.tif
# D:\images\tnia-python-images\imagesc\2025_04_30_scale\labels\input0/VRBD_07_00000.tif
# D:\images\tnia-python-images\imagesc\2025_04_30_scale\labels\ground truth0
# image file is  D:\images\tnia-python-images\imagesc\2025_04_30_scale\A2_10.png
# labelsum is  6493
# (316, 322, 3) (316, 322)
# A2_10_00000
# D:\images\tnia-python-images\imagesc\2025_04_30_scale\labels\input0/A2_10_00000.tif
# D:\images\tnia-python-images\imagesc\2025_04_30_scale\labels\ground truth0/A2_10_00000.tif
# D:\images\tnia-python-images\imagesc\2025_04_30_scale\labels\input0/A2_10_00000.tif
# D:\images\tnia-python-images\imagesc\2025_04_30_scale\labels\ground truth0
# c:\Users\bnort\miniconda3\envs\microsam_cellpose\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: D:\images\tnia-python-images\imagesc\2025_04_30_scale\labels\ground truth0\image (3)_00000.tif is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\bnort\miniconda3\envs\microsam_cellpose\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: D:\images\tnia-python-images\imagesc\2025_04_30_scale\labels\ground truth0\image (3)_00001.tif is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\bnort\miniconda3\envs\microsam_cellpose\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: D:\images\tnia-python-images\imagesc\2025_04_30_scale\labels\ground truth0\VRBD_07_00000.tif is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\bnort\miniconda3\envs\microsam_cellpose\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: D:\images\tnia-python-images\imagesc\2025_04_30_scale\labels\ground truth0\A2_10_00000.tif is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\bnort\miniconda3\envs\microsam_cellpose\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: D:\images\tnia-python-images\imagesc\2025_04_30_scale\annotations\class_0\A2_10.tif is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\bnort\miniconda3\envs\microsam_cellpose\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: D:\images\tnia-python-images\imagesc\2025_04_30_scale\predictions\class_0\A2_10.tif is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\bnort\miniconda3\envs\microsam_cellpose\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: D:\images\tnia-python-images\imagesc\2025_04_30_scale\annotations\class_0\image (3).tif is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\bnort\miniconda3\envs\microsam_cellpose\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: D:\images\tnia-python-images\imagesc\2025_04_30_scale\predictions\class_0\image (3).tif is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\bnort\miniconda3\envs\microsam_cellpose\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: D:\images\tnia-python-images\imagesc\2025_04_30_scale\annotations\class_0\VRBD_07.tif is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\bnort\miniconda3\envs\microsam_cellpose\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: D:\images\tnia-python-images\imagesc\2025_04_30_scale\predictions\class_0\VRBD_07.tif is a low contrast image
#   return func(*args, **kwargs)
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import numpy
numpy.__version__

# %%
import cellpose

cellpose.version

# %%
import micro_sam
micro_sam.__version__
