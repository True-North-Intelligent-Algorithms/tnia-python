# %% [markdown]
# ## Train a semantic segmentation unet using Pytorch

# %% [markdown]
# ## Pytorch setup
#
# setting up environment (Windows 10 with Cuda 11.8)
#
# ```
# conda create --name pytorch_tests python=3.10
# conda activate pytorch_tests
# conda install pip
# pip install pykernel
# pip3 install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118
# pip install pytorch-lightning
# pip install monai
# pip install scipy
# pip install tifffile
# pip install matplotlib
# ```

# %% [markdown]
# ## Imports

# %%
from tifffile import imread
from tqdm import tqdm
from tnia.deeplearning.dl_helper import quantile_normalization
import matplotlib.pyplot as plt
import numpy as np
import torch

from torchvision import transforms
from torchvision.transforms import v2
import torchvision.transforms.functional as TF

# %% [markdown]
# ## Check if GPU is present

# %%
cuda_present = torch.cuda.is_available()
ndevices = torch.cuda.device_count()
use_cuda = cuda_present and ndevices > 0
device = torch.device("cuda" if use_cuda else "cpu")  # "cuda:0" ... default device, "cuda:1" would be GPU index 1, "cuda:2" etc
print("number of devices:", ndevices, "\tchosen device:", device, "\tuse_cuda=", use_cuda)
# Out:
# number of devices: 1 	chosen device: cuda 	use_cuda= True

# %% [markdown]
# ## Set up patch directories

# %%
from pathlib import Path
import json

tnia_images_path = Path("D:/images/tnia-python-images")
parent_path=Path(tnia_images_path / r'imagesc/2024_05_07_ct_scan')

patch_path= parent_path / 'patches' 

with open(patch_path / 'info.json', 'r') as json_file:
    data = json.load(json_file)
    sub_sample = data.get('sub_sample',1)
    print('sub_sample',sub_sample)
    axes = data['axes']
    print('axes',axes)
    num_inputs = data['num_inputs']
    print('num_inputs',num_inputs)
    num_truths = data['num_truths']
    print('num_truths',num_truths)


image_patch_path = patch_path / 'ground truth0'
label_patch_path = patch_path / 'input0'

from glob import glob

tif_files = glob(str(image_patch_path / '*.tif'))

first_im = imread(tif_files[0])
target_shape=first_im.shape

if axes == 'YX':
    num_in_channels=1
else:
    num_in_channels=3
# Out:
# sub_sample 1
# axes YX
# num_inputs 1
# num_truths 1

# %% [markdown]
# ## Create a PyTorch Dataset
#
# Dataset is simply used to retrieve the training patches.  In this case we just set it up to read in image files, then convert the numpy arrays to tensors and a torch stack.
#
# In this example augmentation was done in a previous notebook, and the augmented images explicitly saved.  It is also possible to do augmentation as the data is retrieved.  So in the future the ```MyDataSet``` could be extended to apply augmentation as data is retrieved.

# %%
class MyDataSet():

    def __init__(self, image_files, label_files_list, target_shape=target_shape):
            """
            Parameters
            ----------
            image_files: list of pathlib.Path objects pointing to the *.tif images
            label_files_list: list of lists of pathlib.Path objects pointing to the *.tif segmentation masks
                        there are mulitple lists of label files each potentially representing one class
            target_shape: tuple of length 2 specifying the sample resolutions of files that
                        will be kept. All other files will NOT be used.
            """
            assert len(image_files) == len(label_files_list[0])
            assert all(x.name==y.name for x,y in zip(image_files, label_files_list[0]))

            self.images = []
            self.labels = []

            tensor_transform = transforms.Compose([
                v2.ToTensor(),
            ])

            # use tqdm to have eye pleasing error bars
            for idx in tqdm(range(len(image_files))):
                # we use the same data reading approach as in the previous notebook
                image = imread(image_files[idx])

                labels = []               
                for label_files in label_files_list:
                    label = imread(label_files[idx])
                    labels.append(label)

                if image.shape != target_shape:
                    continue
                
                # NOTE: we convert the label to dtype float32 and not uint8 because
                # the tensor transformation does a normalization if the input is of
                # dtype uint8, destroying the 0/1 labelling which we want to avoid.
                # label = fill_label_holes(label)
                
                labels_binary = []

                for label in labels:
                    label_binary = np.zeros_like(label).astype(np.float32)
                    label_binary[label != 0] = 1.
                    labels_binary.append(label_binary)

                # convert to torch tensor: adds an artificial color channel in the front
                # and scales inputs to have same size as samples tend to differ in image
                # resolutions
                image = tensor_transform(image)
                labels_binary = np.stack(labels_binary, axis=2)
                label = tensor_transform(labels_binary)

                self.images.append(image)
                self.labels.append(label)

            self.images = torch.stack(self.images)
            self.labels = torch.stack(self.labels)
    
    def __getitem__(self, idx):
        return self.images[idx], self.labels[idx]

    def __len__(self):
        return len(self.images)

# %% [markdown]
# ## Initialize the DataSet
#
# Initialize the DataSet with the pre-generated patch names

# %%
src_dir = patch_path

assert src_dir.exists(), f"root directory with images and masks {src_dir} does not exist"

X = sorted(src_dir.rglob('**/input0/*.tif'))

Y = []
for i in range(num_truths):
    Y.append(sorted(src_dir.rglob(f'**/ground truth{i}/*.tif')))

train_data = MyDataSet(
    image_files=X,
    label_files_list=Y,
    target_shape=target_shape
)

# NOTE: the length of the dataset might not be the same as n_samples
#       because files not having the target shape will be discarded
print(len(train_data))
# Out:
# 100%|██████████| 600/600 [00:02<00:00, 262.53it/s]
# 600

# %% [markdown]
# ## Create a DataLoader
#
# This is done so we can load batches of images.

# %%
from torch.utils.data import DataLoader

train_loader = DataLoader(train_data, batch_size=32, shuffle=True)

# %% [markdown]
# ## Create a UNET

# %%
from monai.networks.nets import BasicUNet

model = BasicUNet(
    spatial_dims=2,
    in_channels=num_in_channels,
    out_channels=num_truths,
    #features=[16, 16, 32, 64, 128, 16],
    act="relu",
    norm="batch",
    dropout=0.25,
)

# Important: transfer the model to the chosen device
model = model.to(device)

optimizer = torch.optim.Adam(model.parameters(), lr=1.e-3)
init_params = list(model.parameters())[0].clone().detach()
# Out:
# BasicUNet features: (32, 32, 64, 128, 256, 32).

# %% [markdown]
# ## Train the UNET

# %%
max_nepochs = 200 
log_interval = 20
model.train(True)

# BCEWithLogitsLoss combines sigmoid + BCELoss for better
# numerical stability. It expects raw unnormalized scores as input which are shaped like 
# B x C x W x D
loss_function = torch.nn.BCEWithLogitsLoss(reduction="mean")

for epoch in range(1, max_nepochs + 1):
    for batch_idx, (X, y) in enumerate(train_loader):
        # the inputs and labels have to be on the same device as the model
        X, y = X.to(device), y.to(device)
        
        optimizer.zero_grad()

        prediction_logits = model(X)
        
        batch_loss = loss_function(prediction_logits, y)

        batch_loss.backward()

        optimizer.step()

        if batch_idx % log_interval == 0:
            print(
                "Train Epoch:",
                epoch,
                "Batch:",
                batch_idx,
                "Total samples processed:",
                (batch_idx + 1) * train_loader.batch_size,
                "Loss:",
                batch_loss.item(),
            )
# Out:
# Train Epoch: 1 Batch: 0 Total samples processed: 32 Loss: 0.790025532245636
# Train Epoch: 2 Batch: 0 Total samples processed: 32 Loss: 0.4513431191444397
# Train Epoch: 3 Batch: 0 Total samples processed: 32 Loss: 0.37594878673553467
# Train Epoch: 4 Batch: 0 Total samples processed: 32 Loss: 0.31710219383239746
# Train Epoch: 5 Batch: 0 Total samples processed: 32 Loss: 0.28311145305633545
# Train Epoch: 6 Batch: 0 Total samples processed: 32 Loss: 0.2518812417984009
# Train Epoch: 7 Batch: 0 Total samples processed: 32 Loss: 0.23119693994522095
# Train Epoch: 8 Batch: 0 Total samples processed: 32 Loss: 0.21906507015228271
# Train Epoch: 9 Batch: 0 Total samples processed: 32 Loss: 0.19995760917663574
# Train Epoch: 10 Batch: 0 Total samples processed: 32 Loss: 0.19475339353084564
# Train Epoch: 11 Batch: 0 Total samples processed: 32 Loss: 0.1985943764448166
# Train Epoch: 12 Batch: 0 Total samples processed: 32 Loss: 0.15753433108329773
# Train Epoch: 13 Batch: 0 Total samples processed: 32 Loss: 0.180916428565979
# Train Epoch: 14 Batch: 0 Total samples processed: 32 Loss: 0.1691460907459259
# Train Epoch: 15 Batch: 0 Total samples processed: 32 Loss: 0.15627023577690125
# Train Epoch: 16 Batch: 0 Total samples processed: 32 Loss: 0.17307421565055847
# Train Epoch: 17 Batch: 0 Total samples processed: 32 Loss: 0.16242824494838715
# Train Epoch: 18 Batch: 0 Total samples processed: 32 Loss: 0.15184837579727173
# Train Epoch: 19 Batch: 0 Total samples processed: 32 Loss: 0.16679662466049194
# Train Epoch: 20 Batch: 0 Total samples processed: 32 Loss: 0.14230263233184814
# Train Epoch: 21 Batch: 0 Total samples processed: 32 Loss: 0.14035458862781525
# Train Epoch: 22 Batch: 0 Total samples processed: 32 Loss: 0.14851200580596924
# Train Epoch: 23 Batch: 0 Total samples processed: 32 Loss: 0.13973793387413025
# Train Epoch: 24 Batch: 0 Total samples processed: 32 Loss: 0.12118909507989883
# Train Epoch: 25 Batch: 0 Total samples processed: 32 Loss: 0.12829893827438354
# Train Epoch: 26 Batch: 0 Total samples processed: 32 Loss: 0.14583206176757812
# Train Epoch: 27 Batch: 0 Total samples processed: 32 Loss: 0.14134928584098816
# Train Epoch: 28 Batch: 0 Total samples processed: 32 Loss: 0.11974688619375229
# Train Epoch: 29 Batch: 0 Total samples processed: 32 Loss: 0.1251876950263977
# Train Epoch: 30 Batch: 0 Total samples processed: 32 Loss: 0.12795352935791016
# Train Epoch: 31 Batch: 0 Total samples processed: 32 Loss: 0.11229437589645386
# Train Epoch: 32 Batch: 0 Total samples processed: 32 Loss: 0.10857085883617401
# Train Epoch: 33 Batch: 0 Total samples processed: 32 Loss: 0.12005282938480377
# Train Epoch: 34 Batch: 0 Total samples processed: 32 Loss: 0.1062752902507782
# Train Epoch: 35 Batch: 0 Total samples processed: 32 Loss: 0.10609374940395355
# Train Epoch: 36 Batch: 0 Total samples processed: 32 Loss: 0.10540183633565903
# Train Epoch: 37 Batch: 0 Total samples processed: 32 Loss: 0.1037580817937851
# Train Epoch: 38 Batch: 0 Total samples processed: 32 Loss: 0.09218037128448486
# Train Epoch: 39 Batch: 0 Total samples processed: 32 Loss: 0.09627868235111237
# Train Epoch: 40 Batch: 0 Total samples processed: 32 Loss: 0.09052464365959167
# Train Epoch: 41 Batch: 0 Total samples processed: 32 Loss: 0.09171402454376221
# Train Epoch: 42 Batch: 0 Total samples processed: 32 Loss: 0.08819274604320526
# Train Epoch: 43 Batch: 0 Total samples processed: 32 Loss: 0.08178645372390747
# Train Epoch: 44 Batch: 0 Total samples processed: 32 Loss: 0.08594700694084167
# Train Epoch: 45 Batch: 0 Total samples processed: 32 Loss: 0.06774333864450455
# Train Epoch: 46 Batch: 0 Total samples processed: 32 Loss: 0.07629291713237762
# Train Epoch: 47 Batch: 0 Total samples processed: 32 Loss: 0.07544461637735367
# Train Epoch: 48 Batch: 0 Total samples processed: 32 Loss: 0.07590029388666153
# Train Epoch: 49 Batch: 0 Total samples processed: 32 Loss: 0.08117818087339401
# Train Epoch: 50 Batch: 0 Total samples processed: 32 Loss: 0.071439728140831
# Train Epoch: 51 Batch: 0 Total samples processed: 32 Loss: 0.06968946754932404
# Train Epoch: 52 Batch: 0 Total samples processed: 32 Loss: 0.07868508994579315
# Train Epoch: 53 Batch: 0 Total samples processed: 32 Loss: 0.07048800587654114
# Train Epoch: 54 Batch: 0 Total samples processed: 32 Loss: 0.06785920262336731
# Train Epoch: 55 Batch: 0 Total samples processed: 32 Loss: 0.057750411331653595
# Train Epoch: 56 Batch: 0 Total samples processed: 32 Loss: 0.08075248450040817
# Train Epoch: 57 Batch: 0 Total samples processed: 32 Loss: 0.0677821934223175
# Train Epoch: 58 Batch: 0 Total samples processed: 32 Loss: 0.059810787439346313
# Train Epoch: 59 Batch: 0 Total samples processed: 32 Loss: 0.05995041877031326
# Train Epoch: 60 Batch: 0 Total samples processed: 32 Loss: 0.05857561528682709
# Train Epoch: 61 Batch: 0 Total samples processed: 32 Loss: 0.05716127157211304
# Train Epoch: 62 Batch: 0 Total samples processed: 32 Loss: 0.07010841369628906
# Train Epoch: 63 Batch: 0 Total samples processed: 32 Loss: 0.05923212692141533
# Train Epoch: 64 Batch: 0 Total samples processed: 32 Loss: 0.058884717524051666
# Train Epoch: 65 Batch: 0 Total samples processed: 32 Loss: 0.04956815391778946
# Train Epoch: 66 Batch: 0 Total samples processed: 32 Loss: 0.05227148160338402
# Train Epoch: 67 Batch: 0 Total samples processed: 32 Loss: 0.05329766124486923
# Train Epoch: 68 Batch: 0 Total samples processed: 32 Loss: 0.05164003744721413
# Train Epoch: 69 Batch: 0 Total samples processed: 32 Loss: 0.04544858634471893
# Train Epoch: 70 Batch: 0 Total samples processed: 32 Loss: 0.04518236964941025
# Train Epoch: 71 Batch: 0 Total samples processed: 32 Loss: 0.050102751702070236
# Train Epoch: 72 Batch: 0 Total samples processed: 32 Loss: 0.046563584357500076
# Train Epoch: 73 Batch: 0 Total samples processed: 32 Loss: 0.04354287311434746
# Train Epoch: 74 Batch: 0 Total samples processed: 32 Loss: 0.0446908101439476
# Train Epoch: 75 Batch: 0 Total samples processed: 32 Loss: 0.051373086869716644
# Train Epoch: 76 Batch: 0 Total samples processed: 32 Loss: 0.04396354407072067
# Train Epoch: 77 Batch: 0 Total samples processed: 32 Loss: 0.04791717231273651
# Train Epoch: 78 Batch: 0 Total samples processed: 32 Loss: 0.038769252598285675
# Train Epoch: 79 Batch: 0 Total samples processed: 32 Loss: 0.04470435529947281
# Train Epoch: 80 Batch: 0 Total samples processed: 32 Loss: 0.046364933252334595
# Train Epoch: 81 Batch: 0 Total samples processed: 32 Loss: 0.04473233222961426
# Train Epoch: 82 Batch: 0 Total samples processed: 32 Loss: 0.04328599572181702
# Train Epoch: 83 Batch: 0 Total samples processed: 32 Loss: 0.03995238244533539
# Train Epoch: 84 Batch: 0 Total samples processed: 32 Loss: 0.04252302274107933
# Train Epoch: 85 Batch: 0 Total samples processed: 32 Loss: 0.04559145122766495
# Train Epoch: 86 Batch: 0 Total samples processed: 32 Loss: 0.037901196628808975
# Train Epoch: 87 Batch: 0 Total samples processed: 32 Loss: 0.039906542748212814
# Train Epoch: 88 Batch: 0 Total samples processed: 32 Loss: 0.034272629767656326
# Train Epoch: 89 Batch: 0 Total samples processed: 32 Loss: 0.04525364190340042
# Train Epoch: 90 Batch: 0 Total samples processed: 32 Loss: 0.04139511287212372
# Train Epoch: 91 Batch: 0 Total samples processed: 32 Loss: 0.03704266622662544
# Train Epoch: 92 Batch: 0 Total samples processed: 32 Loss: 0.03697201609611511
# Train Epoch: 93 Batch: 0 Total samples processed: 32 Loss: 0.03558182343840599
# Train Epoch: 94 Batch: 0 Total samples processed: 32 Loss: 0.03646385669708252
# Train Epoch: 95 Batch: 0 Total samples processed: 32 Loss: 0.03180089220404625
# Train Epoch: 96 Batch: 0 Total samples processed: 32 Loss: 0.036584820598363876
# Train Epoch: 97 Batch: 0 Total samples processed: 32 Loss: 0.036076128482818604
# Train Epoch: 98 Batch: 0 Total samples processed: 32 Loss: 0.030177302658557892
# Train Epoch: 99 Batch: 0 Total samples processed: 32 Loss: 0.04347952455282211
# Train Epoch: 100 Batch: 0 Total samples processed: 32 Loss: 0.03717285394668579
# Train Epoch: 101 Batch: 0 Total samples processed: 32 Loss: 0.040658578276634216
# Train Epoch: 102 Batch: 0 Total samples processed: 32 Loss: 0.03774622455239296
# Train Epoch: 103 Batch: 0 Total samples processed: 32 Loss: 0.03183369338512421
# Train Epoch: 104 Batch: 0 Total samples processed: 32 Loss: 0.03267388790845871
# Train Epoch: 105 Batch: 0 Total samples processed: 32 Loss: 0.029498238116502762
# Train Epoch: 106 Batch: 0 Total samples processed: 32 Loss: 0.029491495341062546
# Train Epoch: 107 Batch: 0 Total samples processed: 32 Loss: 0.031167184934020042
# Train Epoch: 108 Batch: 0 Total samples processed: 32 Loss: 0.02937302552163601
# Train Epoch: 109 Batch: 0 Total samples processed: 32 Loss: 0.035678572952747345
# Train Epoch: 110 Batch: 0 Total samples processed: 32 Loss: 0.03270520642399788
# Train Epoch: 111 Batch: 0 Total samples processed: 32 Loss: 0.03434165194630623
# Train Epoch: 112 Batch: 0 Total samples processed: 32 Loss: 0.03077215887606144
# Train Epoch: 113 Batch: 0 Total samples processed: 32 Loss: 0.03832312300801277
# Train Epoch: 114 Batch: 0 Total samples processed: 32 Loss: 0.03994718939065933
# Train Epoch: 115 Batch: 0 Total samples processed: 32 Loss: 0.03463318571448326
# Train Epoch: 116 Batch: 0 Total samples processed: 32 Loss: 0.03208727762103081
# Train Epoch: 117 Batch: 0 Total samples processed: 32 Loss: 0.027408139780163765
# Train Epoch: 118 Batch: 0 Total samples processed: 32 Loss: 0.026774611324071884
# Train Epoch: 119 Batch: 0 Total samples processed: 32 Loss: 0.029042446985840797
# Train Epoch: 120 Batch: 0 Total samples processed: 32 Loss: 0.0291876420378685
# Train Epoch: 121 Batch: 0 Total samples processed: 32 Loss: 0.031161513179540634
# Train Epoch: 122 Batch: 0 Total samples processed: 32 Loss: 0.026315990835428238
# Train Epoch: 123 Batch: 0 Total samples processed: 32 Loss: 0.024973468855023384
# Train Epoch: 124 Batch: 0 Total samples processed: 32 Loss: 0.027497820556163788
# Train Epoch: 125 Batch: 0 Total samples processed: 32 Loss: 0.030123354867100716
# Train Epoch: 126 Batch: 0 Total samples processed: 32 Loss: 0.027719540521502495
# Train Epoch: 127 Batch: 0 Total samples processed: 32 Loss: 0.027712933719158173
# Train Epoch: 128 Batch: 0 Total samples processed: 32 Loss: 0.02616576850414276
# Train Epoch: 129 Batch: 0 Total samples processed: 32 Loss: 0.02906230464577675
# Train Epoch: 130 Batch: 0 Total samples processed: 32 Loss: 0.028750933706760406
# Train Epoch: 131 Batch: 0 Total samples processed: 32 Loss: 0.02795405313372612
# Train Epoch: 132 Batch: 0 Total samples processed: 32 Loss: 0.02707548998296261
# Train Epoch: 133 Batch: 0 Total samples processed: 32 Loss: 0.03312786668539047
# Train Epoch: 134 Batch: 0 Total samples processed: 32 Loss: 0.028544476255774498
# Train Epoch: 135 Batch: 0 Total samples processed: 32 Loss: 0.026414858177304268
# Train Epoch: 136 Batch: 0 Total samples processed: 32 Loss: 0.029747534543275833
# Train Epoch: 137 Batch: 0 Total samples processed: 32 Loss: 0.02521786466240883
# Train Epoch: 138 Batch: 0 Total samples processed: 32 Loss: 0.02843082696199417
# Train Epoch: 139 Batch: 0 Total samples processed: 32 Loss: 0.026263808831572533
# Train Epoch: 140 Batch: 0 Total samples processed: 32 Loss: 0.03365079686045647
# Train Epoch: 141 Batch: 0 Total samples processed: 32 Loss: 0.025829654186964035
# Train Epoch: 142 Batch: 0 Total samples processed: 32 Loss: 0.026368042454123497
# Train Epoch: 143 Batch: 0 Total samples processed: 32 Loss: 0.02983212098479271
# Train Epoch: 144 Batch: 0 Total samples processed: 32 Loss: 0.027763545513153076
# Train Epoch: 145 Batch: 0 Total samples processed: 32 Loss: 0.02653617411851883
# Train Epoch: 146 Batch: 0 Total samples processed: 32 Loss: 0.023775137960910797
# Train Epoch: 147 Batch: 0 Total samples processed: 32 Loss: 0.025325648486614227
# Train Epoch: 148 Batch: 0 Total samples processed: 32 Loss: 0.023436233401298523
# Train Epoch: 149 Batch: 0 Total samples processed: 32 Loss: 0.02171284705400467
# Train Epoch: 150 Batch: 0 Total samples processed: 32 Loss: 0.024270694702863693
# Train Epoch: 151 Batch: 0 Total samples processed: 32 Loss: 0.025782573968172073
# Train Epoch: 152 Batch: 0 Total samples processed: 32 Loss: 0.02244901843369007
# Train Epoch: 153 Batch: 0 Total samples processed: 32 Loss: 0.026310104876756668
# Train Epoch: 154 Batch: 0 Total samples processed: 32 Loss: 0.025297686457633972
# Train Epoch: 155 Batch: 0 Total samples processed: 32 Loss: 0.026448789983987808
# Train Epoch: 156 Batch: 0 Total samples processed: 32 Loss: 0.023991938680410385
# Train Epoch: 157 Batch: 0 Total samples processed: 32 Loss: 0.022023804485797882
# Train Epoch: 158 Batch: 0 Total samples processed: 32 Loss: 0.024498911574482918
# Train Epoch: 159 Batch: 0 Total samples processed: 32 Loss: 0.0257282592356205
# Train Epoch: 160 Batch: 0 Total samples processed: 32 Loss: 0.023927003145217896
# Train Epoch: 161 Batch: 0 Total samples processed: 32 Loss: 0.025617145001888275
# Train Epoch: 162 Batch: 0 Total samples processed: 32 Loss: 0.027059217914938927
# Train Epoch: 163 Batch: 0 Total samples processed: 32 Loss: 0.027557840570807457
# Train Epoch: 164 Batch: 0 Total samples processed: 32 Loss: 0.023193292319774628
# Train Epoch: 165 Batch: 0 Total samples processed: 32 Loss: 0.026572255417704582
# Train Epoch: 166 Batch: 0 Total samples processed: 32 Loss: 0.02909630537033081
# Train Epoch: 167 Batch: 0 Total samples processed: 32 Loss: 0.02165595255792141
# Train Epoch: 168 Batch: 0 Total samples processed: 32 Loss: 0.024757318198680878
# Train Epoch: 169 Batch: 0 Total samples processed: 32 Loss: 0.023218730464577675
# Train Epoch: 170 Batch: 0 Total samples processed: 32 Loss: 0.022130347788333893
# Train Epoch: 171 Batch: 0 Total samples processed: 32 Loss: 0.024590689688920975
# Train Epoch: 172 Batch: 0 Total samples processed: 32 Loss: 0.026764728128910065
# Train Epoch: 173 Batch: 0 Total samples processed: 32 Loss: 0.023335766047239304
# Train Epoch: 174 Batch: 0 Total samples processed: 32 Loss: 0.026691488921642303
# Train Epoch: 175 Batch: 0 Total samples processed: 32 Loss: 0.022539090365171432
# Train Epoch: 176 Batch: 0 Total samples processed: 32 Loss: 0.02763749100267887
# Train Epoch: 177 Batch: 0 Total samples processed: 32 Loss: 0.029588039964437485
# Train Epoch: 178 Batch: 0 Total samples processed: 32 Loss: 0.023154832422733307
# Train Epoch: 179 Batch: 0 Total samples processed: 32 Loss: 0.02809266559779644
# Train Epoch: 180 Batch: 0 Total samples processed: 32 Loss: 0.024373888969421387
# Train Epoch: 181 Batch: 0 Total samples processed: 32 Loss: 0.021198762580752373
# Train Epoch: 182 Batch: 0 Total samples processed: 32 Loss: 0.026051461696624756
# Train Epoch: 183 Batch: 0 Total samples processed: 32 Loss: 0.027277737855911255
# Train Epoch: 184 Batch: 0 Total samples processed: 32 Loss: 0.019020352512598038
# Train Epoch: 185 Batch: 0 Total samples processed: 32 Loss: 0.02030414342880249
# Train Epoch: 186 Batch: 0 Total samples processed: 32 Loss: 0.02055777795612812
# Train Epoch: 187 Batch: 0 Total samples processed: 32 Loss: 0.01890680566430092
# Train Epoch: 188 Batch: 0 Total samples processed: 32 Loss: 0.019830137491226196
# Train Epoch: 189 Batch: 0 Total samples processed: 32 Loss: 0.02262389287352562
# Train Epoch: 190 Batch: 0 Total samples processed: 32 Loss: 0.025285137817263603
# Train Epoch: 191 Batch: 0 Total samples processed: 32 Loss: 0.019493132829666138
# Train Epoch: 192 Batch: 0 Total samples processed: 32 Loss: 0.027924194931983948
# Train Epoch: 193 Batch: 0 Total samples processed: 32 Loss: 0.021114565432071686
# Train Epoch: 194 Batch: 0 Total samples processed: 32 Loss: 0.023353660479187965
# Train Epoch: 195 Batch: 0 Total samples processed: 32 Loss: 0.021838050335645676
# Train Epoch: 196 Batch: 0 Total samples processed: 32 Loss: 0.025397639721632004
# Train Epoch: 197 Batch: 0 Total samples processed: 32 Loss: 0.028335735201835632
# Train Epoch: 198 Batch: 0 Total samples processed: 32 Loss: 0.0199115127325058
# Train Epoch: 199 Batch: 0 Total samples processed: 32 Loss: 0.02206895872950554
# Train Epoch: 200 Batch: 0 Total samples processed: 32 Loss: 0.023116163909435272

# %% [markdown]
# ## Look at self-prediction
#
# Self-prediction does not tell us how the UNET will perform on new data, but it is a useful check to make sure the UNET is learning the training data.

# %%
len(X)
X.shape
# Out:
# torch.Size([24, 1, 256, 256])

# %%
import matplotlib.pyplot as plt

# convert to 0/1 range on each pixel
prediction = torch.nn.functional.sigmoid(prediction_logits)
prediction_binary = prediction #(prediction > 0.5).to(torch.uint8)

print(prediction_binary.shape)

sidx = 1

# make big plot
plt.figure(figsize=(20, 5))
plt.subplot(151)
plt.imshow(X[sidx, 0].cpu().numpy(), cmap="gray")
plt.title("Input")

plt.subplot(152)
plt.imshow(y[sidx, 0].cpu().numpy(), cmap="gray")
plt.title("Ground truth 1")

plt.subplot(153)
plt.imshow(prediction_binary.cpu().detach()[sidx, 0].numpy(), cmap="gray")
plt.title("Prediction 1")
# Out:
# torch.Size([24, 1, 256, 256])
# Text(0.5, 1.0, 'Prediction 1')

# %% [markdown]
# ## Save the UNET

# %%
torch.save(model, patch_path / 'model1')
