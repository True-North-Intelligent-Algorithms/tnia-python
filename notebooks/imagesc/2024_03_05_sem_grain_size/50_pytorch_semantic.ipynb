# %% [markdown]
# ## Train a semantic segmentation unet using Pytorch

# %% [markdown]
# ## Pytorch setup
#
# setting up environment (Windows 10 with Cuda 11.8)
#
# ```
# conda create --name pytorch_tests python=3.10
# conda activate pytorch_tests
# conda install pip
# pip install pykernel
# pip3 install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118
# pip install pytorch-lightning
# pip install monai
# pip install scipy
# pip install tifffile
# pip install matplotlib
# ```

# %% [markdown]
# ## Imports

# %%
from tifffile import imread
from tqdm import tqdm
from tnia.deeplearning.dl_helper import quantile_normalization
import matplotlib.pyplot as plt
import numpy as np
import torch

from torchvision import transforms
from torchvision.transforms import v2
import torchvision.transforms.functional as TF

# %% [markdown]
# ## Check if GPU is present

# %%
cuda_present = torch.cuda.is_available()
ndevices = torch.cuda.device_count()
use_cuda = cuda_present and ndevices > 0
device = torch.device("cuda" if use_cuda else "cpu")  # "cuda:0" ... default device, "cuda:1" would be GPU index 1, "cuda:2" etc
print("number of devices:", ndevices, "\tchosen device:", device, "\tuse_cuda=", use_cuda)

# %% [markdown]
# ## Set up image and label directories

# %%
from pathlib import Path
import json

tnia_images_path = Path(r'D:/images')
parent_path=Path(tnia_images_path / r'D:\images\tnia-python-images\imagesc\2024_03_05_sem_grain_size')
train_path= parent_path / 'patches' 

with open(train_path / 'info.json', 'r') as json_file:
    data = json.load(json_file)
    # Access the sub_sample parameter
    sub_sample = data.get('sub_sample',1)
    print('sub_sample',sub_sample)
    axes = data['axes']
    print('axes',axes)

image_patch_path = train_path / 'ground truth0'
label_patch_path = train_path / 'input0'
# Out:
# sub_sample 1
# axes YX

# %% [markdown]
# ## Create a PyTorch Dataset
#
# Dataset is simply used to retrieve the training patches.  In this case we just set it up to read in image files, then convert the numpy arrays to tensors and a torch stack.
#
# In this example augmentation was done in a previous notebook, and the augmented images explicitly saved.  It is also possible to do augmentation as the data is retrieved.  So in the future the ```MyDataSet``` could be extended to apply augmentation as data is retrieved.

# %%
class MyDataSet():

    def __init__(self, image_files, label_files, target_shape=(256, 256)):
            """
            Parameters
            ----------
            image_files: list of pathlib.Path objects pointing to the *.tif images
            label_files: list of pathlib.Path objects pointing to the *.tif segmentation masks
            target_shape: tuple of length 2 specifying the sample resolutions of files that
                        will be kept. All other files will NOT be used.
            """
            assert len(image_files) == len(label_files)
            assert all(x.name==y.name for x,y in zip(image_files, label_files))

            self.images = []
            self.labels = []

            tensor_transform = transforms.Compose([
                v2.ToTensor(),
            ])

            # use tqdm to have eye pleasing error bars
            for idx in tqdm(range(len(image_files))):
                # we use the same data reading approach as in the previous notebook
                image = imread(image_files[idx])
                label = imread(label_files[idx])

                if image.shape != target_shape:
                    continue
                
                # do the normalizations
                #image = quantile_normalization(
                #   image,
                #    quantile_low=0.01,
                #    quantile_high=0.998,
                #    clip=True)[0].astype(np.float32)

                # NOTE: we convert the label to dtype float32 and not uint8 because
                # the tensor transformation does a normalization if the input is of
                # dtype uint8, destroying the 0/1 labelling which we want to avoid.
                #label = fill_label_holes(label)
                label_binary = np.zeros_like(label).astype(np.float32)
                label_binary[label != 0] = 1.
                

                # convert to torch tensor: adds an artificial color channel in the front
                # and scales inputs to have same size as samples tend to differ in image
                # resolutions
                image = tensor_transform(image)
                label = tensor_transform(label_binary)

                self.images.append(image)
                self.labels.append(label)

            self.images = torch.stack(self.images)
            self.labels = torch.stack(self.labels)
    
    def __getitem__(self, idx):
        return self.images[idx], self.labels[idx]

    def __len__(self):
        return len(self.images)

# %% [markdown]
# ## Initialize the DataSet
#
# Initialize the DataSet with the pre-generated patch names

# %%
src_dir = train_path

assert src_dir.exists(), f"root directory with images and masks {src_dir} does not exist"

X = sorted(src_dir.rglob('**/input0/*.tif'))
Y = sorted(src_dir.rglob('**/ground truth0/*.tif'))

train_data = MyDataSet(
    image_files=X,
    label_files=Y,
    target_shape=(256, 256)
)

# NOTE: the length of the dataset might not be the same as n_samples
#       because files not having the target shape will be discarded
print(len(train_data))
# Out:
# c:\Users\bnort\miniconda3\envs\pytorch_tests2\lib\site-packages\torchvision\transforms\v2\_deprecated.py:43: UserWarning: The transform `ToTensor()` is deprecated and will be removed in a future release. Instead, please use `v2.Compose([v2.ToImage(), v2.ToDtype(torch.float32, scale=True)])`.
#   warnings.warn(
#   0%|          | 0/100 [00:00<?, ?it/s]
# 100%|██████████| 100/100 [00:00<00:00, 566.51it/s]
# 100

# %% [markdown]
# ## Create a DataLoader
#
# This is done so we can load batches of images.

# %%
from torch.utils.data import DataLoader

train_loader = DataLoader(train_data, batch_size=32, shuffle=True)

# %% [markdown]
# ## Create a UNET

# %%
from monai.networks.nets import BasicUNet

model = BasicUNet(
    spatial_dims=2,
    in_channels=1,
    out_channels=1,
    #features=[16, 16, 32, 64, 128, 16],
    act="relu",
    norm="batch",
    dropout=0.25,
)

# Important: transfer the model to the chosen device
model = model.to(device)

optimizer = torch.optim.Adam(model.parameters(), lr=1.e-3)
init_params = list(model.parameters())[0].clone().detach()
# Out:
# BasicUNet features: (32, 32, 64, 128, 256, 32).

# %% [markdown]
# ## Train the UNET

# %%
max_nepochs = 200
log_interval = 1
model.train(True)

# BCEWithLogitsLoss combines sigmoid + BCELoss for better
# numerical stability. It expects raw unnormalized scores as input which are shaped like 
# B x C x W x D
loss_function = torch.nn.BCEWithLogitsLoss(reduction="mean")

for epoch in range(1, max_nepochs + 1):
    for batch_idx, (X, y) in enumerate(train_loader):
        # the inputs and labels have to be on the same device as the model
        X, y = X.to(device), y.to(device)
        
        optimizer.zero_grad()

        prediction_logits = model(X)
        
        batch_loss = loss_function(prediction_logits, y)

        batch_loss.backward()

        optimizer.step()

        if batch_idx % log_interval == 0:
            print(
                "Train Epoch:",
                epoch,
                "Batch:",
                batch_idx,
                "Total samples processed:",
                (batch_idx + 1) * train_loader.batch_size,
                "Loss:",
                batch_loss.item(),
            )
# Out:
# Train Epoch: 1 Batch: 0 Total samples processed: 32 Loss: 0.10496624559164047
# Train Epoch: 1 Batch: 1 Total samples processed: 64 Loss: 0.10184365510940552
# Train Epoch: 1 Batch: 2 Total samples processed: 96 Loss: 0.10556243360042572
# Train Epoch: 1 Batch: 3 Total samples processed: 128 Loss: 0.10895991325378418
# Train Epoch: 2 Batch: 0 Total samples processed: 32 Loss: 0.10287700593471527
# Train Epoch: 2 Batch: 1 Total samples processed: 64 Loss: 0.10283463448286057
# Train Epoch: 2 Batch: 2 Total samples processed: 96 Loss: 0.10158801078796387
# Train Epoch: 2 Batch: 3 Total samples processed: 128 Loss: 0.1038186177611351
# Train Epoch: 3 Batch: 0 Total samples processed: 32 Loss: 0.10267677903175354
# Train Epoch: 3 Batch: 1 Total samples processed: 64 Loss: 0.10023438185453415
# Train Epoch: 3 Batch: 2 Total samples processed: 96 Loss: 0.10090835392475128
# Train Epoch: 3 Batch: 3 Total samples processed: 128 Loss: 0.10009706020355225
# Train Epoch: 4 Batch: 0 Total samples processed: 32 Loss: 0.09857646375894547
# Train Epoch: 4 Batch: 1 Total samples processed: 64 Loss: 0.10213924944400787
# Train Epoch: 4 Batch: 2 Total samples processed: 96 Loss: 0.09818893671035767
# Train Epoch: 4 Batch: 3 Total samples processed: 128 Loss: 0.10421067476272583
# Train Epoch: 5 Batch: 0 Total samples processed: 32 Loss: 0.09959865361452103
# Train Epoch: 5 Batch: 1 Total samples processed: 64 Loss: 0.09603477269411087
# Train Epoch: 5 Batch: 2 Total samples processed: 96 Loss: 0.09958643466234207
# Train Epoch: 5 Batch: 3 Total samples processed: 128 Loss: 0.09795396029949188
# Train Epoch: 6 Batch: 0 Total samples processed: 32 Loss: 0.09632869064807892
# Train Epoch: 6 Batch: 1 Total samples processed: 64 Loss: 0.09637288749217987
# Train Epoch: 6 Batch: 2 Total samples processed: 96 Loss: 0.09676441550254822
# Train Epoch: 6 Batch: 3 Total samples processed: 128 Loss: 0.09836924076080322
# Train Epoch: 7 Batch: 0 Total samples processed: 32 Loss: 0.09584194421768188
# Train Epoch: 7 Batch: 1 Total samples processed: 64 Loss: 0.0942191630601883
# Train Epoch: 7 Batch: 2 Total samples processed: 96 Loss: 0.09770596027374268
# Train Epoch: 7 Batch: 3 Total samples processed: 128 Loss: 0.09137918055057526
# Train Epoch: 8 Batch: 0 Total samples processed: 32 Loss: 0.09615897387266159
# Train Epoch: 8 Batch: 1 Total samples processed: 64 Loss: 0.09398992359638214
# Train Epoch: 8 Batch: 2 Total samples processed: 96 Loss: 0.09365618228912354
# Train Epoch: 8 Batch: 3 Total samples processed: 128 Loss: 0.09613364934921265
# Train Epoch: 9 Batch: 0 Total samples processed: 32 Loss: 0.09346500039100647
# Train Epoch: 9 Batch: 1 Total samples processed: 64 Loss: 0.09311843663454056
# Train Epoch: 9 Batch: 2 Total samples processed: 96 Loss: 0.09134195744991302
# Train Epoch: 9 Batch: 3 Total samples processed: 128 Loss: 0.09526142477989197
# Train Epoch: 10 Batch: 0 Total samples processed: 32 Loss: 0.09271301329135895
# Train Epoch: 10 Batch: 1 Total samples processed: 64 Loss: 0.09316550940275192
# Train Epoch: 10 Batch: 2 Total samples processed: 96 Loss: 0.09079650789499283
# Train Epoch: 10 Batch: 3 Total samples processed: 128 Loss: 0.09270018339157104
# Train Epoch: 11 Batch: 0 Total samples processed: 32 Loss: 0.09096796065568924
# Train Epoch: 11 Batch: 1 Total samples processed: 64 Loss: 0.09139566868543625
# Train Epoch: 11 Batch: 2 Total samples processed: 96 Loss: 0.08947251737117767
# Train Epoch: 11 Batch: 3 Total samples processed: 128 Loss: 0.08751136064529419
# Train Epoch: 12 Batch: 0 Total samples processed: 32 Loss: 0.09217750281095505
# Train Epoch: 12 Batch: 1 Total samples processed: 64 Loss: 0.09114213287830353
# Train Epoch: 12 Batch: 2 Total samples processed: 96 Loss: 0.09032489359378815
# Train Epoch: 12 Batch: 3 Total samples processed: 128 Loss: 0.09084660559892654
# Train Epoch: 13 Batch: 0 Total samples processed: 32 Loss: 0.09121328592300415
# Train Epoch: 13 Batch: 1 Total samples processed: 64 Loss: 0.08689817041158676
# Train Epoch: 13 Batch: 2 Total samples processed: 96 Loss: 0.09106417745351791
# Train Epoch: 13 Batch: 3 Total samples processed: 128 Loss: 0.0886940062046051
# Train Epoch: 14 Batch: 0 Total samples processed: 32 Loss: 0.0893949344754219
# Train Epoch: 14 Batch: 1 Total samples processed: 64 Loss: 0.08853882551193237
# Train Epoch: 14 Batch: 2 Total samples processed: 96 Loss: 0.08766427636146545
# Train Epoch: 14 Batch: 3 Total samples processed: 128 Loss: 0.0943824052810669
# Train Epoch: 15 Batch: 0 Total samples processed: 32 Loss: 0.08891796320676804
# Train Epoch: 15 Batch: 1 Total samples processed: 64 Loss: 0.08716678619384766
# Train Epoch: 15 Batch: 2 Total samples processed: 96 Loss: 0.08970195055007935
# Train Epoch: 15 Batch: 3 Total samples processed: 128 Loss: 0.08568274974822998
# Train Epoch: 16 Batch: 0 Total samples processed: 32 Loss: 0.08741792291402817
# Train Epoch: 16 Batch: 1 Total samples processed: 64 Loss: 0.08572487533092499
# Train Epoch: 16 Batch: 2 Total samples processed: 96 Loss: 0.0867977887392044
# Train Epoch: 16 Batch: 3 Total samples processed: 128 Loss: 0.09148293733596802
# Train Epoch: 17 Batch: 0 Total samples processed: 32 Loss: 0.08812861144542694
# Train Epoch: 17 Batch: 1 Total samples processed: 64 Loss: 0.08670587837696075
# Train Epoch: 17 Batch: 2 Total samples processed: 96 Loss: 0.0851750373840332
# Train Epoch: 17 Batch: 3 Total samples processed: 128 Loss: 0.08565804362297058
# Train Epoch: 18 Batch: 0 Total samples processed: 32 Loss: 0.0872933566570282
# Train Epoch: 18 Batch: 1 Total samples processed: 64 Loss: 0.0854271650314331
# Train Epoch: 18 Batch: 2 Total samples processed: 96 Loss: 0.08638578653335571
# Train Epoch: 18 Batch: 3 Total samples processed: 128 Loss: 0.08849835395812988
# Train Epoch: 19 Batch: 0 Total samples processed: 32 Loss: 0.08521893620491028
# Train Epoch: 19 Batch: 1 Total samples processed: 64 Loss: 0.08629326522350311
# Train Epoch: 19 Batch: 2 Total samples processed: 96 Loss: 0.08728674054145813
# Train Epoch: 19 Batch: 3 Total samples processed: 128 Loss: 0.07984599471092224
# Train Epoch: 20 Batch: 0 Total samples processed: 32 Loss: 0.08424238860607147
# Train Epoch: 20 Batch: 1 Total samples processed: 64 Loss: 0.08439023047685623
# Train Epoch: 20 Batch: 2 Total samples processed: 96 Loss: 0.0855673998594284
# Train Epoch: 20 Batch: 3 Total samples processed: 128 Loss: 0.0834004208445549
# Train Epoch: 21 Batch: 0 Total samples processed: 32 Loss: 0.08229152113199234
# Train Epoch: 21 Batch: 1 Total samples processed: 64 Loss: 0.08462651818990707
# Train Epoch: 21 Batch: 2 Total samples processed: 96 Loss: 0.08305317163467407
# Train Epoch: 21 Batch: 3 Total samples processed: 128 Loss: 0.08334554731845856
# Train Epoch: 22 Batch: 0 Total samples processed: 32 Loss: 0.08244200050830841
# Train Epoch: 22 Batch: 1 Total samples processed: 64 Loss: 0.08398833870887756
# Train Epoch: 22 Batch: 2 Total samples processed: 96 Loss: 0.08158435672521591
# Train Epoch: 22 Batch: 3 Total samples processed: 128 Loss: 0.08005225658416748
# Train Epoch: 23 Batch: 0 Total samples processed: 32 Loss: 0.08371484279632568
# Train Epoch: 23 Batch: 1 Total samples processed: 64 Loss: 0.0807725265622139
# Train Epoch: 23 Batch: 2 Total samples processed: 96 Loss: 0.08104473352432251
# Train Epoch: 23 Batch: 3 Total samples processed: 128 Loss: 0.08332571387290955
# Train Epoch: 24 Batch: 0 Total samples processed: 32 Loss: 0.07946103066205978
# Train Epoch: 24 Batch: 1 Total samples processed: 64 Loss: 0.08129335939884186
# Train Epoch: 24 Batch: 2 Total samples processed: 96 Loss: 0.08124060183763504
# Train Epoch: 24 Batch: 3 Total samples processed: 128 Loss: 0.07841267436742783
# Train Epoch: 25 Batch: 0 Total samples processed: 32 Loss: 0.07983214408159256
# Train Epoch: 25 Batch: 1 Total samples processed: 64 Loss: 0.07961343973875046
# Train Epoch: 25 Batch: 2 Total samples processed: 96 Loss: 0.07984548062086105
# Train Epoch: 25 Batch: 3 Total samples processed: 128 Loss: 0.0763702243566513
# Train Epoch: 26 Batch: 0 Total samples processed: 32 Loss: 0.07821840792894363
# Train Epoch: 26 Batch: 1 Total samples processed: 64 Loss: 0.08064834773540497
# Train Epoch: 26 Batch: 2 Total samples processed: 96 Loss: 0.07825110107660294
# Train Epoch: 26 Batch: 3 Total samples processed: 128 Loss: 0.08624154329299927
# Train Epoch: 27 Batch: 0 Total samples processed: 32 Loss: 0.07965785264968872
# Train Epoch: 27 Batch: 1 Total samples processed: 64 Loss: 0.07995592057704926
# Train Epoch: 27 Batch: 2 Total samples processed: 96 Loss: 0.08130545914173126
# Train Epoch: 27 Batch: 3 Total samples processed: 128 Loss: 0.08039679378271103
# Train Epoch: 28 Batch: 0 Total samples processed: 32 Loss: 0.07878580689430237
# Train Epoch: 28 Batch: 1 Total samples processed: 64 Loss: 0.07975362241268158
# Train Epoch: 28 Batch: 2 Total samples processed: 96 Loss: 0.0813557356595993
# Train Epoch: 28 Batch: 3 Total samples processed: 128 Loss: 0.07691757380962372
# Train Epoch: 29 Batch: 0 Total samples processed: 32 Loss: 0.0770433098077774
# Train Epoch: 29 Batch: 1 Total samples processed: 64 Loss: 0.07856820523738861
# Train Epoch: 29 Batch: 2 Total samples processed: 96 Loss: 0.07916432619094849
# Train Epoch: 29 Batch: 3 Total samples processed: 128 Loss: 0.08018171042203903
# Train Epoch: 30 Batch: 0 Total samples processed: 32 Loss: 0.07937057316303253
# Train Epoch: 30 Batch: 1 Total samples processed: 64 Loss: 0.07769045233726501
# Train Epoch: 30 Batch: 2 Total samples processed: 96 Loss: 0.08065946400165558
# Train Epoch: 30 Batch: 3 Total samples processed: 128 Loss: 0.07745006680488586
# Train Epoch: 31 Batch: 0 Total samples processed: 32 Loss: 0.07713593542575836
# Train Epoch: 31 Batch: 1 Total samples processed: 64 Loss: 0.07719799876213074
# Train Epoch: 31 Batch: 2 Total samples processed: 96 Loss: 0.07770173251628876
# Train Epoch: 31 Batch: 3 Total samples processed: 128 Loss: 0.07812909781932831
# Train Epoch: 32 Batch: 0 Total samples processed: 32 Loss: 0.07633606344461441
# Train Epoch: 32 Batch: 1 Total samples processed: 64 Loss: 0.0770060271024704
# Train Epoch: 32 Batch: 2 Total samples processed: 96 Loss: 0.0794447660446167
# Train Epoch: 32 Batch: 3 Total samples processed: 128 Loss: 0.08016359806060791
# Train Epoch: 33 Batch: 0 Total samples processed: 32 Loss: 0.0790390595793724
# Train Epoch: 33 Batch: 1 Total samples processed: 64 Loss: 0.07612743973731995
# Train Epoch: 33 Batch: 2 Total samples processed: 96 Loss: 0.07739775627851486
# Train Epoch: 33 Batch: 3 Total samples processed: 128 Loss: 0.07967577129602432
# Train Epoch: 34 Batch: 0 Total samples processed: 32 Loss: 0.07647489756345749
# Train Epoch: 34 Batch: 1 Total samples processed: 64 Loss: 0.07694943249225616
# Train Epoch: 34 Batch: 2 Total samples processed: 96 Loss: 0.07680553942918777
# Train Epoch: 34 Batch: 3 Total samples processed: 128 Loss: 0.08371484279632568
# Train Epoch: 35 Batch: 0 Total samples processed: 32 Loss: 0.07676950097084045
# Train Epoch: 35 Batch: 1 Total samples processed: 64 Loss: 0.07677492499351501
# Train Epoch: 35 Batch: 2 Total samples processed: 96 Loss: 0.07888732850551605
# Train Epoch: 35 Batch: 3 Total samples processed: 128 Loss: 0.07547490298748016
# Train Epoch: 36 Batch: 0 Total samples processed: 32 Loss: 0.07853318750858307
# Train Epoch: 36 Batch: 1 Total samples processed: 64 Loss: 0.0756646990776062
# Train Epoch: 36 Batch: 2 Total samples processed: 96 Loss: 0.07723720371723175
# Train Epoch: 36 Batch: 3 Total samples processed: 128 Loss: 0.07401823997497559
# Train Epoch: 37 Batch: 0 Total samples processed: 32 Loss: 0.08121461421251297
# Train Epoch: 37 Batch: 1 Total samples processed: 64 Loss: 0.07665156573057175
# Train Epoch: 37 Batch: 2 Total samples processed: 96 Loss: 0.07490400969982147
# Train Epoch: 37 Batch: 3 Total samples processed: 128 Loss: 0.07474464178085327
# Train Epoch: 38 Batch: 0 Total samples processed: 32 Loss: 0.07431484758853912
# Train Epoch: 38 Batch: 1 Total samples processed: 64 Loss: 0.07547135651111603
# Train Epoch: 38 Batch: 2 Total samples processed: 96 Loss: 0.07560074329376221
# Train Epoch: 38 Batch: 3 Total samples processed: 128 Loss: 0.07328730821609497
# Train Epoch: 39 Batch: 0 Total samples processed: 32 Loss: 0.07511542737483978
# Train Epoch: 39 Batch: 1 Total samples processed: 64 Loss: 0.07502433657646179
# Train Epoch: 39 Batch: 2 Total samples processed: 96 Loss: 0.07488644123077393
# Train Epoch: 39 Batch: 3 Total samples processed: 128 Loss: 0.07104097306728363
# Train Epoch: 40 Batch: 0 Total samples processed: 32 Loss: 0.07316797226667404
# Train Epoch: 40 Batch: 1 Total samples processed: 64 Loss: 0.07429271936416626
# Train Epoch: 40 Batch: 2 Total samples processed: 96 Loss: 0.07484643161296844
# Train Epoch: 40 Batch: 3 Total samples processed: 128 Loss: 0.07193079590797424
# Train Epoch: 41 Batch: 0 Total samples processed: 32 Loss: 0.07410259544849396
# Train Epoch: 41 Batch: 1 Total samples processed: 64 Loss: 0.07303302735090256
# Train Epoch: 41 Batch: 2 Total samples processed: 96 Loss: 0.07419373095035553
# Train Epoch: 41 Batch: 3 Total samples processed: 128 Loss: 0.07648870348930359
# Train Epoch: 42 Batch: 0 Total samples processed: 32 Loss: 0.07378102838993073
# Train Epoch: 42 Batch: 1 Total samples processed: 64 Loss: 0.0731135755777359
# Train Epoch: 42 Batch: 2 Total samples processed: 96 Loss: 0.07301376760005951
# Train Epoch: 42 Batch: 3 Total samples processed: 128 Loss: 0.0722140371799469
# Train Epoch: 43 Batch: 0 Total samples processed: 32 Loss: 0.07325562834739685
# Train Epoch: 43 Batch: 1 Total samples processed: 64 Loss: 0.0731247141957283
# Train Epoch: 43 Batch: 2 Total samples processed: 96 Loss: 0.07256042957305908
# Train Epoch: 43 Batch: 3 Total samples processed: 128 Loss: 0.07226012647151947
# Train Epoch: 44 Batch: 0 Total samples processed: 32 Loss: 0.07250519841909409
# Train Epoch: 44 Batch: 1 Total samples processed: 64 Loss: 0.0709293782711029
# Train Epoch: 44 Batch: 2 Total samples processed: 96 Loss: 0.07351911067962646
# Train Epoch: 44 Batch: 3 Total samples processed: 128 Loss: 0.0723215788602829
# Train Epoch: 45 Batch: 0 Total samples processed: 32 Loss: 0.07176265120506287
# Train Epoch: 45 Batch: 1 Total samples processed: 64 Loss: 0.07033288478851318
# Train Epoch: 45 Batch: 2 Total samples processed: 96 Loss: 0.07192179560661316
# Train Epoch: 45 Batch: 3 Total samples processed: 128 Loss: 0.06863860040903091
# Train Epoch: 46 Batch: 0 Total samples processed: 32 Loss: 0.0706556886434555
# Train Epoch: 46 Batch: 1 Total samples processed: 64 Loss: 0.07101041823625565
# Train Epoch: 46 Batch: 2 Total samples processed: 96 Loss: 0.070478156208992
# Train Epoch: 46 Batch: 3 Total samples processed: 128 Loss: 0.07369373738765717
# Train Epoch: 47 Batch: 0 Total samples processed: 32 Loss: 0.07191316783428192
# Train Epoch: 47 Batch: 1 Total samples processed: 64 Loss: 0.07122204452753067
# Train Epoch: 47 Batch: 2 Total samples processed: 96 Loss: 0.0724141001701355
# Train Epoch: 47 Batch: 3 Total samples processed: 128 Loss: 0.06973109394311905
# Train Epoch: 48 Batch: 0 Total samples processed: 32 Loss: 0.06930607557296753
# Train Epoch: 48 Batch: 1 Total samples processed: 64 Loss: 0.07568071782588959
# Train Epoch: 48 Batch: 2 Total samples processed: 96 Loss: 0.07188398391008377
# Train Epoch: 48 Batch: 3 Total samples processed: 128 Loss: 0.0722016841173172
# Train Epoch: 49 Batch: 0 Total samples processed: 32 Loss: 0.07001373171806335
# Train Epoch: 49 Batch: 1 Total samples processed: 64 Loss: 0.06914350390434265
# Train Epoch: 49 Batch: 2 Total samples processed: 96 Loss: 0.0713849812746048
# Train Epoch: 49 Batch: 3 Total samples processed: 128 Loss: 0.06813318282365799
# Train Epoch: 50 Batch: 0 Total samples processed: 32 Loss: 0.06936568021774292
# Train Epoch: 50 Batch: 1 Total samples processed: 64 Loss: 0.06940484046936035
# Train Epoch: 50 Batch: 2 Total samples processed: 96 Loss: 0.06979766488075256
# Train Epoch: 50 Batch: 3 Total samples processed: 128 Loss: 0.06760691106319427
# Train Epoch: 51 Batch: 0 Total samples processed: 32 Loss: 0.06895261257886887
# Train Epoch: 51 Batch: 1 Total samples processed: 64 Loss: 0.07056351006031036
# Train Epoch: 51 Batch: 2 Total samples processed: 96 Loss: 0.06935784220695496
# Train Epoch: 51 Batch: 3 Total samples processed: 128 Loss: 0.07467979192733765
# Train Epoch: 52 Batch: 0 Total samples processed: 32 Loss: 0.06820002943277359
# Train Epoch: 52 Batch: 1 Total samples processed: 64 Loss: 0.0683596134185791
# Train Epoch: 52 Batch: 2 Total samples processed: 96 Loss: 0.06919097155332565
# Train Epoch: 52 Batch: 3 Total samples processed: 128 Loss: 0.07509361207485199
# Train Epoch: 53 Batch: 0 Total samples processed: 32 Loss: 0.0714297741651535
# Train Epoch: 53 Batch: 1 Total samples processed: 64 Loss: 0.07119420915842056
# Train Epoch: 53 Batch: 2 Total samples processed: 96 Loss: 0.06829532980918884
# Train Epoch: 53 Batch: 3 Total samples processed: 128 Loss: 0.07030598819255829
# Train Epoch: 54 Batch: 0 Total samples processed: 32 Loss: 0.07114994525909424
# Train Epoch: 54 Batch: 1 Total samples processed: 64 Loss: 0.06995075941085815
# Train Epoch: 54 Batch: 2 Total samples processed: 96 Loss: 0.07072111964225769
# Train Epoch: 54 Batch: 3 Total samples processed: 128 Loss: 0.07272544503211975
# Train Epoch: 55 Batch: 0 Total samples processed: 32 Loss: 0.06985341757535934
# Train Epoch: 55 Batch: 1 Total samples processed: 64 Loss: 0.06876817345619202
# Train Epoch: 55 Batch: 2 Total samples processed: 96 Loss: 0.07023071497678757
# Train Epoch: 55 Batch: 3 Total samples processed: 128 Loss: 0.07050828635692596
# Train Epoch: 56 Batch: 0 Total samples processed: 32 Loss: 0.06878818571567535
# Train Epoch: 56 Batch: 1 Total samples processed: 64 Loss: 0.06862683594226837
# Train Epoch: 56 Batch: 2 Total samples processed: 96 Loss: 0.06767809391021729
# Train Epoch: 56 Batch: 3 Total samples processed: 128 Loss: 0.07777723670005798
# Train Epoch: 57 Batch: 0 Total samples processed: 32 Loss: 0.06725001335144043
# Train Epoch: 57 Batch: 1 Total samples processed: 64 Loss: 0.0675799697637558
# Train Epoch: 57 Batch: 2 Total samples processed: 96 Loss: 0.07004491984844208
# Train Epoch: 57 Batch: 3 Total samples processed: 128 Loss: 0.06945376098155975
# Train Epoch: 58 Batch: 0 Total samples processed: 32 Loss: 0.06650570780038834
# Train Epoch: 58 Batch: 1 Total samples processed: 64 Loss: 0.06879177689552307
# Train Epoch: 58 Batch: 2 Total samples processed: 96 Loss: 0.06741103529930115
# Train Epoch: 58 Batch: 3 Total samples processed: 128 Loss: 0.06845920532941818
# Train Epoch: 59 Batch: 0 Total samples processed: 32 Loss: 0.06676845997571945
# Train Epoch: 59 Batch: 1 Total samples processed: 64 Loss: 0.0699136033654213
# Train Epoch: 59 Batch: 2 Total samples processed: 96 Loss: 0.06550527364015579
# Train Epoch: 59 Batch: 3 Total samples processed: 128 Loss: 0.06950393319129944
# Train Epoch: 60 Batch: 0 Total samples processed: 32 Loss: 0.06747205555438995
# Train Epoch: 60 Batch: 1 Total samples processed: 64 Loss: 0.06883903592824936
# Train Epoch: 60 Batch: 2 Total samples processed: 96 Loss: 0.0656408965587616
# Train Epoch: 60 Batch: 3 Total samples processed: 128 Loss: 0.0691046267747879
# Train Epoch: 61 Batch: 0 Total samples processed: 32 Loss: 0.06679383665323257
# Train Epoch: 61 Batch: 1 Total samples processed: 64 Loss: 0.0672532320022583
# Train Epoch: 61 Batch: 2 Total samples processed: 96 Loss: 0.0679406076669693
# Train Epoch: 61 Batch: 3 Total samples processed: 128 Loss: 0.07383999973535538
# Train Epoch: 62 Batch: 0 Total samples processed: 32 Loss: 0.07372422516345978
# Train Epoch: 62 Batch: 1 Total samples processed: 64 Loss: 0.07081080973148346
# Train Epoch: 62 Batch: 2 Total samples processed: 96 Loss: 0.06668156385421753
# Train Epoch: 62 Batch: 3 Total samples processed: 128 Loss: 0.072838194668293
# Train Epoch: 63 Batch: 0 Total samples processed: 32 Loss: 0.07445678859949112
# Train Epoch: 63 Batch: 1 Total samples processed: 64 Loss: 0.07138975709676743
# Train Epoch: 63 Batch: 2 Total samples processed: 96 Loss: 0.06898654997348785
# Train Epoch: 63 Batch: 3 Total samples processed: 128 Loss: 0.07429707050323486
# Train Epoch: 64 Batch: 0 Total samples processed: 32 Loss: 0.07270878553390503
# Train Epoch: 64 Batch: 1 Total samples processed: 64 Loss: 0.06695548444986343
# Train Epoch: 64 Batch: 2 Total samples processed: 96 Loss: 0.07089881598949432
# Train Epoch: 64 Batch: 3 Total samples processed: 128 Loss: 0.0704217255115509
# Train Epoch: 65 Batch: 0 Total samples processed: 32 Loss: 0.06781581044197083
# Train Epoch: 65 Batch: 1 Total samples processed: 64 Loss: 0.06963838636875153
# Train Epoch: 65 Batch: 2 Total samples processed: 96 Loss: 0.06939253211021423
# Train Epoch: 65 Batch: 3 Total samples processed: 128 Loss: 0.06805196404457092
# Train Epoch: 66 Batch: 0 Total samples processed: 32 Loss: 0.06768762320280075
# Train Epoch: 66 Batch: 1 Total samples processed: 64 Loss: 0.06672365218400955
# Train Epoch: 66 Batch: 2 Total samples processed: 96 Loss: 0.06718315184116364
# Train Epoch: 66 Batch: 3 Total samples processed: 128 Loss: 0.06769850850105286
# Train Epoch: 67 Batch: 0 Total samples processed: 32 Loss: 0.06838008761405945
# Train Epoch: 67 Batch: 1 Total samples processed: 64 Loss: 0.0698162391781807
# Train Epoch: 67 Batch: 2 Total samples processed: 96 Loss: 0.06716811656951904
# Train Epoch: 67 Batch: 3 Total samples processed: 128 Loss: 0.0666244775056839
# Train Epoch: 68 Batch: 0 Total samples processed: 32 Loss: 0.07019266486167908
# Train Epoch: 68 Batch: 1 Total samples processed: 64 Loss: 0.0686400830745697
# Train Epoch: 68 Batch: 2 Total samples processed: 96 Loss: 0.06660464406013489
# Train Epoch: 68 Batch: 3 Total samples processed: 128 Loss: 0.07417062669992447
# Train Epoch: 69 Batch: 0 Total samples processed: 32 Loss: 0.06721729040145874
# Train Epoch: 69 Batch: 1 Total samples processed: 64 Loss: 0.06677423417568207
# Train Epoch: 69 Batch: 2 Total samples processed: 96 Loss: 0.06410029530525208
# Train Epoch: 69 Batch: 3 Total samples processed: 128 Loss: 0.06355064362287521
# Train Epoch: 70 Batch: 0 Total samples processed: 32 Loss: 0.06637898087501526
# Train Epoch: 70 Batch: 1 Total samples processed: 64 Loss: 0.06531607359647751
# Train Epoch: 70 Batch: 2 Total samples processed: 96 Loss: 0.06507932394742966
# Train Epoch: 70 Batch: 3 Total samples processed: 128 Loss: 0.07299621403217316
# Train Epoch: 71 Batch: 0 Total samples processed: 32 Loss: 0.06359793990850449
# Train Epoch: 71 Batch: 1 Total samples processed: 64 Loss: 0.06650412827730179
# Train Epoch: 71 Batch: 2 Total samples processed: 96 Loss: 0.06443490833044052
# Train Epoch: 71 Batch: 3 Total samples processed: 128 Loss: 0.06919336318969727
# Train Epoch: 72 Batch: 0 Total samples processed: 32 Loss: 0.06269419193267822
# Train Epoch: 72 Batch: 1 Total samples processed: 64 Loss: 0.0664842426776886
# Train Epoch: 72 Batch: 2 Total samples processed: 96 Loss: 0.06443725526332855
# Train Epoch: 72 Batch: 3 Total samples processed: 128 Loss: 0.06754037737846375
# Train Epoch: 73 Batch: 0 Total samples processed: 32 Loss: 0.06503994017839432
# Train Epoch: 73 Batch: 1 Total samples processed: 64 Loss: 0.06417804956436157
# Train Epoch: 73 Batch: 2 Total samples processed: 96 Loss: 0.0645637959241867
# Train Epoch: 73 Batch: 3 Total samples processed: 128 Loss: 0.06459248065948486
# Train Epoch: 74 Batch: 0 Total samples processed: 32 Loss: 0.06540530174970627
# Train Epoch: 74 Batch: 1 Total samples processed: 64 Loss: 0.06203436106443405
# Train Epoch: 74 Batch: 2 Total samples processed: 96 Loss: 0.06428278237581253
# Train Epoch: 74 Batch: 3 Total samples processed: 128 Loss: 0.0660584568977356
# Train Epoch: 75 Batch: 0 Total samples processed: 32 Loss: 0.06245231628417969
# Train Epoch: 75 Batch: 1 Total samples processed: 64 Loss: 0.06435717642307281
# Train Epoch: 75 Batch: 2 Total samples processed: 96 Loss: 0.0636671856045723
# Train Epoch: 75 Batch: 3 Total samples processed: 128 Loss: 0.06207849085330963
# Train Epoch: 76 Batch: 0 Total samples processed: 32 Loss: 0.06286851316690445
# Train Epoch: 76 Batch: 1 Total samples processed: 64 Loss: 0.06291573494672775
# Train Epoch: 76 Batch: 2 Total samples processed: 96 Loss: 0.06317010521888733
# Train Epoch: 76 Batch: 3 Total samples processed: 128 Loss: 0.06447722017765045
# Train Epoch: 77 Batch: 0 Total samples processed: 32 Loss: 0.06386243551969528
# Train Epoch: 77 Batch: 1 Total samples processed: 64 Loss: 0.06311161071062088
# Train Epoch: 77 Batch: 2 Total samples processed: 96 Loss: 0.06409603357315063
# Train Epoch: 77 Batch: 3 Total samples processed: 128 Loss: 0.060135357081890106
# Train Epoch: 78 Batch: 0 Total samples processed: 32 Loss: 0.06390932947397232
# Train Epoch: 78 Batch: 1 Total samples processed: 64 Loss: 0.06369756162166595
# Train Epoch: 78 Batch: 2 Total samples processed: 96 Loss: 0.06331686675548553
# Train Epoch: 78 Batch: 3 Total samples processed: 128 Loss: 0.0658797025680542
# Train Epoch: 79 Batch: 0 Total samples processed: 32 Loss: 0.06530057638883591
# Train Epoch: 79 Batch: 1 Total samples processed: 64 Loss: 0.06211429461836815
# Train Epoch: 79 Batch: 2 Total samples processed: 96 Loss: 0.06405778229236603
# Train Epoch: 79 Batch: 3 Total samples processed: 128 Loss: 0.06704023480415344
# Train Epoch: 80 Batch: 0 Total samples processed: 32 Loss: 0.061407893896102905
# Train Epoch: 80 Batch: 1 Total samples processed: 64 Loss: 0.06239517405629158
# Train Epoch: 80 Batch: 2 Total samples processed: 96 Loss: 0.06364423036575317
# Train Epoch: 80 Batch: 3 Total samples processed: 128 Loss: 0.06207435578107834
# Train Epoch: 81 Batch: 0 Total samples processed: 32 Loss: 0.06312932074069977
# Train Epoch: 81 Batch: 1 Total samples processed: 64 Loss: 0.06347136199474335
# Train Epoch: 81 Batch: 2 Total samples processed: 96 Loss: 0.0622563399374485
# Train Epoch: 81 Batch: 3 Total samples processed: 128 Loss: 0.06052500754594803
# Train Epoch: 82 Batch: 0 Total samples processed: 32 Loss: 0.06323368847370148
# Train Epoch: 82 Batch: 1 Total samples processed: 64 Loss: 0.06119876354932785
# Train Epoch: 82 Batch: 2 Total samples processed: 96 Loss: 0.062367670238018036
# Train Epoch: 82 Batch: 3 Total samples processed: 128 Loss: 0.06611640751361847
# Train Epoch: 83 Batch: 0 Total samples processed: 32 Loss: 0.06062326952815056
# Train Epoch: 83 Batch: 1 Total samples processed: 64 Loss: 0.0628577470779419
# Train Epoch: 83 Batch: 2 Total samples processed: 96 Loss: 0.062498413026332855
# Train Epoch: 83 Batch: 3 Total samples processed: 128 Loss: 0.064070925116539
# Train Epoch: 84 Batch: 0 Total samples processed: 32 Loss: 0.060972459614276886
# Train Epoch: 84 Batch: 1 Total samples processed: 64 Loss: 0.06336938589811325
# Train Epoch: 84 Batch: 2 Total samples processed: 96 Loss: 0.059645768254995346
# Train Epoch: 84 Batch: 3 Total samples processed: 128 Loss: 0.08265556395053864
# Train Epoch: 85 Batch: 0 Total samples processed: 32 Loss: 0.06438373029232025
# Train Epoch: 85 Batch: 1 Total samples processed: 64 Loss: 0.06331291049718857
# Train Epoch: 85 Batch: 2 Total samples processed: 96 Loss: 0.06277935206890106
# Train Epoch: 85 Batch: 3 Total samples processed: 128 Loss: 0.07113350927829742
# Train Epoch: 86 Batch: 0 Total samples processed: 32 Loss: 0.06436774134635925
# Train Epoch: 86 Batch: 1 Total samples processed: 64 Loss: 0.06696274876594543
# Train Epoch: 86 Batch: 2 Total samples processed: 96 Loss: 0.06206445395946503
# Train Epoch: 86 Batch: 3 Total samples processed: 128 Loss: 0.06655703485012054
# Train Epoch: 87 Batch: 0 Total samples processed: 32 Loss: 0.06765340268611908
# Train Epoch: 87 Batch: 1 Total samples processed: 64 Loss: 0.06170060485601425
# Train Epoch: 87 Batch: 2 Total samples processed: 96 Loss: 0.06366786360740662
# Train Epoch: 87 Batch: 3 Total samples processed: 128 Loss: 0.06512320786714554
# Train Epoch: 88 Batch: 0 Total samples processed: 32 Loss: 0.06371217966079712
# Train Epoch: 88 Batch: 1 Total samples processed: 64 Loss: 0.061778511852025986
# Train Epoch: 88 Batch: 2 Total samples processed: 96 Loss: 0.06294618546962738
# Train Epoch: 88 Batch: 3 Total samples processed: 128 Loss: 0.06369531899690628
# Train Epoch: 89 Batch: 0 Total samples processed: 32 Loss: 0.06476794183254242
# Train Epoch: 89 Batch: 1 Total samples processed: 64 Loss: 0.0606456883251667
# Train Epoch: 89 Batch: 2 Total samples processed: 96 Loss: 0.062273792922496796
# Train Epoch: 89 Batch: 3 Total samples processed: 128 Loss: 0.0672953724861145
# Train Epoch: 90 Batch: 0 Total samples processed: 32 Loss: 0.06412355601787567
# Train Epoch: 90 Batch: 1 Total samples processed: 64 Loss: 0.06151391565799713
# Train Epoch: 90 Batch: 2 Total samples processed: 96 Loss: 0.06184939295053482
# Train Epoch: 90 Batch: 3 Total samples processed: 128 Loss: 0.05848401039838791
# Train Epoch: 91 Batch: 0 Total samples processed: 32 Loss: 0.062242649495601654
# Train Epoch: 91 Batch: 1 Total samples processed: 64 Loss: 0.05978981405496597
# Train Epoch: 91 Batch: 2 Total samples processed: 96 Loss: 0.06233369559049606
# Train Epoch: 91 Batch: 3 Total samples processed: 128 Loss: 0.0695946216583252
# Train Epoch: 92 Batch: 0 Total samples processed: 32 Loss: 0.06184016913175583
# Train Epoch: 92 Batch: 1 Total samples processed: 64 Loss: 0.062035612761974335
# Train Epoch: 92 Batch: 2 Total samples processed: 96 Loss: 0.06095505505800247
# Train Epoch: 92 Batch: 3 Total samples processed: 128 Loss: 0.06472879648208618
# Train Epoch: 93 Batch: 0 Total samples processed: 32 Loss: 0.06112489104270935
# Train Epoch: 93 Batch: 1 Total samples processed: 64 Loss: 0.06079445034265518
# Train Epoch: 93 Batch: 2 Total samples processed: 96 Loss: 0.06136222556233406
# Train Epoch: 93 Batch: 3 Total samples processed: 128 Loss: 0.06117800623178482
# Train Epoch: 94 Batch: 0 Total samples processed: 32 Loss: 0.06208794191479683
# Train Epoch: 94 Batch: 1 Total samples processed: 64 Loss: 0.060914549976587296
# Train Epoch: 94 Batch: 2 Total samples processed: 96 Loss: 0.059415776282548904
# Train Epoch: 94 Batch: 3 Total samples processed: 128 Loss: 0.05979197472333908
# Train Epoch: 95 Batch: 0 Total samples processed: 32 Loss: 0.0625777319073677
# Train Epoch: 95 Batch: 1 Total samples processed: 64 Loss: 0.05909726768732071
# Train Epoch: 95 Batch: 2 Total samples processed: 96 Loss: 0.06001652032136917
# Train Epoch: 95 Batch: 3 Total samples processed: 128 Loss: 0.06548558920621872
# Train Epoch: 96 Batch: 0 Total samples processed: 32 Loss: 0.05914304405450821
# Train Epoch: 96 Batch: 1 Total samples processed: 64 Loss: 0.05853591859340668
# Train Epoch: 96 Batch: 2 Total samples processed: 96 Loss: 0.06083398312330246
# Train Epoch: 96 Batch: 3 Total samples processed: 128 Loss: 0.061934247612953186
# Train Epoch: 97 Batch: 0 Total samples processed: 32 Loss: 0.059575825929641724
# Train Epoch: 97 Batch: 1 Total samples processed: 64 Loss: 0.060920778661966324
# Train Epoch: 97 Batch: 2 Total samples processed: 96 Loss: 0.05949604511260986
# Train Epoch: 97 Batch: 3 Total samples processed: 128 Loss: 0.058836568146944046
# Train Epoch: 98 Batch: 0 Total samples processed: 32 Loss: 0.058351024985313416
# Train Epoch: 98 Batch: 1 Total samples processed: 64 Loss: 0.059622615575790405
# Train Epoch: 98 Batch: 2 Total samples processed: 96 Loss: 0.05929999053478241
# Train Epoch: 98 Batch: 3 Total samples processed: 128 Loss: 0.06433409452438354
# Train Epoch: 99 Batch: 0 Total samples processed: 32 Loss: 0.060264408588409424
# Train Epoch: 99 Batch: 1 Total samples processed: 64 Loss: 0.058524973690509796
# Train Epoch: 99 Batch: 2 Total samples processed: 96 Loss: 0.059301458299160004
# Train Epoch: 99 Batch: 3 Total samples processed: 128 Loss: 0.05850765109062195
# Train Epoch: 100 Batch: 0 Total samples processed: 32 Loss: 0.06023766100406647
# Train Epoch: 100 Batch: 1 Total samples processed: 64 Loss: 0.059422314167022705
# Train Epoch: 100 Batch: 2 Total samples processed: 96 Loss: 0.06019365414977074
# Train Epoch: 100 Batch: 3 Total samples processed: 128 Loss: 0.06342317163944244
# Train Epoch: 101 Batch: 0 Total samples processed: 32 Loss: 0.058959681540727615
# Train Epoch: 101 Batch: 1 Total samples processed: 64 Loss: 0.05856054276227951
# Train Epoch: 101 Batch: 2 Total samples processed: 96 Loss: 0.05994746834039688
# Train Epoch: 101 Batch: 3 Total samples processed: 128 Loss: 0.06007573381066322
# Train Epoch: 102 Batch: 0 Total samples processed: 32 Loss: 0.058629535138607025
# Train Epoch: 102 Batch: 1 Total samples processed: 64 Loss: 0.05846811458468437
# Train Epoch: 102 Batch: 2 Total samples processed: 96 Loss: 0.05821854621171951
# Train Epoch: 102 Batch: 3 Total samples processed: 128 Loss: 0.06170261651277542
# Train Epoch: 103 Batch: 0 Total samples processed: 32 Loss: 0.060057856142520905
# Train Epoch: 103 Batch: 1 Total samples processed: 64 Loss: 0.058413758873939514
# Train Epoch: 103 Batch: 2 Total samples processed: 96 Loss: 0.05789753794670105
# Train Epoch: 103 Batch: 3 Total samples processed: 128 Loss: 0.059458136558532715
# Train Epoch: 104 Batch: 0 Total samples processed: 32 Loss: 0.06070014461874962
# Train Epoch: 104 Batch: 1 Total samples processed: 64 Loss: 0.05781044065952301
# Train Epoch: 104 Batch: 2 Total samples processed: 96 Loss: 0.058675505220890045
# Train Epoch: 104 Batch: 3 Total samples processed: 128 Loss: 0.0678369551897049
# Train Epoch: 105 Batch: 0 Total samples processed: 32 Loss: 0.05894577130675316
# Train Epoch: 105 Batch: 1 Total samples processed: 64 Loss: 0.05768578499555588
# Train Epoch: 105 Batch: 2 Total samples processed: 96 Loss: 0.05930088832974434
# Train Epoch: 105 Batch: 3 Total samples processed: 128 Loss: 0.061265118420124054
# Train Epoch: 106 Batch: 0 Total samples processed: 32 Loss: 0.06200122833251953
# Train Epoch: 106 Batch: 1 Total samples processed: 64 Loss: 0.06099814549088478
# Train Epoch: 106 Batch: 2 Total samples processed: 96 Loss: 0.05720304697751999
# Train Epoch: 106 Batch: 3 Total samples processed: 128 Loss: 0.05315926671028137
# Train Epoch: 107 Batch: 0 Total samples processed: 32 Loss: 0.06010446324944496
# Train Epoch: 107 Batch: 1 Total samples processed: 64 Loss: 0.05904756486415863
# Train Epoch: 107 Batch: 2 Total samples processed: 96 Loss: 0.056720077991485596
# Train Epoch: 107 Batch: 3 Total samples processed: 128 Loss: 0.05616403743624687
# Train Epoch: 108 Batch: 0 Total samples processed: 32 Loss: 0.06045626476407051
# Train Epoch: 108 Batch: 1 Total samples processed: 64 Loss: 0.05740182101726532
# Train Epoch: 108 Batch: 2 Total samples processed: 96 Loss: 0.05744241923093796
# Train Epoch: 108 Batch: 3 Total samples processed: 128 Loss: 0.06147553026676178
# Train Epoch: 109 Batch: 0 Total samples processed: 32 Loss: 0.05714966356754303
# Train Epoch: 109 Batch: 1 Total samples processed: 64 Loss: 0.05719421058893204
# Train Epoch: 109 Batch: 2 Total samples processed: 96 Loss: 0.05833607167005539
# Train Epoch: 109 Batch: 3 Total samples processed: 128 Loss: 0.06894507259130478
# Train Epoch: 110 Batch: 0 Total samples processed: 32 Loss: 0.06063137203454971
# Train Epoch: 110 Batch: 1 Total samples processed: 64 Loss: 0.06054161489009857
# Train Epoch: 110 Batch: 2 Total samples processed: 96 Loss: 0.05748407915234566
# Train Epoch: 110 Batch: 3 Total samples processed: 128 Loss: 0.05626823008060455
# Train Epoch: 111 Batch: 0 Total samples processed: 32 Loss: 0.05875425785779953
# Train Epoch: 111 Batch: 1 Total samples processed: 64 Loss: 0.06139816343784332
# Train Epoch: 111 Batch: 2 Total samples processed: 96 Loss: 0.057719454169273376
# Train Epoch: 111 Batch: 3 Total samples processed: 128 Loss: 0.05914817005395889
# Train Epoch: 112 Batch: 0 Total samples processed: 32 Loss: 0.060597896575927734
# Train Epoch: 112 Batch: 1 Total samples processed: 64 Loss: 0.05700467526912689
# Train Epoch: 112 Batch: 2 Total samples processed: 96 Loss: 0.058741986751556396
# Train Epoch: 112 Batch: 3 Total samples processed: 128 Loss: 0.056561220437288284
# Train Epoch: 113 Batch: 0 Total samples processed: 32 Loss: 0.057966552674770355
# Train Epoch: 113 Batch: 1 Total samples processed: 64 Loss: 0.056744568049907684
# Train Epoch: 113 Batch: 2 Total samples processed: 96 Loss: 0.05874723196029663
# Train Epoch: 113 Batch: 3 Total samples processed: 128 Loss: 0.05646649748086929
# Train Epoch: 114 Batch: 0 Total samples processed: 32 Loss: 0.05703810229897499
# Train Epoch: 114 Batch: 1 Total samples processed: 64 Loss: 0.05609973892569542
# Train Epoch: 114 Batch: 2 Total samples processed: 96 Loss: 0.058995358645915985
# Train Epoch: 114 Batch: 3 Total samples processed: 128 Loss: 0.06355997920036316
# Train Epoch: 115 Batch: 0 Total samples processed: 32 Loss: 0.055877093225717545
# Train Epoch: 115 Batch: 1 Total samples processed: 64 Loss: 0.06030682474374771
# Train Epoch: 115 Batch: 2 Total samples processed: 96 Loss: 0.05983090400695801
# Train Epoch: 115 Batch: 3 Total samples processed: 128 Loss: 0.060357965528964996
# Train Epoch: 116 Batch: 0 Total samples processed: 32 Loss: 0.05961712449789047
# Train Epoch: 116 Batch: 1 Total samples processed: 64 Loss: 0.058660611510276794
# Train Epoch: 116 Batch: 2 Total samples processed: 96 Loss: 0.056731488555669785
# Train Epoch: 116 Batch: 3 Total samples processed: 128 Loss: 0.06038082391023636
# Train Epoch: 117 Batch: 0 Total samples processed: 32 Loss: 0.05808285251259804
# Train Epoch: 117 Batch: 1 Total samples processed: 64 Loss: 0.05586247891187668
# Train Epoch: 117 Batch: 2 Total samples processed: 96 Loss: 0.05842715501785278
# Train Epoch: 117 Batch: 3 Total samples processed: 128 Loss: 0.06190623715519905
# Train Epoch: 118 Batch: 0 Total samples processed: 32 Loss: 0.05723702535033226
# Train Epoch: 118 Batch: 1 Total samples processed: 64 Loss: 0.05646243691444397
# Train Epoch: 118 Batch: 2 Total samples processed: 96 Loss: 0.05816136300563812
# Train Epoch: 118 Batch: 3 Total samples processed: 128 Loss: 0.05549921095371246
# Train Epoch: 119 Batch: 0 Total samples processed: 32 Loss: 0.05664066970348358
# Train Epoch: 119 Batch: 1 Total samples processed: 64 Loss: 0.060335904359817505
# Train Epoch: 119 Batch: 2 Total samples processed: 96 Loss: 0.0570795014500618
# Train Epoch: 119 Batch: 3 Total samples processed: 128 Loss: 0.05909823998808861
# Train Epoch: 120 Batch: 0 Total samples processed: 32 Loss: 0.06134050339460373
# Train Epoch: 120 Batch: 1 Total samples processed: 64 Loss: 0.05580609291791916
# Train Epoch: 120 Batch: 2 Total samples processed: 96 Loss: 0.05720527470111847
# Train Epoch: 120 Batch: 3 Total samples processed: 128 Loss: 0.059304069727659225
# Train Epoch: 121 Batch: 0 Total samples processed: 32 Loss: 0.0563475638628006
# Train Epoch: 121 Batch: 1 Total samples processed: 64 Loss: 0.057325445115566254
# Train Epoch: 121 Batch: 2 Total samples processed: 96 Loss: 0.057664576917886734
# Train Epoch: 121 Batch: 3 Total samples processed: 128 Loss: 0.05971258878707886
# Train Epoch: 122 Batch: 0 Total samples processed: 32 Loss: 0.0595286600291729
# Train Epoch: 122 Batch: 1 Total samples processed: 64 Loss: 0.0588197223842144
# Train Epoch: 122 Batch: 2 Total samples processed: 96 Loss: 0.0575757697224617
# Train Epoch: 122 Batch: 3 Total samples processed: 128 Loss: 0.05804209038615227
# Train Epoch: 123 Batch: 0 Total samples processed: 32 Loss: 0.05754445120692253
# Train Epoch: 123 Batch: 1 Total samples processed: 64 Loss: 0.057842034846544266
# Train Epoch: 123 Batch: 2 Total samples processed: 96 Loss: 0.05671738088130951
# Train Epoch: 123 Batch: 3 Total samples processed: 128 Loss: 0.05702084302902222
# Train Epoch: 124 Batch: 0 Total samples processed: 32 Loss: 0.05820664390921593
# Train Epoch: 124 Batch: 1 Total samples processed: 64 Loss: 0.058275140821933746
# Train Epoch: 124 Batch: 2 Total samples processed: 96 Loss: 0.055124979466199875
# Train Epoch: 124 Batch: 3 Total samples processed: 128 Loss: 0.05720626562833786
# Train Epoch: 125 Batch: 0 Total samples processed: 32 Loss: 0.05640088766813278
# Train Epoch: 125 Batch: 1 Total samples processed: 64 Loss: 0.05505779758095741
# Train Epoch: 125 Batch: 2 Total samples processed: 96 Loss: 0.05928526073694229
# Train Epoch: 125 Batch: 3 Total samples processed: 128 Loss: 0.05822557955980301
# Train Epoch: 126 Batch: 0 Total samples processed: 32 Loss: 0.05509567633271217
# Train Epoch: 126 Batch: 1 Total samples processed: 64 Loss: 0.05866008251905441
# Train Epoch: 126 Batch: 2 Total samples processed: 96 Loss: 0.055101603269577026
# Train Epoch: 126 Batch: 3 Total samples processed: 128 Loss: 0.05791204422712326
# Train Epoch: 127 Batch: 0 Total samples processed: 32 Loss: 0.0575985461473465
# Train Epoch: 127 Batch: 1 Total samples processed: 64 Loss: 0.05793590843677521
# Train Epoch: 127 Batch: 2 Total samples processed: 96 Loss: 0.055952124297618866
# Train Epoch: 127 Batch: 3 Total samples processed: 128 Loss: 0.05443244427442551
# Train Epoch: 128 Batch: 0 Total samples processed: 32 Loss: 0.05830980837345123
# Train Epoch: 128 Batch: 1 Total samples processed: 64 Loss: 0.05768607556819916
# Train Epoch: 128 Batch: 2 Total samples processed: 96 Loss: 0.05506458878517151
# Train Epoch: 128 Batch: 3 Total samples processed: 128 Loss: 0.056561242789030075
# Train Epoch: 129 Batch: 0 Total samples processed: 32 Loss: 0.05686035752296448
# Train Epoch: 129 Batch: 1 Total samples processed: 64 Loss: 0.056962769478559494
# Train Epoch: 129 Batch: 2 Total samples processed: 96 Loss: 0.05611899495124817
# Train Epoch: 129 Batch: 3 Total samples processed: 128 Loss: 0.05683131888508797
# Train Epoch: 130 Batch: 0 Total samples processed: 32 Loss: 0.056130558252334595
# Train Epoch: 130 Batch: 1 Total samples processed: 64 Loss: 0.05699484795331955
# Train Epoch: 130 Batch: 2 Total samples processed: 96 Loss: 0.05701332539319992
# Train Epoch: 130 Batch: 3 Total samples processed: 128 Loss: 0.05601586401462555
# Train Epoch: 131 Batch: 0 Total samples processed: 32 Loss: 0.05674450099468231
# Train Epoch: 131 Batch: 1 Total samples processed: 64 Loss: 0.056567974388599396
# Train Epoch: 131 Batch: 2 Total samples processed: 96 Loss: 0.05570237338542938
# Train Epoch: 131 Batch: 3 Total samples processed: 128 Loss: 0.054797716438770294
# Train Epoch: 132 Batch: 0 Total samples processed: 32 Loss: 0.05623948574066162
# Train Epoch: 132 Batch: 1 Total samples processed: 64 Loss: 0.054509371519088745
# Train Epoch: 132 Batch: 2 Total samples processed: 96 Loss: 0.05538071319460869
# Train Epoch: 132 Batch: 3 Total samples processed: 128 Loss: 0.05622562766075134
# Train Epoch: 133 Batch: 0 Total samples processed: 32 Loss: 0.0537744015455246
# Train Epoch: 133 Batch: 1 Total samples processed: 64 Loss: 0.05431397259235382
# Train Epoch: 133 Batch: 2 Total samples processed: 96 Loss: 0.05651897192001343
# Train Epoch: 133 Batch: 3 Total samples processed: 128 Loss: 0.06438098847866058
# Train Epoch: 134 Batch: 0 Total samples processed: 32 Loss: 0.05474244803190231
# Train Epoch: 134 Batch: 1 Total samples processed: 64 Loss: 0.05936136096715927
# Train Epoch: 134 Batch: 2 Total samples processed: 96 Loss: 0.056929685175418854
# Train Epoch: 134 Batch: 3 Total samples processed: 128 Loss: 0.05273420736193657
# Train Epoch: 135 Batch: 0 Total samples processed: 32 Loss: 0.05593883991241455
# Train Epoch: 135 Batch: 1 Total samples processed: 64 Loss: 0.05366158485412598
# Train Epoch: 135 Batch: 2 Total samples processed: 96 Loss: 0.055452026426792145
# Train Epoch: 135 Batch: 3 Total samples processed: 128 Loss: 0.054474107921123505
# Train Epoch: 136 Batch: 0 Total samples processed: 32 Loss: 0.054771341383457184
# Train Epoch: 136 Batch: 1 Total samples processed: 64 Loss: 0.05244910344481468
# Train Epoch: 136 Batch: 2 Total samples processed: 96 Loss: 0.05586440861225128
# Train Epoch: 136 Batch: 3 Total samples processed: 128 Loss: 0.05492111295461655
# Train Epoch: 137 Batch: 0 Total samples processed: 32 Loss: 0.05504108965396881
# Train Epoch: 137 Batch: 1 Total samples processed: 64 Loss: 0.0545499213039875
# Train Epoch: 137 Batch: 2 Total samples processed: 96 Loss: 0.05460251122713089
# Train Epoch: 137 Batch: 3 Total samples processed: 128 Loss: 0.05484780669212341
# Train Epoch: 138 Batch: 0 Total samples processed: 32 Loss: 0.054940368980169296
# Train Epoch: 138 Batch: 1 Total samples processed: 64 Loss: 0.05419508367776871
# Train Epoch: 138 Batch: 2 Total samples processed: 96 Loss: 0.05506636202335358
# Train Epoch: 138 Batch: 3 Total samples processed: 128 Loss: 0.05826567858457565
# Train Epoch: 139 Batch: 0 Total samples processed: 32 Loss: 0.054752450436353683
# Train Epoch: 139 Batch: 1 Total samples processed: 64 Loss: 0.054600343108177185
# Train Epoch: 139 Batch: 2 Total samples processed: 96 Loss: 0.055511124432086945
# Train Epoch: 139 Batch: 3 Total samples processed: 128 Loss: 0.057227566838264465
# Train Epoch: 140 Batch: 0 Total samples processed: 32 Loss: 0.05506543442606926
# Train Epoch: 140 Batch: 1 Total samples processed: 64 Loss: 0.056555699557065964
# Train Epoch: 140 Batch: 2 Total samples processed: 96 Loss: 0.054021090269088745
# Train Epoch: 140 Batch: 3 Total samples processed: 128 Loss: 0.05548015236854553
# Train Epoch: 141 Batch: 0 Total samples processed: 32 Loss: 0.05465459078550339
# Train Epoch: 141 Batch: 1 Total samples processed: 64 Loss: 0.05672089755535126
# Train Epoch: 141 Batch: 2 Total samples processed: 96 Loss: 0.053566984832286835
# Train Epoch: 141 Batch: 3 Total samples processed: 128 Loss: 0.05200055241584778
# Train Epoch: 142 Batch: 0 Total samples processed: 32 Loss: 0.05343712121248245
# Train Epoch: 142 Batch: 1 Total samples processed: 64 Loss: 0.055181972682476044
# Train Epoch: 142 Batch: 2 Total samples processed: 96 Loss: 0.0542987585067749
# Train Epoch: 142 Batch: 3 Total samples processed: 128 Loss: 0.052674800157547
# Train Epoch: 143 Batch: 0 Total samples processed: 32 Loss: 0.05390205234289169
# Train Epoch: 143 Batch: 1 Total samples processed: 64 Loss: 0.052777282893657684
# Train Epoch: 143 Batch: 2 Total samples processed: 96 Loss: 0.05420558899641037
# Train Epoch: 143 Batch: 3 Total samples processed: 128 Loss: 0.056718774139881134
# Train Epoch: 144 Batch: 0 Total samples processed: 32 Loss: 0.0534977987408638
# Train Epoch: 144 Batch: 1 Total samples processed: 64 Loss: 0.05456480011343956
# Train Epoch: 144 Batch: 2 Total samples processed: 96 Loss: 0.05268801376223564
# Train Epoch: 144 Batch: 3 Total samples processed: 128 Loss: 0.056229911744594574
# Train Epoch: 145 Batch: 0 Total samples processed: 32 Loss: 0.0540039949119091
# Train Epoch: 145 Batch: 1 Total samples processed: 64 Loss: 0.05272369831800461
# Train Epoch: 145 Batch: 2 Total samples processed: 96 Loss: 0.05392542481422424
# Train Epoch: 145 Batch: 3 Total samples processed: 128 Loss: 0.05426465719938278
# Train Epoch: 146 Batch: 0 Total samples processed: 32 Loss: 0.05285918340086937
# Train Epoch: 146 Batch: 1 Total samples processed: 64 Loss: 0.05465378984808922
# Train Epoch: 146 Batch: 2 Total samples processed: 96 Loss: 0.05330313369631767
# Train Epoch: 146 Batch: 3 Total samples processed: 128 Loss: 0.0550251305103302
# Train Epoch: 147 Batch: 0 Total samples processed: 32 Loss: 0.05258522182703018
# Train Epoch: 147 Batch: 1 Total samples processed: 64 Loss: 0.053051166236400604
# Train Epoch: 147 Batch: 2 Total samples processed: 96 Loss: 0.05510006844997406
# Train Epoch: 147 Batch: 3 Total samples processed: 128 Loss: 0.05223262310028076
# Train Epoch: 148 Batch: 0 Total samples processed: 32 Loss: 0.05379132181406021
# Train Epoch: 148 Batch: 1 Total samples processed: 64 Loss: 0.05498816817998886
# Train Epoch: 148 Batch: 2 Total samples processed: 96 Loss: 0.05501618981361389
# Train Epoch: 148 Batch: 3 Total samples processed: 128 Loss: 0.05675182119011879
# Train Epoch: 149 Batch: 0 Total samples processed: 32 Loss: 0.05217679589986801
# Train Epoch: 149 Batch: 1 Total samples processed: 64 Loss: 0.05448039621114731
# Train Epoch: 149 Batch: 2 Total samples processed: 96 Loss: 0.05525083839893341
# Train Epoch: 149 Batch: 3 Total samples processed: 128 Loss: 0.0554085299372673
# Train Epoch: 150 Batch: 0 Total samples processed: 32 Loss: 0.05284622311592102
# Train Epoch: 150 Batch: 1 Total samples processed: 64 Loss: 0.053761787712574005
# Train Epoch: 150 Batch: 2 Total samples processed: 96 Loss: 0.05348082631826401
# Train Epoch: 150 Batch: 3 Total samples processed: 128 Loss: 0.05200442671775818
# Train Epoch: 151 Batch: 0 Total samples processed: 32 Loss: 0.05138804763555527
# Train Epoch: 151 Batch: 1 Total samples processed: 64 Loss: 0.054383013397455215
# Train Epoch: 151 Batch: 2 Total samples processed: 96 Loss: 0.05418157950043678
# Train Epoch: 151 Batch: 3 Total samples processed: 128 Loss: 0.05456103757023811
# Train Epoch: 152 Batch: 0 Total samples processed: 32 Loss: 0.05243069306015968
# Train Epoch: 152 Batch: 1 Total samples processed: 64 Loss: 0.05323099344968796
# Train Epoch: 152 Batch: 2 Total samples processed: 96 Loss: 0.053284209221601486
# Train Epoch: 152 Batch: 3 Total samples processed: 128 Loss: 0.05401817709207535
# Train Epoch: 153 Batch: 0 Total samples processed: 32 Loss: 0.05257145315408707
# Train Epoch: 153 Batch: 1 Total samples processed: 64 Loss: 0.053444817662239075
# Train Epoch: 153 Batch: 2 Total samples processed: 96 Loss: 0.053439535200595856
# Train Epoch: 153 Batch: 3 Total samples processed: 128 Loss: 0.05166797339916229
# Train Epoch: 154 Batch: 0 Total samples processed: 32 Loss: 0.05281941592693329
# Train Epoch: 154 Batch: 1 Total samples processed: 64 Loss: 0.0529966726899147
# Train Epoch: 154 Batch: 2 Total samples processed: 96 Loss: 0.055962663143873215
# Train Epoch: 154 Batch: 3 Total samples processed: 128 Loss: 0.05543065816164017
# Train Epoch: 155 Batch: 0 Total samples processed: 32 Loss: 0.052027538418769836
# Train Epoch: 155 Batch: 1 Total samples processed: 64 Loss: 0.0533168651163578
# Train Epoch: 155 Batch: 2 Total samples processed: 96 Loss: 0.05312812700867653
# Train Epoch: 155 Batch: 3 Total samples processed: 128 Loss: 0.05885157734155655
# Train Epoch: 156 Batch: 0 Total samples processed: 32 Loss: 0.05409309267997742
# Train Epoch: 156 Batch: 1 Total samples processed: 64 Loss: 0.05405304208397865
# Train Epoch: 156 Batch: 2 Total samples processed: 96 Loss: 0.05226943641901016
# Train Epoch: 156 Batch: 3 Total samples processed: 128 Loss: 0.05314787104725838
# Train Epoch: 157 Batch: 0 Total samples processed: 32 Loss: 0.05602680891752243
# Train Epoch: 157 Batch: 1 Total samples processed: 64 Loss: 0.053380243480205536
# Train Epoch: 157 Batch: 2 Total samples processed: 96 Loss: 0.052587226033210754
# Train Epoch: 157 Batch: 3 Total samples processed: 128 Loss: 0.05650121718645096
# Train Epoch: 158 Batch: 0 Total samples processed: 32 Loss: 0.05390401929616928
# Train Epoch: 158 Batch: 1 Total samples processed: 64 Loss: 0.05509759485721588
# Train Epoch: 158 Batch: 2 Total samples processed: 96 Loss: 0.053744181990623474
# Train Epoch: 158 Batch: 3 Total samples processed: 128 Loss: 0.053059887140989304
# Train Epoch: 159 Batch: 0 Total samples processed: 32 Loss: 0.051946528255939484
# Train Epoch: 159 Batch: 1 Total samples processed: 64 Loss: 0.05211027339100838
# Train Epoch: 159 Batch: 2 Total samples processed: 96 Loss: 0.05326157063245773
# Train Epoch: 159 Batch: 3 Total samples processed: 128 Loss: 0.05760856717824936
# Train Epoch: 160 Batch: 0 Total samples processed: 32 Loss: 0.05233181267976761
# Train Epoch: 160 Batch: 1 Total samples processed: 64 Loss: 0.05173030495643616
# Train Epoch: 160 Batch: 2 Total samples processed: 96 Loss: 0.054719917476177216
# Train Epoch: 160 Batch: 3 Total samples processed: 128 Loss: 0.053479716181755066
# Train Epoch: 161 Batch: 0 Total samples processed: 32 Loss: 0.05362425744533539
# Train Epoch: 161 Batch: 1 Total samples processed: 64 Loss: 0.051005758345127106
# Train Epoch: 161 Batch: 2 Total samples processed: 96 Loss: 0.05372334271669388
# Train Epoch: 161 Batch: 3 Total samples processed: 128 Loss: 0.051884155720472336
# Train Epoch: 162 Batch: 0 Total samples processed: 32 Loss: 0.05272647738456726
# Train Epoch: 162 Batch: 1 Total samples processed: 64 Loss: 0.05307120829820633
# Train Epoch: 162 Batch: 2 Total samples processed: 96 Loss: 0.05422559380531311
# Train Epoch: 162 Batch: 3 Total samples processed: 128 Loss: 0.0556110143661499
# Train Epoch: 163 Batch: 0 Total samples processed: 32 Loss: 0.05244129151105881
# Train Epoch: 163 Batch: 1 Total samples processed: 64 Loss: 0.051915403455495834
# Train Epoch: 163 Batch: 2 Total samples processed: 96 Loss: 0.052657924592494965
# Train Epoch: 163 Batch: 3 Total samples processed: 128 Loss: 0.04926351457834244
# Train Epoch: 164 Batch: 0 Total samples processed: 32 Loss: 0.05232372507452965
# Train Epoch: 164 Batch: 1 Total samples processed: 64 Loss: 0.05296259745955467
# Train Epoch: 164 Batch: 2 Total samples processed: 96 Loss: 0.05174640566110611
# Train Epoch: 164 Batch: 3 Total samples processed: 128 Loss: 0.04964730516076088
# Train Epoch: 165 Batch: 0 Total samples processed: 32 Loss: 0.052102431654930115
# Train Epoch: 165 Batch: 1 Total samples processed: 64 Loss: 0.05185761675238609
# Train Epoch: 165 Batch: 2 Total samples processed: 96 Loss: 0.05233679711818695
# Train Epoch: 165 Batch: 3 Total samples processed: 128 Loss: 0.05376382917165756
# Train Epoch: 166 Batch: 0 Total samples processed: 32 Loss: 0.05228858441114426
# Train Epoch: 166 Batch: 1 Total samples processed: 64 Loss: 0.05296194180846214
# Train Epoch: 166 Batch: 2 Total samples processed: 96 Loss: 0.052078716456890106
# Train Epoch: 166 Batch: 3 Total samples processed: 128 Loss: 0.0549502894282341
# Train Epoch: 167 Batch: 0 Total samples processed: 32 Loss: 0.05364741384983063
# Train Epoch: 167 Batch: 1 Total samples processed: 64 Loss: 0.05522199720144272
# Train Epoch: 167 Batch: 2 Total samples processed: 96 Loss: 0.05169073864817619
# Train Epoch: 167 Batch: 3 Total samples processed: 128 Loss: 0.05265810340642929
# Train Epoch: 168 Batch: 0 Total samples processed: 32 Loss: 0.05474844202399254
# Train Epoch: 168 Batch: 1 Total samples processed: 64 Loss: 0.05082138255238533
# Train Epoch: 168 Batch: 2 Total samples processed: 96 Loss: 0.05219282582402229
# Train Epoch: 168 Batch: 3 Total samples processed: 128 Loss: 0.055522412061691284
# Train Epoch: 169 Batch: 0 Total samples processed: 32 Loss: 0.05220996215939522
# Train Epoch: 169 Batch: 1 Total samples processed: 64 Loss: 0.0520583838224411
# Train Epoch: 169 Batch: 2 Total samples processed: 96 Loss: 0.05390686169266701
# Train Epoch: 169 Batch: 3 Total samples processed: 128 Loss: 0.051890213042497635
# Train Epoch: 170 Batch: 0 Total samples processed: 32 Loss: 0.05226542055606842
# Train Epoch: 170 Batch: 1 Total samples processed: 64 Loss: 0.054494135081768036
# Train Epoch: 170 Batch: 2 Total samples processed: 96 Loss: 0.05253183841705322
# Train Epoch: 170 Batch: 3 Total samples processed: 128 Loss: 0.055218495428562164
# Train Epoch: 171 Batch: 0 Total samples processed: 32 Loss: 0.04996562376618385
# Train Epoch: 171 Batch: 1 Total samples processed: 64 Loss: 0.05332213640213013
# Train Epoch: 171 Batch: 2 Total samples processed: 96 Loss: 0.05262262374162674
# Train Epoch: 171 Batch: 3 Total samples processed: 128 Loss: 0.0541037991642952
# Train Epoch: 172 Batch: 0 Total samples processed: 32 Loss: 0.05240495502948761
# Train Epoch: 172 Batch: 1 Total samples processed: 64 Loss: 0.05411818251013756
# Train Epoch: 172 Batch: 2 Total samples processed: 96 Loss: 0.05222482979297638
# Train Epoch: 172 Batch: 3 Total samples processed: 128 Loss: 0.04859194532036781
# Train Epoch: 173 Batch: 0 Total samples processed: 32 Loss: 0.05418569967150688
# Train Epoch: 173 Batch: 1 Total samples processed: 64 Loss: 0.05146174132823944
# Train Epoch: 173 Batch: 2 Total samples processed: 96 Loss: 0.05152092128992081
# Train Epoch: 173 Batch: 3 Total samples processed: 128 Loss: 0.05138034373521805
# Train Epoch: 174 Batch: 0 Total samples processed: 32 Loss: 0.052667081356048584
# Train Epoch: 174 Batch: 1 Total samples processed: 64 Loss: 0.05171172320842743
# Train Epoch: 174 Batch: 2 Total samples processed: 96 Loss: 0.05261319875717163
# Train Epoch: 174 Batch: 3 Total samples processed: 128 Loss: 0.05611066892743111
# Train Epoch: 175 Batch: 0 Total samples processed: 32 Loss: 0.05282583087682724
# Train Epoch: 175 Batch: 1 Total samples processed: 64 Loss: 0.051242731511592865
# Train Epoch: 175 Batch: 2 Total samples processed: 96 Loss: 0.05221642181277275
# Train Epoch: 175 Batch: 3 Total samples processed: 128 Loss: 0.052688658237457275
# Train Epoch: 176 Batch: 0 Total samples processed: 32 Loss: 0.05155874416232109
# Train Epoch: 176 Batch: 1 Total samples processed: 64 Loss: 0.05226270109415054
# Train Epoch: 176 Batch: 2 Total samples processed: 96 Loss: 0.05212123692035675
# Train Epoch: 176 Batch: 3 Total samples processed: 128 Loss: 0.054740458726882935
# Train Epoch: 177 Batch: 0 Total samples processed: 32 Loss: 0.0516914427280426
# Train Epoch: 177 Batch: 1 Total samples processed: 64 Loss: 0.05166744440793991
# Train Epoch: 177 Batch: 2 Total samples processed: 96 Loss: 0.051916323602199554
# Train Epoch: 177 Batch: 3 Total samples processed: 128 Loss: 0.05132453888654709
# Train Epoch: 178 Batch: 0 Total samples processed: 32 Loss: 0.05136100947856903
# Train Epoch: 178 Batch: 1 Total samples processed: 64 Loss: 0.05388971418142319
# Train Epoch: 178 Batch: 2 Total samples processed: 96 Loss: 0.049794502556324005
# Train Epoch: 178 Batch: 3 Total samples processed: 128 Loss: 0.054884329438209534
# Train Epoch: 179 Batch: 0 Total samples processed: 32 Loss: 0.051864027976989746
# Train Epoch: 179 Batch: 1 Total samples processed: 64 Loss: 0.04991438612341881
# Train Epoch: 179 Batch: 2 Total samples processed: 96 Loss: 0.05038149654865265
# Train Epoch: 179 Batch: 3 Total samples processed: 128 Loss: 0.054591402411460876
# Train Epoch: 180 Batch: 0 Total samples processed: 32 Loss: 0.05105223134160042
# Train Epoch: 180 Batch: 1 Total samples processed: 64 Loss: 0.051448188722133636
# Train Epoch: 180 Batch: 2 Total samples processed: 96 Loss: 0.05087624490261078
# Train Epoch: 180 Batch: 3 Total samples processed: 128 Loss: 0.056817393749952316
# Train Epoch: 181 Batch: 0 Total samples processed: 32 Loss: 0.050899095833301544
# Train Epoch: 181 Batch: 1 Total samples processed: 64 Loss: 0.0513811931014061
# Train Epoch: 181 Batch: 2 Total samples processed: 96 Loss: 0.05208370089530945
# Train Epoch: 181 Batch: 3 Total samples processed: 128 Loss: 0.0540238618850708
# Train Epoch: 182 Batch: 0 Total samples processed: 32 Loss: 0.05296759307384491
# Train Epoch: 182 Batch: 1 Total samples processed: 64 Loss: 0.052987027913331985
# Train Epoch: 182 Batch: 2 Total samples processed: 96 Loss: 0.05270858481526375
# Train Epoch: 182 Batch: 3 Total samples processed: 128 Loss: 0.05406881868839264
# Train Epoch: 183 Batch: 0 Total samples processed: 32 Loss: 0.050792090594768524
# Train Epoch: 183 Batch: 1 Total samples processed: 64 Loss: 0.0512780100107193
# Train Epoch: 183 Batch: 2 Total samples processed: 96 Loss: 0.051308415830135345
# Train Epoch: 183 Batch: 3 Total samples processed: 128 Loss: 0.05046379938721657
# Train Epoch: 184 Batch: 0 Total samples processed: 32 Loss: 0.050807513296604156
# Train Epoch: 184 Batch: 1 Total samples processed: 64 Loss: 0.05109882727265358
# Train Epoch: 184 Batch: 2 Total samples processed: 96 Loss: 0.05129594728350639
# Train Epoch: 184 Batch: 3 Total samples processed: 128 Loss: 0.049806367605924606
# Train Epoch: 185 Batch: 0 Total samples processed: 32 Loss: 0.049392376095056534
# Train Epoch: 185 Batch: 1 Total samples processed: 64 Loss: 0.05223432928323746
# Train Epoch: 185 Batch: 2 Total samples processed: 96 Loss: 0.05012904852628708
# Train Epoch: 185 Batch: 3 Total samples processed: 128 Loss: 0.054648496210575104
# Train Epoch: 186 Batch: 0 Total samples processed: 32 Loss: 0.049535974860191345
# Train Epoch: 186 Batch: 1 Total samples processed: 64 Loss: 0.04997734725475311
# Train Epoch: 186 Batch: 2 Total samples processed: 96 Loss: 0.051582399755716324
# Train Epoch: 186 Batch: 3 Total samples processed: 128 Loss: 0.051232147961854935
# Train Epoch: 187 Batch: 0 Total samples processed: 32 Loss: 0.049861181527376175
# Train Epoch: 187 Batch: 1 Total samples processed: 64 Loss: 0.05184640735387802
# Train Epoch: 187 Batch: 2 Total samples processed: 96 Loss: 0.04979126155376434
# Train Epoch: 187 Batch: 3 Total samples processed: 128 Loss: 0.05201994627714157
# Train Epoch: 188 Batch: 0 Total samples processed: 32 Loss: 0.05042055994272232
# Train Epoch: 188 Batch: 1 Total samples processed: 64 Loss: 0.04986592009663582
# Train Epoch: 188 Batch: 2 Total samples processed: 96 Loss: 0.0502437949180603
# Train Epoch: 188 Batch: 3 Total samples processed: 128 Loss: 0.04839414358139038
# Train Epoch: 189 Batch: 0 Total samples processed: 32 Loss: 0.05195767432451248
# Train Epoch: 189 Batch: 1 Total samples processed: 64 Loss: 0.05018436908721924
# Train Epoch: 189 Batch: 2 Total samples processed: 96 Loss: 0.04916093498468399
# Train Epoch: 189 Batch: 3 Total samples processed: 128 Loss: 0.05368804931640625
# Train Epoch: 190 Batch: 0 Total samples processed: 32 Loss: 0.05104077234864235
# Train Epoch: 190 Batch: 1 Total samples processed: 64 Loss: 0.050298187881708145
# Train Epoch: 190 Batch: 2 Total samples processed: 96 Loss: 0.04927925765514374
# Train Epoch: 190 Batch: 3 Total samples processed: 128 Loss: 0.04754452034831047
# Train Epoch: 191 Batch: 0 Total samples processed: 32 Loss: 0.0525917187333107
# Train Epoch: 191 Batch: 1 Total samples processed: 64 Loss: 0.050599467009305954
# Train Epoch: 191 Batch: 2 Total samples processed: 96 Loss: 0.04934796318411827
# Train Epoch: 191 Batch: 3 Total samples processed: 128 Loss: 0.050390347838401794
# Train Epoch: 192 Batch: 0 Total samples processed: 32 Loss: 0.04896017909049988
# Train Epoch: 192 Batch: 1 Total samples processed: 64 Loss: 0.05046429857611656
# Train Epoch: 192 Batch: 2 Total samples processed: 96 Loss: 0.052716806530952454
# Train Epoch: 192 Batch: 3 Total samples processed: 128 Loss: 0.052048757672309875
# Train Epoch: 193 Batch: 0 Total samples processed: 32 Loss: 0.05054953321814537
# Train Epoch: 193 Batch: 1 Total samples processed: 64 Loss: 0.04885381460189819
# Train Epoch: 193 Batch: 2 Total samples processed: 96 Loss: 0.049795642495155334
# Train Epoch: 193 Batch: 3 Total samples processed: 128 Loss: 0.05162554234266281
# Train Epoch: 194 Batch: 0 Total samples processed: 32 Loss: 0.048420682549476624
# Train Epoch: 194 Batch: 1 Total samples processed: 64 Loss: 0.05271857976913452
# Train Epoch: 194 Batch: 2 Total samples processed: 96 Loss: 0.051211193203926086
# Train Epoch: 194 Batch: 3 Total samples processed: 128 Loss: 0.05408911406993866
# Train Epoch: 195 Batch: 0 Total samples processed: 32 Loss: 0.04984806478023529
# Train Epoch: 195 Batch: 1 Total samples processed: 64 Loss: 0.04965534433722496
# Train Epoch: 195 Batch: 2 Total samples processed: 96 Loss: 0.049718163907527924
# Train Epoch: 195 Batch: 3 Total samples processed: 128 Loss: 0.053836870938539505
# Train Epoch: 196 Batch: 0 Total samples processed: 32 Loss: 0.05072341859340668
# Train Epoch: 196 Batch: 1 Total samples processed: 64 Loss: 0.048101261258125305
# Train Epoch: 196 Batch: 2 Total samples processed: 96 Loss: 0.051654405891895294
# Train Epoch: 196 Batch: 3 Total samples processed: 128 Loss: 0.04905577749013901
# Train Epoch: 197 Batch: 0 Total samples processed: 32 Loss: 0.05128200352191925
# Train Epoch: 197 Batch: 1 Total samples processed: 64 Loss: 0.05111619830131531
# Train Epoch: 197 Batch: 2 Total samples processed: 96 Loss: 0.04992526024580002
# Train Epoch: 197 Batch: 3 Total samples processed: 128 Loss: 0.053336407989263535
# Train Epoch: 198 Batch: 0 Total samples processed: 32 Loss: 0.05252918228507042
# Train Epoch: 198 Batch: 1 Total samples processed: 64 Loss: 0.050947047770023346
# Train Epoch: 198 Batch: 2 Total samples processed: 96 Loss: 0.05060744285583496
# Train Epoch: 198 Batch: 3 Total samples processed: 128 Loss: 0.050273481756448746
# Train Epoch: 199 Batch: 0 Total samples processed: 32 Loss: 0.05092784762382507
# Train Epoch: 199 Batch: 1 Total samples processed: 64 Loss: 0.05060918629169464
# Train Epoch: 199 Batch: 2 Total samples processed: 96 Loss: 0.05131784826517105
# Train Epoch: 199 Batch: 3 Total samples processed: 128 Loss: 0.05881083756685257
# Train Epoch: 200 Batch: 0 Total samples processed: 32 Loss: 0.04888509213924408
# Train Epoch: 200 Batch: 1 Total samples processed: 64 Loss: 0.05448035150766373
# Train Epoch: 200 Batch: 2 Total samples processed: 96 Loss: 0.056882694363594055
# Train Epoch: 200 Batch: 3 Total samples processed: 128 Loss: 0.04962106794118881

# %% [markdown]
# ## Look at self-prediction
#
# Self-prediction does not tell us how the UNET will perform on new data, but it is a useful check to make sure the UNET is learning the training data.

# %%
len(X)
# Out:
# 4

# %%
import matplotlib.pyplot as plt

# convert to 0/1 range on each pixel
prediction = torch.nn.functional.sigmoid(prediction_logits)
prediction_binary = prediction #(prediction > 0.5).to(torch.uint8)

sidx = 1
plt.subplot(131)
plt.imshow(X[sidx, 0].cpu().numpy(), cmap="gray")
plt.title("Input")

plt.subplot(132)
plt.imshow(y[sidx, 0].cpu().numpy(), cmap="gray")
plt.title("Ground truth")

plt.subplot(133)
plt.imshow(prediction_binary.cpu().detach()[sidx, 0].numpy(), cmap="gray")
plt.title("Predictions")
# Out:
# Text(0.5, 1.0, 'Predictions')

# %% [markdown]
# ## Save the UNET

# %%
torch.save(model.state_dict(), train_path / 'model1')

# %% [markdown]
# ## Test on unseen data

# %%
test_name = 'SEM.tif'
testim = imread(parent_path  / test_name) 
testim.shape
plt.imshow(testim, cmap="gray")
print('original min max', testim.min(), testim.max())
# Out:
# original min max 0 65535

# %%
testim_.shape
# Out:
# (1024, 1536)

# %%
testim_ = quantile_normalization(
    testim,
    quantile_low=0.01,
    quantile_high=0.998,
    clip=True).astype(np.float32)

x = torch.from_numpy(testim_).unsqueeze(0).unsqueeze(0).to(device)
y = model(x)

plt.imshow(y.cpu().detach()[0, 0].numpy(), cmap="gray")

# %% [markdown]
# ## Look at results in Napari

# %%
import napari
viewer = napari.Viewer()
viewer.add_image(testim, name='testim')
viewer.add_image(y.cpu().detach()[0, 0].numpy(), name='prediction')
binary = y.cpu().detach()[0, 0].numpy() > 0.5
viewer.add_labels(binary, name='prediction binary')
# Out:
# <Labels layer 'prediction binary' at 0x27f943cd540>

# %%
from skimage.io import imsave
imsave(parent_path / 'CNN_segmentation.tif', y.cpu().detach()[0, 0].numpy())

# %%
from cProfile import label
from os import sep
from tnia.segmentation.separate import separate_touching

labels = y.cpu().detach()[0, 0].numpy() > 0.5
# invert labels
labels = 1 - labels

separated, label_separated, _ = separate_touching(labels, 15, 1)

from skimage.measure import label
label_separated = label(separated)

viewer = napari.Viewer()
viewer.add_image(testim, name='image')
viewer.add_labels(label_separated, name='separated')
# Out:
# <Labels layer 'separated' at 0x27faab17a30>

# %%
labels.shape
# Out:
# (1024, 1536)
