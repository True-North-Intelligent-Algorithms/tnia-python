# %% [markdown]
# ## Train a semantic segmentation unet using Pytorch

# %% [markdown]
# ## Pytorch setup
#
# setting up environment (Windows 10 with Cuda 11.8)
#
# ```
# conda create --name pytorch_tests python=3.10
# conda activate pytorch_tests
# conda install pip
# pip install pykernel
# pip3 install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118
# pip install pytorch-lightning
# pip install monai
# pip install scipy
# pip install tifffile
# pip install matplotlib
# ```

# %% [markdown]
# ## Imports

# %%
from tifffile import imread
from tqdm import tqdm
from data import quantile_normalization
import matplotlib.pyplot as plt
import numpy as np
import torch

from torchvision import transforms
from torchvision.transforms import v2
import random
import torchvision.transforms.functional as TF
from PIL import Image

# %% [markdown]
# ## Set up image and label directories

# %%
from pathlib import Path
import json

tnia_images_path = Path(r'D:/images')
parent_path=Path(tnia_images_path / r'tnia-python-images/imagesc/2024_01_12_plant_roots')
label_path = Path(parent_path / r'labels')
train_path= parent_path / 'patches' / 'augment'

with open(train_path / 'info.json', 'r') as json_file:
    data = json.load(json_file)
    # Access the sub_sample parameter
    sub_sample = data['sub_sample']
    print('sub_sample',sub_sample)
    axes = data['axes']
    print('axes',axes)

image_patch_path = train_path / 'ground truth0'
label_patch_path = train_path / 'input0'
# Out:
# sub_sample 1
# axes YX

# %% [markdown]
# ## Create a Dataset for the plant root data
#
# Dataset is simply used to retrieve the training patches.  In this case we just set it up to read in image files, then convert the numpy arrays to tensors and a torch stack.
#
# In this example augmentation was done in a previous notebook, and the augmented images explicitly saved.  It is also possible to do augmentation as the data is retrieved.  So in the future the ```PlantRootData``` could be extended to apply augmentation as data is retrieved.

# %%
class PlantRootData():

    def __init__(self, image_files, label_files, target_shape=(256, 256)):
            """
            Parameters
            ----------
            image_files: list of pathlib.Path objects pointing to the *.tif images
            label_files: list of pathlib.Path objects pointing to the *.tif segmentation masks
            target_shape: tuple of length 2 specifying the sample resolutions of files that
                        will be kept. All other files will NOT be used.
            """
            assert len(image_files) == len(label_files)
            assert all(x.name==y.name for x,y in zip(image_files, label_files))

            self.images = []
            self.labels = []

            tensor_transform = transforms.Compose([
                v2.ToTensor(),
            ])

            # use tqdm to have eye pleasing error bars
            for idx in tqdm(range(len(image_files))):
                # we use the same data reading approach as in the previous notebook
                image = imread(image_files[idx])
                label = imread(label_files[idx])

                if image.shape != target_shape:
                    continue
                
                # do the normalizations
                #image = quantile_normalization(
                #    image,
                #    quantile_low=0.01,
                #    quantile_high=0.998,
                #    clip=True)[0].astype(np.float32)

                # NOTE: we convert the label to dtype float32 and not uint8 because
                # the tensor transformation does a normalization if the input is of
                # dtype uint8, destroying the 0/1 labelling which we want to avoid.
                #label = fill_label_holes(label)
                label_binary = np.zeros_like(label).astype(np.float32)
                label_binary[label != 0] = 1.
                

                # convert to torch tensor: adds an artificial color channel in the front
                # and scales inputs to have same size as samples tend to differ in image
                # resolutions
                image = tensor_transform(image)
                label = tensor_transform(label_binary)

                self.images.append(image)
                self.labels.append(label)

            self.images = torch.stack(self.images)
            self.labels = torch.stack(self.labels)
    
    def __getitem__(self, idx):
        return self.images[idx], self.labels[idx]

    def __len__(self):
        return len(self.images)

# %% [markdown]
# ## Initialize the PlantRootData
#
# Initialize the DataSet with the pre-generated patch names

# %%
src_dir = train_path

assert src_dir.exists(), f"root directory with images and masks {src_dir} does not exist"

X = sorted(src_dir.rglob('**/input0/*.tif'))
Y = sorted(src_dir.rglob('**/ground truth0/*.tif'))

train_data = PlantRootData(
    image_files=X,
    label_files=Y,
    target_shape=(448, 448)
)

# NOTE: the length of the dataset might not be the same as n_samples
#       because files not having the target shape will be discarded
print(len(train_data))

# %% [markdown]
# ## Create a DataLoader
#
# This is done so we can load batches of images.

# %%
from torch.utils.data import DataLoader

train_loader = DataLoader(train_data, batch_size=32, shuffle=True)

# %% [markdown]
# ## Check if GPU is present

# %%
cuda_present = torch.cuda.is_available()
ndevices = torch.cuda.device_count()
use_cuda = cuda_present and ndevices > 0
device = torch.device("cuda" if use_cuda else "cpu")  # "cuda:0" ... default device, "cuda:1" would be GPU index 1, "cuda:2" etc
print("number of devices:", ndevices, "\tchosen device:", device, "\tuse_cuda=", use_cuda)
# Out:
# number of devices: 1 	chosen device: cuda 	use_cuda= True

# %% [markdown]
# ## Create a UNET

# %%
from monai.networks.nets import BasicUNet

model = BasicUNet(
    spatial_dims=2,
    in_channels=1,
    out_channels=1,
    #features=[16, 16, 32, 64, 128, 16],
    act="relu",
    norm="batch",
    dropout=0.25,
)

# Important: transfer the model to the chosen device
model = model.to(device)

optimizer = torch.optim.Adam(model.parameters(), lr=1.e-3)
init_params = list(model.parameters())[0].clone().detach()
# Out:
# BasicUNet features: (32, 32, 64, 128, 256, 32).

# %% [markdown]
# ## Train the UNET

# %%
max_nepochs = 250
log_interval = 1
model.train(True)

# BCEWithLogitsLoss combines sigmoid + BCELoss for better
# numerical stability. It expects raw unnormalized scores as input which are shaped like 
# B x C x W x D
loss_function = torch.nn.BCEWithLogitsLoss(reduction="mean")

for epoch in range(1, max_nepochs + 1):
    for batch_idx, (X, y) in enumerate(train_loader):
        # the inputs and labels have to be on the same device as the model
        X, y = X.to(device), y.to(device)
        
        optimizer.zero_grad()

        prediction_logits = model(X)
        
        batch_loss = loss_function(prediction_logits, y)

        batch_loss.backward()

        optimizer.step()

        if batch_idx % log_interval == 0:
            print(
                "Train Epoch:",
                epoch,
                "Batch:",
                batch_idx,
                "Total samples processed:",
                (batch_idx + 1) * train_loader.batch_size,
                "Loss:",
                batch_loss.item(),
            )
# Out:
# Train Epoch: 1 Batch: 0 Total samples processed: 32 Loss: 0.03569379448890686
# Train Epoch: 1 Batch: 1 Total samples processed: 64 Loss: 0.030034152790904045
# Train Epoch: 1 Batch: 2 Total samples processed: 96 Loss: 0.035338323563337326
# Train Epoch: 1 Batch: 3 Total samples processed: 128 Loss: 0.03783375397324562
# Train Epoch: 1 Batch: 4 Total samples processed: 160 Loss: 0.03719614818692207
# Train Epoch: 1 Batch: 5 Total samples processed: 192 Loss: 0.037289731204509735
# Train Epoch: 1 Batch: 6 Total samples processed: 224 Loss: 0.030672520399093628
# Train Epoch: 2 Batch: 0 Total samples processed: 32 Loss: 0.03724144026637077
# Train Epoch: 2 Batch: 1 Total samples processed: 64 Loss: 0.032107435166835785
# Train Epoch: 2 Batch: 2 Total samples processed: 96 Loss: 0.03025621734559536
# Train Epoch: 2 Batch: 3 Total samples processed: 128 Loss: 0.03411044925451279
# Train Epoch: 2 Batch: 4 Total samples processed: 160 Loss: 0.03727050870656967
# Train Epoch: 2 Batch: 5 Total samples processed: 192 Loss: 0.041371364146471024
# Train Epoch: 2 Batch: 6 Total samples processed: 224 Loss: 0.03625408187508583
# Train Epoch: 3 Batch: 0 Total samples processed: 32 Loss: 0.036414679139852524
# Train Epoch: 3 Batch: 1 Total samples processed: 64 Loss: 0.0357181616127491
# Train Epoch: 3 Batch: 2 Total samples processed: 96 Loss: 0.036526020616292953
# Train Epoch: 3 Batch: 3 Total samples processed: 128 Loss: 0.04014463350176811
# Train Epoch: 3 Batch: 4 Total samples processed: 160 Loss: 0.03612183779478073
# Train Epoch: 3 Batch: 5 Total samples processed: 192 Loss: 0.033930886536836624
# Train Epoch: 3 Batch: 6 Total samples processed: 224 Loss: 0.035708583891391754
# Train Epoch: 4 Batch: 0 Total samples processed: 32 Loss: 0.03661634773015976
# Train Epoch: 4 Batch: 1 Total samples processed: 64 Loss: 0.03578687086701393
# Train Epoch: 4 Batch: 2 Total samples processed: 96 Loss: 0.035294901579618454
# Train Epoch: 4 Batch: 3 Total samples processed: 128 Loss: 0.03849802538752556
# Train Epoch: 4 Batch: 4 Total samples processed: 160 Loss: 0.033397775143384933
# Train Epoch: 4 Batch: 5 Total samples processed: 192 Loss: 0.037681158632040024
# Train Epoch: 4 Batch: 6 Total samples processed: 224 Loss: 0.03703344985842705
# Train Epoch: 5 Batch: 0 Total samples processed: 32 Loss: 0.036343809217214584
# Train Epoch: 5 Batch: 1 Total samples processed: 64 Loss: 0.03225015476346016
# Train Epoch: 5 Batch: 2 Total samples processed: 96 Loss: 0.03579482436180115
# Train Epoch: 5 Batch: 3 Total samples processed: 128 Loss: 0.03733538091182709
# Train Epoch: 5 Batch: 4 Total samples processed: 160 Loss: 0.035118378698825836
# Train Epoch: 5 Batch: 5 Total samples processed: 192 Loss: 0.039190005511045456
# Train Epoch: 5 Batch: 6 Total samples processed: 224 Loss: 0.03494739532470703
# Train Epoch: 6 Batch: 0 Total samples processed: 32 Loss: 0.03768130764365196
# Train Epoch: 6 Batch: 1 Total samples processed: 64 Loss: 0.03355717658996582
# Train Epoch: 6 Batch: 2 Total samples processed: 96 Loss: 0.033529315143823624
# Train Epoch: 6 Batch: 3 Total samples processed: 128 Loss: 0.039973944425582886
# Train Epoch: 6 Batch: 4 Total samples processed: 160 Loss: 0.037496186792850494
# Train Epoch: 6 Batch: 5 Total samples processed: 192 Loss: 0.0316169448196888
# Train Epoch: 6 Batch: 6 Total samples processed: 224 Loss: 0.035214073956012726
# Train Epoch: 7 Batch: 0 Total samples processed: 32 Loss: 0.04178133234381676
# Train Epoch: 7 Batch: 1 Total samples processed: 64 Loss: 0.030323896557092667
# Train Epoch: 7 Batch: 2 Total samples processed: 96 Loss: 0.033865682780742645
# Train Epoch: 7 Batch: 3 Total samples processed: 128 Loss: 0.033364955335855484
# Train Epoch: 7 Batch: 4 Total samples processed: 160 Loss: 0.0370095856487751
# Train Epoch: 7 Batch: 5 Total samples processed: 192 Loss: 0.03577952831983566
# Train Epoch: 7 Batch: 6 Total samples processed: 224 Loss: 0.03429180011153221
# Train Epoch: 8 Batch: 0 Total samples processed: 32 Loss: 0.0352582111954689
# Train Epoch: 8 Batch: 1 Total samples processed: 64 Loss: 0.03697633370757103
# Train Epoch: 8 Batch: 2 Total samples processed: 96 Loss: 0.03631895035505295
# Train Epoch: 8 Batch: 3 Total samples processed: 128 Loss: 0.03223413601517677
# Train Epoch: 8 Batch: 4 Total samples processed: 160 Loss: 0.03404967486858368
# Train Epoch: 8 Batch: 5 Total samples processed: 192 Loss: 0.03533687815070152
# Train Epoch: 8 Batch: 6 Total samples processed: 224 Loss: 0.03536821901798248
# Train Epoch: 9 Batch: 0 Total samples processed: 32 Loss: 0.033690888434648514
# Train Epoch: 9 Batch: 1 Total samples processed: 64 Loss: 0.0364786796271801
# Train Epoch: 9 Batch: 2 Total samples processed: 96 Loss: 0.03503292798995972
# Train Epoch: 9 Batch: 3 Total samples processed: 128 Loss: 0.037216123193502426
# Train Epoch: 9 Batch: 4 Total samples processed: 160 Loss: 0.03202192485332489
# Train Epoch: 9 Batch: 5 Total samples processed: 192 Loss: 0.03043772280216217
# Train Epoch: 9 Batch: 6 Total samples processed: 224 Loss: 0.04273250699043274
# Train Epoch: 10 Batch: 0 Total samples processed: 32 Loss: 0.03455378860235214
# Train Epoch: 10 Batch: 1 Total samples processed: 64 Loss: 0.0339859202504158
# Train Epoch: 10 Batch: 2 Total samples processed: 96 Loss: 0.033200476318597794
# Train Epoch: 10 Batch: 3 Total samples processed: 128 Loss: 0.035898491740226746
# Train Epoch: 10 Batch: 4 Total samples processed: 160 Loss: 0.03402933478355408
# Train Epoch: 10 Batch: 5 Total samples processed: 192 Loss: 0.035647373646497726
# Train Epoch: 10 Batch: 6 Total samples processed: 224 Loss: 0.03305709362030029
# Train Epoch: 11 Batch: 0 Total samples processed: 32 Loss: 0.036919135600328445
# Train Epoch: 11 Batch: 1 Total samples processed: 64 Loss: 0.03287091478705406
# Train Epoch: 11 Batch: 2 Total samples processed: 96 Loss: 0.039455339312553406
# Train Epoch: 11 Batch: 3 Total samples processed: 128 Loss: 0.03347939997911453
# Train Epoch: 11 Batch: 4 Total samples processed: 160 Loss: 0.033326420933008194
# Train Epoch: 11 Batch: 5 Total samples processed: 192 Loss: 0.034586142748594284
# Train Epoch: 11 Batch: 6 Total samples processed: 224 Loss: 0.03013095073401928
# Train Epoch: 12 Batch: 0 Total samples processed: 32 Loss: 0.029972203075885773
# Train Epoch: 12 Batch: 1 Total samples processed: 64 Loss: 0.03816768154501915
# Train Epoch: 12 Batch: 2 Total samples processed: 96 Loss: 0.03295636922121048
# Train Epoch: 12 Batch: 3 Total samples processed: 128 Loss: 0.03434827923774719
# Train Epoch: 12 Batch: 4 Total samples processed: 160 Loss: 0.03577828034758568
# Train Epoch: 12 Batch: 5 Total samples processed: 192 Loss: 0.03345894068479538
# Train Epoch: 12 Batch: 6 Total samples processed: 224 Loss: 0.042458441108465195
# Train Epoch: 13 Batch: 0 Total samples processed: 32 Loss: 0.03233099728822708
# Train Epoch: 13 Batch: 1 Total samples processed: 64 Loss: 0.03050169348716736
# Train Epoch: 13 Batch: 2 Total samples processed: 96 Loss: 0.035193439573049545
# Train Epoch: 13 Batch: 3 Total samples processed: 128 Loss: 0.03039000742137432
# Train Epoch: 13 Batch: 4 Total samples processed: 160 Loss: 0.035991404205560684
# Train Epoch: 13 Batch: 5 Total samples processed: 192 Loss: 0.039726439863443375
# Train Epoch: 13 Batch: 6 Total samples processed: 224 Loss: 0.04269962012767792
# Train Epoch: 14 Batch: 0 Total samples processed: 32 Loss: 0.035259220749139786
# Train Epoch: 14 Batch: 1 Total samples processed: 64 Loss: 0.039136841893196106
# Train Epoch: 14 Batch: 2 Total samples processed: 96 Loss: 0.03829154372215271
# Train Epoch: 14 Batch: 3 Total samples processed: 128 Loss: 0.040170818567276
# Train Epoch: 14 Batch: 4 Total samples processed: 160 Loss: 0.04260694608092308
# Train Epoch: 14 Batch: 5 Total samples processed: 192 Loss: 0.03264408931136131
# Train Epoch: 14 Batch: 6 Total samples processed: 224 Loss: 0.029042331501841545
# Train Epoch: 15 Batch: 0 Total samples processed: 32 Loss: 0.038866233080625534
# Train Epoch: 15 Batch: 1 Total samples processed: 64 Loss: 0.03963570296764374
# Train Epoch: 15 Batch: 2 Total samples processed: 96 Loss: 0.03599272295832634
# Train Epoch: 15 Batch: 3 Total samples processed: 128 Loss: 0.0366082563996315
# Train Epoch: 15 Batch: 4 Total samples processed: 160 Loss: 0.035112448036670685
# Train Epoch: 15 Batch: 5 Total samples processed: 192 Loss: 0.037244632840156555
# Train Epoch: 15 Batch: 6 Total samples processed: 224 Loss: 0.033078789710998535
# Train Epoch: 16 Batch: 0 Total samples processed: 32 Loss: 0.03882306441664696
# Train Epoch: 16 Batch: 1 Total samples processed: 64 Loss: 0.03485727682709694
# Train Epoch: 16 Batch: 2 Total samples processed: 96 Loss: 0.03216153755784035
# Train Epoch: 16 Batch: 3 Total samples processed: 128 Loss: 0.03540487587451935
# Train Epoch: 16 Batch: 4 Total samples processed: 160 Loss: 0.03525860235095024
# Train Epoch: 16 Batch: 5 Total samples processed: 192 Loss: 0.033568572252988815
# Train Epoch: 16 Batch: 6 Total samples processed: 224 Loss: 0.03186909854412079
# Train Epoch: 17 Batch: 0 Total samples processed: 32 Loss: 0.03519013896584511
# Train Epoch: 17 Batch: 1 Total samples processed: 64 Loss: 0.03318631276488304
# Train Epoch: 17 Batch: 2 Total samples processed: 96 Loss: 0.030075693503022194
# Train Epoch: 17 Batch: 3 Total samples processed: 128 Loss: 0.03158795088529587
# Train Epoch: 17 Batch: 4 Total samples processed: 160 Loss: 0.038667526096105576
# Train Epoch: 17 Batch: 5 Total samples processed: 192 Loss: 0.03679518401622772
# Train Epoch: 17 Batch: 6 Total samples processed: 224 Loss: 0.03132167086005211
# Train Epoch: 18 Batch: 0 Total samples processed: 32 Loss: 0.03436477109789848
# Train Epoch: 18 Batch: 1 Total samples processed: 64 Loss: 0.03278309479355812
# Train Epoch: 18 Batch: 2 Total samples processed: 96 Loss: 0.034381017088890076
# Train Epoch: 18 Batch: 3 Total samples processed: 128 Loss: 0.03714407607913017
# Train Epoch: 18 Batch: 4 Total samples processed: 160 Loss: 0.03202207013964653
# Train Epoch: 18 Batch: 5 Total samples processed: 192 Loss: 0.03181951493024826
# Train Epoch: 18 Batch: 6 Total samples processed: 224 Loss: 0.03664621338248253
# Train Epoch: 19 Batch: 0 Total samples processed: 32 Loss: 0.03321070596575737
# Train Epoch: 19 Batch: 1 Total samples processed: 64 Loss: 0.029687613248825073
# Train Epoch: 19 Batch: 2 Total samples processed: 96 Loss: 0.034672871232032776
# Train Epoch: 19 Batch: 3 Total samples processed: 128 Loss: 0.034396637231111526
# Train Epoch: 19 Batch: 4 Total samples processed: 160 Loss: 0.031732503324747086
# Train Epoch: 19 Batch: 5 Total samples processed: 192 Loss: 0.03611300513148308
# Train Epoch: 19 Batch: 6 Total samples processed: 224 Loss: 0.035116955637931824
# Train Epoch: 20 Batch: 0 Total samples processed: 32 Loss: 0.03143157809972763
# Train Epoch: 20 Batch: 1 Total samples processed: 64 Loss: 0.035925835371017456
# Train Epoch: 20 Batch: 2 Total samples processed: 96 Loss: 0.0337502546608448
# Train Epoch: 20 Batch: 3 Total samples processed: 128 Loss: 0.03359523415565491
# Train Epoch: 20 Batch: 4 Total samples processed: 160 Loss: 0.03566136956214905
# Train Epoch: 20 Batch: 5 Total samples processed: 192 Loss: 0.03425288572907448
# Train Epoch: 20 Batch: 6 Total samples processed: 224 Loss: 0.02648608759045601
# Train Epoch: 21 Batch: 0 Total samples processed: 32 Loss: 0.03940851613879204
# Train Epoch: 21 Batch: 1 Total samples processed: 64 Loss: 0.032644402235746384
# Train Epoch: 21 Batch: 2 Total samples processed: 96 Loss: 0.032818619161844254
# Train Epoch: 21 Batch: 3 Total samples processed: 128 Loss: 0.03210859373211861
# Train Epoch: 21 Batch: 4 Total samples processed: 160 Loss: 0.033635612577199936
# Train Epoch: 21 Batch: 5 Total samples processed: 192 Loss: 0.028533287346363068
# Train Epoch: 21 Batch: 6 Total samples processed: 224 Loss: 0.03690031170845032
# Train Epoch: 22 Batch: 0 Total samples processed: 32 Loss: 0.03449556231498718
# Train Epoch: 22 Batch: 1 Total samples processed: 64 Loss: 0.034617770463228226
# Train Epoch: 22 Batch: 2 Total samples processed: 96 Loss: 0.03562360256910324
# Train Epoch: 22 Batch: 3 Total samples processed: 128 Loss: 0.03460691124200821
# Train Epoch: 22 Batch: 4 Total samples processed: 160 Loss: 0.026005325838923454
# Train Epoch: 22 Batch: 5 Total samples processed: 192 Loss: 0.0342244915664196
# Train Epoch: 22 Batch: 6 Total samples processed: 224 Loss: 0.02908451110124588
# Train Epoch: 23 Batch: 0 Total samples processed: 32 Loss: 0.03310778737068176
# Train Epoch: 23 Batch: 1 Total samples processed: 64 Loss: 0.0322161428630352
# Train Epoch: 23 Batch: 2 Total samples processed: 96 Loss: 0.03148510307073593
# Train Epoch: 23 Batch: 3 Total samples processed: 128 Loss: 0.03332022577524185
# Train Epoch: 23 Batch: 4 Total samples processed: 160 Loss: 0.035265713930130005
# Train Epoch: 23 Batch: 5 Total samples processed: 192 Loss: 0.029266059398651123
# Train Epoch: 23 Batch: 6 Total samples processed: 224 Loss: 0.03746552765369415
# Train Epoch: 24 Batch: 0 Total samples processed: 32 Loss: 0.034124232828617096
# Train Epoch: 24 Batch: 1 Total samples processed: 64 Loss: 0.03182169422507286
# Train Epoch: 24 Batch: 2 Total samples processed: 96 Loss: 0.03240092471241951
# Train Epoch: 24 Batch: 3 Total samples processed: 128 Loss: 0.031949687749147415
# Train Epoch: 24 Batch: 4 Total samples processed: 160 Loss: 0.035366155207157135
# Train Epoch: 24 Batch: 5 Total samples processed: 192 Loss: 0.03161570057272911
# Train Epoch: 24 Batch: 6 Total samples processed: 224 Loss: 0.034147873520851135
# Train Epoch: 25 Batch: 0 Total samples processed: 32 Loss: 0.03295509144663811
# Train Epoch: 25 Batch: 1 Total samples processed: 64 Loss: 0.029522307217121124
# Train Epoch: 25 Batch: 2 Total samples processed: 96 Loss: 0.03452200070023537
# Train Epoch: 25 Batch: 3 Total samples processed: 128 Loss: 0.03189178183674812
# Train Epoch: 25 Batch: 4 Total samples processed: 160 Loss: 0.03335722163319588
# Train Epoch: 25 Batch: 5 Total samples processed: 192 Loss: 0.03036896511912346
# Train Epoch: 25 Batch: 6 Total samples processed: 224 Loss: 0.03573576733469963
# Train Epoch: 26 Batch: 0 Total samples processed: 32 Loss: 0.03111371211707592
# Train Epoch: 26 Batch: 1 Total samples processed: 64 Loss: 0.029266852885484695
# Train Epoch: 26 Batch: 2 Total samples processed: 96 Loss: 0.03757786750793457
# Train Epoch: 26 Batch: 3 Total samples processed: 128 Loss: 0.030086541548371315
# Train Epoch: 26 Batch: 4 Total samples processed: 160 Loss: 0.0318901352584362
# Train Epoch: 26 Batch: 5 Total samples processed: 192 Loss: 0.029619069769978523
# Train Epoch: 26 Batch: 6 Total samples processed: 224 Loss: 0.048205286264419556
# Train Epoch: 27 Batch: 0 Total samples processed: 32 Loss: 0.032883331179618835
# Train Epoch: 27 Batch: 1 Total samples processed: 64 Loss: 0.03940633684396744
# Train Epoch: 27 Batch: 2 Total samples processed: 96 Loss: 0.03598589822649956
# Train Epoch: 27 Batch: 3 Total samples processed: 128 Loss: 0.029800672084093094
# Train Epoch: 27 Batch: 4 Total samples processed: 160 Loss: 0.03217799589037895
# Train Epoch: 27 Batch: 5 Total samples processed: 192 Loss: 0.04071903973817825
# Train Epoch: 27 Batch: 6 Total samples processed: 224 Loss: 0.03443766385316849
# Train Epoch: 28 Batch: 0 Total samples processed: 32 Loss: 0.03314739093184471
# Train Epoch: 28 Batch: 1 Total samples processed: 64 Loss: 0.040711719542741776
# Train Epoch: 28 Batch: 2 Total samples processed: 96 Loss: 0.030973386019468307
# Train Epoch: 28 Batch: 3 Total samples processed: 128 Loss: 0.031195133924484253
# Train Epoch: 28 Batch: 4 Total samples processed: 160 Loss: 0.03339922055602074
# Train Epoch: 28 Batch: 5 Total samples processed: 192 Loss: 0.03308122977614403
# Train Epoch: 28 Batch: 6 Total samples processed: 224 Loss: 0.033726029098033905
# Train Epoch: 29 Batch: 0 Total samples processed: 32 Loss: 0.03424738720059395
# Train Epoch: 29 Batch: 1 Total samples processed: 64 Loss: 0.032360952347517014
# Train Epoch: 29 Batch: 2 Total samples processed: 96 Loss: 0.03490344434976578
# Train Epoch: 29 Batch: 3 Total samples processed: 128 Loss: 0.03129778057336807
# Train Epoch: 29 Batch: 4 Total samples processed: 160 Loss: 0.03532303124666214
# Train Epoch: 29 Batch: 5 Total samples processed: 192 Loss: 0.03455523028969765
# Train Epoch: 29 Batch: 6 Total samples processed: 224 Loss: 0.030740883201360703
# Train Epoch: 30 Batch: 0 Total samples processed: 32 Loss: 0.032684482634067535
# Train Epoch: 30 Batch: 1 Total samples processed: 64 Loss: 0.03265127167105675
# Train Epoch: 30 Batch: 2 Total samples processed: 96 Loss: 0.03507973253726959
# Train Epoch: 30 Batch: 3 Total samples processed: 128 Loss: 0.03166147693991661
# Train Epoch: 30 Batch: 4 Total samples processed: 160 Loss: 0.03182905539870262
# Train Epoch: 30 Batch: 5 Total samples processed: 192 Loss: 0.031218715012073517
# Train Epoch: 30 Batch: 6 Total samples processed: 224 Loss: 0.03307062014937401
# Train Epoch: 31 Batch: 0 Total samples processed: 32 Loss: 0.033437490463256836
# Train Epoch: 31 Batch: 1 Total samples processed: 64 Loss: 0.03255867958068848
# Train Epoch: 31 Batch: 2 Total samples processed: 96 Loss: 0.032984860241413116
# Train Epoch: 31 Batch: 3 Total samples processed: 128 Loss: 0.030542956665158272
# Train Epoch: 31 Batch: 4 Total samples processed: 160 Loss: 0.02966068871319294
# Train Epoch: 31 Batch: 5 Total samples processed: 192 Loss: 0.03402306139469147
# Train Epoch: 31 Batch: 6 Total samples processed: 224 Loss: 0.03278927505016327
# Train Epoch: 32 Batch: 0 Total samples processed: 32 Loss: 0.03197193518280983
# Train Epoch: 32 Batch: 1 Total samples processed: 64 Loss: 0.031770218163728714
# Train Epoch: 32 Batch: 2 Total samples processed: 96 Loss: 0.033487867563962936
# Train Epoch: 32 Batch: 3 Total samples processed: 128 Loss: 0.03404606506228447
# Train Epoch: 32 Batch: 4 Total samples processed: 160 Loss: 0.028754612430930138
# Train Epoch: 32 Batch: 5 Total samples processed: 192 Loss: 0.03127426281571388
# Train Epoch: 32 Batch: 6 Total samples processed: 224 Loss: 0.04012459143996239
# Train Epoch: 33 Batch: 0 Total samples processed: 32 Loss: 0.03406520560383797
# Train Epoch: 33 Batch: 1 Total samples processed: 64 Loss: 0.03084505721926689
# Train Epoch: 33 Batch: 2 Total samples processed: 96 Loss: 0.0386015847325325
# Train Epoch: 33 Batch: 3 Total samples processed: 128 Loss: 0.031455039978027344
# Train Epoch: 33 Batch: 4 Total samples processed: 160 Loss: 0.03206767141819
# Train Epoch: 33 Batch: 5 Total samples processed: 192 Loss: 0.02975497953593731
# Train Epoch: 33 Batch: 6 Total samples processed: 224 Loss: 0.03780801221728325
# Train Epoch: 34 Batch: 0 Total samples processed: 32 Loss: 0.027905365452170372
# Train Epoch: 34 Batch: 1 Total samples processed: 64 Loss: 0.032074153423309326
# Train Epoch: 34 Batch: 2 Total samples processed: 96 Loss: 0.036699045449495316
# Train Epoch: 34 Batch: 3 Total samples processed: 128 Loss: 0.030815832316875458
# Train Epoch: 34 Batch: 4 Total samples processed: 160 Loss: 0.03397158533334732
# Train Epoch: 34 Batch: 5 Total samples processed: 192 Loss: 0.03362652659416199
# Train Epoch: 34 Batch: 6 Total samples processed: 224 Loss: 0.034180887043476105
# Train Epoch: 35 Batch: 0 Total samples processed: 32 Loss: 0.031087271869182587
# Train Epoch: 35 Batch: 1 Total samples processed: 64 Loss: 0.03222041204571724
# Train Epoch: 35 Batch: 2 Total samples processed: 96 Loss: 0.030425898730754852
# Train Epoch: 35 Batch: 3 Total samples processed: 128 Loss: 0.033042438328266144
# Train Epoch: 35 Batch: 4 Total samples processed: 160 Loss: 0.0330144539475441
# Train Epoch: 35 Batch: 5 Total samples processed: 192 Loss: 0.030619297176599503
# Train Epoch: 35 Batch: 6 Total samples processed: 224 Loss: 0.03132123872637749
# Train Epoch: 36 Batch: 0 Total samples processed: 32 Loss: 0.031692009419202805
# Train Epoch: 36 Batch: 1 Total samples processed: 64 Loss: 0.031245660036802292
# Train Epoch: 36 Batch: 2 Total samples processed: 96 Loss: 0.03227026388049126
# Train Epoch: 36 Batch: 3 Total samples processed: 128 Loss: 0.035083089023828506
# Train Epoch: 36 Batch: 4 Total samples processed: 160 Loss: 0.03067743219435215
# Train Epoch: 36 Batch: 5 Total samples processed: 192 Loss: 0.028175966814160347
# Train Epoch: 36 Batch: 6 Total samples processed: 224 Loss: 0.0282968208193779
# Train Epoch: 37 Batch: 0 Total samples processed: 32 Loss: 0.03421014919877052
# Train Epoch: 37 Batch: 1 Total samples processed: 64 Loss: 0.02964881993830204
# Train Epoch: 37 Batch: 2 Total samples processed: 96 Loss: 0.030822724103927612
# Train Epoch: 37 Batch: 3 Total samples processed: 128 Loss: 0.028935659676790237
# Train Epoch: 37 Batch: 4 Total samples processed: 160 Loss: 0.031898222863674164
# Train Epoch: 37 Batch: 5 Total samples processed: 192 Loss: 0.02957753650844097
# Train Epoch: 37 Batch: 6 Total samples processed: 224 Loss: 0.029196875169873238
# Train Epoch: 38 Batch: 0 Total samples processed: 32 Loss: 0.030325613915920258
# Train Epoch: 38 Batch: 1 Total samples processed: 64 Loss: 0.029895007610321045
# Train Epoch: 38 Batch: 2 Total samples processed: 96 Loss: 0.030878523364663124
# Train Epoch: 38 Batch: 3 Total samples processed: 128 Loss: 0.031076423823833466
# Train Epoch: 38 Batch: 4 Total samples processed: 160 Loss: 0.029583092778921127
# Train Epoch: 38 Batch: 5 Total samples processed: 192 Loss: 0.030994584783911705
# Train Epoch: 38 Batch: 6 Total samples processed: 224 Loss: 0.030953383073210716
# Train Epoch: 39 Batch: 0 Total samples processed: 32 Loss: 0.03532518818974495
# Train Epoch: 39 Batch: 1 Total samples processed: 64 Loss: 0.03281885012984276
# Train Epoch: 39 Batch: 2 Total samples processed: 96 Loss: 0.029702456668019295
# Train Epoch: 39 Batch: 3 Total samples processed: 128 Loss: 0.030889224261045456
# Train Epoch: 39 Batch: 4 Total samples processed: 160 Loss: 0.027709495276212692
# Train Epoch: 39 Batch: 5 Total samples processed: 192 Loss: 0.028193049132823944
# Train Epoch: 39 Batch: 6 Total samples processed: 224 Loss: 0.024513008072972298
# Train Epoch: 40 Batch: 0 Total samples processed: 32 Loss: 0.03063993528485298
# Train Epoch: 40 Batch: 1 Total samples processed: 64 Loss: 0.02850600890815258
# Train Epoch: 40 Batch: 2 Total samples processed: 96 Loss: 0.02751120738685131
# Train Epoch: 40 Batch: 3 Total samples processed: 128 Loss: 0.02837231568992138
# Train Epoch: 40 Batch: 4 Total samples processed: 160 Loss: 0.03229399397969246
# Train Epoch: 40 Batch: 5 Total samples processed: 192 Loss: 0.03478292375802994
# Train Epoch: 40 Batch: 6 Total samples processed: 224 Loss: 0.03631016984581947
# Train Epoch: 41 Batch: 0 Total samples processed: 32 Loss: 0.0319536067545414
# Train Epoch: 41 Batch: 1 Total samples processed: 64 Loss: 0.03281421959400177
# Train Epoch: 41 Batch: 2 Total samples processed: 96 Loss: 0.028083112090826035
# Train Epoch: 41 Batch: 3 Total samples processed: 128 Loss: 0.028054503723978996
# Train Epoch: 41 Batch: 4 Total samples processed: 160 Loss: 0.03179578483104706
# Train Epoch: 41 Batch: 5 Total samples processed: 192 Loss: 0.030073869973421097
# Train Epoch: 41 Batch: 6 Total samples processed: 224 Loss: 0.031257499009370804
# Train Epoch: 42 Batch: 0 Total samples processed: 32 Loss: 0.03250603377819061
# Train Epoch: 42 Batch: 1 Total samples processed: 64 Loss: 0.032509543001651764
# Train Epoch: 42 Batch: 2 Total samples processed: 96 Loss: 0.028790604323148727
# Train Epoch: 42 Batch: 3 Total samples processed: 128 Loss: 0.030433204025030136
# Train Epoch: 42 Batch: 4 Total samples processed: 160 Loss: 0.029913555830717087
# Train Epoch: 42 Batch: 5 Total samples processed: 192 Loss: 0.029294436797499657
# Train Epoch: 42 Batch: 6 Total samples processed: 224 Loss: 0.03628106042742729
# Train Epoch: 43 Batch: 0 Total samples processed: 32 Loss: 0.03196873515844345
# Train Epoch: 43 Batch: 1 Total samples processed: 64 Loss: 0.02838502638041973
# Train Epoch: 43 Batch: 2 Total samples processed: 96 Loss: 0.03117641620337963
# Train Epoch: 43 Batch: 3 Total samples processed: 128 Loss: 0.028560765087604523
# Train Epoch: 43 Batch: 4 Total samples processed: 160 Loss: 0.028723612427711487
# Train Epoch: 43 Batch: 5 Total samples processed: 192 Loss: 0.0369507372379303
# Train Epoch: 43 Batch: 6 Total samples processed: 224 Loss: 0.030977897346019745
# Train Epoch: 44 Batch: 0 Total samples processed: 32 Loss: 0.032840847969055176
# Train Epoch: 44 Batch: 1 Total samples processed: 64 Loss: 0.02922423742711544
# Train Epoch: 44 Batch: 2 Total samples processed: 96 Loss: 0.03171877935528755
# Train Epoch: 44 Batch: 3 Total samples processed: 128 Loss: 0.03223808854818344
# Train Epoch: 44 Batch: 4 Total samples processed: 160 Loss: 0.031823381781578064
# Train Epoch: 44 Batch: 5 Total samples processed: 192 Loss: 0.02741866186261177
# Train Epoch: 44 Batch: 6 Total samples processed: 224 Loss: 0.03327172249555588
# Train Epoch: 45 Batch: 0 Total samples processed: 32 Loss: 0.029225630685687065
# Train Epoch: 45 Batch: 1 Total samples processed: 64 Loss: 0.032726384699344635
# Train Epoch: 45 Batch: 2 Total samples processed: 96 Loss: 0.029854968190193176
# Train Epoch: 45 Batch: 3 Total samples processed: 128 Loss: 0.026973463594913483
# Train Epoch: 45 Batch: 4 Total samples processed: 160 Loss: 0.03404911234974861
# Train Epoch: 45 Batch: 5 Total samples processed: 192 Loss: 0.03055606596171856
# Train Epoch: 45 Batch: 6 Total samples processed: 224 Loss: 0.02752741239964962
# Train Epoch: 46 Batch: 0 Total samples processed: 32 Loss: 0.03135661780834198
# Train Epoch: 46 Batch: 1 Total samples processed: 64 Loss: 0.031904011964797974
# Train Epoch: 46 Batch: 2 Total samples processed: 96 Loss: 0.031892821192741394
# Train Epoch: 46 Batch: 3 Total samples processed: 128 Loss: 0.029073653742671013
# Train Epoch: 46 Batch: 4 Total samples processed: 160 Loss: 0.026254815980792046
# Train Epoch: 46 Batch: 5 Total samples processed: 192 Loss: 0.031785063445568085
# Train Epoch: 46 Batch: 6 Total samples processed: 224 Loss: 0.030778028070926666
# Train Epoch: 47 Batch: 0 Total samples processed: 32 Loss: 0.02968912571668625
# Train Epoch: 47 Batch: 1 Total samples processed: 64 Loss: 0.02816488966345787
# Train Epoch: 47 Batch: 2 Total samples processed: 96 Loss: 0.030905652791261673
# Train Epoch: 47 Batch: 3 Total samples processed: 128 Loss: 0.030681001022458076
# Train Epoch: 47 Batch: 4 Total samples processed: 160 Loss: 0.028014352545142174
# Train Epoch: 47 Batch: 5 Total samples processed: 192 Loss: 0.03230089321732521
# Train Epoch: 47 Batch: 6 Total samples processed: 224 Loss: 0.030435016378760338
# Train Epoch: 48 Batch: 0 Total samples processed: 32 Loss: 0.0317416787147522
# Train Epoch: 48 Batch: 1 Total samples processed: 64 Loss: 0.029615482315421104
# Train Epoch: 48 Batch: 2 Total samples processed: 96 Loss: 0.026227043941617012
# Train Epoch: 48 Batch: 3 Total samples processed: 128 Loss: 0.029673803597688675
# Train Epoch: 48 Batch: 4 Total samples processed: 160 Loss: 0.032554835081100464
# Train Epoch: 48 Batch: 5 Total samples processed: 192 Loss: 0.030877957120537758
# Train Epoch: 48 Batch: 6 Total samples processed: 224 Loss: 0.01992950029671192
# Train Epoch: 49 Batch: 0 Total samples processed: 32 Loss: 0.028814101591706276
# Train Epoch: 49 Batch: 1 Total samples processed: 64 Loss: 0.03302367404103279
# Train Epoch: 49 Batch: 2 Total samples processed: 96 Loss: 0.028537876904010773
# Train Epoch: 49 Batch: 3 Total samples processed: 128 Loss: 0.02797454595565796
# Train Epoch: 49 Batch: 4 Total samples processed: 160 Loss: 0.02989117242395878
# Train Epoch: 49 Batch: 5 Total samples processed: 192 Loss: 0.032058943063020706
# Train Epoch: 49 Batch: 6 Total samples processed: 224 Loss: 0.03112923353910446
# Train Epoch: 50 Batch: 0 Total samples processed: 32 Loss: 0.031663402915000916
# Train Epoch: 50 Batch: 1 Total samples processed: 64 Loss: 0.02939036302268505
# Train Epoch: 50 Batch: 2 Total samples processed: 96 Loss: 0.028105588629841805
# Train Epoch: 50 Batch: 3 Total samples processed: 128 Loss: 0.030014125630259514
# Train Epoch: 50 Batch: 4 Total samples processed: 160 Loss: 0.031814996153116226
# Train Epoch: 50 Batch: 5 Total samples processed: 192 Loss: 0.028938766568899155
# Train Epoch: 50 Batch: 6 Total samples processed: 224 Loss: 0.025180943310260773
# Train Epoch: 51 Batch: 0 Total samples processed: 32 Loss: 0.029472101479768753
# Train Epoch: 51 Batch: 1 Total samples processed: 64 Loss: 0.027241604402661324
# Train Epoch: 51 Batch: 2 Total samples processed: 96 Loss: 0.030755378305912018
# Train Epoch: 51 Batch: 3 Total samples processed: 128 Loss: 0.030003134161233902
# Train Epoch: 51 Batch: 4 Total samples processed: 160 Loss: 0.031541403383016586
# Train Epoch: 51 Batch: 5 Total samples processed: 192 Loss: 0.030997563153505325
# Train Epoch: 51 Batch: 6 Total samples processed: 224 Loss: 0.02675616927444935
# Train Epoch: 52 Batch: 0 Total samples processed: 32 Loss: 0.028822369873523712
# Train Epoch: 52 Batch: 1 Total samples processed: 64 Loss: 0.02798568643629551
# Train Epoch: 52 Batch: 2 Total samples processed: 96 Loss: 0.0322573222219944
# Train Epoch: 52 Batch: 3 Total samples processed: 128 Loss: 0.028335873037576675
# Train Epoch: 52 Batch: 4 Total samples processed: 160 Loss: 0.0340379998087883
# Train Epoch: 52 Batch: 5 Total samples processed: 192 Loss: 0.028339814394712448
# Train Epoch: 52 Batch: 6 Total samples processed: 224 Loss: 0.027572786435484886
# Train Epoch: 53 Batch: 0 Total samples processed: 32 Loss: 0.0281035415828228
# Train Epoch: 53 Batch: 1 Total samples processed: 64 Loss: 0.03268011659383774
# Train Epoch: 53 Batch: 2 Total samples processed: 96 Loss: 0.03283388540148735
# Train Epoch: 53 Batch: 3 Total samples processed: 128 Loss: 0.02983907237648964
# Train Epoch: 53 Batch: 4 Total samples processed: 160 Loss: 0.02836582064628601
# Train Epoch: 53 Batch: 5 Total samples processed: 192 Loss: 0.029915207996964455
# Train Epoch: 53 Batch: 6 Total samples processed: 224 Loss: 0.024739129468798637
# Train Epoch: 54 Batch: 0 Total samples processed: 32 Loss: 0.02626737765967846
# Train Epoch: 54 Batch: 1 Total samples processed: 64 Loss: 0.03241339698433876
# Train Epoch: 54 Batch: 2 Total samples processed: 96 Loss: 0.02975540980696678
# Train Epoch: 54 Batch: 3 Total samples processed: 128 Loss: 0.037328753620386124
# Train Epoch: 54 Batch: 4 Total samples processed: 160 Loss: 0.029572073370218277
# Train Epoch: 54 Batch: 5 Total samples processed: 192 Loss: 0.026683403179049492
# Train Epoch: 54 Batch: 6 Total samples processed: 224 Loss: 0.021266994997859
# Train Epoch: 55 Batch: 0 Total samples processed: 32 Loss: 0.030885491520166397
# Train Epoch: 55 Batch: 1 Total samples processed: 64 Loss: 0.03342093899846077
# Train Epoch: 55 Batch: 2 Total samples processed: 96 Loss: 0.03140147775411606
# Train Epoch: 55 Batch: 3 Total samples processed: 128 Loss: 0.030560892075300217
# Train Epoch: 55 Batch: 4 Total samples processed: 160 Loss: 0.025302452966570854
# Train Epoch: 55 Batch: 5 Total samples processed: 192 Loss: 0.026760756969451904
# Train Epoch: 55 Batch: 6 Total samples processed: 224 Loss: 0.025321969762444496
# Train Epoch: 56 Batch: 0 Total samples processed: 32 Loss: 0.02604336105287075
# Train Epoch: 56 Batch: 1 Total samples processed: 64 Loss: 0.029186099767684937
# Train Epoch: 56 Batch: 2 Total samples processed: 96 Loss: 0.03036169335246086
# Train Epoch: 56 Batch: 3 Total samples processed: 128 Loss: 0.028016217052936554
# Train Epoch: 56 Batch: 4 Total samples processed: 160 Loss: 0.03263936564326286
# Train Epoch: 56 Batch: 5 Total samples processed: 192 Loss: 0.028320258483290672
# Train Epoch: 56 Batch: 6 Total samples processed: 224 Loss: 0.023775791749358177
# Train Epoch: 57 Batch: 0 Total samples processed: 32 Loss: 0.02629808709025383
# Train Epoch: 57 Batch: 1 Total samples processed: 64 Loss: 0.02603217400610447
# Train Epoch: 57 Batch: 2 Total samples processed: 96 Loss: 0.029043246060609818
# Train Epoch: 57 Batch: 3 Total samples processed: 128 Loss: 0.02891836315393448
# Train Epoch: 57 Batch: 4 Total samples processed: 160 Loss: 0.034556951373815536
# Train Epoch: 57 Batch: 5 Total samples processed: 192 Loss: 0.026723559945821762
# Train Epoch: 57 Batch: 6 Total samples processed: 224 Loss: 0.036989640444517136
# Train Epoch: 58 Batch: 0 Total samples processed: 32 Loss: 0.029175400733947754
# Train Epoch: 58 Batch: 1 Total samples processed: 64 Loss: 0.027121061459183693
# Train Epoch: 58 Batch: 2 Total samples processed: 96 Loss: 0.028872229158878326
# Train Epoch: 58 Batch: 3 Total samples processed: 128 Loss: 0.031782619655132294
# Train Epoch: 58 Batch: 4 Total samples processed: 160 Loss: 0.029609907418489456
# Train Epoch: 58 Batch: 5 Total samples processed: 192 Loss: 0.027478022500872612
# Train Epoch: 58 Batch: 6 Total samples processed: 224 Loss: 0.028960280120372772
# Train Epoch: 59 Batch: 0 Total samples processed: 32 Loss: 0.03097863495349884
# Train Epoch: 59 Batch: 1 Total samples processed: 64 Loss: 0.030380599200725555
# Train Epoch: 59 Batch: 2 Total samples processed: 96 Loss: 0.030164586380124092
# Train Epoch: 59 Batch: 3 Total samples processed: 128 Loss: 0.03150781989097595
# Train Epoch: 59 Batch: 4 Total samples processed: 160 Loss: 0.025911087170243263
# Train Epoch: 59 Batch: 5 Total samples processed: 192 Loss: 0.02795599400997162
# Train Epoch: 59 Batch: 6 Total samples processed: 224 Loss: 0.028336426243185997
# Train Epoch: 60 Batch: 0 Total samples processed: 32 Loss: 0.028593700379133224
# Train Epoch: 60 Batch: 1 Total samples processed: 64 Loss: 0.029482237994670868
# Train Epoch: 60 Batch: 2 Total samples processed: 96 Loss: 0.03184656798839569
# Train Epoch: 60 Batch: 3 Total samples processed: 128 Loss: 0.02918112464249134
# Train Epoch: 60 Batch: 4 Total samples processed: 160 Loss: 0.029237478971481323
# Train Epoch: 60 Batch: 5 Total samples processed: 192 Loss: 0.026271644979715347
# Train Epoch: 60 Batch: 6 Total samples processed: 224 Loss: 0.027051331475377083
# Train Epoch: 61 Batch: 0 Total samples processed: 32 Loss: 0.031042365357279778
# Train Epoch: 61 Batch: 1 Total samples processed: 64 Loss: 0.02945992536842823
# Train Epoch: 61 Batch: 2 Total samples processed: 96 Loss: 0.027392201125621796
# Train Epoch: 61 Batch: 3 Total samples processed: 128 Loss: 0.02989962138235569
# Train Epoch: 61 Batch: 4 Total samples processed: 160 Loss: 0.026948483660817146
# Train Epoch: 61 Batch: 5 Total samples processed: 192 Loss: 0.030096597969532013
# Train Epoch: 61 Batch: 6 Total samples processed: 224 Loss: 0.022782834246754646
# Train Epoch: 62 Batch: 0 Total samples processed: 32 Loss: 0.026721278205513954
# Train Epoch: 62 Batch: 1 Total samples processed: 64 Loss: 0.029730306938290596
# Train Epoch: 62 Batch: 2 Total samples processed: 96 Loss: 0.03252550587058067
# Train Epoch: 62 Batch: 3 Total samples processed: 128 Loss: 0.027631759643554688
# Train Epoch: 62 Batch: 4 Total samples processed: 160 Loss: 0.026805618777871132
# Train Epoch: 62 Batch: 5 Total samples processed: 192 Loss: 0.029373859986662865
# Train Epoch: 62 Batch: 6 Total samples processed: 224 Loss: 0.027067411690950394
# Train Epoch: 63 Batch: 0 Total samples processed: 32 Loss: 0.028494052588939667
# Train Epoch: 63 Batch: 1 Total samples processed: 64 Loss: 0.028953244909644127
# Train Epoch: 63 Batch: 2 Total samples processed: 96 Loss: 0.030170775949954987
# Train Epoch: 63 Batch: 3 Total samples processed: 128 Loss: 0.028592737391591072
# Train Epoch: 63 Batch: 4 Total samples processed: 160 Loss: 0.02675541117787361
# Train Epoch: 63 Batch: 5 Total samples processed: 192 Loss: 0.03116472251713276
# Train Epoch: 63 Batch: 6 Total samples processed: 224 Loss: 0.023871708661317825
# Train Epoch: 64 Batch: 0 Total samples processed: 32 Loss: 0.029919588938355446
# Train Epoch: 64 Batch: 1 Total samples processed: 64 Loss: 0.031272292137145996
# Train Epoch: 64 Batch: 2 Total samples processed: 96 Loss: 0.028856094926595688
# Train Epoch: 64 Batch: 3 Total samples processed: 128 Loss: 0.027143435552716255
# Train Epoch: 64 Batch: 4 Total samples processed: 160 Loss: 0.02519451454281807
# Train Epoch: 64 Batch: 5 Total samples processed: 192 Loss: 0.027731088921427727
# Train Epoch: 64 Batch: 6 Total samples processed: 224 Loss: 0.0320449098944664
# Train Epoch: 65 Batch: 0 Total samples processed: 32 Loss: 0.02865319326519966
# Train Epoch: 65 Batch: 1 Total samples processed: 64 Loss: 0.029744954779744148
# Train Epoch: 65 Batch: 2 Total samples processed: 96 Loss: 0.027304930612444878
# Train Epoch: 65 Batch: 3 Total samples processed: 128 Loss: 0.027963053435087204
# Train Epoch: 65 Batch: 4 Total samples processed: 160 Loss: 0.030545944347977638
# Train Epoch: 65 Batch: 5 Total samples processed: 192 Loss: 0.023590104654431343
# Train Epoch: 65 Batch: 6 Total samples processed: 224 Loss: 0.03135683387517929
# Train Epoch: 66 Batch: 0 Total samples processed: 32 Loss: 0.02893725596368313
# Train Epoch: 66 Batch: 1 Total samples processed: 64 Loss: 0.02610047720372677
# Train Epoch: 66 Batch: 2 Total samples processed: 96 Loss: 0.025616660714149475
# Train Epoch: 66 Batch: 3 Total samples processed: 128 Loss: 0.02988615445792675
# Train Epoch: 66 Batch: 4 Total samples processed: 160 Loss: 0.030974319204688072
# Train Epoch: 66 Batch: 5 Total samples processed: 192 Loss: 0.026768378913402557
# Train Epoch: 66 Batch: 6 Total samples processed: 224 Loss: 0.03438088670372963
# Train Epoch: 67 Batch: 0 Total samples processed: 32 Loss: 0.031221909448504448
# Train Epoch: 67 Batch: 1 Total samples processed: 64 Loss: 0.026840997859835625
# Train Epoch: 67 Batch: 2 Total samples processed: 96 Loss: 0.028472792357206345
# Train Epoch: 67 Batch: 3 Total samples processed: 128 Loss: 0.026767754927277565
# Train Epoch: 67 Batch: 4 Total samples processed: 160 Loss: 0.026829635724425316
# Train Epoch: 67 Batch: 5 Total samples processed: 192 Loss: 0.03053067997097969
# Train Epoch: 67 Batch: 6 Total samples processed: 224 Loss: 0.040137242525815964
# Train Epoch: 68 Batch: 0 Total samples processed: 32 Loss: 0.02966727502644062
# Train Epoch: 68 Batch: 1 Total samples processed: 64 Loss: 0.028348295018076897
# Train Epoch: 68 Batch: 2 Total samples processed: 96 Loss: 0.030582133680582047
# Train Epoch: 68 Batch: 3 Total samples processed: 128 Loss: 0.027634726837277412
# Train Epoch: 68 Batch: 4 Total samples processed: 160 Loss: 0.02856341190636158
# Train Epoch: 68 Batch: 5 Total samples processed: 192 Loss: 0.02778020314872265
# Train Epoch: 68 Batch: 6 Total samples processed: 224 Loss: 0.02880198508501053
# Train Epoch: 69 Batch: 0 Total samples processed: 32 Loss: 0.03177214041352272
# Train Epoch: 69 Batch: 1 Total samples processed: 64 Loss: 0.029027143493294716
# Train Epoch: 69 Batch: 2 Total samples processed: 96 Loss: 0.02788447216153145
# Train Epoch: 69 Batch: 3 Total samples processed: 128 Loss: 0.026506859809160233
# Train Epoch: 69 Batch: 4 Total samples processed: 160 Loss: 0.028697967529296875
# Train Epoch: 69 Batch: 5 Total samples processed: 192 Loss: 0.02589273825287819
# Train Epoch: 69 Batch: 6 Total samples processed: 224 Loss: 0.026486137881875038
# Train Epoch: 70 Batch: 0 Total samples processed: 32 Loss: 0.024603916332125664
# Train Epoch: 70 Batch: 1 Total samples processed: 64 Loss: 0.031489674001932144
# Train Epoch: 70 Batch: 2 Total samples processed: 96 Loss: 0.028083980083465576
# Train Epoch: 70 Batch: 3 Total samples processed: 128 Loss: 0.02958483062684536
# Train Epoch: 70 Batch: 4 Total samples processed: 160 Loss: 0.026617709547281265
# Train Epoch: 70 Batch: 5 Total samples processed: 192 Loss: 0.029788946732878685
# Train Epoch: 70 Batch: 6 Total samples processed: 224 Loss: 0.03244004771113396
# Train Epoch: 71 Batch: 0 Total samples processed: 32 Loss: 0.026787670329213142
# Train Epoch: 71 Batch: 1 Total samples processed: 64 Loss: 0.028451276943087578
# Train Epoch: 71 Batch: 2 Total samples processed: 96 Loss: 0.02566535584628582
# Train Epoch: 71 Batch: 3 Total samples processed: 128 Loss: 0.02779426798224449
# Train Epoch: 71 Batch: 4 Total samples processed: 160 Loss: 0.028667911887168884
# Train Epoch: 71 Batch: 5 Total samples processed: 192 Loss: 0.028278876096010208
# Train Epoch: 71 Batch: 6 Total samples processed: 224 Loss: 0.037826016545295715
# Train Epoch: 72 Batch: 0 Total samples processed: 32 Loss: 0.030862340703606606
# Train Epoch: 72 Batch: 1 Total samples processed: 64 Loss: 0.02776203863322735
# Train Epoch: 72 Batch: 2 Total samples processed: 96 Loss: 0.026277536526322365
# Train Epoch: 72 Batch: 3 Total samples processed: 128 Loss: 0.03151266649365425
# Train Epoch: 72 Batch: 4 Total samples processed: 160 Loss: 0.02479489892721176
# Train Epoch: 72 Batch: 5 Total samples processed: 192 Loss: 0.026607854291796684
# Train Epoch: 72 Batch: 6 Total samples processed: 224 Loss: 0.023514019325375557
# Train Epoch: 73 Batch: 0 Total samples processed: 32 Loss: 0.02599758468568325
# Train Epoch: 73 Batch: 1 Total samples processed: 64 Loss: 0.027076978236436844
# Train Epoch: 73 Batch: 2 Total samples processed: 96 Loss: 0.03138342127203941
# Train Epoch: 73 Batch: 3 Total samples processed: 128 Loss: 0.026319364085793495
# Train Epoch: 73 Batch: 4 Total samples processed: 160 Loss: 0.027305375784635544
# Train Epoch: 73 Batch: 5 Total samples processed: 192 Loss: 0.028125327080488205
# Train Epoch: 73 Batch: 6 Total samples processed: 224 Loss: 0.03140930458903313
# Train Epoch: 74 Batch: 0 Total samples processed: 32 Loss: 0.027037087827920914
# Train Epoch: 74 Batch: 1 Total samples processed: 64 Loss: 0.03208354115486145
# Train Epoch: 74 Batch: 2 Total samples processed: 96 Loss: 0.026495670899748802
# Train Epoch: 74 Batch: 3 Total samples processed: 128 Loss: 0.02537032775580883
# Train Epoch: 74 Batch: 4 Total samples processed: 160 Loss: 0.029369914904236794
# Train Epoch: 74 Batch: 5 Total samples processed: 192 Loss: 0.028267109766602516
# Train Epoch: 74 Batch: 6 Total samples processed: 224 Loss: 0.022403646260499954
# Train Epoch: 75 Batch: 0 Total samples processed: 32 Loss: 0.025635559111833572
# Train Epoch: 75 Batch: 1 Total samples processed: 64 Loss: 0.02857963927090168
# Train Epoch: 75 Batch: 2 Total samples processed: 96 Loss: 0.02989257127046585
# Train Epoch: 75 Batch: 3 Total samples processed: 128 Loss: 0.02799159660935402
# Train Epoch: 75 Batch: 4 Total samples processed: 160 Loss: 0.027720976620912552
# Train Epoch: 75 Batch: 5 Total samples processed: 192 Loss: 0.027193643152713776
# Train Epoch: 75 Batch: 6 Total samples processed: 224 Loss: 0.030439751222729683
# Train Epoch: 76 Batch: 0 Total samples processed: 32 Loss: 0.024234026670455933
# Train Epoch: 76 Batch: 1 Total samples processed: 64 Loss: 0.026791678741574287
# Train Epoch: 76 Batch: 2 Total samples processed: 96 Loss: 0.025989897549152374
# Train Epoch: 76 Batch: 3 Total samples processed: 128 Loss: 0.031127305701375008
# Train Epoch: 76 Batch: 4 Total samples processed: 160 Loss: 0.026828516274690628
# Train Epoch: 76 Batch: 5 Total samples processed: 192 Loss: 0.02870599552989006
# Train Epoch: 76 Batch: 6 Total samples processed: 224 Loss: 0.036058004945516586
# Train Epoch: 77 Batch: 0 Total samples processed: 32 Loss: 0.028659896925091743
# Train Epoch: 77 Batch: 1 Total samples processed: 64 Loss: 0.028387729078531265
# Train Epoch: 77 Batch: 2 Total samples processed: 96 Loss: 0.028584934771060944
# Train Epoch: 77 Batch: 3 Total samples processed: 128 Loss: 0.02794516272842884
# Train Epoch: 77 Batch: 4 Total samples processed: 160 Loss: 0.025530178099870682
# Train Epoch: 77 Batch: 5 Total samples processed: 192 Loss: 0.024815073236823082
# Train Epoch: 77 Batch: 6 Total samples processed: 224 Loss: 0.027820857241749763
# Train Epoch: 78 Batch: 0 Total samples processed: 32 Loss: 0.026499085128307343
# Train Epoch: 78 Batch: 1 Total samples processed: 64 Loss: 0.02895234525203705
# Train Epoch: 78 Batch: 2 Total samples processed: 96 Loss: 0.026267141103744507
# Train Epoch: 78 Batch: 3 Total samples processed: 128 Loss: 0.02995147928595543
# Train Epoch: 78 Batch: 4 Total samples processed: 160 Loss: 0.027409056201577187
# Train Epoch: 78 Batch: 5 Total samples processed: 192 Loss: 0.028265731409192085
# Train Epoch: 78 Batch: 6 Total samples processed: 224 Loss: 0.02587464265525341
# Train Epoch: 79 Batch: 0 Total samples processed: 32 Loss: 0.02681959792971611
# Train Epoch: 79 Batch: 1 Total samples processed: 64 Loss: 0.027601514011621475
# Train Epoch: 79 Batch: 2 Total samples processed: 96 Loss: 0.03064553812146187
# Train Epoch: 79 Batch: 3 Total samples processed: 128 Loss: 0.02993309684097767
# Train Epoch: 79 Batch: 4 Total samples processed: 160 Loss: 0.025624586269259453
# Train Epoch: 79 Batch: 5 Total samples processed: 192 Loss: 0.028333043679594994
# Train Epoch: 79 Batch: 6 Total samples processed: 224 Loss: 0.03274701535701752
# Train Epoch: 80 Batch: 0 Total samples processed: 32 Loss: 0.027256449684500694
# Train Epoch: 80 Batch: 1 Total samples processed: 64 Loss: 0.028689146041870117
# Train Epoch: 80 Batch: 2 Total samples processed: 96 Loss: 0.02564273029565811
# Train Epoch: 80 Batch: 3 Total samples processed: 128 Loss: 0.025977281853556633
# Train Epoch: 80 Batch: 4 Total samples processed: 160 Loss: 0.0293064396828413
# Train Epoch: 80 Batch: 5 Total samples processed: 192 Loss: 0.03006848506629467
# Train Epoch: 80 Batch: 6 Total samples processed: 224 Loss: 0.030886078253388405
# Train Epoch: 81 Batch: 0 Total samples processed: 32 Loss: 0.025647316128015518
# Train Epoch: 81 Batch: 1 Total samples processed: 64 Loss: 0.030651412904262543
# Train Epoch: 81 Batch: 2 Total samples processed: 96 Loss: 0.02714630402624607
# Train Epoch: 81 Batch: 3 Total samples processed: 128 Loss: 0.02930397354066372
# Train Epoch: 81 Batch: 4 Total samples processed: 160 Loss: 0.028082307428121567
# Train Epoch: 81 Batch: 5 Total samples processed: 192 Loss: 0.025789249688386917
# Train Epoch: 81 Batch: 6 Total samples processed: 224 Loss: 0.0296986922621727
# Train Epoch: 82 Batch: 0 Total samples processed: 32 Loss: 0.02506519854068756
# Train Epoch: 82 Batch: 1 Total samples processed: 64 Loss: 0.028795568272471428
# Train Epoch: 82 Batch: 2 Total samples processed: 96 Loss: 0.02812977135181427
# Train Epoch: 82 Batch: 3 Total samples processed: 128 Loss: 0.030180709436535835
# Train Epoch: 82 Batch: 4 Total samples processed: 160 Loss: 0.0316319465637207
# Train Epoch: 82 Batch: 5 Total samples processed: 192 Loss: 0.026898840442299843
# Train Epoch: 82 Batch: 6 Total samples processed: 224 Loss: 0.03496844694018364
# Train Epoch: 83 Batch: 0 Total samples processed: 32 Loss: 0.028600672259926796
# Train Epoch: 83 Batch: 1 Total samples processed: 64 Loss: 0.02644544094800949
# Train Epoch: 83 Batch: 2 Total samples processed: 96 Loss: 0.02518496662378311
# Train Epoch: 83 Batch: 3 Total samples processed: 128 Loss: 0.032846517860889435
# Train Epoch: 83 Batch: 4 Total samples processed: 160 Loss: 0.02902395837008953
# Train Epoch: 83 Batch: 5 Total samples processed: 192 Loss: 0.03003755770623684
# Train Epoch: 83 Batch: 6 Total samples processed: 224 Loss: 0.02517584152519703
# Train Epoch: 84 Batch: 0 Total samples processed: 32 Loss: 0.02724619396030903
# Train Epoch: 84 Batch: 1 Total samples processed: 64 Loss: 0.02754185162484646
# Train Epoch: 84 Batch: 2 Total samples processed: 96 Loss: 0.028722552582621574
# Train Epoch: 84 Batch: 3 Total samples processed: 128 Loss: 0.032068848609924316
# Train Epoch: 84 Batch: 4 Total samples processed: 160 Loss: 0.026934387162327766
# Train Epoch: 84 Batch: 5 Total samples processed: 192 Loss: 0.028207698836922646
# Train Epoch: 84 Batch: 6 Total samples processed: 224 Loss: 0.025688450783491135
# Train Epoch: 85 Batch: 0 Total samples processed: 32 Loss: 0.028124574571847916
# Train Epoch: 85 Batch: 1 Total samples processed: 64 Loss: 0.02719813399016857
# Train Epoch: 85 Batch: 2 Total samples processed: 96 Loss: 0.030006838962435722
# Train Epoch: 85 Batch: 3 Total samples processed: 128 Loss: 0.027545379474759102
# Train Epoch: 85 Batch: 4 Total samples processed: 160 Loss: 0.026042815297842026
# Train Epoch: 85 Batch: 5 Total samples processed: 192 Loss: 0.029221130535006523
# Train Epoch: 85 Batch: 6 Total samples processed: 224 Loss: 0.03041064366698265
# Train Epoch: 86 Batch: 0 Total samples processed: 32 Loss: 0.025674890726804733
# Train Epoch: 86 Batch: 1 Total samples processed: 64 Loss: 0.03119422309100628
# Train Epoch: 86 Batch: 2 Total samples processed: 96 Loss: 0.03001672402024269
# Train Epoch: 86 Batch: 3 Total samples processed: 128 Loss: 0.0249834805727005
# Train Epoch: 86 Batch: 4 Total samples processed: 160 Loss: 0.02612975426018238
# ...
# Train Epoch: 222 Batch: 6 Total samples processed: 224 Loss: 0.02253403514623642
# Train Epoch: 223 Batch: 0 Total samples processed: 32 Loss: 0.021706121042370796
# Train Epoch: 223 Batch: 1 Total samples processed: 64 Loss: 0.023447571322321892
# Train Epoch: 223 Batch: 2 Total samples processed: 96 Loss: 0.020726775750517845
# Train Epoch: 223 Batch: 3 Total samples processed: 128 Loss: 0.02065100520849228
# Train Epoch: 223 Batch: 4 Total samples processed: 160 Loss: 0.02036282978951931
# Train Epoch: 223 Batch: 5 Total samples processed: 192 Loss: 0.02125973254442215
# Train Epoch: 223 Batch: 6 Total samples processed: 224 Loss: 0.01639399304986
# Train Epoch: 224 Batch: 0 Total samples processed: 32 Loss: 0.022625286132097244
# Train Epoch: 224 Batch: 1 Total samples processed: 64 Loss: 0.020709913223981857
# Train Epoch: 224 Batch: 2 Total samples processed: 96 Loss: 0.022134963423013687
# Train Epoch: 224 Batch: 3 Total samples processed: 128 Loss: 0.01894502528011799
# Train Epoch: 224 Batch: 4 Total samples processed: 160 Loss: 0.021020811051130295
# Train Epoch: 224 Batch: 5 Total samples processed: 192 Loss: 0.02057301066815853
# Train Epoch: 224 Batch: 6 Total samples processed: 224 Loss: 0.029425743967294693
# Train Epoch: 225 Batch: 0 Total samples processed: 32 Loss: 0.022855909541249275
# Train Epoch: 225 Batch: 1 Total samples processed: 64 Loss: 0.01992107927799225
# Train Epoch: 225 Batch: 2 Total samples processed: 96 Loss: 0.019450457766652107
# Train Epoch: 225 Batch: 3 Total samples processed: 128 Loss: 0.02186824567615986
# Train Epoch: 225 Batch: 4 Total samples processed: 160 Loss: 0.021950794383883476
# Train Epoch: 225 Batch: 5 Total samples processed: 192 Loss: 0.020854448899626732
# Train Epoch: 225 Batch: 6 Total samples processed: 224 Loss: 0.024681856855750084
# Train Epoch: 226 Batch: 0 Total samples processed: 32 Loss: 0.02314576506614685
# Train Epoch: 226 Batch: 1 Total samples processed: 64 Loss: 0.02304270677268505
# Train Epoch: 226 Batch: 2 Total samples processed: 96 Loss: 0.02057102508842945
# Train Epoch: 226 Batch: 3 Total samples processed: 128 Loss: 0.020686263218522072
# Train Epoch: 226 Batch: 4 Total samples processed: 160 Loss: 0.020060181617736816
# Train Epoch: 226 Batch: 5 Total samples processed: 192 Loss: 0.020360250025987625
# Train Epoch: 226 Batch: 6 Total samples processed: 224 Loss: 0.027675943449139595
# Train Epoch: 227 Batch: 0 Total samples processed: 32 Loss: 0.020506301894783974
# Train Epoch: 227 Batch: 1 Total samples processed: 64 Loss: 0.020016763359308243
# Train Epoch: 227 Batch: 2 Total samples processed: 96 Loss: 0.023437609896063805
# Train Epoch: 227 Batch: 3 Total samples processed: 128 Loss: 0.019136397168040276
# Train Epoch: 227 Batch: 4 Total samples processed: 160 Loss: 0.020238280296325684
# Train Epoch: 227 Batch: 5 Total samples processed: 192 Loss: 0.023230887949466705
# Train Epoch: 227 Batch: 6 Total samples processed: 224 Loss: 0.023652827367186546
# Train Epoch: 228 Batch: 0 Total samples processed: 32 Loss: 0.02181243523955345
# Train Epoch: 228 Batch: 1 Total samples processed: 64 Loss: 0.019132668152451515
# Train Epoch: 228 Batch: 2 Total samples processed: 96 Loss: 0.021756120026111603
# Train Epoch: 228 Batch: 3 Total samples processed: 128 Loss: 0.021734463050961494
# Train Epoch: 228 Batch: 4 Total samples processed: 160 Loss: 0.02134067378938198
# Train Epoch: 228 Batch: 5 Total samples processed: 192 Loss: 0.021017862483859062
# Train Epoch: 228 Batch: 6 Total samples processed: 224 Loss: 0.019892066717147827
# Train Epoch: 229 Batch: 0 Total samples processed: 32 Loss: 0.022800950333476067
# Train Epoch: 229 Batch: 1 Total samples processed: 64 Loss: 0.018472759053111076
# Train Epoch: 229 Batch: 2 Total samples processed: 96 Loss: 0.019692689180374146
# Train Epoch: 229 Batch: 3 Total samples processed: 128 Loss: 0.020525457337498665
# Train Epoch: 229 Batch: 4 Total samples processed: 160 Loss: 0.02265760861337185
# Train Epoch: 229 Batch: 5 Total samples processed: 192 Loss: 0.02110579051077366
# Train Epoch: 229 Batch: 6 Total samples processed: 224 Loss: 0.025756537914276123
# Train Epoch: 230 Batch: 0 Total samples processed: 32 Loss: 0.0182019229978323
# Train Epoch: 230 Batch: 1 Total samples processed: 64 Loss: 0.020963512361049652
# Train Epoch: 230 Batch: 2 Total samples processed: 96 Loss: 0.023516513407230377
# Train Epoch: 230 Batch: 3 Total samples processed: 128 Loss: 0.02307281084358692
# Train Epoch: 230 Batch: 4 Total samples processed: 160 Loss: 0.019941110163927078
# Train Epoch: 230 Batch: 5 Total samples processed: 192 Loss: 0.019996320828795433
# Train Epoch: 230 Batch: 6 Total samples processed: 224 Loss: 0.024883342906832695
# Train Epoch: 231 Batch: 0 Total samples processed: 32 Loss: 0.020778890699148178
# Train Epoch: 231 Batch: 1 Total samples processed: 64 Loss: 0.02371620200574398
# Train Epoch: 231 Batch: 2 Total samples processed: 96 Loss: 0.01983308233320713
# Train Epoch: 231 Batch: 3 Total samples processed: 128 Loss: 0.019952671602368355
# Train Epoch: 231 Batch: 4 Total samples processed: 160 Loss: 0.020658502355217934
# Train Epoch: 231 Batch: 5 Total samples processed: 192 Loss: 0.020973876118659973
# Train Epoch: 231 Batch: 6 Total samples processed: 224 Loss: 0.021742379292845726
# Train Epoch: 232 Batch: 0 Total samples processed: 32 Loss: 0.02079872600734234
# Train Epoch: 232 Batch: 1 Total samples processed: 64 Loss: 0.02156207710504532
# Train Epoch: 232 Batch: 2 Total samples processed: 96 Loss: 0.020223213359713554
# Train Epoch: 232 Batch: 3 Total samples processed: 128 Loss: 0.022845787927508354
# Train Epoch: 232 Batch: 4 Total samples processed: 160 Loss: 0.019518207758665085
# Train Epoch: 232 Batch: 5 Total samples processed: 192 Loss: 0.022591419517993927
# Train Epoch: 232 Batch: 6 Total samples processed: 224 Loss: 0.01821589469909668
# Train Epoch: 233 Batch: 0 Total samples processed: 32 Loss: 0.021550586447119713
# Train Epoch: 233 Batch: 1 Total samples processed: 64 Loss: 0.02398017607629299
# Train Epoch: 233 Batch: 2 Total samples processed: 96 Loss: 0.020511023700237274
# Train Epoch: 233 Batch: 3 Total samples processed: 128 Loss: 0.01958567276597023
# Train Epoch: 233 Batch: 4 Total samples processed: 160 Loss: 0.02066250890493393
# Train Epoch: 233 Batch: 5 Total samples processed: 192 Loss: 0.019839225336909294
# Train Epoch: 233 Batch: 6 Total samples processed: 224 Loss: 0.02550690993666649
# Train Epoch: 234 Batch: 0 Total samples processed: 32 Loss: 0.02125195600092411
# Train Epoch: 234 Batch: 1 Total samples processed: 64 Loss: 0.02233003079891205
# Train Epoch: 234 Batch: 2 Total samples processed: 96 Loss: 0.022672418504953384
# Train Epoch: 234 Batch: 3 Total samples processed: 128 Loss: 0.023592161014676094
# Train Epoch: 234 Batch: 4 Total samples processed: 160 Loss: 0.022249789908528328
# Train Epoch: 234 Batch: 5 Total samples processed: 192 Loss: 0.022866062819957733
# Train Epoch: 234 Batch: 6 Total samples processed: 224 Loss: 0.027397822588682175
# Train Epoch: 235 Batch: 0 Total samples processed: 32 Loss: 0.02111957035958767
# Train Epoch: 235 Batch: 1 Total samples processed: 64 Loss: 0.02400295063853264
# Train Epoch: 235 Batch: 2 Total samples processed: 96 Loss: 0.021256057545542717
# Train Epoch: 235 Batch: 3 Total samples processed: 128 Loss: 0.023195840418338776
# Train Epoch: 235 Batch: 4 Total samples processed: 160 Loss: 0.022411473095417023
# Train Epoch: 235 Batch: 5 Total samples processed: 192 Loss: 0.022486476227641106
# Train Epoch: 235 Batch: 6 Total samples processed: 224 Loss: 0.026049891486763954
# Train Epoch: 236 Batch: 0 Total samples processed: 32 Loss: 0.021103747189044952
# Train Epoch: 236 Batch: 1 Total samples processed: 64 Loss: 0.024708177894353867
# Train Epoch: 236 Batch: 2 Total samples processed: 96 Loss: 0.019313707947731018
# Train Epoch: 236 Batch: 3 Total samples processed: 128 Loss: 0.020977545529603958
# Train Epoch: 236 Batch: 4 Total samples processed: 160 Loss: 0.02271324396133423
# Train Epoch: 236 Batch: 5 Total samples processed: 192 Loss: 0.022441420704126358
# Train Epoch: 236 Batch: 6 Total samples processed: 224 Loss: 0.022917576134204865
# Train Epoch: 237 Batch: 0 Total samples processed: 32 Loss: 0.01992272026836872
# Train Epoch: 237 Batch: 1 Total samples processed: 64 Loss: 0.023136021569371223
# Train Epoch: 237 Batch: 2 Total samples processed: 96 Loss: 0.019493205472826958
# Train Epoch: 237 Batch: 3 Total samples processed: 128 Loss: 0.022031009197235107
# Train Epoch: 237 Batch: 4 Total samples processed: 160 Loss: 0.02062605321407318
# Train Epoch: 237 Batch: 5 Total samples processed: 192 Loss: 0.02566375955939293
# Train Epoch: 237 Batch: 6 Total samples processed: 224 Loss: 0.02542531117796898
# Train Epoch: 238 Batch: 0 Total samples processed: 32 Loss: 0.019696639850735664
# Train Epoch: 238 Batch: 1 Total samples processed: 64 Loss: 0.01989494450390339
# Train Epoch: 238 Batch: 2 Total samples processed: 96 Loss: 0.022461295127868652
# Train Epoch: 238 Batch: 3 Total samples processed: 128 Loss: 0.02204989641904831
# Train Epoch: 238 Batch: 4 Total samples processed: 160 Loss: 0.022064026445150375
# Train Epoch: 238 Batch: 5 Total samples processed: 192 Loss: 0.02329227328300476
# Train Epoch: 238 Batch: 6 Total samples processed: 224 Loss: 0.0273604579269886
# Train Epoch: 239 Batch: 0 Total samples processed: 32 Loss: 0.022928329184651375
# Train Epoch: 239 Batch: 1 Total samples processed: 64 Loss: 0.020478960126638412
# Train Epoch: 239 Batch: 2 Total samples processed: 96 Loss: 0.021968724206089973
# Train Epoch: 239 Batch: 3 Total samples processed: 128 Loss: 0.020437192171812057
# Train Epoch: 239 Batch: 4 Total samples processed: 160 Loss: 0.022116772830486298
# Train Epoch: 239 Batch: 5 Total samples processed: 192 Loss: 0.021469496190547943
# Train Epoch: 239 Batch: 6 Total samples processed: 224 Loss: 0.022511404007673264
# Train Epoch: 240 Batch: 0 Total samples processed: 32 Loss: 0.022177301347255707
# Train Epoch: 240 Batch: 1 Total samples processed: 64 Loss: 0.021474560722708702
# Train Epoch: 240 Batch: 2 Total samples processed: 96 Loss: 0.023090612143278122
# Train Epoch: 240 Batch: 3 Total samples processed: 128 Loss: 0.0211687870323658
# Train Epoch: 240 Batch: 4 Total samples processed: 160 Loss: 0.019157202914357185
# Train Epoch: 240 Batch: 5 Total samples processed: 192 Loss: 0.01972983218729496
# Train Epoch: 240 Batch: 6 Total samples processed: 224 Loss: 0.028103772550821304
# Train Epoch: 241 Batch: 0 Total samples processed: 32 Loss: 0.020908039063215256
# Train Epoch: 241 Batch: 1 Total samples processed: 64 Loss: 0.021100793033838272
# Train Epoch: 241 Batch: 2 Total samples processed: 96 Loss: 0.02277340181171894
# Train Epoch: 241 Batch: 3 Total samples processed: 128 Loss: 0.021182604134082794
# Train Epoch: 241 Batch: 4 Total samples processed: 160 Loss: 0.02220228686928749
# Train Epoch: 241 Batch: 5 Total samples processed: 192 Loss: 0.02528359368443489
# Train Epoch: 241 Batch: 6 Total samples processed: 224 Loss: 0.021286824718117714
# Train Epoch: 242 Batch: 0 Total samples processed: 32 Loss: 0.020732875913381577
# Train Epoch: 242 Batch: 1 Total samples processed: 64 Loss: 0.021797068417072296
# Train Epoch: 242 Batch: 2 Total samples processed: 96 Loss: 0.021374769508838654
# Train Epoch: 242 Batch: 3 Total samples processed: 128 Loss: 0.02441798895597458
# Train Epoch: 242 Batch: 4 Total samples processed: 160 Loss: 0.02237345278263092
# Train Epoch: 242 Batch: 5 Total samples processed: 192 Loss: 0.02251172438263893
# Train Epoch: 242 Batch: 6 Total samples processed: 224 Loss: 0.021301643922924995
# Train Epoch: 243 Batch: 0 Total samples processed: 32 Loss: 0.022328905761241913
# Train Epoch: 243 Batch: 1 Total samples processed: 64 Loss: 0.024235276505351067
# Train Epoch: 243 Batch: 2 Total samples processed: 96 Loss: 0.022819645702838898
# Train Epoch: 243 Batch: 3 Total samples processed: 128 Loss: 0.020091470330953598
# Train Epoch: 243 Batch: 4 Total samples processed: 160 Loss: 0.0207968782633543
# Train Epoch: 243 Batch: 5 Total samples processed: 192 Loss: 0.018698010593652725
# Train Epoch: 243 Batch: 6 Total samples processed: 224 Loss: 0.02584220841526985
# Train Epoch: 244 Batch: 0 Total samples processed: 32 Loss: 0.01980489119887352
# Train Epoch: 244 Batch: 1 Total samples processed: 64 Loss: 0.02233622409403324
# Train Epoch: 244 Batch: 2 Total samples processed: 96 Loss: 0.02437494695186615
# Train Epoch: 244 Batch: 3 Total samples processed: 128 Loss: 0.02035689353942871
# Train Epoch: 244 Batch: 4 Total samples processed: 160 Loss: 0.021758994087576866
# Train Epoch: 244 Batch: 5 Total samples processed: 192 Loss: 0.02213871479034424
# Train Epoch: 244 Batch: 6 Total samples processed: 224 Loss: 0.018618853762745857
# Train Epoch: 245 Batch: 0 Total samples processed: 32 Loss: 0.020731722936034203
# Train Epoch: 245 Batch: 1 Total samples processed: 64 Loss: 0.02001076750457287
# Train Epoch: 245 Batch: 2 Total samples processed: 96 Loss: 0.022497575730085373
# Train Epoch: 245 Batch: 3 Total samples processed: 128 Loss: 0.022667987272143364
# Train Epoch: 245 Batch: 4 Total samples processed: 160 Loss: 0.020136239007115364
# Train Epoch: 245 Batch: 5 Total samples processed: 192 Loss: 0.020946728065609932
# Train Epoch: 245 Batch: 6 Total samples processed: 224 Loss: 0.02864065393805504
# Train Epoch: 246 Batch: 0 Total samples processed: 32 Loss: 0.022054562345147133
# Train Epoch: 246 Batch: 1 Total samples processed: 64 Loss: 0.022753683850169182
# Train Epoch: 246 Batch: 2 Total samples processed: 96 Loss: 0.023185404017567635
# Train Epoch: 246 Batch: 3 Total samples processed: 128 Loss: 0.023635132238268852
# Train Epoch: 246 Batch: 4 Total samples processed: 160 Loss: 0.020453471690416336
# Train Epoch: 246 Batch: 5 Total samples processed: 192 Loss: 0.02280685305595398
# Train Epoch: 246 Batch: 6 Total samples processed: 224 Loss: 0.025494979694485664
# Train Epoch: 247 Batch: 0 Total samples processed: 32 Loss: 0.02394070290029049
# Train Epoch: 247 Batch: 1 Total samples processed: 64 Loss: 0.022318271920084953
# Train Epoch: 247 Batch: 2 Total samples processed: 96 Loss: 0.022808190435171127
# Train Epoch: 247 Batch: 3 Total samples processed: 128 Loss: 0.020664464682340622
# Train Epoch: 247 Batch: 4 Total samples processed: 160 Loss: 0.02176780067384243
# Train Epoch: 247 Batch: 5 Total samples processed: 192 Loss: 0.022560399025678635
# Train Epoch: 247 Batch: 6 Total samples processed: 224 Loss: 0.023856882005929947
# Train Epoch: 248 Batch: 0 Total samples processed: 32 Loss: 0.023634394630789757
# Train Epoch: 248 Batch: 1 Total samples processed: 64 Loss: 0.023415599018335342
# Train Epoch: 248 Batch: 2 Total samples processed: 96 Loss: 0.023173676803708076
# Train Epoch: 248 Batch: 3 Total samples processed: 128 Loss: 0.0208098366856575
# Train Epoch: 248 Batch: 4 Total samples processed: 160 Loss: 0.021072443574666977
# Train Epoch: 248 Batch: 5 Total samples processed: 192 Loss: 0.01801799237728119
# Train Epoch: 248 Batch: 6 Total samples processed: 224 Loss: 0.025349466130137444
# Train Epoch: 249 Batch: 0 Total samples processed: 32 Loss: 0.019281668588519096
# Train Epoch: 249 Batch: 1 Total samples processed: 64 Loss: 0.02209710143506527
# Train Epoch: 249 Batch: 2 Total samples processed: 96 Loss: 0.02468005381524563
# Train Epoch: 249 Batch: 3 Total samples processed: 128 Loss: 0.01963105984032154
# Train Epoch: 249 Batch: 4 Total samples processed: 160 Loss: 0.024321740493178368
# Train Epoch: 249 Batch: 5 Total samples processed: 192 Loss: 0.020308593288064003
# Train Epoch: 249 Batch: 6 Total samples processed: 224 Loss: 0.020322520285844803
# Train Epoch: 250 Batch: 0 Total samples processed: 32 Loss: 0.021401559934020042
# Train Epoch: 250 Batch: 1 Total samples processed: 64 Loss: 0.02058296836912632
# Train Epoch: 250 Batch: 2 Total samples processed: 96 Loss: 0.02253109961748123
# Train Epoch: 250 Batch: 3 Total samples processed: 128 Loss: 0.023015327751636505
# Train Epoch: 250 Batch: 4 Total samples processed: 160 Loss: 0.020748699083924294
# Train Epoch: 250 Batch: 5 Total samples processed: 192 Loss: 0.018065959215164185
# Train Epoch: 250 Batch: 6 Total samples processed: 224 Loss: 0.020975705236196518

# %% [markdown]
# ## Look at self-prediction
#
# Self-prediction does not tell us how the UNET will perform on new data, but it is a useful check to make sure the UNET is learning the training data.

# %%
import matplotlib.pyplot as plt

# convert to 0/1 range on each pixel
prediction = torch.nn.functional.sigmoid(prediction_logits)
prediction_binary = prediction #(prediction > 0.5).to(torch.uint8)

sidx = 12
plt.subplot(131)
plt.imshow(X[sidx, 0].cpu().numpy(), cmap="gray")
plt.title("Input")

plt.subplot(132)
plt.imshow(y[sidx, 0].cpu().numpy(), cmap="gray")
plt.title("Ground truth")

plt.subplot(133)
plt.imshow(prediction_binary.cpu().detach()[sidx, 0].numpy(), cmap="gray")
plt.title("Predictions")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[166], line 9
#       7 sidx = 12
#       8 plt.subplot(131)
# ----> 9 plt.imshow(X[sidx, 0].cpu().numpy(), cmap="gray")
#      10 plt.title("Input")
#      12 plt.subplot(132)
#
# IndexError: index 12 is out of bounds for dimension 0 with size 8

# %% [markdown]
# ## Save the UNET

# %%
torch.save(model.state_dict(), train_path / 'models')

# %% [markdown]
# ## Test on unseen data

# %%
#test_name = '2_force_filtered.tif'
test_name = '24_force_filtered.tif'
#test_name = '33_force_flow_filtered.tif'
#test_name = '44_force_flow_filtered.tif'

testim = imread(parent_path  / test_name) 
testim2 = testim[100:, 100:]
testim.shape
plt.imshow(testim, cmap="gray")
print('original min max', testim.min(), testim.max())
print('cropped min max', testim2.min(), testim2.max())
# Out:
# original min max 0.20914316 0.9671849
# cropped min max 0.5237987 0.8165312

# %%
testim__ = quantile_normalization(
    testim,
    quantile_low=0.01,
    quantile_high=0.998,
    clip=True)[0].astype(np.float32)
x = torch.from_numpy(testim).unsqueeze(0).unsqueeze(0).to(device)
y = model(x)

plt.imshow(y.cpu().detach()[0, 0].numpy(), cmap="gray")

# %% [markdown]
# ## Look at results in Napari

# %%
import napari
viewer = napari.Viewer()
viewer.add_image(testim, name='testim')
viewer.add_image(y.cpu().detach()[0, 0].numpy(), name='prediction')
binary = y.cpu().detach()[0, 0].numpy() > 0.5
viewer.add_labels(binary, name='prediction binary')
# Out:
# <Labels layer 'prediction binary' at 0x1d577c52800>
