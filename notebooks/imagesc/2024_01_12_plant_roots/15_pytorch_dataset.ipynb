# %% [markdown]
# ## Train a semantic segmentation unet using Pytorch

# %% [markdown]
# ## Pytorch setup
#
# setting up environment (Windows 10 with Cuda 11.8)
#
# ```
# conda create --name pytorch_tests python=3.10
# conda activate pytorch_tests
# conda install pip
# pip install pykernel
# pip3 install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118
# pip install pytorch-lightning
# pip install monai
# pip install scipy
# pip install tifffile
# pip install matplotlib
# ```

# %% [markdown]
# ## Imports

# %%
from tifffile import imread
from tqdm import tqdm
from data import quantile_normalization
import matplotlib.pyplot as plt
import numpy as np
import torch

from torchvision import transforms
from torchvision.transforms import v2
import torchvision.transforms.functional as TF

# %% [markdown]
# ## Set up image and label directories

# %%
from pathlib import Path
import json

tnia_images_path = Path(r'D:/images')
parent_path=Path(tnia_images_path / r'tnia-python-images/imagesc/2024_01_12_plant_roots')
label_path = Path(parent_path / r'labels')
test_image_path = Path(label_path / r'images')
train_path= parent_path / 'patches' / 'augment'

with open(train_path / 'info.json', 'r') as json_file:
    data = json.load(json_file)
    # Access the sub_sample parameter
    sub_sample = data['sub_sample']
    print('sub_sample',sub_sample)
    axes = data['axes']
    print('axes',axes)

image_patch_path = train_path / 'ground truth0'
label_patch_path = train_path / 'input0'
# Out:
# sub_sample 1
# axes YX

# %% [markdown]
# ## Create a Dataset for the plant root data
#
# Dataset is simply used to retrieve the training patches.  In this case we just set it up to read in image files, then convert the numpy arrays to tensors and a torch stack.
#
# In this example augmentation was done in a previous notebook, and the augmented images explicitly saved.  It is also possible to do augmentation as the data is retrieved.  So in the future the ```PlantRootData``` could be extended to apply augmentation as data is retrieved.

# %%
class PlantRootData():

    def __init__(self, image_files, label_files, target_shape=(256, 256)):
            """
            Parameters
            ----------
            image_files: list of pathlib.Path objects pointing to the *.tif images
            label_files: list of pathlib.Path objects pointing to the *.tif segmentation masks
            target_shape: tuple of length 2 specifying the sample resolutions of files that
                        will be kept. All other files will NOT be used.
            """
            assert len(image_files) == len(label_files)
            assert all(x.name==y.name for x,y in zip(image_files, label_files))

            self.images = []
            self.labels = []

            tensor_transform = transforms.Compose([
                v2.ToTensor(),
            ])

            # use tqdm to have eye pleasing error bars
            for idx in tqdm(range(len(image_files))):
                # we use the same data reading approach as in the previous notebook
                image = imread(image_files[idx])
                label = imread(label_files[idx])

                if image.shape != target_shape:
                    continue
                
                # do the normalizations
                #image = quantile_normalization(
                #    image,
                #    quantile_low=0.01,
                #    quantile_high=0.998,
                #    clip=True)[0].astype(np.float32)

                # NOTE: we convert the label to dtype float32 and not uint8 because
                # the tensor transformation does a normalization if the input is of
                # dtype uint8, destroying the 0/1 labelling which we want to avoid.
                #label = fill_label_holes(label)
                label_binary = np.zeros_like(label).astype(np.float32)
                label_binary[label != 0] = 1.
                

                # convert to torch tensor: adds an artificial color channel in the front
                # and scales inputs to have same size as samples tend to differ in image
                # resolutions
                image = tensor_transform(image)
                label = tensor_transform(label_binary)

                self.images.append(image)
                self.labels.append(label)

            self.images = torch.stack(self.images)
            self.labels = torch.stack(self.labels)
    
    def __getitem__(self, idx):
        return self.images[idx], self.labels[idx]

    def __len__(self):
        return len(self.images)

# %% [markdown]
# ## Initialize the PlantRootData
#
# Initialize the DataSet with the pre-generated patch names

# %%
src_dir = train_path

assert src_dir.exists(), f"root directory with images and masks {src_dir} does not exist"

X = sorted(src_dir.rglob('**/input0/*.tif'))
Y = sorted(src_dir.rglob('**/ground truth0/*.tif'))

train_data = PlantRootData(
    image_files=X,
    label_files=Y,
    target_shape=(448, 448)
)

# NOTE: the length of the dataset might not be the same as n_samples
#       because files not having the target shape will be discarded
print(len(train_data))
# Out:
# c:\Users\bnort\miniconda3\envs\pytorch_tests2\lib\site-packages\torchvision\transforms\v2\_deprecated.py:43: UserWarning: The transform `ToTensor()` is deprecated and will be removed in a future release. Instead, please use `v2.Compose([v2.ToImage(), v2.ToDtype(torch.float32, scale=True)])`.
#   warnings.warn(
# 100%|██████████| 200/200 [00:01<00:00, 154.18it/s]
# 200

# %% [markdown]
# ## Create a DataLoader
#
# This is done so we can load batches of images.

# %%
from torch.utils.data import DataLoader

train_loader = DataLoader(train_data, batch_size=32, shuffle=True)

# %% [markdown]
# ## Check if GPU is present

# %%
cuda_present = torch.cuda.is_available()
ndevices = torch.cuda.device_count()
use_cuda = cuda_present and ndevices > 0
device = torch.device("cuda" if use_cuda else "cpu")  # "cuda:0" ... default device, "cuda:1" would be GPU index 1, "cuda:2" etc
print("number of devices:", ndevices, "\tchosen device:", device, "\tuse_cuda=", use_cuda)
# Out:
# number of devices: 1 	chosen device: cuda 	use_cuda= True

# %% [markdown]
# ## Create a UNET

# %%
from monai.networks.nets import BasicUNet

model = BasicUNet(
    spatial_dims=2,
    in_channels=1,
    out_channels=1,
    #features=[16, 16, 32, 64, 128, 16],
    act="relu",
    norm="batch",
    dropout=0.25,
)

# Important: transfer the model to the chosen device
model = model.to(device)

optimizer = torch.optim.Adam(model.parameters(), lr=1.e-3)
init_params = list(model.parameters())[0].clone().detach()
# Out:
# BasicUNet features: (32, 32, 64, 128, 256, 32).

# %% [markdown]
# ## Train the UNET

# %%
max_nepochs = 250
log_interval = 1
model.train(True)

# BCEWithLogitsLoss combines sigmoid + BCELoss for better
# numerical stability. It expects raw unnormalized scores as input which are shaped like 
# B x C x W x D
loss_function = torch.nn.BCEWithLogitsLoss(reduction="mean")

for epoch in range(1, max_nepochs + 1):
    for batch_idx, (X, y) in enumerate(train_loader):
        # the inputs and labels have to be on the same device as the model
        X, y = X.to(device), y.to(device)
        
        optimizer.zero_grad()

        prediction_logits = model(X)
        
        batch_loss = loss_function(prediction_logits, y)

        batch_loss.backward()

        optimizer.step()

        if batch_idx % log_interval == 0:
            print(
                "Train Epoch:",
                epoch,
                "Batch:",
                batch_idx,
                "Total samples processed:",
                (batch_idx + 1) * train_loader.batch_size,
                "Loss:",
                batch_loss.item(),
            )
# Out:
# Train Epoch: 1 Batch: 0 Total samples processed: 32 Loss: 0.01994437724351883
# Train Epoch: 1 Batch: 1 Total samples processed: 64 Loss: 0.019882364198565483
# Train Epoch: 1 Batch: 2 Total samples processed: 96 Loss: 0.020159194245934486
# Train Epoch: 1 Batch: 3 Total samples processed: 128 Loss: 0.020134348422288895
# Train Epoch: 1 Batch: 4 Total samples processed: 160 Loss: 0.01972152665257454
# Train Epoch: 1 Batch: 5 Total samples processed: 192 Loss: 0.02241913415491581
# Train Epoch: 1 Batch: 6 Total samples processed: 224 Loss: 0.025538185611367226
# Train Epoch: 2 Batch: 0 Total samples processed: 32 Loss: 0.02109188213944435
# Train Epoch: 2 Batch: 1 Total samples processed: 64 Loss: 0.018426023423671722
# Train Epoch: 2 Batch: 2 Total samples processed: 96 Loss: 0.022672493010759354
# Train Epoch: 2 Batch: 3 Total samples processed: 128 Loss: 0.01940765231847763
# Train Epoch: 2 Batch: 4 Total samples processed: 160 Loss: 0.02107437700033188
# Train Epoch: 2 Batch: 5 Total samples processed: 192 Loss: 0.020608577877283096
# Train Epoch: 2 Batch: 6 Total samples processed: 224 Loss: 0.021137183532118797
# Train Epoch: 3 Batch: 0 Total samples processed: 32 Loss: 0.01893519051373005
# Train Epoch: 3 Batch: 1 Total samples processed: 64 Loss: 0.02208608388900757
# Train Epoch: 3 Batch: 2 Total samples processed: 96 Loss: 0.01995721645653248
# Train Epoch: 3 Batch: 3 Total samples processed: 128 Loss: 0.02106945589184761
# Train Epoch: 3 Batch: 4 Total samples processed: 160 Loss: 0.020233070477843285
# Train Epoch: 3 Batch: 5 Total samples processed: 192 Loss: 0.01721835881471634
# Train Epoch: 3 Batch: 6 Total samples processed: 224 Loss: 0.03787320479750633
# Train Epoch: 4 Batch: 0 Total samples processed: 32 Loss: 0.01919691637158394
# Train Epoch: 4 Batch: 1 Total samples processed: 64 Loss: 0.022464243695139885
# Train Epoch: 4 Batch: 2 Total samples processed: 96 Loss: 0.02188578061759472
# Train Epoch: 4 Batch: 3 Total samples processed: 128 Loss: 0.020640209317207336
# Train Epoch: 4 Batch: 4 Total samples processed: 160 Loss: 0.0225212424993515
# Train Epoch: 4 Batch: 5 Total samples processed: 192 Loss: 0.021935544908046722
# Train Epoch: 4 Batch: 6 Total samples processed: 224 Loss: 0.01679794304072857
# Train Epoch: 5 Batch: 0 Total samples processed: 32 Loss: 0.020392095670104027
# Train Epoch: 5 Batch: 1 Total samples processed: 64 Loss: 0.02418971061706543
# Train Epoch: 5 Batch: 2 Total samples processed: 96 Loss: 0.02089828811585903
# Train Epoch: 5 Batch: 3 Total samples processed: 128 Loss: 0.021272659301757812
# Train Epoch: 5 Batch: 4 Total samples processed: 160 Loss: 0.019061481580138206
# Train Epoch: 5 Batch: 5 Total samples processed: 192 Loss: 0.020948445424437523
# Train Epoch: 5 Batch: 6 Total samples processed: 224 Loss: 0.019593404605984688
# Train Epoch: 6 Batch: 0 Total samples processed: 32 Loss: 0.020641719922423363
# Train Epoch: 6 Batch: 1 Total samples processed: 64 Loss: 0.01960580237209797
# Train Epoch: 6 Batch: 2 Total samples processed: 96 Loss: 0.022088225930929184
# Train Epoch: 6 Batch: 3 Total samples processed: 128 Loss: 0.023033438250422478
# Train Epoch: 6 Batch: 4 Total samples processed: 160 Loss: 0.019676966592669487
# Train Epoch: 6 Batch: 5 Total samples processed: 192 Loss: 0.020120855420827866
# Train Epoch: 6 Batch: 6 Total samples processed: 224 Loss: 0.022506389766931534
# Train Epoch: 7 Batch: 0 Total samples processed: 32 Loss: 0.01910041831433773
# Train Epoch: 7 Batch: 1 Total samples processed: 64 Loss: 0.022224275395274162
# Train Epoch: 7 Batch: 2 Total samples processed: 96 Loss: 0.02067948319017887
# Train Epoch: 7 Batch: 3 Total samples processed: 128 Loss: 0.021716604009270668
# Train Epoch: 7 Batch: 4 Total samples processed: 160 Loss: 0.02319900318980217
# Train Epoch: 7 Batch: 5 Total samples processed: 192 Loss: 0.02198519930243492
# Train Epoch: 7 Batch: 6 Total samples processed: 224 Loss: 0.025676444172859192
# Train Epoch: 8 Batch: 0 Total samples processed: 32 Loss: 0.018176721408963203
# Train Epoch: 8 Batch: 1 Total samples processed: 64 Loss: 0.02205335721373558
# Train Epoch: 8 Batch: 2 Total samples processed: 96 Loss: 0.022864142432808876
# Train Epoch: 8 Batch: 3 Total samples processed: 128 Loss: 0.022052302956581116
# Train Epoch: 8 Batch: 4 Total samples processed: 160 Loss: 0.022181035950779915
# Train Epoch: 8 Batch: 5 Total samples processed: 192 Loss: 0.020867779850959778
# Train Epoch: 8 Batch: 6 Total samples processed: 224 Loss: 0.022499123588204384
# Train Epoch: 9 Batch: 0 Total samples processed: 32 Loss: 0.01774442009627819
# Train Epoch: 9 Batch: 1 Total samples processed: 64 Loss: 0.024770274758338928
# Train Epoch: 9 Batch: 2 Total samples processed: 96 Loss: 0.020949991419911385
# Train Epoch: 9 Batch: 3 Total samples processed: 128 Loss: 0.019056148827075958
# Train Epoch: 9 Batch: 4 Total samples processed: 160 Loss: 0.0222946647554636
# Train Epoch: 9 Batch: 5 Total samples processed: 192 Loss: 0.019984440878033638
# Train Epoch: 9 Batch: 6 Total samples processed: 224 Loss: 0.022939911112189293
# Train Epoch: 10 Batch: 0 Total samples processed: 32 Loss: 0.02060033567249775
# Train Epoch: 10 Batch: 1 Total samples processed: 64 Loss: 0.021367855370044708
# Train Epoch: 10 Batch: 2 Total samples processed: 96 Loss: 0.022570054978132248
# Train Epoch: 10 Batch: 3 Total samples processed: 128 Loss: 0.021060096099972725
# Train Epoch: 10 Batch: 4 Total samples processed: 160 Loss: 0.019809618592262268
# Train Epoch: 10 Batch: 5 Total samples processed: 192 Loss: 0.020842211320996284
# Train Epoch: 10 Batch: 6 Total samples processed: 224 Loss: 0.015938619151711464
# Train Epoch: 11 Batch: 0 Total samples processed: 32 Loss: 0.018931996077299118
# Train Epoch: 11 Batch: 1 Total samples processed: 64 Loss: 0.0207524336874485
# Train Epoch: 11 Batch: 2 Total samples processed: 96 Loss: 0.017980415374040604
# Train Epoch: 11 Batch: 3 Total samples processed: 128 Loss: 0.02016955241560936
# Train Epoch: 11 Batch: 4 Total samples processed: 160 Loss: 0.023524446412920952
# Train Epoch: 11 Batch: 5 Total samples processed: 192 Loss: 0.021959275007247925
# Train Epoch: 11 Batch: 6 Total samples processed: 224 Loss: 0.02584581822156906
# Train Epoch: 12 Batch: 0 Total samples processed: 32 Loss: 0.018635321408510208
# Train Epoch: 12 Batch: 1 Total samples processed: 64 Loss: 0.02150769531726837
# Train Epoch: 12 Batch: 2 Total samples processed: 96 Loss: 0.021192608401179314
# Train Epoch: 12 Batch: 3 Total samples processed: 128 Loss: 0.022018052637577057
# Train Epoch: 12 Batch: 4 Total samples processed: 160 Loss: 0.021205926313996315
# Train Epoch: 12 Batch: 5 Total samples processed: 192 Loss: 0.021490437909960747
# Train Epoch: 12 Batch: 6 Total samples processed: 224 Loss: 0.0140990624204278
# Train Epoch: 13 Batch: 0 Total samples processed: 32 Loss: 0.023842766880989075
# Train Epoch: 13 Batch: 1 Total samples processed: 64 Loss: 0.020376915112137794
# Train Epoch: 13 Batch: 2 Total samples processed: 96 Loss: 0.020604422315955162
# Train Epoch: 13 Batch: 3 Total samples processed: 128 Loss: 0.02159636840224266
# Train Epoch: 13 Batch: 4 Total samples processed: 160 Loss: 0.01929229125380516
# Train Epoch: 13 Batch: 5 Total samples processed: 192 Loss: 0.018600955605506897
# Train Epoch: 13 Batch: 6 Total samples processed: 224 Loss: 0.022810254245996475
# Train Epoch: 14 Batch: 0 Total samples processed: 32 Loss: 0.01921735145151615
# Train Epoch: 14 Batch: 1 Total samples processed: 64 Loss: 0.02169112302362919
# Train Epoch: 14 Batch: 2 Total samples processed: 96 Loss: 0.02189798653125763
# Train Epoch: 14 Batch: 3 Total samples processed: 128 Loss: 0.022086191922426224
# Train Epoch: 14 Batch: 4 Total samples processed: 160 Loss: 0.021042585372924805
# Train Epoch: 14 Batch: 5 Total samples processed: 192 Loss: 0.019110333174467087
# Train Epoch: 14 Batch: 6 Total samples processed: 224 Loss: 0.01642528362572193
# Train Epoch: 15 Batch: 0 Total samples processed: 32 Loss: 0.022791855037212372
# Train Epoch: 15 Batch: 1 Total samples processed: 64 Loss: 0.021573204547166824
# Train Epoch: 15 Batch: 2 Total samples processed: 96 Loss: 0.02024957165122032
# Train Epoch: 15 Batch: 3 Total samples processed: 128 Loss: 0.020324582234025
# Train Epoch: 15 Batch: 4 Total samples processed: 160 Loss: 0.020445700734853745
# Train Epoch: 15 Batch: 5 Total samples processed: 192 Loss: 0.018624594435095787
# Train Epoch: 15 Batch: 6 Total samples processed: 224 Loss: 0.018863549456000328
# Train Epoch: 16 Batch: 0 Total samples processed: 32 Loss: 0.02043377049267292
# Train Epoch: 16 Batch: 1 Total samples processed: 64 Loss: 0.02116766758263111
# Train Epoch: 16 Batch: 2 Total samples processed: 96 Loss: 0.020847830921411514
# Train Epoch: 16 Batch: 3 Total samples processed: 128 Loss: 0.019595280289649963
# Train Epoch: 16 Batch: 4 Total samples processed: 160 Loss: 0.020759854465723038
# Train Epoch: 16 Batch: 5 Total samples processed: 192 Loss: 0.020109083503484726
# Train Epoch: 16 Batch: 6 Total samples processed: 224 Loss: 0.02008376456797123
# Train Epoch: 17 Batch: 0 Total samples processed: 32 Loss: 0.020324159413576126
# Train Epoch: 17 Batch: 1 Total samples processed: 64 Loss: 0.017387064173817635
# Train Epoch: 17 Batch: 2 Total samples processed: 96 Loss: 0.021764501929283142
# Train Epoch: 17 Batch: 3 Total samples processed: 128 Loss: 0.023710155859589577
# Train Epoch: 17 Batch: 4 Total samples processed: 160 Loss: 0.019058069214224815
# Train Epoch: 17 Batch: 5 Total samples processed: 192 Loss: 0.020104236900806427
# Train Epoch: 17 Batch: 6 Total samples processed: 224 Loss: 0.020999470725655556
# Train Epoch: 18 Batch: 0 Total samples processed: 32 Loss: 0.016361478716135025
# Train Epoch: 18 Batch: 1 Total samples processed: 64 Loss: 0.020407389849424362
# Train Epoch: 18 Batch: 2 Total samples processed: 96 Loss: 0.021063391119241714
# Train Epoch: 18 Batch: 3 Total samples processed: 128 Loss: 0.022941669449210167
# Train Epoch: 18 Batch: 4 Total samples processed: 160 Loss: 0.019917184486985207
# Train Epoch: 18 Batch: 5 Total samples processed: 192 Loss: 0.020098187029361725
# Train Epoch: 18 Batch: 6 Total samples processed: 224 Loss: 0.020670544356107712
# Train Epoch: 19 Batch: 0 Total samples processed: 32 Loss: 0.022213658317923546
# Train Epoch: 19 Batch: 1 Total samples processed: 64 Loss: 0.018092598766088486
# Train Epoch: 19 Batch: 2 Total samples processed: 96 Loss: 0.018876386806368828
# Train Epoch: 19 Batch: 3 Total samples processed: 128 Loss: 0.01888061687350273
# Train Epoch: 19 Batch: 4 Total samples processed: 160 Loss: 0.022633560001850128
# Train Epoch: 19 Batch: 5 Total samples processed: 192 Loss: 0.02043766900897026
# Train Epoch: 19 Batch: 6 Total samples processed: 224 Loss: 0.018889417871832848
# Train Epoch: 20 Batch: 0 Total samples processed: 32 Loss: 0.018427733331918716
# Train Epoch: 20 Batch: 1 Total samples processed: 64 Loss: 0.020329995080828667
# Train Epoch: 20 Batch: 2 Total samples processed: 96 Loss: 0.02262207865715027
# Train Epoch: 20 Batch: 3 Total samples processed: 128 Loss: 0.019766345620155334
# Train Epoch: 20 Batch: 4 Total samples processed: 160 Loss: 0.019009048119187355
# Train Epoch: 20 Batch: 5 Total samples processed: 192 Loss: 0.023000244051218033
# Train Epoch: 20 Batch: 6 Total samples processed: 224 Loss: 0.016172053292393684
# Train Epoch: 21 Batch: 0 Total samples processed: 32 Loss: 0.021966271102428436
# Train Epoch: 21 Batch: 1 Total samples processed: 64 Loss: 0.018651483580470085
# Train Epoch: 21 Batch: 2 Total samples processed: 96 Loss: 0.022222721949219704
# Train Epoch: 21 Batch: 3 Total samples processed: 128 Loss: 0.02073867991566658
# Train Epoch: 21 Batch: 4 Total samples processed: 160 Loss: 0.017553633078932762
# Train Epoch: 21 Batch: 5 Total samples processed: 192 Loss: 0.019204547628760338
# Train Epoch: 21 Batch: 6 Total samples processed: 224 Loss: 0.020599067211151123
# Train Epoch: 22 Batch: 0 Total samples processed: 32 Loss: 0.02033914253115654
# Train Epoch: 22 Batch: 1 Total samples processed: 64 Loss: 0.019858483225107193
# Train Epoch: 22 Batch: 2 Total samples processed: 96 Loss: 0.022789819166064262
# Train Epoch: 22 Batch: 3 Total samples processed: 128 Loss: 0.018713563680648804
# Train Epoch: 22 Batch: 4 Total samples processed: 160 Loss: 0.022501565515995026
# Train Epoch: 22 Batch: 5 Total samples processed: 192 Loss: 0.016023868694901466
# Train Epoch: 22 Batch: 6 Total samples processed: 224 Loss: 0.019638871774077415
# Train Epoch: 23 Batch: 0 Total samples processed: 32 Loss: 0.019218238070607185
# Train Epoch: 23 Batch: 1 Total samples processed: 64 Loss: 0.018795156851410866
# Train Epoch: 23 Batch: 2 Total samples processed: 96 Loss: 0.019122347235679626
# Train Epoch: 23 Batch: 3 Total samples processed: 128 Loss: 0.02116687409579754
# Train Epoch: 23 Batch: 4 Total samples processed: 160 Loss: 0.02099154330790043
# Train Epoch: 23 Batch: 5 Total samples processed: 192 Loss: 0.019811242818832397
# Train Epoch: 23 Batch: 6 Total samples processed: 224 Loss: 0.019020207226276398
# Train Epoch: 24 Batch: 0 Total samples processed: 32 Loss: 0.01921990141272545
# Train Epoch: 24 Batch: 1 Total samples processed: 64 Loss: 0.01848756894469261
# Train Epoch: 24 Batch: 2 Total samples processed: 96 Loss: 0.01967332512140274
# Train Epoch: 24 Batch: 3 Total samples processed: 128 Loss: 0.022121071815490723
# Train Epoch: 24 Batch: 4 Total samples processed: 160 Loss: 0.019109303131699562
# Train Epoch: 24 Batch: 5 Total samples processed: 192 Loss: 0.02119729481637478
# Train Epoch: 24 Batch: 6 Total samples processed: 224 Loss: 0.019447200000286102
# Train Epoch: 25 Batch: 0 Total samples processed: 32 Loss: 0.020626546815037727
# Train Epoch: 25 Batch: 1 Total samples processed: 64 Loss: 0.019485626369714737
# Train Epoch: 25 Batch: 2 Total samples processed: 96 Loss: 0.019420200958848
# Train Epoch: 25 Batch: 3 Total samples processed: 128 Loss: 0.020145876333117485
# Train Epoch: 25 Batch: 4 Total samples processed: 160 Loss: 0.02164509706199169
# Train Epoch: 25 Batch: 5 Total samples processed: 192 Loss: 0.01912463828921318
# Train Epoch: 25 Batch: 6 Total samples processed: 224 Loss: 0.01584513485431671
# Train Epoch: 26 Batch: 0 Total samples processed: 32 Loss: 0.021342094987630844
# Train Epoch: 26 Batch: 1 Total samples processed: 64 Loss: 0.020430216565728188
# Train Epoch: 26 Batch: 2 Total samples processed: 96 Loss: 0.01861642859876156
# Train Epoch: 26 Batch: 3 Total samples processed: 128 Loss: 0.018130360171198845
# Train Epoch: 26 Batch: 4 Total samples processed: 160 Loss: 0.0210876502096653
# Train Epoch: 26 Batch: 5 Total samples processed: 192 Loss: 0.01990228332579136
# Train Epoch: 26 Batch: 6 Total samples processed: 224 Loss: 0.022561416029930115
# Train Epoch: 27 Batch: 0 Total samples processed: 32 Loss: 0.019725589081645012
# Train Epoch: 27 Batch: 1 Total samples processed: 64 Loss: 0.020781384781003
# Train Epoch: 27 Batch: 2 Total samples processed: 96 Loss: 0.019147498533129692
# Train Epoch: 27 Batch: 3 Total samples processed: 128 Loss: 0.020606843754649162
# Train Epoch: 27 Batch: 4 Total samples processed: 160 Loss: 0.019437605515122414
# Train Epoch: 27 Batch: 5 Total samples processed: 192 Loss: 0.018978508189320564
# Train Epoch: 27 Batch: 6 Total samples processed: 224 Loss: 0.020723532885313034
# Train Epoch: 28 Batch: 0 Total samples processed: 32 Loss: 0.021784435957670212
# Train Epoch: 28 Batch: 1 Total samples processed: 64 Loss: 0.019079791381955147
# Train Epoch: 28 Batch: 2 Total samples processed: 96 Loss: 0.019445039331912994
# Train Epoch: 28 Batch: 3 Total samples processed: 128 Loss: 0.020702514797449112
# Train Epoch: 28 Batch: 4 Total samples processed: 160 Loss: 0.01751856319606304
# Train Epoch: 28 Batch: 5 Total samples processed: 192 Loss: 0.018021807074546814
# Train Epoch: 28 Batch: 6 Total samples processed: 224 Loss: 0.026110930368304253
# Train Epoch: 29 Batch: 0 Total samples processed: 32 Loss: 0.019254716113209724
# Train Epoch: 29 Batch: 1 Total samples processed: 64 Loss: 0.020785856992006302
# Train Epoch: 29 Batch: 2 Total samples processed: 96 Loss: 0.02030879072844982
# Train Epoch: 29 Batch: 3 Total samples processed: 128 Loss: 0.01967628300189972
# Train Epoch: 29 Batch: 4 Total samples processed: 160 Loss: 0.02044924534857273
# Train Epoch: 29 Batch: 5 Total samples processed: 192 Loss: 0.019971048459410667
# Train Epoch: 29 Batch: 6 Total samples processed: 224 Loss: 0.019226953387260437
# Train Epoch: 30 Batch: 0 Total samples processed: 32 Loss: 0.019529279321432114
# Train Epoch: 30 Batch: 1 Total samples processed: 64 Loss: 0.02023201994597912
# Train Epoch: 30 Batch: 2 Total samples processed: 96 Loss: 0.018375685438513756
# Train Epoch: 30 Batch: 3 Total samples processed: 128 Loss: 0.020350100472569466
# Train Epoch: 30 Batch: 4 Total samples processed: 160 Loss: 0.02104627713561058
# Train Epoch: 30 Batch: 5 Total samples processed: 192 Loss: 0.020147167146205902
# Train Epoch: 30 Batch: 6 Total samples processed: 224 Loss: 0.022279981523752213
# Train Epoch: 31 Batch: 0 Total samples processed: 32 Loss: 0.02042095549404621
# Train Epoch: 31 Batch: 1 Total samples processed: 64 Loss: 0.016170309856534004
# Train Epoch: 31 Batch: 2 Total samples processed: 96 Loss: 0.02078169956803322
# Train Epoch: 31 Batch: 3 Total samples processed: 128 Loss: 0.021947110071778297
# Train Epoch: 31 Batch: 4 Total samples processed: 160 Loss: 0.020416030660271645
# Train Epoch: 31 Batch: 5 Total samples processed: 192 Loss: 0.020678894594311714
# Train Epoch: 31 Batch: 6 Total samples processed: 224 Loss: 0.01929023675620556
# Train Epoch: 32 Batch: 0 Total samples processed: 32 Loss: 0.021613409742712975
# Train Epoch: 32 Batch: 1 Total samples processed: 64 Loss: 0.01457157637923956
# Train Epoch: 32 Batch: 2 Total samples processed: 96 Loss: 0.020455600693821907
# Train Epoch: 32 Batch: 3 Total samples processed: 128 Loss: 0.019811376929283142
# Train Epoch: 32 Batch: 4 Total samples processed: 160 Loss: 0.020032860338687897
# Train Epoch: 32 Batch: 5 Total samples processed: 192 Loss: 0.02082025445997715
# Train Epoch: 32 Batch: 6 Total samples processed: 224 Loss: 0.024280337616801262
# Train Epoch: 33 Batch: 0 Total samples processed: 32 Loss: 0.019783370196819305
# Train Epoch: 33 Batch: 1 Total samples processed: 64 Loss: 0.017163394019007683
# Train Epoch: 33 Batch: 2 Total samples processed: 96 Loss: 0.018896188586950302
# Train Epoch: 33 Batch: 3 Total samples processed: 128 Loss: 0.02121315337717533
# Train Epoch: 33 Batch: 4 Total samples processed: 160 Loss: 0.021922726184129715
# Train Epoch: 33 Batch: 5 Total samples processed: 192 Loss: 0.019698524847626686
# Train Epoch: 33 Batch: 6 Total samples processed: 224 Loss: 0.020547965541481972
# Train Epoch: 34 Batch: 0 Total samples processed: 32 Loss: 0.020812487229704857
# Train Epoch: 34 Batch: 1 Total samples processed: 64 Loss: 0.01795816607773304
# Train Epoch: 34 Batch: 2 Total samples processed: 96 Loss: 0.020338892936706543
# Train Epoch: 34 Batch: 3 Total samples processed: 128 Loss: 0.02056816592812538
# Train Epoch: 34 Batch: 4 Total samples processed: 160 Loss: 0.020490875467658043
# Train Epoch: 34 Batch: 5 Total samples processed: 192 Loss: 0.019236693158745766
# Train Epoch: 34 Batch: 6 Total samples processed: 224 Loss: 0.01597374677658081
# Train Epoch: 35 Batch: 0 Total samples processed: 32 Loss: 0.019595175981521606
# Train Epoch: 35 Batch: 1 Total samples processed: 64 Loss: 0.020247403532266617
# Train Epoch: 35 Batch: 2 Total samples processed: 96 Loss: 0.019313422963023186
# Train Epoch: 35 Batch: 3 Total samples processed: 128 Loss: 0.019208380952477455
# Train Epoch: 35 Batch: 4 Total samples processed: 160 Loss: 0.021841786801815033
# Train Epoch: 35 Batch: 5 Total samples processed: 192 Loss: 0.017627127468585968
# Train Epoch: 35 Batch: 6 Total samples processed: 224 Loss: 0.024296274408698082
# Train Epoch: 36 Batch: 0 Total samples processed: 32 Loss: 0.0188080333173275
# Train Epoch: 36 Batch: 1 Total samples processed: 64 Loss: 0.022114397957921028
# Train Epoch: 36 Batch: 2 Total samples processed: 96 Loss: 0.019860301166772842
# Train Epoch: 36 Batch: 3 Total samples processed: 128 Loss: 0.019475016742944717
# Train Epoch: 36 Batch: 4 Total samples processed: 160 Loss: 0.018895864486694336
# Train Epoch: 36 Batch: 5 Total samples processed: 192 Loss: 0.021032007411122322
# Train Epoch: 36 Batch: 6 Total samples processed: 224 Loss: 0.01686340570449829
# Train Epoch: 37 Batch: 0 Total samples processed: 32 Loss: 0.019423017278313637
# Train Epoch: 37 Batch: 1 Total samples processed: 64 Loss: 0.018002184107899666
# Train Epoch: 37 Batch: 2 Total samples processed: 96 Loss: 0.019450083374977112
# Train Epoch: 37 Batch: 3 Total samples processed: 128 Loss: 0.021734774112701416
# Train Epoch: 37 Batch: 4 Total samples processed: 160 Loss: 0.02027476392686367
# Train Epoch: 37 Batch: 5 Total samples processed: 192 Loss: 0.02175363153219223
# Train Epoch: 37 Batch: 6 Total samples processed: 224 Loss: 0.017189573496580124
# Train Epoch: 38 Batch: 0 Total samples processed: 32 Loss: 0.018919648602604866
# Train Epoch: 38 Batch: 1 Total samples processed: 64 Loss: 0.02191924676299095
# Train Epoch: 38 Batch: 2 Total samples processed: 96 Loss: 0.01984427683055401
# Train Epoch: 38 Batch: 3 Total samples processed: 128 Loss: 0.01985401287674904
# Train Epoch: 38 Batch: 4 Total samples processed: 160 Loss: 0.019939176738262177
# Train Epoch: 38 Batch: 5 Total samples processed: 192 Loss: 0.019801922142505646
# Train Epoch: 38 Batch: 6 Total samples processed: 224 Loss: 0.021891646087169647
# Train Epoch: 39 Batch: 0 Total samples processed: 32 Loss: 0.021747922524809837
# Train Epoch: 39 Batch: 1 Total samples processed: 64 Loss: 0.018868345767259598
# Train Epoch: 39 Batch: 2 Total samples processed: 96 Loss: 0.019515149295330048
# Train Epoch: 39 Batch: 3 Total samples processed: 128 Loss: 0.01866770349442959
# Train Epoch: 39 Batch: 4 Total samples processed: 160 Loss: 0.018931690603494644
# Train Epoch: 39 Batch: 5 Total samples processed: 192 Loss: 0.02304607257246971
# Train Epoch: 39 Batch: 6 Total samples processed: 224 Loss: 0.01769379898905754
# Train Epoch: 40 Batch: 0 Total samples processed: 32 Loss: 0.019591519609093666
# Train Epoch: 40 Batch: 1 Total samples processed: 64 Loss: 0.017741220071911812
# Train Epoch: 40 Batch: 2 Total samples processed: 96 Loss: 0.020739790052175522
# Train Epoch: 40 Batch: 3 Total samples processed: 128 Loss: 0.020348424091935158
# Train Epoch: 40 Batch: 4 Total samples processed: 160 Loss: 0.01932585798203945
# Train Epoch: 40 Batch: 5 Total samples processed: 192 Loss: 0.020304137840867043
# Train Epoch: 40 Batch: 6 Total samples processed: 224 Loss: 0.024659214541316032
# Train Epoch: 41 Batch: 0 Total samples processed: 32 Loss: 0.020105455070734024
# Train Epoch: 41 Batch: 1 Total samples processed: 64 Loss: 0.02147083356976509
# Train Epoch: 41 Batch: 2 Total samples processed: 96 Loss: 0.018076419830322266
# Train Epoch: 41 Batch: 3 Total samples processed: 128 Loss: 0.02011716179549694
# Train Epoch: 41 Batch: 4 Total samples processed: 160 Loss: 0.019443858414888382
# Train Epoch: 41 Batch: 5 Total samples processed: 192 Loss: 0.019063808023929596
# Train Epoch: 41 Batch: 6 Total samples processed: 224 Loss: 0.02673858404159546
# Train Epoch: 42 Batch: 0 Total samples processed: 32 Loss: 0.018007058650255203
# Train Epoch: 42 Batch: 1 Total samples processed: 64 Loss: 0.02246662974357605
# Train Epoch: 42 Batch: 2 Total samples processed: 96 Loss: 0.01895975135266781
# Train Epoch: 42 Batch: 3 Total samples processed: 128 Loss: 0.0180327370762825
# Train Epoch: 42 Batch: 4 Total samples processed: 160 Loss: 0.022087154909968376
# Train Epoch: 42 Batch: 5 Total samples processed: 192 Loss: 0.02003343403339386
# Train Epoch: 42 Batch: 6 Total samples processed: 224 Loss: 0.022737590596079826
# Train Epoch: 43 Batch: 0 Total samples processed: 32 Loss: 0.020778538659214973
# Train Epoch: 43 Batch: 1 Total samples processed: 64 Loss: 0.018651055172085762
# Train Epoch: 43 Batch: 2 Total samples processed: 96 Loss: 0.020686564967036247
# Train Epoch: 43 Batch: 3 Total samples processed: 128 Loss: 0.02362707443535328
# Train Epoch: 43 Batch: 4 Total samples processed: 160 Loss: 0.018456779420375824
# Train Epoch: 43 Batch: 5 Total samples processed: 192 Loss: 0.016535090282559395
# Train Epoch: 43 Batch: 6 Total samples processed: 224 Loss: 0.026666810736060143
# Train Epoch: 44 Batch: 0 Total samples processed: 32 Loss: 0.019108546897768974
# Train Epoch: 44 Batch: 1 Total samples processed: 64 Loss: 0.020551301538944244
# Train Epoch: 44 Batch: 2 Total samples processed: 96 Loss: 0.019366107881069183
# Train Epoch: 44 Batch: 3 Total samples processed: 128 Loss: 0.019729727879166603
# Train Epoch: 44 Batch: 4 Total samples processed: 160 Loss: 0.02136080153286457
# Train Epoch: 44 Batch: 5 Total samples processed: 192 Loss: 0.018448375165462494
# Train Epoch: 44 Batch: 6 Total samples processed: 224 Loss: 0.027559176087379456
# Train Epoch: 45 Batch: 0 Total samples processed: 32 Loss: 0.019532816484570503
# Train Epoch: 45 Batch: 1 Total samples processed: 64 Loss: 0.020964140072464943
# Train Epoch: 45 Batch: 2 Total samples processed: 96 Loss: 0.019268013536930084
# Train Epoch: 45 Batch: 3 Total samples processed: 128 Loss: 0.02058037370443344
# Train Epoch: 45 Batch: 4 Total samples processed: 160 Loss: 0.019378673285245895
# Train Epoch: 45 Batch: 5 Total samples processed: 192 Loss: 0.018960045650601387
# Train Epoch: 45 Batch: 6 Total samples processed: 224 Loss: 0.02003295347094536
# Train Epoch: 46 Batch: 0 Total samples processed: 32 Loss: 0.01980479620397091
# Train Epoch: 46 Batch: 1 Total samples processed: 64 Loss: 0.019141945987939835
# Train Epoch: 46 Batch: 2 Total samples processed: 96 Loss: 0.020809801295399666
# Train Epoch: 46 Batch: 3 Total samples processed: 128 Loss: 0.018328746780753136
# Train Epoch: 46 Batch: 4 Total samples processed: 160 Loss: 0.01984231360256672
# Train Epoch: 46 Batch: 5 Total samples processed: 192 Loss: 0.019060993567109108
# Train Epoch: 46 Batch: 6 Total samples processed: 224 Loss: 0.022063931450247765
# Train Epoch: 47 Batch: 0 Total samples processed: 32 Loss: 0.020097285509109497
# Train Epoch: 47 Batch: 1 Total samples processed: 64 Loss: 0.021650103852152824
# Train Epoch: 47 Batch: 2 Total samples processed: 96 Loss: 0.01785886660218239
# Train Epoch: 47 Batch: 3 Total samples processed: 128 Loss: 0.020197775214910507
# Train Epoch: 47 Batch: 4 Total samples processed: 160 Loss: 0.017251065000891685
# Train Epoch: 47 Batch: 5 Total samples processed: 192 Loss: 0.020586363971233368
# Train Epoch: 47 Batch: 6 Total samples processed: 224 Loss: 0.024026919156312943
# Train Epoch: 48 Batch: 0 Total samples processed: 32 Loss: 0.018060481175780296
# Train Epoch: 48 Batch: 1 Total samples processed: 64 Loss: 0.02042827196419239
# Train Epoch: 48 Batch: 2 Total samples processed: 96 Loss: 0.017995206639170647
# Train Epoch: 48 Batch: 3 Total samples processed: 128 Loss: 0.020542096346616745
# Train Epoch: 48 Batch: 4 Total samples processed: 160 Loss: 0.018489737063646317
# Train Epoch: 48 Batch: 5 Total samples processed: 192 Loss: 0.02471013367176056
# Train Epoch: 48 Batch: 6 Total samples processed: 224 Loss: 0.02059839479625225
# Train Epoch: 49 Batch: 0 Total samples processed: 32 Loss: 0.017464181408286095
# Train Epoch: 49 Batch: 1 Total samples processed: 64 Loss: 0.019289351999759674
# Train Epoch: 49 Batch: 2 Total samples processed: 96 Loss: 0.018598858267068863
# Train Epoch: 49 Batch: 3 Total samples processed: 128 Loss: 0.021827682852745056
# Train Epoch: 49 Batch: 4 Total samples processed: 160 Loss: 0.019948914647102356
# Train Epoch: 49 Batch: 5 Total samples processed: 192 Loss: 0.021272430196404457
# Train Epoch: 49 Batch: 6 Total samples processed: 224 Loss: 0.02930380590260029
# Train Epoch: 50 Batch: 0 Total samples processed: 32 Loss: 0.01825273036956787
# Train Epoch: 50 Batch: 1 Total samples processed: 64 Loss: 0.020408187061548233
# Train Epoch: 50 Batch: 2 Total samples processed: 96 Loss: 0.019719045609235764
# Train Epoch: 50 Batch: 3 Total samples processed: 128 Loss: 0.020323876291513443
# Train Epoch: 50 Batch: 4 Total samples processed: 160 Loss: 0.019115351140499115
# Train Epoch: 50 Batch: 5 Total samples processed: 192 Loss: 0.02245672419667244
# Train Epoch: 50 Batch: 6 Total samples processed: 224 Loss: 0.02286493219435215
# Train Epoch: 51 Batch: 0 Total samples processed: 32 Loss: 0.020512066781520844
# Train Epoch: 51 Batch: 1 Total samples processed: 64 Loss: 0.017219439148902893
# Train Epoch: 51 Batch: 2 Total samples processed: 96 Loss: 0.018660183995962143
# Train Epoch: 51 Batch: 3 Total samples processed: 128 Loss: 0.021019024774432182
# Train Epoch: 51 Batch: 4 Total samples processed: 160 Loss: 0.020446602255105972
# Train Epoch: 51 Batch: 5 Total samples processed: 192 Loss: 0.02115667797625065
# Train Epoch: 51 Batch: 6 Total samples processed: 224 Loss: 0.02924746833741665
# Train Epoch: 52 Batch: 0 Total samples processed: 32 Loss: 0.021457282826304436
# Train Epoch: 52 Batch: 1 Total samples processed: 64 Loss: 0.024003930389881134
# Train Epoch: 52 Batch: 2 Total samples processed: 96 Loss: 0.020226549357175827
# Train Epoch: 52 Batch: 3 Total samples processed: 128 Loss: 0.021697362884879112
# Train Epoch: 52 Batch: 4 Total samples processed: 160 Loss: 0.019990859553217888
# Train Epoch: 52 Batch: 5 Total samples processed: 192 Loss: 0.0186637993901968
# Train Epoch: 52 Batch: 6 Total samples processed: 224 Loss: 0.015908872708678246
# Train Epoch: 53 Batch: 0 Total samples processed: 32 Loss: 0.02217038720846176
# Train Epoch: 53 Batch: 1 Total samples processed: 64 Loss: 0.020384028553962708
# Train Epoch: 53 Batch: 2 Total samples processed: 96 Loss: 0.01904832385480404
# Train Epoch: 53 Batch: 3 Total samples processed: 128 Loss: 0.02081814594566822
# Train Epoch: 53 Batch: 4 Total samples processed: 160 Loss: 0.020489700138568878
# Train Epoch: 53 Batch: 5 Total samples processed: 192 Loss: 0.018564116209745407
# Train Epoch: 53 Batch: 6 Total samples processed: 224 Loss: 0.02198629267513752
# Train Epoch: 54 Batch: 0 Total samples processed: 32 Loss: 0.02153981849551201
# Train Epoch: 54 Batch: 1 Total samples processed: 64 Loss: 0.02141963131725788
# Train Epoch: 54 Batch: 2 Total samples processed: 96 Loss: 0.017761051654815674
# Train Epoch: 54 Batch: 3 Total samples processed: 128 Loss: 0.020649675279855728
# Train Epoch: 54 Batch: 4 Total samples processed: 160 Loss: 0.019522352144122124
# Train Epoch: 54 Batch: 5 Total samples processed: 192 Loss: 0.018392745405435562
# Train Epoch: 54 Batch: 6 Total samples processed: 224 Loss: 0.024660509079694748
# Train Epoch: 55 Batch: 0 Total samples processed: 32 Loss: 0.016846219077706337
# Train Epoch: 55 Batch: 1 Total samples processed: 64 Loss: 0.021485213190317154
# Train Epoch: 55 Batch: 2 Total samples processed: 96 Loss: 0.02076042629778385
# Train Epoch: 55 Batch: 3 Total samples processed: 128 Loss: 0.019687548279762268
# Train Epoch: 55 Batch: 4 Total samples processed: 160 Loss: 0.01875416934490204
# Train Epoch: 55 Batch: 5 Total samples processed: 192 Loss: 0.022540830075740814
# Train Epoch: 55 Batch: 6 Total samples processed: 224 Loss: 0.019348416477441788
# Train Epoch: 56 Batch: 0 Total samples processed: 32 Loss: 0.019980374723672867
# Train Epoch: 56 Batch: 1 Total samples processed: 64 Loss: 0.017134571447968483
# Train Epoch: 56 Batch: 2 Total samples processed: 96 Loss: 0.01940372958779335
# Train Epoch: 56 Batch: 3 Total samples processed: 128 Loss: 0.020104488357901573
# Train Epoch: 56 Batch: 4 Total samples processed: 160 Loss: 0.018934302031993866
# Train Epoch: 56 Batch: 5 Total samples processed: 192 Loss: 0.021599633619189262
# Train Epoch: 56 Batch: 6 Total samples processed: 224 Loss: 0.029680874198675156
# Train Epoch: 57 Batch: 0 Total samples processed: 32 Loss: 0.01893678866326809
# Train Epoch: 57 Batch: 1 Total samples processed: 64 Loss: 0.019413696601986885
# Train Epoch: 57 Batch: 2 Total samples processed: 96 Loss: 0.01885935291647911
# Train Epoch: 57 Batch: 3 Total samples processed: 128 Loss: 0.019467521458864212
# Train Epoch: 57 Batch: 4 Total samples processed: 160 Loss: 0.021029992029070854
# Train Epoch: 57 Batch: 5 Total samples processed: 192 Loss: 0.02009262889623642
# Train Epoch: 57 Batch: 6 Total samples processed: 224 Loss: 0.024045081809163094
# Train Epoch: 58 Batch: 0 Total samples processed: 32 Loss: 0.018813421949744225
# Train Epoch: 58 Batch: 1 Total samples processed: 64 Loss: 0.018595797941088676
# Train Epoch: 58 Batch: 2 Total samples processed: 96 Loss: 0.017669832333922386
# Train Epoch: 58 Batch: 3 Total samples processed: 128 Loss: 0.018474046140909195
# Train Epoch: 58 Batch: 4 Total samples processed: 160 Loss: 0.022496836259961128
# Train Epoch: 58 Batch: 5 Total samples processed: 192 Loss: 0.02206275798380375
# Train Epoch: 58 Batch: 6 Total samples processed: 224 Loss: 0.027174964547157288
# Train Epoch: 59 Batch: 0 Total samples processed: 32 Loss: 0.018983477726578712
# Train Epoch: 59 Batch: 1 Total samples processed: 64 Loss: 0.021220240741968155
# Train Epoch: 59 Batch: 2 Total samples processed: 96 Loss: 0.017335887998342514
# Train Epoch: 59 Batch: 3 Total samples processed: 128 Loss: 0.019984794780611992
# Train Epoch: 59 Batch: 4 Total samples processed: 160 Loss: 0.01866910047829151
# Train Epoch: 59 Batch: 5 Total samples processed: 192 Loss: 0.021698419004678726
# Train Epoch: 59 Batch: 6 Total samples processed: 224 Loss: 0.021748805418610573
# Train Epoch: 60 Batch: 0 Total samples processed: 32 Loss: 0.02119307592511177
# Train Epoch: 60 Batch: 1 Total samples processed: 64 Loss: 0.019985277205705643
# Train Epoch: 60 Batch: 2 Total samples processed: 96 Loss: 0.017936183139681816
# Train Epoch: 60 Batch: 3 Total samples processed: 128 Loss: 0.01939534582197666
# Train Epoch: 60 Batch: 4 Total samples processed: 160 Loss: 0.01959133706986904
# Train Epoch: 60 Batch: 5 Total samples processed: 192 Loss: 0.019869057461619377
# Train Epoch: 60 Batch: 6 Total samples processed: 224 Loss: 0.01967601850628853
# Train Epoch: 61 Batch: 0 Total samples processed: 32 Loss: 0.019703885540366173
# Train Epoch: 61 Batch: 1 Total samples processed: 64 Loss: 0.017789078876376152
# Train Epoch: 61 Batch: 2 Total samples processed: 96 Loss: 0.02035897970199585
# Train Epoch: 61 Batch: 3 Total samples processed: 128 Loss: 0.019222572445869446
# Train Epoch: 61 Batch: 4 Total samples processed: 160 Loss: 0.020636850968003273
# Train Epoch: 61 Batch: 5 Total samples processed: 192 Loss: 0.020639754831790924
# Train Epoch: 61 Batch: 6 Total samples processed: 224 Loss: 0.01625976711511612
# Train Epoch: 62 Batch: 0 Total samples processed: 32 Loss: 0.018670225515961647
# Train Epoch: 62 Batch: 1 Total samples processed: 64 Loss: 0.01781109906733036
# Train Epoch: 62 Batch: 2 Total samples processed: 96 Loss: 0.017538009211421013
# Train Epoch: 62 Batch: 3 Total samples processed: 128 Loss: 0.017521148547530174
# Train Epoch: 62 Batch: 4 Total samples processed: 160 Loss: 0.023833727464079857
# Train Epoch: 62 Batch: 5 Total samples processed: 192 Loss: 0.021911615505814552
# Train Epoch: 62 Batch: 6 Total samples processed: 224 Loss: 0.016681911423802376
# Train Epoch: 63 Batch: 0 Total samples processed: 32 Loss: 0.0189405158162117
# Train Epoch: 63 Batch: 1 Total samples processed: 64 Loss: 0.020123807713389397
# Train Epoch: 63 Batch: 2 Total samples processed: 96 Loss: 0.02047065459191799
# Train Epoch: 63 Batch: 3 Total samples processed: 128 Loss: 0.020880552008748055
# Train Epoch: 63 Batch: 4 Total samples processed: 160 Loss: 0.018749382346868515
# Train Epoch: 63 Batch: 5 Total samples processed: 192 Loss: 0.018828941509127617
# Train Epoch: 63 Batch: 6 Total samples processed: 224 Loss: 0.016279904171824455
# Train Epoch: 64 Batch: 0 Total samples processed: 32 Loss: 0.019803380593657494
# Train Epoch: 64 Batch: 1 Total samples processed: 64 Loss: 0.017726058140397072
# Train Epoch: 64 Batch: 2 Total samples processed: 96 Loss: 0.017520753666758537
# Train Epoch: 64 Batch: 3 Total samples processed: 128 Loss: 0.01998046599328518
# Train Epoch: 64 Batch: 4 Total samples processed: 160 Loss: 0.021063104271888733
# Train Epoch: 64 Batch: 5 Total samples processed: 192 Loss: 0.02017747052013874
# Train Epoch: 64 Batch: 6 Total samples processed: 224 Loss: 0.018034057691693306
# Train Epoch: 65 Batch: 0 Total samples processed: 32 Loss: 0.0177640188485384
# Train Epoch: 65 Batch: 1 Total samples processed: 64 Loss: 0.01988542452454567
# Train Epoch: 65 Batch: 2 Total samples processed: 96 Loss: 0.018798748031258583
# Train Epoch: 65 Batch: 3 Total samples processed: 128 Loss: 0.015428798273205757
# Train Epoch: 65 Batch: 4 Total samples processed: 160 Loss: 0.023772453889250755
# Train Epoch: 65 Batch: 5 Total samples processed: 192 Loss: 0.021266739815473557
# Train Epoch: 65 Batch: 6 Total samples processed: 224 Loss: 0.018813852220773697
# Train Epoch: 66 Batch: 0 Total samples processed: 32 Loss: 0.01818695105612278
# Train Epoch: 66 Batch: 1 Total samples processed: 64 Loss: 0.019753536209464073
# Train Epoch: 66 Batch: 2 Total samples processed: 96 Loss: 0.01915430650115013
# Train Epoch: 66 Batch: 3 Total samples processed: 128 Loss: 0.022591188549995422
# Train Epoch: 66 Batch: 4 Total samples processed: 160 Loss: 0.01805953122675419
# Train Epoch: 66 Batch: 5 Total samples processed: 192 Loss: 0.017637206241488457
# Train Epoch: 66 Batch: 6 Total samples processed: 224 Loss: 0.019183054566383362
# Train Epoch: 67 Batch: 0 Total samples processed: 32 Loss: 0.020661557093262672
# Train Epoch: 67 Batch: 1 Total samples processed: 64 Loss: 0.018216973170638084
# Train Epoch: 67 Batch: 2 Total samples processed: 96 Loss: 0.022044992074370384
# Train Epoch: 67 Batch: 3 Total samples processed: 128 Loss: 0.016518570482730865
# Train Epoch: 67 Batch: 4 Total samples processed: 160 Loss: 0.01960194855928421
# Train Epoch: 67 Batch: 5 Total samples processed: 192 Loss: 0.018417319282889366
# Train Epoch: 67 Batch: 6 Total samples processed: 224 Loss: 0.01710730604827404
# Train Epoch: 68 Batch: 0 Total samples processed: 32 Loss: 0.017528889700770378
# Train Epoch: 68 Batch: 1 Total samples processed: 64 Loss: 0.02073785848915577
# Train Epoch: 68 Batch: 2 Total samples processed: 96 Loss: 0.017972838133573532
# Train Epoch: 68 Batch: 3 Total samples processed: 128 Loss: 0.018464822322130203
# Train Epoch: 68 Batch: 4 Total samples processed: 160 Loss: 0.019412698224186897
# Train Epoch: 68 Batch: 5 Total samples processed: 192 Loss: 0.020056024193763733
# Train Epoch: 68 Batch: 6 Total samples processed: 224 Loss: 0.017611848190426826
# Train Epoch: 69 Batch: 0 Total samples processed: 32 Loss: 0.019266538321971893
# Train Epoch: 69 Batch: 1 Total samples processed: 64 Loss: 0.018049044534564018
# Train Epoch: 69 Batch: 2 Total samples processed: 96 Loss: 0.01801198348402977
# Train Epoch: 69 Batch: 3 Total samples processed: 128 Loss: 0.01875961944460869
# Train Epoch: 69 Batch: 4 Total samples processed: 160 Loss: 0.020117249339818954
# Train Epoch: 69 Batch: 5 Total samples processed: 192 Loss: 0.020782681182026863
# Train Epoch: 69 Batch: 6 Total samples processed: 224 Loss: 0.017138849943876266
# Train Epoch: 70 Batch: 0 Total samples processed: 32 Loss: 0.017857348546385765
# Train Epoch: 70 Batch: 1 Total samples processed: 64 Loss: 0.02345104329288006
# Train Epoch: 70 Batch: 2 Total samples processed: 96 Loss: 0.016502201557159424
# Train Epoch: 70 Batch: 3 Total samples processed: 128 Loss: 0.01902812160551548
# Train Epoch: 70 Batch: 4 Total samples processed: 160 Loss: 0.020480545237660408
# Train Epoch: 70 Batch: 5 Total samples processed: 192 Loss: 0.01831403560936451
# Train Epoch: 70 Batch: 6 Total samples processed: 224 Loss: 0.016581209376454353
# Train Epoch: 71 Batch: 0 Total samples processed: 32 Loss: 0.019464461132884026
# Train Epoch: 71 Batch: 1 Total samples processed: 64 Loss: 0.01777522824704647
# Train Epoch: 71 Batch: 2 Total samples processed: 96 Loss: 0.02074994146823883
# Train Epoch: 71 Batch: 3 Total samples processed: 128 Loss: 0.018924012780189514
# Train Epoch: 71 Batch: 4 Total samples processed: 160 Loss: 0.016902176663279533
# Train Epoch: 71 Batch: 5 Total samples processed: 192 Loss: 0.02088570035994053
# Train Epoch: 71 Batch: 6 Total samples processed: 224 Loss: 0.020883027464151382
# Train Epoch: 72 Batch: 0 Total samples processed: 32 Loss: 0.018612368032336235
# Train Epoch: 72 Batch: 1 Total samples processed: 64 Loss: 0.0190705768764019
# Train Epoch: 72 Batch: 2 Total samples processed: 96 Loss: 0.020127158612012863
# Train Epoch: 72 Batch: 3 Total samples processed: 128 Loss: 0.02158934623003006
# Train Epoch: 72 Batch: 4 Total samples processed: 160 Loss: 0.019268149510025978
# Train Epoch: 72 Batch: 5 Total samples processed: 192 Loss: 0.01792507991194725
# Train Epoch: 72 Batch: 6 Total samples processed: 224 Loss: 0.016510095447301865
# Train Epoch: 73 Batch: 0 Total samples processed: 32 Loss: 0.019236641004681587
# Train Epoch: 73 Batch: 1 Total samples processed: 64 Loss: 0.020175328478217125
# Train Epoch: 73 Batch: 2 Total samples processed: 96 Loss: 0.0206100232899189
# Train Epoch: 73 Batch: 3 Total samples processed: 128 Loss: 0.01947515644133091
# Train Epoch: 73 Batch: 4 Total samples processed: 160 Loss: 0.018467171117663383
# Train Epoch: 73 Batch: 5 Total samples processed: 192 Loss: 0.017645573243498802
# Train Epoch: 73 Batch: 6 Total samples processed: 224 Loss: 0.02356722392141819
# Train Epoch: 74 Batch: 0 Total samples processed: 32 Loss: 0.019492339342832565
# Train Epoch: 74 Batch: 1 Total samples processed: 64 Loss: 0.021044859662652016
# Train Epoch: 74 Batch: 2 Total samples processed: 96 Loss: 0.0193796269595623
# Train Epoch: 74 Batch: 3 Total samples processed: 128 Loss: 0.019601061940193176
# Train Epoch: 74 Batch: 4 Total samples processed: 160 Loss: 0.01873735524713993
# Train Epoch: 74 Batch: 5 Total samples processed: 192 Loss: 0.017904072999954224
# Train Epoch: 74 Batch: 6 Total samples processed: 224 Loss: 0.02163269929587841
# Train Epoch: 75 Batch: 0 Total samples processed: 32 Loss: 0.017859065905213356
# Train Epoch: 75 Batch: 1 Total samples processed: 64 Loss: 0.019467497244477272
# Train Epoch: 75 Batch: 2 Total samples processed: 96 Loss: 0.018190069124102592
# Train Epoch: 75 Batch: 3 Total samples processed: 128 Loss: 0.020610786974430084
# Train Epoch: 75 Batch: 4 Total samples processed: 160 Loss: 0.021036667749285698
# Train Epoch: 75 Batch: 5 Total samples processed: 192 Loss: 0.01813637651503086
# Train Epoch: 75 Batch: 6 Total samples processed: 224 Loss: 0.01871316507458687
# Train Epoch: 76 Batch: 0 Total samples processed: 32 Loss: 0.020371325314044952
# Train Epoch: 76 Batch: 1 Total samples processed: 64 Loss: 0.018066193908452988
# Train Epoch: 76 Batch: 2 Total samples processed: 96 Loss: 0.020542830228805542
# Train Epoch: 76 Batch: 3 Total samples processed: 128 Loss: 0.01815088838338852
# Train Epoch: 76 Batch: 4 Total samples processed: 160 Loss: 0.017296023666858673
# Train Epoch: 76 Batch: 5 Total samples processed: 192 Loss: 0.02081320434808731
# Train Epoch: 76 Batch: 6 Total samples processed: 224 Loss: 0.022991299629211426
# Train Epoch: 77 Batch: 0 Total samples processed: 32 Loss: 0.017598561942577362
# Train Epoch: 77 Batch: 1 Total samples processed: 64 Loss: 0.020457260310649872
# Train Epoch: 77 Batch: 2 Total samples processed: 96 Loss: 0.020869210362434387
# Train Epoch: 77 Batch: 3 Total samples processed: 128 Loss: 0.02061394788324833
# Train Epoch: 77 Batch: 4 Total samples processed: 160 Loss: 0.018499547615647316
# Train Epoch: 77 Batch: 5 Total samples processed: 192 Loss: 0.018237043172121048
# Train Epoch: 77 Batch: 6 Total samples processed: 224 Loss: 0.016326505690813065
# Train Epoch: 78 Batch: 0 Total samples processed: 32 Loss: 0.02048049308359623
# Train Epoch: 78 Batch: 1 Total samples processed: 64 Loss: 0.018744993954896927
# Train Epoch: 78 Batch: 2 Total samples processed: 96 Loss: 0.01712486334145069
# Train Epoch: 78 Batch: 3 Total samples processed: 128 Loss: 0.020659463480114937
# Train Epoch: 78 Batch: 4 Total samples processed: 160 Loss: 0.01852479763329029
# Train Epoch: 78 Batch: 5 Total samples processed: 192 Loss: 0.01829300820827484
# Train Epoch: 78 Batch: 6 Total samples processed: 224 Loss: 0.022369079291820526
# Train Epoch: 79 Batch: 0 Total samples processed: 32 Loss: 0.018906548619270325
# Train Epoch: 79 Batch: 1 Total samples processed: 64 Loss: 0.01916002668440342
# Train Epoch: 79 Batch: 2 Total samples processed: 96 Loss: 0.019255883991718292
# Train Epoch: 79 Batch: 3 Total samples processed: 128 Loss: 0.021342631429433823
# Train Epoch: 79 Batch: 4 Total samples processed: 160 Loss: 0.01737290434539318
# Train Epoch: 79 Batch: 5 Total samples processed: 192 Loss: 0.018532928079366684
# Train Epoch: 79 Batch: 6 Total samples processed: 224 Loss: 0.017210107296705246
# Train Epoch: 80 Batch: 0 Total samples processed: 32 Loss: 0.018666250631213188
# Train Epoch: 80 Batch: 1 Total samples processed: 64 Loss: 0.02158874087035656
# Train Epoch: 80 Batch: 2 Total samples processed: 96 Loss: 0.017370793968439102
# Train Epoch: 80 Batch: 3 Total samples processed: 128 Loss: 0.016694340854883194
# Train Epoch: 80 Batch: 4 Total samples processed: 160 Loss: 0.01961217075586319
# Train Epoch: 80 Batch: 5 Total samples processed: 192 Loss: 0.019779924303293228
# Train Epoch: 80 Batch: 6 Total samples processed: 224 Loss: 0.025902725756168365
# Train Epoch: 81 Batch: 0 Total samples processed: 32 Loss: 0.018991190940141678
# Train Epoch: 81 Batch: 1 Total samples processed: 64 Loss: 0.019186299294233322
# Train Epoch: 81 Batch: 2 Total samples processed: 96 Loss: 0.018526878207921982
# Train Epoch: 81 Batch: 3 Total samples processed: 128 Loss: 0.017215268686413765
# Train Epoch: 81 Batch: 4 Total samples processed: 160 Loss: 0.01853863336145878
# Train Epoch: 81 Batch: 5 Total samples processed: 192 Loss: 0.02159375324845314
# Train Epoch: 81 Batch: 6 Total samples processed: 224 Loss: 0.022227710112929344
# Train Epoch: 82 Batch: 0 Total samples processed: 32 Loss: 0.01863671839237213
# Train Epoch: 82 Batch: 1 Total samples processed: 64 Loss: 0.018955066800117493
# Train Epoch: 82 Batch: 2 Total samples processed: 96 Loss: 0.020385785028338432
# Train Epoch: 82 Batch: 3 Total samples processed: 128 Loss: 0.01984463445842266
# Train Epoch: 82 Batch: 4 Total samples processed: 160 Loss: 0.019644929096102715
# Train Epoch: 82 Batch: 5 Total samples processed: 192 Loss: 0.018082773312926292
# Train Epoch: 82 Batch: 6 Total samples processed: 224 Loss: 0.023290621116757393
# Train Epoch: 83 Batch: 0 Total samples processed: 32 Loss: 0.02000742405653
# Train Epoch: 83 Batch: 1 Total samples processed: 64 Loss: 0.019051823765039444
# Train Epoch: 83 Batch: 2 Total samples processed: 96 Loss: 0.016448793932795525
# Train Epoch: 83 Batch: 3 Total samples processed: 128 Loss: 0.018913211300969124
# Train Epoch: 83 Batch: 4 Total samples processed: 160 Loss: 0.020245976746082306
# Train Epoch: 83 Batch: 5 Total samples processed: 192 Loss: 0.020787034183740616
# Train Epoch: 83 Batch: 6 Total samples processed: 224 Loss: 0.017660489305853844
# Train Epoch: 84 Batch: 0 Total samples processed: 32 Loss: 0.019954372197389603
# Train Epoch: 84 Batch: 1 Total samples processed: 64 Loss: 0.01854082942008972
# Train Epoch: 84 Batch: 2 Total samples processed: 96 Loss: 0.019486896693706512
# Train Epoch: 84 Batch: 3 Total samples processed: 128 Loss: 0.01791577972471714
# Train Epoch: 84 Batch: 4 Total samples processed: 160 Loss: 0.02060594968497753
# Train Epoch: 84 Batch: 5 Total samples processed: 192 Loss: 0.016264773905277252
# Train Epoch: 84 Batch: 6 Total samples processed: 224 Loss: 0.02639627456665039
# Train Epoch: 85 Batch: 0 Total samples processed: 32 Loss: 0.01767023280262947
# Train Epoch: 85 Batch: 1 Total samples processed: 64 Loss: 0.018624210730195045
# Train Epoch: 85 Batch: 2 Total samples processed: 96 Loss: 0.02008070982992649
# Train Epoch: 85 Batch: 3 Total samples processed: 128 Loss: 0.01922852173447609
# Train Epoch: 85 Batch: 4 Total samples processed: 160 Loss: 0.01772286742925644
# Train Epoch: 85 Batch: 5 Total samples processed: 192 Loss: 0.021071575582027435
# Train Epoch: 85 Batch: 6 Total samples processed: 224 Loss: 0.02141299471259117
# Train Epoch: 86 Batch: 0 Total samples processed: 32 Loss: 0.018829328939318657
# Train Epoch: 86 Batch: 1 Total samples processed: 64 Loss: 0.021823907271027565
# Train Epoch: 86 Batch: 2 Total samples processed: 96 Loss: 0.018478913232684135
# Train Epoch: 86 Batch: 3 Total samples processed: 128 Loss: 0.01865299791097641
# ...
# Train Epoch: 223 Batch: 0 Total samples processed: 32 Loss: 0.01754513755440712
# Train Epoch: 223 Batch: 1 Total samples processed: 64 Loss: 0.01893753558397293
# Train Epoch: 223 Batch: 2 Total samples processed: 96 Loss: 0.02028292790055275
# Train Epoch: 223 Batch: 3 Total samples processed: 128 Loss: 0.015760716050863266
# Train Epoch: 223 Batch: 4 Total samples processed: 160 Loss: 0.016048243269324303
# Train Epoch: 223 Batch: 5 Total samples processed: 192 Loss: 0.015960589051246643
# Train Epoch: 223 Batch: 6 Total samples processed: 224 Loss: 0.016264161095023155
# Train Epoch: 224 Batch: 0 Total samples processed: 32 Loss: 0.0146531593054533
# Train Epoch: 224 Batch: 1 Total samples processed: 64 Loss: 0.017988618463277817
# Train Epoch: 224 Batch: 2 Total samples processed: 96 Loss: 0.01706611178815365
# Train Epoch: 224 Batch: 3 Total samples processed: 128 Loss: 0.020231161266565323
# Train Epoch: 224 Batch: 4 Total samples processed: 160 Loss: 0.016704967245459557
# Train Epoch: 224 Batch: 5 Total samples processed: 192 Loss: 0.015764592215418816
# Train Epoch: 224 Batch: 6 Total samples processed: 224 Loss: 0.016752799972891808
# Train Epoch: 225 Batch: 0 Total samples processed: 32 Loss: 0.01645081862807274
# Train Epoch: 225 Batch: 1 Total samples processed: 64 Loss: 0.01688978634774685
# Train Epoch: 225 Batch: 2 Total samples processed: 96 Loss: 0.016521897166967392
# Train Epoch: 225 Batch: 3 Total samples processed: 128 Loss: 0.017437756061553955
# Train Epoch: 225 Batch: 4 Total samples processed: 160 Loss: 0.01574041321873665
# Train Epoch: 225 Batch: 5 Total samples processed: 192 Loss: 0.019230758771300316
# Train Epoch: 225 Batch: 6 Total samples processed: 224 Loss: 0.018796395510435104
# Train Epoch: 226 Batch: 0 Total samples processed: 32 Loss: 0.01603773422539234
# Train Epoch: 226 Batch: 1 Total samples processed: 64 Loss: 0.01720997504889965
# Train Epoch: 226 Batch: 2 Total samples processed: 96 Loss: 0.01589893363416195
# Train Epoch: 226 Batch: 3 Total samples processed: 128 Loss: 0.017200419679284096
# Train Epoch: 226 Batch: 4 Total samples processed: 160 Loss: 0.017902396619319916
# Train Epoch: 226 Batch: 5 Total samples processed: 192 Loss: 0.018825966864824295
# Train Epoch: 226 Batch: 6 Total samples processed: 224 Loss: 0.013195214793086052
# Train Epoch: 227 Batch: 0 Total samples processed: 32 Loss: 0.017415190115571022
# Train Epoch: 227 Batch: 1 Total samples processed: 64 Loss: 0.017541835084557533
# Train Epoch: 227 Batch: 2 Total samples processed: 96 Loss: 0.01758754625916481
# Train Epoch: 227 Batch: 3 Total samples processed: 128 Loss: 0.017175640910863876
# Train Epoch: 227 Batch: 4 Total samples processed: 160 Loss: 0.016407465562224388
# Train Epoch: 227 Batch: 5 Total samples processed: 192 Loss: 0.015526308678090572
# Train Epoch: 227 Batch: 6 Total samples processed: 224 Loss: 0.021032391116023064
# Train Epoch: 228 Batch: 0 Total samples processed: 32 Loss: 0.016670837998390198
# Train Epoch: 228 Batch: 1 Total samples processed: 64 Loss: 0.019863592460751534
# Train Epoch: 228 Batch: 2 Total samples processed: 96 Loss: 0.015135562047362328
# Train Epoch: 228 Batch: 3 Total samples processed: 128 Loss: 0.01648230478167534
# Train Epoch: 228 Batch: 4 Total samples processed: 160 Loss: 0.018044671043753624
# Train Epoch: 228 Batch: 5 Total samples processed: 192 Loss: 0.01617024652659893
# Train Epoch: 228 Batch: 6 Total samples processed: 224 Loss: 0.014682662673294544
# Train Epoch: 229 Batch: 0 Total samples processed: 32 Loss: 0.01597731187939644
# Train Epoch: 229 Batch: 1 Total samples processed: 64 Loss: 0.01595200225710869
# Train Epoch: 229 Batch: 2 Total samples processed: 96 Loss: 0.018102096393704414
# Train Epoch: 229 Batch: 3 Total samples processed: 128 Loss: 0.017936546355485916
# Train Epoch: 229 Batch: 4 Total samples processed: 160 Loss: 0.01803932711482048
# Train Epoch: 229 Batch: 5 Total samples processed: 192 Loss: 0.016123119741678238
# Train Epoch: 229 Batch: 6 Total samples processed: 224 Loss: 0.016961785033345222
# Train Epoch: 230 Batch: 0 Total samples processed: 32 Loss: 0.017666783183813095
# Train Epoch: 230 Batch: 1 Total samples processed: 64 Loss: 0.018531175330281258
# Train Epoch: 230 Batch: 2 Total samples processed: 96 Loss: 0.01593766361474991
# Train Epoch: 230 Batch: 3 Total samples processed: 128 Loss: 0.01482751127332449
# Train Epoch: 230 Batch: 4 Total samples processed: 160 Loss: 0.01827980950474739
# Train Epoch: 230 Batch: 5 Total samples processed: 192 Loss: 0.015907075256109238
# Train Epoch: 230 Batch: 6 Total samples processed: 224 Loss: 0.018041148781776428
# Train Epoch: 231 Batch: 0 Total samples processed: 32 Loss: 0.016451409086585045
# Train Epoch: 231 Batch: 1 Total samples processed: 64 Loss: 0.01787739433348179
# Train Epoch: 231 Batch: 2 Total samples processed: 96 Loss: 0.018810126930475235
# Train Epoch: 231 Batch: 3 Total samples processed: 128 Loss: 0.015792395919561386
# Train Epoch: 231 Batch: 4 Total samples processed: 160 Loss: 0.016669442877173424
# Train Epoch: 231 Batch: 5 Total samples processed: 192 Loss: 0.018388710916042328
# Train Epoch: 231 Batch: 6 Total samples processed: 224 Loss: 0.011057864874601364
# Train Epoch: 232 Batch: 0 Total samples processed: 32 Loss: 0.016743376851081848
# Train Epoch: 232 Batch: 1 Total samples processed: 64 Loss: 0.01731470599770546
# Train Epoch: 232 Batch: 2 Total samples processed: 96 Loss: 0.015144935809075832
# Train Epoch: 232 Batch: 3 Total samples processed: 128 Loss: 0.018743781372904778
# Train Epoch: 232 Batch: 4 Total samples processed: 160 Loss: 0.017847388982772827
# Train Epoch: 232 Batch: 5 Total samples processed: 192 Loss: 0.017175445333123207
# Train Epoch: 232 Batch: 6 Total samples processed: 224 Loss: 0.01624908298254013
# Train Epoch: 233 Batch: 0 Total samples processed: 32 Loss: 0.018352927640080452
# Train Epoch: 233 Batch: 1 Total samples processed: 64 Loss: 0.01749974489212036
# Train Epoch: 233 Batch: 2 Total samples processed: 96 Loss: 0.015530109405517578
# Train Epoch: 233 Batch: 3 Total samples processed: 128 Loss: 0.015837306156754494
# Train Epoch: 233 Batch: 4 Total samples processed: 160 Loss: 0.017911292612552643
# Train Epoch: 233 Batch: 5 Total samples processed: 192 Loss: 0.01666889898478985
# Train Epoch: 233 Batch: 6 Total samples processed: 224 Loss: 0.020933590829372406
# Train Epoch: 234 Batch: 0 Total samples processed: 32 Loss: 0.016804562881588936
# Train Epoch: 234 Batch: 1 Total samples processed: 64 Loss: 0.01692875847220421
# Train Epoch: 234 Batch: 2 Total samples processed: 96 Loss: 0.01637791283428669
# Train Epoch: 234 Batch: 3 Total samples processed: 128 Loss: 0.016810640692710876
# Train Epoch: 234 Batch: 4 Total samples processed: 160 Loss: 0.01761237345635891
# Train Epoch: 234 Batch: 5 Total samples processed: 192 Loss: 0.018467234447598457
# Train Epoch: 234 Batch: 6 Total samples processed: 224 Loss: 0.019836993888020515
# Train Epoch: 235 Batch: 0 Total samples processed: 32 Loss: 0.015315995551645756
# Train Epoch: 235 Batch: 1 Total samples processed: 64 Loss: 0.017158690840005875
# Train Epoch: 235 Batch: 2 Total samples processed: 96 Loss: 0.01993275247514248
# Train Epoch: 235 Batch: 3 Total samples processed: 128 Loss: 0.01606803573668003
# Train Epoch: 235 Batch: 4 Total samples processed: 160 Loss: 0.017444053664803505
# Train Epoch: 235 Batch: 5 Total samples processed: 192 Loss: 0.016642386093735695
# Train Epoch: 235 Batch: 6 Total samples processed: 224 Loss: 0.021629726514220238
# Train Epoch: 236 Batch: 0 Total samples processed: 32 Loss: 0.016056861728429794
# Train Epoch: 236 Batch: 1 Total samples processed: 64 Loss: 0.016916219145059586
# Train Epoch: 236 Batch: 2 Total samples processed: 96 Loss: 0.015416046604514122
# Train Epoch: 236 Batch: 3 Total samples processed: 128 Loss: 0.017579572275280952
# Train Epoch: 236 Batch: 4 Total samples processed: 160 Loss: 0.018429214134812355
# Train Epoch: 236 Batch: 5 Total samples processed: 192 Loss: 0.017324892804026604
# Train Epoch: 236 Batch: 6 Total samples processed: 224 Loss: 0.017918676137924194
# Train Epoch: 237 Batch: 0 Total samples processed: 32 Loss: 0.01707858219742775
# Train Epoch: 237 Batch: 1 Total samples processed: 64 Loss: 0.015687793493270874
# Train Epoch: 237 Batch: 2 Total samples processed: 96 Loss: 0.01746220514178276
# Train Epoch: 237 Batch: 3 Total samples processed: 128 Loss: 0.017342370003461838
# Train Epoch: 237 Batch: 4 Total samples processed: 160 Loss: 0.018510621041059494
# Train Epoch: 237 Batch: 5 Total samples processed: 192 Loss: 0.016634434461593628
# Train Epoch: 237 Batch: 6 Total samples processed: 224 Loss: 0.017255596816539764
# Train Epoch: 238 Batch: 0 Total samples processed: 32 Loss: 0.018053850159049034
# Train Epoch: 238 Batch: 1 Total samples processed: 64 Loss: 0.016563093289732933
# Train Epoch: 238 Batch: 2 Total samples processed: 96 Loss: 0.018267711624503136
# Train Epoch: 238 Batch: 3 Total samples processed: 128 Loss: 0.01749034970998764
# Train Epoch: 238 Batch: 4 Total samples processed: 160 Loss: 0.015874598175287247
# Train Epoch: 238 Batch: 5 Total samples processed: 192 Loss: 0.015045440755784512
# Train Epoch: 238 Batch: 6 Total samples processed: 224 Loss: 0.015687255188822746
# Train Epoch: 239 Batch: 0 Total samples processed: 32 Loss: 0.018178220838308334
# Train Epoch: 239 Batch: 1 Total samples processed: 64 Loss: 0.016121093183755875
# Train Epoch: 239 Batch: 2 Total samples processed: 96 Loss: 0.018836291506886482
# Train Epoch: 239 Batch: 3 Total samples processed: 128 Loss: 0.015796108171343803
# Train Epoch: 239 Batch: 4 Total samples processed: 160 Loss: 0.01678507961332798
# Train Epoch: 239 Batch: 5 Total samples processed: 192 Loss: 0.017041901126503944
# Train Epoch: 239 Batch: 6 Total samples processed: 224 Loss: 0.015384333208203316
# Train Epoch: 240 Batch: 0 Total samples processed: 32 Loss: 0.016901059076189995
# Train Epoch: 240 Batch: 1 Total samples processed: 64 Loss: 0.017305515706539154
# Train Epoch: 240 Batch: 2 Total samples processed: 96 Loss: 0.018683886155486107
# Train Epoch: 240 Batch: 3 Total samples processed: 128 Loss: 0.015521540306508541
# Train Epoch: 240 Batch: 4 Total samples processed: 160 Loss: 0.01698422245681286
# Train Epoch: 240 Batch: 5 Total samples processed: 192 Loss: 0.01613887958228588
# Train Epoch: 240 Batch: 6 Total samples processed: 224 Loss: 0.013784974813461304
# Train Epoch: 241 Batch: 0 Total samples processed: 32 Loss: 0.01641775108873844
# Train Epoch: 241 Batch: 1 Total samples processed: 64 Loss: 0.01602097414433956
# Train Epoch: 241 Batch: 2 Total samples processed: 96 Loss: 0.016621198505163193
# Train Epoch: 241 Batch: 3 Total samples processed: 128 Loss: 0.017492948099970818
# Train Epoch: 241 Batch: 4 Total samples processed: 160 Loss: 0.01925291121006012
# Train Epoch: 241 Batch: 5 Total samples processed: 192 Loss: 0.01571403071284294
# Train Epoch: 241 Batch: 6 Total samples processed: 224 Loss: 0.015938367694616318
# Train Epoch: 242 Batch: 0 Total samples processed: 32 Loss: 0.01861840859055519
# Train Epoch: 242 Batch: 1 Total samples processed: 64 Loss: 0.015290292911231518
# Train Epoch: 242 Batch: 2 Total samples processed: 96 Loss: 0.018227942287921906
# Train Epoch: 242 Batch: 3 Total samples processed: 128 Loss: 0.01507467869669199
# Train Epoch: 242 Batch: 4 Total samples processed: 160 Loss: 0.015840737149119377
# Train Epoch: 242 Batch: 5 Total samples processed: 192 Loss: 0.01920367032289505
# Train Epoch: 242 Batch: 6 Total samples processed: 224 Loss: 0.012233702465891838
# Train Epoch: 243 Batch: 0 Total samples processed: 32 Loss: 0.016657622531056404
# Train Epoch: 243 Batch: 1 Total samples processed: 64 Loss: 0.016589509323239326
# Train Epoch: 243 Batch: 2 Total samples processed: 96 Loss: 0.01673736982047558
# Train Epoch: 243 Batch: 3 Total samples processed: 128 Loss: 0.016647977754473686
# Train Epoch: 243 Batch: 4 Total samples processed: 160 Loss: 0.018629128113389015
# Train Epoch: 243 Batch: 5 Total samples processed: 192 Loss: 0.01600733771920204
# Train Epoch: 243 Batch: 6 Total samples processed: 224 Loss: 0.014572748914361
# Train Epoch: 244 Batch: 0 Total samples processed: 32 Loss: 0.014910043217241764
# Train Epoch: 244 Batch: 1 Total samples processed: 64 Loss: 0.017140205949544907
# Train Epoch: 244 Batch: 2 Total samples processed: 96 Loss: 0.018924657255411148
# Train Epoch: 244 Batch: 3 Total samples processed: 128 Loss: 0.015655064955353737
# Train Epoch: 244 Batch: 4 Total samples processed: 160 Loss: 0.0164908766746521
# Train Epoch: 244 Batch: 5 Total samples processed: 192 Loss: 0.017582515254616737
# Train Epoch: 244 Batch: 6 Total samples processed: 224 Loss: 0.01778080128133297
# Train Epoch: 245 Batch: 0 Total samples processed: 32 Loss: 0.016160275787115097
# Train Epoch: 245 Batch: 1 Total samples processed: 64 Loss: 0.017924999818205833
# Train Epoch: 245 Batch: 2 Total samples processed: 96 Loss: 0.017474770545959473
# Train Epoch: 245 Batch: 3 Total samples processed: 128 Loss: 0.019074423238635063
# Train Epoch: 245 Batch: 4 Total samples processed: 160 Loss: 0.01597747579216957
# Train Epoch: 245 Batch: 5 Total samples processed: 192 Loss: 0.015412328764796257
# Train Epoch: 245 Batch: 6 Total samples processed: 224 Loss: 0.014395501464605331
# Train Epoch: 246 Batch: 0 Total samples processed: 32 Loss: 0.018530696630477905
# Train Epoch: 246 Batch: 1 Total samples processed: 64 Loss: 0.015442890115082264
# Train Epoch: 246 Batch: 2 Total samples processed: 96 Loss: 0.017946509644389153
# Train Epoch: 246 Batch: 3 Total samples processed: 128 Loss: 0.017822830006480217
# Train Epoch: 246 Batch: 4 Total samples processed: 160 Loss: 0.01563360169529915
# Train Epoch: 246 Batch: 5 Total samples processed: 192 Loss: 0.016584062948822975
# Train Epoch: 246 Batch: 6 Total samples processed: 224 Loss: 0.018313191831111908
# Train Epoch: 247 Batch: 0 Total samples processed: 32 Loss: 0.017929762601852417
# Train Epoch: 247 Batch: 1 Total samples processed: 64 Loss: 0.016860174015164375
# Train Epoch: 247 Batch: 2 Total samples processed: 96 Loss: 0.016406288370490074
# Train Epoch: 247 Batch: 3 Total samples processed: 128 Loss: 0.017363473773002625
# Train Epoch: 247 Batch: 4 Total samples processed: 160 Loss: 0.017665013670921326
# Train Epoch: 247 Batch: 5 Total samples processed: 192 Loss: 0.0158416498452425
# Train Epoch: 247 Batch: 6 Total samples processed: 224 Loss: 0.015225499868392944
# Train Epoch: 248 Batch: 0 Total samples processed: 32 Loss: 0.015658656135201454
# Train Epoch: 248 Batch: 1 Total samples processed: 64 Loss: 0.01706860214471817
# Train Epoch: 248 Batch: 2 Total samples processed: 96 Loss: 0.017033373937010765
# Train Epoch: 248 Batch: 3 Total samples processed: 128 Loss: 0.01807931251823902
# Train Epoch: 248 Batch: 4 Total samples processed: 160 Loss: 0.017142891883850098
# Train Epoch: 248 Batch: 5 Total samples processed: 192 Loss: 0.016406042501330376
# Train Epoch: 248 Batch: 6 Total samples processed: 224 Loss: 0.016514955088496208
# Train Epoch: 249 Batch: 0 Total samples processed: 32 Loss: 0.01799333281815052
# Train Epoch: 249 Batch: 1 Total samples processed: 64 Loss: 0.015758544206619263
# Train Epoch: 249 Batch: 2 Total samples processed: 96 Loss: 0.01769055798649788
# Train Epoch: 249 Batch: 3 Total samples processed: 128 Loss: 0.016749264672398567
# Train Epoch: 249 Batch: 4 Total samples processed: 160 Loss: 0.015333529561758041
# Train Epoch: 249 Batch: 5 Total samples processed: 192 Loss: 0.017772873863577843
# Train Epoch: 249 Batch: 6 Total samples processed: 224 Loss: 0.019083019345998764
# Train Epoch: 250 Batch: 0 Total samples processed: 32 Loss: 0.017908569425344467
# Train Epoch: 250 Batch: 1 Total samples processed: 64 Loss: 0.017999008297920227
# Train Epoch: 250 Batch: 2 Total samples processed: 96 Loss: 0.01911493018269539
# Train Epoch: 250 Batch: 3 Total samples processed: 128 Loss: 0.016648123040795326
# Train Epoch: 250 Batch: 4 Total samples processed: 160 Loss: 0.015882251784205437
# Train Epoch: 250 Batch: 5 Total samples processed: 192 Loss: 0.014493666589260101
# Train Epoch: 250 Batch: 6 Total samples processed: 224 Loss: 0.015701301395893097

# %% [markdown]
# ## Look at self-prediction
#
# Self-prediction does not tell us how the UNET will perform on new data, but it is a useful check to make sure the UNET is learning the training data.

# %%
len(X)
# Out:
# 8

# %%
import matplotlib.pyplot as plt

# convert to 0/1 range on each pixel
prediction = torch.nn.functional.sigmoid(prediction_logits)
prediction_binary = prediction #(prediction > 0.5).to(torch.uint8)

sidx = 1
plt.subplot(131)
plt.imshow(X[sidx, 0].cpu().numpy(), cmap="gray")
plt.title("Input")

plt.subplot(132)
plt.imshow(y[sidx, 0].cpu().numpy(), cmap="gray")
plt.title("Ground truth")

plt.subplot(133)
plt.imshow(prediction_binary.cpu().detach()[sidx, 0].numpy(), cmap="gray")
plt.title("Predictions")
# Out:
# Text(0.5, 1.0, 'Predictions')

# %% [markdown]
# ## Save the UNET

# %%
torch.save(model.state_dict(), train_path / 'model1')

# %% [markdown]
# ## Test on unseen data

# %%
#test_name = '2_force_filtered.tif'
test_name = '24_force_filtered.tif'
#test_name = '33_force_flow_filtered.tif'
#test_name = '44_force_flow_filtered.tif'

testim = imread(test_image_path  / test_name) 
testim2 = testim[100:, 100:]
testim.shape
plt.imshow(testim, cmap="gray")
print('original min max', testim.min(), testim.max())
print('cropped min max', testim2.min(), testim2.max())
# Out:
# original min max 0.20914316 0.9671849
# cropped min max 0.5237987 0.8165312

# %%
#testim__ = quantile_normalization(
#    testim,
#    quantile_low=0.01,
#    quantile_high=0.998,
#    clip=True)[0].astype(np.float32)
x = torch.from_numpy(testim).unsqueeze(0).unsqueeze(0).to(device)
y = model(x)

plt.imshow(y.cpu().detach()[0, 0].numpy(), cmap="gray")

# %% [markdown]
# ## Look at results in Napari

# %%
import napari
viewer = napari.Viewer()
viewer.add_image(testim, name='testim')
viewer.add_image(y.cpu().detach()[0, 0].numpy(), name='prediction')
binary = y.cpu().detach()[0, 0].numpy() > 0.5
viewer.add_labels(binary, name='prediction binary')
# Out:
# <Labels layer 'prediction binary' at 0x1a8feab4e50>
