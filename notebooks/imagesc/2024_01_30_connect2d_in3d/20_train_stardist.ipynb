# %% [markdown]
# # Train a stardist neural network for segmentation
#
# This notebook uses the labels generated in '10_create_phantom.ipynb' (which used a stardist2d and a connect-in-3D strategy to generate labels) to train a 3D network.

# %%
from skimage.io import imread, imsave
from tnia.plotting.projections import show_xyz_slice, show_xyz_max, show_xy_zy_max, show_xy_zy_slice
from random import randint
import numpy as np
import os
from skimage.measure import label
from tnia.deeplearning.dl_helper import collect_training_data
from stardist import calculate_extents

from tnia.plotting.plt_helper import random_label_cmap
colormap=random_label_cmap()

# %% [markdown]
# # Get the list of visible devices and confirm that GPU is available
#
# ... or else training will take a long time

# %%
import tensorflow as tf
visible_devices = tf.config.list_physical_devices()
print(visible_devices)
# Out:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'), PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# ## Define model path
#
# This is the path where the model will be saved, change to be local to your machine

# %%
from pathlib import Path
tnia_images_path = Path("D:/images/tnia-python-images")
parent_path = tnia_images_path / "imagesc/2024_01_30_connect2d_in3d"
model_path = parent_path / 'models'
print(model_path)
patches_path = parent_path / 'patches7'
print(patches_path)
# Out:
# D:\images\tnia-python-images\imagesc\2024_01_30_connect2d_in3d\models
# D:\images\tnia-python-images\imagesc\2024_01_30_connect2d_in3d\patches7

# %% [markdown]
# # Load the corrupted images and ground truth images

# %%
paths = [patches_path]

X = []
Y = []

for path in paths:
    X_, Y_ = collect_training_data(path, sub_sample=1, downsample=False, normalize_truth=False, training_multiple=16)

    print(path)
    print(len(X_))
    print()
    X.extend(X_)
    Y.extend(Y_)

print(len(X))
print(len(Y))

print('input shape is', X[0].shape)
print('ground truth shape is', Y[0].shape)

fig = show_xy_zy_max(X[0])
fig = show_xy_zy_max(Y[0])
# Out:
# D:\images\tnia-python-images\imagesc\2024_01_30_connect2d_in3d\patches7
# 5
#
# 5
# 5
# input shape is (96, 288, 288, 1)
# ground truth shape is (96, 288, 288)

# %% [markdown]
# ## Shuffle the datasets
#
# ... and convert to numpy

# %%
from tnia.deeplearning.dl_helper import shuffle

X, Y = shuffle(X, Y)

X = np.array(X)
Y = np.array(Y).astype(np.uint16)

# %%
print(X.max())
print(Y.max())
# Out:
# 1.3412164
# 487

# %% [markdown]
# ## Import Stardist

# %%
from stardist.models import Config3D, StarDist3D

# %% [markdown]
# ## Compute extents and anisotropy

# %%
print('ground truth shape is', Y.shape)

extents = calculate_extents(Y.squeeze().astype('uint16'))

anisotropy = tuple(np.max(extents) / extents)

# alternatively explicitly set extent and anisotropy

#extents = [80, 20, 20]
#anisotropy = (3,1,1)

print('extents', extents)
print('anisotropy', anisotropy)
# Out:
# ground truth shape is (5, 96, 288, 288)
# extents [ 5. 32. 32.]
# anisotropy (6.4, 1.0, 1.0)

# %%
from stardist import Rays_GoldenSpiral
from stardist import Rays_Octo
n_channel_in =1
axes = 'ZYX'

n_rays = 96 

# Use rays on a Fibonacci lattice adjusted for measured anisotropy of the training data
rays = Rays_GoldenSpiral(n_rays, anisotropy=anisotropy)
model_name = 'stardist_model_96ray_2'

#rays = Rays_Octo(n_level=1) 
#model_name = 'stardist_octo'

config = Config3D (rays=rays, axes=axes,n_channel_in=1, train_patch_size=(96, 64, 64), grid=(1,2,2), unet_n_depth=3)

#config = Config(axes, n_channel_in, n_channel_out, train_steps_per_epoch=20, train_epochs=50, unet_n_depth=4)
#print(config)
new_model = False 


if new_model:
    #model = StarDist3D(config, name='stardist_model_48ray_combined', basedir=model_path)
    print('initializing new model')
    model = StarDist3D(config, name=model_name, basedir=model_path)
else:
    model = StarDist3D(None,  name=model_name, basedir=model_path)
vars(config)
# Out:
# model3d.py (223): Mismatch of 'anisotropy' of rays and 'anisotropy'.
# base_model.py (149): output path for model already exists, files may be overwritten: D:\images\tnia-python-images\imagesc\2024_01_30_connect2d_in3d\models\stardist_model_96ray_2
# initializing new model
# Using default values: prob_thresh=0.5, nms_thresh=0.4.
# {'n_dim': 3,
#  'axes': 'ZYXC',
#  'n_channel_in': 1,
#  'n_channel_out': 97,
#  'train_checkpoint': 'weights_best.h5',
#  'train_checkpoint_last': 'weights_last.h5',
#  'train_checkpoint_epoch': 'weights_now.h5',
#  'n_rays': 96,
#  'grid': (1, 2, 2),
#  'anisotropy': None,
#  'backbone': 'unet',
#  'rays_json': {'name': 'Rays_GoldenSpiral',
#   'kwargs': {'n': 96, 'anisotropy': (6.4, 1.0, 1.0)}},
#  'n_classes': None,
#  'unet_n_depth': 3,
#  'unet_kernel_size': (3, 3, 3),
#  'unet_n_filter_base': 32,
#  'unet_n_conv_per_depth': 2,
#  'unet_pool': (2, 2, 2),
#  'unet_activation': 'relu',
#  'unet_last_activation': 'relu',
#  'unet_batch_norm': False,
#  'unet_dropout': 0.0,
#  'unet_prefix': '',
#  'net_conv_after_unet': 128,
#  'net_input_shape': (None, None, None, 1),
#  'net_mask_shape': (None, None, None, 1),
#  'train_patch_size': (96, 64, 64),
#  'train_background_reg': 0.0001,
#  'train_foreground_only': 0.9,
#  'train_sample_cache': True,
#  'train_dist_loss': 'mae',
#  'train_loss_weights': (1, 0.2),
#  'train_class_weights': (1, 1),
#  'train_epochs': 400,
#  'train_steps_per_epoch': 100,
#  'train_learning_rate': 0.0003,
#  'train_batch_size': 1,
#  'train_n_val_patches': None,
#  'train_tensorboard': True,
#  'train_reduce_lr': {'factor': 0.5, 'patience': 40, 'min_delta': 0},
#  'use_gpu': False}

# %%
config.anisotropy, config.grid
median_size = calculate_extents(Y[1:2], np.median)
fov = np.array(model._axes_tile_overlap('ZYX'))
print(f"median object size:      {median_size}")
print(f"network field of view :  {fov}")
if any(median_size > fov):
    print("WARNING: median object size larger than field of view of the neural network.")
# Out:
# median object size:      [ 5. 30. 30.]
# network field of view :  [32 64 64]

# %%
X_train=X
Y_train=Y
X_val=X
Y_val=Y

# %%
model.train(X_train, Y_train, validation_data=(X_val,Y_val),epochs=50, steps_per_epoch=100)
# Out:
# Epoch 1/50
# WARNING:tensorflow:AutoGraph could not transform <function _gcd_import at 0x0000025D9F6113A0> and will run it as-is.
# Cause: Unable to locate the source code of <function _gcd_import at 0x0000025D9F6113A0>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function _gcd_import at 0x0000025D9F6113A0> and will run it as-is.
# Cause: Unable to locate the source code of <function _gcd_import at 0x0000025D9F6113A0>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 3/3 [==============================] - 0s 39ms/step- loss: 1.8931 - prob_loss: 0.2920 - dist_loss: 8.0053 - prob_kld: 0.2453 - dist_relevant_mae: 8.0049 - dist_relevant_mse: 109.5322 - dist_dist_iou_metric: 0.
# 100/100 [==============================] - 26s 209ms/step - loss: 1.8931 - prob_loss: 0.2920 - dist_loss: 8.0053 - prob_kld: 0.2453 - dist_relevant_mae: 8.0049 - dist_relevant_mse: 109.5322 - dist_dist_iou_metric: 0.1181 - val_loss: 1.2425 - val_prob_loss: 0.1767 - val_dist_loss: 5.3290 - val_prob_kld: 0.1342 - val_dist_relevant_mae: 5.3283 - val_dist_relevant_mse: 55.3475 - val_dist_dist_iou_metric: 0.2798 - lr: 3.0000e-04
# Epoch 2/50
# 3/3 [==============================] - 0s 36ms/step- loss: 1.1022 - prob_loss: 0.1151 - dist_loss: 4.9353 - prob_kld: 0.0799 - dist_relevant_mae: 4.9346 - dist_relevant_mse: 46.3552 - dist_dist_iou_metric: 0.
# 100/100 [==============================] - 20s 198ms/step - loss: 1.1022 - prob_loss: 0.1151 - dist_loss: 4.9353 - prob_kld: 0.0799 - dist_relevant_mae: 4.9346 - dist_relevant_mse: 46.3552 - dist_dist_iou_metric: 0.3257 - val_loss: 1.0450 - val_prob_loss: 0.1065 - val_dist_loss: 4.6924 - val_prob_kld: 0.0640 - val_dist_relevant_mae: 4.6919 - val_dist_relevant_mse: 41.1340 - val_dist_dist_iou_metric: 0.3612 - lr: 3.0000e-04
# Epoch 3/50
# 3/3 [==============================] - 0s 35ms/step- loss: 0.9519 - prob_loss: 0.0946 - dist_loss: 4.2865 - prob_kld: 0.0571 - dist_relevant_mae: 4.2859 - dist_relevant_mse: 36.2374 - dist_dist_iou_metric: 0.
# 100/100 [==============================] - 20s 201ms/step - loss: 0.9519 - prob_loss: 0.0946 - dist_loss: 4.2865 - prob_kld: 0.0571 - dist_relevant_mae: 4.2859 - dist_relevant_mse: 36.2374 - dist_dist_iou_metric: 0.3928 - val_loss: 0.8221 - val_prob_loss: 0.0971 - val_dist_loss: 3.6251 - val_prob_kld: 0.0545 - val_dist_relevant_mae: 3.6245 - val_dist_relevant_mse: 26.2281 - val_dist_dist_iou_metric: 0.4649 - lr: 3.0000e-04
# Epoch 4/50
# 3/3 [==============================] - 0s 36ms/step- loss: 0.8048 - prob_loss: 0.0922 - dist_loss: 3.5627 - prob_kld: 0.0553 - dist_relevant_mae: 3.5621 - dist_relevant_mse: 25.2699 - dist_dist_iou_metric: 0.
# 100/100 [==============================] - 20s 205ms/step - loss: 0.8048 - prob_loss: 0.0922 - dist_loss: 3.5627 - prob_kld: 0.0553 - dist_relevant_mae: 3.5621 - dist_relevant_mse: 25.2699 - dist_dist_iou_metric: 0.4920 - val_loss: 0.7364 - val_prob_loss: 0.0958 - val_dist_loss: 3.2030 - val_prob_kld: 0.0533 - val_dist_relevant_mae: 3.2025 - val_dist_relevant_mse: 20.1720 - val_dist_dist_iou_metric: 0.5596 - lr: 3.0000e-04
# Epoch 5/50
# 3/3 [==============================] - 0s 36ms/step- loss: 0.7447 - prob_loss: 0.0959 - dist_loss: 3.2440 - prob_kld: 0.0598 - dist_relevant_mae: 3.2434 - dist_relevant_mse: 21.3864 - dist_dist_iou_metric: 0.
# 100/100 [==============================] - 20s 195ms/step - loss: 0.7447 - prob_loss: 0.0959 - dist_loss: 3.2440 - prob_kld: 0.0598 - dist_relevant_mae: 3.2434 - dist_relevant_mse: 21.3864 - dist_dist_iou_metric: 0.5315 - val_loss: 0.6919 - val_prob_loss: 0.0983 - val_dist_loss: 2.9682 - val_prob_kld: 0.0558 - val_dist_relevant_mae: 2.9676 - val_dist_relevant_mse: 18.0349 - val_dist_dist_iou_metric: 0.5833 - lr: 3.0000e-04
# Epoch 6/50
# 3/3 [==============================] - 0s 36ms/step- loss: 0.7400 - prob_loss: 0.0824 - dist_loss: 3.2881 - prob_kld: 0.0468 - dist_relevant_mae: 3.2875 - dist_relevant_mse: 22.3064 - dist_dist_iou_metric: 0.
# 100/100 [==============================] - 19s 194ms/step - loss: 0.7400 - prob_loss: 0.0824 - dist_loss: 3.2881 - prob_kld: 0.0468 - dist_relevant_mae: 3.2875 - dist_relevant_mse: 22.3064 - dist_dist_iou_metric: 0.5194 - val_loss: 0.6850 - val_prob_loss: 0.0973 - val_dist_loss: 2.9382 - val_prob_kld: 0.0548 - val_dist_relevant_mae: 2.9376 - val_dist_relevant_mse: 17.9696 - val_dist_dist_iou_metric: 0.5847 - lr: 3.0000e-04
# Epoch 7/50
# 3/3 [==============================] - 0s 34ms/step- loss: 0.6636 - prob_loss: 0.0766 - dist_loss: 2.9349 - prob_kld: 0.0423 - dist_relevant_mae: 2.9344 - dist_relevant_mse: 18.3984 - dist_dist_iou_metric: 0.
# 100/100 [==============================] - 19s 189ms/step - loss: 0.6636 - prob_loss: 0.0766 - dist_loss: 2.9349 - prob_kld: 0.0423 - dist_relevant_mae: 2.9344 - dist_relevant_mse: 18.3984 - dist_dist_iou_metric: 0.5462 - val_loss: 0.6329 - val_prob_loss: 0.0918 - val_dist_loss: 2.7053 - val_prob_kld: 0.0493 - val_dist_relevant_mae: 2.7048 - val_dist_relevant_mse: 16.3327 - val_dist_dist_iou_metric: 0.5811 - lr: 3.0000e-04
# Epoch 8/50
# 3/3 [==============================] - 0s 41ms/step- loss: 0.6452 - prob_loss: 0.0810 - dist_loss: 2.8208 - prob_kld: 0.0439 - dist_relevant_mae: 2.8202 - dist_relevant_mse: 17.2267 - dist_dist_iou_metric: 0.
# 100/100 [==============================] - 19s 194ms/step - loss: 0.6452 - prob_loss: 0.0810 - dist_loss: 2.8208 - prob_kld: 0.0439 - dist_relevant_mae: 2.8202 - dist_relevant_mse: 17.2267 - dist_dist_iou_metric: 0.5763 - val_loss: 0.6503 - val_prob_loss: 0.0956 - val_dist_loss: 2.7735 - val_prob_kld: 0.0531 - val_dist_relevant_mae: 2.7730 - val_dist_relevant_mse: 16.8453 - val_dist_dist_iou_metric: 0.5747 - lr: 3.0000e-04
# Epoch 9/50
# 3/3 [==============================] - 0s 34ms/step- loss: 0.6389 - prob_loss: 0.0831 - dist_loss: 2.7789 - prob_kld: 0.0474 - dist_relevant_mae: 2.7784 - dist_relevant_mse: 16.8196 - dist_dist_iou_metric: 0.
# 100/100 [==============================] - 19s 194ms/step - loss: 0.6389 - prob_loss: 0.0831 - dist_loss: 2.7789 - prob_kld: 0.0474 - dist_relevant_mae: 2.7784 - dist_relevant_mse: 16.8196 - dist_dist_iou_metric: 0.5652 - val_loss: 0.6237 - val_prob_loss: 0.0985 - val_dist_loss: 2.6263 - val_prob_kld: 0.0560 - val_dist_relevant_mae: 2.6257 - val_dist_relevant_mse: 16.0393 - val_dist_dist_iou_metric: 0.5925 - lr: 3.0000e-04
# Epoch 10/50
# 3/3 [==============================] - 0s 35ms/step- loss: 0.6110 - prob_loss: 0.0797 - dist_loss: 2.6566 - prob_kld: 0.0428 - dist_relevant_mae: 2.6560 - dist_relevant_mse: 16.1815 - dist_dist_iou_metric: 0.
# 100/100 [==============================] - 20s 200ms/step - loss: 0.6110 - prob_loss: 0.0797 - dist_loss: 2.6566 - prob_kld: 0.0428 - dist_relevant_mae: 2.6560 - dist_relevant_mse: 16.1815 - dist_dist_iou_metric: 0.6002 - val_loss: 0.5921 - val_prob_loss: 0.0911 - val_dist_loss: 2.5048 - val_prob_kld: 0.0486 - val_dist_relevant_mae: 2.5042 - val_dist_relevant_mse: 14.3032 - val_dist_dist_iou_metric: 0.6301 - lr: 3.0000e-04
# Epoch 11/50
# 3/3 [==============================] - 0s 43ms/step- loss: 0.5993 - prob_loss: 0.0741 - dist_loss: 2.6264 - prob_kld: 0.0404 - dist_relevant_mae: 2.6258 - dist_relevant_mse: 15.8410 - dist_dist_iou_metric: 0.
# 100/100 [==============================] - 19s 192ms/step - loss: 0.5993 - prob_loss: 0.0741 - dist_loss: 2.6264 - prob_kld: 0.0404 - dist_relevant_mae: 2.6258 - dist_relevant_mse: 15.8410 - dist_dist_iou_metric: 0.5996 - val_loss: 0.5718 - val_prob_loss: 0.0905 - val_dist_loss: 2.4065 - val_prob_kld: 0.0480 - val_dist_relevant_mae: 2.4060 - val_dist_relevant_mse: 14.2241 - val_dist_dist_iou_metric: 0.6256 - lr: 3.0000e-04
# Epoch 12/50
# 3/3 [==============================] - 0s 36ms/step- loss: 0.5681 - prob_loss: 0.0739 - dist_loss: 2.4713 - prob_kld: 0.0396 - dist_relevant_mae: 2.4707 - dist_relevant_mse: 14.1762 - dist_dist_iou_metric: 0.
# 100/100 [==============================] - 19s 186ms/step - loss: 0.5681 - prob_loss: 0.0739 - dist_loss: 2.4713 - prob_kld: 0.0396 - dist_relevant_mae: 2.4707 - dist_relevant_mse: 14.1762 - dist_dist_iou_metric: 0.6023 - val_loss: 0.5772 - val_prob_loss: 0.0940 - val_dist_loss: 2.4157 - val_prob_kld: 0.0515 - val_dist_relevant_mae: 2.4151 - val_dist_relevant_mse: 13.6127 - val_dist_dist_iou_metric: 0.6261 - lr: 3.0000e-04
# Epoch 13/50
# 3/3 [==============================] - 0s 38ms/step- loss: 0.5743 - prob_loss: 0.0768 - dist_loss: 2.4873 - prob_kld: 0.0414 - dist_relevant_mae: 2.4868 - dist_relevant_mse: 14.4963 - dist_dist_iou_metric: 0.
# 100/100 [==============================] - 19s 193ms/step - loss: 0.5743 - prob_loss: 0.0768 - dist_loss: 2.4873 - prob_kld: 0.0414 - dist_relevant_mae: 2.4868 - dist_relevant_mse: 14.4963 - dist_dist_iou_metric: 0.6109 - val_loss: 0.5657 - val_prob_loss: 0.0912 - val_dist_loss: 2.3728 - val_prob_kld: 0.0486 - val_dist_relevant_mae: 2.3723 - val_dist_relevant_mse: 13.7886 - val_dist_dist_iou_metric: 0.6341 - lr: 3.0000e-04
# Epoch 14/50
# 3/3 [==============================] - 0s 36ms/step- loss: 0.5693 - prob_loss: 0.0749 - dist_loss: 2.4721 - prob_kld: 0.0402 - dist_relevant_mae: 2.4715 - dist_relevant_mse: 14.5458 - dist_dist_iou_metric: 0.
# 100/100 [==============================] - 19s 192ms/step - loss: 0.5693 - prob_loss: 0.0749 - dist_loss: 2.4721 - prob_kld: 0.0402 - dist_relevant_mae: 2.4715 - dist_relevant_mse: 14.5458 - dist_dist_iou_metric: 0.6215 - val_loss: 0.5540 - val_prob_loss: 0.0915 - val_dist_loss: 2.3123 - val_prob_kld: 0.0490 - val_dist_relevant_mae: 2.3117 - val_dist_relevant_mse: 12.8306 - val_dist_dist_iou_metric: 0.6487 - lr: 3.0000e-04
# Epoch 15/50
# 3/3 [==============================] - 0s 32ms/step- loss: 0.5380 - prob_loss: 0.0719 - dist_loss: 2.3306 - prob_kld: 0.0369 - dist_relevant_mae: 2.3300 - dist_relevant_mse: 13.1594 - dist_dist_iou_metric: 0.
# 100/100 [==============================] - 19s 191ms/step - loss: 0.5380 - prob_loss: 0.0719 - dist_loss: 2.3306 - prob_kld: 0.0369 - dist_relevant_mae: 2.3300 - dist_relevant_mse: 13.1594 - dist_dist_iou_metric: 0.6363 - val_loss: 0.5561 - val_prob_loss: 0.0939 - val_dist_loss: 2.3111 - val_prob_kld: 0.0514 - val_dist_relevant_mae: 2.3105 - val_dist_relevant_mse: 13.1855 - val_dist_dist_iou_metric: 0.6403 - lr: 3.0000e-04
# Epoch 16/50
# 3/3 [==============================] - 0s 35ms/step- loss: 0.5439 - prob_loss: 0.0721 - dist_loss: 2.3592 - prob_kld: 0.0384 - dist_relevant_mae: 2.3586 - dist_relevant_mse: 12.9831 - dist_dist_iou_metric: 0.
# 100/100 [==============================] - 20s 199ms/step - loss: 0.5439 - prob_loss: 0.0721 - dist_loss: 2.3592 - prob_kld: 0.0384 - dist_relevant_mae: 2.3586 - dist_relevant_mse: 12.9831 - dist_dist_iou_metric: 0.6266 - val_loss: 0.5493 - val_prob_loss: 0.0912 - val_dist_loss: 2.2906 - val_prob_kld: 0.0487 - val_dist_relevant_mae: 2.2900 - val_dist_relevant_mse: 12.5887 - val_dist_dist_iou_metric: 0.6603 - lr: 3.0000e-04
# Epoch 17/50
# 3/3 [==============================] - 0s 36ms/step- loss: 0.5518 - prob_loss: 0.0792 - dist_loss: 2.3629 - prob_kld: 0.0420 - dist_relevant_mae: 2.3624 - dist_relevant_mse: 13.4886 - dist_dist_iou_metric: 0.
# 100/100 [==============================] - 19s 195ms/step - loss: 0.5518 - prob_loss: 0.0792 - dist_loss: 2.3629 - prob_kld: 0.0420 - dist_relevant_mae: 2.3624 - dist_relevant_mse: 13.4886 - dist_dist_iou_metric: 0.6373 - val_loss: 0.5423 - val_prob_loss: 0.0889 - val_dist_loss: 2.2674 - val_prob_kld: 0.0463 - val_dist_relevant_mae: 2.2669 - val_dist_relevant_mse: 12.9853 - val_dist_dist_iou_metric: 0.6412 - lr: 3.0000e-04
# Epoch 18/50
# 3/3 [==============================] - 0s 36ms/step- loss: 0.5219 - prob_loss: 0.0743 - dist_loss: 2.2380 - prob_kld: 0.0385 - dist_relevant_mae: 2.2375 - dist_relevant_mse: 12.3788 - dist_dist_iou_metric: 0.
# 100/100 [==============================] - 20s 196ms/step - loss: 0.5219 - prob_loss: 0.0743 - dist_loss: 2.2380 - prob_kld: 0.0385 - dist_relevant_mae: 2.2375 - dist_relevant_mse: 12.3788 - dist_dist_iou_metric: 0.6523 - val_loss: 0.5217 - val_prob_loss: 0.0960 - val_dist_loss: 2.1284 - val_prob_kld: 0.0535 - val_dist_relevant_mae: 2.1279 - val_dist_relevant_mse: 11.6426 - val_dist_dist_iou_metric: 0.6733 - lr: 3.0000e-04
# Epoch 19/50
# 3/3 [==============================] - 0s 158ms/step loss: 0.5170 - prob_loss: 0.0752 - dist_loss: 2.2089 - prob_kld: 0.0400 - dist_relevant_mae: 2.2084 - dist_relevant_mse: 12.2767 - dist_dist_iou_metric:
# 100/100 [==============================] - 21s 208ms/step - loss: 0.5170 - prob_loss: 0.0752 - dist_loss: 2.2089 - prob_kld: 0.0400 - dist_relevant_mae: 2.2084 - dist_relevant_mse: 12.2767 - dist_dist_iou_metric: 0.6570 - val_loss: 0.5192 - val_prob_loss: 0.0904 - val_dist_loss: 2.1440 - val_prob_kld: 0.0479 - val_dist_relevant_mae: 2.1435 - val_dist_relevant_mse: 12.0263 - val_dist_dist_iou_metric: 0.6675 - lr: 3.0000e-04
# Epoch 20/50
# 3/3 [==============================] - 0s 33ms/step- loss: 0.4990 - prob_loss: 0.0740 - dist_loss: 2.1253 - prob_kld: 0.0381 - dist_relevant_mae: 2.1248 - dist_relevant_mse: 11.6179 - dist_dist_iou_metric: 0.
# 100/100 [==============================] - 19s 194ms/step - loss: 0.4990 - prob_loss: 0.0740 - dist_loss: 2.1253 - prob_kld: 0.0381 - dist_relevant_mae: 2.1248 - dist_relevant_mse: 11.6179 - dist_dist_iou_metric: 0.6625 - val_loss: 0.5077 - val_prob_loss: 0.0888 - val_dist_loss: 2.0942 - val_prob_kld: 0.0463 - val_dist_relevant_mae: 2.0937 - val_dist_relevant_mse: 11.5676 - val_dist_dist_iou_metric: 0.6830 - lr: 3.0000e-04
# Epoch 21/50
# 3/3 [==============================] - 0s 36ms/step- loss: 0.4900 - prob_loss: 0.0734 - dist_loss: 2.0833 - prob_kld: 0.0367 - dist_relevant_mae: 2.0828 - dist_relevant_mse: 10.9943 - dist_dist_iou_metric: 0.
# 100/100 [==============================] - 19s 194ms/step - loss: 0.4900 - prob_loss: 0.0734 - dist_loss: 2.0833 - prob_kld: 0.0367 - dist_relevant_mae: 2.0828 - dist_relevant_mse: 10.9943 - dist_dist_iou_metric: 0.6740 - val_loss: 0.5092 - val_prob_loss: 0.0907 - val_dist_loss: 2.0923 - val_prob_kld: 0.0482 - val_dist_relevant_mae: 2.0918 - val_dist_relevant_mse: 11.4305 - val_dist_dist_iou_metric: 0.6790 - lr: 3.0000e-04
# Epoch 22/50
# 3/3 [==============================] - 0s 33ms/step- loss: 0.4923 - prob_loss: 0.0700 - dist_loss: 2.1112 - prob_kld: 0.0355 - dist_relevant_mae: 2.1107 - dist_relevant_mse: 11.3930 - dist_dist_iou_metric: 0.
# 100/100 [==============================] - 19s 191ms/step - loss: 0.4923 - prob_loss: 0.0700 - dist_loss: 2.1112 - prob_kld: 0.0355 - dist_relevant_mae: 2.1107 - dist_relevant_mse: 11.3930 - dist_dist_iou_metric: 0.6654 - val_loss: 0.5003 - val_prob_loss: 0.0877 - val_dist_loss: 2.0631 - val_prob_kld: 0.0452 - val_dist_relevant_mae: 2.0626 - val_dist_relevant_mse: 11.0493 - val_dist_dist_iou_metric: 0.6857 - lr: 3.0000e-04
# Epoch 23/50
# 3/3 [==============================] - 0s 39ms/step- loss: 0.5028 - prob_loss: 0.0767 - dist_loss: 2.1305 - prob_kld: 0.0390 - dist_relevant_mae: 2.1299 - dist_relevant_mse: 11.5390 - dist_dist_iou_metric: 0.
# 100/100 [==============================] - 19s 191ms/step - loss: 0.5028 - prob_loss: 0.0767 - dist_loss: 2.1305 - prob_kld: 0.0390 - dist_relevant_mae: 2.1299 - dist_relevant_mse: 11.5390 - dist_dist_iou_metric: 0.6727 - val_loss: 0.5028 - val_prob_loss: 0.0882 - val_dist_loss: 2.0730 - val_prob_kld: 0.0457 - val_dist_relevant_mae: 2.0724 - val_dist_relevant_mse: 11.1332 - val_dist_dist_iou_metric: 0.6925 - lr: 3.0000e-04
# Epoch 24/50
# 3/3 [==============================] - 0s 41ms/step- loss: 0.5012 - prob_loss: 0.0752 - dist_loss: 2.1299 - prob_kld: 0.0376 - dist_relevant_mae: 2.1294 - dist_relevant_mse: 11.4763 - dist_dist_iou_metric: 0.
# 100/100 [==============================] - 20s 204ms/step - loss: 0.5012 - prob_loss: 0.0752 - dist_loss: 2.1299 - prob_kld: 0.0376 - dist_relevant_mae: 2.1294 - dist_relevant_mse: 11.4763 - dist_dist_iou_metric: 0.6674 - val_loss: 0.4993 - val_prob_loss: 0.0854 - val_dist_loss: 2.0692 - val_prob_kld: 0.0429 - val_dist_relevant_mae: 2.0687 - val_dist_relevant_mse: 10.9270 - val_dist_dist_iou_metric: 0.6895 - lr: 3.0000e-04
# Epoch 25/50
# 3/3 [==============================] - 0s 36ms/step- loss: 0.4908 - prob_loss: 0.0708 - dist_loss: 2.0998 - prob_kld: 0.0361 - dist_relevant_mae: 2.0993 - dist_relevant_mse: 11.3479 - dist_dist_iou_metric: 0.
# 100/100 [==============================] - 19s 190ms/step - loss: 0.4908 - prob_loss: 0.0708 - dist_loss: 2.0998 - prob_kld: 0.0361 - dist_relevant_mae: 2.0993 - dist_relevant_mse: 11.3479 - dist_dist_iou_metric: 0.6738 - val_loss: 0.5130 - val_prob_loss: 0.0898 - val_dist_loss: 2.1163 - val_prob_kld: 0.0472 - val_dist_relevant_mae: 2.1158 - val_dist_relevant_mse: 11.2155 - val_dist_dist_iou_metric: 0.6640 - lr: 3.0000e-04
# Epoch 26/50
# 3/3 [==============================] - 0s 38ms/step- loss: 0.4814 - prob_loss: 0.0721 - dist_loss: 2.0462 - prob_kld: 0.0370 - dist_relevant_mae: 2.0457 - dist_relevant_mse: 10.6059 - dist_dist_iou_metric: 0.
# 100/100 [==============================] - 19s 191ms/step - loss: 0.4814 - prob_loss: 0.0721 - dist_loss: 2.0462 - prob_kld: 0.0370 - dist_relevant_mae: 2.0457 - dist_relevant_mse: 10.6059 - dist_dist_iou_metric: 0.6685 - val_loss: 0.5087 - val_prob_loss: 0.0886 - val_dist_loss: 2.1006 - val_prob_kld: 0.0461 - val_dist_relevant_mae: 2.1002 - val_dist_relevant_mse: 11.5993 - val_dist_dist_iou_metric: 0.6679 - lr: 3.0000e-04
# Epoch 27/50
# 3/3 [==============================] - 0s 32ms/step- loss: 0.4750 - prob_loss: 0.0743 - dist_loss: 2.0034 - prob_kld: 0.0374 - dist_relevant_mae: 2.0029 - dist_relevant_mse: 10.4448 - dist_dist_iou_metric: 0.
# 100/100 [==============================] - 20s 199ms/step - loss: 0.4750 - prob_loss: 0.0743 - dist_loss: 2.0034 - prob_kld: 0.0374 - dist_relevant_mae: 2.0029 - dist_relevant_mse: 10.4448 - dist_dist_iou_metric: 0.6869 - val_loss: 0.4777 - val_prob_loss: 0.0854 - val_dist_loss: 1.9613 - val_prob_kld: 0.0429 - val_dist_relevant_mae: 1.9607 - val_dist_relevant_mse: 10.3380 - val_dist_dist_iou_metric: 0.7014 - lr: 3.0000e-04
# Epoch 28/50
# 3/3 [==============================] - 0s 37ms/step- loss: 0.4770 - prob_loss: 0.0696 - dist_loss: 2.0372 - prob_kld: 0.0344 - dist_relevant_mae: 2.0367 - dist_relevant_mse: 10.4367 - dist_dist_iou_metric: 0.
# 100/100 [==============================] - 19s 188ms/step - loss: 0.4770 - prob_loss: 0.0696 - dist_loss: 2.0372 - prob_kld: 0.0344 - dist_relevant_mae: 2.0367 - dist_relevant_mse: 10.4367 - dist_dist_iou_metric: 0.6828 - val_loss: 0.5477 - val_prob_loss: 0.0889 - val_dist_loss: 2.2940 - val_prob_kld: 0.0464 - val_dist_relevant_mae: 2.2934 - val_dist_relevant_mse: 11.9496 - val_dist_dist_iou_metric: 0.6835 - lr: 3.0000e-04
# Epoch 29/50
# 3/3 [==============================] - 0s 36ms/step- loss: 0.4856 - prob_loss: 0.0742 - dist_loss: 2.0567 - prob_kld: 0.0379 - dist_relevant_mae: 2.0562 - dist_relevant_mse: 11.0898 - dist_dist_iou_metric: 0.
# 100/100 [==============================] - 20s 195ms/step - loss: 0.4856 - prob_loss: 0.0742 - dist_loss: 2.0567 - prob_kld: 0.0379 - dist_relevant_mae: 2.0562 - dist_relevant_mse: 11.0898 - dist_dist_iou_metric: 0.6804 - val_loss: 0.4707 - val_prob_loss: 0.0862 - val_dist_loss: 1.9227 - val_prob_kld: 0.0437 - val_dist_relevant_mae: 1.9221 - val_dist_relevant_mse: 9.9726 - val_dist_dist_iou_metric: 0.7053 - lr: 3.0000e-04
# Epoch 30/50
# 3/3 [==============================] - 0s 41ms/step- loss: 0.4697 - prob_loss: 0.0729 - dist_loss: 1.9840 - prob_kld: 0.0361 - dist_relevant_mae: 1.9835 - dist_relevant_mse: 10.6609 - dist_dist_iou_metric: 0.
# 100/100 [==============================] - 19s 192ms/step - loss: 0.4697 - prob_loss: 0.0729 - dist_loss: 1.9840 - prob_kld: 0.0361 - dist_relevant_mae: 1.9835 - dist_relevant_mse: 10.6609 - dist_dist_iou_metric: 0.6868 - val_loss: 0.4851 - val_prob_loss: 0.0917 - val_dist_loss: 1.9672 - val_prob_kld: 0.0492 - val_dist_relevant_mae: 1.9667 - val_dist_relevant_mse: 10.0787 - val_dist_dist_iou_metric: 0.6998 - lr: 3.0000e-04
# Epoch 31/50
# 3/3 [==============================] - 0s 37ms/step- loss: 0.4510 - prob_loss: 0.0679 - dist_loss: 1.9155 - prob_kld: 0.0348 - dist_relevant_mae: 1.9150 - dist_relevant_mse: 9.8022 - dist_dist_iou_metric: 0.
# 100/100 [==============================] - 18s 184ms/step - loss: 0.4510 - prob_loss: 0.0679 - dist_loss: 1.9155 - prob_kld: 0.0348 - dist_relevant_mae: 1.9150 - dist_relevant_mse: 9.8022 - dist_dist_iou_metric: 0.6867 - val_loss: 0.5001 - val_prob_loss: 0.0868 - val_dist_loss: 2.0665 - val_prob_kld: 0.0443 - val_dist_relevant_mae: 2.0660 - val_dist_relevant_mse: 10.5328 - val_dist_dist_iou_metric: 0.7014 - lr: 3.0000e-04
# Epoch 32/50
# 3/3 [==============================] - 0s 38ms/step- loss: 0.4757 - prob_loss: 0.0728 - dist_loss: 2.0147 - prob_kld: 0.0364 - dist_relevant_mae: 2.0142 - dist_relevant_mse: 10.5597 - dist_dist_iou_metric: 0.
# 100/100 [==============================] - 19s 194ms/step - loss: 0.4757 - prob_loss: 0.0728 - dist_loss: 2.0147 - prob_kld: 0.0364 - dist_relevant_mae: 2.0142 - dist_relevant_mse: 10.5597 - dist_dist_iou_metric: 0.6874 - val_loss: 0.4929 - val_prob_loss: 0.0943 - val_dist_loss: 1.9931 - val_prob_kld: 0.0518 - val_dist_relevant_mae: 1.9926 - val_dist_relevant_mse: 10.6779 - val_dist_dist_iou_metric: 0.6897 - lr: 3.0000e-04
# Epoch 33/50
# 3/3 [==============================] - 0s 35ms/step- loss: 0.4527 - prob_loss: 0.0718 - dist_loss: 1.9042 - prob_kld: 0.0358 - dist_relevant_mae: 1.9037 - dist_relevant_mse: 9.5625 - dist_dist_iou_metric: 0.
# 100/100 [==============================] - 19s 193ms/step - loss: 0.4527 - prob_loss: 0.0718 - dist_loss: 1.9042 - prob_kld: 0.0358 - dist_relevant_mae: 1.9037 - dist_relevant_mse: 9.5625 - dist_dist_iou_metric: 0.6968 - val_loss: 0.4857 - val_prob_loss: 0.0849 - val_dist_loss: 2.0043 - val_prob_kld: 0.0423 - val_dist_relevant_mae: 2.0038 - val_dist_relevant_mse: 10.3497 - val_dist_dist_iou_metric: 0.7000 - lr: 3.0000e-04
# Epoch 34/50
# 3/3 [==============================] - 0s 35ms/step- loss: 0.4645 - prob_loss: 0.0652 - dist_loss: 1.9961 - prob_kld: 0.0327 - dist_relevant_mae: 1.9956 - dist_relevant_mse: 10.5347 - dist_dist_iou_metric: 0.
# 100/100 [==============================] - 19s 186ms/step - loss: 0.4645 - prob_loss: 0.0652 - dist_loss: 1.9961 - prob_kld: 0.0327 - dist_relevant_mae: 1.9956 - dist_relevant_mse: 10.5347 - dist_dist_iou_metric: 0.6838 - val_loss: 0.5320 - val_prob_loss: 0.0851 - val_dist_loss: 2.2341 - val_prob_kld: 0.0426 - val_dist_relevant_mae: 2.2337 - val_dist_relevant_mse: 12.2049 - val_dist_dist_iou_metric: 0.6450 - lr: 3.0000e-04
# Epoch 35/50
# 3/3 [==============================] - 0s 35ms/step- loss: 0.4516 - prob_loss: 0.0694 - dist_loss: 1.9110 - prob_kld: 0.0354 - dist_relevant_mae: 1.9105 - dist_relevant_mse: 9.5807 - dist_dist_iou_metric: 0.
# 100/100 [==============================] - 19s 190ms/step - loss: 0.4516 - prob_loss: 0.0694 - dist_loss: 1.9110 - prob_kld: 0.0354 - dist_relevant_mae: 1.9105 - dist_relevant_mse: 9.5807 - dist_dist_iou_metric: 0.6898 - val_loss: 0.4678 - val_prob_loss: 0.0835 - val_dist_loss: 1.9214 - val_prob_kld: 0.0410 - val_dist_relevant_mae: 1.9209 - val_dist_relevant_mse: 10.1768 - val_dist_dist_iou_metric: 0.7035 - lr: 3.0000e-04
# Epoch 36/50
# 3/3 [==============================] - 0s 39ms/step- loss: 0.4540 - prob_loss: 0.0714 - dist_loss: 1.9131 - prob_kld: 0.0357 - dist_relevant_mae: 1.9126 - dist_relevant_mse: 9.8233 - dist_dist_iou_metric: 0.
# 100/100 [==============================] - 19s 189ms/step - loss: 0.4540 - prob_loss: 0.0714 - dist_loss: 1.9131 - prob_kld: 0.0357 - dist_relevant_mae: 1.9126 - dist_relevant_mse: 9.8233 - dist_dist_iou_metric: 0.6977 - val_loss: 0.4930 - val_prob_loss: 0.0850 - val_dist_loss: 2.0402 - val_prob_kld: 0.0424 - val_dist_relevant_mae: 2.0398 - val_dist_relevant_mse: 10.7210 - val_dist_dist_iou_metric: 0.6974 - lr: 3.0000e-04
# Epoch 37/50
# 3/3 [==============================] - 0s 35ms/step- loss: 0.4494 - prob_loss: 0.0688 - dist_loss: 1.9031 - prob_kld: 0.0335 - dist_relevant_mae: 1.9026 - dist_relevant_mse: 9.6652 - dist_dist_iou_metric: 0.
# 100/100 [==============================] - 19s 192ms/step - loss: 0.4494 - prob_loss: 0.0688 - dist_loss: 1.9031 - prob_kld: 0.0335 - dist_relevant_mae: 1.9026 - dist_relevant_mse: 9.6652 - dist_dist_iou_metric: 0.7012 - val_loss: 0.4636 - val_prob_loss: 0.0828 - val_dist_loss: 1.9039 - val_prob_kld: 0.0403 - val_dist_relevant_mae: 1.9034 - val_dist_relevant_mse: 9.5683 - val_dist_dist_iou_metric: 0.6940 - lr: 3.0000e-04
# Epoch 38/50
# 3/3 [==============================] - 0s 38ms/step- loss: 0.4611 - prob_loss: 0.0716 - dist_loss: 1.9474 - prob_kld: 0.0348 - dist_relevant_mae: 1.9469 - dist_relevant_mse: 9.8789 - dist_dist_iou_metric: 0.
# 100/100 [==============================] - 20s 195ms/step - loss: 0.4611 - prob_loss: 0.0716 - dist_loss: 1.9474 - prob_kld: 0.0348 - dist_relevant_mae: 1.9469 - dist_relevant_mse: 9.8789 - dist_dist_iou_metric: 0.6933 - val_loss: 0.4935 - val_prob_loss: 0.0877 - val_dist_loss: 2.0290 - val_prob_kld: 0.0452 - val_dist_relevant_mae: 2.0285 - val_dist_relevant_mse: 10.5013 - val_dist_dist_iou_metric: 0.6766 - lr: 3.0000e-04
# Epoch 39/50
# 3/3 [==============================] - 0s 37ms/step- loss: 0.4460 - prob_loss: 0.0680 - dist_loss: 1.8900 - prob_kld: 0.0344 - dist_relevant_mae: 1.8895 - dist_relevant_mse: 9.7969 - dist_dist_iou_metric: 0.
# 100/100 [==============================] - 20s 196ms/step - loss: 0.4460 - prob_loss: 0.0680 - dist_loss: 1.8900 - prob_kld: 0.0344 - dist_relevant_mae: 1.8895 - dist_relevant_mse: 9.7969 - dist_dist_iou_metric: 0.6989 - val_loss: 0.4500 - val_prob_loss: 0.0847 - val_dist_loss: 1.8264 - val_prob_kld: 0.0422 - val_dist_relevant_mae: 1.8259 - val_dist_relevant_mse: 9.4886 - val_dist_dist_iou_metric: 0.7072 - lr: 3.0000e-04
# Epoch 40/50
# 3/3 [==============================] - 0s 32ms/step- loss: 0.4422 - prob_loss: 0.0711 - dist_loss: 1.8555 - prob_kld: 0.0336 - dist_relevant_mae: 1.8550 - dist_relevant_mse: 9.2637 - dist_dist_iou_metric: 0.
# 100/100 [==============================] - 19s 194ms/step - loss: 0.4422 - prob_loss: 0.0711 - dist_loss: 1.8555 - prob_kld: 0.0336 - dist_relevant_mae: 1.8550 - dist_relevant_mse: 9.2637 - dist_dist_iou_metric: 0.7081 - val_loss: 0.4679 - val_prob_loss: 0.0837 - val_dist_loss: 1.9214 - val_prob_kld: 0.0411 - val_dist_relevant_mae: 1.9209 - val_dist_relevant_mse: 10.7141 - val_dist_dist_iou_metric: 0.7003 - lr: 3.0000e-04
# Epoch 41/50
# 3/3 [==============================] - 0s 35ms/step- loss: 0.4462 - prob_loss: 0.0723 - dist_loss: 1.8696 - prob_kld: 0.0352 - dist_relevant_mae: 1.8691 - dist_relevant_mse: 9.3692 - dist_dist_iou_metric: 0.
# 100/100 [==============================] - 20s 202ms/step - loss: 0.4462 - prob_loss: 0.0723 - dist_loss: 1.8696 - prob_kld: 0.0352 - dist_relevant_mae: 1.8691 - dist_relevant_mse: 9.3692 - dist_dist_iou_metric: 0.7056 - val_loss: 0.4738 - val_prob_loss: 0.0860 - val_dist_loss: 1.9389 - val_prob_kld: 0.0435 - val_dist_relevant_mae: 1.9385 - val_dist_relevant_mse: 10.1233 - val_dist_dist_iou_metric: 0.6871 - lr: 3.0000e-04
# Epoch 42/50
# 3/3 [==============================] - 0s 36ms/step- loss: 0.4405 - prob_loss: 0.0678 - dist_loss: 1.8635 - prob_kld: 0.0327 - dist_relevant_mae: 1.8630 - dist_relevant_mse: 9.2059 - dist_dist_iou_metric: 0.
# 100/100 [==============================] - 20s 199ms/step - loss: 0.4405 - prob_loss: 0.0678 - dist_loss: 1.8635 - prob_kld: 0.0327 - dist_relevant_mae: 1.8630 - dist_relevant_mse: 9.2059 - dist_dist_iou_metric: 0.7050 - val_loss: 0.4553 - val_prob_loss: 0.0852 - val_dist_loss: 1.8503 - val_prob_kld: 0.0427 - val_dist_relevant_mae: 1.8498 - val_dist_relevant_mse: 9.7418 - val_dist_dist_iou_metric: 0.7183 - lr: 3.0000e-04
# Epoch 43/50
# 3/3 [==============================] - 0s 40ms/step- loss: 0.4569 - prob_loss: 0.0748 - dist_loss: 1.9104 - prob_kld: 0.0381 - dist_relevant_mae: 1.9099 - dist_relevant_mse: 9.9086 - dist_dist_iou_metric: 0.
# 100/100 [==============================] - 20s 199ms/step - loss: 0.4569 - prob_loss: 0.0748 - dist_loss: 1.9104 - prob_kld: 0.0381 - dist_relevant_mae: 1.9099 - dist_relevant_mse: 9.9086 - dist_dist_iou_metric: 0.7049 - val_loss: 0.4594 - val_prob_loss: 0.0831 - val_dist_loss: 1.8816 - val_prob_kld: 0.0405 - val_dist_relevant_mae: 1.8811 - val_dist_relevant_mse: 9.5144 - val_dist_dist_iou_metric: 0.7084 - lr: 3.0000e-04
# Epoch 44/50
# 3/3 [==============================] - 0s 32ms/step- loss: 0.4252 - prob_loss: 0.0673 - dist_loss: 1.7893 - prob_kld: 0.0326 - dist_relevant_mae: 1.7888 - dist_relevant_mse: 8.8144 - dist_dist_iou_metric: 0.
# 100/100 [==============================] - 20s 199ms/step - loss: 0.4252 - prob_loss: 0.0673 - dist_loss: 1.7893 - prob_kld: 0.0326 - dist_relevant_mae: 1.7888 - dist_relevant_mse: 8.8144 - dist_dist_iou_metric: 0.7123 - val_loss: 0.4321 - val_prob_loss: 0.0816 - val_dist_loss: 1.7525 - val_prob_kld: 0.0391 - val_dist_relevant_mae: 1.7520 - val_dist_relevant_mse: 8.6617 - val_dist_dist_iou_metric: 0.7235 - lr: 3.0000e-04
# Epoch 45/50
# 3/3 [==============================] - 0s 34ms/step- loss: 0.4699 - prob_loss: 0.0706 - dist_loss: 1.9964 - prob_kld: 0.0343 - dist_relevant_mae: 1.9959 - dist_relevant_mse: 10.1131 - dist_dist_iou_metric: 0.
# 100/100 [==============================] - 19s 192ms/step - loss: 0.4699 - prob_loss: 0.0706 - dist_loss: 1.9964 - prob_kld: 0.0343 - dist_relevant_mae: 1.9959 - dist_relevant_mse: 10.1131 - dist_dist_iou_metric: 0.6938 - val_loss: 0.4616 - val_prob_loss: 0.0847 - val_dist_loss: 1.8846 - val_prob_kld: 0.0421 - val_dist_relevant_mae: 1.8841 - val_dist_relevant_mse: 9.5951 - val_dist_dist_iou_metric: 0.7206 - lr: 3.0000e-04
# Epoch 46/50
# 3/3 [==============================] - 0s 35ms/step- loss: 0.4258 - prob_loss: 0.0688 - dist_loss: 1.7845 - prob_kld: 0.0323 - dist_relevant_mae: 1.7840 - dist_relevant_mse: 8.6468 - dist_dist_iou_metric: 0.
# 100/100 [==============================] - 19s 192ms/step - loss: 0.4258 - prob_loss: 0.0688 - dist_loss: 1.7845 - prob_kld: 0.0323 - dist_relevant_mae: 1.7840 - dist_relevant_mse: 8.6468 - dist_dist_iou_metric: 0.7180 - val_loss: 0.4512 - val_prob_loss: 0.0828 - val_dist_loss: 1.8422 - val_prob_kld: 0.0402 - val_dist_relevant_mae: 1.8417 - val_dist_relevant_mse: 9.2096 - val_dist_dist_iou_metric: 0.7077 - lr: 3.0000e-04
# Epoch 47/50
# 3/3 [==============================] - 0s 38ms/step- loss: 0.4346 - prob_loss: 0.0694 - dist_loss: 1.8260 - prob_kld: 0.0332 - dist_relevant_mae: 1.8255 - dist_relevant_mse: 8.8885 - dist_dist_iou_metric: 0.
# 100/100 [==============================] - 20s 199ms/step - loss: 0.4346 - prob_loss: 0.0694 - dist_loss: 1.8260 - prob_kld: 0.0332 - dist_relevant_mae: 1.8255 - dist_relevant_mse: 8.8885 - dist_dist_iou_metric: 0.7121 - val_loss: 0.4396 - val_prob_loss: 0.0831 - val_dist_loss: 1.7826 - val_prob_kld: 0.0406 - val_dist_relevant_mae: 1.7822 - val_dist_relevant_mse: 9.0490 - val_dist_dist_iou_metric: 0.7204 - lr: 3.0000e-04
# Epoch 48/50
# 3/3 [==============================] - 0s 40ms/step- loss: 0.4322 - prob_loss: 0.0723 - dist_loss: 1.7994 - prob_kld: 0.0349 - dist_relevant_mae: 1.7990 - dist_relevant_mse: 9.1691 - dist_dist_iou_metric: 0.
# 100/100 [==============================] - 20s 203ms/step - loss: 0.4322 - prob_loss: 0.0723 - dist_loss: 1.7994 - prob_kld: 0.0349 - dist_relevant_mae: 1.7990 - dist_relevant_mse: 9.1691 - dist_dist_iou_metric: 0.7178 - val_loss: 0.4178 - val_prob_loss: 0.0810 - val_dist_loss: 1.6840 - val_prob_kld: 0.0385 - val_dist_relevant_mae: 1.6835 - val_dist_relevant_mse: 8.0965 - val_dist_dist_iou_metric: 0.7356 - lr: 3.0000e-04
# Epoch 49/50
# 3/3 [==============================] - 0s 34ms/step- loss: 0.4185 - prob_loss: 0.0681 - dist_loss: 1.7519 - prob_kld: 0.0329 - dist_relevant_mae: 1.7514 - dist_relevant_mse: 8.2861 - dist_dist_iou_metric: 0.
# 100/100 [==============================] - 19s 189ms/step - loss: 0.4185 - prob_loss: 0.0681 - dist_loss: 1.7519 - prob_kld: 0.0329 - dist_relevant_mae: 1.7514 - dist_relevant_mse: 8.2861 - dist_dist_iou_metric: 0.7208 - val_loss: 0.4429 - val_prob_loss: 0.0844 - val_dist_loss: 1.7925 - val_prob_kld: 0.0419 - val_dist_relevant_mae: 1.7920 - val_dist_relevant_mse: 9.1129 - val_dist_dist_iou_metric: 0.7258 - lr: 3.0000e-04
# Epoch 50/50
# 3/3 [==============================] - 0s 38ms/step- loss: 0.4155 - prob_loss: 0.0708 - dist_loss: 1.7232 - prob_kld: 0.0335 - dist_relevant_mae: 1.7227 - dist_relevant_mse: 8.1711 - dist_dist_iou_metric: 0.
# 100/100 [==============================] - 20s 197ms/step - loss: 0.4155 - prob_loss: 0.0708 - dist_loss: 1.7232 - prob_kld: 0.0335 - dist_relevant_mae: 1.7227 - dist_relevant_mse: 8.1711 - dist_dist_iou_metric: 0.7254 - val_loss: 0.4407 - val_prob_loss: 0.0812 - val_dist_loss: 1.7976 - val_prob_kld: 0.0387 - val_dist_relevant_mae: 1.7971 - val_dist_relevant_mse: 9.1711 - val_dist_dist_iou_metric: 0.7263 - lr: 3.0000e-04
#
# Loading network weights from 'weights_best.h5'.

# %%
X_train.shape, Y_train.shape, X_val.shape, Y_val.shape
# Out:
# ((5, 96, 288, 288, 1),
#  (5, 96, 288, 288),
#  (5, 96, 288, 288, 1),
#  (5, 96, 288, 288))

# %%
n=2
labels, details = model.predict_instances(X_train[n], prob_thresh=0.7, nms_thresh=0.2)
fig = show_xy_zy_slice(X_train[n], int(X_train[0].shape[2]/2), int(X_train[0].shape[1]/2), 10,1.4,1.4, figsize=(8,6))
fig = show_xy_zy_slice(Y_train[n], int(Y_train[0].shape[2]/2), int(Y_train[0].shape[1]/2), 10,1.4,1.4, colormap=colormap, figsize=(8,6))
fig = show_xy_zy_slice(labels, int(labels.shape[2]/2), int(labels.shape[1]/2), 10,1.4,1.4, colormap=colormap, figsize=(8,6))

# %%
X_train[n].shape
# Out:
# (16, 128, 128, 1)

# %%
import napari
viewer = napari.Viewer()
viewer.add_image(X_train[n].squeeze())
viewer.add_labels(labels)
viewer.add_labels(Y_train[n].squeeze())
viewer.show()
# Out:
# napari.manifest -> 'napari-hello' could not be imported: Cannot find module 'napari_plugins' declared in entrypoint: 'napari_plugins:napari.yaml'

# %%
X_train[n].shape, X_train[n].min(), X_train[n].max()
# Out:
# ((96, 256, 256, 1), -0.009466953, 1.2167182)

# %%
X_train[0].max()
# Out:
# 1.2449049
