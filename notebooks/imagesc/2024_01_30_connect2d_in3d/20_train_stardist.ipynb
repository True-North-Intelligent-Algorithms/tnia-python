# %% [markdown]
# # Train a stardist neural network for segmentation
#
# This notebook uses stardist2d and a connect-in-3D strategy to generate labels for training a stardist3D network.

# %%
from skimage.io import imread, imsave
from tnia.plotting.projections import show_xyz_slice, show_xyz_max, show_xy_zy_max, show_xy_zy_slice
from random import randint
import numpy as np
import os
from skimage.measure import label
from tnia.deeplearning.dl_helper import collect_training_data
from stardist import calculate_extents

from tnia.plotting.plt_helper import random_label_cmap
colormap=random_label_cmap()

# %% [markdown]
# # Get the list of visible devices and confirm that GPU is available
#
# ... or else training will take a long time

# %%
import tensorflow as tf
visible_devices = tf.config.list_physical_devices()
print(visible_devices)
# Out:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'), PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# ## Define model path
#
# This is the path where the model will be saved, change to be local to your machine

# %%
from pathlib import Path
tnia_images_path = Path("D:/images/tnia-python-images")
parent_path = tnia_images_path / "imagesc/2024_01_30_connect2d_in3d"
model_path = parent_path / 'models'
print(model_path)
patches_path = parent_path / 'patches'
print(patches_path)
# Out:
# D:\images\tnia-python-images\imagesc\2024_01_30_connect2d_in3d\models
# D:\images\tnia-python-images\imagesc\2024_01_30_connect2d_in3d\patches

# %% [markdown]
# # Load the corrupted images and ground truth images

# %%
paths = [patches_path]

X = []
Y = []

for path in paths:
    X_, Y_ = collect_training_data(path, sub_sample=1, downsample=False, normalize_truth=False, training_multiple=16)

    print(path)
    print(len(X_))
    print()
    X.extend(X_)
    Y.extend(Y_)

print(len(X))
print(len(Y))

fig = show_xy_zy_max(X[0])
fig = show_xy_zy_max(Y[0])
# Out:
# D:\images\tnia-python-images\imagesc\2024_01_30_connect2d_in3d\patches
# 5
#
# 5
# 5

# %% [markdown]
# ## Shuffle the datasets

# %%
from tnia.deeplearning.dl_helper import shuffle

X, Y = shuffle(X, Y)

X = np.array(X)
Y = np.array(Y).astype(np.uint16)

# %%
print(X.max())
print(Y.max())
# Out:
# 1.3031219
# 1274

# %% [markdown]
# ## Import Stardist

# %%
from stardist.models import Config3D, StarDist3D

# %%
extents = calculate_extents(Y.squeeze().astype('uint16'))

extents = [80, 20, 20]
anisotropy = tuple(np.max(extents) / extents)
#anisotropy = (3,1,1)

print('extents', extents)
print('anisotropy', anisotropy)
# Out:
# extents [80, 20, 20]
# anisotropy (1.0, 4.0, 4.0)

# %%
from stardist import Rays_GoldenSpiral
from stardist import Rays_Octo
n_channel_in =1
axes = 'ZYX'

n_rays = 96 

# Use rays on a Fibonacci lattice adjusted for measured anisotropy of the training data
rays = Rays_GoldenSpiral(n_rays, anisotropy=anisotropy)
model_name = 'stardist_model_96ray'

#rays = Rays_Octo(n_level=1) 
#model_name = 'stardist_octo'
# create a csbdeep config
# we mostly use the default settings except in this case unet_n_depth=4, so we downsampling 4 times and can use low level features
# consider changing the number of filters (unet_n_first) to save memory

config = Config3D (rays=rays, axes=axes,n_channel_in=1, train_patch_size=(96, 64, 64), grid=(1,2,2), unet_n_depth=3)

#config = Config(axes, n_channel_in, n_channel_out, train_steps_per_epoch=20, train_epochs=50, unet_n_depth=4)
#print(config)
new_model = False 


if new_model:
    #model = StarDist3D(config, name='stardist_model_48ray_combined', basedir=model_path)
    print('initializing new model')
    model = StarDist3D(config, name=model_name, basedir=model_path)
else:
    model = StarDist3D(None,  name=model_name, basedir=model_path)
vars(config)
# Out:
# model3d.py (223): Mismatch of 'anisotropy' of rays and 'anisotropy'.
# Loading network weights from 'weights_best.h5'.
# Couldn't load thresholds from 'thresholds.json', using default values. (Call 'optimize_thresholds' to change that.)
# Using default values: prob_thresh=0.5, nms_thresh=0.4.
# {'n_dim': 3,
#  'axes': 'ZYXC',
#  'n_channel_in': 1,
#  'n_channel_out': 97,
#  'train_checkpoint': 'weights_best.h5',
#  'train_checkpoint_last': 'weights_last.h5',
#  'train_checkpoint_epoch': 'weights_now.h5',
#  'n_rays': 96,
#  'grid': (1, 2, 2),
#  'anisotropy': None,
#  'backbone': 'unet',
#  'rays_json': {'name': 'Rays_GoldenSpiral',
#   'kwargs': {'n': 96, 'anisotropy': (1.0, 4.0, 4.0)}},
#  'n_classes': None,
#  'unet_n_depth': 3,
#  'unet_kernel_size': (3, 3, 3),
#  'unet_n_filter_base': 32,
#  'unet_n_conv_per_depth': 2,
#  'unet_pool': (2, 2, 2),
#  'unet_activation': 'relu',
#  'unet_last_activation': 'relu',
#  'unet_batch_norm': False,
#  'unet_dropout': 0.0,
#  'unet_prefix': '',
#  'net_conv_after_unet': 128,
#  'net_input_shape': (None, None, None, 1),
#  'net_mask_shape': (None, None, None, 1),
#  'train_patch_size': (96, 64, 64),
#  'train_background_reg': 0.0001,
#  'train_foreground_only': 0.9,
#  'train_sample_cache': True,
#  'train_dist_loss': 'mae',
#  'train_loss_weights': (1, 0.2),
#  'train_class_weights': (1, 1),
#  'train_epochs': 400,
#  'train_steps_per_epoch': 100,
#  'train_learning_rate': 0.0003,
#  'train_batch_size': 1,
#  'train_n_val_patches': None,
#  'train_tensorboard': True,
#  'train_reduce_lr': {'factor': 0.5, 'patience': 40, 'min_delta': 0},
#  'use_gpu': False}

# %%
config.anisotropy, config.grid
median_size = calculate_extents(Y[1:2], np.median)
fov = np.array(model._axes_tile_overlap('ZYX'))
print(f"median object size:      {median_size}")
print(f"network field of view :  {fov}")
if any(median_size > fov):
    print("WARNING: median object size larger than field of view of the neural network.")
# Out:
# median object size:      [32. 33. 34.]
# network field of view :  [32 64 64]

# %%
X_train=X
Y_train=Y
X_val=X
Y_val=Y

# %%
model.train(X_train, Y_train, validation_data=(X_val,Y_val),epochs=50, steps_per_epoch=100)
# Out:
# Epoch 1/50
# WARNING:tensorflow:AutoGraph could not transform <function _gcd_import at 0x000001A62AFD13A0> and will run it as-is.
# Cause: Unable to locate the source code of <function _gcd_import at 0x000001A62AFD13A0>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function _gcd_import at 0x000001A62AFD13A0> and will run it as-is.
# Cause: Unable to locate the source code of <function _gcd_import at 0x000001A62AFD13A0>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 3/3 [==============================] - 0s 26ms/step- loss: 0.7134 - prob_loss: 0.1390 - dist_loss: 2.8720 - prob_kld: 0.0250 - dist_relevant_mae: 2.8716 - dist_relevant_mse: 24.6969 - dist_dist_iou_metric: 0.
# 100/100 [==============================] - 42s 385ms/step - loss: 0.7134 - prob_loss: 0.1390 - dist_loss: 2.8720 - prob_kld: 0.0250 - dist_relevant_mae: 2.8716 - dist_relevant_mse: 24.6969 - dist_dist_iou_metric: 0.6314 - val_loss: 0.7279 - val_prob_loss: 0.1200 - val_dist_loss: 3.0396 - val_prob_kld: 0.0179 - val_dist_relevant_mae: 3.0392 - val_dist_relevant_mse: 25.3371 - val_dist_dist_iou_metric: 0.6476 - lr: 3.0000e-04
# Epoch 2/50
# 3/3 [==============================] - 0s 21ms/step- loss: 0.6762 - prob_loss: 0.1289 - dist_loss: 2.7367 - prob_kld: 0.0226 - dist_relevant_mae: 2.7363 - dist_relevant_mse: 22.1662 - dist_dist_iou_metric: 0.63
# 100/100 [==============================] - 35s 352ms/step - loss: 0.6762 - prob_loss: 0.1289 - dist_loss: 2.7367 - prob_kld: 0.0226 - dist_relevant_mae: 2.7363 - dist_relevant_mse: 22.1662 - dist_dist_iou_metric: 0.6366 - val_loss: 0.7123 - val_prob_loss: 0.1192 - val_dist_loss: 2.9657 - val_prob_kld: 0.0171 - val_dist_relevant_mae: 2.9653 - val_dist_relevant_mse: 25.4808 - val_dist_dist_iou_metric: 0.6481 - lr: 3.0000e-04
# Epoch 3/50
# 3/3 [==============================] - 0s 15ms/step- loss: 0.6884 - prob_loss: 0.1388 - dist_loss: 2.7478 - prob_kld: 0.0236 - dist_relevant_mae: 2.7474 - dist_relevant_mse: 22.7134 - dist_dist_iou_metric: 0.64
# 100/100 [==============================] - 38s 382ms/step - loss: 0.6884 - prob_loss: 0.1388 - dist_loss: 2.7478 - prob_kld: 0.0236 - dist_relevant_mae: 2.7474 - dist_relevant_mse: 22.7134 - dist_dist_iou_metric: 0.6425 - val_loss: 0.6458 - val_prob_loss: 0.1178 - val_dist_loss: 2.6397 - val_prob_kld: 0.0157 - val_dist_relevant_mae: 2.6394 - val_dist_relevant_mse: 23.2797 - val_dist_dist_iou_metric: 0.6630 - lr: 3.0000e-04
# Epoch 4/50
# 3/3 [==============================] - 0s 23ms/step- loss: 0.6889 - prob_loss: 0.1312 - dist_loss: 2.7884 - prob_kld: 0.0218 - dist_relevant_mae: 2.7880 - dist_relevant_mse: 23.2414 - dist_dist_iou_metric: 0.63
# 100/100 [==============================] - 37s 367ms/step - loss: 0.6889 - prob_loss: 0.1312 - dist_loss: 2.7884 - prob_kld: 0.0218 - dist_relevant_mae: 2.7880 - dist_relevant_mse: 23.2414 - dist_dist_iou_metric: 0.6372 - val_loss: 0.6712 - val_prob_loss: 0.1189 - val_dist_loss: 2.7616 - val_prob_kld: 0.0168 - val_dist_relevant_mae: 2.7612 - val_dist_relevant_mse: 26.2690 - val_dist_dist_iou_metric: 0.6520 - lr: 3.0000e-04
# Epoch 5/50
# 3/3 [==============================] - 0s 16ms/step- loss: 0.7163 - prob_loss: 0.1483 - dist_loss: 2.8404 - prob_kld: 0.0254 - dist_relevant_mae: 2.8400 - dist_relevant_mse: 24.2709 - dist_dist_iou_metric: 0.64
# 100/100 [==============================] - 40s 398ms/step - loss: 0.7163 - prob_loss: 0.1483 - dist_loss: 2.8404 - prob_kld: 0.0254 - dist_relevant_mae: 2.8400 - dist_relevant_mse: 24.2709 - dist_dist_iou_metric: 0.6428 - val_loss: 0.6737 - val_prob_loss: 0.1199 - val_dist_loss: 2.7694 - val_prob_kld: 0.0178 - val_dist_relevant_mae: 2.7690 - val_dist_relevant_mse: 22.6514 - val_dist_dist_iou_metric: 0.6534 - lr: 3.0000e-04
# Epoch 6/50
# 3/3 [==============================] - 0s 20ms/step- loss: 0.6928 - prob_loss: 0.1356 - dist_loss: 2.7860 - prob_kld: 0.0239 - dist_relevant_mae: 2.7856 - dist_relevant_mse: 22.5413 - dist_dist_iou_metric: 0.63
# 100/100 [==============================] - 37s 366ms/step - loss: 0.6928 - prob_loss: 0.1356 - dist_loss: 2.7860 - prob_kld: 0.0239 - dist_relevant_mae: 2.7856 - dist_relevant_mse: 22.5413 - dist_dist_iou_metric: 0.6375 - val_loss: 0.6850 - val_prob_loss: 0.1192 - val_dist_loss: 2.8287 - val_prob_kld: 0.0171 - val_dist_relevant_mae: 2.8283 - val_dist_relevant_mse: 27.6833 - val_dist_dist_iou_metric: 0.6449 - lr: 3.0000e-04
# Epoch 7/50
# 3/3 [==============================] - 0s 16ms/step- loss: 0.6934 - prob_loss: 0.1386 - dist_loss: 2.7741 - prob_kld: 0.0226 - dist_relevant_mae: 2.7737 - dist_relevant_mse: 24.8699 - dist_dist_iou_metric: 0.65
# 100/100 [==============================] - 38s 383ms/step - loss: 0.6934 - prob_loss: 0.1386 - dist_loss: 2.7741 - prob_kld: 0.0226 - dist_relevant_mae: 2.7737 - dist_relevant_mse: 24.8699 - dist_dist_iou_metric: 0.6550 - val_loss: 0.6317 - val_prob_loss: 0.1171 - val_dist_loss: 2.5734 - val_prob_kld: 0.0150 - val_dist_relevant_mae: 2.5730 - val_dist_relevant_mse: 22.6321 - val_dist_dist_iou_metric: 0.6647 - lr: 3.0000e-04
# Epoch 8/50
# 3/3 [==============================] - 0s 17ms/step- loss: 0.6735 - prob_loss: 0.1388 - dist_loss: 2.6737 - prob_kld: 0.0233 - dist_relevant_mae: 2.6733 - dist_relevant_mse: 21.5809 - dist_dist_iou_metric: 0.65
# 100/100 [==============================] - 38s 378ms/step - loss: 0.6735 - prob_loss: 0.1388 - dist_loss: 2.6737 - prob_kld: 0.0233 - dist_relevant_mae: 2.6733 - dist_relevant_mse: 21.5809 - dist_dist_iou_metric: 0.6532 - val_loss: 0.6510 - val_prob_loss: 0.1177 - val_dist_loss: 2.6666 - val_prob_kld: 0.0156 - val_dist_relevant_mae: 2.6663 - val_dist_relevant_mse: 23.3517 - val_dist_dist_iou_metric: 0.6513 - lr: 3.0000e-04
# Epoch 9/50
# 3/3 [==============================] - 0s 16ms/step- loss: 0.6461 - prob_loss: 0.1306 - dist_loss: 2.5777 - prob_kld: 0.0216 - dist_relevant_mae: 2.5773 - dist_relevant_mse: 20.6868 - dist_dist_iou_metric: 0.65
# 100/100 [==============================] - 37s 365ms/step - loss: 0.6461 - prob_loss: 0.1306 - dist_loss: 2.5777 - prob_kld: 0.0216 - dist_relevant_mae: 2.5773 - dist_relevant_mse: 20.6868 - dist_dist_iou_metric: 0.6533 - val_loss: 0.6278 - val_prob_loss: 0.1171 - val_dist_loss: 2.5535 - val_prob_kld: 0.0150 - val_dist_relevant_mae: 2.5532 - val_dist_relevant_mse: 22.2736 - val_dist_dist_iou_metric: 0.6697 - lr: 3.0000e-04
# Epoch 10/50
# 3/3 [==============================] - 0s 17ms/step- loss: 0.6279 - prob_loss: 0.1269 - dist_loss: 2.5051 - prob_kld: 0.0208 - dist_relevant_mae: 2.5047 - dist_relevant_mse: 18.6213 - dist_dist_iou_metric: 0.65
# 100/100 [==============================] - 34s 342ms/step - loss: 0.6279 - prob_loss: 0.1269 - dist_loss: 2.5051 - prob_kld: 0.0208 - dist_relevant_mae: 2.5047 - dist_relevant_mse: 18.6213 - dist_dist_iou_metric: 0.6577 - val_loss: 0.6114 - val_prob_loss: 0.1181 - val_dist_loss: 2.4666 - val_prob_kld: 0.0160 - val_dist_relevant_mae: 2.4662 - val_dist_relevant_mse: 20.9795 - val_dist_dist_iou_metric: 0.6782 - lr: 3.0000e-04
# Epoch 11/50
# 3/3 [==============================] - 0s 17ms/step- loss: 0.6480 - prob_loss: 0.1339 - dist_loss: 2.5705 - prob_kld: 0.0211 - dist_relevant_mae: 2.5701 - dist_relevant_mse: 20.6493 - dist_dist_iou_metric: 0.66
# 100/100 [==============================] - 38s 378ms/step - loss: 0.6480 - prob_loss: 0.1339 - dist_loss: 2.5705 - prob_kld: 0.0211 - dist_relevant_mae: 2.5701 - dist_relevant_mse: 20.6493 - dist_dist_iou_metric: 0.6625 - val_loss: 0.6345 - val_prob_loss: 0.1172 - val_dist_loss: 2.5868 - val_prob_kld: 0.0151 - val_dist_relevant_mae: 2.5864 - val_dist_relevant_mse: 21.7518 - val_dist_dist_iou_metric: 0.6806 - lr: 3.0000e-04
# Epoch 12/50
# 3/3 [==============================] - 0s 19ms/step- loss: 0.6583 - prob_loss: 0.1381 - dist_loss: 2.6014 - prob_kld: 0.0210 - dist_relevant_mae: 2.6010 - dist_relevant_mse: 21.8207 - dist_dist_iou_metric: 0.66
# 100/100 [==============================] - 39s 391ms/step - loss: 0.6583 - prob_loss: 0.1381 - dist_loss: 2.6014 - prob_kld: 0.0210 - dist_relevant_mae: 2.6010 - dist_relevant_mse: 21.8207 - dist_dist_iou_metric: 0.6648 - val_loss: 0.6441 - val_prob_loss: 0.1187 - val_dist_loss: 2.6271 - val_prob_kld: 0.0166 - val_dist_relevant_mae: 2.6268 - val_dist_relevant_mse: 21.0365 - val_dist_dist_iou_metric: 0.6695 - lr: 3.0000e-04
# Epoch 13/50
# 3/3 [==============================] - 0s 22ms/step- loss: 0.6570 - prob_loss: 0.1411 - dist_loss: 2.5796 - prob_kld: 0.0222 - dist_relevant_mae: 2.5792 - dist_relevant_mse: 21.4424 - dist_dist_iou_metric: 0.66
# 100/100 [==============================] - 39s 387ms/step - loss: 0.6570 - prob_loss: 0.1411 - dist_loss: 2.5796 - prob_kld: 0.0222 - dist_relevant_mae: 2.5792 - dist_relevant_mse: 21.4424 - dist_dist_iou_metric: 0.6684 - val_loss: 0.6460 - val_prob_loss: 0.1179 - val_dist_loss: 2.6405 - val_prob_kld: 0.0158 - val_dist_relevant_mae: 2.6401 - val_dist_relevant_mse: 24.8461 - val_dist_dist_iou_metric: 0.6658 - lr: 3.0000e-04
# Epoch 14/50
# 3/3 [==============================] - 0s 18ms/step- loss: 0.6400 - prob_loss: 0.1381 - dist_loss: 2.5098 - prob_kld: 0.0220 - dist_relevant_mae: 2.5094 - dist_relevant_mse: 19.5047 - dist_dist_iou_metric: 0.67
# 100/100 [==============================] - 38s 380ms/step - loss: 0.6400 - prob_loss: 0.1381 - dist_loss: 2.5098 - prob_kld: 0.0220 - dist_relevant_mae: 2.5094 - dist_relevant_mse: 19.5047 - dist_dist_iou_metric: 0.6735 - val_loss: 0.6344 - val_prob_loss: 0.1191 - val_dist_loss: 2.5767 - val_prob_kld: 0.0170 - val_dist_relevant_mae: 2.5764 - val_dist_relevant_mse: 22.4527 - val_dist_dist_iou_metric: 0.6702 - lr: 3.0000e-04
# Epoch 15/50
# 3/3 [==============================] - 0s 16ms/step- loss: 0.6393 - prob_loss: 0.1385 - dist_loss: 2.5036 - prob_kld: 0.0217 - dist_relevant_mae: 2.5032 - dist_relevant_mse: 19.2660 - dist_dist_iou_metric: 0.66
# 100/100 [==============================] - 38s 379ms/step - loss: 0.6393 - prob_loss: 0.1385 - dist_loss: 2.5036 - prob_kld: 0.0217 - dist_relevant_mae: 2.5032 - dist_relevant_mse: 19.2660 - dist_dist_iou_metric: 0.6675 - val_loss: 0.6173 - val_prob_loss: 0.1168 - val_dist_loss: 2.5027 - val_prob_kld: 0.0147 - val_dist_relevant_mae: 2.5023 - val_dist_relevant_mse: 21.8887 - val_dist_dist_iou_metric: 0.6778 - lr: 3.0000e-04
# Epoch 16/50
# 3/3 [==============================] - 0s 17ms/step- loss: 0.6738 - prob_loss: 0.1393 - dist_loss: 2.6728 - prob_kld: 0.0222 - dist_relevant_mae: 2.6724 - dist_relevant_mse: 23.0591 - dist_dist_iou_metric: 0.65
# 100/100 [==============================] - 38s 382ms/step - loss: 0.6738 - prob_loss: 0.1393 - dist_loss: 2.6728 - prob_kld: 0.0222 - dist_relevant_mae: 2.6724 - dist_relevant_mse: 23.0591 - dist_dist_iou_metric: 0.6599 - val_loss: 0.6281 - val_prob_loss: 0.1202 - val_dist_loss: 2.5399 - val_prob_kld: 0.0181 - val_dist_relevant_mae: 2.5395 - val_dist_relevant_mse: 23.0402 - val_dist_dist_iou_metric: 0.6711 - lr: 3.0000e-04
# Epoch 17/50
# 3/3 [==============================] - 0s 26ms/step- loss: 0.6204 - prob_loss: 0.1385 - dist_loss: 2.4093 - prob_kld: 0.0223 - dist_relevant_mae: 2.4090 - dist_relevant_mse: 18.2002 - dist_dist_iou_metric: 0.
# 100/100 [==============================] - 38s 384ms/step - loss: 0.6204 - prob_loss: 0.1385 - dist_loss: 2.4093 - prob_kld: 0.0223 - dist_relevant_mae: 2.4090 - dist_relevant_mse: 18.2002 - dist_dist_iou_metric: 0.6701 - val_loss: 0.6080 - val_prob_loss: 0.1171 - val_dist_loss: 2.4542 - val_prob_kld: 0.0150 - val_dist_relevant_mae: 2.4538 - val_dist_relevant_mse: 20.9083 - val_dist_dist_iou_metric: 0.6836 - lr: 3.0000e-04
# Epoch 18/50
# 3/3 [==============================] - 0s 15ms/step- loss: 0.6184 - prob_loss: 0.1332 - dist_loss: 2.4260 - prob_kld: 0.0200 - dist_relevant_mae: 2.4256 - dist_relevant_mse: 18.4319 - dist_dist_iou_metric: 0.66
# 100/100 [==============================] - 37s 367ms/step - loss: 0.6184 - prob_loss: 0.1332 - dist_loss: 2.4260 - prob_kld: 0.0200 - dist_relevant_mae: 2.4256 - dist_relevant_mse: 18.4319 - dist_dist_iou_metric: 0.6697 - val_loss: 0.6061 - val_prob_loss: 0.1172 - val_dist_loss: 2.4444 - val_prob_kld: 0.0151 - val_dist_relevant_mae: 2.4441 - val_dist_relevant_mse: 22.6193 - val_dist_dist_iou_metric: 0.6795 - lr: 3.0000e-04
# Epoch 19/50
# 3/3 [==============================] - 0s 17ms/step- loss: 0.6178 - prob_loss: 0.1332 - dist_loss: 2.4232 - prob_kld: 0.0202 - dist_relevant_mae: 2.4228 - dist_relevant_mse: 18.0181 - dist_dist_iou_metric: 0.67
# 100/100 [==============================] - 37s 374ms/step - loss: 0.6178 - prob_loss: 0.1332 - dist_loss: 2.4232 - prob_kld: 0.0202 - dist_relevant_mae: 2.4228 - dist_relevant_mse: 18.0181 - dist_dist_iou_metric: 0.6704 - val_loss: 0.6520 - val_prob_loss: 0.1160 - val_dist_loss: 2.6803 - val_prob_kld: 0.0139 - val_dist_relevant_mae: 2.6800 - val_dist_relevant_mse: 24.4439 - val_dist_dist_iou_metric: 0.6585 - lr: 3.0000e-04
# Epoch 20/50
# 3/3 [==============================] - 0s 20ms/step- loss: 0.6415 - prob_loss: 0.1367 - dist_loss: 2.5240 - prob_kld: 0.0199 - dist_relevant_mae: 2.5236 - dist_relevant_mse: 20.7147 - dist_dist_iou_metric: 0.67
# 100/100 [==============================] - 39s 386ms/step - loss: 0.6415 - prob_loss: 0.1367 - dist_loss: 2.5240 - prob_kld: 0.0199 - dist_relevant_mae: 2.5236 - dist_relevant_mse: 20.7147 - dist_dist_iou_metric: 0.6713 - val_loss: 0.6421 - val_prob_loss: 0.1195 - val_dist_loss: 2.6129 - val_prob_kld: 0.0174 - val_dist_relevant_mae: 2.6126 - val_dist_relevant_mse: 22.0809 - val_dist_dist_iou_metric: 0.6823 - lr: 3.0000e-04
# Epoch 21/50
# 3/3 [==============================] - 0s 15ms/step- loss: 0.6315 - prob_loss: 0.1312 - dist_loss: 2.5015 - prob_kld: 0.0208 - dist_relevant_mae: 2.5011 - dist_relevant_mse: 19.6816 - dist_dist_iou_metric: 0.67
# 100/100 [==============================] - 36s 365ms/step - loss: 0.6315 - prob_loss: 0.1312 - dist_loss: 2.5015 - prob_kld: 0.0208 - dist_relevant_mae: 2.5011 - dist_relevant_mse: 19.6816 - dist_dist_iou_metric: 0.6715 - val_loss: 0.6469 - val_prob_loss: 0.1185 - val_dist_loss: 2.6422 - val_prob_kld: 0.0164 - val_dist_relevant_mae: 2.6418 - val_dist_relevant_mse: 24.2856 - val_dist_dist_iou_metric: 0.6698 - lr: 3.0000e-04
# Epoch 22/50
# 3/3 [==============================] - 0s 17ms/step- loss: 0.6250 - prob_loss: 0.1374 - dist_loss: 2.4381 - prob_kld: 0.0206 - dist_relevant_mae: 2.4377 - dist_relevant_mse: 19.0561 - dist_dist_iou_metric: 0.67
# 100/100 [==============================] - 38s 385ms/step - loss: 0.6250 - prob_loss: 0.1374 - dist_loss: 2.4381 - prob_kld: 0.0206 - dist_relevant_mae: 2.4377 - dist_relevant_mse: 19.0561 - dist_dist_iou_metric: 0.6747 - val_loss: 0.6069 - val_prob_loss: 0.1165 - val_dist_loss: 2.4517 - val_prob_kld: 0.0144 - val_dist_relevant_mae: 2.4514 - val_dist_relevant_mse: 21.0257 - val_dist_dist_iou_metric: 0.6838 - lr: 3.0000e-04
# Epoch 23/50
# 3/3 [==============================] - 0s 25ms/step- loss: 0.6064 - prob_loss: 0.1286 - dist_loss: 2.3892 - prob_kld: 0.0191 - dist_relevant_mae: 2.3888 - dist_relevant_mse: 18.2279 - dist_dist_iou_metric: 0.67
# 100/100 [==============================] - 36s 363ms/step - loss: 0.6064 - prob_loss: 0.1286 - dist_loss: 2.3892 - prob_kld: 0.0191 - dist_relevant_mae: 2.3888 - dist_relevant_mse: 18.2279 - dist_dist_iou_metric: 0.6792 - val_loss: 0.6868 - val_prob_loss: 0.1169 - val_dist_loss: 2.8496 - val_prob_kld: 0.0148 - val_dist_relevant_mae: 2.8492 - val_dist_relevant_mse: 27.5390 - val_dist_dist_iou_metric: 0.6329 - lr: 3.0000e-04
# Epoch 24/50
# 3/3 [==============================] - 0s 15ms/step- loss: 0.6467 - prob_loss: 0.1311 - dist_loss: 2.5781 - prob_kld: 0.0215 - dist_relevant_mae: 2.5777 - dist_relevant_mse: 22.1518 - dist_dist_iou_metric: 0.66
# 100/100 [==============================] - 37s 366ms/step - loss: 0.6467 - prob_loss: 0.1311 - dist_loss: 2.5781 - prob_kld: 0.0215 - dist_relevant_mae: 2.5777 - dist_relevant_mse: 22.1518 - dist_dist_iou_metric: 0.6619 - val_loss: 0.6451 - val_prob_loss: 0.1174 - val_dist_loss: 2.6384 - val_prob_kld: 0.0153 - val_dist_relevant_mae: 2.6380 - val_dist_relevant_mse: 23.1989 - val_dist_dist_iou_metric: 0.6728 - lr: 3.0000e-04
# Epoch 25/50
# 3/3 [==============================] - 0s 16ms/step- loss: 0.6099 - prob_loss: 0.1347 - dist_loss: 2.3761 - prob_kld: 0.0203 - dist_relevant_mae: 2.3757 - dist_relevant_mse: 19.2185 - dist_dist_iou_metric: 0.68
# 100/100 [==============================] - 38s 382ms/step - loss: 0.6099 - prob_loss: 0.1347 - dist_loss: 2.3761 - prob_kld: 0.0203 - dist_relevant_mae: 2.3757 - dist_relevant_mse: 19.2185 - dist_dist_iou_metric: 0.6815 - val_loss: 0.6259 - val_prob_loss: 0.1168 - val_dist_loss: 2.5455 - val_prob_kld: 0.0147 - val_dist_relevant_mae: 2.5452 - val_dist_relevant_mse: 22.8964 - val_dist_dist_iou_metric: 0.6666 - lr: 3.0000e-04
# Epoch 26/50
# 3/3 [==============================] - 0s 14ms/step- loss: 0.6023 - prob_loss: 0.1314 - dist_loss: 2.3547 - prob_kld: 0.0185 - dist_relevant_mae: 2.3543 - dist_relevant_mse: 17.7512 - dist_dist_iou_metric: 0.68
# 100/100 [==============================] - 38s 382ms/step - loss: 0.6023 - prob_loss: 0.1314 - dist_loss: 2.3547 - prob_kld: 0.0185 - dist_relevant_mae: 2.3543 - dist_relevant_mse: 17.7512 - dist_dist_iou_metric: 0.6848 - val_loss: 0.6045 - val_prob_loss: 0.1154 - val_dist_loss: 2.4451 - val_prob_kld: 0.0133 - val_dist_relevant_mae: 2.4448 - val_dist_relevant_mse: 21.3492 - val_dist_dist_iou_metric: 0.6802 - lr: 3.0000e-04
# Epoch 27/50
# 3/3 [==============================] - 0s 18ms/step- loss: 0.6109 - prob_loss: 0.1365 - dist_loss: 2.3724 - prob_kld: 0.0200 - dist_relevant_mae: 2.3720 - dist_relevant_mse: 18.3976 - dist_dist_iou_metric: 0.68
# 100/100 [==============================] - 39s 388ms/step - loss: 0.6109 - prob_loss: 0.1365 - dist_loss: 2.3724 - prob_kld: 0.0200 - dist_relevant_mae: 2.3720 - dist_relevant_mse: 18.3976 - dist_dist_iou_metric: 0.6890 - val_loss: 0.6274 - val_prob_loss: 0.1151 - val_dist_loss: 2.5612 - val_prob_kld: 0.0130 - val_dist_relevant_mae: 2.5609 - val_dist_relevant_mse: 21.9790 - val_dist_dist_iou_metric: 0.6565 - lr: 3.0000e-04
# Epoch 28/50
# 3/3 [==============================] - 0s 63ms/step- loss: 0.5881 - prob_loss: 0.1281 - dist_loss: 2.2999 - prob_kld: 0.0187 - dist_relevant_mae: 2.2995 - dist_relevant_mse: 16.9112 - dist_dist_iou_metric:
# 100/100 [==============================] - 37s 372ms/step - loss: 0.5881 - prob_loss: 0.1281 - dist_loss: 2.2999 - prob_kld: 0.0187 - dist_relevant_mae: 2.2995 - dist_relevant_mse: 16.9112 - dist_dist_iou_metric: 0.6798 - val_loss: 0.5835 - val_prob_loss: 0.1144 - val_dist_loss: 2.3454 - val_prob_kld: 0.0123 - val_dist_relevant_mae: 2.3451 - val_dist_relevant_mse: 20.1801 - val_dist_dist_iou_metric: 0.6949 - lr: 3.0000e-04
# Epoch 29/50
# 3/3 [==============================] - 0s 15ms/step- loss: 0.6054 - prob_loss: 0.1309 - dist_loss: 2.3727 - prob_kld: 0.0188 - dist_relevant_mae: 2.3723 - dist_relevant_mse: 18.1614 - dist_dist_iou_metric: 0.68
# 100/100 [==============================] - 37s 373ms/step - loss: 0.6054 - prob_loss: 0.1309 - dist_loss: 2.3727 - prob_kld: 0.0188 - dist_relevant_mae: 2.3723 - dist_relevant_mse: 18.1614 - dist_dist_iou_metric: 0.6802 - val_loss: 0.6318 - val_prob_loss: 0.1157 - val_dist_loss: 2.5805 - val_prob_kld: 0.0136 - val_dist_relevant_mae: 2.5801 - val_dist_relevant_mse: 20.8465 - val_dist_dist_iou_metric: 0.6827 - lr: 3.0000e-04
# Epoch 30/50
# 3/3 [==============================] - 0s 15ms/step- loss: 0.5698 - prob_loss: 0.1297 - dist_loss: 2.2005 - prob_kld: 0.0182 - dist_relevant_mae: 2.2001 - dist_relevant_mse: 14.9728 - dist_dist_iou_metric: 0.69
# 100/100 [==============================] - 37s 369ms/step - loss: 0.5698 - prob_loss: 0.1297 - dist_loss: 2.2005 - prob_kld: 0.0182 - dist_relevant_mae: 2.2001 - dist_relevant_mse: 14.9728 - dist_dist_iou_metric: 0.6960 - val_loss: 0.5789 - val_prob_loss: 0.1155 - val_dist_loss: 2.3169 - val_prob_kld: 0.0134 - val_dist_relevant_mae: 2.3165 - val_dist_relevant_mse: 18.7687 - val_dist_dist_iou_metric: 0.7016 - lr: 3.0000e-04
# Epoch 31/50
# 3/3 [==============================] - 0s 20ms/step- loss: 0.5893 - prob_loss: 0.1320 - dist_loss: 2.2863 - prob_kld: 0.0182 - dist_relevant_mae: 2.2860 - dist_relevant_mse: 17.1800 - dist_dist_iou_metric: 0.68
# 100/100 [==============================] - 38s 382ms/step - loss: 0.5893 - prob_loss: 0.1320 - dist_loss: 2.2863 - prob_kld: 0.0182 - dist_relevant_mae: 2.2860 - dist_relevant_mse: 17.1800 - dist_dist_iou_metric: 0.6897 - val_loss: 0.5925 - val_prob_loss: 0.1146 - val_dist_loss: 2.3897 - val_prob_kld: 0.0125 - val_dist_relevant_mae: 2.3894 - val_dist_relevant_mse: 20.2647 - val_dist_dist_iou_metric: 0.6908 - lr: 3.0000e-04
# Epoch 32/50
# 3/3 [==============================] - 0s 17ms/step- loss: 0.5679 - prob_loss: 0.1265 - dist_loss: 2.2068 - prob_kld: 0.0172 - dist_relevant_mae: 2.2065 - dist_relevant_mse: 15.3387 - dist_dist_iou_metric: 0.69
# 100/100 [==============================] - 36s 359ms/step - loss: 0.5679 - prob_loss: 0.1265 - dist_loss: 2.2068 - prob_kld: 0.0172 - dist_relevant_mae: 2.2065 - dist_relevant_mse: 15.3387 - dist_dist_iou_metric: 0.6939 - val_loss: 0.5911 - val_prob_loss: 0.1154 - val_dist_loss: 2.3785 - val_prob_kld: 0.0133 - val_dist_relevant_mae: 2.3781 - val_dist_relevant_mse: 19.7731 - val_dist_dist_iou_metric: 0.6952 - lr: 3.0000e-04
# Epoch 33/50
# 3/3 [==============================] - 0s 20ms/step- loss: 0.5620 - prob_loss: 0.1314 - dist_loss: 2.1532 - prob_kld: 0.0173 - dist_relevant_mae: 2.1528 - dist_relevant_mse: 14.6002 - dist_dist_iou_metric: 0.70
# 100/100 [==============================] - 38s 382ms/step - loss: 0.5620 - prob_loss: 0.1314 - dist_loss: 2.1532 - prob_kld: 0.0173 - dist_relevant_mae: 2.1528 - dist_relevant_mse: 14.6002 - dist_dist_iou_metric: 0.7093 - val_loss: 0.6224 - val_prob_loss: 0.1164 - val_dist_loss: 2.5297 - val_prob_kld: 0.0143 - val_dist_relevant_mae: 2.5294 - val_dist_relevant_mse: 22.6719 - val_dist_dist_iou_metric: 0.6719 - lr: 3.0000e-04
# Epoch 34/50
# 3/3 [==============================] - 0s 21ms/step- loss: 0.5875 - prob_loss: 0.1314 - dist_loss: 2.2808 - prob_kld: 0.0185 - dist_relevant_mae: 2.2805 - dist_relevant_mse: 16.4074 - dist_dist_iou_metric: 0.68
# 100/100 [==============================] - 37s 372ms/step - loss: 0.5875 - prob_loss: 0.1314 - dist_loss: 2.2808 - prob_kld: 0.0185 - dist_relevant_mae: 2.2805 - dist_relevant_mse: 16.4074 - dist_dist_iou_metric: 0.6845 - val_loss: 0.6132 - val_prob_loss: 0.1150 - val_dist_loss: 2.4910 - val_prob_kld: 0.0130 - val_dist_relevant_mae: 2.4906 - val_dist_relevant_mse: 21.2965 - val_dist_dist_iou_metric: 0.6906 - lr: 3.0000e-04
# Epoch 35/50
# 3/3 [==============================] - 0s 17ms/step- loss: 0.6145 - prob_loss: 0.1325 - dist_loss: 2.4101 - prob_kld: 0.0194 - dist_relevant_mae: 2.4098 - dist_relevant_mse: 19.3504 - dist_dist_iou_metric: 0.68
# 100/100 [==============================] - 37s 375ms/step - loss: 0.6145 - prob_loss: 0.1325 - dist_loss: 2.4101 - prob_kld: 0.0194 - dist_relevant_mae: 2.4098 - dist_relevant_mse: 19.3504 - dist_dist_iou_metric: 0.6811 - val_loss: 0.6343 - val_prob_loss: 0.1161 - val_dist_loss: 2.5906 - val_prob_kld: 0.0140 - val_dist_relevant_mae: 2.5903 - val_dist_relevant_mse: 25.2063 - val_dist_dist_iou_metric: 0.6616 - lr: 3.0000e-04
# Epoch 36/50
# 3/3 [==============================] - 0s 16ms/step- loss: 0.5988 - prob_loss: 0.1307 - dist_loss: 2.3405 - prob_kld: 0.0176 - dist_relevant_mae: 2.3401 - dist_relevant_mse: 18.7817 - dist_dist_iou_metric: 0.69
# 100/100 [==============================] - 38s 379ms/step - loss: 0.5988 - prob_loss: 0.1307 - dist_loss: 2.3405 - prob_kld: 0.0176 - dist_relevant_mae: 2.3401 - dist_relevant_mse: 18.7817 - dist_dist_iou_metric: 0.6924 - val_loss: 0.5809 - val_prob_loss: 0.1143 - val_dist_loss: 2.3330 - val_prob_kld: 0.0122 - val_dist_relevant_mae: 2.3326 - val_dist_relevant_mse: 17.7615 - val_dist_dist_iou_metric: 0.6976 - lr: 3.0000e-04
# Epoch 37/50
# 3/3 [==============================] - 0s 16ms/step- loss: 0.5584 - prob_loss: 0.1279 - dist_loss: 2.1527 - prob_kld: 0.0170 - dist_relevant_mae: 2.1523 - dist_relevant_mse: 14.1834 - dist_dist_iou_metric: 0.70
# 100/100 [==============================] - 37s 371ms/step - loss: 0.5584 - prob_loss: 0.1279 - dist_loss: 2.1527 - prob_kld: 0.0170 - dist_relevant_mae: 2.1523 - dist_relevant_mse: 14.1834 - dist_dist_iou_metric: 0.7049 - val_loss: 0.5664 - val_prob_loss: 0.1136 - val_dist_loss: 2.2641 - val_prob_kld: 0.0115 - val_dist_relevant_mae: 2.2638 - val_dist_relevant_mse: 18.6850 - val_dist_dist_iou_metric: 0.6979 - lr: 3.0000e-04
# Epoch 38/50
# 3/3 [==============================] - 0s 20ms/step- loss: 0.5673 - prob_loss: 0.1344 - dist_loss: 2.1645 - prob_kld: 0.0181 - dist_relevant_mae: 2.1641 - dist_relevant_mse: 15.7930 - dist_dist_iou_metric: 0.70
# 100/100 [==============================] - 38s 382ms/step - loss: 0.5673 - prob_loss: 0.1344 - dist_loss: 2.1645 - prob_kld: 0.0181 - dist_relevant_mae: 2.1641 - dist_relevant_mse: 15.7930 - dist_dist_iou_metric: 0.7026 - val_loss: 0.5685 - val_prob_loss: 0.1148 - val_dist_loss: 2.2681 - val_prob_kld: 0.0128 - val_dist_relevant_mae: 2.2677 - val_dist_relevant_mse: 19.2133 - val_dist_dist_iou_metric: 0.6998 - lr: 3.0000e-04
# Epoch 39/50
# 3/3 [==============================] - 0s 17ms/step- loss: 0.5906 - prob_loss: 0.1367 - dist_loss: 2.2696 - prob_kld: 0.0180 - dist_relevant_mae: 2.2692 - dist_relevant_mse: 16.8016 - dist_dist_iou_metric: 0.69
# 100/100 [==============================] - 40s 398ms/step - loss: 0.5906 - prob_loss: 0.1367 - dist_loss: 2.2696 - prob_kld: 0.0180 - dist_relevant_mae: 2.2692 - dist_relevant_mse: 16.8016 - dist_dist_iou_metric: 0.6982 - val_loss: 0.5812 - val_prob_loss: 0.1147 - val_dist_loss: 2.3325 - val_prob_kld: 0.0126 - val_dist_relevant_mae: 2.3321 - val_dist_relevant_mse: 20.3799 - val_dist_dist_iou_metric: 0.6926 - lr: 3.0000e-04
# Epoch 40/50
# 3/3 [==============================] - 0s 15ms/step- loss: 0.5832 - prob_loss: 0.1309 - dist_loss: 2.2615 - prob_kld: 0.0172 - dist_relevant_mae: 2.2612 - dist_relevant_mse: 16.5633 - dist_dist_iou_metric: 0.69
# 100/100 [==============================] - 38s 385ms/step - loss: 0.5832 - prob_loss: 0.1309 - dist_loss: 2.2615 - prob_kld: 0.0172 - dist_relevant_mae: 2.2612 - dist_relevant_mse: 16.5633 - dist_dist_iou_metric: 0.6927 - val_loss: 0.5701 - val_prob_loss: 0.1140 - val_dist_loss: 2.2809 - val_prob_kld: 0.0119 - val_dist_relevant_mae: 2.2805 - val_dist_relevant_mse: 18.8240 - val_dist_dist_iou_metric: 0.6944 - lr: 3.0000e-04
# Epoch 41/50
# 3/3 [==============================] - 0s 16ms/step- loss: 0.5724 - prob_loss: 0.1310 - dist_loss: 2.2067 - prob_kld: 0.0164 - dist_relevant_mae: 2.2063 - dist_relevant_mse: 16.5763 - dist_dist_iou_metric: 0.70
# 100/100 [==============================] - 39s 387ms/step - loss: 0.5724 - prob_loss: 0.1310 - dist_loss: 2.2067 - prob_kld: 0.0164 - dist_relevant_mae: 2.2063 - dist_relevant_mse: 16.5763 - dist_dist_iou_metric: 0.7037 - val_loss: 0.5550 - val_prob_loss: 0.1136 - val_dist_loss: 2.2068 - val_prob_kld: 0.0115 - val_dist_relevant_mae: 2.2065 - val_dist_relevant_mse: 17.1701 - val_dist_dist_iou_metric: 0.7137 - lr: 3.0000e-04
# Epoch 42/50
# 3/3 [==============================] - 0s 15ms/step- loss: 0.5559 - prob_loss: 0.1226 - dist_loss: 2.1664 - prob_kld: 0.0163 - dist_relevant_mae: 2.1660 - dist_relevant_mse: 15.4502 - dist_dist_iou_metric: 0.69
# 100/100 [==============================] - 36s 359ms/step - loss: 0.5559 - prob_loss: 0.1226 - dist_loss: 2.1664 - prob_kld: 0.0163 - dist_relevant_mae: 2.1660 - dist_relevant_mse: 15.4502 - dist_dist_iou_metric: 0.6998 - val_loss: 0.5536 - val_prob_loss: 0.1135 - val_dist_loss: 2.2008 - val_prob_kld: 0.0114 - val_dist_relevant_mae: 2.2004 - val_dist_relevant_mse: 17.9465 - val_dist_dist_iou_metric: 0.7068 - lr: 3.0000e-04
# Epoch 43/50
# 3/3 [==============================] - 0s 16ms/step- loss: 0.5815 - prob_loss: 0.1394 - dist_loss: 2.2103 - prob_kld: 0.0172 - dist_relevant_mae: 2.2100 - dist_relevant_mse: 15.3476 - dist_dist_iou_metric: 0.70
# 100/100 [==============================] - 41s 407ms/step - loss: 0.5815 - prob_loss: 0.1394 - dist_loss: 2.2103 - prob_kld: 0.0172 - dist_relevant_mae: 2.2100 - dist_relevant_mse: 15.3476 - dist_dist_iou_metric: 0.7055 - val_loss: 0.5770 - val_prob_loss: 0.1134 - val_dist_loss: 2.3177 - val_prob_kld: 0.0113 - val_dist_relevant_mae: 2.3173 - val_dist_relevant_mse: 17.0640 - val_dist_dist_iou_metric: 0.7046 - lr: 3.0000e-04
# Epoch 44/50
# 3/3 [==============================] - 0s 18ms/step- loss: 0.5748 - prob_loss: 0.1340 - dist_loss: 2.2042 - prob_kld: 0.0178 - dist_relevant_mae: 2.2038 - dist_relevant_mse: 15.2300 - dist_dist_iou_metric: 0.69
# 100/100 [==============================] - 39s 397ms/step - loss: 0.5748 - prob_loss: 0.1340 - dist_loss: 2.2042 - prob_kld: 0.0178 - dist_relevant_mae: 2.2038 - dist_relevant_mse: 15.2300 - dist_dist_iou_metric: 0.6997 - val_loss: 0.5549 - val_prob_loss: 0.1137 - val_dist_loss: 2.2062 - val_prob_kld: 0.0116 - val_dist_relevant_mae: 2.2059 - val_dist_relevant_mse: 17.5040 - val_dist_dist_iou_metric: 0.7036 - lr: 3.0000e-04
# Epoch 45/50
# 3/3 [==============================] - 0s 21ms/step- loss: 0.5529 - prob_loss: 0.1263 - dist_loss: 2.1330 - prob_kld: 0.0154 - dist_relevant_mae: 2.1326 - dist_relevant_mse: 14.8758 - dist_dist_iou_metric: 0.70
# 100/100 [==============================] - 37s 374ms/step - loss: 0.5529 - prob_loss: 0.1263 - dist_loss: 2.1330 - prob_kld: 0.0154 - dist_relevant_mae: 2.1326 - dist_relevant_mse: 14.8758 - dist_dist_iou_metric: 0.7044 - val_loss: 0.5712 - val_prob_loss: 0.1143 - val_dist_loss: 2.2846 - val_prob_kld: 0.0122 - val_dist_relevant_mae: 2.2843 - val_dist_relevant_mse: 17.6644 - val_dist_dist_iou_metric: 0.7045 - lr: 3.0000e-04
# Epoch 46/50
# 3/3 [==============================] - 0s 16ms/step- loss: 0.5619 - prob_loss: 0.1314 - dist_loss: 2.1526 - prob_kld: 0.0155 - dist_relevant_mae: 2.1522 - dist_relevant_mse: 15.7661 - dist_dist_iou_metric: 0.71
# 100/100 [==============================] - 40s 395ms/step - loss: 0.5619 - prob_loss: 0.1314 - dist_loss: 2.1526 - prob_kld: 0.0155 - dist_relevant_mae: 2.1522 - dist_relevant_mse: 15.7661 - dist_dist_iou_metric: 0.7105 - val_loss: 0.5840 - val_prob_loss: 0.1138 - val_dist_loss: 2.3512 - val_prob_kld: 0.0117 - val_dist_relevant_mae: 2.3508 - val_dist_relevant_mse: 18.4727 - val_dist_dist_iou_metric: 0.7053 - lr: 3.0000e-04
# Epoch 47/50
# 3/3 [==============================] - 0s 17ms/step- loss: 0.5668 - prob_loss: 0.1381 - dist_loss: 2.1432 - prob_kld: 0.0179 - dist_relevant_mae: 2.1429 - dist_relevant_mse: 14.9857 - dist_dist_iou_metric: 0.70
# 100/100 [==============================] - 40s 400ms/step - loss: 0.5668 - prob_loss: 0.1381 - dist_loss: 2.1432 - prob_kld: 0.0179 - dist_relevant_mae: 2.1429 - dist_relevant_mse: 14.9857 - dist_dist_iou_metric: 0.7020 - val_loss: 0.5513 - val_prob_loss: 0.1139 - val_dist_loss: 2.1871 - val_prob_kld: 0.0118 - val_dist_relevant_mae: 2.1868 - val_dist_relevant_mse: 17.4046 - val_dist_dist_iou_metric: 0.7038 - lr: 3.0000e-04
# Epoch 48/50
# 3/3 [==============================] - 0s 16ms/step- loss: 0.5684 - prob_loss: 0.1327 - dist_loss: 2.1783 - prob_kld: 0.0158 - dist_relevant_mae: 2.1779 - dist_relevant_mse: 16.0148 - dist_dist_iou_metric: 0.71
# 100/100 [==============================] - 40s 400ms/step - loss: 0.5684 - prob_loss: 0.1327 - dist_loss: 2.1783 - prob_kld: 0.0158 - dist_relevant_mae: 2.1779 - dist_relevant_mse: 16.0148 - dist_dist_iou_metric: 0.7104 - val_loss: 0.5470 - val_prob_loss: 0.1125 - val_dist_loss: 2.1726 - val_prob_kld: 0.0104 - val_dist_relevant_mae: 2.1722 - val_dist_relevant_mse: 16.5120 - val_dist_dist_iou_metric: 0.7106 - lr: 3.0000e-04
# Epoch 49/50
# 3/3 [==============================] - 0s 56ms/step- loss: 0.5681 - prob_loss: 0.1381 - dist_loss: 2.1501 - prob_kld: 0.0173 - dist_relevant_mae: 2.1498 - dist_relevant_mse: 15.4190 - dist_dist_iou_metric: 0.
# 100/100 [==============================] - 42s 417ms/step - loss: 0.5681 - prob_loss: 0.1381 - dist_loss: 2.1501 - prob_kld: 0.0173 - dist_relevant_mae: 2.1498 - dist_relevant_mse: 15.4190 - dist_dist_iou_metric: 0.7088 - val_loss: 0.5493 - val_prob_loss: 0.1137 - val_dist_loss: 2.1779 - val_prob_kld: 0.0116 - val_dist_relevant_mae: 2.1775 - val_dist_relevant_mse: 17.0880 - val_dist_dist_iou_metric: 0.7142 - lr: 3.0000e-04
# Epoch 50/50
# 3/3 [==============================] - 0s 16ms/step- loss: 0.5532 - prob_loss: 0.1299 - dist_loss: 2.1163 - prob_kld: 0.0161 - dist_relevant_mae: 2.1159 - dist_relevant_mse: 15.7960 - dist_dist_iou_metric: 0.70
# 100/100 [==============================] - 38s 377ms/step - loss: 0.5532 - prob_loss: 0.1299 - dist_loss: 2.1163 - prob_kld: 0.0161 - dist_relevant_mae: 2.1159 - dist_relevant_mse: 15.7960 - dist_dist_iou_metric: 0.7089 - val_loss: 0.5509 - val_prob_loss: 0.1147 - val_dist_loss: 2.1813 - val_prob_kld: 0.0126 - val_dist_relevant_mae: 2.1810 - val_dist_relevant_mse: 17.2686 - val_dist_dist_iou_metric: 0.7116 - lr: 3.0000e-04
#
# Loading network weights from 'weights_best.h5'.

# %%
X_train.shape, Y_train.shape, X_val.shape, Y_val.shape
# Out:
# ((5, 96, 256, 256, 1),
#  (5, 96, 256, 256),
#  (5, 96, 256, 256, 1),
#  (5, 96, 256, 256))

# %%
n=2
labels, details = model.predict_instances(X_train[n], prob_thresh=0.3, nms_thresh=0.2)
fig = show_xy_zy_slice(X_train[n], int(X_train[0].shape[2]/2), int(X_train[0].shape[1]/2), 10,1.4,1.4, figsize=(8,6))
fig = show_xy_zy_slice(Y_train[n], int(Y_train[0].shape[2]/2), int(Y_train[0].shape[1]/2), 10,1.4,1.4, colormap=colormap, figsize=(8,6))
fig = show_xy_zy_slice(labels, int(labels.shape[2]/2), int(labels.shape[1]/2), 10,1.4,1.4, colormap=colormap, figsize=(8,6))

# %%
X_train[n].shape
# Out:
# (16, 128, 128, 1)

# %%
import napari
viewer = napari.Viewer()
viewer.add_image(X_train[n].squeeze())
viewer.add_labels(labels)
viewer.add_labels(Y_train[n].squeeze())
viewer.show()

# %%
X_train[n].shape, X_train[n].min(), X_train[n].max()
# Out:
# ((96, 256, 256, 1), -0.009466953, 1.2167182)

# %%
X_train[0].max()
# Out:
# 1.2449049
