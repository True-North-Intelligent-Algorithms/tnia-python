# %%
from skimage.io import imread
from tnia.plotting.projections import show_xy_zy_slice_center, show_xy_zy_max

im = imread('/home/bnorthan/images/tnia-python-images/imagesc/2024_02_15_clij_z_tiling/im.tif')
psf = imread('/home/bnorthan/images/tnia-python-images/imagesc/2024_02_15_clij_z_tiling/psf.tif')

fig=show_xy_zy_slice_center(im)
fig=show_xy_zy_slice_center(psf)

# %%
im.shape, psf.shape
# Out:
# ((512, 512, 512), (128, 128, 128))

# %%
cropped = im[0:256, 0:256, 0:256]
fig = show_xy_zy_max(cropped)

# %%
from skimage.io import imsave

imsave('/home/bnorthan/images/tnia-python-images/imagesc/2024_02_15_clij_z_tiling/half_bead.tif', cropped)

# %%
import numpy as np

test = np.ones((512, 266, 266), dtype=np.float32)

# %%
from skimage.io import imsave

imsave('/home/bnorthan/images/tnia-python-images/imagesc/2024_02_15_clij_z_tiling/ones_266_266_512.tif',test)
# Out:
# /tmp/ipykernel_12272/1455581166.py:3: UserWarning: /home/bnorthan/images/tnia-python-images/imagesc/2024_02_15_clij_z_tiling/ones_266_266_512.tif is a low contrast image
#   imsave('/home/bnorthan/images/tnia-python-images/imagesc/2024_02_15_clij_z_tiling/ones_266_266_512.tif',test)
