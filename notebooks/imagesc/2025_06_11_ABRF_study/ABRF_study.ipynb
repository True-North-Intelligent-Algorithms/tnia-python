# %% [markdown]
# ## Imports

# %%
import pandas as pd
import os
from utility import compute_lsa_distance, find_scale_and_translation, calculate_jac
import numpy as np
from utility import friendly_names
from correction import apply_corrections

# %% [markdown]
# ## Load the coordinate data file

# %%
data_file = r'coordinate_data_deidentified.csv'

data = pd.read_csv(data_file)
print(data.shape)
#data = data[data.csv_path.str.contains('nuclei', na=False)]
print(data.shape)
# Out:
# (108702, 7)
# (108702, 7)

# %% [markdown]
# ## Load the ground truth data

# %%
ground_truth_file = r'ground_truth_coords.csv'

ground_truth = pd.read_csv(ground_truth_file)
print(ground_truth.shape)

# Display the first few rows of the ground truth data
ground_truth['base_name'] = ground_truth['path'].apply(os.path.basename)
ground_truth.head()
# Out:
# (6024, 5)
#    Unnamed: 0          x          y          z  \
# 0           0   5.628644   9.198676   8.751923
# 1           1  22.816774   9.033185   6.689963
# 2           2  22.618367  26.020343  15.707744
# 3           3  13.676880  23.516335  14.263662
# 4           4  25.001824   8.219340  21.236781
#
#                                                path               base_name
# 0  ../../ground truth/nuclei/out_c00_dr90_label.tif  out_c00_dr90_label.tif
# 1  ../../ground truth/nuclei/out_c00_dr90_label.tif  out_c00_dr90_label.tif
# 2  ../../ground truth/nuclei/out_c00_dr90_label.tif  out_c00_dr90_label.tif
# 3  ../../ground truth/nuclei/out_c00_dr90_label.tif  out_c00_dr90_label.tif
# 4  ../../ground truth/nuclei/out_c00_dr90_label.tif  out_c00_dr90_label.tif

# %% [markdown]
# ## Open combined data
#
# Open the file (combined data deidentified.csv) containing the meta data, survey data and the metrics calculated by ABRF

# %%
combined_data = pd.read_csv(r'combined data deidentified.csv')
combined_data = combined_data[['responseid', 'qx.2','setName','lsa_mse_raw', 'lsa_mse_transformed']]

print(combined_data.shape)
# only keep rows where nuclei is in the setName
#combined_data = combined_data[combined_data.setName.str.contains('nuclei')]

print(combined_data.shape)
combined_data.head()
# Out:
# (159, 5)
# (159, 5)
#           responseid    qx.2  setName  lsa_mse_raw  lsa_mse_transformed
# 0  R_31bjqd6Mm8wBxN5  Python  nuclei1   182.451824            56.679462
# 1  R_31bjqd6Mm8wBxN5  Python  nuclei2    47.222279            21.174983
# 2  R_31bjqd6Mm8wBxN5  Python  nuclei3   105.577865            18.732895
# 3  R_31bjqd6Mm8wBxN5  Python  nuclei4    88.287150            19.067347
# 4  R_3lAJ9xY4kGlL99f  Python  nuclei1   565.205858             0.017590

# %%
combined_data['lsa_mse_label_corrected'] = 0
combined_data['lsa_mse_label_and_image_corrected'] = 0
combined_data['lsa_mse_transformed'] = 0
combined_data['lsa_mse_best'] = 0
combined_data['correction'] = 'NONE'
combined_data['jac'] = 0
combined_data['jac_transformed'] = 0
combined_data['jac_best'] = 0

for index, row in combined_data.iterrows():

    responseid = row['responseid']
    print(f'Processing responseid: {responseid}')
    
    data_name = row['setName'].strip()
    test_data = data[data.csv_path.str.contains(responseid, na=False)]

    if test_data.shape[0] == 0:
        print(f'No test data found for responseid {responseid}')
        continue
    
    print('data name', data_name)
    unique_paths = test_data.csv_path.unique()

    key = next(k for k, v in friendly_names.items() if v == data_name)
    print(key)  # Output: 'out_c00_dr10_label.tif'

    data_to_find = test_data[test_data.csv_path.str.contains(data_name, na=False, case=False)]
    print(f'there are {data_to_find.shape[0]} rows for {data_name} in responseid {responseid}')

    if data_to_find.shape[0] == 0:
        print(f'No test data found for {data_name} in responseid {responseid}')
        continue
    print(f'there are {len(data_to_find.csv_path.unique())} unique test csv paths')

    gt = ground_truth[ground_truth['base_name'] == key]
    print(f'there are {gt.shape[0]} rows for {key}')

    name = data_to_find['csv_path'].iloc[0]
    td = data_to_find[data_to_find.csv_path == name]
    
    td = td[['x', 'y', 'z']].apply(pd.to_numeric, errors='coerce').fillna(0)

    # remove any zero rows from answer
    td = td[(td[['x', 'y', 'z']] != 0).any(axis=1)]

    a, b, lsa_mean = compute_lsa_distance(
        gt[['x', 'y', 'z']].values,
        td[['x', 'y', 'z']].fillna(0).values.astype(float)
    )
    print(f'lsa mean raw: {lsa_mean}')
   
    gt_corrected = gt.copy()   
    
    if 'nuclei' in data_name: 
        gt_corrected['z'] = gt['z']*(.124/.2)
    else:
        gt_corrected['z'] = gt['z']*(.1616160/.2)
    
    gt_corrected = gt_corrected[['x', 'y', 'z']].fillna(0).astype(float)
    
    a_, b_, lsa_mean_label_spacings_corrected = compute_lsa_distance(
        gt_corrected[['x', 'y', 'z']].values,
        td[['x', 'y', 'z']].fillna(0).values.astype(float)
    )

    print(f'lsa mean label spacings corrected: {lsa_mean_label_spacings_corrected}')
    
    td_corrected, correction = apply_corrections(td, responseid, data_name)

    combined_data.loc[(combined_data['responseid'] == responseid) &
                        (combined_data['setName'] == data_name), 
                        'correction'] = correction

    a, b, lsa_mean_corrected = compute_lsa_distance(
        gt_corrected.values,
        td_corrected.values
    )

    if 'fish' in data_name:
        tp, fp, fn, jac = calculate_jac(
            gt_corrected[['x', 'y', 'z']].values,
            td_corrected[['x', 'y', 'z']].values, lsa=(a,b)
        )
        print(f'jac is {jac}, tp: {tp}, fp: {fp}, fn: {fn}')
    else:
        jac, tp, fp, fn = 0, 0, 0, 0 

    #if 'R_2rCMx6wAGE7bFJh' in responseid and 'nuclei' in data_name: 
    scale, translation = find_scale_and_translation(gt_corrected, td_corrected, True)
    print(f'detected scale: {scale}, detected translation: {translation}')

    td_transformed = td_corrected.copy()

    td_transformed['x']= td_corrected['x']*scale[0,0] + translation[0,0]
    td_transformed['y']= td_corrected['y']*scale[0,1] + translation[0,1]
    td_transformed['z']= td_corrected['z']*scale[0,2] + translation[0,2]

    scale, translation = find_scale_and_translation(gt_corrected, td_corrected)
    print(f'detected scale: {scale}, detected translation: {translation}')
    #correction = "AUTOMATIC"

    a, b, lsa_mean_corrected_transformed = compute_lsa_distance(
        gt_corrected.values,
        td_transformed.values
    )

    if 'fish' in data_name:
        tp, fp, fn, jac_transformed = calculate_jac(
            gt_corrected[['x', 'y', 'z']].values,
            td_transformed[['x', 'y', 'z']].values, lsa=(a,b)
        )
        print(f'jac transformed is {jac_transformed}, tp: {tp}, fp: {fp}, fn: {fn}')
    else:
        jac_transformed, tp, fp, fn = 0, 0, 0, 0 
          
    print(f'lsa mse raw: {lsa_mean}')
    print(f'lsa mse transformed: {lsa_mean_corrected}')
    print(f'jac: {jac}')
    print('=======================================================')

    # update the combined_data DataFrame with the computed values
    combined_data.loc[(combined_data['responseid'] == responseid) & 
                        (combined_data['setName'] == data_name), 
                        'lsa_mse_label_corrected'] = lsa_mean_label_spacings_corrected
    
    combined_data.loc[(combined_data['responseid'] == responseid) & 
                        (combined_data['setName'] == data_name), 
                        'lsa_mse_label_and_image_corrected'] = lsa_mean_corrected
    
    # best is min of lsa_mse_transformed and lsa_mse_transformed_alt
    combined_data.loc[(combined_data['responseid'] == responseid) & 
                        (combined_data['setName'] == data_name), 
                        'best'] =  combined_data[['lsa_mse_transformed', 'lsa_mse_label_and_image_corrected']].min(axis=1)
    
    combined_data.loc[(combined_data['responseid'] == responseid) &
                        (combined_data['setName'] == data_name), 
                        'jac'] = jac
    
    combined_data.loc[(combined_data['responseid'] == responseid) &
                        (combined_data['setName'] == data_name), 
                        'jac_transformed'] = jac_transformed
    
    combined_data.loc[(combined_data['responseid'] == responseid) &
                        (combined_data['setName'] == data_name), 
                        'lsa_mse_transformed'] = lsa_mean_corrected_transformed

    combined_data.loc[(combined_data['responseid'] == responseid) &
                        (combined_data['setName'] == data_name), 
                        'lsa_mse_best'] = min(lsa_mean_corrected, lsa_mean_corrected_transformed)
    
    combined_data.loc[(combined_data['responseid'] == responseid) &
                        (combined_data['setName'] == data_name), 
                        'jac_best'] = max(jac, jac_transformed)
# Out:
# Processing responseid: R_31bjqd6Mm8wBxN5
# data name nuclei1
# out_c00_dr90_label.tif
# there are 5 rows for nuclei1 in responseid R_31bjqd6Mm8wBxN5
# there are 1 unique test csv paths
# there are 5 rows for out_c00_dr90_label.tif
# lsa mean raw: 182.45182410519618
# lsa mean label spacings corrected: 105.70139484092722
# detected scale: [[1.00323818 1.00323818 1.00520221]], detected translation: [[-0.03374655  0.02866844 -0.02458869]]
# detected scale: [[1.00323818 1.00323818 1.00520221]], detected translation: [[-0.03374655  0.02866844 -0.02458869]]
# lsa mse raw: 182.45182410519618
# lsa mse transformed: 0.019770487446740256
# jac: 0
# =======================================================
# Processing responseid: R_31bjqd6Mm8wBxN5
# data name nuclei2
# out_c90_dr90_label.tif
# there are 5 rows for nuclei2 in responseid R_31bjqd6Mm8wBxN5
# there are 1 unique test csv paths
# there are 5 rows for out_c90_dr90_label.tif
# lsa mean raw: 47.222278976484276
# lsa mean label spacings corrected: 22.69394231922051
# detected scale: [[0.99912468 0.99912468 1.02446098]], detected translation: [[ 0.01556097  0.02794257 -0.14440509]]
# detected scale: [[0.99912468 0.99912468 1.02446098]], detected translation: [[ 0.01556097  0.02794257 -0.14440509]]
# lsa mse raw: 47.222278976484276
# lsa mse transformed: 0.019032444200394544
# jac: 0
# =======================================================
# Processing responseid: R_31bjqd6Mm8wBxN5
# data name nuclei3
# out_c00_dr10_label.tif
# there are 5 rows for nuclei3 in responseid R_31bjqd6Mm8wBxN5
# there are 1 unique test csv paths
# there are 5 rows for out_c00_dr10_label.tif
# lsa mean raw: 105.57786460635778
# lsa mean label spacings corrected: 72.88020901040093
# detected scale: [[1.00165399 1.00165399 1.0250787 ]], detected translation: [[-0.15741128 -0.21501557 -0.23676593]]
# detected scale: [[1.00165399 1.00165399 1.0250787 ]], detected translation: [[-0.15741128 -0.21501557 -0.23676593]]
# lsa mse raw: 105.57786460635778
# lsa mse transformed: 0.0669093440192055
# jac: 0
# =======================================================
# Processing responseid: R_31bjqd6Mm8wBxN5
# data name nuclei4
# out_c90_dr10_label.tif
# there are 5 rows for nuclei4 in responseid R_31bjqd6Mm8wBxN5
# there are 1 unique test csv paths
# there are 5 rows for out_c90_dr10_label.tif
# lsa mean raw: 88.28715037978229
# lsa mean label spacings corrected: 44.82182390926037
# detected scale: [[1.01263252 1.01263252 1.02337116]], detected translation: [[-0.14072649 -0.14475067 -0.2038786 ]]
# detected scale: [[1.01263252 1.01263252 1.02337116]], detected translation: [[-0.14072649 -0.14475067 -0.2038786 ]]
# lsa mse raw: 88.28715037978229
# lsa mse transformed: 0.020630346476575252
# jac: 0
# =======================================================
# C:\Users\bnort\AppData\Local\Temp\ipykernel_4888\648172652.py:123: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '105.70139484092722' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   combined_data.loc[(combined_data['responseid'] == responseid) &
# C:\Users\bnort\AppData\Local\Temp\ipykernel_4888\648172652.py:127: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.019770487446740256' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   combined_data.loc[(combined_data['responseid'] == responseid) &
# C:\Users\bnort\AppData\Local\Temp\ipykernel_4888\648172652.py:144: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.011610509627968115' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   combined_data.loc[(combined_data['responseid'] == responseid) &
# C:\Users\bnort\AppData\Local\Temp\ipykernel_4888\648172652.py:148: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.011610509627968115' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   combined_data.loc[(combined_data['responseid'] == responseid) &
# Processing responseid: R_3lAJ9xY4kGlL99f
# data name nuclei1
# out_c00_dr90_label.tif
# there are 5 rows for nuclei1 in responseid R_3lAJ9xY4kGlL99f
# there are 1 unique test csv paths
# there are 5 rows for out_c00_dr90_label.tif
# lsa mean raw: 565.205858187181
# lsa mean label spacings corrected: 457.89049407357305
# detected scale: [[1.00366614 1.00366614 1.01980049]], detected translation: [[-0.15646795 -0.01690999  0.04452627]]
# detected scale: [[1.00366614 1.00366614 1.01980049]], detected translation: [[-0.15646795 -0.01690999  0.04452627]]
# lsa mse raw: 565.205858187181
# lsa mse transformed: 0.07075414248401397
# jac: 0
# =======================================================
# Processing responseid: R_3lAJ9xY4kGlL99f
# data name nuclei2
# out_c90_dr90_label.tif
# there are 5 rows for nuclei2 in responseid R_3lAJ9xY4kGlL99f
# there are 1 unique test csv paths
# there are 5 rows for out_c90_dr90_label.tif
# lsa mean raw: 382.36635822745177
# lsa mean label spacings corrected: 297.21666707059364
# detected scale: [[1.0306694  1.0306694  0.99961107]], detected translation: [[-0.34364763 -0.44073383  0.17640124]]
# detected scale: [[1.0306694  1.0306694  0.99961107]], detected translation: [[-0.34364763 -0.44073383  0.17640124]]
# lsa mse raw: 382.36635822745177
# lsa mse transformed: 0.11922013270843435
# jac: 0
# =======================================================
# Processing responseid: R_3lAJ9xY4kGlL99f
# data name nuclei3
# out_c00_dr10_label.tif
# there are 5 rows for nuclei3 in responseid R_3lAJ9xY4kGlL99f
# there are 1 unique test csv paths
# there are 5 rows for out_c00_dr10_label.tif
# lsa mean raw: 508.9007579149028
# lsa mean label spacings corrected: 397.9688990649841
# detected scale: [[1.00902042 1.00902042 1.02210356]], detected translation: [[-0.28947396 -0.41461876 -0.27442467]]
# detected scale: [[1.00902042 1.00902042 1.02210356]], detected translation: [[-0.28947396 -0.41461876 -0.27442467]]
# lsa mse raw: 508.9007579149028
# lsa mse transformed: 0.1702084628226332
# jac: 0
# =======================================================
# Processing responseid: R_3lAJ9xY4kGlL99f
# data name nuclei4
# out_c90_dr10_label.tif
# there are 5 rows for nuclei4 in responseid R_3lAJ9xY4kGlL99f
# there are 1 unique test csv paths
# there are 5 rows for out_c90_dr10_label.tif
# lsa mean raw: 459.00121402902295
# lsa mean label spacings corrected: 317.411376056945
# detected scale: [[1.00055496 1.00055496 1.01836531]], detected translation: [[0.05671046 0.01712915 0.04690641]]
# detected scale: [[1.00055496 1.00055496 1.01836531]], detected translation: [[0.05671046 0.01712915 0.04690641]]
# lsa mse raw: 459.00121402902295
# lsa mse transformed: 0.09605110735949655
# jac: 0
# =======================================================
# Processing responseid: R_3lAJ9xY4kGlL99f
# data name fish1
# celegans_dyn-90_ceff-0_label.ics.ome.tiff
# there are 1452 rows for fish1 in responseid R_3lAJ9xY4kGlL99f
# there are 1 unique test csv paths
# there are 1501 rows for celegans_dyn-90_ceff-0_label.ics.ome.tiff
# lsa mean raw: 787.9741272124363
# lsa mean label spacings corrected: 794.2517499086771
# jac is 0.927381745502998, tp: 1392, fp: 60, fn: 49
# detected scale: [[0.99911784 0.99911784 0.99816328]], detected translation: [[-0.04879283 -0.02953876 -0.01067962]]
# detected scale: [[0.99911784 0.99911784 0.99816328]], detected translation: [[-0.04879283 -0.02953876 -0.01067962]]
# jac transformed is 0.9280479680213192, tp: 1393, fp: 59, fn: 49
# lsa mse raw: 787.9741272124363
# lsa mse transformed: 0.0756074348635062
# jac: 0.927381745502998
# =======================================================
# Processing responseid: R_3lAJ9xY4kGlL99f
# data name fish2
# celegans_dyn-90_ceff-90_label.ics.ome.tiff
# there are 1405 rows for fish2 in responseid R_3lAJ9xY4kGlL99f
# there are 1 unique test csv paths
# there are 1501 rows for celegans_dyn-90_ceff-90_label.ics.ome.tiff
# C:\Users\bnort\AppData\Local\Temp\ipykernel_4888\648172652.py:136: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.927381745502998' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   combined_data.loc[(combined_data['responseid'] == responseid) &
# C:\Users\bnort\AppData\Local\Temp\ipykernel_4888\648172652.py:140: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.9280479680213192' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   combined_data.loc[(combined_data['responseid'] == responseid) &
# C:\Users\bnort\AppData\Local\Temp\ipykernel_4888\648172652.py:152: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.9280479680213192' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   combined_data.loc[(combined_data['responseid'] == responseid) &
# lsa mean raw: 647.8575953295809
# lsa mean label spacings corrected: 647.9298010624805
# jac is 0.7921385742838108, tp: 1189, fp: 216, fn: 96
# detected scale: [[0.99313043 0.99313043 0.97635834]], detected translation: [[-0.06667499  0.29991406  0.01797729]]
# detected scale: [[0.99313043 0.99313043 0.97635834]], detected translation: [[-0.06667499  0.29991406  0.01797729]]
# jac transformed is 0.41305796135909395, tp: 620, fp: 785, fn: 96
# lsa mse raw: 647.8575953295809
# lsa mse transformed: 2.084009008888506
# jac: 0.7921385742838108
# =======================================================
# Processing responseid: R_3lAJ9xY4kGlL99f
# data name fish3
# celegans_dyn-10_ceff-0_label.ics.ome.tiff
# there are 1759 rows for fish3 in responseid R_3lAJ9xY4kGlL99f
# there are 1 unique test csv paths
# there are 1501 rows for celegans_dyn-10_ceff-0_label.ics.ome.tiff
# lsa mean raw: 394.31577246053433
# lsa mean label spacings corrected: 393.78661032167753
# jac is 0.8220579874928937, tp: 1446, fp: 313, fn: 0
# detected scale: [[0.99956399 0.99956399 0.99632205]], detected translation: [[-0.0598357  -0.04854492  0.00671338]]
# detected scale: [[0.99956399 0.99956399 0.99632205]], detected translation: [[-0.0598357  -0.04854492  0.00671338]]
# jac transformed is 0.8237635019897669, tp: 1449, fp: 310, fn: 0
# lsa mse raw: 394.31577246053433
# lsa mse transformed: 0.13595725981093626
# jac: 0.8220579874928937
# =======================================================
# Processing responseid: R_3lAJ9xY4kGlL99f
# data name fish4
# celegans_dyn-10_ceff-90_label.ics.ome.tiff
# there are 1482 rows for fish4 in responseid R_3lAJ9xY4kGlL99f
# there are 1 unique test csv paths
# there are 1501 rows for celegans_dyn-10_ceff-90_label.ics.ome.tiff
# lsa mean raw: 1060.1203472035295
# lsa mean label spacings corrected: 1074.6155265705022
# jac is 0.8114590273151232, tp: 1218, fp: 264, fn: 19
# detected scale: [[0.99444427 0.99444427 0.98481591]], detected translation: [[0.0838612  0.19404738 0.01703079]]
# detected scale: [[0.99444427 0.99444427 0.98481591]], detected translation: [[0.0838612  0.19404738 0.01703079]]
# jac transformed is 0.7075283144570287, tp: 1062, fp: 420, fn: 19
# lsa mse raw: 1060.1203472035295
# lsa mse transformed: 1.3221225990489602
# jac: 0.8114590273151232
# =======================================================
# Processing responseid: R_3kpixa7Fm6wlFk2
# data name nuclei1
# out_c00_dr90_label.tif
# there are 5 rows for nuclei1 in responseid R_3kpixa7Fm6wlFk2
# there are 1 unique test csv paths
# there are 5 rows for out_c00_dr90_label.tif
# lsa mean raw: 30.678121967055244
# lsa mean label spacings corrected: 0.6077117838077929
# detected scale: [[1.03504337 1.03504337 0.99811789]], detected translation: [[-0.08995809 -0.06928137  0.0709836 ]]
# detected scale: [[1.03504337 1.03504337 0.99811789]], detected translation: [[-0.08995809 -0.06928137  0.0709836 ]]
# lsa mse raw: 30.678121967055244
# lsa mse transformed: 0.6077117838077929
# jac: 0
# =======================================================
# Processing responseid: R_3kpixa7Fm6wlFk2
# data name nuclei2
# out_c90_dr90_label.tif
# there are 5 rows for nuclei2 in responseid R_3kpixa7Fm6wlFk2
# there are 1 unique test csv paths
# there are 5 rows for out_c90_dr90_label.tif
# lsa mean raw: 25.233951586670948
# lsa mean label spacings corrected: 0.4179521867559036
# detected scale: [[1.03679041 1.03679041 1.03963768]], detected translation: [[-0.09759004 -0.10837993 -0.23867303]]
# detected scale: [[1.03679041 1.03679041 1.03963768]], detected translation: [[-0.09759004 -0.10837993 -0.23867303]]
# lsa mse raw: 25.233951586670948
# lsa mse transformed: 0.4179521867559036
# jac: 0
# =======================================================
# Processing responseid: R_3kpixa7Fm6wlFk2
# data name nuclei3
# out_c00_dr10_label.tif
# there are 5 rows for nuclei3 in responseid R_3kpixa7Fm6wlFk2
# there are 1 unique test csv paths
# there are 5 rows for out_c00_dr10_label.tif
# lsa mean raw: 29.892646040788698
# lsa mean label spacings corrected: 0.2580175274085874
# detected scale: [[1.03384748 1.03384748 1.01885548]], detected translation: [[-0.22458849 -0.24995308 -0.18159109]]
# detected scale: [[1.03384748 1.03384748 1.01885548]], detected translation: [[-0.22458849 -0.24995308 -0.18159109]]
# lsa mse raw: 29.892646040788698
# lsa mse transformed: 0.2580175274085874
# jac: 0
# =======================================================
# Processing responseid: R_3kpixa7Fm6wlFk2
# data name nuclei4
# out_c90_dr10_label.tif
# there are 5 rows for nuclei4 in responseid R_3kpixa7Fm6wlFk2
# there are 1 unique test csv paths
# there are 5 rows for out_c90_dr10_label.tif
# lsa mean raw: 40.96004044453092
# lsa mean label spacings corrected: 0.34475711582014107
# detected scale: [[1.03636813 1.03636813 1.01380106]], detected translation: [[-0.10439393 -0.11214116 -0.09355738]]
# detected scale: [[1.03636813 1.03636813 1.01380106]], detected translation: [[-0.10439393 -0.11214116 -0.09355738]]
# lsa mse raw: 40.96004044453092
# lsa mse transformed: 0.34475711582014107
# jac: 0
# =======================================================
# Processing responseid: R_3Rxaf07hES8CPgE
# data name nuclei1
# out_c00_dr90_label.tif
# there are 5 rows for nuclei1 in responseid R_3Rxaf07hES8CPgE
# there are 1 unique test csv paths
# there are 5 rows for out_c00_dr90_label.tif
# lsa mean raw: 30.348757695678138
# lsa mean label spacings corrected: 0.008677568238877938
# detected scale: [[1.00189788 1.00189788 1.01583069]], detected translation: [[-0.03356535 -0.01884862 -0.06946916]]
# detected scale: [[1.00189788 1.00189788 1.01583069]], detected translation: [[-0.03356535 -0.01884862 -0.06946916]]
# lsa mse raw: 30.348757695678138
# lsa mse transformed: 0.008677568238877938
# jac: 0
# =======================================================
# Processing responseid: R_2q3KgZzjsLNwxgU
# data name fish1
# celegans_dyn-90_ceff-0_label.ics.ome.tiff
# there are 1484 rows for fish1 in responseid R_2q3KgZzjsLNwxgU
# there are 1 unique test csv paths
# there are 1501 rows for celegans_dyn-90_ceff-0_label.ics.ome.tiff
# lsa mean raw: 2.0476728693775548
# lsa mean label spacings corrected: 0.026402367574412947
# jac is 0.9726848767488341, tp: 1460, fp: 24, fn: 17
# detected scale: [[0.99984635 0.99984635 0.99924998]], detected translation: [[-0.07207208 -0.05177636 -0.01194104]]
# detected scale: [[0.99984635 0.99984635 0.99924998]], detected translation: [[-0.07207208 -0.05177636 -0.01194104]]
# jac transformed is 0.9873417721518988, tp: 1482, fp: 2, fn: 17
# lsa mse raw: 2.0476728693775548
# lsa mse transformed: 0.026402367574412947
# jac: 0.9726848767488341
# =======================================================
# Processing responseid: R_2q3KgZzjsLNwxgU
# data name fish2
# celegans_dyn-90_ceff-90_label.ics.ome.tiff
# there are 1474 rows for fish2 in responseid R_2q3KgZzjsLNwxgU
# there are 1 unique test csv paths
# there are 1501 rows for celegans_dyn-90_ceff-90_label.ics.ome.tiff
# lsa mean raw: 2.8449429956135215
# lsa mean label spacings corrected: 0.026329486769616557
# jac is 0.9546968687541639, tp: 1433, fp: 41, fn: 27
# detected scale: [[0.99981876 0.99981876 0.99998187]], detected translation: [[-0.06475609 -0.05045732 -0.01270504]]
# detected scale: [[0.99981876 0.99981876 0.99998187]], detected translation: [[-0.06475609 -0.05045732 -0.01270504]]
# jac transformed is 0.9753497668221186, tp: 1464, fp: 10, fn: 27
# lsa mse raw: 2.8449429956135215
# lsa mse transformed: 0.026329486769616557
# jac: 0.9546968687541639
# =======================================================
# Processing responseid: R_2q3KgZzjsLNwxgU
# data name fish3
# celegans_dyn-10_ceff-0_label.ics.ome.tiff
# there are 1451 rows for fish3 in responseid R_2q3KgZzjsLNwxgU
# there are 1 unique test csv paths
# there are 1501 rows for celegans_dyn-10_ceff-0_label.ics.ome.tiff
# lsa mean raw: 3.1075429341948215
# lsa mean label spacings corrected: 0.026953094888986687
# jac is 0.9493670886075949, tp: 1425, fp: 26, fn: 50
# detected scale: [[0.99979688 0.99979688 1.00012504]], detected translation: [[-0.06638513 -0.05334196 -0.01425102]]
# detected scale: [[0.99979688 0.99979688 1.00012504]], detected translation: [[-0.06638513 -0.05334196 -0.01425102]]
# jac transformed is 0.966022651565623, tp: 1450, fp: 1, fn: 50
# lsa mse raw: 3.1075429341948215
# lsa mse transformed: 0.026953094888986687
# jac: 0.9493670886075949
# =======================================================
# Processing responseid: R_2q3KgZzjsLNwxgU
# data name fish4
# celegans_dyn-10_ceff-90_label.ics.ome.tiff
# there are 1436 rows for fish4 in responseid R_2q3KgZzjsLNwxgU
# there are 1 unique test csv paths
# there are 1501 rows for celegans_dyn-10_ceff-90_label.ics.ome.tiff
# lsa mean raw: 2.9939281919372127
# lsa mean label spacings corrected: 0.027697066987204606
# jac is 0.9353764157228515, tp: 1404, fp: 32, fn: 65
# detected scale: [[1.00000786 1.00000786 1.00002435]], detected translation: [[-0.07466581 -0.06750989 -0.01254149]]
# detected scale: [[1.00000786 1.00000786 1.00002435]], detected translation: [[-0.07466581 -0.06750989 -0.01254149]]
# jac transformed is 0.955363091272485, tp: 1434, fp: 2, fn: 65
# lsa mse raw: 2.9939281919372127
# lsa mse transformed: 0.027697066987204606
# jac: 0.9353764157228515
# =======================================================
# Processing responseid: R_2rCMx6wAGE7bFJh
# data name nuclei1
# out_c00_dr90_label.tif
# there are 5 rows for nuclei1 in responseid R_2rCMx6wAGE7bFJh
# there are 1 unique test csv paths
# there are 5 rows for out_c00_dr90_label.tif
# lsa mean raw: 4.614993960579744
# lsa mean label spacings corrected: 17.203951770316664
# detected scale: [[0.99989475 0.99989475 0.99059065]], detected translation: [[-0.05046763 -0.05341106 -4.02908858]]
# detected scale: [[0.99989475 0.99989475 0.99059065]], detected translation: [[-0.05046763 -0.05341106 -4.02908858]]
# lsa mse raw: 4.614993960579744
# lsa mse transformed: 17.203951770316664
# jac: 0
# =======================================================
# Processing responseid: R_2rCMx6wAGE7bFJh
# data name nuclei2
# out_c90_dr90_label.tif
# there are 5 rows for nuclei2 in responseid R_2rCMx6wAGE7bFJh
# there are 1 unique test csv paths
# there are 5 rows for out_c90_dr90_label.tif
# lsa mean raw: 35.217271043740496
# lsa mean label spacings corrected: 101.59120516504322
# detected scale: [[0.91100588 0.91100588 1.0869333 ]], detected translation: [[ -0.36926363  -0.4151645  -11.22957706]]
# detected scale: [[0.91100588 0.91100588 1.0869333 ]], detected translation: [[ -0.36926363  -0.4151645  -11.22957706]]
# lsa mse raw: 35.217271043740496
# lsa mse transformed: 101.59120516504322
# jac: 0
# =======================================================
# Processing responseid: R_2rCMx6wAGE7bFJh
# data name nuclei3
# out_c00_dr10_label.tif
# there are 5 rows for nuclei3 in responseid R_2rCMx6wAGE7bFJh
# there are 1 unique test csv paths
# there are 5 rows for out_c00_dr10_label.tif
# lsa mean raw: 37.00343429795865
# lsa mean label spacings corrected: 108.14487122479231
# detected scale: [[0.88067249 0.88067249 1.02491174]], detected translation: [[ -0.13503753  -0.18627518 -10.26658787]]
# detected scale: [[0.88067249 0.88067249 1.02491174]], detected translation: [[ -0.13503753  -0.18627518 -10.26658787]]
# lsa mse raw: 37.00343429795865
# lsa mse transformed: 108.14487122479231
# jac: 0
# =======================================================
# Processing responseid: R_2rCMx6wAGE7bFJh
# data name nuclei4
# out_c90_dr10_label.tif
# there are 7 rows for nuclei4 in responseid R_2rCMx6wAGE7bFJh
# there are 1 unique test csv paths
# there are 5 rows for out_c90_dr10_label.tif
# lsa mean raw: 155.4508718431802
# lsa mean label spacings corrected: 327.0311368860078
# detected scale: [[0.90707404 0.90707404 1.05799017]], detected translation: [[ -0.39858154  -0.47931536 -19.46759339]]
# detected scale: [[0.90707404 0.90707404 1.05799017]], detected translation: [[ -0.39858154  -0.47931536 -19.46759339]]
# lsa mse raw: 155.4508718431802
# lsa mse transformed: 327.0311368860078
# jac: 0
# =======================================================
# Processing responseid: R_2rCMx6wAGE7bFJh
# data name fish1
# celegans_dyn-90_ceff-0_label.ics.ome.tiff
# there are 1337 rows for fish1 in responseid R_2rCMx6wAGE7bFJh
# there are 1 unique test csv paths
# there are 1501 rows for celegans_dyn-90_ceff-0_label.ics.ome.tiff
# lsa mean raw: 1.4203226191022806
# lsa mean label spacings corrected: 0.09603247820524427
# jac is 0.08594270486342438, tp: 129, fp: 1208, fn: 164
# detected scale: [[0.99988238 0.99988238 1.00438095]], detected translation: [[-0.1960215  -0.18671699 -0.14506337]]
# detected scale: [[0.99988238 0.99988238 1.00438095]], detected translation: [[-0.1960215  -0.18671699 -0.14506337]]
# jac transformed is 0.8760826115922719, tp: 1315, fp: 22, fn: 164
# lsa mse raw: 1.4203226191022806
# lsa mse transformed: 0.09603247820524427
# jac: 0.08594270486342438
# =======================================================
# Processing responseid: R_2rCMx6wAGE7bFJh
# data name fish2
# celegans_dyn-90_ceff-90_label.ics.ome.tiff
# there are 1336 rows for fish2 in responseid R_2rCMx6wAGE7bFJh
# there are 1 unique test csv paths
# there are 1501 rows for celegans_dyn-90_ceff-90_label.ics.ome.tiff
# lsa mean raw: 2.226873868600263
# lsa mean label spacings corrected: 0.09565678774901608
# jac is 0.12325116588940706, tp: 185, fp: 1151, fn: 165
# detected scale: [[0.99992374 0.99992374 1.00404791]], detected translation: [[-0.19107529 -0.18536407 -0.14093865]]
# detected scale: [[0.99992374 0.99992374 1.00404791]], detected translation: [[-0.19107529 -0.18536407 -0.14093865]]
# jac transformed is 0.8620919387075283, tp: 1294, fp: 42, fn: 165
# lsa mse raw: 2.226873868600263
# lsa mse transformed: 0.09565678774901608
# jac: 0.12325116588940706
# =======================================================
# Processing responseid: R_2rCMx6wAGE7bFJh
# data name fish3
# celegans_dyn-10_ceff-0_label.ics.ome.tiff
# there are 1279 rows for fish3 in responseid R_2rCMx6wAGE7bFJh
# there are 1 unique test csv paths
# there are 1501 rows for celegans_dyn-10_ceff-0_label.ics.ome.tiff
# lsa mean raw: 2.2167488825936537
# lsa mean label spacings corrected: 0.09821389384779773
# jac is 0.13257828114590273, tp: 199, fp: 1080, fn: 222
# detected scale: [[0.99982059 0.99982059 1.00073803]], detected translation: [[-0.19023551 -0.18313509 -0.12049272]]
# detected scale: [[0.99982059 0.99982059 1.00073803]], detected translation: [[-0.19023551 -0.18313509 -0.12049272]]
# jac transformed is 0.8281145902731513, tp: 1243, fp: 36, fn: 222
# lsa mse raw: 2.2167488825936537
# lsa mse transformed: 0.09821389384779773
# jac: 0.13257828114590273
# =======================================================
# Processing responseid: R_2rCMx6wAGE7bFJh
# data name fish4
# celegans_dyn-10_ceff-90_label.ics.ome.tiff
# there are 1278 rows for fish4 in responseid R_2rCMx6wAGE7bFJh
# there are 1 unique test csv paths
# there are 1501 rows for celegans_dyn-10_ceff-90_label.ics.ome.tiff
# lsa mean raw: 1.9757682032085557
# lsa mean label spacings corrected: 0.10258481499972867
# jac is 0.11725516322451698, tp: 176, fp: 946, fn: 379
# detected scale: [[0.99989883 0.99989883 1.00213625]], detected translation: [[-0.18700481 -0.18168327 -0.12144989]]
# detected scale: [[0.99989883 0.99989883 1.00213625]], detected translation: [[-0.18700481 -0.18168327 -0.12144989]]
# jac transformed is 0.6708860759493671, tp: 1007, fp: 115, fn: 379
# lsa mse raw: 1.9757682032085557
# lsa mse transformed: 0.10258481499972867
# jac: 0.11725516322451698
# =======================================================
# Processing responseid: R_2cC2iQifrFmuClP
# data name nuclei1
# out_c00_dr90_label.tif
# there are 5 rows for nuclei1 in responseid R_2cC2iQifrFmuClP
# there are 1 unique test csv paths
# there are 5 rows for out_c00_dr90_label.tif
# lsa mean raw: 29.164517975110545
# lsa mean label spacings corrected: 0.06408436503978313
# detected scale: [[1.00068629 1.00068629 1.01268168]], detected translation: [[-0.03818983 -0.09041519 -0.16367937]]
# detected scale: [[1.00068629 1.00068629 1.01268168]], detected translation: [[-0.03818983 -0.09041519 -0.16367937]]
# lsa mse raw: 29.164517975110545
# lsa mse transformed: 0.06408436503978313
# jac: 0
# =======================================================
# Processing responseid: R_1M6DoAmYEY3Jrvm
# data name nuclei1
# out_c00_dr90_label.tif
# there are 5 rows for nuclei1 in responseid R_1M6DoAmYEY3Jrvm
# there are 1 unique test csv paths
# there are 5 rows for out_c00_dr90_label.tif
# lsa mean raw: 29.325520761511996
# lsa mean label spacings corrected: 0.041243087801639426
# detected scale: [[1.00710975 1.00710975 1.0081794 ]], detected translation: [[-0.14811011 -0.15160066 -0.10236865]]
# detected scale: [[1.00710975 1.00710975 1.0081794 ]], detected translation: [[-0.14811011 -0.15160066 -0.10236865]]
# lsa mse raw: 29.325520761511996
# lsa mse transformed: 0.041243087801639426
# jac: 0
# =======================================================
# Processing responseid: R_1M6DoAmYEY3Jrvm
# data name nuclei2
# out_c90_dr90_label.tif
# there are 5 rows for nuclei2 in responseid R_1M6DoAmYEY3Jrvm
# there are 1 unique test csv paths
# there are 5 rows for out_c90_dr90_label.tif
# lsa mean raw: 24.368009199467355
# lsa mean label spacings corrected: 0.09452940908219436
# detected scale: [[1.02309219 1.02309219 1.04540474]], detected translation: [[-0.24440475 -0.33332063 -0.34702537]]
# detected scale: [[1.02309219 1.02309219 1.04540474]], detected translation: [[-0.24440475 -0.33332063 -0.34702537]]
# lsa mse raw: 24.368009199467355
# lsa mse transformed: 0.09452940908219436
# jac: 0
# =======================================================
# Processing responseid: R_1M6DoAmYEY3Jrvm
# data name nuclei3
# out_c00_dr10_label.tif
# there are 0 rows for nuclei3 in responseid R_1M6DoAmYEY3Jrvm
# No test data found for nuclei3 in responseid R_1M6DoAmYEY3Jrvm
# Processing responseid: R_1M6DoAmYEY3Jrvm
# data name nuclei4
# out_c90_dr10_label.tif
# there are 5 rows for nuclei4 in responseid R_1M6DoAmYEY3Jrvm
# there are 1 unique test csv paths
# there are 5 rows for out_c90_dr10_label.tif
# lsa mean raw: 39.25127480574112
# lsa mean label spacings corrected: 0.2400551831124445
# detected scale: [[1.04818619 1.04818619 1.08516829]], detected translation: [[-0.68637575 -0.80044284 -1.01912356]]
# detected scale: [[1.04818619 1.04818619 1.08516829]], detected translation: [[-0.68637575 -0.80044284 -1.01912356]]
# lsa mse raw: 39.25127480574112
# lsa mse transformed: 0.2400551831124445
# jac: 0
# =======================================================
# Processing responseid: R_1M6DoAmYEY3Jrvm
# data name fish1
# celegans_dyn-90_ceff-0_label.ics.ome.tiff
# there are 1480 rows for fish1 in responseid R_1M6DoAmYEY3Jrvm
# there are 1 unique test csv paths
# there are 1501 rows for celegans_dyn-90_ceff-0_label.ics.ome.tiff
# lsa mean raw: 1.7717367223816738
# lsa mean label spacings corrected: 0.03302729034539445
# jac is 0.8847435043304464, tp: 1328, fp: 152, fn: 21
# detected scale: [[1.00233698 1.00233698 1.00040985]], detected translation: [[-0.16022295 -0.15113453 -0.1230376 ]]
# detected scale: [[1.00233698 1.00233698 1.00040985]], detected translation: [[-0.16022295 -0.15113453 -0.1230376 ]]
# jac transformed is 0.9860093271152565, tp: 1480, fp: 0, fn: 21
# lsa mse raw: 1.7717367223816738
# lsa mse transformed: 0.03302729034539445
# jac: 0.8847435043304464
# =======================================================
# Processing responseid: R_1M6DoAmYEY3Jrvm
# data name fish2
# celegans_dyn-90_ceff-90_label.ics.ome.tiff
# there are 1451 rows for fish2 in responseid R_1M6DoAmYEY3Jrvm
# there are 1 unique test csv paths
# there are 1501 rows for celegans_dyn-90_ceff-90_label.ics.ome.tiff
# lsa mean raw: 2.4257536177474415
# lsa mean label spacings corrected: 0.028860438534578772
# jac is 0.8834110592938041, tp: 1326, fp: 125, fn: 50
# detected scale: [[1.00238792 1.00238792 1.00069422]], detected translation: [[-0.15813928 -0.15355405 -0.12524527]]
# detected scale: [[1.00238792 1.00238792 1.00069422]], detected translation: [[-0.15813928 -0.15355405 -0.12524527]]
# jac transformed is 0.966688874083944, tp: 1451, fp: 0, fn: 50
# lsa mse raw: 2.4257536177474415
# lsa mse transformed: 0.028860438534578772
# jac: 0.8834110592938041
# =======================================================
# Processing responseid: R_1M6DoAmYEY3Jrvm
# data name fish3
# celegans_dyn-10_ceff-0_label.ics.ome.tiff
# there are 1484 rows for fish3 in responseid R_1M6DoAmYEY3Jrvm
# there are 1 unique test csv paths
# there are 1501 rows for celegans_dyn-10_ceff-0_label.ics.ome.tiff
# lsa mean raw: 2.969907174100593
# lsa mean label spacings corrected: 0.02742654621783412
# jac is 0.9127248500999334, tp: 1370, fp: 114, fn: 17
# detected scale: [[1.00231957 1.00231957 1.00040227]], detected translation: [[-0.15596427 -0.14794504 -0.12259397]]
# detected scale: [[1.00231957 1.00231957 1.00040227]], detected translation: [[-0.15596427 -0.14794504 -0.12259397]]
# jac transformed is 0.988674217188541, tp: 1484, fp: 0, fn: 17
# lsa mse raw: 2.969907174100593
# lsa mse transformed: 0.02742654621783412
# jac: 0.9127248500999334
# =======================================================
# Processing responseid: R_1M6DoAmYEY3Jrvm
# data name fish4
# celegans_dyn-10_ceff-90_label.ics.ome.tiff
# there are 1449 rows for fish4 in responseid R_1M6DoAmYEY3Jrvm
# there are 1 unique test csv paths
# there are 1501 rows for celegans_dyn-10_ceff-90_label.ics.ome.tiff
# lsa mean raw: 2.761591503740128
# lsa mean label spacings corrected: 0.04251925006192121
# jac is 0.8114590273151232, tp: 1218, fp: 231, fn: 52
# detected scale: [[1.00265641 1.00265641 1.00114928]], detected translation: [[-0.16123179 -0.16523178 -0.12823381]]
# detected scale: [[1.00265641 1.00265641 1.00114928]], detected translation: [[-0.16123179 -0.16523178 -0.12823381]]
# jac transformed is 0.9646902065289806, tp: 1448, fp: 1, fn: 52
# lsa mse raw: 2.761591503740128
# lsa mse transformed: 0.04251925006192121
# jac: 0.8114590273151232
# =======================================================
# Processing responseid: R_22s3aTqiX7gbY4u
# data name nuclei1
# out_c00_dr90_label.tif
# there are 10 rows for nuclei1 in responseid R_22s3aTqiX7gbY4u
# there are 1 unique test csv paths
# there are 5 rows for out_c00_dr90_label.tif
# lsa mean raw: 29.211458879358464
# lsa mean label spacings corrected: 0.05382565078691439
# detected scale: [[1.00757211 1.00757211 1.00684191]], detected translation: [[-0.14346697 -0.1759596  -0.10224729]]
# detected scale: [[1.00757211 1.00757211 1.00684191]], detected translation: [[-0.14346697 -0.1759596  -0.10224729]]
# lsa mse raw: 29.211458879358464
# lsa mse transformed: 0.05382565078691439
# jac: 0
# =======================================================
# Processing responseid: R_22s3aTqiX7gbY4u
# data name fish1
# celegans_dyn-90_ceff-0_label.ics.ome.tiff
# there are 1464 rows for fish1 in responseid R_22s3aTqiX7gbY4u
# there are 1 unique test csv paths
# there are 1501 rows for celegans_dyn-90_ceff-0_label.ics.ome.tiff
# lsa mean raw: 1.6770997991009504
# lsa mean label spacings corrected: 0.03288549817215284
# jac is 0.8787475016655563, tp: 1319, fp: 145, fn: 37
# detected scale: [[1.00224535 1.00224535 0.99961543]], detected translation: [[-0.15677285 -0.14779681 -0.11944012]]
# detected scale: [[1.00224535 1.00224535 0.99961543]], detected translation: [[-0.15677285 -0.14779681 -0.11944012]]
# jac transformed is 0.9746835443037974, tp: 1463, fp: 1, fn: 37
# lsa mse raw: 1.6770997991009504
# lsa mse transformed: 0.03288549817215284
# jac: 0.8787475016655563
# =======================================================
# Processing responseid: R_22s3aTqiX7gbY4u
# data name fish2
# celegans_dyn-90_ceff-90_label.ics.ome.tiff
# there are 1464 rows for fish2 in responseid R_22s3aTqiX7gbY4u
# there are 1 unique test csv paths
# there are 1501 rows for celegans_dyn-90_ceff-90_label.ics.ome.tiff
# lsa mean raw: 2.1813928414510904
# lsa mean label spacings corrected: 0.029053554274546905
# jac is 0.8341105929380414, tp: 1252, fp: 130, fn: 119
# detected scale: [[1.00214008 1.00214008 0.99927831]], detected translation: [[-0.14875592 -0.14267989 -0.11780139]]
# detected scale: [[1.00214008 1.00214008 0.99927831]], detected translation: [[-0.14875592 -0.14267989 -0.11780139]]
# jac transformed is 0.9207195203197868, tp: 1382, fp: 0, fn: 119
# lsa mse raw: 2.1813928414510904
# lsa mse transformed: 0.029053554274546905
# jac: 0.8341105929380414
# =======================================================
# Processing responseid: R_22s3aTqiX7gbY4u
# data name fish3
# celegans_dyn-10_ceff-0_label.ics.ome.tiff
# there are 1464 rows for fish3 in responseid R_22s3aTqiX7gbY4u
# there are 1 unique test csv paths
# there are 1501 rows for celegans_dyn-10_ceff-0_label.ics.ome.tiff
# lsa mean raw: 2.5361939544334167
# lsa mean label spacings corrected: 0.02747218440019263
# jac is 0.8614257161892072, tp: 1293, fp: 118, fn: 90
# detected scale: [[1.00228708 1.00228708 0.99934557]], detected translation: [[-0.15403293 -0.14759578 -0.11649506]]
# detected scale: [[1.00228708 1.00228708 0.99934557]], detected translation: [[-0.15403293 -0.14759578 -0.11649506]]
# jac transformed is 0.9400399733510992, tp: 1411, fp: 0, fn: 90
# lsa mse raw: 2.5361939544334167
# lsa mse transformed: 0.02747218440019263
# jac: 0.8614257161892072
# =======================================================
# Processing responseid: R_22s3aTqiX7gbY4u
# data name fish4
# celegans_dyn-10_ceff-90_label.ics.ome.tiff
# there are 1464 rows for fish4 in responseid R_22s3aTqiX7gbY4u
# there are 1 unique test csv paths
# there are 1501 rows for celegans_dyn-10_ceff-90_label.ics.ome.tiff
# lsa mean raw: 2.4258602406456347
# lsa mean label spacings corrected: 0.05359285235585021
# jac is 0.7435043304463691, tp: 1116, fp: 247, fn: 138
# detected scale: [[1.00214051 1.00214051 0.9977405 ]], detected translation: [[-0.15103464 -0.14591632 -0.10905807]]
# detected scale: [[1.00214051 1.00214051 0.9977405 ]], detected translation: [[-0.15103464 -0.14591632 -0.10905807]]
# jac transformed is 0.9073950699533644, tp: 1362, fp: 1, fn: 138
# lsa mse raw: 2.4258602406456347
# lsa mse transformed: 0.05359285235585021
# jac: 0.7435043304463691
# =======================================================
# Processing responseid: R_tY87q7yGKRqww5X
# data name nuclei1
# out_c00_dr90_label.tif
# there are 5 rows for nuclei1 in responseid R_tY87q7yGKRqww5X
# there are 1 unique test csv paths
# there are 5 rows for out_c00_dr90_label.tif
# lsa mean raw: 28.670660014518063
# lsa mean label spacings corrected: 0.017998895080774943
# detected scale: [[1.00214792 1.00214792 0.9798537 ]], detected translation: [[-0.05408732 -0.05110703  0.10634711]]
# detected scale: [[1.00214792 1.00214792 0.9798537 ]], detected translation: [[-0.05408732 -0.05110703  0.10634711]]
# lsa mse raw: 28.670660014518063
# lsa mse transformed: 0.017998895080774943
# jac: 0
# =======================================================
# Processing responseid: R_tY87q7yGKRqww5X
# data name nuclei2
# out_c90_dr90_label.tif
# there are 11 rows for nuclei2 in responseid R_tY87q7yGKRqww5X
# there are 1 unique test csv paths
# there are 5 rows for out_c90_dr90_label.tif
# lsa mean raw: 23.50450990957031
# lsa mean label spacings corrected: 0.0414021617353813
# detected scale: [[1.00274331 1.00274331 0.97374184]], detected translation: [[-0.01208986 -0.0892818   0.16576256]]
# detected scale: [[1.00274331 1.00274331 0.97374184]], detected translation: [[-0.01208986 -0.0892818   0.16576256]]
# lsa mse raw: 23.50450990957031
# lsa mse transformed: 0.0414021617353813
# jac: 0
# =======================================================
# Processing responseid: R_tY87q7yGKRqww5X
# data name nuclei3
# out_c00_dr10_label.tif
# there are 11 rows for nuclei3 in responseid R_tY87q7yGKRqww5X
# there are 1 unique test csv paths
# there are 5 rows for out_c00_dr10_label.tif
# lsa mean raw: 28.463783712610088
# lsa mean label spacings corrected: 0.2017827058743013
# detected scale: [[0.98358599 0.98358599 0.97983725]], detected translation: [[-0.00741405  0.02397847  0.05494992]]
# detected scale: [[0.98358599 0.98358599 0.97983725]], detected translation: [[-0.00741405  0.02397847  0.05494992]]
# lsa mse raw: 28.463783712610088
# lsa mse transformed: 0.2017827058743013
# jac: 0
# =======================================================
# Processing responseid: R_tY87q7yGKRqww5X
# data name nuclei4
# out_c90_dr10_label.tif
# there are 11 rows for nuclei4 in responseid R_tY87q7yGKRqww5X
# there are 1 unique test csv paths
# there are 5 rows for out_c90_dr10_label.tif
# lsa mean raw: 36.447149083863486
# lsa mean label spacings corrected: 0.3043392226964692
# detected scale: [[0.95946618 0.95946618 0.96741489]], detected translation: [[0.43170703 0.27489677 0.04746898]]
# detected scale: [[0.95946618 0.95946618 0.96741489]], detected translation: [[0.43170703 0.27489677 0.04746898]]
# lsa mse raw: 36.447149083863486
# lsa mse transformed: 0.3043392226964692
# jac: 0
# =======================================================
# Processing responseid: R_tY87q7yGKRqww5X
# data name fish1
# celegans_dyn-90_ceff-0_label.ics.ome.tiff
# there are 1484 rows for fish1 in responseid R_tY87q7yGKRqww5X
# there are 1 unique test csv paths
# there are 1501 rows for celegans_dyn-90_ceff-0_label.ics.ome.tiff
# lsa mean raw: 1.8017635461310866
# lsa mean label spacings corrected: 0.03447467627550727
# jac is 0.8567621585609594, tp: 1286, fp: 198, fn: 17
# detected scale: [[1.00232008 1.00232008 0.99999264]], detected translation: [[-0.15750734 -0.15681444 -0.12435327]]
# detected scale: [[1.00232008 1.00232008 0.99999264]], detected translation: [[-0.15750734 -0.15681444 -0.12435327]]
# jac transformed is 0.988674217188541, tp: 1484, fp: 0, fn: 17
# lsa mse raw: 1.8017635461310866
# lsa mse transformed: 0.03447467627550727
# jac: 0.8567621585609594
# =======================================================
# Processing responseid: R_tY87q7yGKRqww5X
# data name fish2
# celegans_dyn-90_ceff-90_label.ics.ome.tiff
# there are 1479 rows for fish2 in responseid R_tY87q7yGKRqww5X
# there are 1 unique test csv paths
# there are 1501 rows for celegans_dyn-90_ceff-90_label.ics.ome.tiff
# lsa mean raw: 2.5429496156924127
# lsa mean label spacings corrected: 0.02977266165488898
# jac is 0.8907395069953364, tp: 1337, fp: 142, fn: 22
# detected scale: [[1.00230789 1.00230789 0.99989356]], detected translation: [[-0.1542566  -0.15462541 -0.12303329]]
# detected scale: [[1.00230789 1.00230789 0.99989356]], detected translation: [[-0.1542566  -0.15462541 -0.12303329]]
# jac transformed is 0.9853431045969354, tp: 1479, fp: 0, fn: 22
# lsa mse raw: 2.5429496156924127
# lsa mse transformed: 0.02977266165488898
# jac: 0.8907395069953364
# =======================================================
# Processing responseid: R_tY87q7yGKRqww5X
# data name fish3
# celegans_dyn-10_ceff-0_label.ics.ome.tiff
# there are 1473 rows for fish3 in responseid R_tY87q7yGKRqww5X
# there are 1 unique test csv paths
# there are 1501 rows for celegans_dyn-10_ceff-0_label.ics.ome.tiff
# lsa mean raw: 8.616918906163205
# lsa mean label spacings corrected: 6.293077684624947
# jac is 0.832111925383078, tp: 1249, fp: 224, fn: 28
# detected scale: [[0.98360831 0.98360831 0.99064424]], detected translation: [[ 0.57272028  0.81705496 -0.06557945]]
# detected scale: [[0.98360831 0.98360831 0.99064424]], detected translation: [[ 0.57272028  0.81705496 -0.06557945]]
# jac transformed is 0.28980679546968685, tp: 435, fp: 1038, fn: 28
# lsa mse raw: 8.616918906163205
# lsa mse transformed: 6.293077684624947
# jac: 0.832111925383078
# =======================================================
# Processing responseid: R_tY87q7yGKRqww5X
# data name fish4
# celegans_dyn-10_ceff-90_label.ics.ome.tiff
# there are 1474 rows for fish4 in responseid R_tY87q7yGKRqww5X
# there are 1 unique test csv paths
# there are 1501 rows for celegans_dyn-10_ceff-90_label.ics.ome.tiff
# lsa mean raw: 13.021292803924982
# lsa mean label spacings corrected: 10.374838333589455
# jac is 0.760159893404397, tp: 1141, fp: 333, fn: 27
# detected scale: [[0.9567601 0.9567601 0.993317 ]], detected translation: [[ 0.70692028  1.67836907 -0.08588045]]
# detected scale: [[0.9567601 0.9567601 0.993317 ]], detected translation: [[ 0.70692028  1.67836907 -0.08588045]]
# jac transformed is 0.05729513657561625, tp: 86, fp: 1388, fn: 27
# lsa mse raw: 13.021292803924982
# lsa mse transformed: 10.374838333589455
# jac: 0.760159893404397
# =======================================================
# Processing responseid: R_3j9w1bGwWGd8yOC
# data name nuclei2
# out_c90_dr90_label.tif
# there are 5 rows for nuclei2 in responseid R_3j9w1bGwWGd8yOC
# there are 1 unique test csv paths
# there are 5 rows for out_c90_dr90_label.tif
# lsa mean raw: 24.896320096207226
# lsa mean label spacings corrected: 0.4084882119169406
# detected scale: [[1.06100688 1.06100688 1.15654548]], detected translation: [[-0.76243291 -0.85398819 -1.24681   ]]
# detected scale: [[1.06100688 1.06100688 1.15654548]], detected translation: [[-0.76243291 -0.85398819 -1.24681   ]]
# lsa mse raw: 24.896320096207226
# lsa mse transformed: 0.4084882119169406
# jac: 0
# =======================================================
# Processing responseid: R_3j9w1bGwWGd8yOC
# data name nuclei3
# out_c00_dr10_label.tif
# there are 5 rows for nuclei3 in responseid R_3j9w1bGwWGd8yOC
# there are 1 unique test csv paths
# there are 5 rows for out_c00_dr10_label.tif
# lsa mean raw: 29.475502452178443
# lsa mean label spacings corrected: 0.21140572140384858
# detected scale: [[1.01157844 1.01157844 1.04633013]], detected translation: [[-0.39852154 -0.44720305 -0.48017943]]
# detected scale: [[1.01157844 1.01157844 1.04633013]], detected translation: [[-0.39852154 -0.44720305 -0.48017943]]
# lsa mse raw: 29.475502452178443
# lsa mse transformed: 0.21140572140384858
# jac: 0
# =======================================================
# Processing responseid: R_3j9w1bGwWGd8yOC
# data name fish1
# celegans_dyn-90_ceff-0_label.ics.ome.tiff
# there are 1477 rows for fish1 in responseid R_3j9w1bGwWGd8yOC
# there are 1 unique test csv paths
# there are 1501 rows for celegans_dyn-90_ceff-0_label.ics.ome.tiff
# lsa mean raw: 1.7562245049991818
# lsa mean label spacings corrected: 0.03307765312875273
# jac is 0.882744836775483, tp: 1325, fp: 152, fn: 24
# detected scale: [[1.00234712 1.00234712 1.00043303]], detected translation: [[-0.16035282 -0.15153329 -0.12322846]]
# detected scale: [[1.00234712 1.00234712 1.00043303]], detected translation: [[-0.16035282 -0.15153329 -0.12322846]]
# jac transformed is 0.9840106595602931, tp: 1477, fp: 0, fn: 24
# lsa mse raw: 1.7562245049991818
# lsa mse transformed: 0.03307765312875273
# jac: 0.882744836775483
# =======================================================
# Processing responseid: R_3j9w1bGwWGd8yOC
# data name fish2
# celegans_dyn-90_ceff-90_label.ics.ome.tiff
# there are 1446 rows for fish2 in responseid R_3j9w1bGwWGd8yOC
# there are 1 unique test csv paths
# there are 1501 rows for celegans_dyn-90_ceff-90_label.ics.ome.tiff
# lsa mean raw: 2.4193619024103783
# lsa mean label spacings corrected: 0.028921012265781337
# jac is 0.8760826115922719, tp: 1315, fp: 131, fn: 55
# detected scale: [[1.00238583 1.00238583 1.00071181]], detected translation: [[-0.1581893  -0.15354755 -0.12534819]]
# detected scale: [[1.00238583 1.00238583 1.00071181]], detected translation: [[-0.1581893  -0.15354755 -0.12534819]]
# jac transformed is 0.9626915389740173, tp: 1445, fp: 1, fn: 55
# lsa mse raw: 2.4193619024103783
# lsa mse transformed: 0.028921012265781337
# jac: 0.8760826115922719
# =======================================================
# Processing responseid: R_3j9w1bGwWGd8yOC
# data name fish3
# celegans_dyn-10_ceff-0_label.ics.ome.tiff
# there are 1469 rows for fish3 in responseid R_3j9w1bGwWGd8yOC
# there are 1 unique test csv paths
# there are 1501 rows for celegans_dyn-10_ceff-0_label.ics.ome.tiff
# lsa mean raw: 2.9032684142289393
# lsa mean label spacings corrected: 0.027375703085164595
# jac is 0.90473017988008, tp: 1358, fp: 111, fn: 32
# detected scale: [[1.00232135 1.00232135 1.00045689]], detected translation: [[-0.15583474 -0.14803134 -0.12307276]]
# detected scale: [[1.00232135 1.00232135 1.00045689]], detected translation: [[-0.15583474 -0.14803134 -0.12307276]]
# jac transformed is 0.9786808794137242, tp: 1469, fp: 0, fn: 32
# lsa mse raw: 2.9032684142289393
# lsa mse transformed: 0.027375703085164595
# jac: 0.90473017988008
# =======================================================
# Processing responseid: R_3j9w1bGwWGd8yOC
# data name fish4
# celegans_dyn-10_ceff-90_label.ics.ome.tiff
# there are 1469 rows for fish4 in responseid R_3j9w1bGwWGd8yOC
# there are 1 unique test csv paths
# there are 1501 rows for celegans_dyn-10_ceff-90_label.ics.ome.tiff
# lsa mean raw: 3.022740756363878
# lsa mean label spacings corrected: 0.26054057046022233
# jac is 0.8081279147235176, tp: 1213, fp: 256, fn: 32
# detected scale: [[1.00286445 1.00286445 1.00203313]], detected translation: [[-0.16635975 -0.16690598 -0.13907236]]
# detected scale: [[1.00286445 1.00286445 1.00203313]], detected translation: [[-0.16635975 -0.16690598 -0.13907236]]
# jac transformed is 0.9593604263824117, tp: 1440, fp: 29, fn: 32
# lsa mse raw: 3.022740756363878
# lsa mse transformed: 0.26054057046022233
# jac: 0.8081279147235176
# =======================================================
# Processing responseid: R_24Nwgngl83ucQ8B
# data name nuclei1
# out_c00_dr90_label.tif
# there are 5 rows for nuclei1 in responseid R_24Nwgngl83ucQ8B
# there are 1 unique test csv paths
# there are 5 rows for out_c00_dr90_label.tif
# lsa mean raw: 28.45692123629893
# lsa mean label spacings corrected: 0.02894243539006558
# detected scale: [[0.99806546 0.99806546 0.97681925]], detected translation: [[-0.00648809  0.01456482  0.11372437]]
# detected scale: [[0.99806546 0.99806546 0.97681925]], detected translation: [[-0.00648809  0.01456482  0.11372437]]
# lsa mse raw: 28.45692123629893
# lsa mse transformed: 0.02894243539006558
# jac: 0
# =======================================================
# Processing responseid: R_24Nwgngl83ucQ8B
# data name nuclei4
# out_c90_dr10_label.tif
# there are 7 rows for nuclei4 in responseid R_24Nwgngl83ucQ8B
# there are 1 unique test csv paths
# there are 5 rows for out_c90_dr10_label.tif
# lsa mean raw: nan
# lsa mean label spacings corrected: nan
# detected scale: [[nan nan nan]], detected translation: [[nan nan nan]]
# detected scale: [[nan nan nan]], detected translation: [[nan nan nan]]
# lsa mse raw: nan
# lsa mse transformed: nan
# jac: 0
# =======================================================
# Processing responseid: R_24Nwgngl83ucQ8B
# c:\Users\bnort\miniconda3\envs\stardist_napari_windows\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\bnort\miniconda3\envs\stardist_napari_windows\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\bnort\miniconda3\envs\stardist_napari_windows\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\bnort\miniconda3\envs\stardist_napari_windows\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\bnort\miniconda3\envs\stardist_napari_windows\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\bnort\miniconda3\envs\stardist_napari_windows\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# ...
# detected scale: [[1.02174279 1.02174279 0.90055987]], detected translation: [[-0.40353242 -0.52852296  0.83833237]]
# detected scale: [[1.02174279 1.02174279 0.90055987]], detected translation: [[-0.40353242 -0.52852296  0.83833237]]
# lsa mse raw: 28.833259174778323
# lsa mse transformed: 0.2432950808871975
# jac: 0
# =======================================================
# Processing responseid: R_3kaX79RV1ul5JuI
# data name nuclei4
# out_c90_dr10_label.tif
# there are 5 rows for nuclei4 in responseid R_3kaX79RV1ul5JuI
# there are 1 unique test csv paths
# there are 5 rows for out_c90_dr10_label.tif
# lsa mean raw: 40.11310989010816
# lsa mean label spacings corrected: 0.16809977382169566
# detected scale: [[1.06740675 1.06740675 0.99044043]], detected translation: [[-0.82247699 -0.92972693  0.10523721]]
# detected scale: [[1.06740675 1.06740675 0.99044043]], detected translation: [[-0.82247699 -0.92972693  0.10523721]]
# lsa mse raw: 40.11310989010816
# lsa mse transformed: 0.16809977382169566
# jac: 0
# =======================================================
# Processing responseid: R_2DNRFrAvCDUX1EL
# data name nuclei1
# out_c00_dr90_label.tif
# there are 5 rows for nuclei1 in responseid R_2DNRFrAvCDUX1EL
# there are 1 unique test csv paths
# there are 5 rows for out_c00_dr90_label.tif
# lsa mean raw: 28.245680029204124
# lsa mean label spacings corrected: 0.032290879958573646
# detected scale: [[1.00210182 1.00210182 0.9955271 ]], detected translation: [[ 0.01324695 -0.01868588 -0.0872101 ]]
# detected scale: [[1.00210182 1.00210182 0.9955271 ]], detected translation: [[ 0.01324695 -0.01868588 -0.0872101 ]]
# lsa mse raw: 28.245680029204124
# lsa mse transformed: 0.032290879958573646
# jac: 0
# =======================================================
# Processing responseid: R_2DNRFrAvCDUX1EL
# data name nuclei2
# out_c90_dr90_label.tif
# there are 5 rows for nuclei2 in responseid R_2DNRFrAvCDUX1EL
# there are 1 unique test csv paths
# there are 5 rows for out_c90_dr90_label.tif
# lsa mean raw: 22.571505643922187
# lsa mean label spacings corrected: 0.0587797424378181
# detected scale: [[1.00956537 1.00956537 1.00750973]], detected translation: [[-0.08581928 -0.07651205 -0.22075108]]
# detected scale: [[1.00956537 1.00956537 1.00750973]], detected translation: [[-0.08581928 -0.07651205 -0.22075108]]
# lsa mse raw: 22.571505643922187
# lsa mse transformed: 0.0587797424378181
# jac: 0
# =======================================================
# Processing responseid: R_2DNRFrAvCDUX1EL
# data name nuclei3
# out_c00_dr10_label.tif
# there are 5 rows for nuclei3 in responseid R_2DNRFrAvCDUX1EL
# there are 1 unique test csv paths
# there are 5 rows for out_c00_dr10_label.tif
# lsa mean raw: 27.30256066762744
# lsa mean label spacings corrected: 0.12689490441065357
# detected scale: [[0.99578599 0.99578599 0.98929373]], detected translation: [[-0.066097   -0.13239932 -0.13958432]]
# detected scale: [[0.99578599 0.99578599 0.98929373]], detected translation: [[-0.066097   -0.13239932 -0.13958432]]
# lsa mse raw: 27.30256066762744
# lsa mse transformed: 0.12689490441065357
# jac: 0
# =======================================================
# Processing responseid: R_2DNRFrAvCDUX1EL
# data name nuclei4
# out_c90_dr10_label.tif
# there are 5 rows for nuclei4 in responseid R_2DNRFrAvCDUX1EL
# there are 1 unique test csv paths
# there are 5 rows for out_c90_dr10_label.tif
# lsa mean raw: 37.13619683048773
# lsa mean label spacings corrected: 0.09505391754227573
# detected scale: [[0.99671053 0.99671053 1.00694372]], detected translation: [[ 0.09316057 -0.00923969 -0.32194812]]
# detected scale: [[0.99671053 0.99671053 1.00694372]], detected translation: [[ 0.09316057 -0.00923969 -0.32194812]]
# lsa mse raw: 37.13619683048773
# lsa mse transformed: 0.09505391754227573
# jac: 0
# =======================================================
# Processing responseid: R_2DNRFrAvCDUX1EL
# data name fish1
# celegans_dyn-90_ceff-0_label.ics.ome.tiff
# there are 1496 rows for fish1 in responseid R_2DNRFrAvCDUX1EL
# there are 1 unique test csv paths
# there are 1501 rows for celegans_dyn-90_ceff-0_label.ics.ome.tiff
# lsa mean raw: 41223520.81298292
# lsa mean label spacings corrected: 41242282.26540945
# jac is 0.10059960026648901, tp: 151, fp: 1345, fn: 5
# detected scale: [[1.00223836 1.00223836 0.99989394]], detected translation: [[-0.02764905 -0.0186233  -0.22149536]]
# detected scale: [[1.00223836 1.00223836 0.99989394]], detected translation: [[-0.02764905 -0.0186233  -0.22149536]]
# jac transformed is 0.9966688874083944, tp: 1496, fp: 0, fn: 5
# lsa mse raw: 41223520.81298292
# lsa mse transformed: 0.06125531453183149
# jac: 0.10059960026648901
# =======================================================
# Processing responseid: R_2DNRFrAvCDUX1EL
# data name fish2
# celegans_dyn-90_ceff-90_label.ics.ome.tiff
# there are 1490 rows for fish2 in responseid R_2DNRFrAvCDUX1EL
# there are 1 unique test csv paths
# there are 1501 rows for celegans_dyn-90_ceff-90_label.ics.ome.tiff
# lsa mean raw: 55122341.88421358
# lsa mean label spacings corrected: 55147755.99302673
# jac is 0.06928714190539641, tp: 104, fp: 1386, fn: 11
# detected scale: [[1.00216522 1.00216522 0.99917429]], detected translation: [[-0.02251095 -0.01297457 -0.21723824]]
# detected scale: [[1.00216522 1.00216522 0.99917429]], detected translation: [[-0.02251095 -0.01297457 -0.21723824]]
# jac transformed is 0.9926715522984677, tp: 1490, fp: 0, fn: 11
# lsa mse raw: 55122341.88421358
# lsa mse transformed: 0.06611164931854543
# jac: 0.06928714190539641
# =======================================================
# Processing responseid: R_2DNRFrAvCDUX1EL
# data name fish3
# celegans_dyn-10_ceff-0_label.ics.ome.tiff
# there are 1405 rows for fish3 in responseid R_2DNRFrAvCDUX1EL
# there are 1 unique test csv paths
# there are 1501 rows for celegans_dyn-10_ceff-0_label.ics.ome.tiff
# lsa mean raw: 3.0887829264064868
# lsa mean label spacings corrected: 0.9350187231304417
# jac is 0.07661558960692871, tp: 115, fp: 1290, fn: 96
# detected scale: [[0.99984105 0.99984105 0.99385924]], detected translation: [[ 0.06638009  0.10716539 -0.17820325]]
# detected scale: [[0.99984105 0.99984105 0.99385924]], detected translation: [[ 0.06638009  0.10716539 -0.17820325]]
# jac transformed is 0.9293804130579614, tp: 1395, fp: 10, fn: 96
# lsa mse raw: 3.0887829264064868
# lsa mse transformed: 0.9350187231304417
# jac: 0.07661558960692871
# =======================================================
# Processing responseid: R_2DNRFrAvCDUX1EL
# data name fish4
# celegans_dyn-10_ceff-90_label.ics.ome.tiff
# there are 1456 rows for fish4 in responseid R_2DNRFrAvCDUX1EL
# there are 1 unique test csv paths
# there are 1501 rows for celegans_dyn-10_ceff-90_label.ics.ome.tiff
# lsa mean raw: 62973760.45190067
# lsa mean label spacings corrected: 63001034.646588534
# jac is 0.12858094603597603, tp: 193, fp: 1263, fn: 45
# detected scale: [[0.99546117 0.99546117 0.99495708]], detected translation: [[ 0.10906713  0.24502388 -0.1883505 ]]
# detected scale: [[0.99546117 0.99546117 0.99495708]], detected translation: [[ 0.10906713  0.24502388 -0.1883505 ]]
# jac transformed is 0.8514323784143905, tp: 1278, fp: 178, fn: 45
# lsa mse raw: 62973760.45190067
# lsa mse transformed: 1.3052555936138706
# jac: 0.12858094603597603
# =======================================================
# Processing responseid: R_eRvCx60GZHVIflf
# data name nuclei1
# out_c00_dr90_label.tif
# there are 5 rows for nuclei1 in responseid R_eRvCx60GZHVIflf
# there are 1 unique test csv paths
# there are 5 rows for out_c00_dr90_label.tif
# lsa mean raw: 29.999302429300094
# lsa mean label spacings corrected: 0.02394466740762676
# detected scale: [[0.99621426 0.99621426 1.00115087]], detected translation: [[0.02922007 0.00986417 0.03288412]]
# detected scale: [[0.99621426 0.99621426 1.00115087]], detected translation: [[0.02922007 0.00986417 0.03288412]]
# lsa mse raw: 29.999302429300094
# lsa mse transformed: 0.02394466740762676
# jac: 0
# =======================================================
# Processing responseid: R_eRvCx60GZHVIflf
# data name nuclei2
# out_c90_dr90_label.tif
# there are 5 rows for nuclei2 in responseid R_eRvCx60GZHVIflf
# there are 1 unique test csv paths
# there are 5 rows for out_c90_dr90_label.tif
# lsa mean raw: 25.75731854143688
# lsa mean label spacings corrected: 0.3802284337339926
# detected scale: [[1.03196342 1.03196342 1.12738924]], detected translation: [[-0.41676627 -0.38847947 -0.89780543]]
# detected scale: [[1.03196342 1.03196342 1.12738924]], detected translation: [[-0.41676627 -0.38847947 -0.89780543]]
# lsa mse raw: 25.75731854143688
# lsa mse transformed: 0.3802284337339926
# jac: 0
# =======================================================
# Processing responseid: R_eRvCx60GZHVIflf
# data name nuclei3
# out_c00_dr10_label.tif
# there are 5 rows for nuclei3 in responseid R_eRvCx60GZHVIflf
# there are 1 unique test csv paths
# there are 5 rows for out_c00_dr10_label.tif
# lsa mean raw: 30.053898153153362
# lsa mean label spacings corrected: 0.16313590523212346
# detected scale: [[0.97511063 0.97511063 1.01460535]], detected translation: [[ 0.21438623  0.1752525  -0.11710823]]
# detected scale: [[0.97511063 0.97511063 1.01460535]], detected translation: [[ 0.21438623  0.1752525  -0.11710823]]
# lsa mse raw: 30.053898153153362
# lsa mse transformed: 0.16313590523212346
# jac: 0
# =======================================================
# Processing responseid: R_eRvCx60GZHVIflf
# data name nuclei4
# out_c90_dr10_label.tif
# there are 5 rows for nuclei4 in responseid R_eRvCx60GZHVIflf
# there are 1 unique test csv paths
# there are 5 rows for out_c90_dr10_label.tif
# lsa mean raw: 39.69713905758366
# lsa mean label spacings corrected: 0.1948663015331301
# detected scale: [[0.98782299 0.98782299 1.08270277]], detected translation: [[ 0.10833968  0.04393478 -0.94822577]]
# detected scale: [[0.98782299 0.98782299 1.08270277]], detected translation: [[ 0.10833968  0.04393478 -0.94822577]]
# lsa mse raw: 39.69713905758366
# lsa mse transformed: 0.1948663015331301
# jac: 0
# =======================================================
# Processing responseid: R_1GUZ4XruXifzoPp
# data name nuclei1
# out_c00_dr90_label.tif
# there are 5 rows for nuclei1 in responseid R_1GUZ4XruXifzoPp
# there are 1 unique test csv paths
# there are 5 rows for out_c00_dr90_label.tif
# lsa mean raw: 29.941089543081524
# lsa mean label spacings corrected: 0.03385623344533705
# detected scale: [[1.00434733 1.00434733 0.99661248]], detected translation: [[-0.0584174   0.01854928  0.0685716 ]]
# detected scale: [[1.00434733 1.00434733 0.99661248]], detected translation: [[-0.0584174   0.01854928  0.0685716 ]]
# lsa mse raw: 29.941089543081524
# lsa mse transformed: 0.03385623344533705
# jac: 0
# =======================================================
# Processing responseid: R_1GUZ4XruXifzoPp
# data name nuclei2
# out_c90_dr90_label.tif
# there are 5 rows for nuclei2 in responseid R_1GUZ4XruXifzoPp
# there are 1 unique test csv paths
# there are 5 rows for out_c90_dr90_label.tif
# lsa mean raw: 23.680324749144525
# lsa mean label spacings corrected: 0.07995289471326407
# detected scale: [[1.00322797 1.00322797 1.00038792]], detected translation: [[-0.05104599 -0.00381407 -0.04423691]]
# detected scale: [[1.00322797 1.00322797 1.00038792]], detected translation: [[-0.05104599 -0.00381407 -0.04423691]]
# lsa mse raw: 23.680324749144525
# lsa mse transformed: 0.07995289471326407
# jac: 0
# =======================================================
# Processing responseid: R_1GUZ4XruXifzoPp
# data name nuclei3
# out_c00_dr10_label.tif
# there are 5 rows for nuclei3 in responseid R_1GUZ4XruXifzoPp
# there are 1 unique test csv paths
# there are 5 rows for out_c00_dr10_label.tif
# lsa mean raw: 29.277649650446012
# lsa mean label spacings corrected: 0.14435608909882977
# detected scale: [[1.01349325 1.01349325 1.0140922 ]], detected translation: [[-0.28567895 -0.44938326 -0.18730261]]
# detected scale: [[1.01349325 1.01349325 1.0140922 ]], detected translation: [[-0.28567895 -0.44938326 -0.18730261]]
# lsa mse raw: 29.277649650446012
# lsa mse transformed: 0.14435608909882977
# jac: 0
# =======================================================
# Processing responseid: R_1GUZ4XruXifzoPp
# data name nuclei4
# out_c90_dr10_label.tif
# there are 5 rows for nuclei4 in responseid R_1GUZ4XruXifzoPp
# there are 1 unique test csv paths
# there are 5 rows for out_c90_dr10_label.tif
# lsa mean raw: 42.16964236073757
# lsa mean label spacings corrected: 0.43502555809827337
# detected scale: [[1.07481199 1.07481199 1.10030069]], detected translation: [[-0.99775774 -1.05330566 -0.93418415]]
# detected scale: [[1.07481199 1.07481199 1.10030069]], detected translation: [[-0.99775774 -1.05330566 -0.93418415]]
# lsa mse raw: 42.16964236073757
# lsa mse transformed: 0.43502555809827337
# jac: 0
# =======================================================
# Processing responseid: R_1GUZ4XruXifzoPp
# data name fish1
# celegans_dyn-90_ceff-0_label.ics.ome.tiff
# there are 1376 rows for fish1 in responseid R_1GUZ4XruXifzoPp
# there are 1 unique test csv paths
# there are 1501 rows for celegans_dyn-90_ceff-0_label.ics.ome.tiff
# lsa mean raw: 1.3634200906593352
# lsa mean label spacings corrected: 0.03651225930232543
# jac is 0.6888740839440373, tp: 1034, fp: 342, fn: 125
# detected scale: [[1.00228273 1.00228273 1.00052354]], detected translation: [[-0.15891363 -0.14808511 -0.12555119]]
# detected scale: [[1.00228273 1.00228273 1.00052354]], detected translation: [[-0.15891363 -0.14808511 -0.12555119]]
# jac transformed is 0.9133910726182545, tp: 1371, fp: 5, fn: 125
# lsa mse raw: 1.3634200906593352
# lsa mse transformed: 0.03651225930232543
# jac: 0.6888740839440373
# =======================================================
# Processing responseid: R_1GUZ4XruXifzoPp
# data name fish2
# celegans_dyn-90_ceff-90_label.ics.ome.tiff
# there are 1440 rows for fish2 in responseid R_1GUZ4XruXifzoPp
# there are 1 unique test csv paths
# there are 1501 rows for celegans_dyn-90_ceff-90_label.ics.ome.tiff
# lsa mean raw: 2.432072390684229
# lsa mean label spacings corrected: 0.033145383349333195
# jac is 0.7681545636242505, tp: 1153, fp: 287, fn: 61
# detected scale: [[1.00235859 1.00235859 1.00034013]], detected translation: [[-0.15982729 -0.15032884 -0.12365723]]
# detected scale: [[1.00235859 1.00235859 1.00034013]], detected translation: [[-0.15982729 -0.15032884 -0.12365723]]
# jac transformed is 0.9593604263824117, tp: 1440, fp: 0, fn: 61
# lsa mse raw: 2.432072390684229
# lsa mse transformed: 0.033145383349333195
# jac: 0.7681545636242505
# =======================================================
# Processing responseid: R_1GUZ4XruXifzoPp
# data name fish3
# celegans_dyn-10_ceff-0_label.ics.ome.tiff
# there are 1350 rows for fish3 in responseid R_1GUZ4XruXifzoPp
# there are 1 unique test csv paths
# there are 1501 rows for celegans_dyn-10_ceff-0_label.ics.ome.tiff
# lsa mean raw: 2.4036768187056863
# lsa mean label spacings corrected: 0.03275189257050061
# jac is 0.692871419053964, tp: 1040, fp: 310, fn: 151
# detected scale: [[1.00242694 1.00242694 0.99975977]], detected translation: [[-0.164311   -0.15148978 -0.12101378]]
# detected scale: [[1.00242694 1.00242694 0.99975977]], detected translation: [[-0.164311   -0.15148978 -0.12101378]]
# jac transformed is 0.899400399733511, tp: 1350, fp: 0, fn: 151
# lsa mse raw: 2.4036768187056863
# lsa mse transformed: 0.03275189257050061
# jac: 0.692871419053964
# =======================================================
# Processing responseid: R_1GUZ4XruXifzoPp
# data name fish4
# celegans_dyn-10_ceff-90_label.ics.ome.tiff
# there are 1155 rows for fish4 in responseid R_1GUZ4XruXifzoPp
# there are 1 unique test csv paths
# there are 1501 rows for celegans_dyn-10_ceff-90_label.ics.ome.tiff
# lsa mean raw: 1.979916961753877
# lsa mean label spacings corrected: 0.040107091181825004
# jac is 0.5502998001332445, tp: 826, fp: 329, fn: 346
# detected scale: [[1.00253988 1.00253988 1.00038332]], detected translation: [[-0.16416278 -0.16086831 -0.1225568 ]]
# detected scale: [[1.00253988 1.00253988 1.00038332]], detected translation: [[-0.16416278 -0.16086831 -0.1225568 ]]
# jac transformed is 0.7634910059960026, tp: 1146, fp: 9, fn: 346
# lsa mse raw: 1.979916961753877
# lsa mse transformed: 0.040107091181825004
# jac: 0.5502998001332445
# =======================================================

# %%
combined_data.to_csv(r'combined_data_deidentified_alt.csv', index=False)
combined_data.head()
# Out:
#           responseid    qx.2  setName  lsa_mse_raw  lsa_mse_transformed  \
# 0  R_31bjqd6Mm8wBxN5  Python  nuclei1   182.451824             0.011611
# 1  R_31bjqd6Mm8wBxN5  Python  nuclei2    47.222279             0.013830
# 2  R_31bjqd6Mm8wBxN5  Python  nuclei3   105.577865             0.007744
# 3  R_31bjqd6Mm8wBxN5  Python  nuclei4    88.287150             0.008986
# 4  R_3lAJ9xY4kGlL99f  Python  nuclei1   565.205858             0.014374
#
#    lsa_mse_label_corrected  lsa_mse_label_and_image_corrected  lsa_mse_best  \
# 0               105.701395                           0.019770      0.011611
# 1                22.693942                           0.019032      0.013830
# 2                72.880209                           0.066909      0.007744
# 3                44.821824                           0.020630      0.008986
# 4               457.890494                           0.070754      0.014374
#
#           correction  jac  jac_transformed  jac_best  best
# 0         REVERSE_XY  0.0              0.0       0.0   0.0
# 1         REVERSE_XY  0.0              0.0       0.0   0.0
# 2         REVERSE_XY  0.0              0.0       0.0   0.0
# 3         REVERSE_XY  0.0              0.0       0.0   0.0
# 4  REVERSE_XY_SCALE4  0.0              0.0       0.0   0.0

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.__config__ import show

# %%
plt.figure(figsize=(17, 10))

statistic = 'lsa_mse_label_corrected'
statistic = 'lsa_mse_best'
df4= combined_data[combined_data.setName.str.contains('nuclei', na=False)]
df4['qx.2'] = df4["qx.2"].str.replace(' ', '\n')
df4['qx.2'] = df4["qx.2"].str.replace(',', '\n')
ordered_methods = sorted(df4['qx.2'].unique())
sns.boxplot(x='qx.2', y=statistic, data=df4.dropna(),showfliers=False, order=ordered_methods)
sns.stripplot(x='qx.2', y=statistic, data=df4.dropna(), jitter=0.25, alpha=0.7)
plt.yscale('log')
plt.title('Box Plot of Score by Method')
plt.show()
# Out:
# C:\Users\bnort\AppData\Local\Temp\ipykernel_4888\14511212.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df4['qx.2'] = df4["qx.2"].str.replace(' ', '\n')
# C:\Users\bnort\AppData\Local\Temp\ipykernel_4888\14511212.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df4['qx.2'] = df4["qx.2"].str.replace(',', '\n')

# %%
# Fish only
dffish = combined_data[combined_data['setName'].str.contains('fish', na=False)]
dffish = dffish[dffish['jac'] > 0]  # Filter out rows with jac <= 0

import matplotlib.pyplot as plt
def plot_softwares_jac(df, col_name, title):
    plt.figure(figsize=(17, 10))
    df['tool'] = df["qx.2"].str.replace(' ', '\n')
    ordered_methods = sorted(df['tool'].unique())
    sns.boxplot(x='tool', y=col_name, data=df, showfliers=False, order=ordered_methods)
    sns.stripplot(x='tool', y=col_name, data=df, jitter=0.25, alpha=0.7)
    plt.ylim(0, 1)   
    plt.title(title)
    plt.savefig(os.path.join(r'D:\images\tnia-python-images\imagesc\2025_06_02_check_ABRF_labels', title), dpi=300)
    plt.show()
    
plot_softwares_jac(dffish, 'jac_best', 'Jaccard Index by Software')
