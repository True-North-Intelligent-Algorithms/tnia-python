# %%
# Get image
from skimage.io import imread
test_image_path = r"D:\images\tnia-python-images\imagesc\2024_08-19_Dapi_CJ\Channel0_SL01.png"
test_img = imread(test_image_path)

# Make model
from stardist.models import StarDist2D
model = StarDist2D.from_pretrained('2D_versatile_fluo')


# Make predictions (labels)
from stardist.plot import render_label
from csbdeep.utils import normalize
import matplotlib.pyplot as plt

prob_thresh = None
nms_thresh = None

labels, _ = model.predict_instances(normalize(test_img), scale = 3, 
                                    prob_thresh=prob_thresh, 
                                    nms_thresh=nms_thresh)

# Plot
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.imshow(test_img)
plt.axis("off")
plt.title("input image")

plt.subplot(1,2,2)
plt.imshow(render_label(labels, img=test_img, cmap=(0,255,0), alpha=0.5))
plt.axis("off")
plt.title("prediction + input overlay")
# Out:
# Found model '2D_versatile_fluo' for 'StarDist2D'.
# Loading network weights from 'weights_best.h5'.
# Loading thresholds from 'thresholds.json'.
# Using default values: prob_thresh=0.479071, nms_thresh=0.3.
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# Cell In[4], line 19
#      16 prob_thresh = None
#      17 nms_thresh = None
# ---> 19 labels, _ = model.predict_instances(normalize(test_img), scale = 3,
#      20                                     prob_thresh=prob_thresh,
#      21                                     nms_thresh=nms_thresh)
#      23 # Plot
#      24 plt.figure(figsize=(12,5))
#
# File c:\Users\bnort\miniconda3\envs\segment_bees_311\lib\site-packages\stardist\models\base.py:777, in StarDistBase.predict_instances(self, *args, **kwargs)
#     764 @functools.wraps(_predict_instances_generator)
#     765 def predict_instances(self, *args, **kwargs):
#     766     # the reason why the actual computation happens as a generator function
#    (...)
#     774
#     775     # return last "yield"ed value of generator
#     776     r = None
# --> 777     for r in self._predict_instances_generator(*args, **kwargs):
#     778         pass
#     779     return r
#
# File c:\Users\bnort\miniconda3\envs\segment_bees_311\lib\site-packages\stardist\models\base.py:729, in StarDistBase._predict_instances_generator(self, img, axes, normalizer, sparse, prob_thresh, nms_thresh, scale, n_tiles, show_tile_progress, verbose, return_labels, predict_kwargs, nms_kwargs, overlap_label, return_predict)
#     727 res = None
#     728 if sparse:
# --> 729     for res in self._predict_sparse_generator(img, axes=axes, normalizer=normalizer, n_tiles=n_tiles,
#     730                                               prob_thresh=prob_thresh, show_tile_progress=show_tile_progress, **predict_kwargs):
#     731         if res is None:
#     732             yield 'tile'  # yield 'tile' each time a tile has been processed
#
# File c:\Users\bnort\miniconda3\envs\segment_bees_311\lib\site-packages\stardist\models\base.py:592, in StarDistBase._predict_sparse_generator(self, img, prob_thresh, axes, normalizer, n_tiles, show_tile_progress, b, **predict_kwargs)
#     588         yield  # yield None after each processed tile
#     590 else:
#     591     # predict_direct -> prob, dist, [prob_class if multi_class]
# --> 592     results = predict_direct(x)
#     593     prob, dist = results[:2]
#     594     prob, dist = _prep(prob, dist)
#
# File c:\Users\bnort\miniconda3\envs\segment_bees_311\lib\site-packages\stardist\models\base.py:398, in StarDistBase._predict_setup.<locals>.predict_direct(x)
#     397 def predict_direct(x):
# --> 398     ys = self.keras_model.predict(x[np.newaxis], **predict_kwargs)
#     399     return tuple(y[0] for y in ys)
#
# File c:\Users\bnort\miniconda3\envs\segment_bees_311\lib\site-packages\keras\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File c:\Users\bnort\miniconda3\envs\segment_bees_311\lib\site-packages\tensorflow\python\eager\execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52 try:
#      53   ctx.ensure_initialized()
# ---> 54   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                       inputs, attrs, num_outputs)
#      56 except core._NotOkStatusException as e:
#      57   if name is not None:
#
# ResourceExhaustedError: Graph execution error:
#
# Detected at node 'model_3/conv2d_6/Relu' defined at (most recent call last):
#     File "c:\Users\bnort\miniconda3\envs\segment_bees_311\lib\runpy.py", line 197, in _run_module_as_main
#       return _run_code(code, main_globals, None,
#     File "c:\Users\bnort\miniconda3\envs\segment_bees_311\lib\runpy.py", line 87, in _run_code
#       exec(code, run_globals)
#     File "c:\Users\bnort\miniconda3\envs\segment_bees_311\lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#       app.launch_new_instance()
#     File "c:\Users\bnort\miniconda3\envs\segment_bees_311\lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#       app.start()
#     File "c:\Users\bnort\miniconda3\envs\segment_bees_311\lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#       self.io_loop.start()
#     File "c:\Users\bnort\miniconda3\envs\segment_bees_311\lib\site-packages\tornado\platform\asyncio.py", line 205, in start
#       self.asyncio_loop.run_forever()
#     File "c:\Users\bnort\miniconda3\envs\segment_bees_311\lib\asyncio\base_events.py", line 601, in run_forever
#       self._run_once()
#     File "c:\Users\bnort\miniconda3\envs\segment_bees_311\lib\asyncio\base_events.py", line 1905, in _run_once
#       handle._run()
#     File "c:\Users\bnort\miniconda3\envs\segment_bees_311\lib\asyncio\events.py", line 80, in _run
#       self._context.run(self._callback, *self._args)
#     File "c:\Users\bnort\miniconda3\envs\segment_bees_311\lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#       await self.process_one()
#     File "c:\Users\bnort\miniconda3\envs\segment_bees_311\lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#       await dispatch(*args)
#     File "c:\Users\bnort\miniconda3\envs\segment_bees_311\lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#       await result
#     File "c:\Users\bnort\miniconda3\envs\segment_bees_311\lib\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
#       await super().execute_request(stream, ident, parent)
#     File "c:\Users\bnort\miniconda3\envs\segment_bees_311\lib\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
#       reply_content = await reply_content
#     File "c:\Users\bnort\miniconda3\envs\segment_bees_311\lib\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
#       res = shell.run_cell(
#     File "c:\Users\bnort\miniconda3\envs\segment_bees_311\lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#       return super().run_cell(*args, **kwargs)
#     File "c:\Users\bnort\miniconda3\envs\segment_bees_311\lib\site-packages\IPython\core\interactiveshell.py", line 3048, in run_cell
#       result = self._run_cell(
#     File "c:\Users\bnort\miniconda3\envs\segment_bees_311\lib\site-packages\IPython\core\interactiveshell.py", line 3103, in _run_cell
#       result = runner(coro)
#     File "c:\Users\bnort\miniconda3\envs\segment_bees_311\lib\site-packages\IPython\core\async_helpers.py", line 129, in _pseudo_sync_runner
#       coro.send(None)
#     File "c:\Users\bnort\miniconda3\envs\segment_bees_311\lib\site-packages\IPython\core\interactiveshell.py", line 3308, in run_cell_async
#       has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#     File "c:\Users\bnort\miniconda3\envs\segment_bees_311\lib\site-packages\IPython\core\interactiveshell.py", line 3490, in run_ast_nodes
#       if await self.run_code(code, result, async_=asy):
#     File "c:\Users\bnort\miniconda3\envs\segment_bees_311\lib\site-packages\IPython\core\interactiveshell.py", line 3550, in run_code
#       exec(code_obj, self.user_global_ns, self.user_ns)
#     File "C:\Users\bnort\AppData\Local\Temp\ipykernel_17692\1462505283.py", line 19, in <module>
#       labels, _ = model.predict_instances(normalize(test_img), scale = 3,
#     File "c:\Users\bnort\miniconda3\envs\segment_bees_311\lib\site-packages\stardist\models\base.py", line 777, in predict_instances
#       for r in self._predict_instances_generator(*args, **kwargs):
#     File "c:\Users\bnort\miniconda3\envs\segment_bees_311\lib\site-packages\stardist\models\base.py", line 729, in _predict_instances_generator
#       for res in self._predict_sparse_generator(img, axes=axes, normalizer=normalizer, n_tiles=n_tiles,
#     File "c:\Users\bnort\miniconda3\envs\segment_bees_311\lib\site-packages\stardist\models\base.py", line 592, in _predict_sparse_generator
#       results = predict_direct(x)
#     File "c:\Users\bnort\miniconda3\envs\segment_bees_311\lib\site-packages\stardist\models\base.py", line 398, in predict_direct
#       ys = self.keras_model.predict(x[np.newaxis], **predict_kwargs)
#     File "c:\Users\bnort\miniconda3\envs\segment_bees_311\lib\site-packages\keras\utils\traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "c:\Users\bnort\miniconda3\envs\segment_bees_311\lib\site-packages\keras\engine\training.py", line 2253, in predict
#       tmp_batch_outputs = self.predict_function(iterator)
#     File "c:\Users\bnort\miniconda3\envs\segment_bees_311\lib\site-packages\keras\engine\training.py", line 2041, in predict_function
#       return step_function(self, iterator)
#     File "c:\Users\bnort\miniconda3\envs\segment_bees_311\lib\site-packages\keras\engine\training.py", line 2027, in step_function
#       outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "c:\Users\bnort\miniconda3\envs\segment_bees_311\lib\site-packages\keras\engine\training.py", line 2015, in run_step
#       outputs = model.predict_step(data)
#     File "c:\Users\bnort\miniconda3\envs\segment_bees_311\lib\site-packages\keras\engine\training.py", line 1983, in predict_step
#       return self(x, training=False)
#     File "c:\Users\bnort\miniconda3\envs\segment_bees_311\lib\site-packages\keras\utils\traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "c:\Users\bnort\miniconda3\envs\segment_bees_311\lib\site-packages\keras\engine\training.py", line 557, in __call__
#       return super().__call__(*args, **kwargs)
#     File "c:\Users\bnort\miniconda3\envs\segment_bees_311\lib\site-packages\keras\utils\traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "c:\Users\bnort\miniconda3\envs\segment_bees_311\lib\site-packages\keras\engine\base_layer.py", line 1097, in __call__
#       outputs = call_fn(inputs, *args, **kwargs)
#     File "c:\Users\bnort\miniconda3\envs\segment_bees_311\lib\site-packages\keras\utils\traceback_utils.py", line 96, in error_handler
#       return fn(*args, **kwargs)
#     File "c:\Users\bnort\miniconda3\envs\segment_bees_311\lib\site-packages\keras\engine\functional.py", line 510, in call
#       return self._run_internal_graph(inputs, training=training, mask=mask)
#     File "c:\Users\bnort\miniconda3\envs\segment_bees_311\lib\site-packages\keras\engine\functional.py", line 667, in _run_internal_graph
#       outputs = node.layer(*args, **kwargs)
#     File "c:\Users\bnort\miniconda3\envs\segment_bees_311\lib\site-packages\keras\utils\traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "c:\Users\bnort\miniconda3\envs\segment_bees_311\lib\site-packages\keras\engine\base_layer.py", line 1097, in __call__
#       outputs = call_fn(inputs, *args, **kwargs)
#     File "c:\Users\bnort\miniconda3\envs\segment_bees_311\lib\site-packages\keras\utils\traceback_utils.py", line 96, in error_handler
#       return fn(*args, **kwargs)
#     File "c:\Users\bnort\miniconda3\envs\segment_bees_311\lib\site-packages\keras\layers\convolutional\base_conv.py", line 314, in call
#       return self.activation(outputs)
#     File "c:\Users\bnort\miniconda3\envs\segment_bees_311\lib\site-packages\keras\activations.py", line 317, in relu
#       return backend.relu(
#     File "c:\Users\bnort\miniconda3\envs\segment_bees_311\lib\site-packages\keras\backend.py", line 5366, in relu
#       x = tf.nn.relu(x)
# Node: 'model_3/conv2d_6/Relu'
# OOM when allocating tensor with shape[1,10944,16320,32] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[{{node model_3/conv2d_6/Relu}}]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info. This isn't available when running in Eager mode.
#  [Op:__inference_predict_function_3148]

# %%
test_img.shape
# Out:
# (1000, 1000, 3)
