# %% [markdown]
# ## Deep learning labelling 2d
#
# Use for labelling 2d data for training neural network.  Can do labels from scratch or also use to modify existing labels.

# %% [markdown]
# ## Load image and (optional) label

# %%
# automatically reload
# %load_ext autoreload
# %autoreload 2

from skimage.io import imread
from matplotlib import pyplot as plt
from tnia.plotting.plt_helper import imshow_multi2d
import numpy as np
import os
from pathlib import Path
from tnia.deeplearning.dl_helper import make_patch_directory, make_random_patch, make_patch_source_divide2
import json

tnia_images_path = Path(r'/home/bnorthan/images')

parent_path = Path(tnia_images_path / r'tnia-python-images/imagesc/2023_12_12_segmenting_etch_pits')
input_name = 'ImageJ_question.tif'
patch_base_name = 'etch'
axes = 'YX'
sub_sample = 2

label_name = None#'labels_cycle3.tif'
# load parent image
im = imread(parent_path / input_name)

if label_name is not None:
    labels = imread(parent_path+r'/'+label_name)
else:
    labels = np.zeros((im.shape[0], im.shape[1]), dtype=np.uint16)

if sub_sample > 1:
    im = im[::sub_sample, ::sub_sample]
    labels = labels[::sub_sample, ::sub_sample]

fig = imshow_multi2d([im, labels], ['im', 'labels'], 1, 2)

# %% [markdown]
# ## Create Folders for input and truth (labels) sets

# %%
train_path = os.path.join(parent_path, 'labels')
make_patch_directory(1, 1, train_path)

# Load the existing JSON data which is created when making the patch directory and append addition information to it
json_file = os.path.join(train_path, "info.json")

with open(json_file, 'r') as infile:
    data = json.load(infile)

# add the sub_sample information to the JSON file
data['sub_sample'] = sub_sample 
data['axes'] = axes

# Write the modified data back to the JSON file
with open(json_file, 'w') as outfile:
    json.dump(data, outfile)

# %%
train_path = os.path.join(parent_path, 'labels')

# here we append a 0 to the end of the input and ground truth folders, this is a convention we use so we could hypothetically extend to multiple input and ground truth channels
image_patch_path = train_path + '/input0'
label_patch_path = train_path + '/ground truth0'

if not os.path.exists(image_patch_path):
    os.makedirs(image_patch_path)

if not os.path.exists(label_patch_path):
    os.makedirs(label_patch_path)

# %% [markdown]
# ## Run the next 3 cells multiple times to create input and label sets.
#
# The cells do the following
#
# 1. The first cell creates unique input and label names
# 2. The second cell create a random patch and open the image and label patch in Napari.  Then the user can use Napari labelling tools to draw the labels.
# 3. The third cell saves the image and label patch

# %%
from tnia.deeplearning.dl_helper import generate_patch_names
image_name, label_name = generate_patch_names(image_patch_path, label_patch_path, patch_base_name)
print(image_name, label_name)
# Out:
# image path /home/bnorthan/images/tnia-python-images/imagesc/2023_12_12_segmenting_etch_pits/labels/input0
# mask path /home/bnorthan/images/tnia-python-images/imagesc/2023_12_12_segmenting_etch_pits/labels/ground truth0
# data name etch
# image  0 exists
# image  1 exists
# image  2 exists
# image  3 exists
# image  4 exists
# image  5 exists
# image  6 exists
# image  7 exists
# image  8 exists
# image  9 exists
# image  10 exists
# /home/bnorthan/images/tnia-python-images/imagesc/2023_12_12_segmenting_etch_pits/labels/input0/etch_11.tif
# /home/bnorthan/images/tnia-python-images/imagesc/2023_12_12_segmenting_etch_pits/labels/ground truth0/etch_11.tif
# /home/bnorthan/images/tnia-python-images/imagesc/2023_12_12_segmenting_etch_pits/labels/input0/etch_11.tif /home/bnorthan/images/tnia-python-images/imagesc/2023_12_12_segmenting_etch_pits/labels/ground truth0/etch_11.tif

# %%
from random import randint
import numpy as np

patch_size = 256

x=randint(0,im.shape[1]-patch_size-1)
y=randint(0,im.shape[0]-patch_size-1)

if axes == 'YXC':
    ind = np.s_[y:y+patch_size, x:x+patch_size, :]
else:
    ind = np.s_[y:y+patch_size, x:x+patch_size]
    
ind_label = np.s_[y:y+patch_size, x:x+patch_size]


import napari
viewer=napari.Viewer()

viewer.add_image(im[ind], name='intensity')
viewer.add_labels(labels[ind_label], name='labels')
# Out:
# <Labels layer 'labels' at 0x7fa99bb9b520>

# %%
from tnia.plotting.plt_helper import imshow2d
from skimage.io import imsave

print('saving to ', image_name)

imsave(image_name, im[ind])
imsave(label_name, labels[ind_label])
# Out:
# saving to  /home/bnorthan/images/tnia-python-images/imagesc/2023_12_12_segmenting_etch_pits/labels/input0/etch_11.tif
# /tmp/ipykernel_50116/1730857181.py:7: UserWarning: /home/bnorthan/images/tnia-python-images/imagesc/2023_12_12_segmenting_etch_pits/labels/ground truth0/etch_11.tif is a low contrast image
#   imsave(label_name, labels[ind_label])

# %%
## loop through all files in image_patch_path and label_patch_path and load them into a list
from glob import glob
image_files = glob(image_patch_path+'/*')
label_files = glob(label_patch_path+'/*')

for image_file, label_file in zip(image_files, label_files):
    print(image_file, label_file)
    im = imread(image_file)
    labels = imread(label_file)
    fig = imshow_multi2d([im, labels], ['im', 'labels'], 1, 2)
    fig.suptitle(os.path.basename(image_file))
    plt.show()
# Out:
# /home/bnorthan/images/tnia-python-images/imagesc/2023_12_12_segmenting_etch_pits/labels/input0/etch_3.tif /home/bnorthan/images/tnia-python-images/imagesc/2023_12_12_segmenting_etch_pits/labels/ground truth0/etch_3.tif
# /home/bnorthan/images/tnia-python-images/imagesc/2023_12_12_segmenting_etch_pits/labels/input0/etch_7.tif /home/bnorthan/images/tnia-python-images/imagesc/2023_12_12_segmenting_etch_pits/labels/ground truth0/etch_7.tif
# /home/bnorthan/images/tnia-python-images/imagesc/2023_12_12_segmenting_etch_pits/labels/input0/etch_9.tif /home/bnorthan/images/tnia-python-images/imagesc/2023_12_12_segmenting_etch_pits/labels/ground truth0/etch_9.tif
# /home/bnorthan/images/tnia-python-images/imagesc/2023_12_12_segmenting_etch_pits/labels/input0/etch_2.tif /home/bnorthan/images/tnia-python-images/imagesc/2023_12_12_segmenting_etch_pits/labels/ground truth0/etch_2.tif
# /home/bnorthan/images/tnia-python-images/imagesc/2023_12_12_segmenting_etch_pits/labels/input0/etch_1.tif /home/bnorthan/images/tnia-python-images/imagesc/2023_12_12_segmenting_etch_pits/labels/ground truth0/etch_1.tif
# /home/bnorthan/images/tnia-python-images/imagesc/2023_12_12_segmenting_etch_pits/labels/input0/etch_8.tif /home/bnorthan/images/tnia-python-images/imagesc/2023_12_12_segmenting_etch_pits/labels/ground truth0/etch_8.tif
# /home/bnorthan/images/tnia-python-images/imagesc/2023_12_12_segmenting_etch_pits/labels/input0/etch_6.tif /home/bnorthan/images/tnia-python-images/imagesc/2023_12_12_segmenting_etch_pits/labels/ground truth0/etch_6.tif
# /home/bnorthan/images/tnia-python-images/imagesc/2023_12_12_segmenting_etch_pits/labels/input0/etch_11.tif /home/bnorthan/images/tnia-python-images/imagesc/2023_12_12_segmenting_etch_pits/labels/ground truth0/etch_11.tif
# /home/bnorthan/images/tnia-python-images/imagesc/2023_12_12_segmenting_etch_pits/labels/input0/etch_5.tif /home/bnorthan/images/tnia-python-images/imagesc/2023_12_12_segmenting_etch_pits/labels/ground truth0/etch_5.tif
# /home/bnorthan/images/tnia-python-images/imagesc/2023_12_12_segmenting_etch_pits/labels/input0/etch_0.tif /home/bnorthan/images/tnia-python-images/imagesc/2023_12_12_segmenting_etch_pits/labels/ground truth0/etch_0.tif
# /home/bnorthan/images/tnia-python-images/imagesc/2023_12_12_segmenting_etch_pits/labels/input0/etch_10.tif /home/bnorthan/images/tnia-python-images/imagesc/2023_12_12_segmenting_etch_pits/labels/ground truth0/etch_10.tif
# /home/bnorthan/images/tnia-python-images/imagesc/2023_12_12_segmenting_etch_pits/labels/input0/etch_4.tif /home/bnorthan/images/tnia-python-images/imagesc/2023_12_12_segmenting_etch_pits/labels/ground truth0/etch_4.tif
