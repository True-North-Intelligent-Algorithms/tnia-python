# %% [markdown]
# ## Stardist training example

# %%
import os
from tnia.plotting.plt_helper import imshow_multi2d
import tensorflow as tf
from pathlib import Path
import json

# %% [markdown]
# ## Check what devices we have access to....
#
# Not as important to have a beefy GPU for 2D as it is for 3D, but let's check

# %%
visible_devices = tf.config.list_physical_devices()
print(visible_devices)
# Out:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'), PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# ## Load inputs and ground truth
#
# We load directories called 'input0' and 'ground truth0' which should exist under ```train_path```.  The reason we append '0' to the end of the name is simply because some of the code that generates image and label sets is meant to work on multiple channels (so the 0 is the channel number)

# %%
#tnia_images_path = Path(r'/home/bnorthan/images')
tnia_images_path = Path("D:/images")
parent_path=Path(tnia_images_path / r'tnia-python-images/imagesc/2024_07_03_dl_scale_shape')
#test_name='bsp1-2.jpg'
n_rays = 32

train_path = parent_path / 'patches'

with open(train_path / 'info.json', 'r') as json_file:
    data = json.load(json_file)
    # Access the sub_sample parameter
    sub_sample = data['sub_sample']
    print('sub_sample',sub_sample)
    axes = data['axes']
    print('axes',axes)

image_patch_path = train_path / 'ground truth0'
label_patch_path = train_path / 'input0'

model_path = parent_path / 'model'

if not os.path.exists(model_path):
    os.makedirs(model_path)

if not os.path.exists(image_patch_path):
    print('image_patch_path does not exist')

if not os.path.exists(label_patch_path):
    print('label_patch_path does not exist')
# Out:
# sub_sample 1
# axes YX

# %% [markdown]
# ## Use a helper to collect the training data
#
# The helper will also optionally normalize the inputs.
#
# Normalization is a tricky issue sometimes it makes sense to normalize before creating patches, such that the data is normalized based on statistics of a larger region, closer to the normalization range that will be used for prediction.

# %%
from tnia.deeplearning.dl_helper import collect_training_data
add_trivial_channel = False

X, Y = collect_training_data(train_path, sub_sample=1, downsample=False, normalize_input=False, add_trivial_channel = add_trivial_channel)

print('type X ', type(X))
print('type Y ', type(Y))
# Out:
# type X  <class 'list'>
# type Y  <class 'list'>

# %% [markdown]
# ## Inspect images
#
# Output training data shapes and plot images to make sure image and label set look OK

# %%
n=33
print(X[n].shape, Y[n].shape)
print(X[n].min(), X[n].max())
fig=imshow_multi2d([X[n], Y[n]], ['input', 'label'], 1,2)
# Out:
# (256, 256) (256, 256)
# 0.09854581 1.0

# %%
print(X[0].dtype, Y[0].dtype)
# Out:
# float32 uint8

# %% [markdown]
# ## Divide in to training and validation sets
#
# Use a helper to divide into training and validation.  Note the conversion to numpy arrays (needed for stardist training) is also baked into the divide_training_data function

# %%
from tnia.deeplearning.dl_helper import divide_training_data

X_train, Y_train, X_val, Y_val = divide_training_data(X, Y, val_size=2)

print('type X_train ', type(X_train))
# Out:
# type X_train  <class 'numpy.ndarray'>

# %% [markdown]
# ## Create stardist model
#
# In this cell we create the model.  Make sure to rename the model and give it a descriptive name that conveys the training data and setting used.

# %%
from stardist.models import StarDist2D, Config2D
from tnia.deeplearning.dl_helper import augmenter

if axes == 'YXC':
    n_channel_in =3
else:
    n_channel_in = 1

config = Config2D (n_rays=n_rays, axes=axes,n_channel_in=n_channel_in, train_patch_size = (256,256), unet_n_depth=3)

model = StarDist2D(config=config, name="model_second_try", basedir=model_path)
# Out:
# Using default values: prob_thresh=0.5, nms_thresh=0.4.
# base_model.py (198): output path for model already exists, files may be overwritten: D:\images\tnia-python-images\imagesc\2024_07_03_dl_scale_shape\model\model_second_try

# %% [markdown]
# ## Train the model

# %%
X_val.shape, Y_val.shape
# Out:
# ((2, 256, 256), (2, 256, 256))

# %%
X_train.shape, Y_train.shape
# Out:
# ((598, 256, 256), (598, 256, 256))

# %%
import napari
viewer = napari.Viewer()
# Out:
# INFO:albumentations.check_version:A new version of Albumentations is available: 1.4.10 (you have 1.4.8). Upgrade using: pip install --upgrade albumentations

# %%
print(config)
# Out:
# Config2D(n_dim=2, axes='YXC', n_channel_in=1, n_channel_out=33, train_checkpoint='weights_best.h5', train_checkpoint_last='weights_last.h5', train_checkpoint_epoch='weights_now.h5', n_rays=32, grid=(1, 1), backbone='unet', n_classes=None, unet_n_depth=3, unet_kernel_size=(3, 3), unet_n_filter_base=32, unet_n_conv_per_depth=2, unet_pool=(2, 2), unet_activation='relu', unet_last_activation='relu', unet_batch_norm=False, unet_dropout=0.0, unet_prefix='', net_conv_after_unet=128, net_input_shape=(None, None, 1), net_mask_shape=(None, None, 1), train_shape_completion=False, train_completion_crop=32, train_patch_size=(256, 256), train_background_reg=0.0001, train_foreground_only=0.9, train_sample_cache=True, train_dist_loss='mae', train_loss_weights=(1, 0.2), train_class_weights=(1, 1), train_epochs=400, train_steps_per_epoch=100, train_learning_rate=0.0003, train_batch_size=4, train_n_val_patches=None, train_tensorboard=True, train_reduce_lr={'factor': 0.5, 'patience': 40, 'min_delta': 0}, use_gpu=False)

# %%
#model.train(X_train, Y_train, validation_data=(X_val,Y_val),epochs=100, steps_per_epoch=200, augmenter=augmenter) 
model.train(X_train, Y_train, validation_data=(X_val,Y_val),epochs=80, steps_per_epoch=100)
# Out:
# Epoch 1/80
# 100/100 [==============================] - 17s 151ms/step - loss: 2.0351 - prob_loss: 0.2557 - dist_loss: 8.8968 - prob_kld: 0.2052 - dist_relevant_mae: 8.8962 - dist_relevant_mse: 184.6784 - dist_dist_iou_metric: 0.2110 - val_loss: 1.3625 - val_prob_loss: 0.1930 - val_dist_loss: 5.8474 - val_prob_kld: 0.1483 - val_dist_relevant_mae: 5.8465 - val_dist_relevant_mse: 72.9371 - val_dist_dist_iou_metric: 0.3679 - lr: 3.0000e-04
# Epoch 2/80
# 100/100 [==============================] - 15s 147ms/step - loss: 1.5436 - prob_loss: 0.1645 - dist_loss: 6.8955 - prob_kld: 0.1160 - dist_relevant_mae: 6.8946 - dist_relevant_mse: 129.1105 - dist_dist_iou_metric: 0.3328 - val_loss: 1.3069 - val_prob_loss: 0.1245 - val_dist_loss: 5.9119 - val_prob_kld: 0.0797 - val_dist_relevant_mae: 5.9110 - val_dist_relevant_mse: 80.8936 - val_dist_dist_iou_metric: 0.3235 - lr: 3.0000e-04
# Epoch 3/80
# 100/100 [==============================] - 14s 142ms/step - loss: 1.4709 - prob_loss: 0.1305 - dist_loss: 6.7018 - prob_kld: 0.0823 - dist_relevant_mae: 6.7008 - dist_relevant_mse: 119.4870 - dist_dist_iou_metric: 0.3329 - val_loss: 1.2760 - val_prob_loss: 0.1370 - val_dist_loss: 5.6948 - val_prob_kld: 0.0923 - val_dist_relevant_mae: 5.6939 - val_dist_relevant_mse: 73.2962 - val_dist_dist_iou_metric: 0.3539 - lr: 3.0000e-04
# Epoch 4/80
# 100/100 [==============================] - 15s 149ms/step - loss: 1.4611 - prob_loss: 0.1178 - dist_loss: 6.7162 - prob_kld: 0.0694 - dist_relevant_mae: 6.7153 - dist_relevant_mse: 126.1491 - dist_dist_iou_metric: 0.3430 - val_loss: 1.2054 - val_prob_loss: 0.1401 - val_dist_loss: 5.3262 - val_prob_kld: 0.0954 - val_dist_relevant_mae: 5.3254 - val_dist_relevant_mse: 66.8810 - val_dist_dist_iou_metric: 0.3730 - lr: 3.0000e-04
# Epoch 5/80
# 100/100 [==============================] - 14s 140ms/step - loss: 1.2811 - prob_loss: 0.1081 - dist_loss: 5.8652 - prob_kld: 0.0611 - dist_relevant_mae: 5.8641 - dist_relevant_mse: 103.5281 - dist_dist_iou_metric: 0.4022 - val_loss: 1.0751 - val_prob_loss: 0.0979 - val_dist_loss: 4.8858 - val_prob_kld: 0.0532 - val_dist_relevant_mae: 4.8847 - val_dist_relevant_mse: 57.4146 - val_dist_dist_iou_metric: 0.4275 - lr: 3.0000e-04
# Epoch 6/80
# 100/100 [==============================] - 14s 140ms/step - loss: 1.1676 - prob_loss: 0.0998 - dist_loss: 5.3391 - prob_kld: 0.0509 - dist_relevant_mae: 5.3381 - dist_relevant_mse: 92.1329 - dist_dist_iou_metric: 0.4354 - val_loss: 1.0902 - val_prob_loss: 0.0914 - val_dist_loss: 4.9941 - val_prob_kld: 0.0467 - val_dist_relevant_mae: 4.9930 - val_dist_relevant_mse: 53.1026 - val_dist_dist_iou_metric: 0.4604 - lr: 3.0000e-04
# Epoch 7/80
# 100/100 [==============================] - 14s 142ms/step - loss: 1.1440 - prob_loss: 0.0927 - dist_loss: 5.2565 - prob_kld: 0.0448 - dist_relevant_mae: 5.2554 - dist_relevant_mse: 91.8343 - dist_dist_iou_metric: 0.4475 - val_loss: 1.0132 - val_prob_loss: 0.0812 - val_dist_loss: 4.6598 - val_prob_kld: 0.0365 - val_dist_relevant_mae: 4.6587 - val_dist_relevant_mse: 51.8328 - val_dist_dist_iou_metric: 0.4667 - lr: 3.0000e-04
# Epoch 8/80
# 100/100 [==============================] - 14s 137ms/step - loss: 1.1004 - prob_loss: 0.0823 - dist_loss: 5.0907 - prob_kld: 0.0341 - dist_relevant_mae: 5.0897 - dist_relevant_mse: 87.2007 - dist_dist_iou_metric: 0.4571 - val_loss: 1.0056 - val_prob_loss: 0.0772 - val_dist_loss: 4.6419 - val_prob_kld: 0.0325 - val_dist_relevant_mae: 4.6410 - val_dist_relevant_mse: 53.6691 - val_dist_dist_iou_metric: 0.4421 - lr: 3.0000e-04
# Epoch 9/80
# 100/100 [==============================] - 15s 148ms/step - loss: 1.0700 - prob_loss: 0.0797 - dist_loss: 4.9514 - prob_kld: 0.0315 - dist_relevant_mae: 4.9504 - dist_relevant_mse: 82.5147 - dist_dist_iou_metric: 0.4633 - val_loss: 1.0002 - val_prob_loss: 0.0766 - val_dist_loss: 4.6183 - val_prob_kld: 0.0318 - val_dist_relevant_mae: 4.6175 - val_dist_relevant_mse: 53.1395 - val_dist_dist_iou_metric: 0.4640 - lr: 3.0000e-04
# Epoch 10/80
# 100/100 [==============================] - 14s 137ms/step - loss: 1.0643 - prob_loss: 0.0760 - dist_loss: 4.9412 - prob_kld: 0.0284 - dist_relevant_mae: 4.9403 - dist_relevant_mse: 81.9522 - dist_dist_iou_metric: 0.4667 - val_loss: 0.9682 - val_prob_loss: 0.0767 - val_dist_loss: 4.4576 - val_prob_kld: 0.0320 - val_dist_relevant_mae: 4.4568 - val_dist_relevant_mse: 47.3090 - val_dist_dist_iou_metric: 0.4838 - lr: 3.0000e-04
# Epoch 11/80
# 100/100 [==============================] - 15s 147ms/step - loss: 1.0441 - prob_loss: 0.0767 - dist_loss: 4.8367 - prob_kld: 0.0280 - dist_relevant_mae: 4.8359 - dist_relevant_mse: 80.2671 - dist_dist_iou_metric: 0.4738 - val_loss: 0.9785 - val_prob_loss: 0.0759 - val_dist_loss: 4.5131 - val_prob_kld: 0.0312 - val_dist_relevant_mae: 4.5123 - val_dist_relevant_mse: 49.4537 - val_dist_dist_iou_metric: 0.4738 - lr: 3.0000e-04
# Epoch 12/80
# 100/100 [==============================] - 14s 143ms/step - loss: 1.0531 - prob_loss: 0.0770 - dist_loss: 4.8805 - prob_kld: 0.0292 - dist_relevant_mae: 4.8797 - dist_relevant_mse: 81.9559 - dist_dist_iou_metric: 0.4748 - val_loss: 0.9867 - val_prob_loss: 0.0741 - val_dist_loss: 4.5627 - val_prob_kld: 0.0294 - val_dist_relevant_mae: 4.5619 - val_dist_relevant_mse: 52.0735 - val_dist_dist_iou_metric: 0.4484 - lr: 3.0000e-04
# Epoch 13/80
# 100/100 [==============================] - 14s 143ms/step - loss: 0.9999 - prob_loss: 0.0785 - dist_loss: 4.6067 - prob_kld: 0.0302 - dist_relevant_mae: 4.6058 - dist_relevant_mse: 71.3851 - dist_dist_iou_metric: 0.4951 - val_loss: 0.9814 - val_prob_loss: 0.0780 - val_dist_loss: 4.5168 - val_prob_kld: 0.0333 - val_dist_relevant_mae: 4.5161 - val_dist_relevant_mse: 50.0042 - val_dist_dist_iou_metric: 0.4601 - lr: 3.0000e-04
# Epoch 14/80
# 100/100 [==============================] - 14s 141ms/step - loss: 0.9429 - prob_loss: 0.0754 - dist_loss: 4.3373 - prob_kld: 0.0280 - dist_relevant_mae: 4.3364 - dist_relevant_mse: 63.4958 - dist_dist_iou_metric: 0.5175 - val_loss: 0.9011 - val_prob_loss: 0.0760 - val_dist_loss: 4.1252 - val_prob_kld: 0.0313 - val_dist_relevant_mae: 4.1244 - val_dist_relevant_mse: 40.4698 - val_dist_dist_iou_metric: 0.5328 - lr: 3.0000e-04
# Epoch 15/80
# 100/100 [==============================] - 14s 142ms/step - loss: 0.9202 - prob_loss: 0.0760 - dist_loss: 4.2207 - prob_kld: 0.0278 - dist_relevant_mae: 4.2198 - dist_relevant_mse: 59.0415 - dist_dist_iou_metric: 0.5318 - val_loss: 0.8330 - val_prob_loss: 0.0716 - val_dist_loss: 3.8066 - val_prob_kld: 0.0269 - val_dist_relevant_mae: 3.8059 - val_dist_relevant_mse: 34.4887 - val_dist_dist_iou_metric: 0.5504 - lr: 3.0000e-04
# Epoch 16/80
# 100/100 [==============================] - 14s 139ms/step - loss: 0.8694 - prob_loss: 0.0743 - dist_loss: 3.9757 - prob_kld: 0.0265 - dist_relevant_mae: 3.9749 - dist_relevant_mse: 52.8856 - dist_dist_iou_metric: 0.5544 - val_loss: 0.8109 - val_prob_loss: 0.0732 - val_dist_loss: 3.6884 - val_prob_kld: 0.0284 - val_dist_relevant_mae: 3.6875 - val_dist_relevant_mse: 32.6141 - val_dist_dist_iou_metric: 0.5674 - lr: 3.0000e-04
# Epoch 17/80
# 100/100 [==============================] - 14s 140ms/step - loss: 0.8639 - prob_loss: 0.0760 - dist_loss: 3.9395 - prob_kld: 0.0275 - dist_relevant_mae: 3.9387 - dist_relevant_mse: 49.9425 - dist_dist_iou_metric: 0.5574 - val_loss: 0.8045 - val_prob_loss: 0.0718 - val_dist_loss: 3.6634 - val_prob_kld: 0.0270 - val_dist_relevant_mae: 3.6627 - val_dist_relevant_mse: 33.0115 - val_dist_dist_iou_metric: 0.5617 - lr: 3.0000e-04
# Epoch 18/80
# 100/100 [==============================] - 14s 142ms/step - loss: 0.8397 - prob_loss: 0.0738 - dist_loss: 3.8296 - prob_kld: 0.0257 - dist_relevant_mae: 3.8287 - dist_relevant_mse: 47.9063 - dist_dist_iou_metric: 0.5699 - val_loss: 0.7985 - val_prob_loss: 0.0729 - val_dist_loss: 3.6282 - val_prob_kld: 0.0282 - val_dist_relevant_mae: 3.6274 - val_dist_relevant_mse: 30.1655 - val_dist_dist_iou_metric: 0.5817 - lr: 3.0000e-04
# Epoch 19/80
# 100/100 [==============================] - 14s 136ms/step - loss: 0.8089 - prob_loss: 0.0726 - dist_loss: 3.6811 - prob_kld: 0.0245 - dist_relevant_mae: 3.6803 - dist_relevant_mse: 43.8077 - dist_dist_iou_metric: 0.5816 - val_loss: 0.8108 - val_prob_loss: 0.0713 - val_dist_loss: 3.6977 - val_prob_kld: 0.0265 - val_dist_relevant_mae: 3.6969 - val_dist_relevant_mse: 31.3354 - val_dist_dist_iou_metric: 0.5886 - lr: 3.0000e-04
# Epoch 20/80
# 100/100 [==============================] - 15s 146ms/step - loss: 0.8033 - prob_loss: 0.0708 - dist_loss: 3.6628 - prob_kld: 0.0235 - dist_relevant_mae: 3.6620 - dist_relevant_mse: 43.5406 - dist_dist_iou_metric: 0.5868 - val_loss: 0.7601 - val_prob_loss: 0.0718 - val_dist_loss: 3.4419 - val_prob_kld: 0.0270 - val_dist_relevant_mae: 3.4411 - val_dist_relevant_mse: 27.3503 - val_dist_dist_iou_metric: 0.5978 - lr: 3.0000e-04
# Epoch 21/80
# 100/100 [==============================] - 14s 140ms/step - loss: 0.8037 - prob_loss: 0.0723 - dist_loss: 3.6571 - prob_kld: 0.0239 - dist_relevant_mae: 3.6563 - dist_relevant_mse: 42.4595 - dist_dist_iou_metric: 0.5863 - val_loss: 0.7720 - val_prob_loss: 0.0715 - val_dist_loss: 3.5028 - val_prob_kld: 0.0267 - val_dist_relevant_mae: 3.5020 - val_dist_relevant_mse: 28.6375 - val_dist_dist_iou_metric: 0.6066 - lr: 3.0000e-04
# Epoch 22/80
# 100/100 [==============================] - 14s 141ms/step - loss: 0.7738 - prob_loss: 0.0714 - dist_loss: 3.5120 - prob_kld: 0.0229 - dist_relevant_mae: 3.5112 - dist_relevant_mse: 38.7427 - dist_dist_iou_metric: 0.5990 - val_loss: 0.7990 - val_prob_loss: 0.0721 - val_dist_loss: 3.6347 - val_prob_kld: 0.0273 - val_dist_relevant_mae: 3.6338 - val_dist_relevant_mse: 29.4970 - val_dist_dist_iou_metric: 0.5892 - lr: 3.0000e-04
# Epoch 23/80
# 100/100 [==============================] - 15s 153ms/step - loss: 0.7856 - prob_loss: 0.0724 - dist_loss: 3.5660 - prob_kld: 0.0235 - dist_relevant_mae: 3.5652 - dist_relevant_mse: 39.9228 - dist_dist_iou_metric: 0.5949 - val_loss: 0.7530 - val_prob_loss: 0.0729 - val_dist_loss: 3.4003 - val_prob_kld: 0.0282 - val_dist_relevant_mae: 3.3996 - val_dist_relevant_mse: 27.0649 - val_dist_dist_iou_metric: 0.5901 - lr: 3.0000e-04
# Epoch 24/80
# 100/100 [==============================] - 14s 141ms/step - loss: 0.7471 - prob_loss: 0.0694 - dist_loss: 3.3884 - prob_kld: 0.0223 - dist_relevant_mae: 3.3876 - dist_relevant_mse: 36.1959 - dist_dist_iou_metric: 0.6109 - val_loss: 0.7175 - val_prob_loss: 0.0683 - val_dist_loss: 3.2462 - val_prob_kld: 0.0236 - val_dist_relevant_mae: 3.2455 - val_dist_relevant_mse: 24.8543 - val_dist_dist_iou_metric: 0.6179 - lr: 3.0000e-04
# Epoch 25/80
# 100/100 [==============================] - 14s 139ms/step - loss: 0.7351 - prob_loss: 0.0694 - dist_loss: 3.3283 - prob_kld: 0.0216 - dist_relevant_mae: 3.3275 - dist_relevant_mse: 35.0151 - dist_dist_iou_metric: 0.6187 - val_loss: 0.7650 - val_prob_loss: 0.0684 - val_dist_loss: 3.4830 - val_prob_kld: 0.0237 - val_dist_relevant_mae: 3.4821 - val_dist_relevant_mse: 26.5321 - val_dist_dist_iou_metric: 0.6260 - lr: 3.0000e-04
# Epoch 26/80
# 100/100 [==============================] - 14s 140ms/step - loss: 0.7307 - prob_loss: 0.0698 - dist_loss: 3.3046 - prob_kld: 0.0210 - dist_relevant_mae: 3.3038 - dist_relevant_mse: 34.7972 - dist_dist_iou_metric: 0.6190 - val_loss: 0.7393 - val_prob_loss: 0.0687 - val_dist_loss: 3.3529 - val_prob_kld: 0.0240 - val_dist_relevant_mae: 3.3521 - val_dist_relevant_mse: 25.0516 - val_dist_dist_iou_metric: 0.6205 - lr: 3.0000e-04
# Epoch 27/80
# 100/100 [==============================] - 14s 142ms/step - loss: 0.7090 - prob_loss: 0.0674 - dist_loss: 3.2079 - prob_kld: 0.0201 - dist_relevant_mae: 3.2071 - dist_relevant_mse: 33.3859 - dist_dist_iou_metric: 0.6313 - val_loss: 0.7186 - val_prob_loss: 0.0694 - val_dist_loss: 3.2460 - val_prob_kld: 0.0247 - val_dist_relevant_mae: 3.2452 - val_dist_relevant_mse: 22.8850 - val_dist_dist_iou_metric: 0.6290 - lr: 3.0000e-04
# Epoch 28/80
# 100/100 [==============================] - 15s 146ms/step - loss: 0.6966 - prob_loss: 0.0679 - dist_loss: 3.1436 - prob_kld: 0.0200 - dist_relevant_mae: 3.1428 - dist_relevant_mse: 31.5660 - dist_dist_iou_metric: 0.6358 - val_loss: 0.7277 - val_prob_loss: 0.0686 - val_dist_loss: 3.2956 - val_prob_kld: 0.0238 - val_dist_relevant_mae: 3.2948 - val_dist_relevant_mse: 23.5714 - val_dist_dist_iou_metric: 0.6304 - lr: 3.0000e-04
# Epoch 29/80
# 100/100 [==============================] - 14s 139ms/step - loss: 0.6964 - prob_loss: 0.0692 - dist_loss: 3.1358 - prob_kld: 0.0206 - dist_relevant_mae: 3.1350 - dist_relevant_mse: 31.1929 - dist_dist_iou_metric: 0.6356 - val_loss: 0.6857 - val_prob_loss: 0.0678 - val_dist_loss: 3.0894 - val_prob_kld: 0.0230 - val_dist_relevant_mae: 3.0886 - val_dist_relevant_mse: 22.1928 - val_dist_dist_iou_metric: 0.6476 - lr: 3.0000e-04
# Epoch 30/80
# 100/100 [==============================] - 14s 136ms/step - loss: 0.6839 - prob_loss: 0.0668 - dist_loss: 3.0853 - prob_kld: 0.0191 - dist_relevant_mae: 3.0846 - dist_relevant_mse: 31.1731 - dist_dist_iou_metric: 0.6456 - val_loss: 0.7113 - val_prob_loss: 0.0694 - val_dist_loss: 3.2095 - val_prob_kld: 0.0247 - val_dist_relevant_mae: 3.2088 - val_dist_relevant_mse: 23.0535 - val_dist_dist_iou_metric: 0.6423 - lr: 3.0000e-04
# Epoch 31/80
# 100/100 [==============================] - 15s 148ms/step - loss: 0.6713 - prob_loss: 0.0665 - dist_loss: 3.0242 - prob_kld: 0.0189 - dist_relevant_mae: 3.0234 - dist_relevant_mse: 28.7876 - dist_dist_iou_metric: 0.6474 - val_loss: 0.6639 - val_prob_loss: 0.0694 - val_dist_loss: 2.9727 - val_prob_kld: 0.0247 - val_dist_relevant_mae: 2.9719 - val_dist_relevant_mse: 21.1233 - val_dist_dist_iou_metric: 0.6603 - lr: 3.0000e-04
# Epoch 32/80
# 100/100 [==============================] - 14s 136ms/step - loss: 0.6618 - prob_loss: 0.0669 - dist_loss: 2.9749 - prob_kld: 0.0189 - dist_relevant_mae: 2.9742 - dist_relevant_mse: 27.9301 - dist_dist_iou_metric: 0.6520 - val_loss: 0.6665 - val_prob_loss: 0.0668 - val_dist_loss: 2.9983 - val_prob_kld: 0.0221 - val_dist_relevant_mae: 2.9975 - val_dist_relevant_mse: 21.0839 - val_dist_dist_iou_metric: 0.6639 - lr: 3.0000e-04
# Epoch 33/80
# 100/100 [==============================] - 14s 145ms/step - loss: 0.6498 - prob_loss: 0.0672 - dist_loss: 2.9126 - prob_kld: 0.0186 - dist_relevant_mae: 2.9118 - dist_relevant_mse: 28.2655 - dist_dist_iou_metric: 0.6594 - val_loss: 0.6994 - val_prob_loss: 0.0672 - val_dist_loss: 3.1610 - val_prob_kld: 0.0224 - val_dist_relevant_mae: 3.1603 - val_dist_relevant_mse: 23.8644 - val_dist_dist_iou_metric: 0.6389 - lr: 3.0000e-04
# Epoch 34/80
# 100/100 [==============================] - 14s 140ms/step - loss: 0.6239 - prob_loss: 0.0668 - dist_loss: 2.7852 - prob_kld: 0.0182 - dist_relevant_mae: 2.7844 - dist_relevant_mse: 25.5034 - dist_dist_iou_metric: 0.6705 - val_loss: 0.6729 - val_prob_loss: 0.0675 - val_dist_loss: 3.0268 - val_prob_kld: 0.0228 - val_dist_relevant_mae: 3.0261 - val_dist_relevant_mse: 20.4473 - val_dist_dist_iou_metric: 0.6553 - lr: 3.0000e-04
# Epoch 35/80
# 100/100 [==============================] - 14s 144ms/step - loss: 0.6350 - prob_loss: 0.0652 - dist_loss: 2.8491 - prob_kld: 0.0179 - dist_relevant_mae: 2.8483 - dist_relevant_mse: 27.9219 - dist_dist_iou_metric: 0.6653 - val_loss: 0.6294 - val_prob_loss: 0.0652 - val_dist_loss: 2.8212 - val_prob_kld: 0.0204 - val_dist_relevant_mae: 2.8205 - val_dist_relevant_mse: 19.2520 - val_dist_dist_iou_metric: 0.6748 - lr: 3.0000e-04
# Epoch 36/80
# 100/100 [==============================] - 14s 145ms/step - loss: 0.6249 - prob_loss: 0.0660 - dist_loss: 2.7942 - prob_kld: 0.0176 - dist_relevant_mae: 2.7934 - dist_relevant_mse: 25.1542 - dist_dist_iou_metric: 0.6718 - val_loss: 0.6519 - val_prob_loss: 0.0676 - val_dist_loss: 2.9215 - val_prob_kld: 0.0229 - val_dist_relevant_mae: 2.9208 - val_dist_relevant_mse: 20.4002 - val_dist_dist_iou_metric: 0.6595 - lr: 3.0000e-04
# Epoch 37/80
# 100/100 [==============================] - 14s 140ms/step - loss: 0.5989 - prob_loss: 0.0645 - dist_loss: 2.6721 - prob_kld: 0.0166 - dist_relevant_mae: 2.6713 - dist_relevant_mse: 24.1567 - dist_dist_iou_metric: 0.6819 - val_loss: 0.6589 - val_prob_loss: 0.0687 - val_dist_loss: 2.9510 - val_prob_kld: 0.0240 - val_dist_relevant_mae: 2.9502 - val_dist_relevant_mse: 20.0220 - val_dist_dist_iou_metric: 0.6814 - lr: 3.0000e-04
# Epoch 38/80
# 100/100 [==============================] - 14s 142ms/step - loss: 0.6142 - prob_loss: 0.0635 - dist_loss: 2.7534 - prob_kld: 0.0164 - dist_relevant_mae: 2.7526 - dist_relevant_mse: 24.5630 - dist_dist_iou_metric: 0.6733 - val_loss: 0.6145 - val_prob_loss: 0.0651 - val_dist_loss: 2.7468 - val_prob_kld: 0.0204 - val_dist_relevant_mae: 2.7461 - val_dist_relevant_mse: 17.8348 - val_dist_dist_iou_metric: 0.6774 - lr: 3.0000e-04
# Epoch 39/80
# 100/100 [==============================] - 14s 143ms/step - loss: 0.6053 - prob_loss: 0.0652 - dist_loss: 2.7003 - prob_kld: 0.0164 - dist_relevant_mae: 2.6996 - dist_relevant_mse: 24.7361 - dist_dist_iou_metric: 0.6816 - val_loss: 0.5853 - val_prob_loss: 0.0636 - val_dist_loss: 2.6083 - val_prob_kld: 0.0189 - val_dist_relevant_mae: 2.6075 - val_dist_relevant_mse: 17.1408 - val_dist_dist_iou_metric: 0.6880 - lr: 3.0000e-04
# Epoch 40/80
# 100/100 [==============================] - 14s 144ms/step - loss: 0.5782 - prob_loss: 0.0632 - dist_loss: 2.5752 - prob_kld: 0.0155 - dist_relevant_mae: 2.5744 - dist_relevant_mse: 23.0214 - dist_dist_iou_metric: 0.6920 - val_loss: 0.6192 - val_prob_loss: 0.0634 - val_dist_loss: 2.7793 - val_prob_kld: 0.0186 - val_dist_relevant_mae: 2.7785 - val_dist_relevant_mse: 17.4486 - val_dist_dist_iou_metric: 0.6833 - lr: 3.0000e-04
# Epoch 41/80
# 100/100 [==============================] - 14s 145ms/step - loss: 0.5760 - prob_loss: 0.0636 - dist_loss: 2.5618 - prob_kld: 0.0152 - dist_relevant_mae: 2.5611 - dist_relevant_mse: 22.7289 - dist_dist_iou_metric: 0.6945 - val_loss: 0.6125 - val_prob_loss: 0.0640 - val_dist_loss: 2.7426 - val_prob_kld: 0.0192 - val_dist_relevant_mae: 2.7419 - val_dist_relevant_mse: 18.1739 - val_dist_dist_iou_metric: 0.6868 - lr: 3.0000e-04
# Epoch 42/80
# 100/100 [==============================] - 14s 143ms/step - loss: 0.5689 - prob_loss: 0.0639 - dist_loss: 2.5247 - prob_kld: 0.0155 - dist_relevant_mae: 2.5240 - dist_relevant_mse: 22.1607 - dist_dist_iou_metric: 0.6966 - val_loss: 0.6294 - val_prob_loss: 0.0669 - val_dist_loss: 2.8129 - val_prob_kld: 0.0221 - val_dist_relevant_mae: 2.8122 - val_dist_relevant_mse: 19.8221 - val_dist_dist_iou_metric: 0.6823 - lr: 3.0000e-04
# Epoch 43/80
# 100/100 [==============================] - 14s 140ms/step - loss: 0.5573 - prob_loss: 0.0633 - dist_loss: 2.4699 - prob_kld: 0.0147 - dist_relevant_mae: 2.4692 - dist_relevant_mse: 21.2956 - dist_dist_iou_metric: 0.7026 - val_loss: 0.6096 - val_prob_loss: 0.0649 - val_dist_loss: 2.7234 - val_prob_kld: 0.0202 - val_dist_relevant_mae: 2.7227 - val_dist_relevant_mse: 18.9807 - val_dist_dist_iou_metric: 0.6835 - lr: 3.0000e-04
# Epoch 44/80
# 100/100 [==============================] - 15s 147ms/step - loss: 0.5582 - prob_loss: 0.0621 - dist_loss: 2.4806 - prob_kld: 0.0143 - dist_relevant_mae: 2.4799 - dist_relevant_mse: 21.7451 - dist_dist_iou_metric: 0.7003 - val_loss: 0.5899 - val_prob_loss: 0.0629 - val_dist_loss: 2.6348 - val_prob_kld: 0.0182 - val_dist_relevant_mae: 2.6341 - val_dist_relevant_mse: 17.2370 - val_dist_dist_iou_metric: 0.6966 - lr: 3.0000e-04
# Epoch 45/80
# 100/100 [==============================] - 15s 150ms/step - loss: 0.5417 - prob_loss: 0.0610 - dist_loss: 2.4037 - prob_kld: 0.0137 - dist_relevant_mae: 2.4030 - dist_relevant_mse: 20.5552 - dist_dist_iou_metric: 0.7101 - val_loss: 0.5762 - val_prob_loss: 0.0634 - val_dist_loss: 2.5639 - val_prob_kld: 0.0187 - val_dist_relevant_mae: 2.5632 - val_dist_relevant_mse: 16.3566 - val_dist_dist_iou_metric: 0.6959 - lr: 3.0000e-04
# Epoch 46/80
# 100/100 [==============================] - 14s 142ms/step - loss: 0.5447 - prob_loss: 0.0622 - dist_loss: 2.4126 - prob_kld: 0.0142 - dist_relevant_mae: 2.4119 - dist_relevant_mse: 20.4430 - dist_dist_iou_metric: 0.7090 - val_loss: 0.6593 - val_prob_loss: 0.0664 - val_dist_loss: 2.9643 - val_prob_kld: 0.0217 - val_dist_relevant_mae: 2.9637 - val_dist_relevant_mse: 20.9963 - val_dist_dist_iou_metric: 0.6573 - lr: 3.0000e-04
# Epoch 47/80
# 100/100 [==============================] - 14s 140ms/step - loss: 0.5297 - prob_loss: 0.0620 - dist_loss: 2.3388 - prob_kld: 0.0132 - dist_relevant_mae: 2.3381 - dist_relevant_mse: 19.8605 - dist_dist_iou_metric: 0.7156 - val_loss: 0.5765 - val_prob_loss: 0.0643 - val_dist_loss: 2.5610 - val_prob_kld: 0.0195 - val_dist_relevant_mae: 2.5603 - val_dist_relevant_mse: 15.9113 - val_dist_dist_iou_metric: 0.6999 - lr: 3.0000e-04
# Epoch 48/80
# 100/100 [==============================] - 15s 147ms/step - loss: 0.5104 - prob_loss: 0.0606 - dist_loss: 2.2490 - prob_kld: 0.0127 - dist_relevant_mae: 2.2483 - dist_relevant_mse: 18.6579 - dist_dist_iou_metric: 0.7237 - val_loss: 0.5636 - val_prob_loss: 0.0639 - val_dist_loss: 2.4986 - val_prob_kld: 0.0191 - val_dist_relevant_mae: 2.4979 - val_dist_relevant_mse: 16.0823 - val_dist_dist_iou_metric: 0.7064 - lr: 3.0000e-04
# Epoch 49/80
# 100/100 [==============================] - 14s 141ms/step - loss: 0.5172 - prob_loss: 0.0609 - dist_loss: 2.2816 - prob_kld: 0.0127 - dist_relevant_mae: 2.2809 - dist_relevant_mse: 19.3305 - dist_dist_iou_metric: 0.7234 - val_loss: 0.5720 - val_prob_loss: 0.0628 - val_dist_loss: 2.5462 - val_prob_kld: 0.0180 - val_dist_relevant_mae: 2.5455 - val_dist_relevant_mse: 15.2674 - val_dist_dist_iou_metric: 0.7016 - lr: 3.0000e-04
# Epoch 50/80
# 100/100 [==============================] - 15s 145ms/step - loss: 0.5094 - prob_loss: 0.0607 - dist_loss: 2.2434 - prob_kld: 0.0124 - dist_relevant_mae: 2.2428 - dist_relevant_mse: 19.0462 - dist_dist_iou_metric: 0.7271 - val_loss: 0.5921 - val_prob_loss: 0.0636 - val_dist_loss: 2.6426 - val_prob_kld: 0.0189 - val_dist_relevant_mae: 2.6419 - val_dist_relevant_mse: 17.6458 - val_dist_dist_iou_metric: 0.7031 - lr: 3.0000e-04
# Epoch 51/80
# 100/100 [==============================] - 14s 139ms/step - loss: 0.5027 - prob_loss: 0.0598 - dist_loss: 2.2144 - prob_kld: 0.0121 - dist_relevant_mae: 2.2137 - dist_relevant_mse: 18.2712 - dist_dist_iou_metric: 0.7266 - val_loss: 0.5700 - val_prob_loss: 0.0643 - val_dist_loss: 2.5281 - val_prob_kld: 0.0196 - val_dist_relevant_mae: 2.5274 - val_dist_relevant_mse: 16.6783 - val_dist_dist_iou_metric: 0.7006 - lr: 3.0000e-04
# Epoch 52/80
# 100/100 [==============================] - 15s 150ms/step - loss: 0.5008 - prob_loss: 0.0594 - dist_loss: 2.2066 - prob_kld: 0.0118 - dist_relevant_mae: 2.2059 - dist_relevant_mse: 17.8546 - dist_dist_iou_metric: 0.7297 - val_loss: 0.5528 - val_prob_loss: 0.0619 - val_dist_loss: 2.4543 - val_prob_kld: 0.0172 - val_dist_relevant_mae: 2.4536 - val_dist_relevant_mse: 14.5688 - val_dist_dist_iou_metric: 0.7081 - lr: 3.0000e-04
# Epoch 53/80
# 100/100 [==============================] - 14s 140ms/step - loss: 0.4856 - prob_loss: 0.0591 - dist_loss: 2.1326 - prob_kld: 0.0113 - dist_relevant_mae: 2.1319 - dist_relevant_mse: 17.5845 - dist_dist_iou_metric: 0.7371 - val_loss: 0.5704 - val_prob_loss: 0.0629 - val_dist_loss: 2.5374 - val_prob_kld: 0.0182 - val_dist_relevant_mae: 2.5367 - val_dist_relevant_mse: 15.2669 - val_dist_dist_iou_metric: 0.7151 - lr: 3.0000e-04
# Epoch 54/80
# 100/100 [==============================] - 16s 159ms/step - loss: 0.4828 - prob_loss: 0.0601 - dist_loss: 2.1137 - prob_kld: 0.0115 - dist_relevant_mae: 2.1130 - dist_relevant_mse: 16.9559 - dist_dist_iou_metric: 0.7394 - val_loss: 0.5301 - val_prob_loss: 0.0614 - val_dist_loss: 2.3434 - val_prob_kld: 0.0167 - val_dist_relevant_mae: 2.3428 - val_dist_relevant_mse: 13.2342 - val_dist_dist_iou_metric: 0.7136 - lr: 3.0000e-04
# Epoch 55/80
# 100/100 [==============================] - 15s 146ms/step - loss: 0.4777 - prob_loss: 0.0591 - dist_loss: 2.0931 - prob_kld: 0.0114 - dist_relevant_mae: 2.0924 - dist_relevant_mse: 16.8245 - dist_dist_iou_metric: 0.7414 - val_loss: 0.5301 - val_prob_loss: 0.0610 - val_dist_loss: 2.3453 - val_prob_kld: 0.0163 - val_dist_relevant_mae: 2.3447 - val_dist_relevant_mse: 14.0957 - val_dist_dist_iou_metric: 0.7228 - lr: 3.0000e-04
# Epoch 56/80
# 100/100 [==============================] - 14s 140ms/step - loss: 0.4585 - prob_loss: 0.0597 - dist_loss: 1.9938 - prob_kld: 0.0107 - dist_relevant_mae: 1.9931 - dist_relevant_mse: 16.0754 - dist_dist_iou_metric: 0.7516 - val_loss: 0.5356 - val_prob_loss: 0.0621 - val_dist_loss: 2.3672 - val_prob_kld: 0.0174 - val_dist_relevant_mae: 2.3665 - val_dist_relevant_mse: 14.2469 - val_dist_dist_iou_metric: 0.7319 - lr: 3.0000e-04
# Epoch 57/80
# 100/100 [==============================] - 15s 146ms/step - loss: 0.4685 - prob_loss: 0.0586 - dist_loss: 2.0491 - prob_kld: 0.0112 - dist_relevant_mae: 2.0485 - dist_relevant_mse: 16.3636 - dist_dist_iou_metric: 0.7466 - val_loss: 0.5073 - val_prob_loss: 0.0601 - val_dist_loss: 2.2361 - val_prob_kld: 0.0154 - val_dist_relevant_mae: 2.2354 - val_dist_relevant_mse: 12.6235 - val_dist_dist_iou_metric: 0.7337 - lr: 3.0000e-04
# Epoch 58/80
# 100/100 [==============================] - 14s 143ms/step - loss: 0.4729 - prob_loss: 0.0584 - dist_loss: 2.0724 - prob_kld: 0.0105 - dist_relevant_mae: 2.0717 - dist_relevant_mse: 16.1063 - dist_dist_iou_metric: 0.7436 - val_loss: 0.5074 - val_prob_loss: 0.0603 - val_dist_loss: 2.2353 - val_prob_kld: 0.0156 - val_dist_relevant_mae: 2.2347 - val_dist_relevant_mse: 12.5472 - val_dist_dist_iou_metric: 0.7238 - lr: 3.0000e-04
# Epoch 59/80
# 100/100 [==============================] - 15s 153ms/step - loss: 0.4529 - prob_loss: 0.0579 - dist_loss: 1.9748 - prob_kld: 0.0098 - dist_relevant_mae: 1.9741 - dist_relevant_mse: 16.1477 - dist_dist_iou_metric: 0.7553 - val_loss: 0.5163 - val_prob_loss: 0.0609 - val_dist_loss: 2.2769 - val_prob_kld: 0.0162 - val_dist_relevant_mae: 2.2762 - val_dist_relevant_mse: 13.3819 - val_dist_dist_iou_metric: 0.7344 - lr: 3.0000e-04
# Epoch 60/80
# 100/100 [==============================] - 15s 153ms/step - loss: 0.4446 - prob_loss: 0.0591 - dist_loss: 1.9276 - prob_kld: 0.0106 - dist_relevant_mae: 1.9269 - dist_relevant_mse: 15.4071 - dist_dist_iou_metric: 0.7595 - val_loss: 0.4923 - val_prob_loss: 0.0603 - val_dist_loss: 2.1603 - val_prob_kld: 0.0155 - val_dist_relevant_mae: 2.1597 - val_dist_relevant_mse: 12.3644 - val_dist_dist_iou_metric: 0.7423 - lr: 3.0000e-04
# Epoch 61/80
# 100/100 [==============================] - 16s 157ms/step - loss: 0.4472 - prob_loss: 0.0575 - dist_loss: 1.9487 - prob_kld: 0.0096 - dist_relevant_mae: 1.9480 - dist_relevant_mse: 15.1342 - dist_dist_iou_metric: 0.7581 - val_loss: 0.5123 - val_prob_loss: 0.0603 - val_dist_loss: 2.2602 - val_prob_kld: 0.0155 - val_dist_relevant_mae: 2.2596 - val_dist_relevant_mse: 13.5005 - val_dist_dist_iou_metric: 0.7365 - lr: 3.0000e-04
# Epoch 62/80
# 100/100 [==============================] - 14s 143ms/step - loss: 0.4374 - prob_loss: 0.0567 - dist_loss: 1.9037 - prob_kld: 0.0092 - dist_relevant_mae: 1.9031 - dist_relevant_mse: 15.3226 - dist_dist_iou_metric: 0.7607 - val_loss: 0.5226 - val_prob_loss: 0.0628 - val_dist_loss: 2.2987 - val_prob_kld: 0.0181 - val_dist_relevant_mae: 2.2981 - val_dist_relevant_mse: 13.5716 - val_dist_dist_iou_metric: 0.7238 - lr: 3.0000e-04
# Epoch 63/80
# 100/100 [==============================] - 15s 147ms/step - loss: 0.4430 - prob_loss: 0.0570 - dist_loss: 1.9297 - prob_kld: 0.0095 - dist_relevant_mae: 1.9290 - dist_relevant_mse: 15.1493 - dist_dist_iou_metric: 0.7590 - val_loss: 0.5444 - val_prob_loss: 0.0625 - val_dist_loss: 2.4094 - val_prob_kld: 0.0178 - val_dist_relevant_mae: 2.4088 - val_dist_relevant_mse: 14.2077 - val_dist_dist_iou_metric: 0.7156 - lr: 3.0000e-04
# Epoch 64/80
# 100/100 [==============================] - 15s 146ms/step - loss: 0.4234 - prob_loss: 0.0579 - dist_loss: 1.8273 - prob_kld: 0.0090 - dist_relevant_mae: 1.8267 - dist_relevant_mse: 14.5834 - dist_dist_iou_metric: 0.7713 - val_loss: 0.5239 - val_prob_loss: 0.0623 - val_dist_loss: 2.3082 - val_prob_kld: 0.0175 - val_dist_relevant_mae: 2.3075 - val_dist_relevant_mse: 14.0429 - val_dist_dist_iou_metric: 0.7279 - lr: 3.0000e-04
# Epoch 65/80
# 100/100 [==============================] - 14s 143ms/step - loss: 0.4205 - prob_loss: 0.0567 - dist_loss: 1.8186 - prob_kld: 0.0090 - dist_relevant_mae: 1.8180 - dist_relevant_mse: 13.1420 - dist_dist_iou_metric: 0.7689 - val_loss: 0.5262 - val_prob_loss: 0.0611 - val_dist_loss: 2.3254 - val_prob_kld: 0.0164 - val_dist_relevant_mae: 2.3248 - val_dist_relevant_mse: 13.4344 - val_dist_dist_iou_metric: 0.7195 - lr: 3.0000e-04
# Epoch 66/80
# 100/100 [==============================] - 14s 142ms/step - loss: 0.4297 - prob_loss: 0.0569 - dist_loss: 1.8639 - prob_kld: 0.0088 - dist_relevant_mae: 1.8633 - dist_relevant_mse: 14.6190 - dist_dist_iou_metric: 0.7669 - val_loss: 0.5585 - val_prob_loss: 0.0634 - val_dist_loss: 2.4754 - val_prob_kld: 0.0187 - val_dist_relevant_mae: 2.4748 - val_dist_relevant_mse: 15.4843 - val_dist_dist_iou_metric: 0.7089 - lr: 3.0000e-04
# Epoch 67/80
# 100/100 [==============================] - 15s 145ms/step - loss: 0.4282 - prob_loss: 0.0565 - dist_loss: 1.8585 - prob_kld: 0.0085 - dist_relevant_mae: 1.8578 - dist_relevant_mse: 15.0369 - dist_dist_iou_metric: 0.7683 - val_loss: 0.5303 - val_prob_loss: 0.0621 - val_dist_loss: 2.3411 - val_prob_kld: 0.0174 - val_dist_relevant_mae: 2.3404 - val_dist_relevant_mse: 15.1175 - val_dist_dist_iou_metric: 0.7316 - lr: 3.0000e-04
# Epoch 68/80
# 100/100 [==============================] - 14s 143ms/step - loss: 0.3996 - prob_loss: 0.0573 - dist_loss: 1.7116 - prob_kld: 0.0084 - dist_relevant_mae: 1.7110 - dist_relevant_mse: 11.7717 - dist_dist_iou_metric: 0.7814 - val_loss: 0.5184 - val_prob_loss: 0.0624 - val_dist_loss: 2.2797 - val_prob_kld: 0.0177 - val_dist_relevant_mae: 2.2791 - val_dist_relevant_mse: 13.6810 - val_dist_dist_iou_metric: 0.7321 - lr: 3.0000e-04
# Epoch 69/80
# 100/100 [==============================] - 14s 145ms/step - loss: 0.4082 - prob_loss: 0.0556 - dist_loss: 1.7626 - prob_kld: 0.0081 - dist_relevant_mae: 1.7620 - dist_relevant_mse: 13.6757 - dist_dist_iou_metric: 0.7779 - val_loss: 0.5004 - val_prob_loss: 0.0614 - val_dist_loss: 2.1949 - val_prob_kld: 0.0167 - val_dist_relevant_mae: 2.1943 - val_dist_relevant_mse: 12.8150 - val_dist_dist_iou_metric: 0.7384 - lr: 3.0000e-04
# Epoch 70/80
# 100/100 [==============================] - 14s 143ms/step - loss: 0.4168 - prob_loss: 0.0570 - dist_loss: 1.7990 - prob_kld: 0.0082 - dist_relevant_mae: 1.7984 - dist_relevant_mse: 14.5598 - dist_dist_iou_metric: 0.7758 - val_loss: 0.5065 - val_prob_loss: 0.0619 - val_dist_loss: 2.2230 - val_prob_kld: 0.0171 - val_dist_relevant_mae: 2.2224 - val_dist_relevant_mse: 12.4401 - val_dist_dist_iou_metric: 0.7336 - lr: 3.0000e-04
# Epoch 71/80
# 100/100 [==============================] - 15s 147ms/step - loss: 0.4124 - prob_loss: 0.0554 - dist_loss: 1.7852 - prob_kld: 0.0081 - dist_relevant_mae: 1.7846 - dist_relevant_mse: 14.1065 - dist_dist_iou_metric: 0.7748 - val_loss: 0.4874 - val_prob_loss: 0.0603 - val_dist_loss: 2.1355 - val_prob_kld: 0.0156 - val_dist_relevant_mae: 2.1349 - val_dist_relevant_mse: 12.2404 - val_dist_dist_iou_metric: 0.7461 - lr: 3.0000e-04
# Epoch 72/80
# 100/100 [==============================] - 14s 141ms/step - loss: 0.4102 - prob_loss: 0.0573 - dist_loss: 1.7650 - prob_kld: 0.0089 - dist_relevant_mae: 1.7643 - dist_relevant_mse: 12.3644 - dist_dist_iou_metric: 0.7777 - val_loss: 0.5156 - val_prob_loss: 0.0616 - val_dist_loss: 2.2704 - val_prob_kld: 0.0168 - val_dist_relevant_mae: 2.2698 - val_dist_relevant_mse: 13.3278 - val_dist_dist_iou_metric: 0.7212 - lr: 3.0000e-04
# Epoch 73/80
# 100/100 [==============================] - 15s 151ms/step - loss: 0.4173 - prob_loss: 0.0558 - dist_loss: 1.8075 - prob_kld: 0.0082 - dist_relevant_mae: 1.8069 - dist_relevant_mse: 13.4853 - dist_dist_iou_metric: 0.7735 - val_loss: 0.5272 - val_prob_loss: 0.0618 - val_dist_loss: 2.3266 - val_prob_kld: 0.0171 - val_dist_relevant_mae: 2.3260 - val_dist_relevant_mse: 13.8117 - val_dist_dist_iou_metric: 0.7310 - lr: 3.0000e-04
# Epoch 74/80
# 100/100 [==============================] - 15s 149ms/step - loss: 0.3986 - prob_loss: 0.0556 - dist_loss: 1.7149 - prob_kld: 0.0077 - dist_relevant_mae: 1.7143 - dist_relevant_mse: 12.8985 - dist_dist_iou_metric: 0.7840 - val_loss: 0.4970 - val_prob_loss: 0.0605 - val_dist_loss: 2.1826 - val_prob_kld: 0.0158 - val_dist_relevant_mae: 2.1820 - val_dist_relevant_mse: 12.4656 - val_dist_dist_iou_metric: 0.7359 - lr: 3.0000e-04
# Epoch 75/80
# 100/100 [==============================] - 16s 164ms/step - loss: 0.3919 - prob_loss: 0.0565 - dist_loss: 1.6773 - prob_kld: 0.0078 - dist_relevant_mae: 1.6767 - dist_relevant_mse: 12.0992 - dist_dist_iou_metric: 0.7872 - val_loss: 0.5146 - val_prob_loss: 0.0613 - val_dist_loss: 2.2668 - val_prob_kld: 0.0165 - val_dist_relevant_mae: 2.2663 - val_dist_relevant_mse: 13.6199 - val_dist_dist_iou_metric: 0.7398 - lr: 3.0000e-04
# Epoch 76/80
# 100/100 [==============================] - 14s 143ms/step - loss: 0.4112 - prob_loss: 0.0568 - dist_loss: 1.7723 - prob_kld: 0.0077 - dist_relevant_mae: 1.7717 - dist_relevant_mse: 13.5133 - dist_dist_iou_metric: 0.7792 - val_loss: 0.5153 - val_prob_loss: 0.0625 - val_dist_loss: 2.2639 - val_prob_kld: 0.0178 - val_dist_relevant_mae: 2.2633 - val_dist_relevant_mse: 13.2739 - val_dist_dist_iou_metric: 0.7393 - lr: 3.0000e-04
# Epoch 77/80
# 100/100 [==============================] - 15s 148ms/step - loss: 0.3847 - prob_loss: 0.0545 - dist_loss: 1.6506 - prob_kld: 0.0073 - dist_relevant_mae: 1.6500 - dist_relevant_mse: 12.0811 - dist_dist_iou_metric: 0.7889 - val_loss: 0.4845 - val_prob_loss: 0.0598 - val_dist_loss: 2.1233 - val_prob_kld: 0.0151 - val_dist_relevant_mae: 2.1227 - val_dist_relevant_mse: 11.7588 - val_dist_dist_iou_metric: 0.7487 - lr: 3.0000e-04
# Epoch 78/80
# 100/100 [==============================] - 15s 153ms/step - loss: 0.3783 - prob_loss: 0.0549 - dist_loss: 1.6166 - prob_kld: 0.0070 - dist_relevant_mae: 1.6160 - dist_relevant_mse: 12.2837 - dist_dist_iou_metric: 0.7951 - val_loss: 0.5534 - val_prob_loss: 0.0635 - val_dist_loss: 2.4495 - val_prob_kld: 0.0187 - val_dist_relevant_mae: 2.4490 - val_dist_relevant_mse: 15.7428 - val_dist_dist_iou_metric: 0.7187 - lr: 3.0000e-04
# Epoch 79/80
# 100/100 [==============================] - 15s 147ms/step - loss: 0.3769 - prob_loss: 0.0550 - dist_loss: 1.6095 - prob_kld: 0.0070 - dist_relevant_mae: 1.6089 - dist_relevant_mse: 11.7806 - dist_dist_iou_metric: 0.7939 - val_loss: 0.5083 - val_prob_loss: 0.0622 - val_dist_loss: 2.2303 - val_prob_kld: 0.0175 - val_dist_relevant_mae: 2.2297 - val_dist_relevant_mse: 13.4868 - val_dist_dist_iou_metric: 0.7372 - lr: 3.0000e-04
# Epoch 80/80
# 100/100 [==============================] - 14s 145ms/step - loss: 0.3653 - prob_loss: 0.0547 - dist_loss: 1.5531 - prob_kld: 0.0071 - dist_relevant_mae: 1.5525 - dist_relevant_mse: 11.2173 - dist_dist_iou_metric: 0.7993 - val_loss: 0.5163 - val_prob_loss: 0.0622 - val_dist_loss: 2.2707 - val_prob_kld: 0.0174 - val_dist_relevant_mae: 2.2702 - val_dist_relevant_mse: 13.7618 - val_dist_dist_iou_metric: 0.7364 - lr: 3.0000e-04
#
# Loading network weights from 'weights_best.h5'.

# %%
model.optimize_thresholds(X_val, Y_val)
# Out:
# NMS threshold = 0.3:  15%|█▌        | 3/20 [00:00<00:00, 57.85it/s, 0.761 -> 0.000]
# NMS threshold = 0.4:  15%|█▌        | 3/20 [00:00<00:00, 91.15it/s, 0.761 -> 0.000]
# NMS threshold = 0.5:  15%|█▌        | 3/20 [00:00<00:00, 97.03it/s, 0.761 -> 0.000]
# Using optimized values: prob_thresh=0.380721, nms_thresh=0.3.
# Saving to 'thresholds.json'.
# {'prob': 0.38072118163108826, 'nms': 0.3}

# %% [markdown]
# ## Test network on one of the training images (self prediction)
#
# Self prediction is not a good way to evaluate the 'real' performance of the NN.  However it is good sanity test.  If the self prediction looks wrong something really went bad.

# %%
for n in range(10):
    labels, details = model.predict_instances(X_train[n], prob_thresh=0.5, nms_thresh=0.1)
    fig = imshow_multi2d([X_train[n],Y_train[n],labels],['input','ground truth','predicted instances'],1,3)

# %%
from skimage.io import imread
from tnia.plotting.plt_helper import random_label_cmap
from tnia.deeplearning.dl_helper import ray4_to_ellipsoid2d_labels
from csbdeep.utils import normalize
import numpy as np
test_name='phantom2.tif'
testim = imread(parent_path  / test_name) 
if (sub_sample != 1):
    testim = testim[::sub_sample,::sub_sample]  
testim = normalize(testim,1,99.8, axis=(0,1))
labels, details = model.predict_instances(testim, prob_thresh=0.5, nms_thresh=0.1)

if n_rays == 4:
    labels2 = np.zeros_like(labels)#ray4_to_ellipsoid2d_labels(details['coord'], testim.shape)
    fig = imshow_multi2d([testim,labels,labels2],['input','predicted octohedrons', 'rendered as ellipses'],1,3, width=14, height=8,colormaps=['gray', random_label_cmap(), random_label_cmap()])
else:
    fig = imshow_multi2d([testim,labels],['input','predicted octohedrons'],1,2, width=14, height=8,colormaps=['gray', random_label_cmap()])

# %%
import napari

viewer = napari.Viewer()
viewer.add_image(testim, name='testim')
viewer.add_labels(labels, name='labels2')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       1 import napari
#       3 viewer = napari.Viewer()
# ----> 4 viewer.add_image(testim, name='testim')
#       5 viewer.add_labels(labels, name='labels2')
#
# NameError: name 'testim' is not defined
